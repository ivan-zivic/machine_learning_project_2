# %%
import pandas as pd
import seaborn as sns
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from sklearn.metrics import silhouette_score
from kmodes.kprototypes import KPrototypes
from scipy.cluster.hierarchy import linkage, dendrogram
from sklearn.cluster import AgglomerativeClustering

# %matplotlib inline

# %%
df = pd.read_csv('kl.csv', encoding='ISO-8859-1')
df.head()
# Out:
#    Unnamed: 0      ID               Name   Age  \
# 0           0  158023           L. Messi  31.0
# 1           1   20801  Cristiano Ronaldo  33.0
# 2           2  190871          Neymar Jr  26.0
# 3           3  193080             De Gea  27.0
# 4           4  192985       K. De Bruyne  27.0
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png     94.0         94
# 1  https://cdn.sofifa.org/flags/38.png     94.0         94
# 2  https://cdn.sofifa.org/flags/54.png     92.0         93
# 3  https://cdn.sofifa.org/flags/45.png     91.0         93
# 4   https://cdn.sofifa.org/flags/7.png     91.0         92
#
#                   Club  ... Composure Marking StandingTackle  SlidingTackle  \
# 0         FC Barcelona  ...      96.0    33.0           28.0           26.0
# 1             Juventus  ...      95.0    28.0           31.0           23.0
# 2  Paris Saint-Germain  ...      94.0    27.0           24.0           33.0
# 3    Manchester United  ...      68.0    15.0           21.0           13.0
# 4      Manchester City  ...      88.0    68.0           58.0           51.0
#
#   GKDiving  GKHandling  GKKicking  GKPositioning GKReflexes Release Clause
# 0      6.0        11.0       15.0           14.0        8.0        226.5M
# 1      7.0        11.0       15.0           14.0       11.0        127.1M
# 2      9.0         9.0       15.0           15.0       11.0        228.1M
# 3     90.0        85.0       87.0           88.0       94.0        138.6M
# 4     15.0        13.0        5.0           10.0       13.0        196.4M
#
# [5 rows x 89 columns]

# %%
df.shape
# Out:
# (18207, 89)

# %%
df.isnull().mean()
# Out:
# Unnamed: 0        0.000000
# ID                0.000000
# Name              0.000000
# Age               0.000055
# Photo             0.000000
#                     ...
# GKHandling        0.002636
# GKKicking         0.002636
# GKPositioning     0.002636
# GKReflexes        0.002636
# Release Clause    0.085901
# Length: 89, dtype: float64

# %%
sns.heatmap(df.isna(), cmap='viridis', yticklabels=False, cbar=None)
# Out:
# <AxesSubplot:>

# %%
def missing_values_boundry(df, missing_percentige):
    
    columns_with_missing_values_above_border = []
    series = df.isna().mean()
    for index in series.index:
        if series[index] > missing_percentige:
            columns_with_missing_values_above_border.append(index)
    return columns_with_missing_values_above_border
        
missing_values_boundry(df, 0.3)
# Out:
# ['Loaned From']

# %%
df['Loaned From'].isna().mean()
# Out:
# 0.9305761520294392

# %%
df.drop('Loaned From', axis=1, inplace=True)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'Name', 'Age', 'Photo', 'Nationality', 'Flag',
#        'Overall', 'Potential', 'Club', 'Club Logo', 'Value', 'Wage', 'Special',
#        'Preferred Foot', 'International Reputation', 'Weak Foot',
#        'Skill Moves', 'Work Rate', 'Body Type', 'Real Face', 'Position',
#        'Jersey Number', 'Joined', 'Contract Valid Until', 'Height', 'Weight',
#        'LS', 'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW', 'LAM', 'CAM', 'RAM',
#        'LM', 'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM', 'CDM', 'RDM', 'RWB', 'LB',
#        'LCB', 'CB', 'RCB', 'RB', 'Crossing', 'Finishing', 'HeadingAccuracy',
#        'ShortPassing', 'Volleys', 'Dribbling', 'Curve', 'FKAccuracy',
#        'LongPassing', 'BallControl', 'Acceleration', 'SprintSpeed', 'Agility',
#        'Reactions', 'Balance', 'ShotPower', 'Jumping', 'Stamina', 'Strength',
#        'LongShots', 'Aggression', 'Interceptions', 'Positioning', 'Vision',
#        'Penalties', 'Composure', 'Marking', 'StandingTackle', 'SlidingTackle',
#        'GKDiving', 'GKHandling', 'GKKicking', 'GKPositioning', 'GKReflexes',
#        'Release Clause'],
#       dtype='object')

# %%
df['Position'].unique()
# Out:
# array(['RF', 'ST', 'LW', 'GK', 'RCM', 'LF', 'RS', 'RCB', 'LCM', 'CB',
#        'LDM', 'CAM', 'CDM', 'LS', 'LCB', 'RM', 'LAM', 'LM', 'LB', 'RDM',
#        'RW', 'CM', 'RB', 'RAM', 'CF', 'RWB', 'LWB', nan], dtype=object)

# %%
# podela promenljivih na numericke i kategoricke

numeric = []
categorical = []
for column in df.columns:
    if str(df[column].dtype) == 'object':
        categorical.append(column)
    else:
        numeric.append(column)
        
numeric
categorical

len(numeric) + len(categorical)
print('Broj kategorickih promenljivih:', len(categorical))
print('Broj numerickih promenljivih:', len(numeric))
# Out:
# Broj kategorickih promenljivih: 44
# Broj numerickih promenljivih: 44

# %%
# zamena NaN vrednosti zeljenim metodom (mean, mode, median ili random sample imputation-om)

def impute_value(df, variable, method='random sample'):

    if method == 'mean':
        df[variable].fillna(df[variable].mean(), inplace=True)
    elif method == 'mode':
        df[variable].fillna(df[variable].mode()[0], inplace=True)
    elif method == 'median':
        df[variable + '_median'] = df[variable].fillna(df[variable].median())
    else:
        df[variable + '_random_sample'] = df[variable]
        random_sample = df[variable].dropna().sample(df[variable].isna().sum(), random_state=0)
        random_sample.index = df.loc[df[variable].isna()].index
        df.loc[df[variable].isna(), variable] = random_sample

# %%
def find_irq_outliers(values):
    
    outliers = []
    sorted_values = sorted(values)
    min, max = np.percentile(sorted_values, [25, 75])
    irq_difference = max - min
    upper_border = max + 1.5 * irq_difference
    lower_border = min - 1.5 * irq_difference

    for value in sorted_values:
        if value < lower_border or value > upper_border:
#         if upper_border < value < lower_border:
            outliers.append(value)
    return outliers
        
outlier_numeric_columns = []
for numerical_variable in numeric:
    if len(find_irq_outliers(df[numerical_variable])):
        outlier_numeric_columns.append(numerical_variable)

outlier_numeric_columns
# Out:
# ['ID', 'Potential', 'Special']

# %%
for variable in numeric:
    if variable in outlier_numeric_columns:
        impute_value(df, variable, 'median')
        impute_value(df, variable)
        standard_deviation_old_values = df[variable].std()
        standard_deviation_median_values = df[variable + '_median'].std()
        standard_deviation_random_sample = df[variable + '_random_sample'].std()
        if abs(standard_deviation_median_values - standard_deviation_old_values) < abs(standard_deviation_random_sample - standard_deviation_old_values):
            df[variable] = df[variable + '_median']
        else:
            df[variable] = df[variable + '_random_sample']
        df.drop(columns=[variable + '_random_sample', variable + '_median'], inplace=True)

    else:
        impute_value(df, variable, 'mean')

# %%
for categorical_variable in categorical:
    impute_value(df, categorical_variable, 'mode')
sum(df[categorical].isna().sum().values)
# Out:
# 0

# %%
sum(df[numeric].isna().sum().values)
# Out:
# 0

# %%
sns.heatmap(df.isna(), cmap='viridis', yticklabels=False, cbar=None)
# Out:
# <AxesSubplot:>

# %%
# Funkcija koja vrsi skaliranje promenljivih zeljenom metodom

def feature_scaling(df, features, method):
    
    for feature in features:
        scaled_feature = method.fit_transform(df[[feature]])
        df[feature] = scaled_feature
        
feature_scaling(df, numeric, MinMaxScaler())

df[numeric].head()
# Out:
#    Unnamed: 0        ID       Age   Overall  Potential   Special  \
# 0    0.000000  0.640732  0.517241  1.000000   0.978723  0.910836
# 1    0.000055  0.084285  0.586207  1.000000   0.978723  0.926935
# 2    0.000110  0.773933  0.344828  0.958333   0.957447  0.874303
# 3    0.000165  0.782891  0.379310  0.937500   0.957447  0.458204
# 4    0.000220  0.782506  0.379310  0.937500   0.936170  0.959752
#
#    International Reputation  Weak Foot  Skill Moves  Jersey Number  ...  \
# 0                      1.00       0.75         0.75       0.091837  ...
# 1                      1.00       0.75         1.00       0.061224  ...
# 2                      1.00       1.00         1.00       0.091837  ...
# 3                      0.75       0.50         0.00       0.000000  ...
# 4                      0.75       1.00         0.75       0.061224  ...
#
#    Penalties  Composure   Marking  StandingTackle  SlidingTackle  GKDiving  \
# 0   0.804598   1.000000  0.329670        0.285714       0.261364  0.056180
# 1   0.919540   0.989247  0.274725        0.318681       0.227273  0.067416
# 2   0.873563   0.978495  0.263736        0.241758       0.340909  0.089888
# 3   0.402299   0.698925  0.131868        0.208791       0.113636  1.000000
# 4   0.850575   0.913978  0.714286        0.615385       0.545455  0.157303
#
#    GKHandling  GKKicking  GKPositioning  GKReflexes
# 0    0.109890   0.155556       0.146067    0.075269
# 1    0.109890   0.155556       0.146067    0.107527
# 2    0.087912   0.155556       0.157303    0.107527
# 3    0.923077   0.955556       0.977528    1.000000
# 4    0.131868   0.044444       0.101124    0.129032
#
# [5 rows x 44 columns]

# %%
from collections import Counter

# kmeans = KMeans(n_clusters=3, random_state=0)
# kmeans.fit(df[numeric])
# kmeans.labels_
# count = Counter(kmeans.labels_)
# d = {}
# for value, times in count.most_common():
#     d[value] = times
    
# d

sse = []
silhouette = []
for k in range(2, 11):
    kmeans = KMeans(n_clusters=k, random_state=0)
    kmeans.fit(df[numeric])
    sse.append(kmeans.inertia_)
    silhouette.append(silhouette_score(df[numeric], kmeans.labels_))

# %%
plt.plot(range(2, 11), sse)
plt.title('Elbow method')
plt.xlabel('K')
plt.ylabel('SSE')
# Out:
# Text(0, 0.5, 'SSE')

# %%
kmeans = KMeans(n_clusters=8, random_state=0)
kmeans.fit(df[numeric])
kmeans.labels_

count = Counter(kmeans.labels_)
d = {}
for value, times in count.most_common():
    d[value] = [times, times / len(df)]
d
# Out:
# {1: [3512, 0.19289284341187454],
#  7: [3113, 0.1709781951996485],
#  2: [2858, 0.15697259295875213],
#  4: [2561, 0.1406601856428846],
#  6: [2234, 0.12270006041632339],
#  3: [1903, 0.10452023946833636],
#  5: [1013, 0.05563794145109024],
#  0: [1013, 0.05563794145109024]}

# %%
df['Position'].unique()
# Out:
# array(['RF', 'ST', 'LW', 'GK', 'RCM', 'LF', 'RS', 'RCB', 'LCM', 'CB',
#        'LDM', 'CAM', 'CDM', 'LS', 'LCB', 'RM', 'LAM', 'LM', 'LB', 'RDM',
#        'RW', 'CM', 'RB', 'RAM', 'CF', 'RWB', 'LWB'], dtype=object)

# %% [markdown]
# Golman - GK
# Odbrana - RWB, RB, RCB, CB, LCB, LB, LWB
# Vezni red - RDM, CDM, LDM, RM, RCM, CM, LCM, LM, RAM, CAM, LAM
# Napad - RF, CF, LF, RS, ST, LS, LW, RW

# %%
l1 = ['GK', 'RWB', 'RB', 'RCB', 'CB', 'LCB', 'LB', 'LWB', 'RDM', 'CDM',
      'LDM', 'RM', 'RCM', 'CM', 'LCM', 'LM', 'RAM', 'CAM', 'LAM',
     'RF', 'CF', 'LF', 'RS', 'ST', 'LS']

l2 = ['RF', 'ST', 'LW', 'GK', 'RCM', 'LF', 'RS', 'RCB', 'LCM', 'CB',
       'LDM', 'CAM', 'CDM', 'LS', 'LCB', 'RM', 'LAM', 'LM', 'LB', 'RDM',
       'RW', 'CM', 'RB', 'RAM', 'CF', 'RWB', 'LWB']

a = []

for i in l2:
    if i not in l1:
        a.append(i)
        
a
# Out:
# ['LW', 'RW']

# %% [markdown]
# Golman - GK
# Odbrana - +RWB, +RB, -RCB, +CB, +LCB, +LB, +LWB
# Vezni red - +RDM, +CDM, +LDM, +RM, +RCM, +CM, +LCM, +LM, +RAM, +CAM, +LAM
# Napad - +RF, +CF, +LF, +RS, +ST, +LS, +LW, +RW

# %%
def f(df, cluster_number, original_dataset_length):
    
    print(f'Broj igraca u klasteru {cluster_number}: {len(df)}, ({len(df) / original_dataset_length})' )
    print()

    # Napad

    df_num_of_attackers = len(df.loc[(df['Position'] == 'RF') | (df['Position'] == 'LF') | (df['Position'] == 'RW') | (df['Position'] == 'LW') | (df['Position'] == 'ST') | (df['Position'] =='CF') |  (df['Position'] == 'RS') | (df['Position'] == 'LS')])
    df_num_of_attackers_percentige = df_num_of_attackers / len(df)

    print(f'NAPAD: {df_num_of_attackers} ({df_num_of_attackers_percentige})')
    rf = df.loc[df['Position'] == 'RF']#
    print('Broj igraca na poziciji RF:', len(rf))#
    lf = df.loc[df['Position'] == 'LF']#
    print('Broj igraca na poziciji LF:', len(lf))#
    rf = df.loc[df['Position'] == 'RW']# 
    print('Broj igraca na poziciji RW:', len(rf))#
    lf = df.loc[df['Position'] == 'LW']# 
    print('Broj igraca na poziciji LW:', len(lf))#
    st = df.loc[df['Position'] == 'ST']#
    print('Broj igraca na poziciji ST:', len(st))#
    cf = df.loc[df['Position'] == 'CF']#
    print('Broj igraca na poziciji CF:', len(cf))#
    rs = df.loc[df['Position'] == 'RS']#
    print('Broj igraca na poziciji RS:', len(rs))#
    ls = df.loc[df['Position'] == 'LS']#
    print('Broj igraca na poziciji LS:', len(ls))#
    print()

    # Vezni red

    df_num_of_mid = len(df.loc[(df['Position'] == 'RDM') | (df['Position'] == 'CDM') | (df['Position'] == 'LDM') | (df['Position'] == 'RM') | (df['Position'] == 'RCM') | (df['Position'] == 'CM') | (df['Position'] == 'LCM') | (df['Position'] == 'LM') | (df['Position'] == 'RAM') | (df['Position'] == 'CAM') | (df['Position'] =='LAM')])
    df_num_of_mid_percentige = df_num_of_mid / len(df)

    print(f'VEZNI RED: {df_num_of_mid} ({df_num_of_mid_percentige})')
    rdm = df.loc[df['Position'] == 'RDM']#
    print('Broj igraca na poziciji RDM:', len(rdm))#
    cdm = df.loc[df['Position'] == 'CDM']#
    print('Broj igraca na poziciji CDM:', len(cdm))#
    ldm = df.loc[df['Position'] == 'LDM']#
    print('Broj igraca na poziciji LDM:', len(ldm))#
    rm = df.loc[df['Position'] == 'RM']#
    print('Broj igraca na poziciji RM:', len(rm))#
    rcm = df.loc[df['Position'] == 'RCM']#
    print('Broj igraca na poziciji RCM:', len(rcm))#
    cm = df.loc[df['Position'] == 'CM']#
    print('Broj igraca na poziciji CM:', len(cm))#
    lcm = df.loc[df['Position'] == 'LCM']#
    print('Broj igraca na poziciji LCM:', len(lcm))#
    lm = df.loc[df['Position'] == 'LM']#
    print('Broj igraca na poziciji LM:', len(lm))#
    ram = df.loc[df['Position'] == 'RAM']#
    print('Broj igraca na poziciji RAM:', len(ram))#
    cam = df.loc[df['Position'] == 'CAM']#
    print('Broj igraca na poziciji CAM:', len(cam))#
    lam = df.loc[df['Position'] == 'LAM']#
    print('Broj igraca na poziciji LAM:', len(lam))#
    print()

    # Odbrana

    df_num_of_dif = len(df.loc[(df['Position'] == 'RWB') | (df['Position'] == 'RB') | (df['Position'] == 'RCB') | (df['Position'] == 'CB') | (df['Position'] == 'LCB') | (df['Position'] == 'LB') | (df['Position'] == 'LWB')])
    df_num_of_dif_percentige = df_num_of_dif / len(df)


    print(f'ODBRANA: {df_num_of_dif} ({df_num_of_dif_percentige})')
    rwb = df.loc[df['Position'] == 'RWB']#
    print('Broj igraca na poziciji RWB', len(rwb))#
    rb = df.loc[df['Position'] == 'RB']#
    print('Broj igraca na poziciji RB', len(rb))#
    rb = df.loc[df['Position'] == 'RCB']
    print('Broj igraca na poziciji RCB', len(rb))
    cb = df.loc[df['Position'] == 'CB']#
    print('Broj igraca na poziciji CB', len(cb))#
    lcb = df.loc[df['Position'] == 'LCB']#
    print('Broj igraca na poziciji LCB', len(lcb))#
    lb = df.loc[df['Position'] == 'LB']#
    print('Broj igraca na poziciji LB', len(lb))#
    lwb = df.loc[df['Position'] == 'LWB']#
    print('Broj igraca na poziciji LWB', len(lwb))#
    print()

    # Golmani

    df_num_of_gk = len(df.loc[df['Position'] == 'GK'])
    df_num_of_gk_percentige = df_num_of_gk / len(df)
    
    print(f'GOLMANI: {df_num_of_gk} ({df_num_of_gk_percentige})')
    print()

# %%
df['cluster_marks'] = kmeans.labels_

df_cluster_0 = df.loc[df['cluster_marks'] == 0]
df_cluster_1 = df.loc[df['cluster_marks'] == 1]
df_cluster_2 = df.loc[df['cluster_marks'] == 2]
df_cluster_3 = df.loc[df['cluster_marks'] == 3]
df_cluster_4 = df.loc[df['cluster_marks'] == 4]
df_cluster_5 = df.loc[df['cluster_marks'] == 5]
df_cluster_6 = df.loc[df['cluster_marks'] == 6]
df_cluster_7 = df.loc[df['cluster_marks'] == 7]

f(df_cluster_0, 0, len(df))
f(df_cluster_1, 1, len(df))
f(df_cluster_2, 2, len(df))
f(df_cluster_3, 3, len(df))
f(df_cluster_4, 4, len(df))
f(df_cluster_5, 5, len(df))
f(df_cluster_6, 6, len(df))
f(df_cluster_7, 7, len(df))
# Out:
# Broj igraca u klasteru 0: 1013, (0.05563794145109024)
#
# NAPAD: 1 (0.0009871668311944718)
# Broj igraca na poziciji RF: 0
# Broj igraca na poziciji LF: 0
# Broj igraca na poziciji RW: 0
# Broj igraca na poziciji LW: 0
# Broj igraca na poziciji ST: 1
# Broj igraca na poziciji CF: 0
# Broj igraca na poziciji RS: 0
# Broj igraca na poziciji LS: 0
#
# VEZNI RED: 0 (0.0)
# Broj igraca na poziciji RDM: 0
# Broj igraca na poziciji CDM: 0
# Broj igraca na poziciji LDM: 0
# Broj igraca na poziciji RM: 0
# Broj igraca na poziciji RCM: 0
# Broj igraca na poziciji CM: 0
# Broj igraca na poziciji LCM: 0
# Broj igraca na poziciji LM: 0
# Broj igraca na poziciji RAM: 0
# Broj igraca na poziciji CAM: 0
# Broj igraca na poziciji LAM: 0
#
# ODBRANA: 0 (0.0)
# Broj igraca na poziciji RWB 0
# Broj igraca na poziciji RB 0
# Broj igraca na poziciji RCB 0
# Broj igraca na poziciji CB 0
# Broj igraca na poziciji LCB 0
# Broj igraca na poziciji LB 0
# Broj igraca na poziciji LWB 0
#
# GOLMANI: 1012 (0.9990128331688055)
#
# Broj igraca u klasteru 1: 3512, (0.19289284341187454)
#
# NAPAD: 143 (0.04071753986332574)
# Broj igraca na poziciji RF: 0
# Broj igraca na poziciji LF: 0
# Broj igraca na poziciji RW: 25
# Broj igraca na poziciji LW: 27
# Broj igraca na poziciji ST: 81
# Broj igraca na poziciji CF: 2
# Broj igraca na poziciji RS: 5
# Broj igraca na poziciji LS: 3
#
# VEZNI RED: 1913 (0.5447038724373576)
# Broj igraca na poziciji RDM: 78
# Broj igraca na poziciji CDM: 390
# Broj igraca na poziciji LDM: 87
# Broj igraca na poziciji RM: 162
# Broj igraca na poziciji RCM: 151
# Broj igraca na poziciji CM: 635
# Broj igraca na poziciji LCM: 134
# Broj igraca na poziciji LM: 152
# Broj igraca na poziciji RAM: 1
# Broj igraca na poziciji CAM: 123
# Broj igraca na poziciji LAM: 0
#
# ODBRANA: 1456 (0.4145785876993166)
# Broj igraca na poziciji RWB 45
# Broj igraca na poziciji RB 578
# Broj igraca na poziciji RCB 41
# Broj igraca na poziciji CB 107
# Broj igraca na poziciji LCB 48
# Broj igraca na poziciji LB 598
# Broj igraca na poziciji LWB 39
#
# GOLMANI: 0 (0.0)
#
# Broj igraca u klasteru 2: 2858, (0.15697259295875213)
#
# NAPAD: 1650 (0.5773268019594122)
# Broj igraca na poziciji RF: 0
# Broj igraca na poziciji LF: 1
# Broj igraca na poziciji RW: 149
# Broj igraca na poziciji LW: 156
# Broj igraca na poziciji ST: 1181
# Broj igraca na poziciji CF: 35
# Broj igraca na poziciji RS: 65
# Broj igraca na poziciji LS: 63
#
# VEZNI RED: 1200 (0.4198740377886634)
# Broj igraca na poziciji RDM: 1
# Broj igraca na poziciji CDM: 0
# Broj igraca na poziciji LDM: 2
# Broj igraca na poziciji RM: 384
# Broj igraca na poziciji RCM: 12
# Broj igraca na poziciji CM: 144
# Broj igraca na poziciji LCM: 9
# Broj igraca na poziciji LM: 348
# Broj igraca na poziciji RAM: 1
# Broj igraca na poziciji CAM: 298
# Broj igraca na poziciji LAM: 1
#
# ODBRANA: 8 (0.0027991602519244225)
# Broj igraca na poziciji RWB 1
# Broj igraca na poziciji RB 2
# Broj igraca na poziciji RCB 0
# Broj igraca na poziciji CB 1
# Broj igraca na poziciji LCB 0
# Broj igraca na poziciji LB 3
# Broj igraca na poziciji LWB 1
#
# GOLMANI: 0 (0.0)
#
# Broj igraca u klasteru 3: 1903, (0.10452023946833636)
#
# NAPAD: 2 (0.0010509721492380452)
# Broj igraca na poziciji RF: 0
# Broj igraca na poziciji LF: 0
# Broj igraca na poziciji RW: 0
# Broj igraca na poziciji LW: 0
# Broj igraca na poziciji ST: 2
# Broj igraca na poziciji CF: 0
# Broj igraca na poziciji RS: 0
# Broj igraca na poziciji LS: 0
#
# VEZNI RED: 164 (0.0861797162375197)
# Broj igraca na poziciji RDM: 25
# Broj igraca na poziciji CDM: 94
# Broj igraca na poziciji LDM: 22
# Broj igraca na poziciji RM: 0
# Broj igraca na poziciji RCM: 8
# Broj igraca na poziciji CM: 4
# Broj igraca na poziciji LCM: 9
# Broj igraca na poziciji LM: 1
# Broj igraca na poziciji RAM: 0
# Broj igraca na poziciji CAM: 1
# Broj igraca na poziciji LAM: 0
#
# ODBRANA: 1737 (0.9127693116132423)
# Broj igraca na poziciji RWB 1
# Broj igraca na poziciji RB 57
# Broj igraca na poziciji RCB 443
# Broj igraca na poziciji CB 747
# Broj igraca na poziciji LCB 424
# Broj igraca na poziciji LB 64
# Broj igraca na poziciji LWB 1
#
# GOLMANI: 0 (0.0)
#
# Broj igraca u klasteru 4: 2561, (0.1406601856428846)
#
# NAPAD: 50 (0.01952362358453729)
# Broj igraca na poziciji RF: 1
# Broj igraca na poziciji LF: 3
# Broj igraca na poziciji RW: 10
# Broj igraca na poziciji LW: 15
# Broj igraca na poziciji ST: 13
# Broj igraca na poziciji CF: 2
# Broj igraca na poziciji RS: 3
# Broj igraca na poziciji LS: 3
#
# VEZNI RED: 1617 (0.631393986723936)
# Broj igraca na poziciji RDM: 130
# Broj igraca na poziciji CDM: 296
# Broj igraca na poziciji LDM: 114
# Broj igraca na poziciji RM: 104
# Broj igraca na poziciji RCM: 186
# Broj igraca na poziciji CM: 373
# Broj igraca na poziciji LCM: 183
# Broj igraca na poziciji LM: 106
# Broj igraca na poziciji RAM: 4
# Broj igraca na poziciji CAM: 120
# Broj igraca na poziciji LAM: 1
#
# ODBRANA: 894 (0.3490823896915268)
# Broj igraca na poziciji RWB 19
# Broj igraca na poziciji RB 335
# Broj igraca na poziciji RCB 52
# Broj igraca na poziciji CB 71
# Broj igraca na poziciji LCB 61
# Broj igraca na poziciji LB 335
# Broj igraca na poziciji LWB 21
#
# GOLMANI: 0 (0.0)
#
# Broj igraca u klasteru 5: 1013, (0.05563794145109024)
#
# NAPAD: 0 (0.0)
# Broj igraca na poziciji RF: 0
# Broj igraca na poziciji LF: 0
# Broj igraca na poziciji RW: 0
# Broj igraca na poziciji LW: 0
# Broj igraca na poziciji ST: 0
# Broj igraca na poziciji CF: 0
# Broj igraca na poziciji RS: 0
# Broj igraca na poziciji LS: 0
#
# VEZNI RED: 0 (0.0)
# Broj igraca na poziciji RDM: 0
# Broj igraca na poziciji CDM: 0
# Broj igraca na poziciji LDM: 0
# Broj igraca na poziciji RM: 0
# Broj igraca na poziciji RCM: 0
# Broj igraca na poziciji CM: 0
# Broj igraca na poziciji LCM: 0
# Broj igraca na poziciji LM: 0
# Broj igraca na poziciji RAM: 0
# Broj igraca na poziciji CAM: 0
# Broj igraca na poziciji LAM: 0
#
# ODBRANA: 0 (0.0)
# Broj igraca na poziciji RWB 0
# Broj igraca na poziciji RB 0
# Broj igraca na poziciji RCB 0
# Broj igraca na poziciji CB 0
# Broj igraca na poziciji LCB 0
# Broj igraca na poziciji LB 0
# Broj igraca na poziciji LWB 0
#
# GOLMANI: 1013 (1.0)
#
# Broj igraca u klasteru 6: 2234, (0.12270006041632339)
#
# NAPAD: 9 (0.0040286481647269475)
# Broj igraca na poziciji RF: 0
# Broj igraca na poziciji LF: 0
# Broj igraca na poziciji RW: 0
# Broj igraca na poziciji LW: 2
# Broj igraca na poziciji ST: 7
# Broj igraca na poziciji CF: 0
# Broj igraca na poziciji RS: 0
# Broj igraca na poziciji LS: 0
#
# VEZNI RED: 459 (0.20546105640107432)
# Broj igraca na poziciji RDM: 7
# Broj igraca na poziciji CDM: 168
# Broj igraca na poziciji LDM: 12
# Broj igraca na poziciji RM: 24
# Broj igraca na poziciji RCM: 6
# Broj igraca na poziciji CM: 204
# Broj igraca na poziciji LCM: 11
# Broj igraca na poziciji LM: 17
# Broj igraca na poziciji RAM: 0
# Broj igraca na poziciji CAM: 10
# Broj igraca na poziciji LAM: 0
#
# ODBRANA: 1766 (0.7905102954341987)
# Broj igraca na poziciji RWB 21
# Broj igraca na poziciji RB 319
# Broj igraca na poziciji RCB 125
# Broj igraca na poziciji CB 852
# Broj igraca na poziciji LCB 115
# Broj igraca na poziciji LB 319
# Broj igraca na poziciji LWB 15
#
# GOLMANI: 0 (0.0)
#
# Broj igraca u klasteru 7: 3113, (0.1709781951996485)
#
# NAPAD: 1623 (0.5213620301959525)
# Broj igraca na poziciji RF: 15
# Broj igraca na poziciji LF: 11
# Broj igraca na poziciji RW: 186
# Broj igraca na poziciji LW: 181
# Broj igraca na poziciji ST: 927
# Broj igraca na poziciji CF: 35
# Broj igraca na poziciji RS: 130
# Broj igraca na poziciji LS: 138
#
# VEZNI RED: 1485 (0.47703180212014135)
# Broj igraca na poziciji RDM: 7
# Broj igraca na poziciji CDM: 0
# Broj igraca na poziciji LDM: 6
# Broj igraca na poziciji RM: 450
# Broj igraca na poziciji RCM: 28
# Broj igraca na poziciji CM: 34
# Broj igraca na poziciji LCM: 49
# Broj igraca na poziciji LM: 471
# Broj igraca na poziciji RAM: 15
# Broj igraca na poziciji CAM: 406
# Broj igraca na poziciji LAM: 19
#
# ODBRANA: 5 (0.0016061676839061998)
# Broj igraca na poziciji RWB 0
# Broj igraca na poziciji RB 0
# Broj igraca na poziciji RCB 1
# Broj igraca na poziciji CB 0
# Broj igraca na poziciji LCB 0
# Broj igraca na poziciji LB 3
# Broj igraca na poziciji LWB 1
#
# GOLMANI: 0 (0.0)

# %%
player = df_cluster_0.loc[df_cluster_0['Position'] == 'ST']
player
# Out:
#        Unnamed: 0        ID     Name       Age  \
# 16450    0.903548  0.786261  S. Paul  0.517241
#
#                                                 Photo Nationality  \
# 16450  https://cdn.sofifa.org/players/4/19/193911.png       India
#
#                                        Flag   Overall  Potential       Club  \
# 16450  https://cdn.sofifa.org/flags/159.png  0.229167   0.191489  AS Monaco
#
#        ...   Marking StandingTackle SlidingTackle  GKDiving GKHandling  \
# 16450  ...  0.098901       0.142857      0.102273   0.58427   0.516484
#
#        GKKicking  GKPositioning  GKReflexes Release Clause cluster_marks
# 16450   0.677778       0.629213    0.634409          1.1M             0
#
# [1 rows x 89 columns]

# %%
plt.plot(range(2, 11), silhouette)
plt.title('Silhouette test')
plt.xlabel('K')
plt.ylabel('Silhouette score')
# Out:
# Text(0, 0.5, 'Silhouette score')

# %%
kmeans = KMeans(n_clusters=2, random_state=0)
kmeans.fit(df[numeric])
kmeans.labels_

count = Counter(kmeans.labels_)
d = {}
for value, times in count.most_common():
    d[value] = [times, times / len(df)]
d
# Out:
# {1: [16180, 0.8886691931674631], 0: [2027, 0.11133080683253693]}

# %%
df['cluster_marks'] = kmeans.labels_

df_cluster_0 = df.loc[df['cluster_marks'] == 0]
df_cluster_1 = df.loc[df['cluster_marks'] == 1]

f(df_cluster_0, 0, len(df))
f(df_cluster_1, 1, len(df))
# Out:
# Broj igraca u klasteru 0: 2027, (0.11133080683253693)
#
# NAPAD: 1 (0.000493339911198816)
# Broj igraca na poziciji RF: 0
# Broj igraca na poziciji LF: 0
# Broj igraca na poziciji ST: 1
# Broj igraca na poziciji CF: 0
# Broj igraca na poziciji RS: 0
# Broj igraca na poziciji LS: 0
#
# VEZNI RED: 0 (0.0)
# Broj igraca na poziciji RDM: 0
# Broj igraca na poziciji CDM: 0
# Broj igraca na poziciji LDM: 0
# Broj igraca na poziciji RM: 0
# Broj igraca na poziciji RCM: 0
# Broj igraca na poziciji CM: 0
# Broj igraca na poziciji LCM: 0
# Broj igraca na poziciji LM: 0
# Broj igraca na poziciji RAM: 0
# Broj igraca na poziciji CAM: 0
# Broj igraca na poziciji LAM: 0
#
# ODBRANA: 1 (0.000493339911198816)
# Broj igraca na poziciji RWB 0
# Broj igraca na poziciji RB 0
# Broj igraca na poziciji CB 1
# Broj igraca na poziciji LCB 0
# Broj igraca na poziciji LB 0
# Broj igraca na poziciji LWB 0
#
# GOLMANI: 2025 (0.9990133201776024)
#
# Broj igraca u klasteru 1: 16180, (0.8886691931674631)
#
# NAPAD: 2726 (0.1684796044499382)
# Broj igraca na poziciji RF: 16
# Broj igraca na poziciji LF: 15
# Broj igraca na poziciji ST: 2211
# Broj igraca na poziciji CF: 74
# Broj igraca na poziciji RS: 203
# Broj igraca na poziciji LS: 207
#
# VEZNI RED: 6838 (0.42262051915945614)
# Broj igraca na poziciji RDM: 248
# Broj igraca na poziciji CDM: 948
# Broj igraca na poziciji LDM: 243
# Broj igraca na poziciji RM: 1124
# Broj igraca na poziciji RCM: 391
# Broj igraca na poziciji CM: 1394
# Broj igraca na poziciji LCM: 395
# Broj igraca na poziciji LM: 1095
# Broj igraca na poziciji RAM: 21
# Broj igraca na poziciji CAM: 958
# Broj igraca na poziciji LAM: 21
#
# ODBRANA: 5203 (0.3215698393077874)
# Broj igraca na poziciji RWB 87
# Broj igraca na poziciji RB 1291
# Broj igraca na poziciji CB 1777
# Broj igraca na poziciji LCB 648
# Broj igraca na poziciji LB 1322
# Broj igraca na poziciji LWB 78
#
# GOLMANI: 0 (0.0)

# %%
player = df_cluster_0.loc[df_cluster_0['Position'] == 'ST']
player
# Out:
#        Unnamed: 0        ID     Name       Age  \
# 16450    0.903548  0.786261  S. Paul  0.517241
#
#                                                 Photo Nationality  \
# 16450  https://cdn.sofifa.org/players/4/19/193911.png       India
#
#                                        Flag   Overall  Potential       Club  \
# 16450  https://cdn.sofifa.org/flags/159.png  0.229167   0.191489  AS Monaco
#
#        ...   Marking StandingTackle SlidingTackle  GKDiving GKHandling  \
# 16450  ...  0.098901       0.142857      0.102273   0.58427   0.516484
#
#        GKKicking  GKPositioning  GKReflexes Release Clause cluster_marks
# 16450   0.677778       0.629213    0.634409          1.1M             0
#
# [1 rows x 89 columns]

# %%
# Koristiti domensko znanje prilikom odabira k

# Generalno, postoje 4 razlicite pozicije (golman, odbrana, vezni red i napad), tako da prvo pokusati za k=4

kmeans = KMeans(n_clusters=4, random_state=0)
kmeans.fit(df[numeric])
kmeans.labels_

count = Counter(kmeans.labels_)
d = {}
for value, times in count.most_common():
    d[value] = [times, times / len(df)]
d
# Out:
# {2: [5899, 0.3239962651727358],
#  3: [5522, 0.30328994342835175],
#  0: [4760, 0.26143790849673204],
#  1: [2026, 0.11127588290218048]}

# %%
df['cluster_marks'] = kmeans.labels_

df_cluster_0 = df.loc[df['cluster_marks'] == 0]
df_cluster_1 = df.loc[df['cluster_marks'] == 1]
df_cluster_2 = df.loc[df['cluster_marks'] == 2]
df_cluster_3 = df.loc[df['cluster_marks'] == 3]

f(df_cluster_0, 0, len(df))
f(df_cluster_1, 1, len(df))
f(df_cluster_2, 2, len(df))
f(df_cluster_3, 3, len(df))
# Out:
# Broj igraca u klasteru 0: 4760, (0.26143790849673204)
#
# NAPAD: 2545 (0.5346638655462185)
# Broj igraca na poziciji RF: 5
# Broj igraca na poziciji LF: 7
# Broj igraca na poziciji RW: 248
# Broj igraca na poziciji LW: 260
# Broj igraca na poziciji ST: 1719
# Broj igraca na poziciji CF: 50
# Broj igraca na poziciji RS: 128
# Broj igraca na poziciji LS: 128
#
# VEZNI RED: 2176 (0.45714285714285713)
# Broj igraca na poziciji RDM: 11
# Broj igraca na poziciji CDM: 7
# Broj igraca na poziciji LDM: 10
# Broj igraca na poziciji RM: 624
# Broj igraca na poziciji RCM: 34
# Broj igraca na poziciji CM: 306
# Broj igraca na poziciji LCM: 40
# Broj igraca na poziciji LM: 621
# Broj igraca na poziciji RAM: 3
# Broj igraca na poziciji CAM: 512
# Broj igraca na poziciji LAM: 8
#
# ODBRANA: 39 (0.00819327731092437)
# Broj igraca na poziciji RWB 5
# Broj igraca na poziciji RB 10
# Broj igraca na poziciji RCB 1
# Broj igraca na poziciji CB 3
# Broj igraca na poziciji LCB 1
# Broj igraca na poziciji LB 14
# Broj igraca na poziciji LWB 5
#
# GOLMANI: 0 (0.0)
#
# Broj igraca u klasteru 1: 2026, (0.11127588290218048)
#
# NAPAD: 1 (0.0004935834155972359)
# Broj igraca na poziciji RF: 0
# Broj igraca na poziciji LF: 0
# Broj igraca na poziciji RW: 0
# Broj igraca na poziciji LW: 0
# Broj igraca na poziciji ST: 1
# Broj igraca na poziciji CF: 0
# Broj igraca na poziciji RS: 0
# Broj igraca na poziciji LS: 0
#
# VEZNI RED: 0 (0.0)
# Broj igraca na poziciji RDM: 0
# Broj igraca na poziciji CDM: 0
# Broj igraca na poziciji LDM: 0
# Broj igraca na poziciji RM: 0
# Broj igraca na poziciji RCM: 0
# Broj igraca na poziciji CM: 0
# Broj igraca na poziciji LCM: 0
# Broj igraca na poziciji LM: 0
# Broj igraca na poziciji RAM: 0
# Broj igraca na poziciji CAM: 0
# Broj igraca na poziciji LAM: 0
#
# ODBRANA: 0 (0.0)
# Broj igraca na poziciji RWB 0
# Broj igraca na poziciji RB 0
# Broj igraca na poziciji RCB 0
# Broj igraca na poziciji CB 0
# Broj igraca na poziciji LCB 0
# Broj igraca na poziciji LB 0
# Broj igraca na poziciji LWB 0
#
# GOLMANI: 2025 (0.9995064165844028)
#
# Broj igraca u klasteru 2: 5899, (0.3239962651727358)
#
# NAPAD: 72 (0.012205458552296999)
# Broj igraca na poziciji RF: 0
# Broj igraca na poziciji LF: 0
# Broj igraca na poziciji RW: 3
# Broj igraca na poziciji LW: 4
# Broj igraca na poziciji ST: 65
# Broj igraca na poziciji CF: 0
# Broj igraca na poziciji RS: 0
# Broj igraca na poziciji LS: 0
#
# VEZNI RED: 1412 (0.23936260383115782)
# Broj igraca na poziciji RDM: 68
# Broj igraca na poziciji CDM: 525
# Broj igraca na poziciji LDM: 82
# Broj igraca na poziciji RM: 57
# Broj igraca na poziciji RCM: 76
# Broj igraca na poziciji CM: 450
# Broj igraca na poziciji LCM: 74
# Broj igraca na poziciji LM: 50
# Broj igraca na poziciji RAM: 1
# Broj igraca na poziciji CAM: 29
# Broj igraca na poziciji LAM: 0
#
# ODBRANA: 4415 (0.7484319376165451)
# Broj igraca na poziciji RWB 47
# Broj igraca na poziciji RB 783
# Broj igraca na poziciji RCB 570
# Broj igraca na poziciji CB 1642
# Broj igraca na poziciji LCB 550
# Broj igraca na poziciji LB 786
# Broj igraca na poziciji LWB 37
#
# GOLMANI: 0 (0.0)
#
# Broj igraca u klasteru 3: 5522, (0.30328994342835175)
#
# NAPAD: 860 (0.15574067366896052)
# Broj igraca na poziciji RF: 11
# Broj igraca na poziciji LF: 8
# Broj igraca na poziciji RW: 119
# Broj igraca na poziciji LW: 117
# Broj igraca na poziciji ST: 427
# Broj igraca na poziciji CF: 24
# Broj igraca na poziciji RS: 75
# Broj igraca na poziciji LS: 79
#
# VEZNI RED: 3250 (0.5885548714233974)
# Broj igraca na poziciji RDM: 169
# Broj igraca na poziciji CDM: 416
# Broj igraca na poziciji LDM: 151
# Broj igraca na poziciji RM: 443
# Broj igraca na poziciji RCM: 281
# Broj igraca na poziciji CM: 638
# Broj igraca na poziciji LCM: 281
# Broj igraca na poziciji LM: 424
# Broj igraca na poziciji RAM: 17
# Broj igraca na poziciji CAM: 417
# Broj igraca na poziciji LAM: 13
#
# ODBRANA: 1412 (0.25570445490764215)
# Broj igraca na poziciji RWB 35
# Broj igraca na poziciji RB 498
# Broj igraca na poziciji RCB 91
# Broj igraca na poziciji CB 133
# Broj igraca na poziciji LCB 97
# Broj igraca na poziciji LB 522
# Broj igraca na poziciji LWB 36
#
# GOLMANI: 0 (0.0)

# %%
# Dalje, ukoliko znammo da se svaka pozicija (odbrana, vezni, red i napad) moze podeliti na...
# ... podpozicije, dolazimo na 27 razlicitih podpozicija
# Pokusati za k=27

kmeans = KMeans(n_clusters=27, random_state=0)
kmeans.fit(df[numeric])
kmeans.labels_

count = Counter(kmeans.labels_)
d = {}
for value, times in count.most_common():
    d[value] = [times, times / len(df)]
d
# Out:
# {12: [975, 0.0535508320975449],
#  11: [918, 0.05042016806722689],
#  26: [897, 0.04926676552974131],
#  23: [874, 0.048003515131542815],
#  22: [857, 0.047069808315483054],
#  4: [855, 0.04695996045477014],
#  7: [845, 0.04641072115120558],
#  9: [836, 0.04591640577799747],
#  3: [830, 0.04558686219585874],
#  19: [782, 0.04295051353874883],
#  5: [755, 0.04146756741912451],
#  1: [723, 0.03971000164771791],
#  15: [693, 0.03806228373702422],
#  8: [692, 0.038007359806667765],
#  16: [638, 0.035041467567419125],
#  6: [630, 0.03460207612456748],
#  24: [615, 0.03377821716922063],
#  18: [614, 0.03372329323886417],
#  2: [531, 0.0291646070192783],
#  25: [524, 0.028780139506783105],
#  21: [507, 0.027846432690723347],
#  14: [503, 0.027626736969297523],
#  20: [481, 0.026418410501455485],
#  13: [460, 0.025265007963969903],
#  0: [411, 0.02257373537650354],
#  10: [387, 0.021255561047948592],
#  17: [374, 0.02054154995331466]}

# %%
df['cluster_marks'] = kmeans.labels_

df_cluster_0 = df.loc[df['cluster_marks'] == 0]
df_cluster_1 = df.loc[df['cluster_marks'] == 1]
df_cluster_2 = df.loc[df['cluster_marks'] == 2]
df_cluster_3 = df.loc[df['cluster_marks'] == 3]
df_cluster_4 = df.loc[df['cluster_marks'] == 4]
df_cluster_5 = df.loc[df['cluster_marks'] == 5]
df_cluster_6 = df.loc[df['cluster_marks'] == 6]
df_cluster_7 = df.loc[df['cluster_marks'] == 7]
df_cluster_8 = df.loc[df['cluster_marks'] == 8]
df_cluster_9 = df.loc[df['cluster_marks'] == 9]
df_cluster_10 = df.loc[df['cluster_marks'] == 10]
df_cluster_11 = df.loc[df['cluster_marks'] == 11]
df_cluster_12 = df.loc[df['cluster_marks'] == 12]
df_cluster_13 = df.loc[df['cluster_marks'] == 13]
df_cluster_14 = df.loc[df['cluster_marks'] == 14]
df_cluster_15 = df.loc[df['cluster_marks'] == 15]
df_cluster_16 = df.loc[df['cluster_marks'] == 16]
df_cluster_17 = df.loc[df['cluster_marks'] == 17]
df_cluster_18 = df.loc[df['cluster_marks'] == 18]
df_cluster_19 = df.loc[df['cluster_marks'] == 19]
df_cluster_20 = df.loc[df['cluster_marks'] == 20]
df_cluster_21 = df.loc[df['cluster_marks'] == 21]
df_cluster_22 = df.loc[df['cluster_marks'] == 22]
df_cluster_23 = df.loc[df['cluster_marks'] == 23]
df_cluster_24 = df.loc[df['cluster_marks'] == 24]
df_cluster_25 = df.loc[df['cluster_marks'] == 25]
df_cluster_26 = df.loc[df['cluster_marks'] == 26]

f(df_cluster_0, 0, len(df))
f(df_cluster_1, 1, len(df))
f(df_cluster_2, 2, len(df))
f(df_cluster_3, 3, len(df))
f(df_cluster_4, 4, len(df))
f(df_cluster_5, 5, len(df))
f(df_cluster_6, 6, len(df))
f(df_cluster_7, 7, len(df))
f(df_cluster_8, 8, len(df))
f(df_cluster_9, 9, len(df))
f(df_cluster_10, 10, len(df))
f(df_cluster_11, 11, len(df))
f(df_cluster_12, 12, len(df))
f(df_cluster_13, 13, len(df))
f(df_cluster_14, 14, len(df))
f(df_cluster_15, 15, len(df))
f(df_cluster_16, 16, len(df))
f(df_cluster_17, 17, len(df))
f(df_cluster_18, 18, len(df))
f(df_cluster_19, 19, len(df))
f(df_cluster_20, 20, len(df))
f(df_cluster_21, 12, len(df))
f(df_cluster_22, 22, len(df))
f(df_cluster_23, 23, len(df))
f(df_cluster_24, 24, len(df))
f(df_cluster_24, 25, len(df))
f(df_cluster_26, 26, len(df))
# Out:
# Broj igraca u klasteru 0: 411, (0.02257373537650354)
#
# NAPAD: 403 (0.9805352798053528)
# Broj igraca na poziciji RF: 0
# Broj igraca na poziciji LF: 0
# Broj igraca na poziciji RW: 3
# Broj igraca na poziciji LW: 1
# Broj igraca na poziciji ST: 334
# Broj igraca na poziciji CF: 3
# Broj igraca na poziciji RS: 31
# Broj igraca na poziciji LS: 31
#
# VEZNI RED: 8 (0.019464720194647202)
# Broj igraca na poziciji RDM: 0
# Broj igraca na poziciji CDM: 0
# Broj igraca na poziciji LDM: 0
# Broj igraca na poziciji RM: 2
# Broj igraca na poziciji RCM: 2
# Broj igraca na poziciji CM: 0
# Broj igraca na poziciji LCM: 0
# Broj igraca na poziciji LM: 3
# Broj igraca na poziciji RAM: 0
# Broj igraca na poziciji CAM: 1
# Broj igraca na poziciji LAM: 0
#
# ODBRANA: 0 (0.0)
# Broj igraca na poziciji RWB 0
# Broj igraca na poziciji RB 0
# Broj igraca na poziciji RCB 0
# Broj igraca na poziciji CB 0
# Broj igraca na poziciji LCB 0
# Broj igraca na poziciji LB 0
# Broj igraca na poziciji LWB 0
#
# GOLMANI: 0 (0.0)
#
# Broj igraca u klasteru 1: 723, (0.03971000164771791)
#
# NAPAD: 0 (0.0)
# Broj igraca na poziciji RF: 0
# Broj igraca na poziciji LF: 0
# Broj igraca na poziciji RW: 0
# Broj igraca na poziciji LW: 0
# Broj igraca na poziciji ST: 0
# Broj igraca na poziciji CF: 0
# Broj igraca na poziciji RS: 0
# Broj igraca na poziciji LS: 0
#
# VEZNI RED: 73 (0.10096818810511757)
# Broj igraca na poziciji RDM: 11
# Broj igraca na poziciji CDM: 38
# Broj igraca na poziciji LDM: 15
# Broj igraca na poziciji RM: 0
# Broj igraca na poziciji RCM: 3
# Broj igraca na poziciji CM: 2
# Broj igraca na poziciji LCM: 3
# Broj igraca na poziciji LM: 1
# Broj igraca na poziciji RAM: 0
# Broj igraca na poziciji CAM: 0
# Broj igraca na poziciji LAM: 0
#
# ODBRANA: 650 (0.8990318118948825)
# Broj igraca na poziciji RWB 0
# Broj igraca na poziciji RB 19
# Broj igraca na poziciji RCB 184
# Broj igraca na poziciji CB 247
# Broj igraca na poziciji LCB 180
# Broj igraca na poziciji LB 20
# Broj igraca na poziciji LWB 0
#
# GOLMANI: 0 (0.0)
#
# Broj igraca u klasteru 2: 531, (0.0291646070192783)
#
# NAPAD: 508 (0.9566854990583804)
# Broj igraca na poziciji RF: 0
# Broj igraca na poziciji LF: 0
# Broj igraca na poziciji RW: 6
# Broj igraca na poziciji LW: 9
# Broj igraca na poziciji ST: 475
# Broj igraca na poziciji CF: 5
# Broj igraca na poziciji RS: 5
# Broj igraca na poziciji LS: 8
#
# VEZNI RED: 23 (0.04331450094161959)
# Broj igraca na poziciji RDM: 0
# Broj igraca na poziciji CDM: 0
# Broj igraca na poziciji LDM: 0
# Broj igraca na poziciji RM: 14
# Broj igraca na poziciji RCM: 0
# Broj igraca na poziciji CM: 0
# Broj igraca na poziciji LCM: 0
# Broj igraca na poziciji LM: 4
# Broj igraca na poziciji RAM: 0
# Broj igraca na poziciji CAM: 5
# Broj igraca na poziciji LAM: 0
#
# ODBRANA: 0 (0.0)
# Broj igraca na poziciji RWB 0
# Broj igraca na poziciji RB 0
# Broj igraca na poziciji RCB 0
# Broj igraca na poziciji CB 0
# Broj igraca na poziciji LCB 0
# Broj igraca na poziciji LB 0
# Broj igraca na poziciji LWB 0
#
# GOLMANI: 0 (0.0)
#
# Broj igraca u klasteru 3: 830, (0.04558686219585874)
#
# NAPAD: 1 (0.0012048192771084338)
# Broj igraca na poziciji RF: 0
# Broj igraca na poziciji LF: 0
# Broj igraca na poziciji RW: 0
# Broj igraca na poziciji LW: 0
# Broj igraca na poziciji ST: 1
# Broj igraca na poziciji CF: 0
# Broj igraca na poziciji RS: 0
# Broj igraca na poziciji LS: 0
#
# VEZNI RED: 0 (0.0)
# Broj igraca na poziciji RDM: 0
# Broj igraca na poziciji CDM: 0
# Broj igraca na poziciji LDM: 0
# Broj igraca na poziciji RM: 0
# Broj igraca na poziciji RCM: 0
# Broj igraca na poziciji CM: 0
# Broj igraca na poziciji LCM: 0
# Broj igraca na poziciji LM: 0
# Broj igraca na poziciji RAM: 0
# Broj igraca na poziciji CAM: 0
# Broj igraca na poziciji LAM: 0
#
# ODBRANA: 0 (0.0)
# Broj igraca na poziciji RWB 0
# Broj igraca na poziciji RB 0
# Broj igraca na poziciji RCB 0
# Broj igraca na poziciji CB 0
# Broj igraca na poziciji LCB 0
# Broj igraca na poziciji LB 0
# Broj igraca na poziciji LWB 0
#
# GOLMANI: 829 (0.9987951807228915)
#
# Broj igraca u klasteru 4: 855, (0.04695996045477014)
#
# NAPAD: 256 (0.2994152046783626)
# Broj igraca na poziciji RF: 4
# Broj igraca na poziciji LF: 4
# Broj igraca na poziciji RW: 80
# Broj igraca na poziciji LW: 80
# Broj igraca na poziciji ST: 51
# Broj igraca na poziciji CF: 8
# Broj igraca na poziciji RS: 13
# Broj igraca na poziciji LS: 16
#
# VEZNI RED: 597 (0.6982456140350877)
# Broj igraca na poziciji RDM: 3
# Broj igraca na poziciji CDM: 0
# Broj igraca na poziciji LDM: 2
# Broj igraca na poziciji RM: 184
# Broj igraca na poziciji RCM: 7
# Broj igraca na poziciji CM: 6
# Broj igraca na poziciji LCM: 20
# Broj igraca na poziciji LM: 200
# Broj igraca na poziciji RAM: 11
# Broj igraca na poziciji CAM: 153
# Broj igraca na poziciji LAM: 11
#
# ODBRANA: 2 (0.0023391812865497076)
# Broj igraca na poziciji RWB 0
# Broj igraca na poziciji RB 0
# Broj igraca na poziciji RCB 0
# Broj igraca na poziciji CB 0
# Broj igraca na poziciji LCB 0
# Broj igraca na poziciji LB 1
# Broj igraca na poziciji LWB 1
#
# GOLMANI: 0 (0.0)
#
# Broj igraca u klasteru 5: 755, (0.04146756741912451)
#
# NAPAD: 5 (0.006622516556291391)
# Broj igraca na poziciji RF: 0
# Broj igraca na poziciji LF: 0
# Broj igraca na poziciji RW: 0
# Broj igraca na poziciji LW: 1
# Broj igraca na poziciji ST: 4
# Broj igraca na poziciji CF: 0
# Broj igraca na poziciji RS: 0
# Broj igraca na poziciji LS: 0
#
# VEZNI RED: 260 (0.3443708609271523)
# Broj igraca na poziciji RDM: 3
# Broj igraca na poziciji CDM: 82
# Broj igraca na poziciji LDM: 7
# Broj igraca na poziciji RM: 20
# Broj igraca na poziciji RCM: 3
# Broj igraca na poziciji CM: 119
# Broj igraca na poziciji LCM: 4
# Broj igraca na poziciji LM: 15
# Broj igraca na poziciji RAM: 0
# Broj igraca na poziciji CAM: 7
# Broj igraca na poziciji LAM: 0
#
# ODBRANA: 490 (0.6490066225165563)
# Broj igraca na poziciji RWB 15
# Broj igraca na poziciji RB 196
# Broj igraca na poziciji RCB 2
# Broj igraca na poziciji CB 53
# Broj igraca na poziciji LCB 7
# Broj igraca na poziciji LB 210
# Broj igraca na poziciji LWB 7
#
# GOLMANI: 0 (0.0)
#
# Broj igraca u klasteru 6: 630, (0.03460207612456748)
#
# NAPAD: 1 (0.0015873015873015873)
# Broj igraca na poziciji RF: 0
# Broj igraca na poziciji LF: 0
# Broj igraca na poziciji RW: 0
# Broj igraca na poziciji LW: 0
# Broj igraca na poziciji ST: 1
# Broj igraca na poziciji CF: 0
# Broj igraca na poziciji RS: 0
# Broj igraca na poziciji LS: 0
#
# VEZNI RED: 5 (0.007936507936507936)
# Broj igraca na poziciji RDM: 0
# Broj igraca na poziciji CDM: 4
# Broj igraca na poziciji LDM: 1
# Broj igraca na poziciji RM: 0
# Broj igraca na poziciji RCM: 0
# Broj igraca na poziciji CM: 0
# Broj igraca na poziciji LCM: 0
# Broj igraca na poziciji LM: 0
# Broj igraca na poziciji RAM: 0
# Broj igraca na poziciji CAM: 0
# Broj igraca na poziciji LAM: 0
#
# ODBRANA: 624 (0.9904761904761905)
# Broj igraca na poziciji RWB 0
# Broj igraca na poziciji RB 16
# Broj igraca na poziciji RCB 58
# Broj igraca na poziciji CB 495
# Broj igraca na poziciji LCB 38
# Broj igraca na poziciji LB 16
# Broj igraca na poziciji LWB 1
#
# GOLMANI: 0 (0.0)
#
# Broj igraca u klasteru 7: 845, (0.04641072115120558)
#
# NAPAD: 38 (0.04497041420118343)
# Broj igraca na poziciji RF: 0
# Broj igraca na poziciji LF: 0
# Broj igraca na poziciji RW: 14
# Broj igraca na poziciji LW: 17
# Broj igraca na poziciji ST: 4
# Broj igraca na poziciji CF: 0
# Broj igraca na poziciji RS: 1
# Broj igraca na poziciji LS: 2
#
# VEZNI RED: 685 (0.8106508875739645)
# Broj igraca na poziciji RDM: 19
# Broj igraca na poziciji CDM: 74
# Broj igraca na poziciji LDM: 21
# Broj igraca na poziciji RM: 83
# Broj igraca na poziciji RCM: 52
# Broj igraca na poziciji CM: 251
# Broj igraca na poziciji LCM: 42
# Broj igraca na poziciji LM: 70
# Broj igraca na poziciji RAM: 1
# Broj igraca na poziciji CAM: 72
# Broj igraca na poziciji LAM: 0
#
# ODBRANA: 122 (0.14437869822485208)
# Broj igraca na poziciji RWB 8
# Broj igraca na poziciji RB 37
# Broj igraca na poziciji RCB 2
# Broj igraca na poziciji CB 2
# Broj igraca na poziciji LCB 4
# Broj igraca na poziciji LB 63
# Broj igraca na poziciji LWB 6
#
# GOLMANI: 0 (0.0)
#
# Broj igraca u klasteru 8: 692, (0.038007359806667765)
#
# NAPAD: 154 (0.22254335260115607)
# Broj igraca na poziciji RF: 0
# Broj igraca na poziciji LF: 0
# Broj igraca na poziciji RW: 57
# Broj igraca na poziciji LW: 49
# Broj igraca na poziciji ST: 36
# Broj igraca na poziciji CF: 10
# Broj igraca na poziciji RS: 0
# Broj igraca na poziciji LS: 2
#
# VEZNI RED: 533 (0.7702312138728323)
# Broj igraca na poziciji RDM: 0
# Broj igraca na poziciji CDM: 1
# Broj igraca na poziciji LDM: 0
# Broj igraca na poziciji RM: 145
# Broj igraca na poziciji RCM: 6
# Broj igraca na poziciji CM: 75
# Broj igraca na poziciji LCM: 5
# Broj igraca na poziciji LM: 157
# Broj igraca na poziciji RAM: 0
# Broj igraca na poziciji CAM: 144
# Broj igraca na poziciji LAM: 0
#
# ODBRANA: 5 (0.0072254335260115606)
# Broj igraca na poziciji RWB 1
# Broj igraca na poziciji RB 1
# Broj igraca na poziciji RCB 0
# Broj igraca na poziciji CB 0
# Broj igraca na poziciji LCB 0
# Broj igraca na poziciji LB 2
# Broj igraca na poziciji LWB 1
#
# GOLMANI: 0 (0.0)
#
# Broj igraca u klasteru 9: 836, (0.04591640577799747)
#
# NAPAD: 244 (0.291866028708134)
# Broj igraca na poziciji RF: 1
# Broj igraca na poziciji LF: 3
# Broj igraca na poziciji RW: 84
# Broj igraca na poziciji LW: 96
# Broj igraca na poziciji ST: 38
# Broj igraca na poziciji CF: 9
# Broj igraca na poziciji RS: 8
# Broj igraca na poziciji LS: 5
#
# VEZNI RED: 592 (0.7081339712918661)
# Broj igraca na poziciji RDM: 3
# Broj igraca na poziciji CDM: 0
# Broj igraca na poziciji LDM: 3
# Broj igraca na poziciji RM: 204
# Broj igraca na poziciji RCM: 3
# Broj igraca na poziciji CM: 15
# Broj igraca na poziciji LCM: 6
# Broj igraca na poziciji LM: 193
# Broj igraca na poziciji RAM: 2
# Broj igraca na poziciji CAM: 162
# Broj igraca na poziciji LAM: 1
#
# ODBRANA: 0 (0.0)
# Broj igraca na poziciji RWB 0
# Broj igraca na poziciji RB 0
# Broj igraca na poziciji RCB 0
# Broj igraca na poziciji CB 0
# Broj igraca na poziciji LCB 0
# Broj igraca na poziciji LB 0
# Broj igraca na poziciji LWB 0
#
# GOLMANI: 0 (0.0)
#
# Broj igraca u klasteru 10: 387, (0.021255561047948592)
#
# NAPAD: 161 (0.4160206718346253)
# Broj igraca na poziciji RF: 4
# Broj igraca na poziciji LF: 3
# Broj igraca na poziciji RW: 33
# Broj igraca na poziciji LW: 27
# Broj igraca na poziciji ST: 55
# Broj igraca na poziciji CF: 8
# Broj igraca na poziciji RS: 11
# Broj igraca na poziciji LS: 20
#
# VEZNI RED: 226 (0.5839793281653747)
# Broj igraca na poziciji RDM: 0
# Broj igraca na poziciji CDM: 0
# Broj igraca na poziciji LDM: 1
# Broj igraca na poziciji RM: 66
# Broj igraca na poziciji RCM: 6
# Broj igraca na poziciji CM: 4
# Broj igraca na poziciji LCM: 10
# Broj igraca na poziciji LM: 59
# Broj igraca na poziciji RAM: 1
# Broj igraca na poziciji CAM: 77
# Broj igraca na poziciji LAM: 2
#
# ODBRANA: 0 (0.0)
# Broj igraca na poziciji RWB 0
# Broj igraca na poziciji RB 0
# Broj igraca na poziciji RCB 0
# Broj igraca na poziciji CB 0
# Broj igraca na poziciji LCB 0
# Broj igraca na poziciji LB 0
# Broj igraca na poziciji LWB 0
#
# GOLMANI: 0 (0.0)
#
# Broj igraca u klasteru 11: 918, (0.05042016806722689)
#
# NAPAD: 4 (0.004357298474945534)
# Broj igraca na poziciji RF: 0
# Broj igraca na poziciji LF: 0
# Broj igraca na poziciji RW: 2
# Broj igraca na poziciji LW: 1
# Broj igraca na poziciji ST: 0
# Broj igraca na poziciji CF: 0
# Broj igraca na poziciji RS: 1
# Broj igraca na poziciji LS: 0
#
# VEZNI RED: 302 (0.3289760348583878)
# Broj igraca na poziciji RDM: 27
# Broj igraca na poziciji CDM: 96
# Broj igraca na poziciji LDM: 23
# Broj igraca na poziciji RM: 23
# Broj igraca na poziciji RCM: 42
# Broj igraca na poziciji CM: 48
# Broj igraca na poziciji LCM: 25
# Broj igraca na poziciji LM: 17
# Broj igraca na poziciji RAM: 0
# Broj igraca na poziciji CAM: 1
# Broj igraca na poziciji LAM: 0
#
# ODBRANA: 612 (0.6666666666666666)
# Broj igraca na poziciji RWB 15
# Broj igraca na poziciji RB 281
# Broj igraca na poziciji RCB 17
# Broj igraca na poziciji CB 20
# Broj igraca na poziciji LCB 6
# Broj igraca na poziciji LB 261
# Broj igraca na poziciji LWB 12
#
# GOLMANI: 0 (0.0)
#
# Broj igraca u klasteru 12: 975, (0.0535508320975449)
#
# NAPAD: 78 (0.08)
# Broj igraca na poziciji RF: 0
# Broj igraca na poziciji LF: 0
# Broj igraca na poziciji RW: 9
# Broj igraca na poziciji LW: 8
# Broj igraca na poziciji ST: 55
# Broj igraca na poziciji CF: 3
# Broj igraca na poziciji RS: 2
# Broj igraca na poziciji LS: 1
#
# VEZNI RED: 721 (0.7394871794871795)
# Broj igraca na poziciji RDM: 9
# Broj igraca na poziciji CDM: 120
# Broj igraca na poziciji LDM: 13
# Broj igraca na poziciji RM: 55
# Broj igraca na poziciji RCM: 21
# Broj igraca na poziciji CM: 360
# Broj igraca na poziciji LCM: 25
# Broj igraca na poziciji LM: 55
# Broj igraca na poziciji RAM: 0
# Broj igraca na poziciji CAM: 63
# Broj igraca na poziciji LAM: 0
#
# ODBRANA: 176 (0.18051282051282053)
# Broj igraca na poziciji RWB 10
# Broj igraca na poziciji RB 63
# Broj igraca na poziciji RCB 1
# Broj igraca na poziciji CB 18
# Broj igraca na poziciji LCB 3
# Broj igraca na poziciji LB 73
# Broj igraca na poziciji LWB 8
#
# GOLMANI: 0 (0.0)
#
# Broj igraca u klasteru 13: 460, (0.025265007963969903)
#
# NAPAD: 2 (0.004347826086956522)
# Broj igraca na poziciji RF: 0
# Broj igraca na poziciji LF: 0
# Broj igraca na poziciji RW: 0
# Broj igraca na poziciji LW: 0
# Broj igraca na poziciji ST: 2
# Broj igraca na poziciji CF: 0
# Broj igraca na poziciji RS: 0
# Broj igraca na poziciji LS: 0
#
# VEZNI RED: 314 (0.6826086956521739)
# Broj igraca na poziciji RDM: 39
# Broj igraca na poziciji CDM: 104
# Broj igraca na poziciji LDM: 34
# Broj igraca na poziciji RM: 2
# Broj igraca na poziciji RCM: 38
# Broj igraca na poziciji CM: 50
# Broj igraca na poziciji LCM: 33
# Broj igraca na poziciji LM: 1
# Broj igraca na poziciji RAM: 0
# Broj igraca na poziciji CAM: 13
# Broj igraca na poziciji LAM: 0
#
# ODBRANA: 144 (0.3130434782608696)
# Broj igraca na poziciji RWB 0
# Broj igraca na poziciji RB 28
# Broj igraca na poziciji RCB 19
# Broj igraca na poziciji CB 48
# Broj igraca na poziciji LCB 29
# Broj igraca na poziciji LB 20
# Broj igraca na poziciji LWB 0
#
# GOLMANI: 0 (0.0)
#
# Broj igraca u klasteru 14: 503, (0.027626736969297523)
#
# NAPAD: 0 (0.0)
# Broj igraca na poziciji RF: 0
# Broj igraca na poziciji LF: 0
# Broj igraca na poziciji RW: 0
# Broj igraca na poziciji LW: 0
# Broj igraca na poziciji ST: 0
# Broj igraca na poziciji CF: 0
# Broj igraca na poziciji RS: 0
# Broj igraca na poziciji LS: 0
#
# VEZNI RED: 0 (0.0)
# Broj igraca na poziciji RDM: 0
# Broj igraca na poziciji CDM: 0
# Broj igraca na poziciji LDM: 0
# Broj igraca na poziciji RM: 0
# Broj igraca na poziciji RCM: 0
# Broj igraca na poziciji CM: 0
# Broj igraca na poziciji LCM: 0
# Broj igraca na poziciji LM: 0
# Broj igraca na poziciji RAM: 0
# Broj igraca na poziciji CAM: 0
# Broj igraca na poziciji LAM: 0
#
# ODBRANA: 0 (0.0)
# Broj igraca na poziciji RWB 0
# Broj igraca na poziciji RB 0
# Broj igraca na poziciji RCB 0
# Broj igraca na poziciji CB 0
# Broj igraca na poziciji LCB 0
# Broj igraca na poziciji LB 0
# Broj igraca na poziciji LWB 0
#
# GOLMANI: 503 (1.0)
#
# Broj igraca u klasteru 15: 693, (0.03806228373702422)
#
# NAPAD: 0 (0.0)
# Broj igraca na poziciji RF: 0
# Broj igraca na poziciji LF: 0
# Broj igraca na poziciji RW: 0
# Broj igraca na poziciji LW: 0
# Broj igraca na poziciji ST: 0
# Broj igraca na poziciji CF: 0
# Broj igraca na poziciji RS: 0
# Broj igraca na poziciji LS: 0
#
# VEZNI RED: 0 (0.0)
# Broj igraca na poziciji RDM: 0
# Broj igraca na poziciji CDM: 0
# Broj igraca na poziciji LDM: 0
# Broj igraca na poziciji RM: 0
# Broj igraca na poziciji RCM: 0
# Broj igraca na poziciji CM: 0
# Broj igraca na poziciji LCM: 0
# Broj igraca na poziciji LM: 0
# Broj igraca na poziciji RAM: 0
# Broj igraca na poziciji CAM: 0
# Broj igraca na poziciji LAM: 0
#
# ODBRANA: 0 (0.0)
# Broj igraca na poziciji RWB 0
# Broj igraca na poziciji RB 0
# Broj igraca na poziciji RCB 0
# Broj igraca na poziciji CB 0
# Broj igraca na poziciji LCB 0
# Broj igraca na poziciji LB 0
# Broj igraca na poziciji LWB 0
#
# GOLMANI: 693 (1.0)
#
# Broj igraca u klasteru 16: 638, (0.035041467567419125)
#
# NAPAD: 509 (0.7978056426332288)
# Broj igraca na poziciji RF: 0
# Broj igraca na poziciji LF: 0
# Broj igraca na poziciji RW: 29
# Broj igraca na poziciji LW: 26
# Broj igraca na poziciji ST: 385
# Broj igraca na poziciji CF: 11
# Broj igraca na poziciji RS: 28
# Broj igraca na poziciji LS: 30
#
# VEZNI RED: 129 (0.20219435736677116)
# Broj igraca na poziciji RDM: 1
# Broj igraca na poziciji CDM: 0
# Broj igraca na poziciji LDM: 0
# Broj igraca na poziciji RM: 60
# Broj igraca na poziciji RCM: 1
# Broj igraca na poziciji CM: 0
# Broj igraca na poziciji LCM: 1
# Broj igraca na poziciji LM: 50
# Broj igraca na poziciji RAM: 0
# Broj igraca na poziciji CAM: 15
# Broj igraca na poziciji LAM: 1
#
# ODBRANA: 0 (0.0)
# Broj igraca na poziciji RWB 0
# Broj igraca na poziciji RB 0
# Broj igraca na poziciji RCB 0
# Broj igraca na poziciji CB 0
# Broj igraca na poziciji LCB 0
# Broj igraca na poziciji LB 0
# Broj igraca na poziciji LWB 0
#
# GOLMANI: 0 (0.0)
#
# Broj igraca u klasteru 17: 374, (0.02054154995331466)
#
# NAPAD: 9 (0.02406417112299465)
# Broj igraca na poziciji RF: 0
# Broj igraca na poziciji LF: 2
# Broj igraca na poziciji RW: 2
# Broj igraca na poziciji LW: 1
# Broj igraca na poziciji ST: 3
# Broj igraca na poziciji CF: 1
# Broj igraca na poziciji RS: 0
# Broj igraca na poziciji LS: 0
#
# VEZNI RED: 270 (0.7219251336898396)
# Broj igraca na poziciji RDM: 16
# Broj igraca na poziciji CDM: 27
# Broj igraca na poziciji LDM: 20
# Broj igraca na poziciji RM: 16
# Broj igraca na poziciji RCM: 41
# Broj igraca na poziciji CM: 74
# Broj igraca na poziciji LCM: 34
# Broj igraca na poziciji LM: 19
# Broj igraca na poziciji RAM: 1
# Broj igraca na poziciji CAM: 22
# Broj igraca na poziciji LAM: 0
#
# ODBRANA: 95 (0.2540106951871658)
# Broj igraca na poziciji RWB 2
# Broj igraca na poziciji RB 35
# Broj igraca na poziciji RCB 3
# Broj igraca na poziciji CB 2
# Broj igraca na poziciji LCB 7
# Broj igraca na poziciji LB 40
# Broj igraca na poziciji LWB 6
#
# GOLMANI: 0 (0.0)
#
# Broj igraca u klasteru 18: 614, (0.03372329323886417)
#
# NAPAD: 480 (0.7817589576547231)
# Broj igraca na poziciji RF: 3
# Broj igraca na poziciji LF: 1
# Broj igraca na poziciji RW: 17
# Broj igraca na poziciji LW: 23
# Broj igraca na poziciji ST: 357
# Broj igraca na poziciji CF: 5
# Broj igraca na poziciji RS: 37
# Broj igraca na poziciji LS: 37
#
# VEZNI RED: 133 (0.21661237785016288)
# Broj igraca na poziciji RDM: 0
# Broj igraca na poziciji CDM: 0
# Broj igraca na poziciji LDM: 0
# Broj igraca na poziciji RM: 52
# Broj igraca na poziciji RCM: 1
# Broj igraca na poziciji CM: 0
# Broj igraca na poziciji LCM: 1
# Broj igraca na poziciji LM: 58
# Broj igraca na poziciji RAM: 0
# Broj igraca na poziciji CAM: 20
# Broj igraca na poziciji LAM: 1
#
# ODBRANA: 1 (0.0016286644951140066)
# Broj igraca na poziciji RWB 0
# Broj igraca na poziciji RB 0
# Broj igraca na poziciji RCB 1
# Broj igraca na poziciji CB 0
# Broj igraca na poziciji LCB 0
# Broj igraca na poziciji LB 0
# Broj igraca na poziciji LWB 0
#
# GOLMANI: 0 (0.0)
#
# Broj igraca u klasteru 19: 782, (0.04295051353874883)
#
# NAPAD: 42 (0.05370843989769821)
# Broj igraca na poziciji RF: 2
# Broj igraca na poziciji LF: 1
# Broj igraca na poziciji RW: 7
# Broj igraca na poziciji LW: 13
# Broj igraca na poziciji ST: 10
# Broj igraca na poziciji CF: 3
# Broj igraca na poziciji RS: 4
# Broj igraca na poziciji LS: 2
#
# VEZNI RED: 618 (0.7902813299232737)
# Broj igraca na poziciji RDM: 25
# Broj igraca na poziciji CDM: 44
# Broj igraca na poziciji LDM: 38
# Broj igraca na poziciji RM: 65
# Broj igraca na poziciji RCM: 62
# Broj igraca na poziciji CM: 164
# Broj igraca na poziciji LCM: 73
# Broj igraca na poziciji LM: 67
# Broj igraca na poziciji RAM: 3
# Broj igraca na poziciji CAM: 76
# Broj igraca na poziciji LAM: 1
#
# ODBRANA: 122 (0.15601023017902813)
# Broj igraca na poziciji RWB 1
# Broj igraca na poziciji RB 42
# Broj igraca na poziciji RCB 2
# Broj igraca na poziciji CB 0
# Broj igraca na poziciji LCB 3
# Broj igraca na poziciji LB 73
# Broj igraca na poziciji LWB 1
#
# GOLMANI: 0 (0.0)
#
# Broj igraca u klasteru 20: 481, (0.026418410501455485)
#
# NAPAD: 443 (0.920997920997921)
# Broj igraca na poziciji RF: 0
# Broj igraca na poziciji LF: 0
# Broj igraca na poziciji RW: 6
# Broj igraca na poziciji LW: 6
# Broj igraca na poziciji ST: 323
# Broj igraca na poziciji CF: 4
# Broj igraca na poziciji RS: 56
# Broj igraca na poziciji LS: 48
#
# VEZNI RED: 38 (0.079002079002079)
# Broj igraca na poziciji RDM: 0
# Broj igraca na poziciji CDM: 0
# Broj igraca na poziciji LDM: 0
# Broj igraca na poziciji RM: 12
# Broj igraca na poziciji RCM: 0
# Broj igraca na poziciji CM: 0
# Broj igraca na poziciji LCM: 0
# Broj igraca na poziciji LM: 14
# Broj igraca na poziciji RAM: 0
# Broj igraca na poziciji CAM: 11
# Broj igraca na poziciji LAM: 1
#
# ODBRANA: 0 (0.0)
# Broj igraca na poziciji RWB 0
# Broj igraca na poziciji RB 0
# Broj igraca na poziciji RCB 0
# Broj igraca na poziciji CB 0
# Broj igraca na poziciji LCB 0
# Broj igraca na poziciji LB 0
# Broj igraca na poziciji LWB 0
#
# GOLMANI: 0 (0.0)
#
# Broj igraca u klasteru 12: 507, (0.027846432690723347)
# NAPAD: 1 (0.0019723865877712033)
# Broj igraca na poziciji RF: 0
# Broj igraca na poziciji LF: 0
# Broj igraca na poziciji RW: 0
# Broj igraca na poziciji LW: 0
# Broj igraca na poziciji ST: 1
# Broj igraca na poziciji CF: 0
# Broj igraca na poziciji RS: 0
# Broj igraca na poziciji LS: 0
#
# VEZNI RED: 19 (0.03747534516765286)
# Broj igraca na poziciji RDM: 3
# Broj igraca na poziciji CDM: 14
# Broj igraca na poziciji LDM: 1
# Broj igraca na poziciji RM: 0
# Broj igraca na poziciji RCM: 0
# Broj igraca na poziciji CM: 0
# Broj igraca na poziciji LCM: 0
# Broj igraca na poziciji LM: 0
# Broj igraca na poziciji RAM: 0
# Broj igraca na poziciji CAM: 1
# Broj igraca na poziciji LAM: 0
#
# ODBRANA: 487 (0.960552268244576)
# Broj igraca na poziciji RWB 0
# Broj igraca na poziciji RB 3
# Broj igraca na poziciji RCB 125
# Broj igraca na poziciji CB 242
# Broj igraca na poziciji LCB 114
# Broj igraca na poziciji LB 3
# Broj igraca na poziciji LWB 0
#
# GOLMANI: 0 (0.0)
#
# Broj igraca u klasteru 22: 857, (0.047069808315483054)
#
# NAPAD: 0 (0.0)
# Broj igraca na poziciji RF: 0
# Broj igraca na poziciji LF: 0
# Broj igraca na poziciji RW: 0
# Broj igraca na poziciji LW: 0
# Broj igraca na poziciji ST: 0
# Broj igraca na poziciji CF: 0
# Broj igraca na poziciji RS: 0
# Broj igraca na poziciji LS: 0
#
# VEZNI RED: 34 (0.039673278879813305)
# Broj igraca na poziciji RDM: 3
# Broj igraca na poziciji CDM: 24
# Broj igraca na poziciji LDM: 3
# Broj igraca na poziciji RM: 1
# Broj igraca na poziciji RCM: 0
# Broj igraca na poziciji CM: 1
# Broj igraca na poziciji LCM: 2
# Broj igraca na poziciji LM: 0
# Broj igraca na poziciji RAM: 0
# Broj igraca na poziciji CAM: 0
# Broj igraca na poziciji LAM: 0
#
# ODBRANA: 823 (0.9603267211201867)
# Broj igraca na poziciji RWB 1
# Broj igraca na poziciji RB 22
# Broj igraca na poziciji RCB 155
# Broj igraca na poziciji CB 452
# Broj igraca na poziciji LCB 171
# Broj igraca na poziciji LB 21
# Broj igraca na poziciji LWB 1
#
# GOLMANI: 0 (0.0)
#
# Broj igraca u klasteru 23: 874, (0.048003515131542815)
#
# NAPAD: 2 (0.002288329519450801)
# Broj igraca na poziciji RF: 0
# Broj igraca na poziciji LF: 0
# Broj igraca na poziciji RW: 0
# Broj igraca na poziciji LW: 1
# Broj igraca na poziciji ST: 1
# Broj igraca na poziciji CF: 0
# Broj igraca na poziciji RS: 0
# Broj igraca na poziciji LS: 0
#
# VEZNI RED: 119 (0.13615560640732266)
# Broj igraca na poziciji RDM: 9
# Broj igraca na poziciji CDM: 58
# Broj igraca na poziciji LDM: 8
# Broj igraca na poziciji RM: 12
# Broj igraca na poziciji RCM: 5
# Broj igraca na poziciji CM: 8
# Broj igraca na poziciji LCM: 7
# Broj igraca na poziciji LM: 12
# Broj igraca na poziciji RAM: 0
# Broj igraca na poziciji CAM: 0
# Broj igraca na poziciji LAM: 0
#
# ODBRANA: 753 (0.8615560640732265)
# Broj igraca na poziciji RWB 13
# Broj igraca na poziciji RB 312
# Broj igraca na poziciji RCB 30
# Broj igraca na poziciji CB 75
# Broj igraca na poziciji LCB 22
# Broj igraca na poziciji LB 286
# Broj igraca na poziciji LWB 15
#
# GOLMANI: 0 (0.0)
#
# Broj igraca u klasteru 24: 615, (0.03377821716922063)
#
# NAPAD: 2 (0.0032520325203252032)
# Broj igraca na poziciji RF: 0
# Broj igraca na poziciji LF: 0
# Broj igraca na poziciji RW: 0
# Broj igraca na poziciji LW: 1
# Broj igraca na poziciji ST: 1
# Broj igraca na poziciji CF: 0
# Broj igraca na poziciji RS: 0
# Broj igraca na poziciji LS: 0
#
# VEZNI RED: 287 (0.4666666666666667)
# Broj igraca na poziciji RDM: 39
# Broj igraca na poziciji CDM: 90
# Broj igraca na poziciji LDM: 17
# Broj igraca na poziciji RM: 10
# Broj igraca na poziciji RCM: 32
# Broj igraca na poziciji CM: 49
# Broj igraca na poziciji LCM: 38
# Broj igraca na poziciji LM: 10
# Broj igraca na poziciji RAM: 0
# Broj igraca na poziciji CAM: 2
# Broj igraca na poziciji LAM: 0
#
# ODBRANA: 326 (0.5300813008130081)
# Broj igraca na poziciji RWB 11
# Broj igraca na poziciji RB 121
# Broj igraca na poziciji RCB 20
# Broj igraca na poziciji CB 19
# Broj igraca na poziciji LCB 22
# Broj igraca na poziciji LB 121
# Broj igraca na poziciji LWB 12
#
# GOLMANI: 0 (0.0)
#
# Broj igraca u klasteru 25: 615, (0.03377821716922063)
#
# NAPAD: 2 (0.0032520325203252032)
# Broj igraca na poziciji RF: 0
# Broj igraca na poziciji LF: 0
# Broj igraca na poziciji RW: 0
# Broj igraca na poziciji LW: 1
# Broj igraca na poziciji ST: 1
# Broj igraca na poziciji CF: 0
# Broj igraca na poziciji RS: 0
# Broj igraca na poziciji LS: 0
#
# VEZNI RED: 287 (0.4666666666666667)
# Broj igraca na poziciji RDM: 39
# Broj igraca na poziciji CDM: 90
# Broj igraca na poziciji LDM: 17
# Broj igraca na poziciji RM: 10
# Broj igraca na poziciji RCM: 32
# Broj igraca na poziciji CM: 49
# Broj igraca na poziciji LCM: 38
# Broj igraca na poziciji LM: 10
# Broj igraca na poziciji RAM: 0
# Broj igraca na poziciji CAM: 2
# Broj igraca na poziciji LAM: 0
#
# ODBRANA: 326 (0.5300813008130081)
# Broj igraca na poziciji RWB 11
# Broj igraca na poziciji RB 121
# Broj igraca na poziciji RCB 20
# Broj igraca na poziciji CB 19
# Broj igraca na poziciji LCB 22
# Broj igraca na poziciji LB 121
# Broj igraca na poziciji LWB 12
#
# GOLMANI: 0 (0.0)
#
# Broj igraca u klasteru 26: 897, (0.04926676552974131)
#
# NAPAD: 18 (0.020066889632107024)
# Broj igraca na poziciji RF: 0
# Broj igraca na poziciji LF: 0
# Broj igraca na poziciji RW: 0
# Broj igraca na poziciji LW: 1
# Broj igraca na poziciji ST: 17
# Broj igraca na poziciji CF: 0
# Broj igraca na poziciji RS: 0
# Broj igraca na poziciji LS: 0
#
# VEZNI RED: 460 (0.5128205128205128)
# Broj igraca na poziciji RDM: 34
# Broj igraca na poziciji CDM: 169
# Broj igraca na poziciji LDM: 33
# Broj igraca na poziciji RM: 10
# Broj igraca na poziciji RCM: 48
# Broj igraca na poziciji CM: 106
# Broj igraca na poziciji LCM: 40
# Broj igraca na poziciji LM: 12
# Broj igraca na poziciji RAM: 0
# Broj igraca na poziciji CAM: 8
# Broj igraca na poziciji LAM: 0
#
# ODBRANA: 419 (0.46711259754738016)
# Broj igraca na poziciji RWB 9
# Broj igraca na poziciji RB 109
# Broj igraca na poziciji RCB 43
# Broj igraca na poziciji CB 105
# Broj igraca na poziciji LCB 41
# Broj igraca na poziciji LB 106
# Broj igraca na poziciji LWB 6
#
# GOLMANI: 0 (0.0)

# %%
# KPrototypes

categorical_features_index = []
for index, feature in enumerate(df.columns.values):
    if str(df[feature].dtype) == 'object':
        categorical_features_index.append(index)

sse = []
# silhouette = []

for k in range(2, 11):
    kprototypes = KPrototypes(n_clusters=k, random_state=0, n_jobs=-1)
    kprototypes.fit(df, categorical=categorical_features_index)
    sse.append(kprototypes.cost_)
    
# kprototypes = KPrototypes(n_clusters=3, random_state=0)
# kprototypes.fit(df, categorical=categorical_features_index)
# print('Klasteri:')
# print(kprototypes.labels_)

# kprototypes = KPrototypes(n_clusters=3, random_state=0, n_jobs=-1)
# kprototypes.fit(df, categorical=categorical_features_index)
# kprototypes.labels_

# %%
# kprototypes.inertia_
print('Cost:', kprototypes.cost_)
# Out:
# Cost: 94788.28557037296

# %%
# Agglomerative

distance_matrix = linkage(df[numeric], 'ward')
dendrogram(distance_matrix, truncate_mode='lastp', p=12, leaf_font_size=15, show_contracted=True)
plt.axhline(y=120, linestyle='-.', color='red')
plt.axhline(y=70, linestyle='-.', color='red')
plt.title('Dendrogram')
plt.xlabel('Clusters')
plt.ylabel('Distance between clusters')
# Out:
# Text(0, 0.5, 'Distance between clusters')

# %%
agglomerative = AgglomerativeClustering(n_clusters=2, affinity='euclidean', linkage='ward')
agglomerative.fit(df[numeric])
clusters = agglomerative.labels_
count = Counter(clusters)
d = {}
for value, times in count.most_common():
    d[value] = times
d
# Out:
# {0: 16181, 1: 2026}

# %%
# za podelu na 2 klastera

count = Counter(agglomerative.labels_)
d = {}
for value, times in count.most_common():
    d[value] = [times, times / len(df)]
d
# Out:
# {0: [16181, 0.8887241170978195], 1: [2026, 0.11127588290218048]}

# %%
df['cluster_marks'] = agglomerative.labels_

df_cluster_0 = df.loc[df['cluster_marks'] == 0]
df_cluster_1 = df.loc[df['cluster_marks'] == 1]

f(df_cluster_0, 0, len(df))
f(df_cluster_1, 1, len(df))
# Out:
# Broj igraca u klasteru 0: 16181, (0.8887241170978195)
#
# NAPAD: 3477 (0.21488165131944872)
# Broj igraca na poziciji RF: 16
# Broj igraca na poziciji LF: 15
# Broj igraca na poziciji RW: 370
# Broj igraca na poziciji LW: 381
# Broj igraca na poziciji ST: 2211
# Broj igraca na poziciji CF: 74
# Broj igraca na poziciji RS: 203
# Broj igraca na poziciji LS: 207
#
# VEZNI RED: 6838 (0.42259440084049193)
# Broj igraca na poziciji RDM: 248
# Broj igraca na poziciji CDM: 948
# Broj igraca na poziciji LDM: 243
# Broj igraca na poziciji RM: 1124
# Broj igraca na poziciji RCM: 391
# Broj igraca na poziciji CM: 1394
# Broj igraca na poziciji LCM: 395
# Broj igraca na poziciji LM: 1095
# Broj igraca na poziciji RAM: 21
# Broj igraca na poziciji CAM: 958
# Broj igraca na poziciji LAM: 21
#
# ODBRANA: 5866 (0.3625239478400593)
# Broj igraca na poziciji RWB 87
# Broj igraca na poziciji RB 1291
# Broj igraca na poziciji RCB 662
# Broj igraca na poziciji CB 1778
# Broj igraca na poziciji LCB 648
# Broj igraca na poziciji LB 1322
# Broj igraca na poziciji LWB 78
#
# GOLMANI: 0 (0.0)
#
# Broj igraca u klasteru 1: 2026, (0.11127588290218048)
#
# NAPAD: 1 (0.0004935834155972359)
# Broj igraca na poziciji RF: 0
# Broj igraca na poziciji LF: 0
# Broj igraca na poziciji RW: 0
# Broj igraca na poziciji LW: 0
# Broj igraca na poziciji ST: 1
# Broj igraca na poziciji CF: 0
# Broj igraca na poziciji RS: 0
# Broj igraca na poziciji LS: 0
#
# VEZNI RED: 0 (0.0)
# Broj igraca na poziciji RDM: 0
# Broj igraca na poziciji CDM: 0
# Broj igraca na poziciji LDM: 0
# Broj igraca na poziciji RM: 0
# Broj igraca na poziciji RCM: 0
# Broj igraca na poziciji CM: 0
# Broj igraca na poziciji LCM: 0
# Broj igraca na poziciji LM: 0
# Broj igraca na poziciji RAM: 0
# Broj igraca na poziciji CAM: 0
# Broj igraca na poziciji LAM: 0
#
# ODBRANA: 0 (0.0)
# Broj igraca na poziciji RWB 0
# Broj igraca na poziciji RB 0
# Broj igraca na poziciji RCB 0
# Broj igraca na poziciji CB 0
# Broj igraca na poziciji LCB 0
# Broj igraca na poziciji LB 0
# Broj igraca na poziciji LWB 0
#
# GOLMANI: 2025 (0.9995064165844028)
