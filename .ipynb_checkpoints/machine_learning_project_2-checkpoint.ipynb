# %%
import pandas as pd
import seaborn as sns
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans, AgglomerativeClustering, DBSCAN
import matplotlib.pyplot as plt
from sklearn.metrics import silhouette_score
from kmodes.kprototypes import KPrototypes
from scipy.cluster.hierarchy import linkage, dendrogram
from collections import Counter

# %matplotlib inline

# %%
df = pd.read_csv('kl.csv', encoding='ISO-8859-1')
df.head()
# Out:
#    Unnamed: 0      ID               Name   Age  \
# 0           0  158023           L. Messi  31.0
# 1           1   20801  Cristiano Ronaldo  33.0
# 2           2  190871          Neymar Jr  26.0
# 3           3  193080             De Gea  27.0
# 4           4  192985       K. De Bruyne  27.0
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png     94.0         94
# 1  https://cdn.sofifa.org/flags/38.png     94.0         94
# 2  https://cdn.sofifa.org/flags/54.png     92.0         93
# 3  https://cdn.sofifa.org/flags/45.png     91.0         93
# 4   https://cdn.sofifa.org/flags/7.png     91.0         92
#
#                   Club  ... Composure Marking StandingTackle  SlidingTackle  \
# 0         FC Barcelona  ...      96.0    33.0           28.0           26.0
# 1             Juventus  ...      95.0    28.0           31.0           23.0
# 2  Paris Saint-Germain  ...      94.0    27.0           24.0           33.0
# 3    Manchester United  ...      68.0    15.0           21.0           13.0
# 4      Manchester City  ...      88.0    68.0           58.0           51.0
#
#   GKDiving  GKHandling  GKKicking  GKPositioning GKReflexes Release Clause
# 0      6.0        11.0       15.0           14.0        8.0        226.5M
# 1      7.0        11.0       15.0           14.0       11.0        127.1M
# 2      9.0         9.0       15.0           15.0       11.0        228.1M
# 3     90.0        85.0       87.0           88.0       94.0        138.6M
# 4     15.0        13.0        5.0           10.0       13.0        196.4M
#
# [5 rows x 89 columns]

# %%
df.shape
# Out:
# (18207, 89)

# %%
df.isnull().mean()
# Out:
# Unnamed: 0        0.000000
# ID                0.000000
# Name              0.000000
# Age               0.000055
# Photo             0.000000
#                     ...
# GKHandling        0.002636
# GKKicking         0.002636
# GKPositioning     0.002636
# GKReflexes        0.002636
# Release Clause    0.085901
# Length: 89, dtype: float64

# %%
sns.heatmap(df.isna(), cmap='viridis', yticklabels=False, cbar=None)
# Out:
# <AxesSubplot:>

# %%
# Funkcija koja vraca sve promenljive dataframe-a (prosledjenog kao argument)...
# ... cije vrednosti prevazilaze definisani prag nedostajucih vrednosti (missing_percentige)

def missing_values_boundry(df, missing_percentige):
    
    columns_with_missing_values_above_border = []
    series = df.isna().mean()
    for index in series.index:
        if series[index] > missing_percentige:
            columns_with_missing_values_above_border.append(index)
    return columns_with_missing_values_above_border

# Pozivom funkcije utvrdjeno je da postoji samo jedna promenljiva koja prevazilazi...
# granicu od 30 % nedostajucih vrednosti ('Loaned From')

missing_values_boundry(df, 0.3)
# Out:
# ['Loaned From']

# %%
# Promenljiva 'Loaned From' sadrzi oko 93 % nedostajucih vrednosti

df['Loaned From'].isna().mean()
# Out:
# 0.9305761520294392

# %%
# S obzirom da se u koloni 'Loaned From' nalazi oko 93 % nedostajucih vrednosti...
# ... ukloni ovu kolonu iz skupa podataka

df.drop('Loaned From', axis=1, inplace=True)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'Name', 'Age', 'Photo', 'Nationality', 'Flag',
#        'Overall', 'Potential', 'Club', 'Club Logo', 'Value', 'Wage', 'Special',
#        'Preferred Foot', 'International Reputation', 'Weak Foot',
#        'Skill Moves', 'Work Rate', 'Body Type', 'Real Face', 'Position',
#        'Jersey Number', 'Joined', 'Contract Valid Until', 'Height', 'Weight',
#        'LS', 'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW', 'LAM', 'CAM', 'RAM',
#        'LM', 'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM', 'CDM', 'RDM', 'RWB', 'LB',
#        'LCB', 'CB', 'RCB', 'RB', 'Crossing', 'Finishing', 'HeadingAccuracy',
#        'ShortPassing', 'Volleys', 'Dribbling', 'Curve', 'FKAccuracy',
#        'LongPassing', 'BallControl', 'Acceleration', 'SprintSpeed', 'Agility',
#        'Reactions', 'Balance', 'ShotPower', 'Jumping', 'Stamina', 'Strength',
#        'LongShots', 'Aggression', 'Interceptions', 'Positioning', 'Vision',
#        'Penalties', 'Composure', 'Marking', 'StandingTackle', 'SlidingTackle',
#        'GKDiving', 'GKHandling', 'GKKicking', 'GKPositioning', 'GKReflexes',
#        'Release Clause'],
#       dtype='object')

# %%
df['Position'].unique()
# Out:
# array(['RF', 'ST', 'LW', 'GK', 'RCM', 'LF', 'RS', 'RCB', 'LCM', 'CB',
#        'LDM', 'CAM', 'CDM', 'LS', 'LCB', 'RM', 'LAM', 'LM', 'LB', 'RDM',
#        'RW', 'CM', 'RB', 'RAM', 'CF', 'RWB', 'LWB', nan], dtype=object)

# %%
# podela promenljivih na numericke i kategoricke

numeric = []
categorical = []
for column in df.columns:
    if str(df[column].dtype) == 'object':
        categorical.append(column)
    else:
        numeric.append(column)
        
numeric.remove('ID')
numeric.remove('Unnamed: 0')

len(numeric) + len(categorical)
print('Broj kategorickih promenljivih:', len(categorical))
print('Broj numerickih promenljivih:', len(numeric))
# Out:
# Broj kategorickih promenljivih: 44
# Broj numerickih promenljivih: 42

# %%
# zamena NaN vrednosti zeljenim metodom (mean, mode, median ili random sample imputation-om)

def impute_value(df, variable, method='random sample'):

    if method == 'mean':
        df[variable].fillna(df[variable].mean(), inplace=True)
    elif method == 'mode':
        df[variable].fillna(df[variable].mode()[0], inplace=True)
    elif method == 'median':
        df[variable + '_median'] = df[variable].fillna(df[variable].median())
    else:
        df[variable + '_random_sample'] = df[variable]
        random_sample = df[variable].dropna().sample(df[variable].isna().sum(), random_state=0)
        random_sample.index = df.loc[df[variable].isna()].index
        df.loc[df[variable].isna(), variable] = random_sample

# %%
# Funkcija koja na osnovu medjukvartalnog rastojanja odredjuje elemente van granica...
# ... (outlier-e) promenljive koja se prosledjuje kao argument (values)

def find_irq_outliers(values):
    
    outliers = []
    sorted_values = sorted(values)
    min, max = np.percentile(sorted_values, [25, 75])
    irq_difference = max - min
    upper_border = max + 1.5 * irq_difference
    lower_border = min - 1.5 * irq_difference

    for value in sorted_values:
        if value < lower_border or value > upper_border:
            outliers.append(value)
    return outliers
        
outlier_numeric_columns = []
for numerical_variable in numeric:
    if len(find_irq_outliers(df[numerical_variable])):
        outlier_numeric_columns.append(numerical_variable)

outlier_numeric_columns
# Out:
# ['Potential', 'Special']

# %%
# Za sve promenljive numerickog tipa ispitati pojavljivanje elemenata van granica(outlier-a)
# Ukoliko u odgovarajucoj promenljivoj postoje outlier vrednosti...
# ... ispitati da li zamena outlier vrednosti median vrednoscu ili random sample imputation principom...
# ... unosi manju promenu standardne devijacije. U konacnom, zameniti nedostajuce vrednosti onim vrednostima...
# ... koje unose najmanju promenu standardne devijacije
# ... Ukoliko promenljiva ne sadrzi outlier-e zameniti nedostajuce vrednosti srednjom vrednoscu

for variable in numeric:
    if variable in outlier_numeric_columns:
        impute_value(df, variable, 'median')
        impute_value(df, variable)
        standard_deviation_old_values = df[variable].std()
        standard_deviation_median_values = df[variable + '_median'].std()
        standard_deviation_random_sample = df[variable + '_random_sample'].std()
        if abs(standard_deviation_median_values - standard_deviation_old_values) < abs(standard_deviation_random_sample - standard_deviation_old_values):
            df[variable] = df[variable + '_median']
        else:
            df[variable] = df[variable + '_random_sample']
        df.drop(columns=[variable + '_random_sample', variable + '_median'], inplace=True)

    else:
        impute_value(df, variable, 'mean')

# %%
# Zameniti sve nedostajuce vrednosti kategorickih promenljivih modom

for categorical_variable in categorical:
    impute_value(df, categorical_variable, 'mode')
sum(df[categorical].isna().sum().values)
# Out:
# 0

# %%
# Nakon zamene svih nedostajucih vrednosti odgovarajucom taktikom...
# ... u skupu podataka ne sme postojati nijedna nedostajuca vrednost

sum(df[numeric].isna().sum().values)
# Out:
# 0

# %%
sns.heatmap(df.isna(), cmap='viridis', yticklabels=False, cbar=None)
# Out:
# <AxesSubplot:>

# %%
# Funkcija koja vrsi skaliranje promenljivih zeljenom metodom

def feature_scaling(df, features, method):
    
    for feature in features:
        scaled_feature = method.fit_transform(df[[feature]])
        df[feature] = scaled_feature
        
feature_scaling(df, numeric, MinMaxScaler())

df[numeric].head()
# Out:
#         Age   Overall  Potential   Special  International Reputation  \
# 0  0.517241  1.000000   0.978723  0.910836                      1.00
# 1  0.586207  1.000000   0.978723  0.926935                      1.00
# 2  0.344828  0.958333   0.957447  0.874303                      1.00
# 3  0.379310  0.937500   0.957447  0.458204                      0.75
# 4  0.379310  0.937500   0.936170  0.959752                      0.75
#
#    Weak Foot  Skill Moves  Jersey Number  Crossing  Finishing  ...  Penalties  \
# 0       0.75         0.75       0.091837  0.897727   1.000000  ...   0.804598
# 1       0.75         1.00       0.061224  0.897727   0.989247  ...   0.919540
# 2       1.00         1.00       0.091837  0.840909   0.913978  ...   0.873563
# 3       0.50         0.00       0.000000  0.136364   0.118280  ...   0.402299
# 4       1.00         0.75       0.061224  1.000000   0.860215  ...   0.850575
#
#    Composure   Marking  StandingTackle  SlidingTackle  GKDiving  GKHandling  \
# 0   1.000000  0.329670        0.285714       0.261364  0.056180    0.109890
# 1   0.989247  0.274725        0.318681       0.227273  0.067416    0.109890
# 2   0.978495  0.263736        0.241758       0.340909  0.089888    0.087912
# 3   0.698925  0.131868        0.208791       0.113636  1.000000    0.923077
# 4   0.913978  0.714286        0.615385       0.545455  0.157303    0.131868
#
#    GKKicking  GKPositioning  GKReflexes
# 0   0.155556       0.146067    0.075269
# 1   0.155556       0.146067    0.107527
# 2   0.155556       0.157303    0.107527
# 3   0.955556       0.977528    1.000000
# 4   0.044444       0.101124    0.129032
#
# [5 rows x 42 columns]

# %% [markdown]
# ## Pozicije igrača u timu (i podpozicije u okviru odgovarajuće pozicije)
#
# **Golman** - GK
#
# **Odbrana** - RWB, RB, RCB, CB, LCB, LB, LWB
#
# **Vezni red** - RDM, CDM, LDM, RM, RCM, CM, LCM, LM, RAM, CAM, LAM
#
# **Napad** - RF, CF, LF, RS, ST, LS, LW, RW

# %%
# Funkcija koja za prosledjeni dataframe koji predstavlja jedan klaster...
# ... (sadrzi opservacije koje pripadaju istom klasteru)...
# ... stampa procenat zastupljenosti svih podpozicija igraca u datom klasteru

def show_position_percentige_per_cluster(df, cluster_number, original_dataset_length):
    
    number_of_players_in_cluster = len(df)
    print(f'Broj igraca u klasteru {cluster_number}: {number_of_players_in_cluster}, ({(number_of_players_in_cluster / original_dataset_length) * 100} %)' )
    print()

    # Napad
    
    df_num_of_attackers = len(df.loc[(df['Position'] == 'RF') | (df['Position'] == 'LF') | (df['Position'] == 'RW') | (df['Position'] == 'LW') | (df['Position'] == 'ST') | (df['Position'] =='CF') |  (df['Position'] == 'RS') | (df['Position'] == 'LS')])
    df_num_of_attackers_percentige = (df_num_of_attackers / number_of_players_in_cluster) * 100

    print(f'NAPAD: {df_num_of_attackers} ({df_num_of_attackers_percentige} %)')
    rf_number = len(df.loc[df['Position'] == 'RF'])
    rf_percentige = (rf_number / number_of_players_in_cluster) * 100
    print('Broj igraca na poziciji RF:', f'{rf_number}, ({rf_percentige} %)')
    lf_number = len(df.loc[df['Position'] == 'LF'])
    lf_percentige = (lf_number / number_of_players_in_cluster) * 100
    print('Broj igraca na poziciji LF:', f'{lf_number}, ({lf_percentige} %)')
    rw_number = len(df.loc[df['Position'] == 'RW'])
    rw_percentige = (rw_number / number_of_players_in_cluster) * 100
    print('Broj igraca na poziciji RW:', f'{rw_number}, ({rw_percentige} %)')
    lw_number = len(df.loc[df['Position'] == 'LW'])
    lw_percentige = (lw_number / number_of_players_in_cluster) * 100
    print('Broj igraca na poziciji LW:', f'{lw_number}, ({lw_percentige} %)')
    st_number = len(df.loc[df['Position'] == 'ST'])
    st_percentige = (st_number / number_of_players_in_cluster ) * 100
    print('Broj igraca na poziciji ST:', f'{st_number}, ({st_percentige} %)')
    cf_number = len(df.loc[df['Position'] == 'CF'])
    cf_percentige = (cf_number / number_of_players_in_cluster) * 100
    print('Broj igraca na poziciji CF:', f'{cf_number}, ({cf_percentige} %)')
    rs_number = len(df.loc[df['Position'] == 'RS'])
    rs_percentige = (rs_number / number_of_players_in_cluster) * 100
    print('Broj igraca na poziciji RS:', f'{rs_number}, ({rs_percentige} %)')
    ls_number = len(df.loc[df['Position'] == 'LS'])
    ls_percentige = (ls_number / number_of_players_in_cluster) * 100
    print('Broj igraca na poziciji LS:', f'{ls_number}, ({ls_percentige} %)')
    print()

    # Vezni red

    df_num_of_mid = len(df.loc[(df['Position'] == 'RDM') | (df['Position'] == 'CDM') | (df['Position'] == 'LDM') | (df['Position'] == 'RM') | (df['Position'] == 'RCM') | (df['Position'] == 'CM') | (df['Position'] == 'LCM') | (df['Position'] == 'LM') | (df['Position'] == 'RAM') | (df['Position'] == 'CAM') | (df['Position'] =='LAM')])
    df_num_of_mid_percentige = (df_num_of_mid / number_of_players_in_cluster) * 100

    print(f'VEZNI RED: {df_num_of_mid} ({df_num_of_mid_percentige} %)')
    rdm_number = len(df.loc[df['Position'] == 'RDM'])
    rdm_percentige = (rdm_number / number_of_players_in_cluster) * 100
    print('Broj igraca na poziciji RDM:', f'{rdm_number}, ({rdm_percentige} %)')
    cdm_number = len(df.loc[df['Position'] == 'CDM'])
    cdm_percentige = (cdm_number / number_of_players_in_cluster) * 100
    print('Broj igraca na poziciji CDM:', f'{cdm_number}, ({cdm_percentige} %)')
    ldm_number = len(df.loc[df['Position'] == 'LDM'])
    ldm_percentige = (ldm_number / number_of_players_in_cluster) * 100
    print('Broj igraca na poziciji LDM:', f'{ldm_number}, ({ldm_percentige} %)')
    rm_number = len(df.loc[df['Position'] == 'RM'])
    rm_percentige = (rm_number / number_of_players_in_cluster) * 100
    print('Broj igraca na poziciji RM:', f'{rm_number}, ({rm_percentige} %)')
    rcm_number = len(df.loc[df['Position'] == 'RCM'])
    rcm_percentige = (rcm_number / number_of_players_in_cluster) * 100
    print('Broj igraca na poziciji RCM:', f'{rcm_number}, ({rcm_percentige} %)')
    cm_number = len(df.loc[df['Position'] == 'CM'])
    cm_percentige = (cm_number / number_of_players_in_cluster) * 100
    print('Broj igraca na poziciji CM:', f'{cm_number}, ({cm_percentige} %)')
    lcm_number = len(df.loc[df['Position'] == 'LCM'])
    lcm_percentige = (lcm_number / number_of_players_in_cluster) * 100
    print('Broj igraca na poziciji LCM:', f'{lcm_number}, ({lcm_percentige} %)')
    lm_number = len(df.loc[df['Position'] == 'LM'])
    lm_percentige = (lm_number / number_of_players_in_cluster) * 100
    print('Broj igraca na poziciji LM:', f'{lm_number}, ({lm_percentige} %)')
    ram_number = len(df.loc[df['Position'] == 'RAM'])
    ram_percentige = (ram_number / number_of_players_in_cluster) * 100
    print('Broj igraca na poziciji RAM:', f'{ram_number}, ({ram_percentige} %)')
    cam_number = len(df.loc[df['Position'] == 'CAM'])
    cam_percentige = (cam_number / number_of_players_in_cluster) * 100
    print('Broj igraca na poziciji CAM:', f'{cam_number}, ({cam_percentige} %)')
    lam_number = len(df.loc[df['Position'] == 'LAM'])
    lam_percentige = (lam_number / number_of_players_in_cluster) * 100
    print('Broj igraca na poziciji LAM:', f'{lam_number}, ({lam_percentige} %)')
    print()

    # Odbrana

    df_num_of_dif = len(df.loc[(df['Position'] == 'RWB') | (df['Position'] == 'RB') | (df['Position'] == 'RCB') | (df['Position'] == 'CB') | (df['Position'] == 'LCB') | (df['Position'] == 'LB') | (df['Position'] == 'LWB')])
    df_num_of_dif_percentige = (df_num_of_dif / number_of_players_in_cluster) * 100

    print(f'ODBRANA: {df_num_of_dif} ({df_num_of_dif_percentige} %)')
    rwb_number = len(df.loc[df['Position'] == 'RWB'])
    rwb_percentige = (rwb_number / number_of_players_in_cluster) * 100
    print('Broj igraca na poziciji RWB:', f'{rwb_number}, ({rwb_percentige} %)')
    rb_number = len(df.loc[df['Position'] == 'RB'])
    rb_percentige = (rb_number / number_of_players_in_cluster) * 100
    print('Broj igraca na poziciji RB:', f'{rb_number}, ({rb_percentige} %)')
    rcb_number = len(df.loc[df['Position'] == 'RCB'])
    rcb_percentige = (rcb_number / number_of_players_in_cluster) * 100
    print('Broj igraca na poziciji RCB:', f'{rcb_number}, ({rcb_percentige} %)')
    cb_number = len(df.loc[df['Position'] == 'CB'])
    cb_percentige = (cb_number / number_of_players_in_cluster) * 100
    print('Broj igraca na poziciji CB:', f'{cb_number}, ({cb_percentige} %)')
    lcb_number = len(df.loc[df['Position'] == 'LCB'])
    lcb_percentige = (lcb_number / number_of_players_in_cluster) * 100
    print('Broj igraca na poziciji LCB:', f'{lcb_number}, ({lcb_percentige} %)')
    lb_number = len(df.loc[df['Position'] == 'LB'])
    lb_percentige = (lb_number / number_of_players_in_cluster) * 100
    print('Broj igraca na poziciji LB:', f'{lb_number}, ({lb_percentige} %)')
    lwb_number = len(df.loc[df['Position'] == 'LWB'])
    lwb_percentige = (lwb_number / number_of_players_in_cluster) * 100
    print('Broj igraca na poziciji LWB:', f'{lwb_number}, ({lwb_percentige} %)')
    print()

    # Golmani

    df_num_of_gk = len(df.loc[df['Position'] == 'GK'])
    df_num_of_gk_percentige = (df_num_of_gk / number_of_players_in_cluster) * 100
    
    print(f'GOLMANI: {df_num_of_gk} ({df_num_of_gk_percentige} %)')
    print()

# %% [markdown]
# # <center>K-means algoritam</center>

# %% [markdown]
# - Jedan od glavnih problema klasterizacije k-means algoritmom, pored njegove nedeterminističnosti je i taj što se broj klastera **k** mora odrediti unapred i smatra se jednim od ulaznih hiperparametara u algoritam.
#
# - Stoga, potrebno je izvršiti klasterizaciju za različite vrednosti parametra **k**, a onda iskoristiti neku od taktika pomoću koje se kvantitativno karakteriše kvalitet dobijenog rešenja da se odabere optimalan (tačnije što je moguće optimalniji) broj klastera.

# %%
# Izvrsiti klasterizaciju za razlicite vrednosti parametra k...
# ... pocevsi od 2, pa sve do 10
# Za svako pojedinacno dobijeno resenje, zapamtiti SSE (sumu kvadratnih gresaka) i silhouette score

sse = []
silhouette = []
for k in range(2, 11):
    kmeans = KMeans(n_clusters=k, random_state=0)
    kmeans.fit(df[numeric])
    sse.append(kmeans.inertia_)
    silhouette.append(silhouette_score(df[numeric], kmeans.labels_))

# %% [markdown]
# - Najpre, kvalitet svakog pojedinačno dobijenog rešenja testirati pomoću metode lakta (elbow method).
# - Metoda lakta se oslanja na vizuelno prikazivanje zavisnosti **SSE** (sume kvadratnih gresaka) od vrednosti broja klastera **k**
# - Vrednost **SSE** opada sa povećanjem vrednosti **k**, konvergira ka nuli, i dostiže tu konvergenciju kada broj klastera odgovara broju opservacija u skupu podataka (**singleton** klasteri)
# - Najoptimalniji broj klastera se dobija tražeći krivinu na grafiku koja se naziva "lakat", do koje **SSE** ima veću brzinu opadanja, a nakon koje **SSE** nastavlja da opada ali znatno manjim intenzitetom, odnosno brzinom

# %%
plt.figure(num=None, figsize=(8, 6), dpi=200)
plt.plot(range(2, 11), sse)
plt.title('Elbow method')
plt.xlabel('K')
plt.ylabel('SSE')
# Out:
# Text(0, 0.5, 'SSE')

# %% [markdown]
# Vizuelnim putem, utvrđeno je da je najoptimalnija vrednost za **k=5**, zato što je brzina opadanja **SSE** vrednosti do te vrednosti veća, a nakon nje opadanje je nastavljeno umanjenom brzinom

# %%
kmeans = KMeans(n_clusters=5, random_state=0)
kmeans.fit(df[numeric])
kmeans.labels_

count = Counter(kmeans.labels_)
number_and_percentige_per_cluster = {}

for value, times in count.most_common():
    number_and_percentige_per_cluster[value] = [times, (times / len(df)) * 100]
    
number_and_percentige_per_cluster
# Out:
# {4: [4894, 26.87977151644972],
#  0: [4626, 25.40781018289669],
#  1: [3545, 19.47053331136376],
#  3: [3116, 17.114296699071787],
#  2: [2026, 11.127588290218048]}

# %%
df['cluster_marks'] = kmeans.labels_

df_cluster_0 = df.loc[df['cluster_marks'] == 0]
df_cluster_1 = df.loc[df['cluster_marks'] == 1]
df_cluster_2 = df.loc[df['cluster_marks'] == 2]
df_cluster_3 = df.loc[df['cluster_marks'] == 3]
df_cluster_4 = df.loc[df['cluster_marks'] == 4]

show_position_percentige_per_cluster(df_cluster_0, 0, len(df))
show_position_percentige_per_cluster(df_cluster_1, 1, len(df))
show_position_percentige_per_cluster(df_cluster_2, 2, len(df))
show_position_percentige_per_cluster(df_cluster_3, 3, len(df))
show_position_percentige_per_cluster(df_cluster_4, 4, len(df))
# Out:
# Broj igraca u klasteru 0: 4626, (25.40781018289669 %)
#
# NAPAD: 10 (0.21616947686986598 %)
# Broj igraca na poziciji RF: 0, (0.0 %)
# Broj igraca na poziciji LF: 0, (0.0 %)
# Broj igraca na poziciji RW: 0, (0.0 %)
# Broj igraca na poziciji LW: 0, (0.0 %)
# Broj igraca na poziciji ST: 10, (0.21616947686986598 %)
# Broj igraca na poziciji CF: 0, (0.0 %)
# Broj igraca na poziciji RS: 0, (0.0 %)
# Broj igraca na poziciji LS: 0, (0.0 %)
#
# VEZNI RED: 809 (17.488110678772156 %)
# Broj igraca na poziciji RDM: 37, (0.799827064418504 %)
# Broj igraca na poziciji CDM: 355, (7.674016428880242 %)
# Broj igraca na poziciji LDM: 37, (0.799827064418504 %)
# Broj igraca na poziciji RM: 27, (0.5836575875486382 %)
# Broj igraca na poziciji RCM: 35, (0.7565931690445309 %)
# Broj igraca na poziciji CM: 255, (5.512321660181582 %)
# Broj igraca na poziciji LCM: 31, (0.6701253782965845 %)
# Broj igraca na poziciji LM: 24, (0.5188067444876783 %)
# Broj igraca na poziciji RAM: 0, (0.0 %)
# Broj igraca na poziciji CAM: 8, (0.17293558149589278 %)
# Broj igraca na poziciji LAM: 0, (0.0 %)
#
# ODBRANA: 3807 (82.29571984435798 %)
# Broj igraca na poziciji RWB: 37, (0.799827064418504 %)
# Broj igraca na poziciji RB: 591, (12.775616083009078 %)
# Broj igraca na poziciji RCB: 517, (11.175961954172072 %)
# Broj igraca na poziciji CB: 1562, (33.765672287073066 %)
# Broj igraca na poziciji LCB: 496, (10.722006052745352 %)
# Broj igraca na poziciji LB: 575, (12.429744920017294 %)
# Broj igraca na poziciji LWB: 29, (0.6268914829226113 %)
#
# GOLMANI: 0 (0.0 %)
#
# Broj igraca u klasteru 1: 3545, (19.47053331136376 %)
#
# NAPAD: 1937 (54.64033850493652 %)
# Broj igraca na poziciji RF: 1, (0.028208744710860365 %)
# Broj igraca na poziciji LF: 1, (0.028208744710860365 %)
# Broj igraca na poziciji RW: 165, (4.65444287729196 %)
# Broj igraca na poziciji LW: 171, (4.823695345557122 %)
# Broj igraca na poziciji ST: 1400, (39.492242595204516 %)
# Broj igraca na poziciji CF: 39, (1.1001410437235544 %)
# Broj igraca na poziciji RS: 78, (2.2002820874471087 %)
# Broj igraca na poziciji LS: 82, (2.31311706629055 %)
#
# VEZNI RED: 1569 (44.25952045133992 %)
# Broj igraca na poziciji RDM: 6, (0.16925246826516221 %)
# Broj igraca na poziciji CDM: 8, (0.22566995768688292 %)
# Broj igraca na poziciji LDM: 6, (0.16925246826516221 %)
# Broj igraca na poziciji RM: 444, (12.524682651622001 %)
# Broj igraca na poziciji RCM: 18, (0.5077574047954866 %)
# Broj igraca na poziciji CM: 300, (8.46262341325811 %)
# Broj igraca na poziciji LCM: 25, (0.7052186177715092 %)
# Broj igraca na poziciji LM: 419, (11.819464033850494 %)
# Broj igraca na poziciji RAM: 1, (0.028208744710860365 %)
# Broj igraca na poziciji CAM: 340, (9.590973201692526 %)
# Broj igraca na poziciji LAM: 2, (0.05641748942172073 %)
#
# ODBRANA: 39 (1.1001410437235544 %)
# Broj igraca na poziciji RWB: 5, (0.14104372355430184 %)
# Broj igraca na poziciji RB: 14, (0.39492242595204513 %)
# Broj igraca na poziciji RCB: 0, (0.0 %)
# Broj igraca na poziciji CB: 3, (0.08462623413258111 %)
# Broj igraca na poziciji LCB: 1, (0.028208744710860365 %)
# Broj igraca na poziciji LB: 13, (0.36671368124118475 %)
# Broj igraca na poziciji LWB: 3, (0.08462623413258111 %)
#
# GOLMANI: 0 (0.0 %)
#
# Broj igraca u klasteru 2: 2026, (11.127588290218048 %)
#
# NAPAD: 1 (0.04935834155972359 %)
# Broj igraca na poziciji RF: 0, (0.0 %)
# Broj igraca na poziciji LF: 0, (0.0 %)
# Broj igraca na poziciji RW: 0, (0.0 %)
# Broj igraca na poziciji LW: 0, (0.0 %)
# Broj igraca na poziciji ST: 1, (0.04935834155972359 %)
# Broj igraca na poziciji CF: 0, (0.0 %)
# Broj igraca na poziciji RS: 0, (0.0 %)
# Broj igraca na poziciji LS: 0, (0.0 %)
#
# VEZNI RED: 0 (0.0 %)
# Broj igraca na poziciji RDM: 0, (0.0 %)
# Broj igraca na poziciji CDM: 0, (0.0 %)
# Broj igraca na poziciji LDM: 0, (0.0 %)
# Broj igraca na poziciji RM: 0, (0.0 %)
# Broj igraca na poziciji RCM: 0, (0.0 %)
# Broj igraca na poziciji CM: 0, (0.0 %)
# Broj igraca na poziciji LCM: 0, (0.0 %)
# Broj igraca na poziciji LM: 0, (0.0 %)
# Broj igraca na poziciji RAM: 0, (0.0 %)
# Broj igraca na poziciji CAM: 0, (0.0 %)
# Broj igraca na poziciji LAM: 0, (0.0 %)
#
# ODBRANA: 0 (0.0 %)
# Broj igraca na poziciji RWB: 0, (0.0 %)
# Broj igraca na poziciji RB: 0, (0.0 %)
# Broj igraca na poziciji RCB: 0, (0.0 %)
# Broj igraca na poziciji CB: 0, (0.0 %)
# Broj igraca na poziciji LCB: 0, (0.0 %)
# Broj igraca na poziciji LB: 0, (0.0 %)
# Broj igraca na poziciji LWB: 0, (0.0 %)
#
# GOLMANI: 2025 (99.95064165844028 %)
#
# Broj igraca u klasteru 3: 3116, (17.114296699071787 %)
#
# NAPAD: 1453 (46.63029525032093 %)
# Broj igraca na poziciji RF: 14, (0.4492939666238768 %)
# Broj igraca na poziciji LF: 13, (0.41720154043645696 %)
# Broj igraca na poziciji RW: 182, (5.840821566110398 %)
# Broj igraca na poziciji LW: 185, (5.937098844672657 %)
# Broj igraca na poziciji ST: 780, (25.03209242618742 %)
# Broj igraca na poziciji CF: 35, (1.123234916559692 %)
# Broj igraca na poziciji RS: 121, (3.8831835686777922 %)
# Broj igraca na poziciji LS: 123, (3.9473684210526314 %)
#
# VEZNI RED: 1658 (53.20924261874198 %)
# Broj igraca na poziciji RDM: 8, (0.25673940949935814 %)
# Broj igraca na poziciji CDM: 2, (0.06418485237483953 %)
# Broj igraca na poziciji LDM: 12, (0.38510911424903727 %)
# Broj igraca na poziciji RM: 477, (15.30808729139923 %)
# Broj igraca na poziciji RCM: 45, (1.4441591784338896 %)
# Broj igraca na poziciji CM: 80, (2.5673940949935816 %)
# Broj igraca na poziciji LCM: 63, (2.0218228498074455 %)
# Broj igraca na poziciji LM: 473, (15.179717586649552 %)
# Broj igraca na poziciji RAM: 18, (0.5776636713735559 %)
# Broj igraca na poziciji CAM: 461, (14.794608472400514 %)
# Broj igraca na poziciji LAM: 19, (0.6097560975609756 %)
#
# ODBRANA: 5 (0.16046213093709885 %)
# Broj igraca na poziciji RWB: 0, (0.0 %)
# Broj igraca na poziciji RB: 0, (0.0 %)
# Broj igraca na poziciji RCB: 1, (0.03209242618741977 %)
# Broj igraca na poziciji CB: 0, (0.0 %)
# Broj igraca na poziciji LCB: 0, (0.0 %)
# Broj igraca na poziciji LB: 3, (0.09627727856225932 %)
# Broj igraca na poziciji LWB: 1, (0.03209242618741977 %)
#
# GOLMANI: 0 (0.0 %)
#
# Broj igraca u klasteru 4: 4894, (26.87977151644972 %)
#
# NAPAD: 77 (1.5733551287290561 %)
# Broj igraca na poziciji RF: 1, (0.02043318348998774 %)
# Broj igraca na poziciji LF: 1, (0.02043318348998774 %)
# Broj igraca na poziciji RW: 23, (0.469963220269718 %)
# Broj igraca na poziciji LW: 25, (0.5108295872496935 %)
# Broj igraca na poziciji ST: 21, (0.4290968532897425 %)
# Broj igraca na poziciji CF: 0, (0.0 %)
# Broj igraca na poziciji RS: 4, (0.08173273395995095 %)
# Broj igraca na poziciji LS: 2, (0.04086636697997548 %)
#
# VEZNI RED: 2802 (57.25378013894564 %)
# Broj igraca na poziciji RDM: 197, (4.025337147527585 %)
# Broj igraca na poziciji CDM: 583, (11.912545974662853 %)
# Broj igraca na poziciji LDM: 188, (3.8414384961176955 %)
# Broj igraca na poziciji RM: 176, (3.5962402942378424 %)
# Broj igraca na poziciji RCM: 293, (5.986922762566408 %)
# Broj igraca na poziciji CM: 759, (15.508786268900696 %)
# Broj igraca na poziciji LCM: 276, (5.639558643236616 %)
# Broj igraca na poziciji LM: 179, (3.657539844707806 %)
# Broj igraca na poziciji RAM: 2, (0.04086636697997548 %)
# Broj igraca na poziciji CAM: 149, (3.0445443400081733 %)
# Broj igraca na poziciji LAM: 0, (0.0 %)
#
# ODBRANA: 2015 (41.1728647323253 %)
# Broj igraca na poziciji RWB: 45, (0.9194932570494483 %)
# Broj igraca na poziciji RB: 686, (14.017163874131588 %)
# Broj igraca na poziciji RCB: 144, (2.942378422558235 %)
# Broj igraca na poziciji CB: 213, (4.352268083367389 %)
# Broj igraca na poziciji LCB: 151, (3.085410706988149 %)
# Broj igraca na poziciji LB: 731, (14.936657131181038 %)
# Broj igraca na poziciji LWB: 45, (0.9194932570494483 %)
#
# GOLMANI: 0 (0.0 %)

# %% [markdown]
# ### Algoritam k-means svrstava jednog napadača (ST pozicija) u klaster koji čine golmani, što ukazuje na outlier

# %%
player = df_cluster_2.loc[df_cluster_2['Position'] == 'ST']
player
# Out:
#        Unnamed: 0      ID     Name       Age  \
# 16450       16450  193911  S. Paul  0.517241
#
#                                                 Photo Nationality  \
# 16450  https://cdn.sofifa.org/players/4/19/193911.png       India
#
#                                        Flag   Overall  Potential       Club  \
# 16450  https://cdn.sofifa.org/flags/159.png  0.229167   0.191489  AS Monaco
#
#        ...   Marking StandingTackle SlidingTackle  GKDiving GKHandling  \
# 16450  ...  0.098901       0.142857      0.102273   0.58427   0.516484
#
#        GKKicking  GKPositioning  GKReflexes Release Clause cluster_marks
# 16450   0.677778       0.629213    0.634409          1.1M             2
#
# [1 rows x 89 columns]

# %%
df1 = df.replace({'RF': 'ATT', 'LF': 'ATT', 'RW': 'ATT', 'LW': 'ATT', 'ST': 'ATT', 'CF': 'ATT', 'RS': 'ATT', 'LS': 'ATT',
            'RDM': 'MF', 'CDM': 'MF', 'LDM': 'MF', 'RM': 'MF', 'RCM': 'MF', 'CM': 'MF', 'LCM': 'MF', 'LM': 'MF', 'RAM': 'MF', 'CAM': 'MF', 'LAM': 'MF',
            'RWB': 'DF', 'RB': 'DF', 'RCB': 'DF', 'CB': 'DF', 'LCB': 'DF', 'LB': 'DF', 'LWB': 'DF'})

df1['Position'].unique()
# Out:
# array(['ATT', 'GK', 'MF', 'DF'], dtype=object)

# %%
plt.figure(num=None, figsize=(8, 6), dpi=200)
sns.countplot(x='cluster_marks', hue='Position', data=df1)
# Out:
# <AxesSubplot:xlabel='cluster_marks', ylabel='count'>

# %% [markdown]
# - Pored metode lakta, korisno bi bilo upotrebiti i **silhouette** skor kao još jednu od metoda kvantitativnog određivanja kvaliteta dobijenog rešenja nakon izvršene klasterizacije
# - Teoretski gledano, **silhouette** skor je optimalniji u odnosu na metodu lakta, zato što nagrađuje dobru koheziju (gustinu) klastera i dobru separaciju klastera, odnosno kažnjava lošu koheziju, odnosno lošu separaciju klastera, dok metoda lakta nagrađuje samo dobru koheziju klastera, dok na separaciju klastera ne obraća pažnju
# - Međutim, jedan od nedostataka nenadgledanog učenja je baš taj što za razliku od nadgledanog učenja "rešenja" nisu poznata (kolona koja sadrži oznake, odnosno labele opservacija čak i da je određena ne tretira se na isti način kao kod nadgledanog učenja), tako da je teško odrediti koju metodu za evaluaciju rešenja uzeti u konačnom kao merodavnu

# %% [markdown]
# ### **Silhouette** skor je pokazao da je najbolja kohezija i separacija dobijena kada je k=2,  što možemo odbaciti na osnovu intuicije, znajući da u fudbalu postoje četiri osnovne pozicije

# %%
plt.figure(num=None, figsize=(8, 6), dpi=200)
plt.plot(range(2, 11), silhouette)
plt.title('Silhouette test')
plt.xlabel('K')
plt.ylabel('Silhouette score')
# Out:
# Text(0, 0.5, 'Silhouette score')

# %%
kmeans = KMeans(n_clusters=2, random_state=0)
kmeans.fit(df[numeric])
kmeans.labels_

count = Counter(kmeans.labels_)
number_and_percentige_per_cluster = {}

for value, times in count.most_common():
    number_and_percentige_per_cluster[value] = [times, (times / len(df)) * 100]

number_and_percentige_per_cluster
# Out:
# {0: [16180, 88.8669193167463], 1: [2027, 11.133080683253693]}

# %%
df['cluster_marks'] = kmeans.labels_

df_cluster_0 = df.loc[df['cluster_marks'] == 0]
df_cluster_1 = df.loc[df['cluster_marks'] == 1]

show_position_percentige_per_cluster(df_cluster_0, 0, len(df))
show_position_percentige_per_cluster(df_cluster_1, 1, len(df))
# Out:
# Broj igraca u klasteru 0: 16180, (88.8669193167463 %)
#
# NAPAD: 3477 (21.489493201483313 %)
# Broj igraca na poziciji RF: 16, (0.0988875154511743 %)
# Broj igraca na poziciji LF: 15, (0.0927070457354759 %)
# Broj igraca na poziciji RW: 370, (2.2867737948084055 %)
# Broj igraca na poziciji LW: 381, (2.3547589616810876 %)
# Broj igraca na poziciji ST: 2211, (13.665018541409147 %)
# Broj igraca na poziciji CF: 74, (0.4573547589616811 %)
# Broj igraca na poziciji RS: 203, (1.254635352286774 %)
# Broj igraca na poziciji LS: 207, (1.2793572311495673 %)
#
# VEZNI RED: 6838 (42.26205191594561 %)
# Broj igraca na poziciji RDM: 248, (1.5327564894932013 %)
# Broj igraca na poziciji CDM: 948, (5.859085290482077 %)
# Broj igraca na poziciji LDM: 243, (1.5018541409147095 %)
# Broj igraca na poziciji RM: 1124, (6.946847960444994 %)
# Broj igraca na poziciji RCM: 391, (2.4165636588380717 %)
# Broj igraca na poziciji CM: 1394, (8.615574783683561 %)
# Broj igraca na poziciji LCM: 395, (2.4412855377008653 %)
# Broj igraca na poziciji LM: 1095, (6.767614338689741 %)
# Broj igraca na poziciji RAM: 21, (0.12978986402966625 %)
# Broj igraca na poziciji CAM: 958, (5.920889987639061 %)
# Broj igraca na poziciji LAM: 21, (0.12978986402966625 %)
#
# ODBRANA: 5865 (36.248454882571075 %)
# Broj igraca na poziciji RWB: 87, (0.5377008652657602 %)
# Broj igraca na poziciji RB: 1291, (7.978986402966626 %)
# Broj igraca na poziciji RCB: 662, (4.091470951792337 %)
# Broj igraca na poziciji CB: 1777, (10.982694684796044 %)
# Broj igraca na poziciji LCB: 648, (4.004944375772559 %)
# Broj igraca na poziciji LB: 1322, (8.170580964153276 %)
# Broj igraca na poziciji LWB: 78, (0.4820766378244747 %)
#
# GOLMANI: 0 (0.0 %)
#
# Broj igraca u klasteru 1: 2027, (11.133080683253693 %)
#
# NAPAD: 1 (0.049333991119881605 %)
# Broj igraca na poziciji RF: 0, (0.0 %)
# Broj igraca na poziciji LF: 0, (0.0 %)
# Broj igraca na poziciji RW: 0, (0.0 %)
# Broj igraca na poziciji LW: 0, (0.0 %)
# Broj igraca na poziciji ST: 1, (0.049333991119881605 %)
# Broj igraca na poziciji CF: 0, (0.0 %)
# Broj igraca na poziciji RS: 0, (0.0 %)
# Broj igraca na poziciji LS: 0, (0.0 %)
#
# VEZNI RED: 0 (0.0 %)
# Broj igraca na poziciji RDM: 0, (0.0 %)
# Broj igraca na poziciji CDM: 0, (0.0 %)
# Broj igraca na poziciji LDM: 0, (0.0 %)
# Broj igraca na poziciji RM: 0, (0.0 %)
# Broj igraca na poziciji RCM: 0, (0.0 %)
# Broj igraca na poziciji CM: 0, (0.0 %)
# Broj igraca na poziciji LCM: 0, (0.0 %)
# Broj igraca na poziciji LM: 0, (0.0 %)
# Broj igraca na poziciji RAM: 0, (0.0 %)
# Broj igraca na poziciji CAM: 0, (0.0 %)
# Broj igraca na poziciji LAM: 0, (0.0 %)
#
# ODBRANA: 1 (0.049333991119881605 %)
# Broj igraca na poziciji RWB: 0, (0.0 %)
# Broj igraca na poziciji RB: 0, (0.0 %)
# Broj igraca na poziciji RCB: 0, (0.0 %)
# Broj igraca na poziciji CB: 1, (0.049333991119881605 %)
# Broj igraca na poziciji LCB: 0, (0.0 %)
# Broj igraca na poziciji LB: 0, (0.0 %)
# Broj igraca na poziciji LWB: 0, (0.0 %)
#
# GOLMANI: 2025 (99.90133201776024 %)

# %%
player = df_cluster_1.loc[df_cluster_1['Position'] == 'ST']
player
# Out:
#        Unnamed: 0      ID     Name       Age  \
# 16450       16450  193911  S. Paul  0.517241
#
#                                                 Photo Nationality  \
# 16450  https://cdn.sofifa.org/players/4/19/193911.png       India
#
#                                        Flag   Overall  Potential       Club  \
# 16450  https://cdn.sofifa.org/flags/159.png  0.229167   0.191489  AS Monaco
#
#        ...   Marking StandingTackle SlidingTackle  GKDiving GKHandling  \
# 16450  ...  0.098901       0.142857      0.102273   0.58427   0.516484
#
#        GKKicking  GKPositioning  GKReflexes Release Clause cluster_marks
# 16450   0.677778       0.629213    0.634409          1.1M             1
#
# [1 rows x 89 columns]

# %%
player = df_cluster_1.loc[df_cluster_1['Position'] == 'CB']
player
# Out:
#        Unnamed: 0     ID        Name       Age  \
# 17657       17657  11430  J. McCombe  0.655172
#
#                                                Photo Nationality  \
# 17657  https://cdn.sofifa.org/players/4/19/11430.png     England
#
#                                       Flag   Overall  Potential          Club  \
# 17657  https://cdn.sofifa.org/flags/14.png  0.145833   0.106383  Lincoln City
#
#        ...   Marking StandingTackle SlidingTackle  GKDiving GKHandling  \
# 17657  ...  0.527473       0.538462      0.568182   0.05618   0.142857
#
#        GKKicking  GKPositioning  GKReflexes Release Clause cluster_marks
# 17657   0.122222        0.11236    0.139785           18K             1
#
# [1 rows x 89 columns]

# %%
df1 = df.replace({'RF': 'ATT', 'LF': 'ATT', 'RW': 'ATT', 'LW': 'ATT', 'ST': 'ATT', 'CF': 'ATT', 'RS': 'ATT', 'LS': 'ATT',
            'RDM': 'MF', 'CDM': 'MF', 'LDM': 'MF', 'RM': 'MF', 'RCM': 'MF', 'CM': 'MF', 'LCM': 'MF', 'LM': 'MF', 'RAM': 'MF', 'CAM': 'MF', 'LAM': 'MF',
            'RWB': 'DF', 'RB': 'DF', 'RCB': 'DF', 'CB': 'DF', 'LCB': 'DF', 'LB': 'DF', 'LWB': 'DF'})

df1['Position'].unique()
# Out:
# array(['ATT', 'GK', 'MF', 'DF'], dtype=object)

# %%
plt.figure(num=None, figsize=(8, 6), dpi=200)
sns.countplot(x='cluster_marks', hue='Position', data=df1)
# Out:
# <AxesSubplot:xlabel='cluster_marks', ylabel='count'>

# %% [markdown]
# # <center>K-prototypes</center>

# %% [markdown]
# - K-prototypes algoritam je varijanta k-means algoritma, koja je projektovana da vrši klasterizaciju opservacija sa mešovitim promenljivama (skup podataka koji sadrži i kategoričke i numeričke vrednosti)
# - K-means algoritam u osnovnoj varijanti može vršiti klasterizaciju opservacija koje sadrže kategoričke vrednosti pored numeričkih vrednosti, ali je najpre neophodno izvršiti mapiranje kategoričkih vrednosti u numeričke
# - Mapiranjem kategoričkih vrednosti u numeričke, uvodi se ordinalnosti u podatke koji nemaju prirodno utvrđenu ordinalnost (zašto bi crveno bilo nula, zeleno jedan, a plavo dva ?!)
# - Stoga, najefikasnije bi bilo uvesti varijantu k-means algoritma koji će kategoričke vrednosti upravo tako i tretirati... kao kategoričke...
# - Ta varijanta k-means algoritma je upravo k-prototypes

# %%
categorical_features_index = []

for index, feature in enumerate(df.columns.values):
    if str(df[feature].dtype) == 'object':
        categorical_features_index.append(index)

# %%
# KPrototypes

sse = []

for k in range(2, 11):
    kprototypes = KPrototypes(n_clusters=k, random_state=0, n_jobs=-1)
    kprototypes.fit(df, categorical=categorical_features_index)
    sse.append(kprototypes.cost_)

# %%
plt.figure(num=None, figsize=(8, 6), dpi=200)
plt.plot(range(2, 11), sse)
plt.xlabel('K')
plt.ylabel('Cost')
# Out:
# Text(0, 0.5, 'Cost')

# %%
kprototypes = KPrototypes(n_clusters=5, random_state=0)
kprototypes.fit(df, categorical=categorical_features_index)
# Out:
# KPrototypes(gamma=15955.297012178464, n_clusters=5, random_state=0)

# %%
count = Counter(kprototypes.labels_)
number_and_percentige_per_cluster = {}

for value, times in count.most_common():
    number_and_percentige_per_cluster[value] = [times, (times / len(df)) * 100]
    
number_and_percentige_per_cluster
# Out:
# {4: [7894, 43.35695062338661],
#  1: [5468, 30.03240511891031],
#  2: [3600, 19.77261492832427],
#  0: [1101, 6.047124732245839],
#  3: [144, 0.7909045971329708]}

# %%
df['cluster_marks'] = kprototypes.labels_

df_cluster_0 = df.loc[df['cluster_marks'] == 0]
df_cluster_1 = df.loc[df['cluster_marks'] == 1]
df_cluster_2 = df.loc[df['cluster_marks'] == 2]
df_cluster_3 = df.loc[df['cluster_marks'] == 3]
df_cluster_4 = df.loc[df['cluster_marks'] == 3]

show_position_percentige_per_cluster(df_cluster_0, 0, len(df))
show_position_percentige_per_cluster(df_cluster_1, 1, len(df))
show_position_percentige_per_cluster(df_cluster_2, 2, len(df))
show_position_percentige_per_cluster(df_cluster_3, 3, len(df))
show_position_percentige_per_cluster(df_cluster_4, 4, len(df))
# Out:
# Broj igraca u klasteru 0: 1101, (6.047124732245839 %)
#
# NAPAD: 171 (15.531335149863759 %)
# Broj igraca na poziciji RF: 3, (0.2724795640326975 %)
# Broj igraca na poziciji LF: 0, (0.0 %)
# Broj igraca na poziciji RW: 13, (1.1807447774750226 %)
# Broj igraca na poziciji LW: 6, (0.544959128065395 %)
# Broj igraca na poziciji ST: 105, (9.536784741144414 %)
# Broj igraca na poziciji CF: 2, (0.18165304268846502 %)
# Broj igraca na poziciji RS: 18, (1.6348773841961852 %)
# Broj igraca na poziciji LS: 24, (2.17983651226158 %)
#
# VEZNI RED: 350 (31.78928247048138 %)
# Broj igraca na poziciji RDM: 17, (1.544050862851953 %)
# Broj igraca na poziciji CDM: 65, (5.903723887375113 %)
# Broj igraca na poziciji LDM: 20, (1.8165304268846505 %)
# Broj igraca na poziciji RM: 39, (3.5422343324250685 %)
# Broj igraca na poziciji RCM: 31, (2.815622161671208 %)
# Broj igraca na poziciji CM: 54, (4.904632152588556 %)
# Broj igraca na poziciji LCM: 26, (2.361489554950045 %)
# Broj igraca na poziciji LM: 46, (4.178019981834695 %)
# Broj igraca na poziciji RAM: 0, (0.0 %)
# Broj igraca na poziciji CAM: 51, (4.632152588555858 %)
# Broj igraca na poziciji LAM: 1, (0.09082652134423251 %)
#
# ODBRANA: 376 (34.15077202543142 %)
# Broj igraca na poziciji RWB: 3, (0.2724795640326975 %)
# Broj igraca na poziciji RB: 67, (6.085376930063579 %)
# Broj igraca na poziciji RCB: 63, (5.722070844686648 %)
# Broj igraca na poziciji CB: 114, (10.354223433242508 %)
# Broj igraca na poziciji LCB: 62, (5.631244323342416 %)
# Broj igraca na poziciji LB: 64, (5.812897366030881 %)
# Broj igraca na poziciji LWB: 3, (0.2724795640326975 %)
#
# GOLMANI: 204 (18.52861035422343 %)
#
# Broj igraca u klasteru 1: 5468, (30.03240511891031 %)
#
# NAPAD: 997 (18.233357717629847 %)
# Broj igraca na poziciji RF: 8, (0.1463057790782736 %)
# Broj igraca na poziciji LF: 5, (0.09144111192392099 %)
# Broj igraca na poziciji RW: 110, (2.011704462326262 %)
# Broj igraca na poziciji LW: 112, (2.04828090709583 %)
# Broj igraca na poziciji ST: 584, (10.680321872713973 %)
# Broj igraca na poziciji CF: 17, (0.3108997805413314 %)
# Broj igraca na poziciji RS: 80, (1.4630577907827358 %)
# Broj igraca na poziciji LS: 81, (1.48134601316752 %)
#
# VEZNI RED: 2138 (39.10021945866862 %)
# Broj igraca na poziciji RDM: 102, (1.8653986832479885 %)
# Broj igraca na poziciji CDM: 274, (5.01097293343087 %)
# Broj igraca na poziciji LDM: 82, (1.4996342355523042 %)
# Broj igraca na poziciji RM: 399, (7.297000731528895 %)
# Broj igraca na poziciji RCM: 142, (2.596927578639356 %)
# Broj igraca na poziciji CM: 351, (6.419166057059254 %)
# Broj igraca na poziciji LCM: 134, (2.4506217995610826 %)
# Broj igraca na poziciji LM: 394, (7.2055596196049745 %)
# Broj igraca na poziciji RAM: 3, (0.05486466715435259 %)
# Broj igraca na poziciji CAM: 255, (4.663496708119971 %)
# Broj igraca na poziciji LAM: 2, (0.0365764447695684 %)
#
# ODBRANA: 1788 (32.69934162399415 %)
# Broj igraca na poziciji RWB: 27, (0.4937820043891734 %)
# Broj igraca na poziciji RB: 417, (7.626188734455011 %)
# Broj igraca na poziciji RCB: 223, (4.078273591806876 %)
# Broj igraca na poziciji CB: 444, (8.119970738844184 %)
# Broj igraca na poziciji LCB: 236, (4.316020482809071 %)
# Broj igraca na poziciji LB: 410, (7.498171177761521 %)
# Broj igraca na poziciji LWB: 31, (0.5669348939283102 %)
#
# GOLMANI: 545 (9.967081199707389 %)
#
# Broj igraca u klasteru 2: 3600, (19.77261492832427 %)
#
# NAPAD: 660 (18.333333333333332 %)
# Broj igraca na poziciji RF: 3, (0.08333333333333334 %)
# Broj igraca na poziciji LF: 6, (0.16666666666666669 %)
# Broj igraca na poziciji RW: 51, (1.4166666666666665 %)
# Broj igraca na poziciji LW: 54, (1.5 %)
# Broj igraca na poziciji ST: 428, (11.88888888888889 %)
# Broj igraca na poziciji CF: 12, (0.33333333333333337 %)
# Broj igraca na poziciji RS: 56, (1.5555555555555556 %)
# Broj igraca na poziciji LS: 50, (1.3888888888888888 %)
#
# VEZNI RED: 1300 (36.11111111111111 %)
# Broj igraca na poziciji RDM: 62, (1.7222222222222223 %)
# Broj igraca na poziciji CDM: 173, (4.805555555555555 %)
# Broj igraca na poziciji LDM: 62, (1.7222222222222223 %)
# Broj igraca na poziciji RM: 185, (5.138888888888888 %)
# Broj igraca na poziciji RCM: 100, (2.7777777777777777 %)
# Broj igraca na poziciji CM: 214, (5.944444444444445 %)
# Broj igraca na poziciji LCM: 132, (3.6666666666666665 %)
# Broj igraca na poziciji LM: 184, (5.111111111111112 %)
# Broj igraca na poziciji RAM: 3, (0.08333333333333334 %)
# Broj igraca na poziciji CAM: 183, (5.083333333333333 %)
# Broj igraca na poziciji LAM: 2, (0.05555555555555555 %)
#
# ODBRANA: 1228 (34.11111111111111 %)
# Broj igraca na poziciji RWB: 21, (0.5833333333333334 %)
# Broj igraca na poziciji RB: 260, (7.222222222222221 %)
# Broj igraca na poziciji RCB: 188, (5.222222222222222 %)
# Broj igraca na poziciji CB: 312, (8.666666666666668 %)
# Broj igraca na poziciji LCB: 165, (4.583333333333333 %)
# Broj igraca na poziciji LB: 265, (7.361111111111112 %)
# Broj igraca na poziciji LWB: 17, (0.4722222222222222 %)
#
# GOLMANI: 412 (11.444444444444445 %)
#
# Broj igraca u klasteru 3: 144, (0.7909045971329708 %)
#
# NAPAD: 27 (18.75 %)
# Broj igraca na poziciji RF: 0, (0.0 %)
# Broj igraca na poziciji LF: 1, (0.6944444444444444 %)
# Broj igraca na poziciji RW: 2, (1.3888888888888888 %)
# Broj igraca na poziciji LW: 1, (0.6944444444444444 %)
# Broj igraca na poziciji ST: 18, (12.5 %)
# Broj igraca na poziciji CF: 0, (0.0 %)
# Broj igraca na poziciji RS: 3, (2.083333333333333 %)
# Broj igraca na poziciji LS: 2, (1.3888888888888888 %)
#
# VEZNI RED: 48 (33.33333333333333 %)
# Broj igraca na poziciji RDM: 3, (2.083333333333333 %)
# Broj igraca na poziciji CDM: 10, (6.944444444444445 %)
# Broj igraca na poziciji LDM: 0, (0.0 %)
# Broj igraca na poziciji RM: 6, (4.166666666666666 %)
# Broj igraca na poziciji RCM: 4, (2.7777777777777777 %)
# Broj igraca na poziciji CM: 14, (9.722222222222223 %)
# Broj igraca na poziciji LCM: 2, (1.3888888888888888 %)
# Broj igraca na poziciji LM: 2, (1.3888888888888888 %)
# Broj igraca na poziciji RAM: 0, (0.0 %)
# Broj igraca na poziciji CAM: 7, (4.861111111111112 %)
# Broj igraca na poziciji LAM: 0, (0.0 %)
#
# ODBRANA: 29 (20.13888888888889 %)
# Broj igraca na poziciji RWB: 0, (0.0 %)
# Broj igraca na poziciji RB: 0, (0.0 %)
# Broj igraca na poziciji RCB: 2, (1.3888888888888888 %)
# Broj igraca na poziciji CB: 15, (10.416666666666668 %)
# Broj igraca na poziciji LCB: 10, (6.944444444444445 %)
# Broj igraca na poziciji LB: 2, (1.3888888888888888 %)
# Broj igraca na poziciji LWB: 0, (0.0 %)
#
# GOLMANI: 40 (27.77777777777778 %)
#
# Broj igraca u klasteru 4: 144, (0.7909045971329708 %)
#
# NAPAD: 27 (18.75 %)
# Broj igraca na poziciji RF: 0, (0.0 %)
# Broj igraca na poziciji LF: 1, (0.6944444444444444 %)
# Broj igraca na poziciji RW: 2, (1.3888888888888888 %)
# Broj igraca na poziciji LW: 1, (0.6944444444444444 %)
# Broj igraca na poziciji ST: 18, (12.5 %)
# Broj igraca na poziciji CF: 0, (0.0 %)
# Broj igraca na poziciji RS: 3, (2.083333333333333 %)
# Broj igraca na poziciji LS: 2, (1.3888888888888888 %)
#
# VEZNI RED: 48 (33.33333333333333 %)
# Broj igraca na poziciji RDM: 3, (2.083333333333333 %)
# Broj igraca na poziciji CDM: 10, (6.944444444444445 %)
# Broj igraca na poziciji LDM: 0, (0.0 %)
# Broj igraca na poziciji RM: 6, (4.166666666666666 %)
# Broj igraca na poziciji RCM: 4, (2.7777777777777777 %)
# Broj igraca na poziciji CM: 14, (9.722222222222223 %)
# Broj igraca na poziciji LCM: 2, (1.3888888888888888 %)
# Broj igraca na poziciji LM: 2, (1.3888888888888888 %)
# Broj igraca na poziciji RAM: 0, (0.0 %)
# Broj igraca na poziciji CAM: 7, (4.861111111111112 %)
# Broj igraca na poziciji LAM: 0, (0.0 %)
#
# ODBRANA: 29 (20.13888888888889 %)
# Broj igraca na poziciji RWB: 0, (0.0 %)
# Broj igraca na poziciji RB: 0, (0.0 %)
# Broj igraca na poziciji RCB: 2, (1.3888888888888888 %)
# Broj igraca na poziciji CB: 15, (10.416666666666668 %)
# Broj igraca na poziciji LCB: 10, (6.944444444444445 %)
# Broj igraca na poziciji LB: 2, (1.3888888888888888 %)
# Broj igraca na poziciji LWB: 0, (0.0 %)
#
# GOLMANI: 40 (27.77777777777778 %)

# %%
df1 = df.replace({'RF': 'ATT', 'LF': 'ATT', 'RW': 'ATT', 'LW': 'ATT', 'ST': 'ATT', 'CF': 'ATT', 'RS': 'ATT', 'LS': 'ATT',
            'RDM': 'MF', 'CDM': 'MF', 'LDM': 'MF', 'RM': 'MF', 'RCM': 'MF', 'CM': 'MF', 'LCM': 'MF', 'LM': 'MF', 'RAM': 'MF', 'CAM': 'MF', 'LAM': 'MF',
            'RWB': 'DF', 'RB': 'DF', 'RCB': 'DF', 'CB': 'DF', 'LCB': 'DF', 'LB': 'DF', 'LWB': 'DF'})

df1['Position'].unique()
# Out:
# array(['ATT', 'GK', 'MF', 'DF'], dtype=object)

# %%
plt.figure(num=None, figsize=(8, 6), dpi=200)
sns.countplot(x='cluster_marks', hue='Position', data=df1)
# Out:
# <AxesSubplot:xlabel='cluster_marks', ylabel='count'>

# %% [markdown]
# # <center>Hijerarhijska klasterizacija</center>

# %% [markdown]
# ## <center>Sakupljajuća (agglomerative) klasterizacija</center>

# %% [markdown]
# - Sakupljajuća hijerarhijska klasterizacija vrši grupisanje opservacija u klastere na osnovu sličnosti, a nakon toga vrši dalje grupisanje klastera takođe na osnovu sličnosti, u klastere višeg nivoa (otuda i naziv hijerarhijska klasterizacija)
# - Jedan od mogućih izlaza hijerarhijske klasterizacije je dendrogram, grafički prikaz koji pokazije kako su se opservacije grupisale u klastere, a klasteri u klastere višeg nivoa
# - Na ovaj način ukazuje se na bliskost među opservacijama koje su grupisane u isti klaster, a neku dalju bliskost, odnosno srodnost, među opservacijama čiji su klasteri grupisani u klastere višeg nivoa
# - Međutim, ukoliko skup podataka poseduje veliki broj opservacija, zaista je teško ispratiti dendrogram
# - Sakupljajuća klasterizacija može se iskoristiti da se pomoću nje dođe do ravne klasterizacije, kombinovanjem scipy i sklearn biblioteka

# %% [markdown]
# - Scipy biblioteku je moguće iskoristiti za hijerarhijsku sakupljajuću klasterizaciju, nakon koje se dobija dendrogram
# - Visine grana u dendrogramu proporcionalne su rastojanju između klastera (što je rastojanje, odnosno razlika između klastera veća, to je grana koja spaja ta dva klastera duža)
# - Najduže vertikalne linije koje predstavljaju rastojanje između klastera, potrebno je preseću horizontalnom linijom
# - Nakon toga, utvrditi koji je broj presečnih tačaka horizontalne i vertikalnih linija
# - Upravo taj broj treba proslediti **AgglomerativeClustering** algoritmu sklear biblioteke kao ulazni hiperparametar
# - **AgglomerativeClustering** algoritam takođe vrši hijerarhijsku klasterizaciju, ali će prosleđeni ulazni hiperparametar uzeti kao informaciju kada treba prestati sa daljom hijerarhijskom klasterizacijom

# %%
# Agglomerative

plt.figure(num=None, figsize=(8, 6), dpi=200)
distance_matrix = linkage(df[numeric], 'ward')
dendrogram(distance_matrix, truncate_mode='lastp', p=12, leaf_font_size=15, show_contracted=True)
plt.axhline(y=120, linestyle='-.', color='red')
plt.axhline(y=70, linestyle='-.', color='red')
plt.title('Dendrogram')
plt.xlabel('Clusters')
plt.ylabel('Distance between clusters')
# Out:
# Text(0, 0.5, 'Distance between clusters')

# %%
# za podelu na 2 klastera

agglomerative = AgglomerativeClustering(n_clusters=2, affinity='euclidean', linkage='ward')
agglomerative.fit(df[numeric])
# Out:
# AgglomerativeClustering()

# %%
count = Counter(agglomerative.labels_)
number_and_percentige_per_cluster = {}

for value, times in count.most_common():
    number_and_percentige_per_cluster[value] = [times, (times / len(df)) * 100]
    
number_and_percentige_per_cluster
# Out:
# {0: [16181, 88.87241170978196], 1: [2026, 11.127588290218048]}

# %%
df['cluster_marks'] = agglomerative.labels_

df_cluster_0 = df.loc[df['cluster_marks'] == 0]
df_cluster_1 = df.loc[df['cluster_marks'] == 1]

show_position_percentige_per_cluster(df_cluster_0, 0, len(df))
show_position_percentige_per_cluster(df_cluster_1, 1, len(df))
# Out:
# Broj igraca u klasteru 0: 16181, (88.87241170978196 %)
#
# NAPAD: 3477 (21.48816513194487 %)
# Broj igraca na poziciji RF: 16, (0.09888140411593845 %)
# Broj igraca na poziciji LF: 15, (0.09270131635869229 %)
# Broj igraca na poziciji RW: 370, (2.2866324701810767 %)
# Broj igraca na poziciji LW: 381, (2.3546134355107844 %)
# Broj igraca na poziciji ST: 2211, (13.664174031271244 %)
# Broj igraca na poziciji CF: 74, (0.45732649403621534 %)
# Broj igraca na poziciji RS: 203, (1.254557814720969 %)
# Broj igraca na poziciji LS: 207, (1.2792781657499537 %)
#
# VEZNI RED: 6838 (42.259440084049196 %)
# Broj igraca na poziciji RDM: 248, (1.5326617637970459 %)
# Broj igraca na poziciji CDM: 948, (5.858723193869353 %)
# Broj igraca na poziciji LDM: 243, (1.5017613250108153 %)
# Broj igraca na poziciji RM: 1124, (6.946418639144676 %)
# Broj igraca na poziciji RCM: 391, (2.416414313083246 %)
# Broj igraca na poziciji CM: 1394, (8.615042333601137 %)
# Broj igraca na poziciji LCM: 395, (2.4411346641122305 %)
# Broj igraca na poziciji LM: 1095, (6.767196094184537 %)
# Broj igraca na poziciji RAM: 21, (0.1297818429021692 %)
# Broj igraca na poziciji CAM: 958, (5.920524071441815 %)
# Broj igraca na poziciji LAM: 21, (0.1297818429021692 %)
#
# ODBRANA: 5866 (36.25239478400593 %)
# Broj igraca na poziciji RWB: 87, (0.5376676348804152 %)
# Broj igraca na poziciji RB: 1291, (7.978493294604784 %)
# Broj igraca na poziciji RCB: 662, (4.091218095296953 %)
# Broj igraca na poziciji CB: 1778, (10.98819603238366 %)
# Broj igraca na poziciji LCB: 648, (4.004696866695507 %)
# Broj igraca na poziciji LB: 1322, (8.170076015079413 %)
# Broj igraca na poziciji LWB: 78, (0.4820468450651999 %)
#
# GOLMANI: 0 (0.0 %)
#
# Broj igraca u klasteru 1: 2026, (11.127588290218048 %)
#
# NAPAD: 1 (0.04935834155972359 %)
# Broj igraca na poziciji RF: 0, (0.0 %)
# Broj igraca na poziciji LF: 0, (0.0 %)
# Broj igraca na poziciji RW: 0, (0.0 %)
# Broj igraca na poziciji LW: 0, (0.0 %)
# Broj igraca na poziciji ST: 1, (0.04935834155972359 %)
# Broj igraca na poziciji CF: 0, (0.0 %)
# Broj igraca na poziciji RS: 0, (0.0 %)
# Broj igraca na poziciji LS: 0, (0.0 %)
#
# VEZNI RED: 0 (0.0 %)
# Broj igraca na poziciji RDM: 0, (0.0 %)
# Broj igraca na poziciji CDM: 0, (0.0 %)
# Broj igraca na poziciji LDM: 0, (0.0 %)
# Broj igraca na poziciji RM: 0, (0.0 %)
# Broj igraca na poziciji RCM: 0, (0.0 %)
# Broj igraca na poziciji CM: 0, (0.0 %)
# Broj igraca na poziciji LCM: 0, (0.0 %)
# Broj igraca na poziciji LM: 0, (0.0 %)
# Broj igraca na poziciji RAM: 0, (0.0 %)
# Broj igraca na poziciji CAM: 0, (0.0 %)
# Broj igraca na poziciji LAM: 0, (0.0 %)
#
# ODBRANA: 0 (0.0 %)
# Broj igraca na poziciji RWB: 0, (0.0 %)
# Broj igraca na poziciji RB: 0, (0.0 %)
# Broj igraca na poziciji RCB: 0, (0.0 %)
# Broj igraca na poziciji CB: 0, (0.0 %)
# Broj igraca na poziciji LCB: 0, (0.0 %)
# Broj igraca na poziciji LB: 0, (0.0 %)
# Broj igraca na poziciji LWB: 0, (0.0 %)
#
# GOLMANI: 2025 (99.95064165844028 %)

# %%
df1 = df.replace({'RF': 'ATT', 'LF': 'ATT', 'RW': 'ATT', 'LW': 'ATT', 'ST': 'ATT', 'CF': 'ATT', 'RS': 'ATT', 'LS': 'ATT',
            'RDM': 'MF', 'CDM': 'MF', 'LDM': 'MF', 'RM': 'MF', 'RCM': 'MF', 'CM': 'MF', 'LCM': 'MF', 'LM': 'MF', 'RAM': 'MF', 'CAM': 'MF', 'LAM': 'MF',
            'RWB': 'DF', 'RB': 'DF', 'RCB': 'DF', 'CB': 'DF', 'LCB': 'DF', 'LB': 'DF', 'LWB': 'DF'})

df1['Position'].unique()
# Out:
# array(['ATT', 'GK', 'MF', 'DF'], dtype=object)

# %%
plt.figure(num=None, figsize=(8, 6), dpi=200)
sns.countplot(x='cluster_marks', hue='Position', data=df1)
# Out:
# <AxesSubplot:xlabel='cluster_marks', ylabel='count'>

# %%
# Za podelu na 3 klastera

agglomerative = AgglomerativeClustering(n_clusters=3, affinity='euclidean', linkage='ward')
agglomerative.fit(df[numeric])
clusters = agglomerative.labels_

count = Counter(clusters)
number_and_percentige_per_cluster = {}

for value, times in count.most_common():
    number_and_percentige_per_cluster[value] = [times, (times / len(df)) * 100]
    
number_and_percentige_per_cluster
# Out:
# {0: [9548, 52.441368704344484],
#  2: [6633, 36.431043005437466],
#  1: [2026, 11.127588290218048]}

# %%
df['cluster_marks'] = agglomerative.labels_

df_cluster_0 = df.loc[df['cluster_marks'] == 0]
df_cluster_1 = df.loc[df['cluster_marks'] == 1]
df_cluster_2 = df.loc[df['cluster_marks'] == 2]

show_position_percentige_per_cluster(df_cluster_0, 0, len(df))
show_position_percentige_per_cluster(df_cluster_1, 1, len(df))
show_position_percentige_per_cluster(df_cluster_2, 1, len(df))
# Out:
# Broj igraca u klasteru 0: 9548, (52.441368704344484 %)
#
# NAPAD: 99 (1.0368663594470047 %)
# Broj igraca na poziciji RF: 1, (0.010473397570171763 %)
# Broj igraca na poziciji LF: 4, (0.04189359028068705 %)
# Broj igraca na poziciji RW: 28, (0.2932551319648094 %)
# Broj igraca na poziciji LW: 29, (0.3037285295349812 %)
# Broj igraca na poziciji ST: 30, (0.31420192710515293 %)
# Broj igraca na poziciji CF: 4, (0.04189359028068705 %)
# Broj igraca na poziciji RS: 2, (0.020946795140343526 %)
# Broj igraca na poziciji LS: 1, (0.010473397570171763 %)
#
# VEZNI RED: 3633 (38.049853372434015 %)
# Broj igraca na poziciji RDM: 233, (2.440301633850021 %)
# Broj igraca na poziciji CDM: 926, (9.698366149979053 %)
# Broj igraca na poziciji LDM: 220, (2.3041474654377883 %)
# Broj igraca na poziciji RM: 223, (2.3355676581483036 %)
# Broj igraca na poziciji RCM: 316, (3.309593632174277 %)
# Broj igraca na poziciji CM: 1040, (10.892333472978635 %)
# Broj igraca na poziciji LCM: 293, (3.068705488060327 %)
# Broj igraca na poziciji LM: 226, (2.366987850858819 %)
# Broj igraca na poziciji RAM: 3, (0.03142019271051529 %)
# Broj igraca na poziciji CAM: 153, (1.6024298282362799 %)
# Broj igraca na poziciji LAM: 0, (0.0 %)
#
# ODBRANA: 5816 (60.913280268118974 %)
# Broj igraca na poziciji RWB: 85, (0.8902387934645999 %)
# Broj igraca na poziciji RB: 1277, (13.374528697109342 %)
# Broj igraca na poziciji RCB: 659, (6.901968998743192 %)
# Broj igraca na poziciji CB: 1776, (18.600754084625052 %)
# Broj igraca na poziciji LCB: 647, (6.776288227901131 %)
# Broj igraca na poziciji LB: 1298, (13.594470046082948 %)
# Broj igraca na poziciji LWB: 74, (0.7750314201927105 %)
#
# GOLMANI: 0 (0.0 %)
#
# Broj igraca u klasteru 1: 2026, (11.127588290218048 %)
#
# NAPAD: 1 (0.04935834155972359 %)
# Broj igraca na poziciji RF: 0, (0.0 %)
# Broj igraca na poziciji LF: 0, (0.0 %)
# Broj igraca na poziciji RW: 0, (0.0 %)
# Broj igraca na poziciji LW: 0, (0.0 %)
# Broj igraca na poziciji ST: 1, (0.04935834155972359 %)
# Broj igraca na poziciji CF: 0, (0.0 %)
# Broj igraca na poziciji RS: 0, (0.0 %)
# Broj igraca na poziciji LS: 0, (0.0 %)
#
# VEZNI RED: 0 (0.0 %)
# Broj igraca na poziciji RDM: 0, (0.0 %)
# Broj igraca na poziciji CDM: 0, (0.0 %)
# Broj igraca na poziciji LDM: 0, (0.0 %)
# Broj igraca na poziciji RM: 0, (0.0 %)
# Broj igraca na poziciji RCM: 0, (0.0 %)
# Broj igraca na poziciji CM: 0, (0.0 %)
# Broj igraca na poziciji LCM: 0, (0.0 %)
# Broj igraca na poziciji LM: 0, (0.0 %)
# Broj igraca na poziciji RAM: 0, (0.0 %)
# Broj igraca na poziciji CAM: 0, (0.0 %)
# Broj igraca na poziciji LAM: 0, (0.0 %)
#
# ODBRANA: 0 (0.0 %)
# Broj igraca na poziciji RWB: 0, (0.0 %)
# Broj igraca na poziciji RB: 0, (0.0 %)
# Broj igraca na poziciji RCB: 0, (0.0 %)
# Broj igraca na poziciji CB: 0, (0.0 %)
# Broj igraca na poziciji LCB: 0, (0.0 %)
# Broj igraca na poziciji LB: 0, (0.0 %)
# Broj igraca na poziciji LWB: 0, (0.0 %)
#
# GOLMANI: 2025 (99.95064165844028 %)
#
# Broj igraca u klasteru 1: 6633, (36.431043005437466 %)
#
# NAPAD: 3378 (50.927182270465856 %)
# Broj igraca na poziciji RF: 15, (0.22614201718679333 %)
# Broj igraca na poziciji LF: 11, (0.16583747927031509 %)
# Broj igraca na poziciji RW: 342, (5.156037991858888 %)
# Broj igraca na poziciji LW: 352, (5.306799336650083 %)
# Broj igraca na poziciji ST: 2181, (32.881049298959745 %)
# Broj igraca na poziciji CF: 70, (1.0553294135383688 %)
# Broj igraca na poziciji RS: 201, (3.0303030303030303 %)
# Broj igraca na poziciji LS: 206, (3.105683702698628 %)
#
# VEZNI RED: 3205 (48.31901100557817 %)
# Broj igraca na poziciji RDM: 15, (0.22614201718679333 %)
# Broj igraca na poziciji CDM: 22, (0.33167495854063017 %)
# Broj igraca na poziciji LDM: 23, (0.3467510930197497 %)
# Broj igraca na poziciji RM: 901, (13.583597165686717 %)
# Broj igraca na poziciji RCM: 75, (1.1307100859339665 %)
# Broj igraca na poziciji CM: 354, (5.336951605608322 %)
# Broj igraca na poziciji LCM: 102, (1.5377657168701944 %)
# Broj igraca na poziciji LM: 869, (13.101160862354892 %)
# Broj igraca na poziciji RAM: 18, (0.27137042062415195 %)
# Broj igraca na poziciji CAM: 805, (12.136288255691241 %)
# Broj igraca na poziciji LAM: 21, (0.31659882406151063 %)
#
# ODBRANA: 50 (0.7538067239559777 %)
# Broj igraca na poziciji RWB: 2, (0.030152268958239106 %)
# Broj igraca na poziciji RB: 14, (0.21106588270767374 %)
# Broj igraca na poziciji RCB: 3, (0.045228403437358664 %)
# Broj igraca na poziciji CB: 2, (0.030152268958239106 %)
# Broj igraca na poziciji LCB: 1, (0.015076134479119553 %)
# Broj igraca na poziciji LB: 24, (0.3618272274988693 %)
# Broj igraca na poziciji LWB: 4, (0.06030453791647821 %)
#
# GOLMANI: 0 (0.0 %)

# %%
df1 = df.replace({'RF': 'ATT', 'LF': 'ATT', 'RW': 'ATT', 'LW': 'ATT', 'ST': 'ATT', 'CF': 'ATT', 'RS': 'ATT', 'LS': 'ATT',
            'RDM': 'MF', 'CDM': 'MF', 'LDM': 'MF', 'RM': 'MF', 'RCM': 'MF', 'CM': 'MF', 'LCM': 'MF', 'LM': 'MF', 'RAM': 'MF', 'CAM': 'MF', 'LAM': 'MF',
            'RWB': 'DF', 'RB': 'DF', 'RCB': 'DF', 'CB': 'DF', 'LCB': 'DF', 'LB': 'DF', 'LWB': 'DF'})

df1['Position'].unique()
# Out:
# array(['ATT', 'GK', 'MF', 'DF'], dtype=object)

# %%
plt.figure(num=None, figsize=(8, 6), dpi=200)
sns.countplot(x='cluster_marks', hue='Position', data=df1)
# Out:
# <AxesSubplot:xlabel='cluster_marks', ylabel='count'>

# %% [markdown]
# # <center>DBSCAN</center>

# %% [markdown]
# - **DBSCAN** algoritam spada u kategoriju algoritama klaster analize koji se zasnivaju na gustini
# - Vrši delimičnu (neiscrpnu), krutu i ravnu klasterizaciju
# - Za razliku od **k-means** algoritma, dobro se snalazi sa klasterima nesferičnih oblika, kao i sa klasterima različitih veličina
# - Za razliku od **k-means** algoritma, **DBSCAN** "samostalno" dolazi do broja klastera, ne očekujući isti kao ulazni hiperparametar u algoritam
# - **DBSCAN** algoritam pretražuje regije koje sadrže povećanu gustinu, odnosno koncentraciju opservacija, svrstavajući te opservacije u klaster
# - Takođe, opservacije koje se nalaze u regijama manje koncentracije proglašava outlier-ima

# %%
# DBSCAN

dbscan = DBSCAN()
dbscan.fit(df[numeric])

count = Counter(dbscan.labels_)
number_and_percentige_per_cluster = {}

for value, times in count.most_common():
    number_and_percentige_per_cluster[value] = [times, (times / len(df)) * 100]

number_and_percentige_per_cluster
# Out:
# {1: [11995, 65.88125446256934],
#  -1: [4452, 24.452133794694348],
#  0: [1705, 9.3645301257758],
#  4: [14, 0.07689350249903884],
#  8: [12, 0.06590871642774757],
#  3: [8, 0.043939144285165044],
#  7: [7, 0.03844675124951942],
#  2: [5, 0.027461965178228156],
#  9: [4, 0.021969572142582522],
#  5: [3, 0.01647717910693689],
#  6: [2, 0.010984786071291261]}

# %%
df['cluster_marks'] = dbscan.labels_

df_cluster_minus_1 = df.loc[df['cluster_marks'] == -1]
df_cluster_0 = df.loc[df['cluster_marks'] == 0]
df_cluster_1 = df.loc[df['cluster_marks'] == 1]
df_cluster_2 = df.loc[df['cluster_marks'] == 2]
df_cluster_3 = df.loc[df['cluster_marks'] == 3]
df_cluster_4 = df.loc[df['cluster_marks'] == 4]
df_cluster_5 = df.loc[df['cluster_marks'] == 5]
df_cluster_6 = df.loc[df['cluster_marks'] == 6]
df_cluster_7 = df.loc[df['cluster_marks'] == 7]
df_cluster_8 = df.loc[df['cluster_marks'] == 8]
df_cluster_9 = df.loc[df['cluster_marks'] == 9]
df_cluster_10 = df.loc[df['cluster_marks'] == 10]
df_cluster_11 = df.loc[df['cluster_marks'] == 11]
df_cluster_12 = df.loc[df['cluster_marks'] == 12]
df_cluster_13 = df.loc[df['cluster_marks'] == 13]

show_position_percentige_per_cluster(df_cluster_minus_1, -1, len(df))
show_position_percentige_per_cluster(df_cluster_0, 0, len(df))
show_position_percentige_per_cluster(df_cluster_1, 1, len(df))
show_position_percentige_per_cluster(df_cluster_2, 2, len(df))
show_position_percentige_per_cluster(df_cluster_3, 3, len(df))
show_position_percentige_per_cluster(df_cluster_4, 4, len(df))
show_position_percentige_per_cluster(df_cluster_5, 5, len(df))
show_position_percentige_per_cluster(df_cluster_6, 6, len(df))
show_position_percentige_per_cluster(df_cluster_7, 7, len(df))
show_position_percentige_per_cluster(df_cluster_8, 8, len(df))
show_position_percentige_per_cluster(df_cluster_9, 9, len(df))
show_position_percentige_per_cluster(df_cluster_10, 10, len(df))
show_position_percentige_per_cluster(df_cluster_11, 11, len(df))
show_position_percentige_per_cluster(df_cluster_12, 12, len(df))
show_position_percentige_per_cluster(df_cluster_13, 13, len(df))
# Out:
# Broj igraca u klasteru -1: 4452, (24.452133794694348 %)
#
# NAPAD: 1097 (24.640610961365677 %)
# Broj igraca na poziciji RF: 6, (0.13477088948787064 %)
# Broj igraca na poziciji LF: 6, (0.13477088948787064 %)
# Broj igraca na poziciji RW: 130, (2.9200359389038635 %)
# Broj igraca na poziciji LW: 123, (2.7628032345013476 %)
# Broj igraca na poziciji ST: 662, (14.86972147349506 %)
# Broj igraca na poziciji CF: 25, (0.5615453728661276 %)
# Broj igraca na poziciji RS: 72, (1.6172506738544474 %)
# Broj igraca na poziciji LS: 73, (1.6397124887690926 %)
#
# VEZNI RED: 1661 (37.309074573225516 %)
# Broj igraca na poziciji RDM: 52, (1.1680143755615455 %)
# Broj igraca na poziciji CDM: 199, (4.469901168014376 %)
# Broj igraca na poziciji LDM: 61, (1.3701707097933513 %)
# Broj igraca na poziciji RM: 311, (6.985624438454627 %)
# Broj igraca na poziciji RCM: 82, (1.8418688230008984 %)
# Broj igraca na poziciji CM: 232, (5.211141060197664 %)
# Broj igraca na poziciji LCM: 77, (1.729559748427673 %)
# Broj igraca na poziciji LM: 321, (7.210242587601077 %)
# Broj igraca na poziciji RAM: 15, (0.3369272237196766 %)
# Broj igraca na poziciji CAM: 298, (6.693620844564241 %)
# Broj igraca na poziciji LAM: 13, (0.2920035938903864 %)
#
# ODBRANA: 1386 (31.132075471698112 %)
# Broj igraca na poziciji RWB: 14, (0.3144654088050315 %)
# Broj igraca na poziciji RB: 234, (5.256064690026954 %)
# Broj igraca na poziciji RCB: 211, (4.739442946990117 %)
# Broj igraca na poziciji CB: 458, (10.287511230907457 %)
# Broj igraca na poziciji LCB: 216, (4.8517520215633425 %)
# Broj igraca na poziciji LB: 239, (5.36837376460018 %)
# Broj igraca na poziciji LWB: 14, (0.3144654088050315 %)
#
# GOLMANI: 308 (6.918238993710692 %)
#
# Broj igraca u klasteru 0: 1705, (9.3645301257758 %)
#
# NAPAD: 0 (0.0 %)
# Broj igraca na poziciji RF: 0, (0.0 %)
# Broj igraca na poziciji LF: 0, (0.0 %)
# Broj igraca na poziciji RW: 0, (0.0 %)
# Broj igraca na poziciji LW: 0, (0.0 %)
# Broj igraca na poziciji ST: 0, (0.0 %)
# Broj igraca na poziciji CF: 0, (0.0 %)
# Broj igraca na poziciji RS: 0, (0.0 %)
# Broj igraca na poziciji LS: 0, (0.0 %)
#
# VEZNI RED: 0 (0.0 %)
# Broj igraca na poziciji RDM: 0, (0.0 %)
# Broj igraca na poziciji CDM: 0, (0.0 %)
# Broj igraca na poziciji LDM: 0, (0.0 %)
# Broj igraca na poziciji RM: 0, (0.0 %)
# Broj igraca na poziciji RCM: 0, (0.0 %)
# Broj igraca na poziciji CM: 0, (0.0 %)
# Broj igraca na poziciji LCM: 0, (0.0 %)
# Broj igraca na poziciji LM: 0, (0.0 %)
# Broj igraca na poziciji RAM: 0, (0.0 %)
# Broj igraca na poziciji CAM: 0, (0.0 %)
# Broj igraca na poziciji LAM: 0, (0.0 %)
#
# ODBRANA: 0 (0.0 %)
# Broj igraca na poziciji RWB: 0, (0.0 %)
# Broj igraca na poziciji RB: 0, (0.0 %)
# Broj igraca na poziciji RCB: 0, (0.0 %)
# Broj igraca na poziciji CB: 0, (0.0 %)
# Broj igraca na poziciji LCB: 0, (0.0 %)
# Broj igraca na poziciji LB: 0, (0.0 %)
# Broj igraca na poziciji LWB: 0, (0.0 %)
#
# GOLMANI: 1705 (100.0 %)
#
# Broj igraca u klasteru 1: 11995, (65.88125446256934 %)
#
# NAPAD: 2370 (19.75823259691538 %)
# Broj igraca na poziciji RF: 10, (0.08336807002917883 %)
# Broj igraca na poziciji LF: 9, (0.07503126302626094 %)
# Broj igraca na poziciji RW: 236, (1.9674864526886202 %)
# Broj igraca na poziciji LW: 257, (2.1425593997498957 %)
# Broj igraca na poziciji ST: 1545, (12.88036681950813 %)
# Broj igraca na poziciji CF: 49, (0.40850354314297627 %)
# Broj igraca na poziciji RS: 131, (1.0921217173822426 %)
# Broj igraca na poziciji LS: 133, (1.1087953313880783 %)
#
# VEZNI RED: 5169 (43.09295539808253 %)
# Broj igraca na poziciji RDM: 196, (1.634014172571905 %)
# Broj igraca na poziciji CDM: 749, (6.244268445185494 %)
# Broj igraca na poziciji LDM: 182, (1.5172988745310545 %)
# Broj igraca na poziciji RM: 810, (6.752813672363485 %)
# Broj igraca na poziciji RCM: 309, (2.576073363901626 %)
# Broj igraca na poziciji CM: 1162, (9.68736973739058 %)
# Broj igraca na poziciji LCM: 318, (2.6511046269278866 %)
# Broj igraca na poziciji LM: 771, (6.427678199249687 %)
# Broj igraca na poziciji RAM: 6, (0.0500208420175073 %)
# Broj igraca na poziciji CAM: 658, (5.485619007919967 %)
# Broj igraca na poziciji LAM: 8, (0.06669445602334305 %)
#
# ODBRANA: 4456 (37.148812005002085 %)
# Broj igraca na poziciji RWB: 73, (0.6085869112130055 %)
# Broj igraca na poziciji RB: 1057, (8.812005002084202 %)
# Broj igraca na poziciji RCB: 447, (3.726552730304294 %)
# Broj igraca na poziciji CB: 1307, (10.896206752813672 %)
# Broj igraca na poziciji LCB: 425, (3.5431429762401003 %)
# Broj igraca na poziciji LB: 1083, (9.028761984160067 %)
# Broj igraca na poziciji LWB: 64, (0.5335556481867444 %)
#
# GOLMANI: 0 (0.0 %)
#
# Broj igraca u klasteru 2: 5, (0.027461965178228156 %)
#
# NAPAD: 2 (40.0 %)
# Broj igraca na poziciji RF: 0, (0.0 %)
# Broj igraca na poziciji LF: 0, (0.0 %)
# Broj igraca na poziciji RW: 0, (0.0 %)
# Broj igraca na poziciji LW: 0, (0.0 %)
# Broj igraca na poziciji ST: 1, (20.0 %)
# Broj igraca na poziciji CF: 0, (0.0 %)
# Broj igraca na poziciji RS: 0, (0.0 %)
# Broj igraca na poziciji LS: 1, (20.0 %)
#
# VEZNI RED: 3 (60.0 %)
# Broj igraca na poziciji RDM: 0, (0.0 %)
# Broj igraca na poziciji CDM: 0, (0.0 %)
# Broj igraca na poziciji LDM: 0, (0.0 %)
# Broj igraca na poziciji RM: 1, (20.0 %)
# Broj igraca na poziciji RCM: 0, (0.0 %)
# Broj igraca na poziciji CM: 0, (0.0 %)
# Broj igraca na poziciji LCM: 0, (0.0 %)
# Broj igraca na poziciji LM: 2, (40.0 %)
# Broj igraca na poziciji RAM: 0, (0.0 %)
# Broj igraca na poziciji CAM: 0, (0.0 %)
# Broj igraca na poziciji LAM: 0, (0.0 %)
#
# ODBRANA: 0 (0.0 %)
# Broj igraca na poziciji RWB: 0, (0.0 %)
# Broj igraca na poziciji RB: 0, (0.0 %)
# Broj igraca na poziciji RCB: 0, (0.0 %)
# Broj igraca na poziciji CB: 0, (0.0 %)
# Broj igraca na poziciji LCB: 0, (0.0 %)
# Broj igraca na poziciji LB: 0, (0.0 %)
# Broj igraca na poziciji LWB: 0, (0.0 %)
#
# GOLMANI: 0 (0.0 %)
#
# Broj igraca u klasteru 3: 8, (0.043939144285165044 %)
#
# NAPAD: 0 (0.0 %)
# Broj igraca na poziciji RF: 0, (0.0 %)
# Broj igraca na poziciji LF: 0, (0.0 %)
# Broj igraca na poziciji RW: 0, (0.0 %)
# Broj igraca na poziciji LW: 0, (0.0 %)
# Broj igraca na poziciji ST: 0, (0.0 %)
# Broj igraca na poziciji CF: 0, (0.0 %)
# Broj igraca na poziciji RS: 0, (0.0 %)
# Broj igraca na poziciji LS: 0, (0.0 %)
#
# VEZNI RED: 0 (0.0 %)
# Broj igraca na poziciji RDM: 0, (0.0 %)
# Broj igraca na poziciji CDM: 0, (0.0 %)
# Broj igraca na poziciji LDM: 0, (0.0 %)
# Broj igraca na poziciji RM: 0, (0.0 %)
# Broj igraca na poziciji RCM: 0, (0.0 %)
# Broj igraca na poziciji CM: 0, (0.0 %)
# Broj igraca na poziciji LCM: 0, (0.0 %)
# Broj igraca na poziciji LM: 0, (0.0 %)
# Broj igraca na poziciji RAM: 0, (0.0 %)
# Broj igraca na poziciji CAM: 0, (0.0 %)
# Broj igraca na poziciji LAM: 0, (0.0 %)
#
# ODBRANA: 8 (100.0 %)
# Broj igraca na poziciji RWB: 0, (0.0 %)
# Broj igraca na poziciji RB: 0, (0.0 %)
# Broj igraca na poziciji RCB: 1, (12.5 %)
# Broj igraca na poziciji CB: 6, (75.0 %)
# Broj igraca na poziciji LCB: 1, (12.5 %)
# Broj igraca na poziciji LB: 0, (0.0 %)
# Broj igraca na poziciji LWB: 0, (0.0 %)
#
# GOLMANI: 0 (0.0 %)
#
# Broj igraca u klasteru 4: 14, (0.07689350249903884 %)
#
# NAPAD: 0 (0.0 %)
# Broj igraca na poziciji RF: 0, (0.0 %)
# Broj igraca na poziciji LF: 0, (0.0 %)
# Broj igraca na poziciji RW: 0, (0.0 %)
# Broj igraca na poziciji LW: 0, (0.0 %)
# Broj igraca na poziciji ST: 0, (0.0 %)
# Broj igraca na poziciji CF: 0, (0.0 %)
# Broj igraca na poziciji RS: 0, (0.0 %)
# Broj igraca na poziciji LS: 0, (0.0 %)
#
# VEZNI RED: 0 (0.0 %)
# Broj igraca na poziciji RDM: 0, (0.0 %)
# Broj igraca na poziciji CDM: 0, (0.0 %)
# Broj igraca na poziciji LDM: 0, (0.0 %)
# Broj igraca na poziciji RM: 0, (0.0 %)
# Broj igraca na poziciji RCM: 0, (0.0 %)
# Broj igraca na poziciji CM: 0, (0.0 %)
# Broj igraca na poziciji LCM: 0, (0.0 %)
# Broj igraca na poziciji LM: 0, (0.0 %)
# Broj igraca na poziciji RAM: 0, (0.0 %)
# Broj igraca na poziciji CAM: 0, (0.0 %)
# Broj igraca na poziciji LAM: 0, (0.0 %)
#
# ODBRANA: 14 (100.0 %)
# Broj igraca na poziciji RWB: 0, (0.0 %)
# Broj igraca na poziciji RB: 0, (0.0 %)
# Broj igraca na poziciji RCB: 2, (14.285714285714285 %)
# Broj igraca na poziciji CB: 7, (50.0 %)
# Broj igraca na poziciji LCB: 5, (35.714285714285715 %)
# Broj igraca na poziciji LB: 0, (0.0 %)
# Broj igraca na poziciji LWB: 0, (0.0 %)
#
# GOLMANI: 0 (0.0 %)
#
# Broj igraca u klasteru 5: 3, (0.01647717910693689 %)
#
# NAPAD: 1 (33.33333333333333 %)
# Broj igraca na poziciji RF: 0, (0.0 %)
# Broj igraca na poziciji LF: 0, (0.0 %)
# Broj igraca na poziciji RW: 1, (33.33333333333333 %)
# Broj igraca na poziciji LW: 0, (0.0 %)
# Broj igraca na poziciji ST: 0, (0.0 %)
# Broj igraca na poziciji CF: 0, (0.0 %)
# Broj igraca na poziciji RS: 0, (0.0 %)
# Broj igraca na poziciji LS: 0, (0.0 %)
#
# VEZNI RED: 2 (66.66666666666666 %)
# Broj igraca na poziciji RDM: 0, (0.0 %)
# Broj igraca na poziciji CDM: 0, (0.0 %)
# Broj igraca na poziciji LDM: 0, (0.0 %)
# Broj igraca na poziciji RM: 0, (0.0 %)
# Broj igraca na poziciji RCM: 0, (0.0 %)
# Broj igraca na poziciji CM: 0, (0.0 %)
# Broj igraca na poziciji LCM: 0, (0.0 %)
# Broj igraca na poziciji LM: 0, (0.0 %)
# Broj igraca na poziciji RAM: 0, (0.0 %)
# Broj igraca na poziciji CAM: 2, (66.66666666666666 %)
# Broj igraca na poziciji LAM: 0, (0.0 %)
#
# ODBRANA: 0 (0.0 %)
# Broj igraca na poziciji RWB: 0, (0.0 %)
# Broj igraca na poziciji RB: 0, (0.0 %)
# Broj igraca na poziciji RCB: 0, (0.0 %)
# Broj igraca na poziciji CB: 0, (0.0 %)
# Broj igraca na poziciji LCB: 0, (0.0 %)
# Broj igraca na poziciji LB: 0, (0.0 %)
# Broj igraca na poziciji LWB: 0, (0.0 %)
#
# GOLMANI: 0 (0.0 %)
#
# Broj igraca u klasteru 6: 2, (0.010984786071291261 %)
#
# NAPAD: 0 (0.0 %)
# Broj igraca na poziciji RF: 0, (0.0 %)
# Broj igraca na poziciji LF: 0, (0.0 %)
# Broj igraca na poziciji RW: 0, (0.0 %)
# Broj igraca na poziciji LW: 0, (0.0 %)
# Broj igraca na poziciji ST: 0, (0.0 %)
# Broj igraca na poziciji CF: 0, (0.0 %)
# Broj igraca na poziciji RS: 0, (0.0 %)
# Broj igraca na poziciji LS: 0, (0.0 %)
#
# VEZNI RED: 0 (0.0 %)
# Broj igraca na poziciji RDM: 0, (0.0 %)
# Broj igraca na poziciji CDM: 0, (0.0 %)
# Broj igraca na poziciji LDM: 0, (0.0 %)
# Broj igraca na poziciji RM: 0, (0.0 %)
# Broj igraca na poziciji RCM: 0, (0.0 %)
# Broj igraca na poziciji CM: 0, (0.0 %)
# Broj igraca na poziciji LCM: 0, (0.0 %)
# Broj igraca na poziciji LM: 0, (0.0 %)
# Broj igraca na poziciji RAM: 0, (0.0 %)
# Broj igraca na poziciji CAM: 0, (0.0 %)
# Broj igraca na poziciji LAM: 0, (0.0 %)
#
# ODBRANA: 2 (100.0 %)
# Broj igraca na poziciji RWB: 0, (0.0 %)
# Broj igraca na poziciji RB: 0, (0.0 %)
# Broj igraca na poziciji RCB: 1, (50.0 %)
# Broj igraca na poziciji CB: 0, (0.0 %)
# Broj igraca na poziciji LCB: 1, (50.0 %)
# Broj igraca na poziciji LB: 0, (0.0 %)
# Broj igraca na poziciji LWB: 0, (0.0 %)
#
# GOLMANI: 0 (0.0 %)
#
# Broj igraca u klasteru 7: 7, (0.03844675124951942 %)
#
# NAPAD: 4 (57.14285714285714 %)
# Broj igraca na poziciji RF: 0, (0.0 %)
# Broj igraca na poziciji LF: 0, (0.0 %)
# Broj igraca na poziciji RW: 3, (42.857142857142854 %)
# Broj igraca na poziciji LW: 1, (14.285714285714285 %)
# Broj igraca na poziciji ST: 0, (0.0 %)
# Broj igraca na poziciji CF: 0, (0.0 %)
# Broj igraca na poziciji RS: 0, (0.0 %)
# Broj igraca na poziciji LS: 0, (0.0 %)
#
# VEZNI RED: 3 (42.857142857142854 %)
# Broj igraca na poziciji RDM: 0, (0.0 %)
# Broj igraca na poziciji CDM: 0, (0.0 %)
# Broj igraca na poziciji LDM: 0, (0.0 %)
# Broj igraca na poziciji RM: 2, (28.57142857142857 %)
# Broj igraca na poziciji RCM: 0, (0.0 %)
# Broj igraca na poziciji CM: 0, (0.0 %)
# Broj igraca na poziciji LCM: 0, (0.0 %)
# Broj igraca na poziciji LM: 1, (14.285714285714285 %)
# Broj igraca na poziciji RAM: 0, (0.0 %)
# Broj igraca na poziciji CAM: 0, (0.0 %)
# Broj igraca na poziciji LAM: 0, (0.0 %)
#
# ODBRANA: 0 (0.0 %)
# Broj igraca na poziciji RWB: 0, (0.0 %)
# Broj igraca na poziciji RB: 0, (0.0 %)
# Broj igraca na poziciji RCB: 0, (0.0 %)
# Broj igraca na poziciji CB: 0, (0.0 %)
# Broj igraca na poziciji LCB: 0, (0.0 %)
# Broj igraca na poziciji LB: 0, (0.0 %)
# Broj igraca na poziciji LWB: 0, (0.0 %)
#
# GOLMANI: 0 (0.0 %)
#
# Broj igraca u klasteru 8: 12, (0.06590871642774757 %)
#
# NAPAD: 0 (0.0 %)
# Broj igraca na poziciji RF: 0, (0.0 %)
# Broj igraca na poziciji LF: 0, (0.0 %)
# Broj igraca na poziciji RW: 0, (0.0 %)
# Broj igraca na poziciji LW: 0, (0.0 %)
# Broj igraca na poziciji ST: 0, (0.0 %)
# Broj igraca na poziciji CF: 0, (0.0 %)
# Broj igraca na poziciji RS: 0, (0.0 %)
# Broj igraca na poziciji LS: 0, (0.0 %)
#
# VEZNI RED: 0 (0.0 %)
# Broj igraca na poziciji RDM: 0, (0.0 %)
# Broj igraca na poziciji CDM: 0, (0.0 %)
# Broj igraca na poziciji LDM: 0, (0.0 %)
# Broj igraca na poziciji RM: 0, (0.0 %)
# Broj igraca na poziciji RCM: 0, (0.0 %)
# Broj igraca na poziciji CM: 0, (0.0 %)
# Broj igraca na poziciji LCM: 0, (0.0 %)
# Broj igraca na poziciji LM: 0, (0.0 %)
# Broj igraca na poziciji RAM: 0, (0.0 %)
# Broj igraca na poziciji CAM: 0, (0.0 %)
# Broj igraca na poziciji LAM: 0, (0.0 %)
#
# ODBRANA: 0 (0.0 %)
# Broj igraca na poziciji RWB: 0, (0.0 %)
# Broj igraca na poziciji RB: 0, (0.0 %)
# Broj igraca na poziciji RCB: 0, (0.0 %)
# Broj igraca na poziciji CB: 0, (0.0 %)
# Broj igraca na poziciji LCB: 0, (0.0 %)
# Broj igraca na poziciji LB: 0, (0.0 %)
# Broj igraca na poziciji LWB: 0, (0.0 %)
#
# GOLMANI: 12 (100.0 %)
#
# Broj igraca u klasteru 9: 4, (0.021969572142582522 %)
#
# NAPAD: 4 (100.0 %)
# Broj igraca na poziciji RF: 0, (0.0 %)
# Broj igraca na poziciji LF: 0, (0.0 %)
# Broj igraca na poziciji RW: 0, (0.0 %)
# Broj igraca na poziciji LW: 0, (0.0 %)
# Broj igraca na poziciji ST: 4, (100.0 %)
# Broj igraca na poziciji CF: 0, (0.0 %)
# Broj igraca na poziciji RS: 0, (0.0 %)
# Broj igraca na poziciji LS: 0, (0.0 %)
#
# VEZNI RED: 0 (0.0 %)
# Broj igraca na poziciji RDM: 0, (0.0 %)
# Broj igraca na poziciji CDM: 0, (0.0 %)
# Broj igraca na poziciji LDM: 0, (0.0 %)
# Broj igraca na poziciji RM: 0, (0.0 %)
# Broj igraca na poziciji RCM: 0, (0.0 %)
# Broj igraca na poziciji CM: 0, (0.0 %)
# Broj igraca na poziciji LCM: 0, (0.0 %)
# Broj igraca na poziciji LM: 0, (0.0 %)
# Broj igraca na poziciji RAM: 0, (0.0 %)
# Broj igraca na poziciji CAM: 0, (0.0 %)
# Broj igraca na poziciji LAM: 0, (0.0 %)
#
# ODBRANA: 0 (0.0 %)
# Broj igraca na poziciji RWB: 0, (0.0 %)
# Broj igraca na poziciji RB: 0, (0.0 %)
# Broj igraca na poziciji RCB: 0, (0.0 %)
# Broj igraca na poziciji CB: 0, (0.0 %)
# Broj igraca na poziciji LCB: 0, (0.0 %)
# Broj igraca na poziciji LB: 0, (0.0 %)
# Broj igraca na poziciji LWB: 0, (0.0 %)
#
# GOLMANI: 0 (0.0 %)
#
# Broj igraca u klasteru 10: 0, (0.0 %)
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-53-dba099242275> in <module>
#      28 show_position_percentige_per_cluster(df_cluster_8, 8, len(df))
#      29 show_position_percentige_per_cluster(df_cluster_9, 9, len(df))
# ---> 30 show_position_percentige_per_cluster(df_cluster_10, 10, len(df))
#      31 show_position_percentige_per_cluster(df_cluster_11, 11, len(df))
#      32 show_position_percentige_per_cluster(df_cluster_12, 12, len(df))
#
# <ipython-input-19-c589522eeaa5> in show_position_percentige_per_cluster(df, cluster_number, original_dataset_length)
#      12
#      13     df_num_of_attackers = len(df.loc[(df['Position'] == 'RF') | (df['Position'] == 'LF') | (df['Position'] == 'RW') | (df['Position'] == 'LW') | (df['Position'] == 'ST') | (df['Position'] =='CF') |  (df['Position'] == 'RS') | (df['Position'] == 'LS')])
# ---> 14     df_num_of_attackers_percentige = (df_num_of_attackers / number_of_players_in_cluster) * 100
#      15
#      16     print(f'NAPAD: {df_num_of_attackers} ({df_num_of_attackers_percentige} %)')
#
# ZeroDivisionError: division by zero

# %%
df1 = df.replace({'RF': 'ATT', 'LF': 'ATT', 'RW': 'ATT', 'LW': 'ATT', 'ST': 'ATT', 'CF': 'ATT', 'RS': 'ATT', 'LS': 'ATT',
            'RDM': 'MF', 'CDM': 'MF', 'LDM': 'MF', 'RM': 'MF', 'RCM': 'MF', 'CM': 'MF', 'LCM': 'MF', 'LM': 'MF', 'RAM': 'MF', 'CAM': 'MF', 'LAM': 'MF',
            'RWB': 'DF', 'RB': 'DF', 'RCB': 'DF', 'CB': 'DF', 'LCB': 'DF', 'LB': 'DF', 'LWB': 'DF'})

df1['Position'].unique()
# Out:
# array(['ATT', 'GK', 'MF', 'DF'], dtype=object)

# %%
plt.figure(num=None, figsize=(8, 6), dpi=200)
sns.countplot(x='cluster_marks', hue='Position', data=df1)
# Out:
# <AxesSubplot:xlabel='cluster_marks', ylabel='count'>

# %%
dbscan = DBSCAN(min_samples=6)
dbscan.fit(df[numeric])

count = Counter(dbscan.labels_)
number_and_percentige_per_cluster = {}

for value, times in count.most_common():
    number_and_percentige_per_cluster[value] = [times, (times / len(df)) * 100]
    
number_and_percentige_per_cluster
# Out:
# {2: [11883, 65.26610644257703],
#  -1: [4592, 25.22106881968474],
#  0: [1689, 9.27665183720547],
#  7: [11, 0.06041632339210194],
#  3: [10, 0.05492393035645631],
#  1: [8, 0.043939144285165044],
#  5: [7, 0.03844675124951942],
#  4: [4, 0.021969572142582522],
#  6: [3, 0.01647717910693689]}

# %%
df['cluster_marks'] = dbscan.labels_

df_cluster_minus_1 = df.loc[df['cluster_marks'] == -1]
df_cluster_0 = df.loc[df['cluster_marks'] == 0]
df_cluster_1 = df.loc[df['cluster_marks'] == 1]
df_cluster_2 = df.loc[df['cluster_marks'] == 2]
df_cluster_3 = df.loc[df['cluster_marks'] == 3]
df_cluster_4 = df.loc[df['cluster_marks'] == 4]
df_cluster_5 = df.loc[df['cluster_marks'] == 5]

show_position_percentige_per_cluster(df_cluster_minus_1, -1, len(df))
show_position_percentige_per_cluster(df_cluster_0, 0, len(df))
show_position_percentige_per_cluster(df_cluster_1, 1, len(df))
show_position_percentige_per_cluster(df_cluster_2, 2, len(df))
show_position_percentige_per_cluster(df_cluster_3, 3, len(df))
show_position_percentige_per_cluster(df_cluster_4, 4, len(df))
show_position_percentige_per_cluster(df_cluster_5, 5, len(df))
# Out:
# Broj igraca u klasteru -1: 4592, (25.22106881968474 %)
#
# NAPAD: 1134 (24.695121951219512 %)
# Broj igraca na poziciji RF: 6, (0.13066202090592335 %)
# Broj igraca na poziciji LF: 6, (0.13066202090592335 %)
# Broj igraca na poziciji RW: 132, (2.8745644599303137 %)
# Broj igraca na poziciji LW: 128, (2.7874564459930316 %)
# Broj igraca na poziciji ST: 682, (14.85191637630662 %)
# Broj igraca na poziciji CF: 26, (0.5662020905923345 %)
# Broj igraca na poziciji RS: 77, (1.676829268292683 %)
# Broj igraca na poziciji LS: 77, (1.676829268292683 %)
#
# VEZNI RED: 1706 (37.15156794425087 %)
# Broj igraca na poziciji RDM: 53, (1.1541811846689896 %)
# Broj igraca na poziciji CDM: 202, (4.398954703832753 %)
# Broj igraca na poziciji LDM: 62, (1.3501742160278747 %)
# Broj igraca na poziciji RM: 320, (6.968641114982578 %)
# Broj igraca na poziciji RCM: 85, (1.8510452961672474 %)
# Broj igraca na poziciji CM: 236, (5.139372822299651 %)
# Broj igraca na poziciji LCM: 79, (1.7203832752613242 %)
# Broj igraca na poziciji LM: 331, (7.208188153310105 %)
# Broj igraca na poziciji RAM: 15, (0.32665505226480834 %)
# Broj igraca na poziciji CAM: 310, (6.7508710801393725 %)
# Broj igraca na poziciji LAM: 13, (0.28310104529616725 %)
#
# ODBRANA: 1431 (31.162891986062718 %)
# Broj igraca na poziciji RWB: 15, (0.32665505226480834 %)
# Broj igraca na poziciji RB: 238, (5.182926829268292 %)
# Broj igraca na poziciji RCB: 220, (4.790940766550523 %)
# Broj igraca na poziciji CB: 474, (10.322299651567944 %)
# Broj igraca na poziciji LCB: 222, (4.834494773519164 %)
# Broj igraca na poziciji LB: 246, (5.357142857142857 %)
# Broj igraca na poziciji LWB: 16, (0.34843205574912894 %)
#
# GOLMANI: 321 (6.9904181184668985 %)
#
# Broj igraca u klasteru 0: 1689, (9.27665183720547 %)
#
# NAPAD: 0 (0.0 %)
# Broj igraca na poziciji RF: 0, (0.0 %)
# Broj igraca na poziciji LF: 0, (0.0 %)
# Broj igraca na poziciji RW: 0, (0.0 %)
# Broj igraca na poziciji LW: 0, (0.0 %)
# Broj igraca na poziciji ST: 0, (0.0 %)
# Broj igraca na poziciji CF: 0, (0.0 %)
# Broj igraca na poziciji RS: 0, (0.0 %)
# Broj igraca na poziciji LS: 0, (0.0 %)
#
# VEZNI RED: 0 (0.0 %)
# Broj igraca na poziciji RDM: 0, (0.0 %)
# Broj igraca na poziciji CDM: 0, (0.0 %)
# Broj igraca na poziciji LDM: 0, (0.0 %)
# Broj igraca na poziciji RM: 0, (0.0 %)
# Broj igraca na poziciji RCM: 0, (0.0 %)
# Broj igraca na poziciji CM: 0, (0.0 %)
# Broj igraca na poziciji LCM: 0, (0.0 %)
# Broj igraca na poziciji LM: 0, (0.0 %)
# Broj igraca na poziciji RAM: 0, (0.0 %)
# Broj igraca na poziciji CAM: 0, (0.0 %)
# Broj igraca na poziciji LAM: 0, (0.0 %)
#
# ODBRANA: 0 (0.0 %)
# Broj igraca na poziciji RWB: 0, (0.0 %)
# Broj igraca na poziciji RB: 0, (0.0 %)
# Broj igraca na poziciji RCB: 0, (0.0 %)
# Broj igraca na poziciji CB: 0, (0.0 %)
# Broj igraca na poziciji LCB: 0, (0.0 %)
# Broj igraca na poziciji LB: 0, (0.0 %)
# Broj igraca na poziciji LWB: 0, (0.0 %)
#
# GOLMANI: 1689 (100.0 %)
#
# Broj igraca u klasteru 1: 8, (0.043939144285165044 %)
#
# NAPAD: 0 (0.0 %)
# Broj igraca na poziciji RF: 0, (0.0 %)
# Broj igraca na poziciji LF: 0, (0.0 %)
# Broj igraca na poziciji RW: 0, (0.0 %)
# Broj igraca na poziciji LW: 0, (0.0 %)
# Broj igraca na poziciji ST: 0, (0.0 %)
# Broj igraca na poziciji CF: 0, (0.0 %)
# Broj igraca na poziciji RS: 0, (0.0 %)
# Broj igraca na poziciji LS: 0, (0.0 %)
#
# VEZNI RED: 0 (0.0 %)
# Broj igraca na poziciji RDM: 0, (0.0 %)
# Broj igraca na poziciji CDM: 0, (0.0 %)
# Broj igraca na poziciji LDM: 0, (0.0 %)
# Broj igraca na poziciji RM: 0, (0.0 %)
# Broj igraca na poziciji RCM: 0, (0.0 %)
# Broj igraca na poziciji CM: 0, (0.0 %)
# Broj igraca na poziciji LCM: 0, (0.0 %)
# Broj igraca na poziciji LM: 0, (0.0 %)
# Broj igraca na poziciji RAM: 0, (0.0 %)
# Broj igraca na poziciji CAM: 0, (0.0 %)
# Broj igraca na poziciji LAM: 0, (0.0 %)
#
# ODBRANA: 8 (100.0 %)
# Broj igraca na poziciji RWB: 0, (0.0 %)
# Broj igraca na poziciji RB: 0, (0.0 %)
# Broj igraca na poziciji RCB: 1, (12.5 %)
# Broj igraca na poziciji CB: 6, (75.0 %)
# Broj igraca na poziciji LCB: 1, (12.5 %)
# Broj igraca na poziciji LB: 0, (0.0 %)
# Broj igraca na poziciji LWB: 0, (0.0 %)
#
# GOLMANI: 0 (0.0 %)
#
# Broj igraca u klasteru 2: 11883, (65.26610644257703 %)
#
# NAPAD: 2340 (19.691996970462007 %)
# Broj igraca na poziciji RF: 10, (0.08415383320710258 %)
# Broj igraca na poziciji LF: 9, (0.07573844988639232 %)
# Broj igraca na poziciji RW: 235, (1.9776150803669106 %)
# Broj igraca na poziciji LW: 252, (2.120676596818985 %)
# Broj igraca na poziciji ST: 1530, (12.875536480686694 %)
# Broj igraca na poziciji CF: 48, (0.40393839939409243 %)
# Broj igraca na poziciji RS: 126, (1.0603382984094925 %)
# Broj igraca na poziciji LS: 130, (1.0939998316923336 %)
#
# VEZNI RED: 5129 (43.162501051922916 %)
# Broj igraca na poziciji RDM: 195, (1.6409997475385005 %)
# Broj igraca na poziciji CDM: 746, (6.277875957249853 %)
# Broj igraca na poziciji LDM: 181, (1.5231843810485568 %)
# Broj igraca na poziciji RM: 802, (6.749137423209627 %)
# Broj igraca na poziciji RCM: 306, (2.575107296137339 %)
# Broj igraca na poziciji CM: 1158, (9.745013885382479 %)
# Broj igraca na poziciji LCM: 316, (2.6592611293444417 %)
# Broj igraca na poziciji LM: 763, (6.420937473701926 %)
# Broj igraca na poziciji RAM: 6, (0.050492299924261554 %)
# Broj igraca na poziciji CAM: 648, (5.453168391820248 %)
# Broj igraca na poziciji LAM: 8, (0.06732306656568207 %)
#
# ODBRANA: 4414 (37.14550197761508 %)
# Broj igraca na poziciji RWB: 72, (0.6059075990911386 %)
# Broj igraca na poziciji RB: 1051, (8.844567870066482 %)
# Broj igraca na poziciji RCB: 440, (3.7027686611125135 %)
# Broj igraca na poziciji CB: 1292, (10.872675250357654 %)
# Broj igraca na poziciji LCB: 422, (3.551291761339729 %)
# Broj igraca na poziciji LB: 1075, (9.046537069763527 %)
# Broj igraca na poziciji LWB: 62, (0.521753765884036 %)
#
# GOLMANI: 0 (0.0 %)
#
# Broj igraca u klasteru 3: 10, (0.05492393035645631 %)
#
# NAPAD: 0 (0.0 %)
# Broj igraca na poziciji RF: 0, (0.0 %)
# Broj igraca na poziciji LF: 0, (0.0 %)
# Broj igraca na poziciji RW: 0, (0.0 %)
# Broj igraca na poziciji LW: 0, (0.0 %)
# Broj igraca na poziciji ST: 0, (0.0 %)
# Broj igraca na poziciji CF: 0, (0.0 %)
# Broj igraca na poziciji RS: 0, (0.0 %)
# Broj igraca na poziciji LS: 0, (0.0 %)
#
# VEZNI RED: 0 (0.0 %)
# Broj igraca na poziciji RDM: 0, (0.0 %)
# Broj igraca na poziciji CDM: 0, (0.0 %)
# Broj igraca na poziciji LDM: 0, (0.0 %)
# Broj igraca na poziciji RM: 0, (0.0 %)
# Broj igraca na poziciji RCM: 0, (0.0 %)
# Broj igraca na poziciji CM: 0, (0.0 %)
# Broj igraca na poziciji LCM: 0, (0.0 %)
# Broj igraca na poziciji LM: 0, (0.0 %)
# Broj igraca na poziciji RAM: 0, (0.0 %)
# Broj igraca na poziciji CAM: 0, (0.0 %)
# Broj igraca na poziciji LAM: 0, (0.0 %)
#
# ODBRANA: 10 (100.0 %)
# Broj igraca na poziciji RWB: 0, (0.0 %)
# Broj igraca na poziciji RB: 0, (0.0 %)
# Broj igraca na poziciji RCB: 1, (10.0 %)
# Broj igraca na poziciji CB: 6, (60.0 %)
# Broj igraca na poziciji LCB: 3, (30.0 %)
# Broj igraca na poziciji LB: 0, (0.0 %)
# Broj igraca na poziciji LWB: 0, (0.0 %)
#
# GOLMANI: 0 (0.0 %)
#
# Broj igraca u klasteru 4: 4, (0.021969572142582522 %)
#
# NAPAD: 0 (0.0 %)
# Broj igraca na poziciji RF: 0, (0.0 %)
# Broj igraca na poziciji LF: 0, (0.0 %)
# Broj igraca na poziciji RW: 0, (0.0 %)
# Broj igraca na poziciji LW: 0, (0.0 %)
# Broj igraca na poziciji ST: 0, (0.0 %)
# Broj igraca na poziciji CF: 0, (0.0 %)
# Broj igraca na poziciji RS: 0, (0.0 %)
# Broj igraca na poziciji LS: 0, (0.0 %)
#
# VEZNI RED: 0 (0.0 %)
# Broj igraca na poziciji RDM: 0, (0.0 %)
# Broj igraca na poziciji CDM: 0, (0.0 %)
# Broj igraca na poziciji LDM: 0, (0.0 %)
# Broj igraca na poziciji RM: 0, (0.0 %)
# Broj igraca na poziciji RCM: 0, (0.0 %)
# Broj igraca na poziciji CM: 0, (0.0 %)
# Broj igraca na poziciji LCM: 0, (0.0 %)
# Broj igraca na poziciji LM: 0, (0.0 %)
# Broj igraca na poziciji RAM: 0, (0.0 %)
# Broj igraca na poziciji CAM: 0, (0.0 %)
# Broj igraca na poziciji LAM: 0, (0.0 %)
#
# ODBRANA: 0 (0.0 %)
# Broj igraca na poziciji RWB: 0, (0.0 %)
# Broj igraca na poziciji RB: 0, (0.0 %)
# Broj igraca na poziciji RCB: 0, (0.0 %)
# Broj igraca na poziciji CB: 0, (0.0 %)
# Broj igraca na poziciji LCB: 0, (0.0 %)
# Broj igraca na poziciji LB: 0, (0.0 %)
# Broj igraca na poziciji LWB: 0, (0.0 %)
#
# GOLMANI: 4 (100.0 %)
#
# Broj igraca u klasteru 5: 7, (0.03844675124951942 %)
#
# NAPAD: 4 (57.14285714285714 %)
# Broj igraca na poziciji RF: 0, (0.0 %)
# Broj igraca na poziciji LF: 0, (0.0 %)
# Broj igraca na poziciji RW: 3, (42.857142857142854 %)
# Broj igraca na poziciji LW: 1, (14.285714285714285 %)
# Broj igraca na poziciji ST: 0, (0.0 %)
# Broj igraca na poziciji CF: 0, (0.0 %)
# Broj igraca na poziciji RS: 0, (0.0 %)
# Broj igraca na poziciji LS: 0, (0.0 %)
#
# VEZNI RED: 3 (42.857142857142854 %)
# Broj igraca na poziciji RDM: 0, (0.0 %)
# Broj igraca na poziciji CDM: 0, (0.0 %)
# Broj igraca na poziciji LDM: 0, (0.0 %)
# Broj igraca na poziciji RM: 2, (28.57142857142857 %)
# Broj igraca na poziciji RCM: 0, (0.0 %)
# Broj igraca na poziciji CM: 0, (0.0 %)
# Broj igraca na poziciji LCM: 0, (0.0 %)
# Broj igraca na poziciji LM: 1, (14.285714285714285 %)
# Broj igraca na poziciji RAM: 0, (0.0 %)
# Broj igraca na poziciji CAM: 0, (0.0 %)
# Broj igraca na poziciji LAM: 0, (0.0 %)
#
# ODBRANA: 0 (0.0 %)
# Broj igraca na poziciji RWB: 0, (0.0 %)
# Broj igraca na poziciji RB: 0, (0.0 %)
# Broj igraca na poziciji RCB: 0, (0.0 %)
# Broj igraca na poziciji CB: 0, (0.0 %)
# Broj igraca na poziciji LCB: 0, (0.0 %)
# Broj igraca na poziciji LB: 0, (0.0 %)
# Broj igraca na poziciji LWB: 0, (0.0 %)
#
# GOLMANI: 0 (0.0 %)

# %%
df1 = df.replace({'RF': 'ATT', 'LF': 'ATT', 'RW': 'ATT', 'LW': 'ATT', 'ST': 'ATT', 'CF': 'ATT', 'RS': 'ATT', 'LS': 'ATT',
            'RDM': 'MF', 'CDM': 'MF', 'LDM': 'MF', 'RM': 'MF', 'RCM': 'MF', 'CM': 'MF', 'LCM': 'MF', 'LM': 'MF', 'RAM': 'MF', 'CAM': 'MF', 'LAM': 'MF',
            'RWB': 'DF', 'RB': 'DF', 'RCB': 'DF', 'CB': 'DF', 'LCB': 'DF', 'LB': 'DF', 'LWB': 'DF'})

df1['Position'].unique()
# Out:
# array(['ATT', 'GK', 'MF', 'DF'], dtype=object)

# %%
plt.figure(num=None, figsize=(8, 6), dpi=200)
sns.countplot(x='cluster_marks', hue='Position', data=df1)
# Out:
# <AxesSubplot:xlabel='cluster_marks', ylabel='count'>

# %%
dbscan = DBSCAN(min_samples=7)
dbscan.fit(df[numeric])
dbscan.labels_

count = Counter(dbscan.labels_)
number_and_percentige_per_cluster = {}

for value, times in count.most_common():
    number_and_percentige_per_cluster[value] = [times, (times / len(df)) * 100]
    
number_and_percentige_per_cluster
# Out:
# {1: [11771, 64.65095842258472],
#  -1: [4737, 26.017465809853352],
#  0: [1678, 9.216235513813368],
#  2: [7, 0.03844675124951942],
#  3: [7, 0.03844675124951942],
#  4: [7, 0.03844675124951942]}

# %%
df['cluster_marks'] = dbscan.labels_

df_cluster_minus_1 = df.loc[df['cluster_marks'] == -1]
df_cluster_0 = df.loc[df['cluster_marks'] == 0]
df_cluster_1 = df.loc[df['cluster_marks'] == 1]
df_cluster_2 = df.loc[df['cluster_marks'] == 2]
df_cluster_3 = df.loc[df['cluster_marks'] == 3]

show_position_percentige_per_cluster(df_cluster_minus_1, -1, len(df))
show_position_percentige_per_cluster(df_cluster_0, 0, len(df))
show_position_percentige_per_cluster(df_cluster_1, 1, len(df))
show_position_percentige_per_cluster(df_cluster_2, 2, len(df))
show_position_percentige_per_cluster(df_cluster_3, 3, len(df))
# Out:
# Broj igraca u klasteru -1: 4737, (26.017465809853352 %)
#
# NAPAD: 1173 (24.762507916402786 %)
# Broj igraca na poziciji RF: 7, (0.1477728520160439 %)
# Broj igraca na poziciji LF: 6, (0.1266624445851805 %)
# Broj igraca na poziciji RW: 136, (2.8710154105974244 %)
# Broj igraca na poziciji LW: 133, (2.8076841883048345 %)
# Broj igraca na poziciji ST: 705, (14.88283723875871 %)
# Broj igraca na poziciji CF: 27, (0.5699810006333123 %)
# Broj igraca na poziciji RS: 79, (1.66772218703821 %)
# Broj igraca na poziciji LS: 80, (1.6888325944690732 %)
#
# VEZNI RED: 1753 (37.00654422630357 %)
# Broj igraca na poziciji RDM: 55, (1.1610724086974877 %)
# Broj igraca na poziciji CDM: 207, (4.369854338188727 %)
# Broj igraca na poziciji LDM: 63, (1.3299556681443951 %)
# Broj igraca na poziciji RM: 328, (6.9242136373231995 %)
# Broj igraca na poziciji RCM: 88, (1.8577158539159806 %)
# Broj igraca na poziciji CM: 239, (5.045387375976356 %)
# Broj igraca na poziciji LCM: 84, (1.773274224192527 %)
# Broj igraca na poziciji LM: 346, (7.304200971078742 %)
# Broj igraca na poziciji RAM: 15, (0.31665611146295125 %)
# Broj igraca na poziciji CAM: 315, (6.649778340721976 %)
# Broj igraca na poziciji LAM: 13, (0.2744352966012244 %)
#
# ODBRANA: 1471 (31.053409330800086 %)
# Broj igraca na poziciji RWB: 15, (0.31665611146295125 %)
# Broj igraca na poziciji RB: 243, (5.1298290056998095 %)
# Broj igraca na poziciji RCB: 232, (4.897614523960312 %)
# Broj igraca na poziciji CB: 488, (10.301878826261348 %)
# Broj igraca na poziciji LCB: 229, (4.834283301667722 %)
# Broj igraca na poziciji LB: 248, (5.235381042854128 %)
# Broj igraca na poziciji LWB: 16, (0.33776651889381465 %)
#
# GOLMANI: 340 (7.177538526493561 %)
#
# Broj igraca u klasteru 0: 1678, (9.216235513813368 %)
#
# NAPAD: 0 (0.0 %)
# Broj igraca na poziciji RF: 0, (0.0 %)
# Broj igraca na poziciji LF: 0, (0.0 %)
# Broj igraca na poziciji RW: 0, (0.0 %)
# Broj igraca na poziciji LW: 0, (0.0 %)
# Broj igraca na poziciji ST: 0, (0.0 %)
# Broj igraca na poziciji CF: 0, (0.0 %)
# Broj igraca na poziciji RS: 0, (0.0 %)
# Broj igraca na poziciji LS: 0, (0.0 %)
#
# VEZNI RED: 0 (0.0 %)
# Broj igraca na poziciji RDM: 0, (0.0 %)
# Broj igraca na poziciji CDM: 0, (0.0 %)
# Broj igraca na poziciji LDM: 0, (0.0 %)
# Broj igraca na poziciji RM: 0, (0.0 %)
# Broj igraca na poziciji RCM: 0, (0.0 %)
# Broj igraca na poziciji CM: 0, (0.0 %)
# Broj igraca na poziciji LCM: 0, (0.0 %)
# Broj igraca na poziciji LM: 0, (0.0 %)
# Broj igraca na poziciji RAM: 0, (0.0 %)
# Broj igraca na poziciji CAM: 0, (0.0 %)
# Broj igraca na poziciji LAM: 0, (0.0 %)
#
# ODBRANA: 0 (0.0 %)
# Broj igraca na poziciji RWB: 0, (0.0 %)
# Broj igraca na poziciji RB: 0, (0.0 %)
# Broj igraca na poziciji RCB: 0, (0.0 %)
# Broj igraca na poziciji CB: 0, (0.0 %)
# Broj igraca na poziciji LCB: 0, (0.0 %)
# Broj igraca na poziciji LB: 0, (0.0 %)
# Broj igraca na poziciji LWB: 0, (0.0 %)
#
# GOLMANI: 1678 (100.0 %)
#
# Broj igraca u klasteru 1: 11771, (64.65095842258472 %)
#
# NAPAD: 2301 (19.548041797638263 %)
# Broj igraca na poziciji RF: 9, (0.0764590943845043 %)
# Broj igraca na poziciji LF: 9, (0.0764590943845043 %)
# Broj igraca na poziciji RW: 231, (1.9624500892022767 %)
# Broj igraca na poziciji LW: 247, (2.0983773681080624 %)
# Broj igraca na poziciji ST: 1507, (12.802650581938662 %)
# Broj igraca na poziciji CF: 47, (0.3992863817857446 %)
# Broj igraca na poziciji RS: 124, (1.053436411519837 %)
# Broj igraca na poziciji LS: 127, (1.0789227763146716 %)
#
# VEZNI RED: 5082 (43.17390196245009 %)
# Broj igraca na poziciji RDM: 193, (1.6396228018010364 %)
# Broj igraca na poziciji CDM: 741, (6.2951321043241855 %)
# Broj igraca na poziciji LDM: 180, (1.5291818876900858 %)
# Broj igraca na poziciji RM: 794, (6.7453912156996 %)
# Broj igraca na poziciji RCM: 303, (2.574122844278311 %)
# Broj igraca na poziciji CM: 1155, (9.812250446011383 %)
# Broj igraca na poziciji LCM: 311, (2.642086483731204 %)
# Broj igraca na poziciji LM: 748, (6.354600288845467 %)
# Broj igraca na poziciji RAM: 6, (0.05097272958966952 %)
# Broj igraca na poziciji CAM: 643, (5.462577521026251 %)
# Broj igraca na poziciji LAM: 8, (0.0679636394528927 %)
#
# ODBRANA: 4388 (37.27805623991165 %)
# Broj igraca na poziciji RWB: 72, (0.6116727550760344 %)
# Broj igraca na poziciji RB: 1048, (8.903236768328943 %)
# Broj igraca na poziciji RCB: 429, (3.6445501656613715 %)
# Broj igraca na poziciji CB: 1287, (10.933650496984114 %)
# Broj igraca na poziciji LCB: 416, (3.5341092515504204 %)
# Broj igraca na poziciji LB: 1074, (9.124118596550845 %)
# Broj igraca na poziciji LWB: 62, (0.5267182057599185 %)
#
# GOLMANI: 0 (0.0 %)
#
# Broj igraca u klasteru 2: 7, (0.03844675124951942 %)
#
# NAPAD: 0 (0.0 %)
# Broj igraca na poziciji RF: 0, (0.0 %)
# Broj igraca na poziciji LF: 0, (0.0 %)
# Broj igraca na poziciji RW: 0, (0.0 %)
# Broj igraca na poziciji LW: 0, (0.0 %)
# Broj igraca na poziciji ST: 0, (0.0 %)
# Broj igraca na poziciji CF: 0, (0.0 %)
# Broj igraca na poziciji RS: 0, (0.0 %)
# Broj igraca na poziciji LS: 0, (0.0 %)
#
# VEZNI RED: 0 (0.0 %)
# Broj igraca na poziciji RDM: 0, (0.0 %)
# Broj igraca na poziciji CDM: 0, (0.0 %)
# Broj igraca na poziciji LDM: 0, (0.0 %)
# Broj igraca na poziciji RM: 0, (0.0 %)
# Broj igraca na poziciji RCM: 0, (0.0 %)
# Broj igraca na poziciji CM: 0, (0.0 %)
# Broj igraca na poziciji LCM: 0, (0.0 %)
# Broj igraca na poziciji LM: 0, (0.0 %)
# Broj igraca na poziciji RAM: 0, (0.0 %)
# Broj igraca na poziciji CAM: 0, (0.0 %)
# Broj igraca na poziciji LAM: 0, (0.0 %)
#
# ODBRANA: 7 (100.0 %)
# Broj igraca na poziciji RWB: 0, (0.0 %)
# Broj igraca na poziciji RB: 0, (0.0 %)
# Broj igraca na poziciji RCB: 1, (14.285714285714285 %)
# Broj igraca na poziciji CB: 3, (42.857142857142854 %)
# Broj igraca na poziciji LCB: 3, (42.857142857142854 %)
# Broj igraca na poziciji LB: 0, (0.0 %)
# Broj igraca na poziciji LWB: 0, (0.0 %)
#
# GOLMANI: 0 (0.0 %)
#
# Broj igraca u klasteru 3: 7, (0.03844675124951942 %)
#
# NAPAD: 4 (57.14285714285714 %)
# Broj igraca na poziciji RF: 0, (0.0 %)
# Broj igraca na poziciji LF: 0, (0.0 %)
# Broj igraca na poziciji RW: 3, (42.857142857142854 %)
# Broj igraca na poziciji LW: 1, (14.285714285714285 %)
# Broj igraca na poziciji ST: 0, (0.0 %)
# Broj igraca na poziciji CF: 0, (0.0 %)
# Broj igraca na poziciji RS: 0, (0.0 %)
# Broj igraca na poziciji LS: 0, (0.0 %)
#
# VEZNI RED: 3 (42.857142857142854 %)
# Broj igraca na poziciji RDM: 0, (0.0 %)
# Broj igraca na poziciji CDM: 0, (0.0 %)
# Broj igraca na poziciji LDM: 0, (0.0 %)
# Broj igraca na poziciji RM: 2, (28.57142857142857 %)
# Broj igraca na poziciji RCM: 0, (0.0 %)
# Broj igraca na poziciji CM: 0, (0.0 %)
# Broj igraca na poziciji LCM: 0, (0.0 %)
# Broj igraca na poziciji LM: 1, (14.285714285714285 %)
# Broj igraca na poziciji RAM: 0, (0.0 %)
# Broj igraca na poziciji CAM: 0, (0.0 %)
# Broj igraca na poziciji LAM: 0, (0.0 %)
#
# ODBRANA: 0 (0.0 %)
# Broj igraca na poziciji RWB: 0, (0.0 %)
# Broj igraca na poziciji RB: 0, (0.0 %)
# Broj igraca na poziciji RCB: 0, (0.0 %)
# Broj igraca na poziciji CB: 0, (0.0 %)
# Broj igraca na poziciji LCB: 0, (0.0 %)
# Broj igraca na poziciji LB: 0, (0.0 %)
# Broj igraca na poziciji LWB: 0, (0.0 %)
#
# GOLMANI: 0 (0.0 %)

# %%
df1 = df.replace({'RF': 'ATT', 'LF': 'ATT', 'RW': 'ATT', 'LW': 'ATT', 'ST': 'ATT', 'CF': 'ATT', 'RS': 'ATT', 'LS': 'ATT',
            'RDM': 'MF', 'CDM': 'MF', 'LDM': 'MF', 'RM': 'MF', 'RCM': 'MF', 'CM': 'MF', 'LCM': 'MF', 'LM': 'MF', 'RAM': 'MF', 'CAM': 'MF', 'LAM': 'MF',
            'RWB': 'DF', 'RB': 'DF', 'RCB': 'DF', 'CB': 'DF', 'LCB': 'DF', 'LB': 'DF', 'LWB': 'DF'})

# %%
plt.figure(num=None, figsize=(8, 6), dpi=200)
sns.countplot(x='cluster_marks', hue='Position', data=df1)
# Out:
# <AxesSubplot:xlabel='cluster_marks', ylabel='count'>

# %% [markdown]
# ## Koji su to parametri koji golmane razlikuju od igrača na ostalim pozicijama?

# %% [markdown]
# **Golman** - GK
#
# **Odbrana** - RWB, RB, RCB, CB, LCB, LB, LWB
#
# **Vezni red** - RDM, CDM, LDM, RM, RCM, CM, LCM, LM, RAM, CAM, LAM
#
# **Napad** - RF, CF, LF, RS, ST, LS, LW, RW

# %%
def show_mean_and_median_for_each_team_position(df, variable):
    
    gk = df.loc[df['Position'] == 'GK']

    print(f'GK, srednja vrednost {variable}: ', gk[variable].mean())
    print(f'GK, medijan vrednost {variable}: ', gk[variable].median())
    print()

    # Napadaci 

    print('NAPAD:')

    rf = df.loc[df['Position'] == 'RF']

    print(f'RF, srednja vrednost {variable}: ', rf[variable].mean())
    print(f'RF, medijan vrednost {variable}: ', rf[variable].median())
    print()

    cf = df.loc[df['Position'] == 'CF']

    print(f'CF, srednja vrednost {variable}: ', cf[variable].mean())
    print(f'CF, medijan vrednost {variable}: ', cf[variable].median())
    print()

    lf = df.loc[df['Position'] == 'LF']

    print(f'LF, srednja vrednost {variable}: ', lf[variable].mean())
    print(f'LF, medijan vrednost {variable}: ', lf[variable].median())
    print()

    rs = df.loc[df['Position'] == 'RS']

    print(f'RS, srednja vrednost {variable}: ', rs[variable].mean())
    print(f'RS, medijan vrednost {variable}: ', rs[variable].median())
    print()

    st = df.loc[df['Position'] == 'ST']

    print(f'ST, srednja vrednost {variable}: ', st[variable].mean())
    print(f'ST, medijan vrednost {variable}: ', st[variable].median())
    print()

    ls = df.loc[df['Position'] == 'LS']

    print(f'LS, srednja vrednost {variable}: ', ls[variable].mean())
    print(f'LS, medijan vrednost {variable}: ', ls[variable].median())
    print()

    lw = df.loc[df['Position'] == 'LW']

    print(f'LW, srednja vrednost {variable}: ', lw[variable].mean())
    print(f'LW, medijan vrednost {variable}: ', lw[variable].median())
    print()

    rw = df.loc[df['Position'] == 'RW']

    print(f'RW, srednja vrednost {variable}: ', rw[variable].mean())
    print(f'RW, medijan vrednost {variable}: ', rw[variable].median())
    print()

    # Vezni red

    print('VEZNI RED:')

    rdm = df.loc[df['Position'] == 'RDM']

    print(f'RDM, srednja vrednost {variable}: ', rdm[variable].mean())
    print(f'RDM, medijan vrednost {variable}: ', rdm[variable].median())
    print()

    cdm = df.loc[df['Position'] == 'CDM']

    print(f'CDM, srednja vrednost {variable}: ', cdm[variable].mean())
    print(f'CDM, medijan vrednost {variable}: ', cdm[variable].median())
    print()

    ldm = df.loc[df['Position'] == 'LDM']

    print(f'LDM, srednja vrednost {variable}: ', ldm[variable].mean())
    print(f'LDM, medijan vrednost {variable}: ', ldm[variable].median())
    print()

    rm = df.loc[df['Position'] == 'RM']

    print(f'RM, srednja vrednost {variable}: ', rm[variable].mean())
    print(f'RM, medijan vrednost {variable}: ', rm[variable].median())
    print()

    rcm = df.loc[df['Position'] == 'RCM']

    print(f'RCM, srednja vrednost {variable}: ', rcm[variable].mean())
    print(f'RCM, medijan vrednost {variable}: ', rcm[variable].median())
    print()

    cm = df.loc[df['Position'] == 'CM']

    print(f'CM, srednja vrednost {variable}: ', cm[variable].mean())
    print(f'CM, medijan vrednost {variable}: ', cm[variable].median())
    print()

    lcm = df.loc[df['Position'] == 'LCM']

    print(f'LCM, srednja vrednost {variable}: ', lcm[variable].mean())
    print(f'LCM, medijan vrednost {variable}: ', lcm[variable].median())
    print()

    lm = df.loc[df['Position'] == 'LM']

    print(f'LM, srednja vrednost {variable}: ', lm[variable].mean())
    print(f'LM, medijan vrednost {variable}: ', lm[variable].median())
    print()

    ram = df.loc[df['Position'] == 'RAM']

    print(f'RAM, srednja vrednost {variable}: ', ram[variable].mean())
    print(f'RAM, medijan vrednost {variable}: ', ram[variable].median())
    print()

    cam = df.loc[df['Position'] == 'CAM']

    print(f'CAM, srednja vrednost {variable}: ', cam[variable].mean())
    print(f'CAM, medijan vrednost {variable}: ', cam[variable].median())
    print()

    # Odbrana

    print('ODBRANA:')

    rwb = df.loc[df['Position'] == 'RWB']

    print(f'RWB, srednja vrednost {variable}: ', rwb[variable].mean())
    print(f'RWB, medijan vrednost {variable}: ', rwb[variable].median())
    print()

    rb = df.loc[df['Position'] == 'RB']

    print(f'RB, srednja vrednost {variable}: ', rb[variable].mean())
    print(f'RB, medijan vrednost {variable}: ', rb[variable].median())
    print()

    rcb = df.loc[df['Position'] == 'RCB']

    print(f'RCB, srednja vrednost {variable}: ', rcb[variable].mean())
    print(f'RCB, medijan vrednost {variable}: ', rcb[variable].median())
    print()

    cb = df.loc[df['Position'] == 'CB']

    print(f'CB, srednja vrednost {variable}: ', cb[variable].mean())
    print(f'CB, medijan vrednost {variable}: ', cb[variable].median())
    print()

    lcb = df.loc[df['Position'] == 'LCB']

    print(f'LCB, srednja vrednost {variable}: ', lcb[variable].mean())
    print(f'LCB, medijan vrednost {variable}: ', lcb[variable].median())
    print()

    lb = df.loc[df['Position'] == 'LB']

    print(f'LB, srednja vrednost {variable}: ', lb[variable].mean())
    print(f'LB, medijan vrednost {variable}: ', lb[variable].median())
    print()

    lwb = df.loc[df['Position'] == 'LWB']

    print(f'LWB, srednja vrednost {variable}: ', lwb[variable].mean())
    print(f'LWB, medijan vrednost {variable}: ', lwb[variable].median())
    print()

# %% [markdown]
# ## "Neutralni" parametri (ne čine golmana ni "inferiornijim" ni "superiornijim" u odnosu na igrače na ostalim pozicijama)

# %%
show_mean_and_median_for_each_team_position(df, 'Age')
# Out:
# GK, srednja vrednost Age:  0.3463260962111537
# GK, medijan vrednost Age:  0.31034482758620685
#
# NAPAD:
# RF, srednja vrednost Age:  0.40086206896551724
# RF, medijan vrednost Age:  0.3793103448275862
#
# CF, srednja vrednost Age:  0.2590866728797763
# CF, medijan vrednost Age:  0.24137931034482762
#
# LF, srednja vrednost Age:  0.37011494252873567
# LF, medijan vrednost Age:  0.3793103448275862
#
# RS, srednja vrednost Age:  0.368269067436725
# RS, medijan vrednost Age:  0.3448275862068966
#
# ST, srednja vrednost Age:  0.2994481511504646
# ST, medijan vrednost Age:  0.27586206896551724
#
# LS, srednja vrednost Age:  0.3726470098284191
# LS, medijan vrednost Age:  0.3793103448275862
#
# LW, srednja vrednost Age:  0.2555887410625396
# LW, medijan vrednost Age:  0.24137931034482762
#
# RW, srednja vrednost Age:  0.261789375582479
# RW, medijan vrednost Age:  0.24137931034482762
#
# VEZNI RED:
# RDM, srednja vrednost Age:  0.3794493882091212
# RDM, medijan vrednost Age:  0.3793103448275862
#
# CDM, srednja vrednost Age:  0.31845627819001887
# CDM, medijan vrednost Age:  0.31034482758620685
#
# LDM, srednja vrednost Age:  0.37505321413367393
# LDM, medijan vrednost Age:  0.3793103448275862
#
# RM, srednja vrednost Age:  0.2899128727451221
# RM, medijan vrednost Age:  0.27586206896551724
#
# RCM, srednja vrednost Age:  0.35073639650762856
# RCM, medijan vrednost Age:  0.3448275862068966
#
# CM, srednja vrednost Age:  0.25797753920744076
# CM, medijan vrednost Age:  0.2068965517241379
#
# LCM, srednja vrednost Age:  0.34675879944797816
# LCM, medijan vrednost Age:  0.3448275862068966
#
# LM, srednja vrednost Age:  0.2928672649976382
# LM, medijan vrednost Age:  0.27586206896551724
#
# RAM, srednja vrednost Age:  0.438423645320197
# RAM, medijan vrednost Age:  0.48275862068965525
#
# CAM, srednja vrednost Age:  0.2958750269958967
# CAM, medijan vrednost Age:  0.27586206896551724
#
# ODBRANA:
# RWB, srednja vrednost Age:  0.2885453824811732
# RWB, medijan vrednost Age:  0.31034482758620685
#
# RB, srednja vrednost Age:  0.3203077005261893
# RB, medijan vrednost Age:  0.31034482758620685
#
# RCB, srednja vrednost Age:  0.3787373684758829
# RCB, medijan vrednost Age:  0.3793103448275862
#
# CB, srednja vrednost Age:  0.30408052441720657
# CB, medijan vrednost Age:  0.27586206896551724
#
# LCB, srednja vrednost Age:  0.381119625372499
# LCB, medijan vrednost Age:  0.3793103448275862
#
# LB, srednja vrednost Age:  0.31329229485106164
# LB, medijan vrednost Age:  0.31034482758620685
#
# LWB, srednja vrednost Age:  0.32360742705570283
# LWB, medijan vrednost Age:  0.31034482758620685

# %%
show_mean_and_median_for_each_team_position(df, 'Overall')
# Out:
# GK, srednja vrednost Overall:  0.38733783383942977
# GK, medijan vrednost Overall:  0.375
#
# NAPAD:
# RF, srednja vrednost Overall:  0.5677083333333334
# RF, medijan vrednost Overall:  0.5208333333333334
#
# CF, srednja vrednost Overall:  0.4130067567567567
# CF, medijan vrednost Overall:  0.40625
#
# LF, srednja vrednost Overall:  0.5805555555555556
# LF, medijan vrednost Overall:  0.5208333333333333
#
# RS, srednja vrednost Overall:  0.4900451559934318
# RS, medijan vrednost Overall:  0.47916666666666674
#
# ST, srednja vrednost Overall:  0.40479015973477994
# ST, medijan vrednost Overall:  0.39583333333333326
#
# LS, srednja vrednost Overall:  0.5013083735909823
# LS, medijan vrednost Overall:  0.5
#
# LW, srednja vrednost Overall:  0.42951662292213466
# LW, medijan vrednost Overall:  0.41666666666666674
#
# RW, srednja vrednost Overall:  0.43603603603603597
# RW, medijan vrednost Overall:  0.4375
#
# VEZNI RED:
# RDM, srednja vrednost Overall:  0.49487567204301075
# RDM, medijan vrednost Overall:  0.5
#
# CDM, srednja vrednost Overall:  0.4231935654008439
# CDM, medijan vrednost Overall:  0.41666666666666674
#
# LDM, srednja vrednost Overall:  0.47985253772290803
# LDM, medijan vrednost Overall:  0.47916666666666674
#
# RM, srednja vrednost Overall:  0.4270091933570581
# RM, medijan vrednost Overall:  0.41666666666666674
#
# RCM, srednja vrednost Overall:  0.4807651321398124
# RCM, medijan vrednost Overall:  0.47916666666666674
#
# CM, srednja vrednost Overall:  0.3693657340985174
# CM, medijan vrednost Overall:  0.375
#
# LCM, srednja vrednost Overall:  0.48481012658227846
# LCM, medijan vrednost Overall:  0.47916666666666674
#
# LM, srednja vrednost Overall:  0.4310882800608828
# LM, medijan vrednost Overall:  0.4375
#
# RAM, srednja vrednost Overall:  0.5476190476190476
# RAM, medijan vrednost Overall:  0.5416666666666667
#
# CAM, srednja vrednost Overall:  0.4354993041057759
# CAM, medijan vrednost Overall:  0.4375
#
# ODBRANA:
# RWB, srednja vrednost Overall:  0.38864942528735624
# RWB, medijan vrednost Overall:  0.375
#
# RB, srednja vrednost Overall:  0.41789310611928737
# RB, medijan vrednost Overall:  0.41666666666666674
#
# RCB, srednja vrednost Overall:  0.485083081570997
# RCB, medijan vrednost Overall:  0.47916666666666674
#
# CB, srednja vrednost Overall:  0.39634889388826394
# CB, medijan vrednost Overall:  0.39583333333333326
#
# LCB, srednja vrednost Overall:  0.4841820987654321
# LCB, medijan vrednost Overall:  0.47916666666666674
#
# LB, srednja vrednost Overall:  0.41364094805849727
# LB, medijan vrednost Overall:  0.41666666666666674
#
# LWB, srednja vrednost Overall:  0.4273504273504273
# LWB, medijan vrednost Overall:  0.41666666666666674

# %%
show_mean_and_median_for_each_team_position(df, 'Potential')
# Out:
# GK, srednja vrednost Potential:  0.46380877331231946
# GK, medijan vrednost Potential:  0.44680851063829796
#
# NAPAD:
# RF, srednja vrednost Potential:  0.583776595744681
# RF, medijan vrednost Potential:  0.574468085106383
#
# CF, srednja vrednost Potential:  0.5264519838987926
# CF, medijan vrednost Potential:  0.5319148936170213
#
# LF, srednja vrednost Potential:  0.6085106382978723
# LF, medijan vrednost Potential:  0.5957446808510638
#
# RS, srednja vrednost Potential:  0.5191279740069175
# RS, medijan vrednost Potential:  0.5106382978723405
#
# ST, srednja vrednost Potential:  0.4889865722750183
# ST, medijan vrednost Potential:  0.4893617021276597
#
# LS, srednja vrednost Potential:  0.5278034741494502
# LS, medijan vrednost Potential:  0.5106382978723405
#
# LW, srednja vrednost Potential:  0.5345395655330318
# LW, medijan vrednost Potential:  0.5319148936170213
#
# RW, srednja vrednost Potential:  0.5389304197814836
# RW, medijan vrednost Potential:  0.5425531914893618
#
# VEZNI RED:
# RDM, srednja vrednost Potential:  0.5209334248455731
# RDM, medijan vrednost Potential:  0.5319148936170213
#
# CDM, srednja vrednost Potential:  0.5000897746655893
# CDM, medijan vrednost Potential:  0.4893617021276597
#
# LDM, srednja vrednost Potential:  0.5158917783031258
# LDM, medijan vrednost Potential:  0.5106382978723405
#
# RM, srednja vrednost Potential:  0.500927538426592
# RM, medijan vrednost Potential:  0.4893617021276597
#
# RCM, srednja vrednost Potential:  0.5217391304347826
# RCM, medijan vrednost Potential:  0.5106382978723405
#
# CM, srednja vrednost Potential:  0.48734698861381603
# CM, medijan vrednost Potential:  0.4893617021276597
#
# LCM, srednja vrednost Potential:  0.5273363856719634
# LCM, medijan vrednost Potential:  0.5319148936170213
#
# LM, srednja vrednost Potential:  0.5052365685417275
# LM, medijan vrednost Potential:  0.4893617021276597
#
# RAM, srednja vrednost Potential:  0.5288753799392099
# RAM, medijan vrednost Potential:  0.5106382978723405
#
# CAM, srednja vrednost Potential:  0.5242526540221206
# CAM, medijan vrednost Potential:  0.5106382978723405
#
# ODBRANA:
# RWB, srednja vrednost Potential:  0.4671068720958672
# RWB, medijan vrednost Potential:  0.44680851063829796
#
# RB, srednja vrednost Potential:  0.47817130049277323
# RB, medijan vrednost Potential:  0.46808510638297873
#
# RCB, srednja vrednost Potential:  0.5155235585267083
# RCB, medijan vrednost Potential:  0.5106382978723405
#
# CB, srednja vrednost Potential:  0.4873991814852931
# CB, medijan vrednost Potential:  0.4893617021276597
#
# LCB, srednja vrednost Potential:  0.5172051484108222
# LCB, medijan vrednost Potential:  0.5106382978723405
#
# LB, srednja vrednost Potential:  0.47910966620529827
# LB, medijan vrednost Potential:  0.46808510638297873
#
# LWB, srednja vrednost Potential:  0.48254228041462083
# LWB, medijan vrednost Potential:  0.46808510638297873

# %%
show_mean_and_median_for_each_team_position(df, 'International Reputation')
# Out:
# GK, srednja vrednost International Reputation:  0.023950617283950617
# GK, medijan vrednost International Reputation:  0.0
#
# NAPAD:
# RF, srednja vrednost International Reputation:  0.140625
# RF, medijan vrednost International Reputation:  0.0
#
# CF, srednja vrednost International Reputation:  0.0472972972972973
# CF, medijan vrednost International Reputation:  0.0
#
# LF, srednja vrednost International Reputation:  0.16666666666666666
# LF, medijan vrednost International Reputation:  0.0
#
# RS, srednja vrednost International Reputation:  0.05295566502463054
# RS, medijan vrednost International Reputation:  0.0
#
# ST, srednja vrednost International Reputation:  0.029321277181162543
# ST, medijan vrednost International Reputation:  0.0
#
# LS, srednja vrednost International Reputation:  0.05555555555555555
# LS, medijan vrednost International Reputation:  0.0
#
# LW, srednja vrednost International Reputation:  0.026246719160104987
# LW, medijan vrednost International Reputation:  0.0
#
# RW, srednja vrednost International Reputation:  0.037162162162162164
# RW, medijan vrednost International Reputation:  0.0
#
# VEZNI RED:
# RDM, srednja vrednost International Reputation:  0.028225806451612902
# RDM, medijan vrednost International Reputation:  0.0
#
# CDM, srednja vrednost International Reputation:  0.031118143459915613
# CDM, medijan vrednost International Reputation:  0.0
#
# LDM, srednja vrednost International Reputation:  0.03292181069958848
# LDM, medijan vrednost International Reputation:  0.0
#
# RM, srednja vrednost International Reputation:  0.025133451957295373
# RM, medijan vrednost International Reputation:  0.0
#
# RCM, srednja vrednost International Reputation:  0.04539641943734015
# RCM, medijan vrednost International Reputation:  0.0
#
# CM, srednja vrednost International Reputation:  0.021520803443328552
# CM, medijan vrednost International Reputation:  0.0
#
# LCM, srednja vrednost International Reputation:  0.046202531645569624
# LCM, medijan vrednost International Reputation:  0.0
#
# LM, srednja vrednost International Reputation:  0.025799086757990867
# LM, medijan vrednost International Reputation:  0.0
#
# RAM, srednja vrednost International Reputation:  0.047619047619047616
# RAM, medijan vrednost International Reputation:  0.0
#
# CAM, srednja vrednost International Reputation:  0.03392484342379958
# CAM, medijan vrednost International Reputation:  0.0
#
# ODBRANA:
# RWB, srednja vrednost International Reputation:  0.02586206896551724
# RWB, medijan vrednost International Reputation:  0.0
#
# RB, srednja vrednost International Reputation:  0.022075910147172733
# RB, medijan vrednost International Reputation:  0.0
#
# RCB, srednja vrednost International Reputation:  0.038897280966767374
# RCB, medijan vrednost International Reputation:  0.0
#
# CB, srednja vrednost International Reputation:  0.02066929133858268
# CB, medijan vrednost International Reputation:  0.0
#
# LCB, srednja vrednost International Reputation:  0.03742283950617284
# LCB, medijan vrednost International Reputation:  0.0
#
# LB, srednja vrednost International Reputation:  0.02023449319213313
# LB, medijan vrednost International Reputation:  0.0
#
# LWB, srednja vrednost International Reputation:  0.022435897435897436
# LWB, medijan vrednost International Reputation:  0.0

# %%
show_mean_and_median_for_each_team_position(df, 'Weak Foot')
# Out:
# GK, srednja vrednost Weak Foot:  0.37246913580246915
# GK, medijan vrednost Weak Foot:  0.5
#
# NAPAD:
# RF, srednja vrednost Weak Foot:  0.609375
# RF, medijan vrednost Weak Foot:  0.5
#
# CF, srednja vrednost Weak Foot:  0.5608108108108109
# CF, medijan vrednost Weak Foot:  0.5
#
# LF, srednja vrednost Weak Foot:  0.65
# LF, medijan vrednost Weak Foot:  0.75
#
# RS, srednja vrednost Weak Foot:  0.5529556650246306
# RS, medijan vrednost Weak Foot:  0.5
#
# ST, srednja vrednost Weak Foot:  0.5165540625320221
# ST, medijan vrednost Weak Foot:  0.5
#
# LS, srednja vrednost Weak Foot:  0.5628019323671497
# LS, medijan vrednost Weak Foot:  0.5
#
# LW, srednja vrednost Weak Foot:  0.5439632545931758
# LW, medijan vrednost Weak Foot:  0.5
#
# RW, srednja vrednost Weak Foot:  0.5452702702702703
# RW, medijan vrednost Weak Foot:  0.5
#
# VEZNI RED:
# RDM, srednja vrednost Weak Foot:  0.5181451612903226
# RDM, medijan vrednost Weak Foot:  0.5
#
# CDM, srednja vrednost Weak Foot:  0.4923523206751055
# CDM, medijan vrednost Weak Foot:  0.5
#
# LDM, srednja vrednost Weak Foot:  0.5041152263374485
# LDM, medijan vrednost Weak Foot:  0.5
#
# RM, srednja vrednost Weak Foot:  0.5258007117437722
# RM, medijan vrednost Weak Foot:  0.5
#
# RCM, srednja vrednost Weak Foot:  0.5441176470588235
# RCM, medijan vrednost Weak Foot:  0.5
#
# CM, srednja vrednost Weak Foot:  0.5111190817790531
# CM, medijan vrednost Weak Foot:  0.5
#
# LCM, srednja vrednost Weak Foot:  0.5341772151898734
# LCM, medijan vrednost Weak Foot:  0.5
#
# LM, srednja vrednost Weak Foot:  0.5422374429223744
# LM, medijan vrednost Weak Foot:  0.5
#
# RAM, srednja vrednost Weak Foot:  0.5952380952380952
# RAM, medijan vrednost Weak Foot:  0.75
#
# CAM, srednja vrednost Weak Foot:  0.5545407098121086
# CAM, medijan vrednost Weak Foot:  0.5
#
# ODBRANA:
# RWB, srednja vrednost Weak Foot:  0.48563218390804597
# RWB, medijan vrednost Weak Foot:  0.5
#
# RB, srednja vrednost Weak Foot:  0.48024786986831913
# RB, medijan vrednost Weak Foot:  0.5
#
# RCB, srednja vrednost Weak Foot:  0.4550604229607251
# RCB, medijan vrednost Weak Foot:  0.5
#
# CB, srednja vrednost Weak Foot:  0.44502249718785153
# CB, medijan vrednost Weak Foot:  0.5
#
# LCB, srednja vrednost Weak Foot:  0.45100308641975306
# LCB, medijan vrednost Weak Foot:  0.5
#
# LB, srednja vrednost Weak Foot:  0.44780635400907715
# LB, medijan vrednost Weak Foot:  0.5
#
# LWB, srednja vrednost Weak Foot:  0.4423076923076923
# LWB, medijan vrednost Weak Foot:  0.5

# %%
show_mean_and_median_for_each_team_position(df, 'Jersey Number')
# Out:
# GK, srednja vrednost Jersey Number:  0.19914840010078103
# GK, medijan vrednost Jersey Number:  0.2040816326530612
#
# NAPAD:
# RF, srednja vrednost Jersey Number:  0.13137755102040816
# RF, medijan vrednost Jersey Number:  0.09693877551020408
#
# CF, srednja vrednost Jersey Number:  0.21704357418643128
# CF, medijan vrednost Jersey Number:  0.17857142857142855
#
# LF, srednja vrednost Jersey Number:  0.16122448979591833
# LF, medijan vrednost Jersey Number:  0.1020408163265306
#
# RS, srednja vrednost Jersey Number:  0.1709560671559264
# RS, medijan vrednost Jersey Number:  0.1020408163265306
#
# ST, srednja vrednost Jersey Number:  0.2192621219434087
# ST, medijan vrednost Jersey Number:  0.18367346938775508
#
# LS, srednja vrednost Jersey Number:  0.1815537809326629
# LS, medijan vrednost Jersey Number:  0.12244897959183672
#
# LW, srednja vrednost Jersey Number:  0.21822272215973001
# LW, medijan vrednost Jersey Number:  0.173469387755102
#
# RW, srednja vrednost Jersey Number:  0.22233866519580806
# RW, medijan vrednost Jersey Number:  0.18367346938775508
#
# VEZNI RED:
# RDM, srednja vrednost Jersey Number:  0.1540487162606978
# RDM, medijan vrednost Jersey Number:  0.1173469387755102
#
# CDM, srednja vrednost Jersey Number:  0.19294110049082921
# CDM, medijan vrednost Jersey Number:  0.16326530612244897
#
# LDM, srednja vrednost Jersey Number:  0.16234147980179725
# LDM, medijan vrednost Jersey Number:  0.12244897959183672
#
# RM, srednja vrednost Jersey Number:  0.19576585082431544
# RM, medijan vrednost Jersey Number:  0.173469387755102
#
# RCM, srednja vrednost Jersey Number:  0.1552273083146302
# RCM, medijan vrednost Jersey Number:  0.13265306122448978
#
# CM, srednja vrednost Jersey Number:  0.21142359382777498
# CM, medijan vrednost Jersey Number:  0.19387755102040813
#
# LCM, srednja vrednost Jersey Number:  0.1507620769826918
# LCM, medijan vrednost Jersey Number:  0.13265306122448978
#
# LM, srednja vrednost Jersey Number:  0.20622495573571892
# LM, medijan vrednost Jersey Number:  0.173469387755102
#
# RAM, srednja vrednost Jersey Number:  0.13265306122448978
# RAM, medijan vrednost Jersey Number:  0.07142857142857142
#
# CAM, srednja vrednost Jersey Number:  0.20014059903710962
# CAM, medijan vrednost Jersey Number:  0.173469387755102
#
# ODBRANA:
# RWB, srednja vrednost Jersey Number:  0.1975134881538822
# RWB, medijan vrednost Jersey Number:  0.173469387755102
#
# RB, srednja vrednost Jersey Number:  0.17569831960669627
# RB, medijan vrednost Jersey Number:  0.16326530612244897
#
# RCB, srednja vrednost Jersey Number:  0.1238054134040323
# RCB, medijan vrednost Jersey Number:  0.05102040816326531
#
# CB, srednja vrednost Jersey Number:  0.18311103969146714
# CB, medijan vrednost Jersey Number:  0.173469387755102
#
# LCB, srednja vrednost Jersey Number:  0.12818090199042578
# LCB, medijan vrednost Jersey Number:  0.05102040816326531
#
# LB, srednja vrednost Jersey Number:  0.17830899379418938
# LB, medijan vrednost Jersey Number:  0.16326530612244897
#
# LWB, srednja vrednost Jersey Number:  0.13840920983778127
# LWB, medijan vrednost Jersey Number:  0.12244897959183672

# %%
show_mean_and_median_for_each_team_position(df, 'Reactions')
# Out:
# GK, srednja vrednost Reactions:  0.5056855967078189
# GK, medijan vrednost Reactions:  0.52
#
# NAPAD:
# RF, srednja vrednost Reactions:  0.6600000000000001
# RF, medijan vrednost Reactions:  0.66
#
# CF, srednja vrednost Reactions:  0.5574774774774774
# CF, medijan vrednost Reactions:  0.5466666666666667
#
# LF, srednja vrednost Reactions:  0.6666666666666666
# LF, medijan vrednost Reactions:  0.6533333333333333
#
# RS, srednja vrednost Reactions:  0.6005911330049262
# RS, medijan vrednost Reactions:  0.6
#
# ST, srednja vrednost Reactions:  0.5424843717744612
# ST, medijan vrednost Reactions:  0.544488132606421
#
# LS, srednja vrednost Reactions:  0.6045088566827698
# LS, medijan vrednost Reactions:  0.6
#
# LW, srednja vrednost Reactions:  0.5294138232720911
# LW, medijan vrednost Reactions:  0.5333333333333333
#
# RW, srednja vrednost Reactions:  0.5343423423423423
# RW, medijan vrednost Reactions:  0.5466666666666667
#
# VEZNI RED:
# RDM, srednja vrednost Reactions:  0.6112365591397849
# RDM, medijan vrednost Reactions:  0.6133333333333334
#
# CDM, srednja vrednost Reactions:  0.5650773558368496
# CDM, medijan vrednost Reactions:  0.5733333333333334
#
# LDM, srednja vrednost Reactions:  0.6046090534979425
# LDM, medijan vrednost Reactions:  0.6133333333333334
#
# RM, srednja vrednost Reactions:  0.5362633451957295
# RM, medijan vrednost Reactions:  0.5466666666666667
#
# RCM, srednja vrednost Reactions:  0.6085592497868714
# RCM, medijan vrednost Reactions:  0.6133333333333334
#
# CM, srednja vrednost Reactions:  0.5388330942132951
# CM, medijan vrednost Reactions:  0.5333333333333333
#
# LCM, srednja vrednost Reactions:  0.6041181434599157
# LCM, medijan vrednost Reactions:  0.6
#
# LM, srednja vrednost Reactions:  0.5367184170471843
# LM, medijan vrednost Reactions:  0.5466666666666667
#
# RAM, srednja vrednost Reactions:  0.6590476190476191
# RAM, medijan vrednost Reactions:  0.6666666666666667
#
# CAM, srednja vrednost Reactions:  0.5478775226165623
# CAM, medijan vrednost Reactions:  0.5466666666666667
#
# ODBRANA:
# RWB, srednja vrednost Reactions:  0.528888888888889
# RWB, medijan vrednost Reactions:  0.52
#
# RB, srednja vrednost Reactions:  0.552873741285825
# RB, medijan vrednost Reactions:  0.5466666666666667
#
# RCB, srednja vrednost Reactions:  0.5703726082578047
# RCB, medijan vrednost Reactions:  0.5733333333333334
#
# CB, srednja vrednost Reactions:  0.5053543307086614
# CB, medijan vrednost Reactions:  0.5066666666666667
#
# LCB, srednja vrednost Reactions:  0.5685185185185185
# LCB, medijan vrednost Reactions:  0.56
#
# LB, srednja vrednost Reactions:  0.5513464447806354
# LB, medijan vrednost Reactions:  0.5466666666666667
#
# LWB, srednja vrednost Reactions:  0.5588034188034188
# LWB, medijan vrednost Reactions:  0.5466666666666667

# %%
show_mean_and_median_for_each_team_position(df, 'Jumping')
# Out:
# GK, srednja vrednost Jumping:  0.5337283950617285
# GK, medijan vrednost Jumping:  0.55
#
# NAPAD:
# RF, srednja vrednost Jumping:  0.58984375
# RF, medijan vrednost Jumping:  0.6062500000000001
#
# CF, srednja vrednost Jumping:  0.6173986486486487
# CF, medijan vrednost Jumping:  0.625
#
# LF, srednja vrednost Jumping:  0.7033333333333334
# LF, medijan vrednost Jumping:  0.75
#
# RS, srednja vrednost Jumping:  0.6859605911330049
# RS, medijan vrednost Jumping:  0.7000000000000001
#
# ST, srednja vrednost Jumping:  0.6620608767371043
# ST, medijan vrednost Jumping:  0.6625000000000001
#
# LS, srednja vrednost Jumping:  0.6783816425120773
# LS, medijan vrednost Jumping:  0.6875
#
# LW, srednja vrednost Jumping:  0.5576771653543308
# LW, medijan vrednost Jumping:  0.5625
#
# RW, srednja vrednost Jumping:  0.5588175675675676
# RW, medijan vrednost Jumping:  0.5687500000000001
#
# VEZNI RED:
# RDM, srednja vrednost Jumping:  0.6641633064516128
# RDM, medijan vrednost Jumping:  0.6625000000000001
#
# CDM, srednja vrednost Jumping:  0.6410469409282702
# CDM, medijan vrednost Jumping:  0.6375000000000001
#
# LDM, srednja vrednost Jumping:  0.6263374485596709
# LDM, medijan vrednost Jumping:  0.6375000000000001
#
# RM, srednja vrednost Jumping:  0.5917259786476868
# RM, medijan vrednost Jumping:  0.6000000000000001
#
# RCM, srednja vrednost Jumping:  0.6325447570332481
# RCM, medijan vrednost Jumping:  0.6375000000000001
#
# CM, srednja vrednost Jumping:  0.5931043758967003
# CM, medijan vrednost Jumping:  0.5875
#
# LCM, srednja vrednost Jumping:  0.6260443037974684
# LCM, medijan vrednost Jumping:  0.6375000000000001
#
# LM, srednja vrednost Jumping:  0.5909703196347033
# LM, medijan vrednost Jumping:  0.6000000000000001
#
# RAM, srednja vrednost Jumping:  0.5916666666666668
# RAM, medijan vrednost Jumping:  0.65
#
# CAM, srednja vrednost Jumping:  0.564848643006263
# CAM, medijan vrednost Jumping:  0.55
#
# ODBRANA:
# RWB, srednja vrednost Jumping:  0.6474137931034483
# RWB, medijan vrednost Jumping:  0.65
#
# RB, srednja vrednost Jumping:  0.6677478698683192
# RB, medijan vrednost Jumping:  0.675
#
# RCB, srednja vrednost Jumping:  0.6994901812688822
# RCB, medijan vrednost Jumping:  0.7125
#
# CB, srednja vrednost Jumping:  0.6783605174353206
# CB, medijan vrednost Jumping:  0.7000000000000001
#
# LCB, srednja vrednost Jumping:  0.7042245370370371
# LCB, medijan vrednost Jumping:  0.7250000000000001
#
# LB, srednja vrednost Jumping:  0.6578857791225418
# LB, medijan vrednost Jumping:  0.6625000000000001
#
# LWB, srednja vrednost Jumping:  0.6690705128205129
# LWB, medijan vrednost Jumping:  0.675

# %%
show_mean_and_median_for_each_team_position(df, 'Strength')
# Out:
# GK, srednja vrednost Strength:  0.545037037037037
# GK, medijan vrednost Strength:  0.5625
#
# NAPAD:
# RF, srednja vrednost Strength:  0.5796875
# RF, medijan vrednost Strength:  0.55625
#
# CF, srednja vrednost Strength:  0.5045608108108108
# CF, medijan vrednost Strength:  0.525
#
# LF, srednja vrednost Strength:  0.5675000000000001
# LF, medijan vrednost Strength:  0.5875
#
# RS, srednja vrednost Strength:  0.6884236453201971
# RS, medijan vrednost Strength:  0.7000000000000001
#
# ST, srednja vrednost Strength:  0.6484627847697957
# ST, medijan vrednost Strength:  0.6625
#
# LS, srednja vrednost Strength:  0.685990338164251
# LS, medijan vrednost Strength:  0.6875
#
# LW, srednja vrednost Strength:  0.49534120734908144
# LW, medijan vrednost Strength:  0.5125000000000001
#
# RW, srednja vrednost Strength:  0.4849662162162162
# RW, medijan vrednost Strength:  0.5125000000000001
#
# VEZNI RED:
# RDM, srednja vrednost Strength:  0.6695060483870968
# RDM, medijan vrednost Strength:  0.6875
#
# CDM, srednja vrednost Strength:  0.6419303797468354
# CDM, medijan vrednost Strength:  0.65
#
# LDM, srednja vrednost Strength:  0.640277777777778
# LDM, medijan vrednost Strength:  0.65
#
# RM, srednja vrednost Strength:  0.5123443060498221
# RM, medijan vrednost Strength:  0.5375
#
# RCM, srednja vrednost Strength:  0.6240728900255755
# RCM, medijan vrednost Strength:  0.6375000000000001
#
# CM, srednja vrednost Strength:  0.5545552367288379
# CM, medijan vrednost Strength:  0.5750000000000001
#
# LCM, srednja vrednost Strength:  0.610632911392405
# LCM, medijan vrednost Strength:  0.625
#
# LM, srednja vrednost Strength:  0.5127968036529681
# LM, medijan vrednost Strength:  0.5375
#
# RAM, srednja vrednost Strength:  0.46488095238095245
# RAM, medijan vrednost Strength:  0.475
#
# CAM, srednja vrednost Strength:  0.4918058455114822
# CAM, medijan vrednost Strength:  0.5
#
# ODBRANA:
# RWB, srednja vrednost Strength:  0.590948275862069
# RWB, medijan vrednost Strength:  0.6
#
# RB, srednja vrednost Strength:  0.6002033307513555
# RB, medijan vrednost Strength:  0.6125
#
# RCB, srednja vrednost Strength:  0.7688066465256798
# RCB, medijan vrednost Strength:  0.7625000000000001
#
# CB, srednja vrednost Strength:  0.7169010123734534
# CB, medijan vrednost Strength:  0.725
#
# LCB, srednja vrednost Strength:  0.7637345679012345
# LCB, medijan vrednost Strength:  0.7625000000000001
#
# LB, srednja vrednost Strength:  0.5914807110438729
# LB, medijan vrednost Strength:  0.6
#
# LWB, srednja vrednost Strength:  0.5982371794871795
# LWB, medijan vrednost Strength:  0.6125

# %% [markdown]
# ## Parametri koji golmane čine "inferiornijim" u odnosu na igrače na ostalim pozicijama

# %%
show_mean_and_median_for_each_team_position(df, 'Special')
# Out:
# GK, srednja vrednost Special:  0.19517333639108667
# GK, medijan vrednost Special:  0.20371517027863778
#
# NAPAD:
# RF, srednja vrednost Special:  0.6937693498452012
# RF, medijan vrednost Special:  0.6705882352941177
#
# CF, srednja vrednost Special:  0.5785038908877919
# CF, medijan vrednost Special:  0.5668730650154798
#
# LF, srednja vrednost Special:  0.706295149638803
# LF, medijan vrednost Special:  0.6575851393188854
#
# RS, srednja vrednost Special:  0.6080983391541734
# RS, medijan vrednost Special:  0.6167182662538699
#
# ST, srednja vrednost Special:  0.5383259899562757
# ST, medijan vrednost Special:  0.5380804953560372
#
# LS, srednja vrednost Special:  0.6118394878927925
# LS, medijan vrednost Special:  0.6068111455108358
#
# LW, srednja vrednost Special:  0.5875852205780778
# LW, medijan vrednost Special:  0.5894736842105264
#
# RW, srednja vrednost Special:  0.5885967701447578
# RW, medijan vrednost Special:  0.5873065015479876
#
# VEZNI RED:
# RDM, srednja vrednost Special:  0.6737191650853889
# RDM, medijan vrednost Special:  0.6749226006191951
#
# CDM, srednja vrednost Special:  0.6139279695889015
# CDM, medijan vrednost Special:  0.6142414860681114
#
# LDM, srednja vrednost Special:  0.6629948145600021
# LDM, medijan vrednost Special:  0.6643962848297214
#
# RM, srednja vrednost Special:  0.5985247292398884
# RM, medijan vrednost Special:  0.5996904024767802
#
# RCM, srednja vrednost Special:  0.6823545247955151
# RCM, medijan vrednost Special:  0.6823529411764706
#
# CM, srednja vrednost Special:  0.6070976453709174
# CM, medijan vrednost Special:  0.603095975232198
#
# LCM, srednja vrednost Special:  0.6808026021867775
# LCM, medijan vrednost Special:  0.6823529411764706
#
# LM, srednja vrednost Special:  0.602632851265957
# LM, medijan vrednost Special:  0.6037151702786379
#
# RAM, srednja vrednost Special:  0.6709715465133422
# RAM, medijan vrednost Special:  0.6507739938080495
#
# CAM, srednja vrednost Special:  0.607531169813272
# CAM, medijan vrednost Special:  0.6102167182662538
#
# ODBRANA:
# RWB, srednja vrednost Special:  0.5913810896409382
# RWB, medijan vrednost Special:  0.5814241486068112
#
# RB, srednja vrednost Special:  0.5995352439969016
# RB, medijan vrednost Special:  0.5993808049535603
#
# RCB, srednja vrednost Special:  0.5237828888909675
# RCB, medijan vrednost Special:  0.5226006191950465
#
# CB, srednja vrednost Special:  0.46834757110469555
# CB, medijan vrednost Special:  0.4588235294117647
#
# LCB, srednja vrednost Special:  0.5314843481252151
# LCB, medijan vrednost Special:  0.5256965944272447
#
# LB, srednja vrednost Special:  0.6030575682777292
# LB, medijan vrednost Special:  0.6043343653250774
#
# LWB, srednja vrednost Special:  0.624220052393427
# LWB, medijan vrednost Special:  0.6232198142414861

# %%
show_mean_and_median_for_each_team_position(df, 'Skill Moves')
# Out:
# GK, srednja vrednost Skill Moves:  0.0
# GK, medijan vrednost Skill Moves:  0.0
#
# NAPAD:
# RF, srednja vrednost Skill Moves:  0.578125
# RF, medijan vrednost Skill Moves:  0.5
#
# CF, srednja vrednost Skill Moves:  0.4831081081081081
# CF, medijan vrednost Skill Moves:  0.5
#
# LF, srednja vrednost Skill Moves:  0.6
# LF, medijan vrednost Skill Moves:  0.5
#
# RS, srednja vrednost Skill Moves:  0.44950738916256155
# RS, medijan vrednost Skill Moves:  0.5
#
# ST, srednja vrednost Skill Moves:  0.38498449426091225
# ST, medijan vrednost Skill Moves:  0.34032711052370723
#
# LS, srednja vrednost Skill Moves:  0.4553140096618358
# LS, medijan vrednost Skill Moves:  0.5
#
# LW, srednja vrednost Skill Moves:  0.5111548556430446
# LW, medijan vrednost Skill Moves:  0.5
#
# RW, srednja vrednost Skill Moves:  0.5027027027027027
# RW, medijan vrednost Skill Moves:  0.5
#
# VEZNI RED:
# RDM, srednja vrednost Skill Moves:  0.39314516129032256
# RDM, medijan vrednost Skill Moves:  0.5
#
# CDM, srednja vrednost Skill Moves:  0.3314873417721519
# CDM, medijan vrednost Skill Moves:  0.25
#
# LDM, srednja vrednost Skill Moves:  0.39814814814814814
# LDM, medijan vrednost Skill Moves:  0.5
#
# RM, srednja vrednost Skill Moves:  0.47597864768683273
# RM, medijan vrednost Skill Moves:  0.5
#
# RCM, srednja vrednost Skill Moves:  0.440537084398977
# RCM, medijan vrednost Skill Moves:  0.5
#
# CM, srednja vrednost Skill Moves:  0.38432568149210905
# CM, medijan vrednost Skill Moves:  0.5
#
# LCM, srednja vrednost Skill Moves:  0.4449367088607595
# LCM, medijan vrednost Skill Moves:  0.5
#
# LM, srednja vrednost Skill Moves:  0.47990867579908675
# LM, medijan vrednost Skill Moves:  0.5
#
# RAM, srednja vrednost Skill Moves:  0.5714285714285714
# RAM, medijan vrednost Skill Moves:  0.5
#
# CAM, srednja vrednost Skill Moves:  0.49086638830897705
# CAM, medijan vrednost Skill Moves:  0.5
#
# ODBRANA:
# RWB, srednja vrednost Skill Moves:  0.3448275862068966
# RWB, medijan vrednost Skill Moves:  0.25
#
# RB, srednja vrednost Skill Moves:  0.35147172734314486
# RB, medijan vrednost Skill Moves:  0.25
#
# RCB, srednja vrednost Skill Moves:  0.25944108761329304
# RCB, medijan vrednost Skill Moves:  0.25
#
# CB, srednja vrednost Skill Moves:  0.2544994375703037
# CB, medijan vrednost Skill Moves:  0.25
#
# LCB, srednja vrednost Skill Moves:  0.26157407407407407
# LCB, medijan vrednost Skill Moves:  0.25
#
# LB, srednja vrednost Skill Moves:  0.3557110438729198
# LB, medijan vrednost Skill Moves:  0.25
#
# LWB, srednja vrednost Skill Moves:  0.3782051282051282
# LWB, medijan vrednost Skill Moves:  0.25

# %%
show_mean_and_median_for_each_team_position(df, 'Crossing')
# Out:
# GK, srednja vrednost Crossing:  0.10519640852974185
# GK, medijan vrednost Crossing:  0.09090909090909091
#
# NAPAD:
# RF, srednja vrednost Crossing:  0.7215909090909091
# RF, medijan vrednost Crossing:  0.7045454545454545
#
# CF, srednja vrednost Crossing:  0.5658783783783784
# CF, medijan vrednost Crossing:  0.5681818181818181
#
# LF, srednja vrednost Crossing:  0.7106060606060608
# LF, medijan vrednost Crossing:  0.6818181818181819
#
# RS, srednja vrednost Crossing:  0.5361621137483207
# RS, medijan vrednost Crossing:  0.5568181818181819
#
# ST, srednja vrednost Crossing:  0.46838649056328807
# ST, medijan vrednost Crossing:  0.4659090909090909
#
# LS, srednja vrednost Crossing:  0.550175669740887
# LS, medijan vrednost Crossing:  0.5681818181818181
#
# LW, srednja vrednost Crossing:  0.6406585540443808
# LW, medijan vrednost Crossing:  0.6477272727272727
#
# RW, srednja vrednost Crossing:  0.6489250614250615
# RW, medijan vrednost Crossing:  0.6590909090909092
#
# VEZNI RED:
# RDM, srednja vrednost Crossing:  0.5858687683284458
# RDM, medijan vrednost Crossing:  0.5965909090909091
#
# CDM, srednja vrednost Crossing:  0.5355293440736479
# CDM, medijan vrednost Crossing:  0.5340909090909092
#
# LDM, srednja vrednost Crossing:  0.5937616909839131
# LDM, medijan vrednost Crossing:  0.6022727272727273
#
# RM, srednja vrednost Crossing:  0.6530350210287934
# RM, medijan vrednost Crossing:  0.6590909090909092
#
# RCM, srednja vrednost Crossing:  0.6276447337828412
# RCM, medijan vrednost Crossing:  0.625
#
# CM, srednja vrednost Crossing:  0.5643912221207774
# CM, medijan vrednost Crossing:  0.5681818181818181
#
# LCM, srednja vrednost Crossing:  0.62885500575374
# LCM, medijan vrednost Crossing:  0.6477272727272727
#
# LM, srednja vrednost Crossing:  0.6559049398090494
# LM, medijan vrednost Crossing:  0.6590909090909092
#
# RAM, srednja vrednost Crossing:  0.7207792207792207
# RAM, medijan vrednost Crossing:  0.75
#
# CAM, srednja vrednost Crossing:  0.621310969823496
# CAM, medijan vrednost Crossing:  0.6363636363636365
#
# ODBRANA:
# RWB, srednja vrednost Crossing:  0.6430250783699059
# RWB, medijan vrednost Crossing:  0.6477272727272727
#
# RB, srednja vrednost Crossing:  0.6539504260263361
# RB, medijan vrednost Crossing:  0.6590909090909092
#
# RCB, srednja vrednost Crossing:  0.4165922823400165
# RCB, medijan vrednost Crossing:  0.39772727272727276
#
# CB, srednja vrednost Crossing:  0.3856158605174354
# CB, medijan vrednost Crossing:  0.3522727272727273
#
# LCB, srednja vrednost Crossing:  0.4441287878787878
# LCB, medijan vrednost Crossing:  0.4318181818181818
#
# LB, srednja vrednost Crossing:  0.6637326365011691
# LB, medijan vrednost Crossing:  0.6704545454545454
#
# LWB, srednja vrednost Crossing:  0.6756993006993008
# LWB, medijan vrednost Crossing:  0.6704545454545454

# %%
show_mean_and_median_for_each_team_position(df, 'Finishing')
# Out:
# GK, srednja vrednost Finishing:  0.10770211071286338
# GK, medijan vrednost Finishing:  0.1075268817204301
#
# NAPAD:
# RF, srednja vrednost Finishing:  0.7358870967741936
# RF, medijan vrednost Finishing:  0.7043010752688172
#
# CF, srednja vrednost Finishing:  0.6732054635280443
# CF, medijan vrednost Finishing:  0.6720430107526882
#
# LF, srednja vrednost Finishing:  0.7240143369175628
# LF, medijan vrednost Finishing:  0.7204301075268817
#
# RS, srednja vrednost Finishing:  0.7276338789130782
# RS, medijan vrednost Finishing:  0.7204301075268817
#
# ST, srednja vrednost Finishing:  0.6866721292796981
# ST, medijan vrednost Finishing:  0.6881720430107527
#
# LS, srednja vrednost Finishing:  0.7298841618617214
# LS, medijan vrednost Finishing:  0.7204301075268817
#
# LW, srednja vrednost Finishing:  0.6432986199305734
# LW, medijan vrednost Finishing:  0.6451612903225807
#
# RW, srednja vrednost Finishing:  0.6489973844812557
# RW, medijan vrednost Finishing:  0.6451612903225807
#
# VEZNI RED:
# RDM, srednja vrednost Finishing:  0.5294831772459244
# RDM, medijan vrednost Finishing:  0.5376344086021506
#
# CDM, srednja vrednost Finishing:  0.45600244997958356
# CDM, medijan vrednost Finishing:  0.4516129032258065
#
# LDM, srednja vrednost Finishing:  0.5232974910394266
# LDM, medijan vrednost Finishing:  0.5376344086021506
#
# RM, srednja vrednost Finishing:  0.6139077029043739
# RM, medijan vrednost Finishing:  0.6236559139784947
#
# RCM, srednja vrednost Finishing:  0.5739350438632678
# RCM, medijan vrednost Finishing:  0.5913978494623656
#
# CM, srednja vrednost Finishing:  0.5150182811126025
# CM, medijan vrednost Finishing:  0.5161290322580646
#
# LCM, srednja vrednost Finishing:  0.5774329658363959
# LCM, medijan vrednost Finishing:  0.5806451612903226
#
# LM, srednja vrednost Finishing:  0.6172828595276675
# LM, medijan vrednost Finishing:  0.6236559139784947
#
# RAM, srednja vrednost Finishing:  0.6569380440348183
# RAM, medijan vrednost Finishing:  0.6774193548387097
#
# CAM, srednja vrednost Finishing:  0.6176622443711137
# CAM, medijan vrednost Finishing:  0.6236559139784947
#
# ODBRANA:
# RWB, srednja vrednost Finishing:  0.42825361512791993
# RWB, medijan vrednost Finishing:  0.4516129032258065
#
# RB, srednja vrednost Finishing:  0.40492907890024404
# RB, medijan vrednost Finishing:  0.39784946236559143
#
# RCB, srednja vrednost Finishing:  0.3257967059740766
# RCB, medijan vrednost Finishing:  0.31182795698924737
#
# CB, srednja vrednost Finishing:  0.2958319726163262
# CB, medijan vrednost Finishing:  0.2688172043010753
#
# LCB, srednja vrednost Finishing:  0.3258661887694146
# LCB, medijan vrednost Finishing:  0.31182795698924737
#
# LB, srednja vrednost Finishing:  0.4078457208855921
# LB, medijan vrednost Finishing:  0.39784946236559143
#
# LWB, srednja vrednost Finishing:  0.4363110008271299
# LWB, medijan vrednost Finishing:  0.4301075268817205

# %%
show_mean_and_median_for_each_team_position(df, 'HeadingAccuracy')
# Out:
# GK, srednja vrednost HeadingAccuracy:  0.11520987654320987
# GK, medijan vrednost HeadingAccuracy:  0.1111111111111111
#
# NAPAD:
# RF, srednja vrednost HeadingAccuracy:  0.563888888888889
# RF, medijan vrednost HeadingAccuracy:  0.5611111111111112
#
# CF, srednja vrednost HeadingAccuracy:  0.5560060060060061
# CF, medijan vrednost HeadingAccuracy:  0.5611111111111111
#
# LF, srednja vrednost HeadingAccuracy:  0.5607407407407409
# LF, medijan vrednost HeadingAccuracy:  0.6000000000000001
#
# RS, srednja vrednost HeadingAccuracy:  0.6733990147783252
# RS, medijan vrednost HeadingAccuracy:  0.688888888888889
#
# ST, srednja vrednost HeadingAccuracy:  0.6555822328722366
# ST, medijan vrednost HeadingAccuracy:  0.6555555555555557
#
# LS, srednja vrednost HeadingAccuracy:  0.6703166935050995
# LS, medijan vrednost HeadingAccuracy:  0.6777777777777778
#
# LW, srednja vrednost HeadingAccuracy:  0.504666083406241
# LW, medijan vrednost HeadingAccuracy:  0.5000000000000001
#
# RW, srednja vrednost HeadingAccuracy:  0.5020120120120121
# RW, medijan vrednost HeadingAccuracy:  0.5000000000000001
#
# VEZNI RED:
# RDM, srednja vrednost HeadingAccuracy:  0.6131720430107527
# RDM, medijan vrednost HeadingAccuracy:  0.6111111111111112
#
# CDM, srednja vrednost HeadingAccuracy:  0.5907172995780592
# CDM, medijan vrednost HeadingAccuracy:  0.5888888888888889
#
# LDM, srednja vrednost HeadingAccuracy:  0.5976680384087792
# LDM, medijan vrednost HeadingAccuracy:  0.6000000000000001
#
# RM, srednja vrednost HeadingAccuracy:  0.5029853697113484
# RM, medijan vrednost HeadingAccuracy:  0.5000000000000001
#
# RCM, srednja vrednost HeadingAccuracy:  0.5699630576868429
# RCM, medijan vrednost HeadingAccuracy:  0.5777777777777778
#
# CM, srednja vrednost HeadingAccuracy:  0.5302725968436155
# CM, medijan vrednost HeadingAccuracy:  0.5222222222222223
#
# LCM, srednja vrednost HeadingAccuracy:  0.5642756680731364
# LCM, medijan vrednost HeadingAccuracy:  0.5666666666666668
#
# LM, srednja vrednost HeadingAccuracy:  0.4998477929984781
# LM, medijan vrednost HeadingAccuracy:  0.4888888888888889
#
# RAM, srednja vrednost HeadingAccuracy:  0.5132275132275133
# RAM, medijan vrednost HeadingAccuracy:  0.5000000000000001
#
# CAM, srednja vrednost HeadingAccuracy:  0.5000811876594757
# CAM, medijan vrednost HeadingAccuracy:  0.4888888888888889
#
# ODBRANA:
# RWB, srednja vrednost HeadingAccuracy:  0.5344827586206896
# RWB, medijan vrednost HeadingAccuracy:  0.5444444444444445
#
# RB, srednja vrednost HeadingAccuracy:  0.5799294259402702
# RB, medijan vrednost HeadingAccuracy:  0.5888888888888889
#
# RCB, srednja vrednost HeadingAccuracy:  0.7176233635448138
# RCB, medijan vrednost HeadingAccuracy:  0.7222222222222223
#
# CB, srednja vrednost HeadingAccuracy:  0.6659042619672542
# CB, medijan vrednost HeadingAccuracy:  0.6666666666666667
#
# LCB, srednja vrednost HeadingAccuracy:  0.7141975308641977
# LCB, medijan vrednost HeadingAccuracy:  0.7111111111111111
#
# LB, srednja vrednost HeadingAccuracy:  0.5734493192133132
# LB, medijan vrednost HeadingAccuracy:  0.5777777777777778
#
# LWB, srednja vrednost HeadingAccuracy:  0.556980056980057
# LWB, medijan vrednost HeadingAccuracy:  0.5611111111111111

# %%
show_mean_and_median_for_each_team_position(df, 'ShortPassing')
# Out:
# GK, srednja vrednost ShortPassing:  0.2356876256101062
# GK, medijan vrednost ShortPassing:  0.23255813953488372
#
# NAPAD:
# RF, srednja vrednost ShortPassing:  0.7492732558139534
# RF, medijan vrednost ShortPassing:  0.7383720930232558
#
# CF, srednja vrednost ShortPassing:  0.6555625392834695
# CF, medijan vrednost ShortPassing:  0.6395348837209301
#
# LF, srednja vrednost ShortPassing:  0.7620155038759688
# LF, medijan vrednost ShortPassing:  0.7674418604651162
#
# RS, srednja vrednost ShortPassing:  0.6434299461564899
# RS, medijan vrednost ShortPassing:  0.6511627906976744
#
# ST, srednja vrednost ShortPassing:  0.5880659519298553
# ST, medijan vrednost ShortPassing:  0.5930232558139534
#
# LS, srednja vrednost ShortPassing:  0.6513313110886416
# LS, medijan vrednost ShortPassing:  0.6627906976744186
#
# LW, srednja vrednost ShortPassing:  0.6533601904413111
# LW, medijan vrednost ShortPassing:  0.6627906976744186
#
# RW, srednja vrednost ShortPassing:  0.6608108108108108
# RW, medijan vrednost ShortPassing:  0.6627906976744186
#
# VEZNI RED:
# RDM, srednja vrednost ShortPassing:  0.7416541635408851
# RDM, medijan vrednost ShortPassing:  0.7441860465116279
#
# CDM, srednja vrednost ShortPassing:  0.7057084682563045
# CDM, medijan vrednost ShortPassing:  0.7093023255813953
#
# LDM, srednja vrednost ShortPassing:  0.7358120394296105
# LDM, medijan vrednost ShortPassing:  0.7325581395348837
#
# RM, srednja vrednost ShortPassing:  0.6606285690639742
# RM, medijan vrednost ShortPassing:  0.6627906976744186
#
# RCM, srednja vrednost ShortPassing:  0.7405281627312199
# RCM, medijan vrednost ShortPassing:  0.7441860465116279
#
# CM, srednja vrednost ShortPassing:  0.703847052150412
# CM, medijan vrednost ShortPassing:  0.6976744186046511
#
# LCM, srednja vrednost ShortPassing:  0.7435678539888135
# LCM, medijan vrednost ShortPassing:  0.7325581395348837
#
# LM, srednja vrednost ShortPassing:  0.6655622809812043
# LM, medijan vrednost ShortPassing:  0.6627906976744186
#
# RAM, srednja vrednost ShortPassing:  0.7580287929125137
# RAM, medijan vrednost ShortPassing:  0.755813953488372
#
# CAM, srednja vrednost ShortPassing:  0.7037675389619847
# CAM, medijan vrednost ShortPassing:  0.7093023255813953
#
# ODBRANA:
# RWB, srednja vrednost ShortPassing:  0.6265704357123765
# RWB, medijan vrednost ShortPassing:  0.6395348837209301
#
# RB, srednja vrednost ShortPassing:  0.6358510619134257
# RB, medijan vrednost ShortPassing:  0.6511627906976744
#
# RCB, srednja vrednost ShortPassing:  0.6115716995714185
# RCB, medijan vrednost ShortPassing:  0.6162790697674418
#
# CB, srednja vrednost ShortPassing:  0.5589112407460696
# CB, medijan vrednost ShortPassing:  0.5813953488372092
#
# LCB, srednja vrednost ShortPassing:  0.6192578237151881
# LCB, medijan vrednost ShortPassing:  0.627906976744186
#
# LB, srednja vrednost ShortPassing:  0.6317067163916547
# LB, medijan vrednost ShortPassing:  0.6511627906976744
#
# LWB, srednja vrednost ShortPassing:  0.6414728682170543
# LWB, medijan vrednost ShortPassing:  0.6337209302325582

# %%
show_mean_and_median_for_each_team_position(df, 'Volleys')
# Out:
# GK, srednja vrednost Volleys:  0.09763996554694229
# GK, medijan vrednost Volleys:  0.09302325581395349
#
# NAPAD:
# RF, srednja vrednost Volleys:  0.7129360465116279
# RF, medijan vrednost Volleys:  0.6918604651162791
#
# CF, srednja vrednost Volleys:  0.6379635449402893
# CF, medijan vrednost Volleys:  0.627906976744186
#
# LF, srednja vrednost Volleys:  0.7085271317829457
# LF, medijan vrednost Volleys:  0.6976744186046512
#
# RS, srednja vrednost Volleys:  0.6751059686103793
# RS, medijan vrednost Volleys:  0.686046511627907
#
# ST, srednja vrednost Volleys:  0.6167502483268632
# ST, medijan vrednost Volleys:  0.627906976744186
#
# LS, srednja vrednost Volleys:  0.6873385012919896
# LS, medijan vrednost Volleys:  0.686046511627907
#
# LW, srednja vrednost Volleys:  0.5973570164194593
# LW, medijan vrednost Volleys:  0.5930232558139535
#
# RW, srednja vrednost Volleys:  0.5970773098680076
# RW, medijan vrednost Volleys:  0.5930232558139535
#
# VEZNI RED:
# RDM, srednja vrednost Volleys:  0.5237246811702926
# RDM, medijan vrednost Volleys:  0.5116279069767442
#
# CDM, srednja vrednost Volleys:  0.4576709842017467
# CDM, medijan vrednost Volleys:  0.4418604651162791
#
# LDM, srednja vrednost Volleys:  0.5079911953296966
# LDM, medijan vrednost Volleys:  0.5
#
# RM, srednja vrednost Volleys:  0.5706260862368617
# RM, medijan vrednost Volleys:  0.5697674418604651
#
# RCM, srednja vrednost Volleys:  0.5720573365847856
# RCM, medijan vrednost Volleys:  0.5697674418604651
#
# CM, srednja vrednost Volleys:  0.5112358613326216
# CM, medijan vrednost Volleys:  0.4883720930232558
#
# LCM, srednja vrednost Volleys:  0.5637621430674125
# LCM, medijan vrednost Volleys:  0.5581395348837209
#
# LM, srednja vrednost Volleys:  0.5732823616863121
# LM, medijan vrednost Volleys:  0.5813953488372093
#
# RAM, srednja vrednost Volleys:  0.682170542635659
# RAM, medijan vrednost Volleys:  0.7093023255813954
#
# CAM, srednja vrednost Volleys:  0.6007913773850562
# CAM, medijan vrednost Volleys:  0.6046511627906977
#
# ODBRANA:
# RWB, srednja vrednost Volleys:  0.4179363806468858
# RWB, medijan vrednost Volleys:  0.41860465116279066
#
# RB, srednja vrednost Volleys:  0.40731900635887086
# RB, medijan vrednost Volleys:  0.38372093023255816
#
# RCB, srednja vrednost Volleys:  0.34449870020375184
# RCB, medijan vrednost Volleys:  0.32558139534883723
#
# CB, srednja vrednost Volleys:  0.3209380804143668
# CB, medijan vrednost Volleys:  0.3023255813953488
#
# LCB, srednja vrednost Volleys:  0.3419824863623313
# LCB, medijan vrednost Volleys:  0.313953488372093
#
# LB, srednja vrednost Volleys:  0.41026633360306786
# LB, medijan vrednost Volleys:  0.38372093023255816
#
# LWB, srednja vrednost Volleys:  0.43395945140131187
# LWB, medijan vrednost Volleys:  0.41279069767441856

# %%
show_mean_and_median_for_each_team_position(df, 'Dribbling')
# Out:
# GK, srednja vrednost Dribbling:  0.10598168060533653
# GK, medijan vrednost Dribbling:  0.09677419354838711
#
# NAPAD:
# RF, srednja vrednost Dribbling:  0.7412634408602151
# RF, medijan vrednost Dribbling:  0.6989247311827957
#
# CF, srednja vrednost Dribbling:  0.695437372856728
# CF, medijan vrednost Dribbling:  0.6881720430107527
#
# LF, srednja vrednost Dribbling:  0.7813620071684588
# LF, medijan vrednost Dribbling:  0.7634408602150539
#
# RS, srednja vrednost Dribbling:  0.6742941893108748
# RS, medijan vrednost Dribbling:  0.6881720430107527
#
# ST, srednja vrednost Dribbling:  0.6286327170909239
# ST, medijan vrednost Dribbling:  0.6344086021505377
#
# LS, srednja vrednost Dribbling:  0.6855228299828582
# LS, medijan vrednost Dribbling:  0.6881720430107527
#
# LW, srednja vrednost Dribbling:  0.7074478593401633
# LW, medijan vrednost Dribbling:  0.7096774193548389
#
# RW, srednja vrednost Dribbling:  0.7097936646323744
# RW, medijan vrednost Dribbling:  0.7096774193548389
#
# VEZNI RED:
# RDM, srednja vrednost Dribbling:  0.6386576482830387
# RDM, medijan vrednost Dribbling:  0.6451612903225807
#
# CDM, srednja vrednost Dribbling:  0.5965700285830954
# CDM, medijan vrednost Dribbling:  0.6021505376344087
#
# LDM, srednja vrednost Dribbling:  0.6429488030443825
# LDM, medijan vrednost Dribbling:  0.6451612903225807
#
# RM, srednja vrednost Dribbling:  0.6899801017870127
# RM, medijan vrednost Dribbling:  0.6881720430107527
#
# RCM, srednja vrednost Dribbling:  0.6685091989109812
# RCM, medijan vrednost Dribbling:  0.6666666666666667
#
# CM, srednja vrednost Dribbling:  0.6304824053933141
# CM, medijan vrednost Dribbling:  0.6344086021505377
#
# LCM, srednja vrednost Dribbling:  0.6735266095004766
# LCM, medijan vrednost Dribbling:  0.6774193548387097
#
# LM, srednja vrednost Dribbling:  0.6948298718515247
# LM, medijan vrednost Dribbling:  0.6881720430107527
#
# RAM, srednja vrednost Dribbling:  0.7496159754224271
# RAM, medijan vrednost Dribbling:  0.7419354838709679
#
# CAM, srednja vrednost Dribbling:  0.68935057355153
# CAM, medijan vrednost Dribbling:  0.6881720430107527
#
# ODBRANA:
# RWB, srednja vrednost Dribbling:  0.617599802249413
# RWB, medijan vrednost Dribbling:  0.6236559139784947
#
# RB, srednja vrednost Dribbling:  0.6154518877589267
# RB, medijan vrednost Dribbling:  0.6236559139784947
#
# RCB, srednja vrednost Dribbling:  0.45414676932072895
# RCB, medijan vrednost Dribbling:  0.46774193548387094
#
# CB, srednja vrednost Dribbling:  0.41223072922336323
# CB, medijan vrednost Dribbling:  0.40860215053763443
#
# LCB, srednja vrednost Dribbling:  0.4656013540422143
# LCB, medijan vrednost Dribbling:  0.47311827956989244
#
# LB, srednja vrednost Dribbling:  0.6193044100662081
# LB, medijan vrednost Dribbling:  0.6236559139784947
#
# LWB, srednja vrednost Dribbling:  0.629170113041081
# LWB, medijan vrednost Dribbling:  0.6236559139784947

# %%
show_mean_and_median_for_each_team_position(df, 'Curve')
# Out:
# GK, srednja vrednost Curve:  0.09895061728395062
# GK, medijan vrednost Curve:  0.09090909090909091
#
# NAPAD:
# RF, srednja vrednost Curve:  0.7365056818181819
# RF, medijan vrednost Curve:  0.7329545454545454
#
# CF, srednja vrednost Curve:  0.6048832923832923
# CF, medijan vrednost Curve:  0.5965909090909091
#
# LF, srednja vrednost Curve:  0.7136363636363637
# LF, medijan vrednost Curve:  0.7272727272727273
#
# RS, srednja vrednost Curve:  0.5668943125839677
# RS, medijan vrednost Curve:  0.5795454545454546
#
# ST, srednja vrednost Curve:  0.5076452797265995
# ST, medijan vrednost Curve:  0.5
#
# LS, srednja vrednost Curve:  0.5741655687307861
# LS, medijan vrednost Curve:  0.5795454545454546
#
# LW, srednja vrednost Curve:  0.6037640181340969
# LW, medijan vrednost Curve:  0.6022727272727273
#
# RW, srednja vrednost Curve:  0.6034090909090909
# RW, medijan vrednost Curve:  0.6022727272727273
#
# VEZNI RED:
# RDM, srednja vrednost Curve:  0.5448130498533724
# RDM, medijan vrednost Curve:  0.5454545454545454
#
# CDM, srednja vrednost Curve:  0.49925680859225163
# CDM, medijan vrednost Curve:  0.47727272727272724
#
# LDM, srednja vrednost Curve:  0.5632248410026188
# LDM, medijan vrednost Curve:  0.5568181818181819
#
# RM, srednja vrednost Curve:  0.5921526205111615
# RM, medijan vrednost Curve:  0.6022727272727273
#
# RCM, srednja vrednost Curve:  0.6067484305975355
# RCM, medijan vrednost Curve:  0.625
#
# CM, srednja vrednost Curve:  0.5478185731055172
# CM, medijan vrednost Curve:  0.5454545454545454
#
# LCM, srednja vrednost Curve:  0.6149597238204834
# LCM, medijan vrednost Curve:  0.625
#
# LM, srednja vrednost Curve:  0.6040473225404733
# LM, medijan vrednost Curve:  0.6136363636363638
#
# RAM, srednja vrednost Curve:  0.6839826839826839
# RAM, medijan vrednost Curve:  0.6931818181818181
#
# CAM, srednja vrednost Curve:  0.6288076485101537
# CAM, medijan vrednost Curve:  0.6477272727272727
#
# ODBRANA:
# RWB, srednja vrednost Curve:  0.502742946708464
# RWB, medijan vrednost Curve:  0.5113636363636365
#
# RB, srednja vrednost Curve:  0.49667276952327305
# RB, medijan vrednost Curve:  0.5
#
# RCB, srednja vrednost Curve:  0.35896731667124415
# RCB, medijan vrednost Curve:  0.3295454545454546
#
# CB, srednja vrednost Curve:  0.32817133653747826
# CB, medijan vrednost Curve:  0.29545454545454547
#
# LCB, srednja vrednost Curve:  0.3757716049382716
# LCB, medijan vrednost Curve:  0.34090909090909094
#
# LB, srednja vrednost Curve:  0.5297930133406685
# LB, medijan vrednost Curve:  0.5454545454545454
#
# LWB, srednja vrednost Curve:  0.5585664335664335
# LWB, medijan vrednost Curve:  0.6022727272727273

# %%
show_mean_and_median_for_each_team_position(df, 'FKAccuracy')
# Out:
# GK, srednja vrednost FKAccuracy:  0.12598019264685933
# GK, medijan vrednost FKAccuracy:  0.10989010989010992
#
# NAPAD:
# RF, srednja vrednost FKAccuracy:  0.6655219780219781
# RF, medijan vrednost FKAccuracy:  0.6923076923076924
#
# CF, srednja vrednost FKAccuracy:  0.5472230472230473
# CF, medijan vrednost FKAccuracy:  0.5274725274725275
#
# LF, srednja vrednost FKAccuracy:  0.6417582417582417
# LF, medijan vrednost FKAccuracy:  0.6263736263736265
#
# RS, srednja vrednost FKAccuracy:  0.5033291831321388
# RS, medijan vrednost FKAccuracy:  0.4835164835164836
#
# ST, srednja vrednost FKAccuracy:  0.4474267797843542
# ST, medijan vrednost FKAccuracy:  0.4175824175824176
#
# LS, srednja vrednost FKAccuracy:  0.508998248128683
# LS, medijan vrednost FKAccuracy:  0.4945054945054945
#
# LW, srednja vrednost FKAccuracy:  0.532058492688414
# LW, medijan vrednost FKAccuracy:  0.5164835164835165
#
# RW, srednja vrednost FKAccuracy:  0.5353133353133354
# RW, medijan vrednost FKAccuracy:  0.5054945054945056
#
# VEZNI RED:
# RDM, srednja vrednost FKAccuracy:  0.5393920595533499
# RDM, medijan vrednost FKAccuracy:  0.5384615384615385
#
# CDM, srednja vrednost FKAccuracy:  0.49706727871284845
# CDM, medijan vrednost FKAccuracy:  0.4725274725274726
#
# LDM, srednja vrednost FKAccuracy:  0.5602134491023381
# LDM, medijan vrednost FKAccuracy:  0.5604395604395604
#
# RM, srednja vrednost FKAccuracy:  0.5300046928160808
# RM, medijan vrednost FKAccuracy:  0.5164835164835165
#
# RCM, srednja vrednost FKAccuracy:  0.581124757595346
# RCM, medijan vrednost FKAccuracy:  0.5934065934065934
#
# CM, srednja vrednost FKAccuracy:  0.5321787251485961
# CM, medijan vrednost FKAccuracy:  0.5054945054945056
#
# LCM, srednja vrednost FKAccuracy:  0.5981638614550008
# LCM, medijan vrednost FKAccuracy:  0.6153846153846154
#
# LM, srednja vrednost FKAccuracy:  0.5471624266144814
# LM, medijan vrednost FKAccuracy:  0.5384615384615385
#
# RAM, srednja vrednost FKAccuracy:  0.6739926739926742
# RAM, medijan vrednost FKAccuracy:  0.7472527472527474
#
# CAM, srednja vrednost FKAccuracy:  0.6057032737617289
# CAM, medijan vrednost FKAccuracy:  0.6153846153846154
#
# ODBRANA:
# RWB, srednja vrednost FKAccuracy:  0.4204875584185929
# RWB, medijan vrednost FKAccuracy:  0.3736263736263737
#
# RB, srednja vrednost FKAccuracy:  0.4208595432452908
# RB, medijan vrednost FKAccuracy:  0.38461538461538464
#
# RCB, srednja vrednost FKAccuracy:  0.36081139404402246
# RCB, medijan vrednost FKAccuracy:  0.3186813186813187
#
# CB, srednja vrednost FKAccuracy:  0.33701281845263853
# CB, medijan vrednost FKAccuracy:  0.3076923076923077
#
# LCB, srednja vrednost FKAccuracy:  0.36674128340795015
# LCB, medijan vrednost FKAccuracy:  0.3186813186813187
#
# LB, srednja vrednost FKAccuracy:  0.4677312097886985
# LB, medijan vrednost FKAccuracy:  0.4285714285714286
#
# LWB, srednja vrednost FKAccuracy:  0.49732318963088207
# LWB, medijan vrednost FKAccuracy:  0.521978021978022

# %%
show_mean_and_median_for_each_team_position(df, 'LongPassing')
# Out:
# GK, srednja vrednost LongPassing:  0.2000999412110523
# GK, medijan vrednost LongPassing:  0.17857142857142855
#
# NAPAD:
# RF, srednja vrednost LongPassing:  0.6614583333333333
# RF, medijan vrednost LongPassing:  0.6845238095238095
#
# CF, srednja vrednost LongPassing:  0.5381274131274131
# CF, medijan vrednost LongPassing:  0.5476190476190477
#
# LF, srednja vrednost LongPassing:  0.7111111111111111
# LF, medijan vrednost LongPassing:  0.7023809523809524
#
# RS, srednja vrednost LongPassing:  0.4822894675111424
# RS, medijan vrednost LongPassing:  0.4880952380952381
#
# ST, srednja vrednost LongPassing:  0.4252355808515921
# ST, medijan vrednost LongPassing:  0.4166666666666666
#
# LS, srednja vrednost LongPassing:  0.5025879917184265
# LS, medijan vrednost LongPassing:  0.511904761904762
#
# LW, srednja vrednost LongPassing:  0.5441507311586051
# LW, medijan vrednost LongPassing:  0.5595238095238095
#
# RW, srednja vrednost LongPassing:  0.5526061776061776
# RW, medijan vrednost LongPassing:  0.5595238095238095
#
# VEZNI RED:
# RDM, srednja vrednost LongPassing:  0.6961405529953917
# RDM, medijan vrednost LongPassing:  0.7023809523809524
#
# CDM, srednja vrednost LongPassing:  0.6565325497287522
# CDM, medijan vrednost LongPassing:  0.6547619047619048
#
# LDM, srednja vrednost LongPassing:  0.6925827944346462
# LDM, medijan vrednost LongPassing:  0.6785714285714286
#
# RM, srednja vrednost LongPassing:  0.57478605321132
# RM, medijan vrednost LongPassing:  0.5833333333333334
#
# RCM, srednja vrednost LongPassing:  0.6950127877237852
# RCM, medijan vrednost LongPassing:  0.6904761904761905
#
# CM, srednja vrednost LongPassing:  0.65662362505978
# CM, medijan vrednost LongPassing:  0.6547619047619048
#
# LCM, srednja vrednost LongPassing:  0.6968053044002411
# LCM, medijan vrednost LongPassing:  0.6904761904761905
#
# LM, srednja vrednost LongPassing:  0.5813655142422266
# LM, medijan vrednost LongPassing:  0.5833333333333334
#
# RAM, srednja vrednost LongPassing:  0.6377551020408163
# RAM, medijan vrednost LongPassing:  0.6428571428571429
#
# CAM, srednja vrednost LongPassing:  0.6374639626205387
# CAM, medijan vrednost LongPassing:  0.6428571428571429
#
# ODBRANA:
# RWB, srednja vrednost LongPassing:  0.5528188286808977
# RWB, medijan vrednost LongPassing:  0.5833333333333334
#
# RB, srednja vrednost LongPassing:  0.5502747962081811
# RB, medijan vrednost LongPassing:  0.5714285714285714
#
# RCB, srednja vrednost LongPassing:  0.5487519781326428
# RCB, medijan vrednost LongPassing:  0.5714285714285714
#
# CB, srednja vrednost LongPassing:  0.4797324441587658
# CB, medijan vrednost LongPassing:  0.49999999999999994
#
# LCB, srednja vrednost LongPassing:  0.5543430335097002
# LCB, medijan vrednost LongPassing:  0.5714285714285714
#
# LB, srednja vrednost LongPassing:  0.5512120884662488
# LB, medijan vrednost LongPassing:  0.5714285714285714
#
# LWB, srednja vrednost LongPassing:  0.5764652014652014
# LWB, medijan vrednost LongPassing:  0.5833333333333334

# %%
show_mean_and_median_for_each_team_position(df, 'BallControl')
# Out:
# GK, srednja vrednost BallControl:  0.1642816442816443
# GK, medijan vrednost BallControl:  0.16483516483516486
#
# NAPAD:
# RF, srednja vrednost BallControl:  0.7561813186813188
# RF, medijan vrednost BallControl:  0.7197802197802199
#
# CF, srednja vrednost BallControl:  0.6905256905256906
# CF, medijan vrednost BallControl:  0.6813186813186813
#
# LF, srednja vrednost BallControl:  0.78021978021978
# LF, medijan vrednost BallControl:  0.7582417582417583
#
# RS, srednja vrednost BallControl:  0.6916039625399231
# RS, medijan vrednost BallControl:  0.7032967032967034
#
# ST, srednja vrednost BallControl:  0.6423292232984438
# ST, medijan vrednost BallControl:  0.6483516483516484
#
# LS, srednja vrednost BallControl:  0.7015979189892233
# LS, medijan vrednost BallControl:  0.6923076923076923
#
# LW, srednja vrednost BallControl:  0.6948746791266477
# LW, medijan vrednost BallControl:  0.6923076923076923
#
# RW, srednja vrednost BallControl:  0.6942975942975943
# RW, medijan vrednost BallControl:  0.6923076923076923
#
# VEZNI RED:
# RDM, srednja vrednost BallControl:  0.6909340659340659
# RDM, medijan vrednost BallControl:  0.6923076923076923
#
# CDM, srednja vrednost BallControl:  0.6549241897343163
# CDM, medijan vrednost BallControl:  0.6593406593406593
#
# LDM, srednja vrednost BallControl:  0.691358024691358
# LDM, medijan vrednost BallControl:  0.6923076923076923
#
# RM, srednja vrednost BallControl:  0.6787278557741191
# RM, medijan vrednost BallControl:  0.6703296703296704
#
# RCM, srednja vrednost BallControl:  0.7063601360276552
# RCM, medijan vrednost BallControl:  0.7032967032967034
#
# CM, srednja vrednost BallControl:  0.6605783026156054
# CM, medijan vrednost BallControl:  0.6593406593406593
#
# LCM, srednja vrednost BallControl:  0.7087216580887467
# LCM, medijan vrednost BallControl:  0.7032967032967034
#
# LM, srednja vrednost BallControl:  0.6829344171809926
# LM, medijan vrednost BallControl:  0.6813186813186813
#
# RAM, srednja vrednost BallControl:  0.7535321821036106
# RAM, medijan vrednost BallControl:  0.7582417582417583
#
# CAM, srednja vrednost BallControl:  0.6975727821239304
# CAM, medijan vrednost BallControl:  0.7032967032967034
#
# ODBRANA:
# RWB, srednja vrednost BallControl:  0.6264999368447645
# RWB, medijan vrednost BallControl:  0.6263736263736264
#
# RB, srednja vrednost BallControl:  0.6288165745950409
# RB, medijan vrednost BallControl:  0.6373626373626374
#
# RCB, srednja vrednost BallControl:  0.5610205504465324
# RCB, medijan vrednost BallControl:  0.5604395604395604
#
# CB, srednja vrednost BallControl:  0.5103894980160447
# CB, medijan vrednost BallControl:  0.5164835164835165
#
# LCB, srednja vrednost BallControl:  0.5683591100257767
# LCB, medijan vrednost BallControl:  0.5714285714285714
#
# LB, srednja vrednost BallControl:  0.6281940449867832
# LB, medijan vrednost BallControl:  0.6373626373626374
#
# LWB, srednja vrednost BallControl:  0.6499013806706114
# LWB, medijan vrednost BallControl:  0.6483516483516484

# %%
show_mean_and_median_for_each_team_position(df, 'Acceleration')
# Out:
# GK, srednja vrednost Acceleration:  0.3096470588235294
# GK, medijan vrednost Acceleration:  0.3176470588235294
#
# NAPAD:
# RF, srednja vrednost Acceleration:  0.7345588235294118
# RF, medijan vrednost Acceleration:  0.7352941176470589
#
# CF, srednja vrednost Acceleration:  0.7214626391096979
# CF, medijan vrednost Acceleration:  0.7294117647058824
#
# LF, srednja vrednost Acceleration:  0.7662745098039216
# LF, medijan vrednost Acceleration:  0.7529411764705882
#
# RS, srednja vrednost Acceleration:  0.7057084902926688
# RS, medijan vrednost Acceleration:  0.7176470588235293
#
# ST, srednja vrednost Acceleration:  0.6649637040310501
# ST, medijan vrednost Acceleration:  0.6705882352941177
#
# LS, srednja vrednost Acceleration:  0.7023586246092641
# LS, medijan vrednost Acceleration:  0.7176470588235293
#
# LW, srednja vrednost Acceleration:  0.7740620657711903
# LW, medijan vrednost Acceleration:  0.776470588235294
#
# RW, srednja vrednost Acceleration:  0.7767885532591415
# RW, medijan vrednost Acceleration:  0.776470588235294
#
# VEZNI RED:
# RDM, srednja vrednost Acceleration:  0.607495256166983
# RDM, medijan vrednost Acceleration:  0.6235294117647059
#
# CDM, srednja vrednost Acceleration:  0.586609580541077
# CDM, medijan vrednost Acceleration:  0.6000000000000001
#
# LDM, srednja vrednost Acceleration:  0.6061002178649236
# LDM, medijan vrednost Acceleration:  0.6235294117647059
#
# RM, srednja vrednost Acceleration:  0.7625706510362152
# RM, medijan vrednost Acceleration:  0.7647058823529411
#
# RCM, srednja vrednost Acceleration:  0.6430269294418535
# RCM, medijan vrednost Acceleration:  0.6588235294117648
#
# CM, srednja vrednost Acceleration:  0.6314034939657356
# CM, medijan vrednost Acceleration:  0.6352941176470588
#
# LCM, srednja vrednost Acceleration:  0.6469099032017871
# LCM, medijan vrednost Acceleration:  0.6588235294117648
#
# LM, srednja vrednost Acceleration:  0.7610206822455009
# LM, medijan vrednost Acceleration:  0.7647058823529411
#
# RAM, srednja vrednost Acceleration:  0.7439775910364146
# RAM, medijan vrednost Acceleration:  0.776470588235294
#
# CAM, srednja vrednost Acceleration:  0.6903598182488025
# CAM, medijan vrednost Acceleration:  0.6941176470588235
#
# ODBRANA:
# RWB, srednja vrednost Acceleration:  0.7229208924949289
# RWB, medijan vrednost Acceleration:  0.7411764705882353
#
# RB, srednja vrednost Acceleration:  0.7105754772861894
# RB, medijan vrednost Acceleration:  0.7176470588235293
#
# RCB, srednja vrednost Acceleration:  0.527190332326284
# RCB, medijan vrednost Acceleration:  0.5411764705882354
#
# CB, srednja vrednost Acceleration:  0.5269701581419969
# CB, medijan vrednost Acceleration:  0.5411764705882354
#
# LCB, srednja vrednost Acceleration:  0.5338053740014523
# LCB, medijan vrednost Acceleration:  0.5529411764705883
#
# LB, srednja vrednost Acceleration:  0.7047254605321706
# LB, medijan vrednost Acceleration:  0.7058823529411764
#
# LWB, srednja vrednost Acceleration:  0.7297134238310709
# LWB, medijan vrednost Acceleration:  0.7294117647058824

# %%
show_mean_and_median_for_each_team_position(df, 'SprintSpeed')
# Out:
# GK, srednja vrednost SprintSpeed:  0.3180011757789535
# GK, medijan vrednost SprintSpeed:  0.3333333333333333
#
# NAPAD:
# RF, srednja vrednost SprintSpeed:  0.7328869047619048
# RF, medijan vrednost SprintSpeed:  0.75
#
# CF, srednja vrednost SprintSpeed:  0.7125160875160875
# CF, medijan vrednost SprintSpeed:  0.726190476190476
#
# LF, srednja vrednost SprintSpeed:  0.7507936507936507
# LF, medijan vrednost SprintSpeed:  0.7380952380952381
#
# RS, srednja vrednost SprintSpeed:  0.7300609899132066
# RS, medijan vrednost SprintSpeed:  0.7380952380952381
#
# ST, srednja vrednost SprintSpeed:  0.6842810558884052
# ST, medijan vrednost SprintSpeed:  0.6904761904761905
#
# LS, srednja vrednost SprintSpeed:  0.7254428341384861
# LS, medijan vrednost SprintSpeed:  0.75
#
# LW, srednja vrednost SprintSpeed:  0.7704974378202726
# LW, medijan vrednost SprintSpeed:  0.7619047619047619
#
# RW, srednja vrednost SprintSpeed:  0.774163449163449
# RW, medijan vrednost SprintSpeed:  0.7738095238095237
#
# VEZNI RED:
# RDM, srednja vrednost SprintSpeed:  0.605894777265745
# RDM, medijan vrednost SprintSpeed:  0.6309523809523809
#
# CDM, srednja vrednost SprintSpeed:  0.5861462728551337
# CDM, medijan vrednost SprintSpeed:  0.6071428571428572
#
# LDM, srednja vrednost SprintSpeed:  0.6079757005682932
# LDM, medijan vrednost SprintSpeed:  0.6190476190476191
#
# RM, srednja vrednost SprintSpeed:  0.7653363836637859
# RM, medijan vrednost SprintSpeed:  0.7738095238095237
#
# RCM, srednja vrednost SprintSpeed:  0.6389294848374132
# RCM, medijan vrednost SprintSpeed:  0.6428571428571428
#
# CM, srednja vrednost SprintSpeed:  0.6271008403361343
# CM, medijan vrednost SprintSpeed:  0.6428571428571428
#
# LCM, srednja vrednost SprintSpeed:  0.6436106088004823
# LCM, medijan vrednost SprintSpeed:  0.6547619047619047
#
# LM, srednja vrednost SprintSpeed:  0.7597412480974124
# LM, medijan vrednost SprintSpeed:  0.7619047619047619
#
# RAM, srednja vrednost SprintSpeed:  0.7488662131519274
# RAM, medijan vrednost SprintSpeed:  0.7619047619047619
#
# CAM, srednja vrednost SprintSpeed:  0.6767819862809422
# CAM, medijan vrednost SprintSpeed:  0.6785714285714286
#
# ODBRANA:
# RWB, srednja vrednost SprintSpeed:  0.733032293377121
# RWB, medijan vrednost SprintSpeed:  0.75
#
# RB, srednja vrednost SprintSpeed:  0.7210172992512264
# RB, medijan vrednost SprintSpeed:  0.726190476190476
#
# RCB, srednja vrednost SprintSpeed:  0.5610164005179111
# RCB, medijan vrednost SprintSpeed:  0.5833333333333333
#
# CB, srednja vrednost SprintSpeed:  0.5503910225507526
# CB, medijan vrednost SprintSpeed:  0.5714285714285714
#
# LCB, srednja vrednost SprintSpeed:  0.5669826572604351
# LCB, medijan vrednost SprintSpeed:  0.5952380952380951
#
# LB, srednja vrednost SprintSpeed:  0.7136823715870614
# LB, medijan vrednost SprintSpeed:  0.7142857142857142
#
# LWB, srednja vrednost SprintSpeed:  0.7406898656898656
# LWB, medijan vrednost SprintSpeed:  0.75

# %%
show_mean_and_median_for_each_team_position(df, 'Agility')
# Out:
# GK, srednja vrednost Agility:  0.3195302619692864
# GK, medijan vrednost Agility:  0.29268292682926833
#
# NAPAD:
# RF, srednja vrednost Agility:  0.7629573170731707
# RF, medijan vrednost Agility:  0.75
#
# CF, srednja vrednost Agility:  0.7391232696110744
# CF, medijan vrednost Agility:  0.75
#
# LF, srednja vrednost Agility:  0.8016260162601628
# LF, medijan vrednost Agility:  0.7804878048780488
#
# RS, srednja vrednost Agility:  0.6850895109936322
# RS, medijan vrednost Agility:  0.6951219512195121
#
# ST, srednja vrednost Agility:  0.6351341526115164
# ST, medijan vrednost Agility:  0.6463414634146342
#
# LS, srednja vrednost Agility:  0.6815718157181571
# LS, medijan vrednost Agility:  0.6951219512195121
#
# LW, srednja vrednost Agility:  0.7565136674988797
# LW, medijan vrednost Agility:  0.7682926829268293
#
# RW, srednja vrednost Agility:  0.7544825313117995
# RW, medijan vrednost Agility:  0.7682926829268293
#
# VEZNI RED:
# RDM, srednja vrednost Agility:  0.63286782061369
# RDM, medijan vrednost Agility:  0.6402439024390244
#
# CDM, srednja vrednost Agility:  0.6080451785530513
# CDM, medijan vrednost Agility:  0.6097560975609756
#
# LDM, srednja vrednost Agility:  0.6352002408912979
# LDM, medijan vrednost Agility:  0.6341463414634146
#
# RM, srednja vrednost Agility:  0.7430236090617134
# RM, medijan vrednost Agility:  0.7439024390243902
#
# RCM, srednja vrednost Agility:  0.6804004740814672
# RCM, medijan vrednost Agility:  0.6829268292682926
#
# CM, srednja vrednost Agility:  0.6491321692270007
# CM, medijan vrednost Agility:  0.6463414634146342
#
# LCM, srednja vrednost Agility:  0.6912318616857055
# LCM, medijan vrednost Agility:  0.6951219512195121
#
# LM, srednja vrednost Agility:  0.7485131974607416
# LM, medijan vrednost Agility:  0.7560975609756098
#
# RAM, srednja vrednost Agility:  0.7775842044134729
# RAM, medijan vrednost Agility:  0.7804878048780488
#
# CAM, srednja vrednost Agility:  0.7150949641020418
# CAM, medijan vrednost Agility:  0.7195121951219512
#
# ODBRANA:
# RWB, srednja vrednost Agility:  0.6710120549481358
# RWB, medijan vrednost Agility:  0.6951219512195121
#
# RB, srednja vrednost Agility:  0.6608603653813456
# RB, medijan vrednost Agility:  0.6707317073170732
#
# RCB, srednja vrednost Agility:  0.4856127035590598
# RCB, medijan vrednost Agility:  0.5
#
# CB, srednja vrednost Agility:  0.4653488435896732
# CB, medijan vrednost Agility:  0.46341463414634143
#
# LCB, srednja vrednost Agility:  0.49486224028906967
# LCB, medijan vrednost Agility:  0.5121951219512195
#
# LB, srednja vrednost Agility:  0.6614423821999188
# LB, medijan vrednost Agility:  0.6707317073170732
#
# LWB, srednja vrednost Agility:  0.6880863039399624
# LWB, medijan vrednost Agility:  0.6951219512195121

# %%
show_mean_and_median_for_each_team_position(df, 'Balance')
# Out:
# GK, srednja vrednost Balance:  0.3387283950617284
# GK, medijan vrednost Balance:  0.33749999999999997
#
# NAPAD:
# RF, srednja vrednost Balance:  0.7296875
# RF, medijan vrednost Balance:  0.7375
#
# CF, srednja vrednost Balance:  0.7219594594594596
# CF, medijan vrednost Balance:  0.7250000000000001
#
# LF, srednja vrednost Balance:  0.805
# LF, medijan vrednost Balance:  0.7875000000000001
#
# RS, srednja vrednost Balance:  0.6280172413793104
# RS, medijan vrednost Balance:  0.6375
#
# ST, srednja vrednost Balance:  0.5988098751489631
# ST, medijan vrednost Balance:  0.6125
#
# LS, srednja vrednost Balance:  0.6137077294685992
# LS, medijan vrednost Balance:  0.6375
#
# LW, srednja vrednost Balance:  0.7224409448818898
# LW, medijan vrednost Balance:  0.7125000000000001
#
# RW, srednja vrednost Balance:  0.7277364864864866
# RW, medijan vrednost Balance:  0.7375
#
# VEZNI RED:
# RDM, srednja vrednost Balance:  0.6378528225806451
# RDM, medijan vrednost Balance:  0.6500000000000001
#
# CDM, srednja vrednost Balance:  0.621215717299578
# CDM, medijan vrednost Balance:  0.6375
#
# LDM, srednja vrednost Balance:  0.6342078189300412
# LDM, medijan vrednost Balance:  0.625
#
# RM, srednja vrednost Balance:  0.7184052491103203
# RM, medijan vrednost Balance:  0.7250000000000001
#
# RCM, srednja vrednost Balance:  0.6710677749360615
# RCM, medijan vrednost Balance:  0.675
#
# CM, srednja vrednost Balance:  0.672022955523673
# CM, medijan vrednost Balance:  0.675
#
# LCM, srednja vrednost Balance:  0.6845886075949368
# LCM, medijan vrednost Balance:  0.6875
#
# LM, srednja vrednost Balance:  0.7264269406392694
# LM, medijan vrednost Balance:  0.7250000000000001
#
# RAM, srednja vrednost Balance:  0.7636904761904763
# RAM, medijan vrednost Balance:  0.75
#
# CAM, srednja vrednost Balance:  0.7156054279749477
# CAM, medijan vrednost Balance:  0.7250000000000001
#
# ODBRANA:
# RWB, srednja vrednost Balance:  0.6603448275862069
# RWB, medijan vrednost Balance:  0.675
#
# RB, srednja vrednost Balance:  0.6627033307513556
# RB, medijan vrednost Balance:  0.6625000000000001
#
# RCB, srednja vrednost Balance:  0.47456570996978853
# RCB, medijan vrednost Balance:  0.5
#
# CB, srednja vrednost Balance:  0.48566507311586055
# CB, medijan vrednost Balance:  0.5
#
# LCB, srednja vrednost Balance:  0.48821373456790135
# LCB, medijan vrednost Balance:  0.5125
#
# LB, srednja vrednost Balance:  0.6651285930408473
# LB, medijan vrednost Balance:  0.675
#
# LWB, srednja vrednost Balance:  0.6748397435897437
# LWB, medijan vrednost Balance:  0.6687500000000001

# %%
show_mean_and_median_for_each_team_position(df, 'ShotPower')
# Out:
# GK, srednja vrednost ShotPower:  0.22078853046594982
# GK, medijan vrednost ShotPower:  0.21505376344086022
#
# NAPAD:
# RF, srednja vrednost ShotPower:  0.7661290322580646
# RF, medijan vrednost ShotPower:  0.7365591397849464
#
# CF, srednja vrednost ShotPower:  0.6697181052019764
# CF, medijan vrednost ShotPower:  0.6774193548387097
#
# LF, srednja vrednost ShotPower:  0.7541218637992831
# LF, medijan vrednost ShotPower:  0.7311827956989249
#
# RS, srednja vrednost ShotPower:  0.7318184225859423
# RS, medijan vrednost ShotPower:  0.7311827956989249
#
# ST, srednja vrednost ShotPower:  0.6837488686988515
# ST, medijan vrednost ShotPower:  0.6881720430107527
#
# LS, srednja vrednost ShotPower:  0.7402212872058596
# LS, medijan vrednost ShotPower:  0.7311827956989249
#
# LW, srednja vrednost ShotPower:  0.6785200237067142
# LW, medijan vrednost ShotPower:  0.6774193548387097
#
# RW, srednja vrednost ShotPower:  0.6836384771868644
# RW, medijan vrednost ShotPower:  0.6881720430107527
#
# VEZNI RED:
# RDM, srednja vrednost ShotPower:  0.6844432882414153
# RDM, medijan vrednost ShotPower:  0.6989247311827957
#
# CDM, srednja vrednost ShotPower:  0.6310285377251487
# CDM, medijan vrednost ShotPower:  0.6344086021505377
#
# LDM, srednja vrednost ShotPower:  0.6788353466967565
# LDM, medijan vrednost ShotPower:  0.6774193548387097
#
# RM, srednja vrednost ShotPower:  0.6584108215666018
# RM, medijan vrednost ShotPower:  0.6666666666666667
#
# RCM, srednja vrednost ShotPower:  0.6933146330060779
# RCM, medijan vrednost ShotPower:  0.6989247311827957
#
# CM, srednja vrednost ShotPower:  0.6385584918467782
# CM, medijan vrednost ShotPower:  0.6451612903225807
#
# LCM, srednja vrednost ShotPower:  0.6952225398121684
# LCM, medijan vrednost ShotPower:  0.6989247311827957
#
# LM, srednja vrednost ShotPower:  0.6673344135120539
# LM, medijan vrednost ShotPower:  0.6774193548387097
#
# RAM, srednja vrednost ShotPower:  0.6543778801843319
# RAM, medijan vrednost ShotPower:  0.6559139784946237
#
# CAM, srednja vrednost ShotPower:  0.6645565357936563
# CAM, medijan vrednost ShotPower:  0.6666666666666667
#
# ODBRANA:
# RWB, srednja vrednost ShotPower:  0.5597577555308368
# RWB, medijan vrednost ShotPower:  0.5913978494623656
#
# RB, srednja vrednost ShotPower:  0.5420404287748933
# RB, medijan vrednost ShotPower:  0.5698924731182796
#
# RCB, srednja vrednost ShotPower:  0.5322743072475068
# RCB, medijan vrednost ShotPower:  0.5161290322580646
#
# CB, srednja vrednost ShotPower:  0.49833690143570775
# CB, medijan vrednost ShotPower:  0.47311827956989255
#
# LCB, srednja vrednost ShotPower:  0.5392771804062129
# LCB, medijan vrednost ShotPower:  0.5268817204301076
#
# LB, srednja vrednost ShotPower:  0.5549916223382624
# LB, medijan vrednost ShotPower:  0.5806451612903226
#
# LWB, srednja vrednost ShotPower:  0.5883650399779433
# LWB, medijan vrednost ShotPower:  0.6021505376344086

# %%
show_mean_and_median_for_each_team_position(df, 'Stamina')
# Out:
# GK, srednja vrednost Stamina:  0.219782480893592
# GK, medijan vrednost Stamina:  0.21428571428571425
#
# NAPAD:
# RF, srednja vrednost Stamina:  0.7299107142857142
# RF, medijan vrednost Stamina:  0.7321428571428571
#
# CF, srednja vrednost Stamina:  0.6145431145431144
# CF, medijan vrednost Stamina:  0.6309523809523809
#
# LF, srednja vrednost Stamina:  0.6928571428571428
# LF, medijan vrednost Stamina:  0.6428571428571428
#
# RS, srednja vrednost Stamina:  0.6824419422941591
# RS, medijan vrednost Stamina:  0.6785714285714286
#
# ST, srednja vrednost Stamina:  0.6144598586150702
# ST, medijan vrednost Stamina:  0.6190476190476191
#
# LS, srednja vrednost Stamina:  0.6664366229583621
# LS, medijan vrednost Stamina:  0.6785714285714286
#
# LW, srednja vrednost Stamina:  0.6177040369953756
# LW, medijan vrednost Stamina:  0.6309523809523809
#
# RW, srednja vrednost Stamina:  0.6247747747747748
# RW, medijan vrednost Stamina:  0.6428571428571428
#
# VEZNI RED:
# RDM, srednja vrednost Stamina:  0.7601766513056836
# RDM, medijan vrednost Stamina:  0.7619047619047619
#
# CDM, srednja vrednost Stamina:  0.6910412899336951
# CDM, medijan vrednost Stamina:  0.7023809523809523
#
# LDM, srednja vrednost Stamina:  0.7384381736233588
# LDM, medijan vrednost Stamina:  0.75
#
# RM, srednja vrednost Stamina:  0.6524741569225554
# RM, medijan vrednost Stamina:  0.6666666666666667
#
# RCM, srednja vrednost Stamina:  0.7496041895018877
# RCM, medijan vrednost Stamina:  0.7619047619047619
#
# CM, srednja vrednost Stamina:  0.6538054246088679
# CM, medijan vrednost Stamina:  0.6666666666666667
#
# LCM, srednja vrednost Stamina:  0.7361060880048224
# LCM, medijan vrednost Stamina:  0.75
#
# LM, srednja vrednost Stamina:  0.6470428353989998
# LM, medijan vrednost Stamina:  0.6666666666666667
#
# RAM, srednja vrednost Stamina:  0.6479591836734694
# RAM, medijan vrednost Stamina:  0.6666666666666667
#
# CAM, srednja vrednost Stamina:  0.6123620638234416
# CAM, medijan vrednost Stamina:  0.6309523809523809
#
# ODBRANA:
# RWB, srednja vrednost Stamina:  0.722495894909688
# RWB, medijan vrednost Stamina:  0.7380952380952381
#
# RB, srednja vrednost Stamina:  0.7203625834532108
# RB, medijan vrednost Stamina:  0.726190476190476
#
# RCB, srednja vrednost Stamina:  0.6567220543806647
# RCB, medijan vrednost Stamina:  0.6666666666666667
#
# CB, srednja vrednost Stamina:  0.6003937007874016
# CB, medijan vrednost Stamina:  0.6071428571428572
#
# LCB, srednja vrednost Stamina:  0.6545598177542622
# LCB, medijan vrednost Stamina:  0.6666666666666667
#
# LB, srednja vrednost Stamina:  0.7084774151718176
# LB, medijan vrednost Stamina:  0.7142857142857142
#
# LWB, srednja vrednost Stamina:  0.7368742368742368
# LWB, medijan vrednost Stamina:  0.7619047619047619

# %%
show_mean_and_median_for_each_team_position(df, 'LongShots')
# Out:
# GK, srednja vrednost LongShots:  0.1060805860805861
# GK, medijan vrednost LongShots:  0.10989010989010992
#
# NAPAD:
# RF, srednja vrednost LongShots:  0.742445054945055
# RF, medijan vrednost LongShots:  0.7087912087912089
#
# CF, srednja vrednost LongShots:  0.638996138996139
# CF, medijan vrednost LongShots:  0.6483516483516484
#
# LF, srednja vrednost LongShots:  0.7443223443223441
# LF, medijan vrednost LongShots:  0.7472527472527474
#
# RS, srednja vrednost LongShots:  0.6528446922535592
# RS, medijan vrednost LongShots:  0.6703296703296704
#
# ST, srednja vrednost LongShots:  0.6144073222223163
# ST, medijan vrednost LongShots:  0.6153846153846154
#
# LS, srednja vrednost LongShots:  0.6647555343207517
# LS, medijan vrednost LongShots:  0.6703296703296704
#
# LW, srednja vrednost LongShots:  0.6176343341697673
# LW, medijan vrednost LongShots:  0.6153846153846154
#
# RW, srednja vrednost LongShots:  0.6123552123552125
# RW, medijan vrednost LongShots:  0.6153846153846154
#
# VEZNI RED:
# RDM, srednja vrednost LongShots:  0.6136565047855371
# RDM, medijan vrednost LongShots:  0.6373626373626374
#
# CDM, srednja vrednost LongShots:  0.5407914869940187
# CDM, medijan vrednost LongShots:  0.5494505494505495
#
# LDM, srednja vrednost LongShots:  0.6159272825939492
# LDM, medijan vrednost LongShots:  0.6373626373626374
#
# RM, srednja vrednost LongShots:  0.5962516131555278
# RM, medijan vrednost LongShots:  0.6043956043956045
#
# RCM, srednja vrednost LongShots:  0.6482954385767685
# RCM, medijan vrednost LongShots:  0.6593406593406594
#
# CM, srednja vrednost LongShots:  0.5755041228498906
# CM, medijan vrednost LongShots:  0.5934065934065934
#
# LCM, srednja vrednost LongShots:  0.6492418973431633
# LCM, medijan vrednost LongShots:  0.6593406593406594
#
# LM, srednja vrednost LongShots:  0.6047368156957198
# LM, medijan vrednost LongShots:  0.6153846153846154
#
# RAM, srednja vrednost LongShots:  0.6640502354788068
# RAM, medijan vrednost LongShots:  0.6813186813186813
#
# CAM, srednja vrednost LongShots:  0.6292986762715365
# CAM, medijan vrednost LongShots:  0.6483516483516484
#
# ODBRANA:
# RWB, srednja vrednost LongShots:  0.4724011620563346
# RWB, medijan vrednost LongShots:  0.46153846153846156
#
# RB, srednja vrednost LongShots:  0.4533839514474682
# RB, medijan vrednost LongShots:  0.4505494505494506
#
# RCB, srednja vrednost LongShots:  0.3664220975399223
# RCB, medijan vrednost LongShots:  0.34065934065934067
#
# CB, srednja vrednost LongShots:  0.33099914708463646
# CB, medijan vrednost LongShots:  0.29670329670329676
#
# LCB, srednja vrednost LongShots:  0.3746608329941664
# LCB, medijan vrednost LongShots:  0.3516483516483517
#
# LB, srednja vrednost LongShots:  0.4693105684028529
# LB, medijan vrednost LongShots:  0.4505494505494506
#
# LWB, srednja vrednost LongShots:  0.49704142011834324
# LWB, medijan vrednost LongShots:  0.4945054945054945

# %%
show_mean_and_median_for_each_team_position(df, 'Aggression')
# Out:
# GK, srednja vrednost Aggression:  0.18299823633156967
# GK, medijan vrednost Aggression:  0.16666666666666669
#
# NAPAD:
# RF, srednja vrednost Aggression:  0.5290178571428571
# RF, medijan vrednost Aggression:  0.4880952380952381
#
# CF, srednja vrednost Aggression:  0.45093307593307586
# CF, medijan vrednost Aggression:  0.43452380952380953
#
# LF, srednja vrednost Aggression:  0.4841269841269841
# LF, medijan vrednost Aggression:  0.5119047619047619
#
# RS, srednja vrednost Aggression:  0.5505512549847524
# RS, medijan vrednost Aggression:  0.5595238095238095
#
# ST, srednja vrednost Aggression:  0.4865544623912465
# ST, medijan vrednost Aggression:  0.5
#
# LS, srednja vrednost Aggression:  0.5562456866804693
# LS, medijan vrednost Aggression:  0.5952380952380952
#
# LW, srednja vrednost Aggression:  0.45013123359580054
# LW, medijan vrednost Aggression:  0.44047619047619047
#
# RW, srednja vrednost Aggression:  0.42879665379665377
# RW, medijan vrednost Aggression:  0.40476190476190477
#
# VEZNI RED:
# RDM, srednja vrednost Aggression:  0.7092933947772657
# RDM, medijan vrednost Aggression:  0.7261904761904762
#
# CDM, srednja vrednost Aggression:  0.6854405264215391
# CDM, medijan vrednost Aggression:  0.6845238095238095
#
# LDM, srednja vrednost Aggression:  0.6780325298843817
# LDM, medijan vrednost Aggression:  0.7023809523809523
#
# RM, srednja vrednost Aggression:  0.4778109642433486
# RM, medijan vrednost Aggression:  0.47619047619047616
#
# RCM, srednja vrednost Aggression:  0.6635306296431617
# RCM, medijan vrednost Aggression:  0.6785714285714286
#
# CM, srednja vrednost Aggression:  0.5893711142993783
# CM, medijan vrednost Aggression:  0.5952380952380952
#
# LCM, srednja vrednost Aggression:  0.6496081977094634
# LCM, medijan vrednost Aggression:  0.6666666666666666
#
# LM, srednja vrednost Aggression:  0.47384213959556426
# LM, medijan vrednost Aggression:  0.4642857142857143
#
# RAM, srednja vrednost Aggression:  0.4886621315192744
# RAM, medijan vrednost Aggression:  0.41666666666666663
#
# CAM, srednja vrednost Aggression:  0.4828636047320808
# CAM, medijan vrednost Aggression:  0.4642857142857143
#
# ODBRANA:
# RWB, srednja vrednost Aggression:  0.6128899835796386
# RWB, medijan vrednost Aggression:  0.6071428571428571
#
# RB, srednja vrednost Aggression:  0.6340968610527092
# RB, medijan vrednost Aggression:  0.6428571428571428
#
# RCB, srednja vrednost Aggression:  0.7040174075672564
# RCB, medijan vrednost Aggression:  0.7023809523809523
#
# CB, srednja vrednost Aggression:  0.640748031496063
# CB, medijan vrednost Aggression:  0.6428571428571428
#
# LCB, srednja vrednost Aggression:  0.7010214579659023
# LCB, medijan vrednost Aggression:  0.7023809523809523
#
# LB, srednja vrednost Aggression:  0.6248018874720841
# LB, medijan vrednost Aggression:  0.6309523809523809
#
# LWB, srednja vrednost Aggression:  0.6202686202686203
# LWB, medijan vrednost Aggression:  0.625

# %%
show_mean_and_median_for_each_team_position(df, 'Interceptions')
# Out:
# GK, srednja vrednost Interceptions:  0.15789152448328478
# GK, medijan vrednost Interceptions:  0.15730337078651685
#
# NAPAD:
# RF, srednja vrednost Interceptions:  0.3595505617977528
# RF, medijan vrednost Interceptions:  0.3707865168539326
#
# CF, srednja vrednost Interceptions:  0.28515031885818404
# CF, medijan vrednost Interceptions:  0.2640449438202247
#
# LF, srednja vrednost Interceptions:  0.4014981273408241
# LF, medijan vrednost Interceptions:  0.3370786516853933
#
# RS, srednja vrednost Interceptions:  0.3037028837106327
# RS, medijan vrednost Interceptions:  0.2808988764044944
#
# ST, srednja vrednost Interceptions:  0.26432694629988895
# ST, medijan vrednost Interceptions:  0.23595505617977527
#
# LS, srednja vrednost Interceptions:  0.30076534766324703
# LS, medijan vrednost Interceptions:  0.2921348314606742
#
# LW, srednja vrednost Interceptions:  0.3305317172432098
# LW, medijan vrednost Interceptions:  0.3033707865168539
#
# RW, srednja vrednost Interceptions:  0.32900091102338297
# RW, medijan vrednost Interceptions:  0.3033707865168539
#
# VEZNI RED:
# RDM, srednja vrednost Interceptions:  0.7126676332004349
# RDM, medijan vrednost Interceptions:  0.7303370786516854
#
# CDM, srednja vrednost Interceptions:  0.6916157018916229
# CDM, medijan vrednost Interceptions:  0.6966292134831461
#
# LDM, srednja vrednost Interceptions:  0.6972765524575764
# LDM, medijan vrednost Interceptions:  0.7078651685393259
#
# RM, srednja vrednost Interceptions:  0.39409812467511696
# RM, medijan vrednost Interceptions:  0.3820224719101124
#
# RCM, srednja vrednost Interceptions:  0.6642719618379839
# RCM, medijan vrednost Interceptions:  0.6853932584269663
#
# CM, srednja vrednost Interceptions:  0.59032289265391
# CM, medijan vrednost Interceptions:  0.601123595505618
#
# LCM, srednja vrednost Interceptions:  0.6489546294979377
# LCM, medijan vrednost Interceptions:  0.6741573033707865
#
# LM, srednja vrednost Interceptions:  0.39129854804781694
# LM, medijan vrednost Interceptions:  0.3595505617977528
#
# RAM, srednja vrednost Interceptions:  0.4890315676832531
# RAM, medijan vrednost Interceptions:  0.4943820224719101
#
# CAM, srednja vrednost Interceptions:  0.4092092608665056
# CAM, medijan vrednost Interceptions:  0.3932584269662921
#
# ODBRANA:
# RWB, srednja vrednost Interceptions:  0.6334753971328941
# RWB, medijan vrednost Interceptions:  0.6179775280898877
#
# RB, srednja vrednost Interceptions:  0.6755585340168322
# RB, medijan vrednost Interceptions:  0.6741573033707865
#
# RCB, srednja vrednost Interceptions:  0.7234970637156727
# RCB, medijan vrednost Interceptions:  0.7191011235955056
#
# CB, srednja vrednost Interceptions:  0.6722235563251222
# CB, medijan vrednost Interceptions:  0.6629213483146067
#
# LCB, srednja vrednost Interceptions:  0.7231758912470523
# LCB, medijan vrednost Interceptions:  0.7191011235955056
#
# LB, srednja vrednost Interceptions:  0.6705026432541773
# LB, medijan vrednost Interceptions:  0.6741573033707865
#
# LWB, srednja vrednost Interceptions:  0.6567271679631228
# LWB, medijan vrednost Interceptions:  0.651685393258427

# %%
show_mean_and_median_for_each_team_position(df, 'Positioning')
# Out:
# GK, srednja vrednost Positioning:  0.09955661754944908
# GK, medijan vrednost Positioning:  0.0967741935483871
#
# NAPAD:
# RF, srednja vrednost Positioning:  0.739247311827957
# RF, medijan vrednost Positioning:  0.7096774193548387
#
# CF, srednja vrednost Positioning:  0.6620168555652429
# CF, medijan vrednost Positioning:  0.6559139784946237
#
# LF, srednja vrednost Positioning:  0.7304659498207886
# LF, medijan vrednost Positioning:  0.6989247311827957
#
# RS, srednja vrednost Positioning:  0.7257799671592777
# RS, medijan vrednost Positioning:  0.7311827956989249
#
# ST, srednja vrednost Positioning:  0.673219423567968
# ST, medijan vrednost Positioning:  0.6774193548387097
#
# LS, srednja vrednost Positioning:  0.7305075061035792
# LS, medijan vrednost Positioning:  0.7311827956989249
#
# LW, srednja vrednost Positioning:  0.6561679790026248
# LW, medijan vrednost Positioning:  0.6559139784946237
#
# RW, srednja vrednost Positioning:  0.6602731764022088
# RW, medijan vrednost Positioning:  0.6666666666666667
#
# VEZNI RED:
# RDM, srednja vrednost Positioning:  0.5957336108220604
# RDM, medijan vrednost Positioning:  0.6075268817204302
#
# CDM, srednja vrednost Positioning:  0.5236604509777234
# CDM, medijan vrednost Positioning:  0.5376344086021506
#
# LDM, srednja vrednost Positioning:  0.5961325722377097
# LDM, medijan vrednost Positioning:  0.6129032258064517
#
# RM, srednja vrednost Positioning:  0.643802854628248
# RM, medijan vrednost Positioning:  0.6451612903225807
#
# RCM, srednja vrednost Positioning:  0.6319610593185383
# RCM, medijan vrednost Positioning:  0.6344086021505377
#
# CM, srednja vrednost Positioning:  0.5900402647290232
# CM, medijan vrednost Positioning:  0.5913978494623656
#
# LCM, srednja vrednost Positioning:  0.6421940928270045
# LCM, medijan vrednost Positioning:  0.6451612903225807
#
# LM, srednja vrednost Positioning:  0.6460156134924143
# LM, medijan vrednost Positioning:  0.6451612903225807
#
# RAM, srednja vrednost Positioning:  0.7281105990783411
# RAM, medijan vrednost Positioning:  0.7311827956989249
#
# CAM, srednja vrednost Positioning:  0.6456439266392799
# CAM, medijan vrednost Positioning:  0.6559139784946237
#
# ODBRANA:
# RWB, srednja vrednost Positioning:  0.5558027437893958
# RWB, medijan vrednost Positioning:  0.5483870967741936
#
# RB, srednja vrednost Positioning:  0.5552418313718632
# RB, medijan vrednost Positioning:  0.5591397849462366
#
# RCB, srednja vrednost Positioning:  0.3693597115290908
# RCB, medijan vrednost Positioning:  0.34408602150537637
#
# CB, srednja vrednost Positioning:  0.34238058952308387
# CB, medijan vrednost Positioning:  0.31182795698924737
#
# LCB, srednja vrednost Positioning:  0.3771405814416568
# LCB, medijan vrednost Positioning:  0.35483870967741943
#
# LB, srednja vrednost Positioning:  0.5552356319034374
# LB, medijan vrednost Positioning:  0.5591397849462366
#
# LWB, srednja vrednost Positioning:  0.5732009925558312
# LWB, medijan vrednost Positioning:  0.5913978494623656

# %%
show_mean_and_median_for_each_team_position(df, 'Vision')
# Out:
# GK, srednja vrednost Vision:  0.32139917695473247
# GK, medijan vrednost Vision:  0.30952380952380953
#
# NAPAD:
# RF, srednja vrednost Vision:  0.7299107142857142
# RF, medijan vrednost Vision:  0.7261904761904762
#
# CF, srednja vrednost Vision:  0.6274131274131275
# CF, medijan vrednost Vision:  0.6309523809523809
#
# LF, srednja vrednost Vision:  0.7261904761904762
# LF, medijan vrednost Vision:  0.6904761904761905
#
# RS, srednja vrednost Vision:  0.5796973961998592
# RS, medijan vrednost Vision:  0.5714285714285714
#
# ST, srednja vrednost Vision:  0.5318729190906998
# ST, medijan vrednost Vision:  0.5238095238095237
#
# LS, srednja vrednost Vision:  0.5884518058431101
# LS, medijan vrednost Vision:  0.5714285714285714
#
# LW, srednja vrednost Vision:  0.6060492438445193
# LW, medijan vrednost Vision:  0.6071428571428571
#
# RW, srednja vrednost Vision:  0.6119691119691119
# RW, medijan vrednost Vision:  0.6071428571428571
#
# VEZNI RED:
# RDM, srednja vrednost Vision:  0.6459293394777265
# RDM, medijan vrednost Vision:  0.6488095238095237
#
# CDM, srednja vrednost Vision:  0.58710066305003
# CDM, medijan vrednost Vision:  0.5952380952380951
#
# LDM, srednja vrednost Vision:  0.6422692533803644
# LDM, medijan vrednost Vision:  0.6547619047619047
#
# RM, srednja vrednost Vision:  0.6039972038637519
# RM, medijan vrednost Vision:  0.5952380952380951
#
# RCM, srednja vrednost Vision:  0.6694068931920593
# RCM, medijan vrednost Vision:  0.6666666666666666
#
# CM, srednja vrednost Vision:  0.6231553597048575
# CM, medijan vrednost Vision:  0.6309523809523809
#
# LCM, srednja vrednost Vision:  0.6802893309222422
# LCM, medijan vrednost Vision:  0.6904761904761905
#
# LM, srednja vrednost Vision:  0.6098825831702542
# LM, medijan vrednost Vision:  0.6071428571428571
#
# RAM, srednja vrednost Vision:  0.7403628117913831
# RAM, medijan vrednost Vision:  0.738095238095238
#
# CAM, srednja vrednost Vision:  0.665672532060841
# CAM, medijan vrednost Vision:  0.6666666666666666
#
# ODBRANA:
# RWB, srednja vrednost Vision:  0.5027367268746576
# RWB, medijan vrednost Vision:  0.5119047619047619
#
# RB, srednja vrednost Vision:  0.48777249087086416
# RB, medijan vrednost Vision:  0.488095238095238
#
# RCB, srednja vrednost Vision:  0.3985937275212199
# RCB, medijan vrednost Vision:  0.3928571428571428
#
# CB, srednja vrednost Vision:  0.3587297123573838
# CB, medijan vrednost Vision:  0.33333333333333326
#
# LCB, srednja vrednost Vision:  0.40670928865373307
# LCB, medijan vrednost Vision:  0.40476190476190466
#
# LB, srednja vrednost Vision:  0.4891488365391542
# LB, medijan vrednost Vision:  0.5
#
# LWB, srednja vrednost Vision:  0.5291514041514039
# LWB, medijan vrednost Vision:  0.5535714285714285

# %%
show_mean_and_median_for_each_team_position(df, 'Penalties')
# Out:
# GK, srednja vrednost Penalties:  0.17249893571732655
# GK, medijan vrednost Penalties:  0.1724137931034483
#
# NAPAD:
# RF, srednja vrednost Penalties:  0.6961206896551724
# RF, medijan vrednost Penalties:  0.7241379310344827
#
# CF, srednja vrednost Penalties:  0.6247281764523143
# CF, medijan vrednost Penalties:  0.6264367816091954
#
# LF, srednja vrednost Penalties:  0.6888888888888888
# LF, medijan vrednost Penalties:  0.6551724137931034
#
# RS, srednja vrednost Penalties:  0.6868806975822433
# RS, medijan vrednost Penalties:  0.689655172413793
#
# ST, srednja vrednost Penalties:  0.6610355881584934
# ST, medijan vrednost Penalties:  0.6666666666666666
#
# LS, srednja vrednost Penalties:  0.69026597812205
# LS, medijan vrednost Penalties:  0.7011494252873562
#
# LW, srednja vrednost Penalties:  0.6033426856125742
# LW, medijan vrednost Penalties:  0.6091954022988505
#
# RW, srednja vrednost Penalties:  0.6075799937868903
# RW, medijan vrednost Penalties:  0.6206896551724137
#
# VEZNI RED:
# RDM, srednja vrednost Penalties:  0.5624304783092324
# RDM, medijan vrednost Penalties:  0.5632183908045977
#
# CDM, srednja vrednost Penalties:  0.5203210630971433
# CDM, medijan vrednost Penalties:  0.5057471264367815
#
# LDM, srednja vrednost Penalties:  0.5611844283619507
# LDM, medijan vrednost Penalties:  0.5632183908045977
#
# RM, srednja vrednost Penalties:  0.5870454452489057
# RM, medijan vrednost Penalties:  0.5862068965517241
#
# RCM, srednja vrednost Penalties:  0.5810624099714848
# RCM, medijan vrednost Penalties:  0.5632183908045977
#
# CM, srednja vrednost Penalties:  0.5396856808324676
# CM, medijan vrednost Penalties:  0.528735632183908
#
# LCM, srednja vrednost Penalties:  0.5923759639167757
# LCM, medijan vrednost Penalties:  0.5977011494252873
#
# LM, srednja vrednost Penalties:  0.5911719939117198
# LM, medijan vrednost Penalties:  0.5977011494252873
#
# RAM, srednja vrednost Penalties:  0.6737821565407772
# RAM, medijan vrednost Penalties:  0.689655172413793
#
# CAM, srednja vrednost Penalties:  0.6107671633911644
# CAM, medijan vrednost Penalties:  0.6091954022988505
#
# ODBRANA:
# RWB, srednja vrednost Penalties:  0.46584753600211376
# RWB, medijan vrednost Penalties:  0.4482758620689656
#
# RB, srednja vrednost Penalties:  0.460811809432232
# RB, medijan vrednost Penalties:  0.4482758620689656
#
# RCB, srednja vrednost Penalties:  0.43197208042504426
# RCB, medijan vrednost Penalties:  0.41379310344827586
#
# CB, srednja vrednost Penalties:  0.41033448405156253
# CB, medijan vrednost Penalties:  0.40229885057471265
#
# LCB, srednja vrednost Penalties:  0.4382183908045977
# LCB, medijan vrednost Penalties:  0.41379310344827586
#
# LB, srednja vrednost Penalties:  0.46972542473090234
# LB, medijan vrednost Penalties:  0.4482758620689656
#
# LWB, srednja vrednost Penalties:  0.48644267609784836
# LWB, medijan vrednost Penalties:  0.4827586206896552

# %%
show_mean_and_median_for_each_team_position(df, 'Composure')
# Out:
# GK, srednja vrednost Composure:  0.45292977565379006
# GK, medijan vrednost Composure:  0.4623655913978495
#
# NAPAD:
# RF, srednja vrednost Composure:  0.7204301075268817
# RF, medijan vrednost Composure:  0.7043010752688172
#
# CF, srednja vrednost Composure:  0.6232199941877362
# CF, medijan vrednost Composure:  0.6021505376344087
#
# LF, srednja vrednost Composure:  0.7218637992831543
# LF, medijan vrednost Composure:  0.6774193548387097
#
# RS, srednja vrednost Composure:  0.6594628952804706
# RS, medijan vrednost Composure:  0.6666666666666667
#
# ST, srednja vrednost Composure:  0.6112072815532126
# ST, medijan vrednost Composure:  0.6021505376344087
#
# LS, srednja vrednost Composure:  0.6702508960573479
# LS, medijan vrednost Composure:  0.6774193548387097
#
# LW, srednja vrednost Composure:  0.6220190218158216
# LW, medijan vrednost Composure:  0.6236559139784947
#
# RW, srednja vrednost Composure:  0.6227840743969778
# RW, medijan vrednost Composure:  0.6236559139784947
#
# VEZNI RED:
# RDM, srednja vrednost Composure:  0.675685050294832
# RDM, medijan vrednost Composure:  0.6774193548387097
#
# CDM, srednja vrednost Composure:  0.6238714214418585
# CDM, medijan vrednost Composure:  0.6236559139784947
#
# LDM, srednja vrednost Composure:  0.6666224169211027
# LDM, medijan vrednost Composure:  0.6666666666666667
#
# RM, srednja vrednost Composure:  0.6123770711361116
# RM, medijan vrednost Composure:  0.6129032258064517
#
# RCM, srednja vrednost Composure:  0.6799493991144847
# RCM, medijan vrednost Composure:  0.6881720430107527
#
# CM, srednja vrednost Composure:  0.6119853134015212
# CM, medijan vrednost Composure:  0.6129032258064517
#
# LCM, srednja vrednost Composure:  0.6777187967878047
# LCM, medijan vrednost Composure:  0.6774193548387097
#
# LM, srednja vrednost Composure:  0.6178229488879071
# LM, medijan vrednost Composure:  0.6236559139784947
#
# RAM, srednja vrednost Composure:  0.703020993343574
# RAM, medijan vrednost Composure:  0.7096774193548387
#
# CAM, srednja vrednost Composure:  0.6463622690641345
# CAM, medijan vrednost Composure:  0.6451612903225807
#
# ODBRANA:
# RWB, srednja vrednost Composure:  0.577802496601162
# RWB, medijan vrednost Composure:  0.5698924731182796
#
# RB, srednja vrednost Composure:  0.5941380775093078
# RB, medijan vrednost Composure:  0.6129032258064517
#
# RCB, srednja vrednost Composure:  0.6304778611571323
# RCB, medijan vrednost Composure:  0.6344086021505377
#
# CB, srednja vrednost Composure:  0.5728134789602914
# CB, medijan vrednost Composure:  0.5698924731182796
#
# LCB, srednja vrednost Composure:  0.6342924465684324
# LCB, medijan vrednost Composure:  0.6344086021505377
#
# LB, srednja vrednost Composure:  0.5928781741577605
# LB, medijan vrednost Composure:  0.6021505376344087
#
# LWB, srednja vrednost Composure:  0.6065618968844776
# LWB, medijan vrednost Composure:  0.6075268817204302

# %%
show_mean_and_median_for_each_team_position(df, 'Marking')
# Out:
# GK, srednja vrednost Marking:  0.13434269434269436
# GK, medijan vrednost Marking:  0.1208791208791209
#
# NAPAD:
# RF, srednja vrednost Marking:  0.41689560439560447
# RF, medijan vrednost Marking:  0.39560439560439564
#
# CF, srednja vrednost Marking:  0.32551232551232556
# CF, medijan vrednost Marking:  0.29670329670329676
#
# LF, srednja vrednost Marking:  0.4051282051282052
# LF, medijan vrednost Marking:  0.38461538461538464
#
# RS, srednja vrednost Marking:  0.33291831321387977
# RS, medijan vrednost Marking:  0.3186813186813187
#
# ST, srednja vrednost Marking:  0.2897259599238712
# ST, medijan vrednost Marking:  0.27472527472527475
#
# LS, srednja vrednost Marking:  0.33227159314115845
# LS, medijan vrednost Marking:  0.3186813186813187
#
# LW, srednja vrednost Marking:  0.35906088661994173
# LW, medijan vrednost Marking:  0.34065934065934067
#
# RW, srednja vrednost Marking:  0.3594891594891595
# RW, medijan vrednost Marking:  0.34065934065934067
#
# VEZNI RED:
# RDM, srednja vrednost Marking:  0.6770205600850763
# RDM, medijan vrednost Marking:  0.6923076923076924
#
# CDM, srednja vrednost Marking:  0.661543098251959
# CDM, medijan vrednost Marking:  0.6703296703296704
#
# LDM, srednja vrednost Marking:  0.6658074435852215
# LDM, medijan vrednost Marking:  0.6813186813186813
#
# RM, srednja vrednost Marking:  0.419879942121935
# RM, medijan vrednost Marking:  0.40659340659340665
#
# RCM, srednja vrednost Marking:  0.6289030662432197
# RCM, medijan vrednost Marking:  0.6373626373626374
#
# CM, srednja vrednost Marking:  0.5692370756933168
# CM, medijan vrednost Marking:  0.5714285714285715
#
# LCM, srednja vrednost Marking:  0.6158853804423425
# LCM, medijan vrednost Marking:  0.6263736263736265
#
# LM, srednja vrednost Marking:  0.4162677505143259
# LM, medijan vrednost Marking:  0.39560439560439564
#
# RAM, srednja vrednost Marking:  0.3197278911564626
# RAM, medijan vrednost Marking:  0.3076923076923077
#
# CAM, srednja vrednost Marking:  0.4135332308609971
# CAM, medijan vrednost Marking:  0.40659340659340665
#
# ODBRANA:
# RWB, srednja vrednost Marking:  0.632183908045977
# RWB, medijan vrednost Marking:  0.6263736263736265
#
# RB, srednja vrednost Marking:  0.6581234412373065
# RB, medijan vrednost Marking:  0.6593406593406594
#
# RCB, srednja vrednost Marking:  0.7137545234221971
# RCB, medijan vrednost Marking:  0.7142857142857143
#
# CB, srednja vrednost Marking:  0.6627894040717439
# CB, medijan vrednost Marking:  0.6593406593406594
#
# LCB, srednja vrednost Marking:  0.7106905440238774
# LCB, medijan vrednost Marking:  0.7142857142857143
#
# LB, srednja vrednost Marking:  0.6511196821332979
# LB, medijan vrednost Marking:  0.6593406593406594
#
# LWB, srednja vrednost Marking:  0.6489151873767259
# LWB, medijan vrednost Marking:  0.6483516483516484

# %%
show_mean_and_median_for_each_team_position(df, 'StandingTackle')
# Out:
# GK, srednja vrednost StandingTackle:  0.13342016008682675
# GK, medijan vrednost StandingTackle:  0.13186813186813187
#
# NAPAD:
# RF, srednja vrednost StandingTackle:  0.3853021978021978
# RF, medijan vrednost StandingTackle:  0.40659340659340665
#
# CF, srednja vrednost StandingTackle:  0.29610929610929615
# CF, medijan vrednost StandingTackle:  0.2637362637362638
#
# LF, srednja vrednost StandingTackle:  0.36923076923076936
# LF, medijan vrednost StandingTackle:  0.41758241758241765
#
# RS, srednja vrednost StandingTackle:  0.2989227521247226
# RS, medijan vrednost StandingTackle:  0.28571428571428575
#
# ST, srednja vrednost StandingTackle:  0.2606337863284563
# ST, medijan vrednost StandingTackle:  0.2307692307692308
#
# LS, srednja vrednost StandingTackle:  0.2934119021075543
# LS, medijan vrednost StandingTackle:  0.28571428571428575
#
# LW, srednja vrednost StandingTackle:  0.35104265812927227
# LW, medijan vrednost StandingTackle:  0.3296703296703297
#
# RW, srednja vrednost StandingTackle:  0.3403920403920404
# RW, medijan vrednost StandingTackle:  0.3186813186813187
#
# VEZNI RED:
# RDM, srednja vrednost StandingTackle:  0.7135324353066289
# RDM, medijan vrednost StandingTackle:  0.7307692307692308
#
# CDM, srednja vrednost StandingTackle:  0.6991700282839524
# CDM, medijan vrednost StandingTackle:  0.7032967032967034
#
# LDM, srednja vrednost StandingTackle:  0.7028897028897029
# LDM, medijan vrednost StandingTackle:  0.7032967032967034
#
# RM, srednja vrednost StandingTackle:  0.4075612999100544
# RM, medijan vrednost StandingTackle:  0.3846153846153847
#
# RCM, srednja vrednost StandingTackle:  0.6633596582445688
# RCM, medijan vrednost StandingTackle:  0.6813186813186813
#
# CM, srednja vrednost StandingTackle:  0.6067999432418371
# CM, medijan vrednost StandingTackle:  0.6153846153846154
#
# LCM, srednja vrednost StandingTackle:  0.646710251773543
# LCM, medijan vrednost StandingTackle:  0.6703296703296704
#
# LM, srednja vrednost StandingTackle:  0.40888152942947464
# LM, medijan vrednost StandingTackle:  0.3846153846153847
#
# RAM, srednja vrednost StandingTackle:  0.47043432757718473
# RAM, medijan vrednost StandingTackle:  0.4945054945054946
#
# CAM, srednja vrednost StandingTackle:  0.4328844433228567
# CAM, medijan vrednost StandingTackle:  0.4285714285714286
#
# ODBRANA:
# RWB, srednja vrednost StandingTackle:  0.6659088038398382
# RWB, medijan vrednost StandingTackle:  0.6703296703296704
#
# RB, srednja vrednost StandingTackle:  0.7008026829870362
# RB, medijan vrednost StandingTackle:  0.7032967032967034
#
# RCB, srednja vrednost StandingTackle:  0.7466717572457754
# RCB, medijan vrednost StandingTackle:  0.7362637362637363
#
# CB, srednja vrednost StandingTackle:  0.7057441995574729
# CB, medijan vrednost StandingTackle:  0.7032967032967034
#
# LCB, srednja vrednost StandingTackle:  0.7471340388007055
# LCB, medijan vrednost StandingTackle:  0.7472527472527473
#
# LB, srednja vrednost StandingTackle:  0.6983757543515486
# LB, medijan vrednost StandingTackle:  0.6923076923076923
#
# LWB, srednja vrednost StandingTackle:  0.6828684136376443
# LWB, medijan vrednost StandingTackle:  0.6813186813186813

# %%
show_mean_and_median_for_each_team_position(df, 'SlidingTackle')
# Out:
# GK, srednja vrednost SlidingTackle:  0.1258193041526375
# GK, medijan vrednost SlidingTackle:  0.11363636363636365
#
# NAPAD:
# RF, srednja vrednost SlidingTackle:  0.3515625
# RF, medijan vrednost SlidingTackle:  0.33522727272727276
#
# CF, srednja vrednost SlidingTackle:  0.261977886977887
# CF, medijan vrednost SlidingTackle:  0.23295454545454544
#
# LF, srednja vrednost SlidingTackle:  0.36515151515151517
# LF, medijan vrednost SlidingTackle:  0.36363636363636365
#
# RS, srednja vrednost SlidingTackle:  0.2536386027765338
# RS, medijan vrednost SlidingTackle:  0.22727272727272727
#
# ST, srednja vrednost SlidingTackle:  0.2305130532059145
# ST, medijan vrednost SlidingTackle:  0.20454545454545456
#
# LS, srednja vrednost SlidingTackle:  0.26064997804128237
# LS, medijan vrednost SlidingTackle:  0.23863636363636362
#
# LW, srednja vrednost SlidingTackle:  0.3277857313290385
# LW, medijan vrednost SlidingTackle:  0.2954545454545454
#
# RW, srednja vrednost SlidingTackle:  0.32039312039312046
# RW, medijan vrednost SlidingTackle:  0.3068181818181819
#
# VEZNI RED:
# RDM, srednja vrednost SlidingTackle:  0.6844299853372434
# RDM, medijan vrednost SlidingTackle:  0.6931818181818182
#
# CDM, srednja vrednost SlidingTackle:  0.6781142117376295
# CDM, medijan vrednost SlidingTackle:  0.6704545454545455
#
# LDM, srednja vrednost SlidingTackle:  0.6656378600823045
# LDM, medijan vrednost SlidingTackle:  0.6818181818181819
#
# RM, srednja vrednost SlidingTackle:  0.38819354577806536
# RM, medijan vrednost SlidingTackle:  0.36363636363636365
#
# RCM, srednja vrednost SlidingTackle:  0.6303475935828878
# RCM, medijan vrednost SlidingTackle:  0.6590909090909092
#
# CM, srednja vrednost SlidingTackle:  0.5861321246902308
# CM, medijan vrednost SlidingTackle:  0.5909090909090909
#
# LCM, srednja vrednost SlidingTackle:  0.6086881472957423
# LCM, medijan vrednost SlidingTackle:  0.6477272727272728
#
# LM, srednja vrednost SlidingTackle:  0.38738065587380655
# LM, medijan vrednost SlidingTackle:  0.3522727272727273
#
# RAM, srednja vrednost SlidingTackle:  0.40476190476190477
# RAM, medijan vrednost SlidingTackle:  0.375
#
# CAM, srednja vrednost SlidingTackle:  0.4110243879293984
# CAM, medijan vrednost SlidingTackle:  0.40909090909090906
#
# ODBRANA:
# RWB, srednja vrednost SlidingTackle:  0.6617032392894461
# RWB, medijan vrednost SlidingTackle:  0.6590909090909092
#
# RB, srednja vrednost SlidingTackle:  0.7030578832476587
# RB, medijan vrednost SlidingTackle:  0.7045454545454546
#
# RCB, srednja vrednost SlidingTackle:  0.7307230156550398
# RCB, medijan vrednost SlidingTackle:  0.7272727272727273
#
# CB, srednja vrednost SlidingTackle:  0.6912133142448104
# CB, medijan vrednost SlidingTackle:  0.6818181818181819
#
# LCB, srednja vrednost SlidingTackle:  0.7359357463524131
# LCB, medijan vrednost SlidingTackle:  0.7272727272727273
#
# LB, srednja vrednost SlidingTackle:  0.7011845000687664
# LB, medijan vrednost SlidingTackle:  0.7045454545454546
#
# LWB, srednja vrednost SlidingTackle:  0.6821095571095571
# LWB, medijan vrednost SlidingTackle:  0.6704545454545455

# %% [markdown]
# ## Parametri koji golmane čine "superiornijim" u odnosu na igrače na ostalim pozicijama

# %%
show_mean_and_median_for_each_team_position(df, 'GKDiving')
# Out:
# GK, srednja vrednost GKDiving:  0.7227410181717296
# GK, medijan vrednost GKDiving:  0.7191011235955056
#
# NAPAD:
# RF, srednja vrednost GKDiving:  0.10674157303370786
# RF, medijan vrednost GKDiving:  0.10674157303370786
#
# CF, srednja vrednost GKDiving:  0.09474643182508351
# CF, medijan vrednost GKDiving:  0.0898876404494382
#
# LF, srednja vrednost GKDiving:  0.10636704119850186
# LF, medijan vrednost GKDiving:  0.11235955056179775
#
# RS, srednja vrednost GKDiving:  0.10970277301156804
# RS, medijan vrednost GKDiving:  0.11235955056179775
#
# ST, srednja vrednost GKDiving:  0.10758263771306269
# ST, medijan vrednost GKDiving:  0.11235955056179775
#
# LS, srednja vrednost GKDiving:  0.10817999240080338
# LS, medijan vrednost GKDiving:  0.11235955056179775
#
# LW, srednja vrednost GKDiving:  0.10619599516352592
# LW, medijan vrednost GKDiving:  0.11235955056179775
#
# RW, srednja vrednost GKDiving:  0.1066808381415123
# RW, medijan vrednost GKDiving:  0.10112359550561797
#
# VEZNI RED:
# RDM, srednja vrednost GKDiving:  0.10950525552736498
# RDM, medijan vrednost GKDiving:  0.11235955056179775
#
# CDM, srednja vrednost GKDiving:  0.10808087991276726
# CDM, medijan vrednost GKDiving:  0.11235955056179775
#
# LDM, srednja vrednost GKDiving:  0.10634854579923243
# LDM, medijan vrednost GKDiving:  0.11235955056179775
#
# RM, srednja vrednost GKDiving:  0.10693150465832299
# RM, medijan vrednost GKDiving:  0.11235955056179775
#
# RCM, srednja vrednost GKDiving:  0.10891117560849449
# RCM, medijan vrednost GKDiving:  0.11235955056179775
#
# CM, srednja vrednost GKDiving:  0.10525849144810019
# CM, medijan vrednost GKDiving:  0.10112359550561797
#
# LCM, srednja vrednost GKDiving:  0.10849096856777128
# LCM, medijan vrednost GKDiving:  0.11235955056179775
#
# LM, srednja vrednost GKDiving:  0.10628495202914165
# LM, medijan vrednost GKDiving:  0.10112359550561797
#
# RAM, srednja vrednost GKDiving:  0.11396468699839488
# RAM, medijan vrednost GKDiving:  0.11235955056179775
#
# CAM, srednja vrednost GKDiving:  0.1044193192747062
# CAM, medijan vrednost GKDiving:  0.10112359550561797
#
# ODBRANA:
# RWB, srednja vrednost GKDiving:  0.10887253002712129
# RWB, medijan vrednost GKDiving:  0.11235955056179775
#
# RB, srednja vrednost GKDiving:  0.10651093569134631
# RB, medijan vrednost GKDiving:  0.10112359550561797
#
# RCB, srednja vrednost GKDiving:  0.10701313690213517
# RCB, medijan vrednost GKDiving:  0.10112359550561797
#
# CB, srednja vrednost GKDiving:  0.10638136525069199
# CB, medijan vrednost GKDiving:  0.10112359550561797
#
# LCB, srednja vrednost GKDiving:  0.10785129698987378
# LCB, medijan vrednost GKDiving:  0.11235955056179775
#
# LB, srednja vrednost GKDiving:  0.10880688096007073
# LB, medijan vrednost GKDiving:  0.11235955056179775
#
# LWB, srednja vrednost GKDiving:  0.10861423220973783
# LWB, medijan vrednost GKDiving:  0.11235955056179775

# %%
show_mean_and_median_for_each_team_position(df, 'GKHandling')
# Out:
# GK, srednja vrednost GKHandling:  0.67986975986976
# GK, medijan vrednost GKHandling:  0.6813186813186815
#
# NAPAD:
# RF, srednja vrednost GKHandling:  0.11195054945054947
# RF, medijan vrednost GKHandling:  0.1098901098901099
#
# CF, srednja vrednost GKHandling:  0.09414909414909416
# CF, medijan vrednost GKHandling:  0.09890109890109891
#
# LF, srednja vrednost GKHandling:  0.11941391941391943
# LF, medijan vrednost GKHandling:  0.1318681318681319
#
# RS, srednja vrednost GKHandling:  0.11216369837059492
# RS, medijan vrednost GKHandling:  0.1098901098901099
#
# ST, srednja vrednost GKHandling:  0.10651589049624607
# ST, medijan vrednost GKHandling:  0.1098901098901099
#
# LS, srednja vrednost GKHandling:  0.10330732069862504
# LS, medijan vrednost GKHandling:  0.09890109890109891
#
# LW, srednja vrednost GKHandling:  0.10141040062299907
# LW, medijan vrednost GKHandling:  0.09890109890109891
#
# RW, srednja vrednost GKHandling:  0.10430650430650432
# RW, medijan vrednost GKHandling:  0.10439560439560441
#
# VEZNI RED:
# RDM, srednja vrednost GKHandling:  0.10833924140375754
# RDM, medijan vrednost GKHandling:  0.1098901098901099
#
# CDM, srednja vrednost GKHandling:  0.1052649881763806
# CDM, medijan vrednost GKHandling:  0.1098901098901099
#
# LDM, srednja vrednost GKHandling:  0.10744810744810744
# LDM, medijan vrednost GKHandling:  0.1098901098901099
#
# RM, srednja vrednost GKHandling:  0.10570568221813775
# RM, medijan vrednost GKHandling:  0.1098901098901099
#
# RCM, srednja vrednost GKHandling:  0.1056462718866811
# RCM, medijan vrednost GKHandling:  0.1098901098901099
#
# CM, srednja vrednost GKHandling:  0.10304759802607723
# CM, medijan vrednost GKHandling:  0.09890109890109891
#
# LCM, srednja vrednost GKHandling:  0.10415913200723328
# LCM, medijan vrednost GKHandling:  0.1098901098901099
#
# LM, srednja vrednost GKHandling:  0.10533393547092179
# LM, medijan vrednost GKHandling:  0.1098901098901099
#
# RAM, srednja vrednost GKHandling:  0.10256410256410256
# RAM, medijan vrednost GKHandling:  0.09890109890109891
#
# CAM, srednja vrednost GKHandling:  0.10574915689738239
# CAM, medijan vrednost GKHandling:  0.1098901098901099
#
# ODBRANA:
# RWB, srednja vrednost GKHandling:  0.10509031198686371
# RWB, medijan vrednost GKHandling:  0.09890109890109891
#
# RB, srednja vrednost GKHandling:  0.10668959235961561
# RB, medijan vrednost GKHandling:  0.1098901098901099
#
# RCB, srednja vrednost GKHandling:  0.10519239069088014
# RCB, medijan vrednost GKHandling:  0.09890109890109891
#
# CB, srednja vrednost GKHandling:  0.10402477162882114
# CB, medijan vrednost GKHandling:  0.09890109890109891
#
# LCB, srednja vrednost GKHandling:  0.10877085877085879
# LCB, medijan vrednost GKHandling:  0.1098901098901099
#
# LB, srednja vrednost GKHandling:  0.10262506026499976
# LB, medijan vrednost GKHandling:  0.09890109890109891
#
# LWB, srednja vrednost GKHandling:  0.11200338123415045
# LWB, medijan vrednost GKHandling:  0.1098901098901099

# %%
show_mean_and_median_for_each_team_position(df, 'GKKicking')
# Out:
# GK, srednja vrednost GKKicking:  0.6719725651577504
# GK, medijan vrednost GKKicking:  0.6666666666666667
#
# NAPAD:
# RF, srednja vrednost GKKicking:  0.11250000000000002
# RF, medijan vrednost GKKicking:  0.09444444444444444
#
# CF, srednja vrednost GKKicking:  0.0993993993993994
# CF, medijan vrednost GKKicking:  0.1
#
# LF, srednja vrednost GKKicking:  0.09407407407407406
# LF, medijan vrednost GKKicking:  0.08888888888888889
#
# RS, srednja vrednost GKKicking:  0.10711548987411056
# RS, medijan vrednost GKKicking:  0.11111111111111112
#
# ST, srednja vrednost GKKicking:  0.10835914677199573
# ST, medijan vrednost GKKicking:  0.11111111111111112
#
# LS, srednja vrednost GKKicking:  0.10703166935050992
# LS, medijan vrednost GKKicking:  0.1
#
# LW, srednja vrednost GKKicking:  0.10597841936424614
# LW, medijan vrednost GKKicking:  0.1
#
# RW, srednja vrednost GKKicking:  0.10558558558558558
# RW, medijan vrednost GKKicking:  0.11111111111111112
#
# VEZNI RED:
# RDM, srednja vrednost GKKicking:  0.11227598566308246
# RDM, medijan vrednost GKKicking:  0.11111111111111112
#
# CDM, srednja vrednost GKKicking:  0.1063877168307548
# CDM, medijan vrednost GKKicking:  0.11111111111111112
#
# LDM, srednja vrednost GKKicking:  0.10676726108824873
# LDM, medijan vrednost GKKicking:  0.11111111111111112
#
# RM, srednja vrednost GKKicking:  0.10603993673388692
# RM, medijan vrednost GKKicking:  0.1
#
# RCM, srednja vrednost GKKicking:  0.10852514919011082
# RCM, medijan vrednost GKKicking:  0.11111111111111112
#
# CM, srednja vrednost GKKicking:  0.10479834210106807
# CM, medijan vrednost GKKicking:  0.1
#
# LCM, srednja vrednost GKKicking:  0.10407876230661041
# LCM, medijan vrednost GKKicking:  0.1
#
# LM, srednja vrednost GKKicking:  0.10552004058853375
# LM, medijan vrednost GKKicking:  0.1
#
# RAM, srednja vrednost GKKicking:  0.10423280423280425
# RAM, medijan vrednost GKKicking:  0.1
#
# CAM, srednja vrednost GKKicking:  0.10744606819763397
# CAM, medijan vrednost GKKicking:  0.11111111111111112
#
# ODBRANA:
# RWB, srednja vrednost GKKicking:  0.10906768837803318
# RWB, medijan vrednost GKKicking:  0.11111111111111112
#
# RB, srednja vrednost GKKicking:  0.1055426456665806
# RB, medijan vrednost GKKicking:  0.1
#
# RCB, srednja vrednost GKKicking:  0.1090802282645183
# RCB, medijan vrednost GKKicking:  0.11111111111111112
#
# CB, srednja vrednost GKKicking:  0.1055743032120985
# CB, medijan vrednost GKKicking:  0.11111111111111112
#
# LCB, srednja vrednost GKKicking:  0.10565843621399179
# LCB, medijan vrednost GKKicking:  0.1
#
# LB, srednja vrednost GKKicking:  0.1050764834425954
# LB, medijan vrednost GKKicking:  0.1
#
# LWB, srednja vrednost GKKicking:  0.09914529914529914
# LWB, medijan vrednost GKKicking:  0.08888888888888889

# %%
show_mean_and_median_for_each_team_position(df, 'GKPositioning')
# Out:
# GK, srednja vrednost GKPositioning:  0.6971618809821057
# GK, medijan vrednost GKPositioning:  0.696629213483146
#
# NAPAD:
# RF, srednja vrednost GKPositioning:  0.10603932584269662
# RF, medijan vrednost GKPositioning:  0.10112359550561797
#
# CF, srednja vrednost GKPositioning:  0.10081992104464015
# CF, medijan vrednost GKPositioning:  0.10112359550561797
#
# LF, srednja vrednost GKPositioning:  0.12059925093632959
# LF, medijan vrednost GKPositioning:  0.1348314606741573
#
# RS, srednja vrednost GKPositioning:  0.10820833563956385
# RS, medijan vrednost GKPositioning:  0.10112359550561797
#
# ST, srednja vrednost GKPositioning:  0.10849232535109597
# ST, medijan vrednost GKPositioning:  0.11235955056179775
#
# LS, srednja vrednost GKPositioning:  0.10427183412039298
# LS, medijan vrednost GKPositioning:  0.10112359550561797
#
# LW, srednja vrednost GKPositioning:  0.10478044177062137
# LW, medijan vrednost GKPositioning:  0.10112359550561797
#
# RW, srednja vrednost GKPositioning:  0.10464621925296082
# RW, medijan vrednost GKPositioning:  0.10112359550561797
#
# VEZNI RED:
# RDM, srednja vrednost GKPositioning:  0.11254077564334904
# RDM, medijan vrednost GKPositioning:  0.11235955056179775
#
# CDM, srednja vrednost GKPositioning:  0.10761864125539278
# CDM, medijan vrednost GKPositioning:  0.11235955056179775
#
# LDM, srednja vrednost GKPositioning:  0.10981643316225088
# LDM, medijan vrednost GKPositioning:  0.11235955056179775
#
# RM, srednja vrednost GKPositioning:  0.1071114398816426
# RM, medijan vrednost GKPositioning:  0.11235955056179775
#
# RCM, srednja vrednost GKPositioning:  0.10807781832811288
# RCM, medijan vrednost GKPositioning:  0.11235955056179775
#
# CM, srednja vrednost GKPositioning:  0.10740251156642433
# CM, medijan vrednost GKPositioning:  0.11235955056179775
#
# LCM, srednja vrednost GKPositioning:  0.10746693215758783
# LCM, medijan vrednost GKPositioning:  0.10112359550561797
#
# LM, srednja vrednost GKPositioning:  0.10631573546765175
# LM, medijan vrednost GKPositioning:  0.10112359550561797
#
# RAM, srednja vrednost GKPositioning:  0.09898341359015517
# RAM, medijan vrednost GKPositioning:  0.0898876404494382
#
# CAM, srednja vrednost GKPositioning:  0.10664774459900071
# CAM, medijan vrednost GKPositioning:  0.10112359550561797
#
# ODBRANA:
# RWB, srednja vrednost GKPositioning:  0.1035774247707607
# RWB, medijan vrednost GKPositioning:  0.10112359550561797
#
# RB, srednja vrednost GKPositioning:  0.10645871591571726
# RB, medijan vrednost GKPositioning:  0.10112359550561797
#
# RCB, srednja vrednost GKPositioning:  0.10820122882650464
# RCB, medijan vrednost GKPositioning:  0.11235955056179775
#
# CB, srednja vrednost GKPositioning:  0.10801809886123785
# CB, medijan vrednost GKPositioning:  0.11235955056179775
#
# LCB, srednja vrednost GKPositioning:  0.10799001248439451
# LCB, medijan vrednost GKPositioning:  0.11235955056179775
#
# LB, srednja vrednost GKPositioning:  0.10688605959645751
# LB, medijan vrednost GKPositioning:  0.10112359550561797
#
# LWB, srednja vrednost GKPositioning:  0.099250936329588
# LWB, medijan vrednost GKPositioning:  0.0898876404494382

# %%
show_mean_and_median_for_each_team_position(df, 'GKReflexes')
# Out:
# GK, srednja vrednost GKReflexes:  0.7000185848931368
# GK, medijan vrednost GKReflexes:  0.6989247311827957
#
# NAPAD:
# RF, srednja vrednost GKReflexes:  0.09610215053763442
# RF, medijan vrednost GKReflexes:  0.0913978494623656
#
# CF, srednja vrednost GKReflexes:  0.09968032548677712
# CF, medijan vrednost GKReflexes:  0.10215053763440861
#
# LF, srednja vrednost GKReflexes:  0.10537634408602149
# LF, medijan vrednost GKReflexes:  0.11827956989247311
#
# RS, srednja vrednost GKReflexes:  0.102971555696806
# RS, medijan vrednost GKReflexes:  0.09677419354838711
#
# ST, srednja vrednost GKReflexes:  0.1036532043391993
# ST, medijan vrednost GKReflexes:  0.10752688172043011
#
# LS, srednja vrednost GKReflexes:  0.1032154173809153
# LS, medijan vrednost GKReflexes:  0.09677419354838711
#
# LW, srednja vrednost GKReflexes:  0.10128975813507184
# LW, medijan vrednost GKReflexes:  0.09677419354838711
#
# RW, srednja vrednost GKReflexes:  0.09959314152862539
# RW, medijan vrednost GKReflexes:  0.09677419354838711
#
# VEZNI RED:
# RDM, srednja vrednost GKReflexes:  0.10791710024280264
# RDM, medijan vrednost GKReflexes:  0.10752688172043011
#
# CDM, srednja vrednost GKReflexes:  0.10285377251485867
# CDM, medijan vrednost GKReflexes:  0.10752688172043011
#
# LDM, srednja vrednost GKReflexes:  0.10292490818177795
# LDM, medijan vrednost GKReflexes:  0.10752688172043011
#
# RM, srednja vrednost GKReflexes:  0.10294455286419471
# RM, medijan vrednost GKReflexes:  0.10752688172043011
#
# RCM, srednja vrednost GKReflexes:  0.10235679124384679
# RCM, medijan vrednost GKReflexes:  0.09677419354838711
#
# CM, srednja vrednost GKReflexes:  0.10141003687076719
# CM, medijan vrednost GKReflexes:  0.10215053763440861
#
# LCM, srednja vrednost GKReflexes:  0.10186470668299988
# LCM, medijan vrednost GKReflexes:  0.09677419354838711
#
# LM, srednja vrednost GKReflexes:  0.10240094270142878
# LM, medijan vrednost GKReflexes:  0.10752688172043011
#
# RAM, srednja vrednost GKReflexes:  0.11520737327188939
# RAM, medijan vrednost GKReflexes:  0.11827956989247311
#
# CAM, srednja vrednost GKReflexes:  0.10072507688508765
# CAM, medijan vrednost GKReflexes:  0.09677419354838711
#
# ODBRANA:
# RWB, srednja vrednost GKReflexes:  0.09726857001606729
# RWB, medijan vrednost GKReflexes:  0.09677419354838711
#
# RB, srednja vrednost GKReflexes:  0.10160499071320891
# RB, medijan vrednost GKReflexes:  0.09677419354838711
#
# RCB, srednja vrednost GKReflexes:  0.10400220901146738
# RCB, medijan vrednost GKReflexes:  0.10752688172043011
#
# CB, srednja vrednost GKReflexes:  0.10256782418326742
# CB, medijan vrednost GKReflexes:  0.10752688172043011
#
# LCB, srednja vrednost GKReflexes:  0.10147019779636267
# LCB, medijan vrednost GKReflexes:  0.09677419354838711
#
# LB, srednja vrednost GKReflexes:  0.10287443267776097
# LB, medijan vrednost GKReflexes:  0.10752688172043011
#
# LWB, srednja vrednost GKReflexes:  0.10476978218913705
# LWB, medijan vrednost GKReflexes:  0.10752688172043011

# %% [markdown]
# ## Odbacivanje svih onih kolona koje golmane razlikuju od igrača na ostalim pozicijama

# %%
# Print percentige of five clusters

def print_percentige_of_five_clusters(df):
    
    df['cluster_marks'] = kmeans.labels_

    df_cluster_0 = df.loc[df['cluster_marks'] == 0]
    df_cluster_1 = df.loc[df['cluster_marks'] == 1]
    df_cluster_2 = df.loc[df['cluster_marks'] == 2]
    df_cluster_3 = df.loc[df['cluster_marks'] == 3]
    df_cluster_4 = df.loc[df['cluster_marks'] == 4]

    show_position_percentige_per_cluster(df_cluster_0, 0, len(df))
    show_position_percentige_per_cluster(df_cluster_1, 1, len(df))
    show_position_percentige_per_cluster(df_cluster_2, 2, len(df))
    show_position_percentige_per_cluster(df_cluster_3, 3, len(df))
    show_position_percentige_per_cluster(df_cluster_4, 4, len(df))

# %%
def draw(df):
    
    df1 = df.replace({'RF': 'ATT', 'LF': 'ATT', 'RW': 'ATT', 'LW': 'ATT', 'ST': 'ATT', 'CF': 'ATT', 'RS': 'ATT', 'LS': 'ATT',
            'RDM': 'MF', 'CDM': 'MF', 'LDM': 'MF', 'RM': 'MF', 'RCM': 'MF', 'CM': 'MF', 'LCM': 'MF', 'LM': 'MF', 'RAM': 'MF', 'CAM': 'MF', 'LAM': 'MF',
            'RWB': 'DF', 'RB': 'DF', 'RCB': 'DF', 'CB': 'DF', 'LCB': 'DF', 'LB': 'DF', 'LWB': 'DF'})
    
    plt.figure(num=None, figsize=(8, 6), dpi=200)
    sns.countplot(x='cluster_marks', hue='Position', data=df1)

# %%
columns_to_drop = ['Special', 'Skill Moves', 'Crossing', 'Finishing', 'HeadingAccuracy',
                   'ShortPassing', 'Volleys', 'Dribbling', 'Curve', 'FKAccuracy',
                   'LongPassing', 'BallControl', 'Acceleration', 'SprintSpeed',
                   'Agility', 'Balance', 'ShotPower', 'Stamina', 'LongShots', 
                   'Aggression', 'Interceptions', 'Positioning', 'Vision', 'Penalties',
                   'Composure', 'Marking', 'StandingTackle', 'SlidingTackle',
                   'GKDiving', 'GKHandling', 'GKKicking', 'GKPositioning', 'GKReflexes']

# %%
kmeans = KMeans(n_clusters=5, random_state=0)
kmeans.fit(df[numeric].drop(columns=columns_to_drop, axis=1))
# Out:
# KMeans(n_clusters=5, random_state=0)

# %%
print_percentige_of_five_clusters(df)
# Out:
# Broj igraca u klasteru 0: 616, (3.3833141099577086 %)
#
# NAPAD: 169 (27.435064935064936 %)
# Broj igraca na poziciji RF: 0, (0.0 %)
# Broj igraca na poziciji LF: 0, (0.0 %)
# Broj igraca na poziciji RW: 22, (3.571428571428571 %)
# Broj igraca na poziciji LW: 21, (3.4090909090909087 %)
# Broj igraca na poziciji ST: 111, (18.019480519480517 %)
# Broj igraca na poziciji CF: 2, (0.3246753246753247 %)
# Broj igraca na poziciji RS: 7, (1.1363636363636365 %)
# Broj igraca na poziciji LS: 6, (0.974025974025974 %)
#
# VEZNI RED: 230 (37.33766233766234 %)
# Broj igraca na poziciji RDM: 8, (1.2987012987012987 %)
# Broj igraca na poziciji CDM: 37, (6.0064935064935066 %)
# Broj igraca na poziciji LDM: 8, (1.2987012987012987 %)
# Broj igraca na poziciji RM: 36, (5.844155844155844 %)
# Broj igraca na poziciji RCM: 8, (1.2987012987012987 %)
# Broj igraca na poziciji CM: 45, (7.305194805194805 %)
# Broj igraca na poziciji LCM: 4, (0.6493506493506493 %)
# Broj igraca na poziciji LM: 51, (8.279220779220779 %)
# Broj igraca na poziciji RAM: 1, (0.16233766233766234 %)
# Broj igraca na poziciji CAM: 32, (5.194805194805195 %)
# Broj igraca na poziciji LAM: 0, (0.0 %)
#
# ODBRANA: 139 (22.564935064935064 %)
# Broj igraca na poziciji RWB: 5, (0.8116883116883116 %)
# Broj igraca na poziciji RB: 42, (6.8181818181818175 %)
# Broj igraca na poziciji RCB: 10, (1.6233766233766231 %)
# Broj igraca na poziciji CB: 43, (6.98051948051948 %)
# Broj igraca na poziciji LCB: 6, (0.974025974025974 %)
# Broj igraca na poziciji LB: 33, (5.357142857142857 %)
# Broj igraca na poziciji LWB: 0, (0.0 %)
#
# GOLMANI: 78 (12.662337662337661 %)
#
# Broj igraca u klasteru 1: 5040, (27.68166089965398 %)
#
# NAPAD: 1065 (21.13095238095238 %)
# Broj igraca na poziciji RF: 10, (0.1984126984126984 %)
# Broj igraca na poziciji LF: 7, (0.1388888888888889 %)
# Broj igraca na poziciji RW: 127, (2.5198412698412698 %)
# Broj igraca na poziciji LW: 130, (2.579365079365079 %)
# Broj igraca na poziciji ST: 607, (12.043650793650794 %)
# Broj igraca na poziciji CF: 24, (0.4761904761904762 %)
# Broj igraca na poziciji RS: 81, (1.607142857142857 %)
# Broj igraca na poziciji LS: 79, (1.5674603174603174 %)
#
# VEZNI RED: 2259 (44.82142857142858 %)
# Broj igraca na poziciji RDM: 97, (1.9246031746031746 %)
# Broj igraca na poziciji CDM: 285, (5.654761904761905 %)
# Broj igraca na poziciji LDM: 88, (1.746031746031746 %)
# Broj igraca na poziciji RM: 394, (7.817460317460317 %)
# Broj igraca na poziciji RCM: 155, (3.075396825396825 %)
# Broj igraca na poziciji CM: 360, (7.142857142857142 %)
# Broj igraca na poziciji LCM: 154, (3.0555555555555554 %)
# Broj igraca na poziciji LM: 386, (7.658730158730159 %)
# Broj igraca na poziciji RAM: 12, (0.2380952380952381 %)
# Broj igraca na poziciji CAM: 319, (6.329365079365079 %)
# Broj igraca na poziciji LAM: 9, (0.17857142857142858 %)
#
# ODBRANA: 1480 (29.365079365079367 %)
# Broj igraca na poziciji RWB: 23, (0.4563492063492064 %)
# Broj igraca na poziciji RB: 372, (7.380952380952381 %)
# Broj igraca na poziciji RCB: 160, (3.1746031746031744 %)
# Broj igraca na poziciji CB: 384, (7.6190476190476195 %)
# Broj igraca na poziciji LCB: 178, (3.5317460317460316 %)
# Broj igraca na poziciji LB: 342, (6.785714285714286 %)
# Broj igraca na poziciji LWB: 21, (0.4166666666666667 %)
#
# GOLMANI: 236 (4.682539682539683 %)
#
# Broj igraca u klasteru 2: 5140, (28.23090020321854 %)
#
# NAPAD: 978 (19.027237354085603 %)
# Broj igraca na poziciji RF: 0, (0.0 %)
# Broj igraca na poziciji LF: 0, (0.0 %)
# Broj igraca na poziciji RW: 135, (2.6264591439688716 %)
# Broj igraca na poziciji LW: 148, (2.8793774319066148 %)
# Broj igraca na poziciji ST: 634, (12.334630350194553 %)
# Broj igraca na poziciji CF: 25, (0.48638132295719844 %)
# Broj igraca na poziciji RS: 17, (0.33073929961089493 %)
# Broj igraca na poziciji LS: 19, (0.3696498054474708 %)
#
# VEZNI RED: 2044 (39.766536964980546 %)
# Broj igraca na poziciji RDM: 16, (0.311284046692607 %)
# Broj igraca na poziciji CDM: 211, (4.1050583657587545 %)
# Broj igraca na poziciji LDM: 25, (0.48638132295719844 %)
# Broj igraca na poziciji RM: 391, (7.607003891050583 %)
# Broj igraca na poziciji RCM: 41, (0.7976653696498054 %)
# Broj igraca na poziciji CM: 606, (11.78988326848249 %)
# Broj igraca na poziciji LCM: 46, (0.8949416342412451 %)
# Broj igraca na poziciji LM: 362, (7.042801556420233 %)
# Broj igraca na poziciji RAM: 1, (0.019455252918287938 %)
# Broj igraca na poziciji CAM: 345, (6.712062256809339 %)
# Broj igraca na poziciji LAM: 0, (0.0 %)
#
# ODBRANA: 1288 (25.058365758754864 %)
# Broj igraca na poziciji RWB: 26, (0.5058365758754864 %)
# Broj igraca na poziciji RB: 325, (6.3229571984435795 %)
# Broj igraca na poziciji RCB: 35, (0.6809338521400778 %)
# Broj igraca na poziciji CB: 485, (9.43579766536965 %)
# Broj igraca na poziciji LCB: 35, (0.6809338521400778 %)
# Broj igraca na poziciji LB: 363, (7.062256809338521 %)
# Broj igraca na poziciji LWB: 19, (0.3696498054474708 %)
#
# GOLMANI: 830 (16.147859922178988 %)
#
# Broj igraca u klasteru 3: 5901, (32.410611303344865 %)
#
# NAPAD: 929 (15.743094390781224 %)
# Broj igraca na poziciji RF: 2, (0.03389256058295204 %)
# Broj igraca na poziciji LF: 3, (0.05083884087442806 %)
# Broj igraca na poziciji RW: 46, (0.779528893407897 %)
# Broj igraca na poziciji LW: 56, (0.9489916963226572 %)
# Broj igraca na poziciji ST: 670, (11.354007795288934 %)
# Broj igraca na poziciji CF: 13, (0.2203016437891883 %)
# Broj igraca na poziciji RS: 69, (1.1692933401118455 %)
# Broj igraca na poziciji LS: 70, (1.1862396204033214 %)
#
# VEZNI RED: 1716 (29.07981698017285 %)
# Broj igraca na poziciji RDM: 102, (1.728520589730554 %)
# Broj igraca na poziciji CDM: 328, (5.558379935604135 %)
# Broj igraca na poziciji LDM: 103, (1.7454668700220302 %)
# Broj igraca na poziciji RM: 222, (3.7620742247076766 %)
# Broj igraca na poziciji RCM: 128, (2.1691238773089307 %)
# Broj igraca na poziciji CM: 293, (4.965260125402474 %)
# Broj igraca na poziciji LCM: 135, (2.2877478393492625 %)
# Broj igraca na poziciji LM: 217, (3.6773428232502967 %)
# Broj igraca na poziciji RAM: 5, (0.0847314014573801 %)
# Broj igraca na poziciji CAM: 173, (2.9317064904253516 %)
# Broj igraca na poziciji LAM: 10, (0.1694628029147602 %)
#
# ODBRANA: 2508 (42.50127097102186 %)
# Broj igraca na poziciji RWB: 24, (0.4067107269954245 %)
# Broj igraca na poziciji RB: 464, (7.863074055244875 %)
# Broj igraca na poziciji RCB: 385, (6.524317912218268 %)
# Broj igraca na poziciji CB: 752, (12.743602779189967 %)
# Broj igraca na poziciji LCB: 352, (5.965090662599559 %)
# Broj igraca na poziciji LB: 499, (8.456193865446535 %)
# Broj igraca na poziciji LWB: 32, (0.5422809693272327 %)
#
# GOLMANI: 748 (12.675817658024064 %)
#
# Broj igraca u klasteru 4: 1510, (8.293513483824903 %)
#
# NAPAD: 337 (22.317880794701985 %)
# Broj igraca na poziciji RF: 4, (0.26490066225165565 %)
# Broj igraca na poziciji LF: 5, (0.33112582781456956 %)
# Broj igraca na poziciji RW: 40, (2.6490066225165565 %)
# Broj igraca na poziciji LW: 26, (1.7218543046357615 %)
# Broj igraca na poziciji ST: 190, (12.582781456953644 %)
# Broj igraca na poziciji CF: 10, (0.6622516556291391 %)
# Broj igraca na poziciji RS: 29, (1.9205298013245033 %)
# Broj igraca na poziciji LS: 33, (2.185430463576159 %)
#
# VEZNI RED: 589 (39.00662251655629 %)
# Broj igraca na poziciji RDM: 25, (1.6556291390728477 %)
# Broj igraca na poziciji CDM: 87, (5.76158940397351 %)
# Broj igraca na poziciji LDM: 19, (1.2582781456953642 %)
# Broj igraca na poziciji RM: 81, (5.364238410596026 %)
# Broj igraca na poziciji RCM: 59, (3.90728476821192 %)
# Broj igraca na poziciji CM: 90, (5.960264900662252 %)
# Broj igraca na poziciji LCM: 56, (3.708609271523179 %)
# Broj igraca na poziciji LM: 79, (5.231788079470199 %)
# Broj igraca na poziciji RAM: 2, (0.13245033112582782 %)
# Broj igraca na poziciji CAM: 89, (5.894039735099338 %)
# Broj igraca na poziciji LAM: 2, (0.13245033112582782 %)
#
# ODBRANA: 451 (29.867549668874172 %)
# Broj igraca na poziciji RWB: 9, (0.5960264900662252 %)
# Broj igraca na poziciji RB: 88, (5.827814569536424 %)
# Broj igraca na poziciji RCB: 72, (4.768211920529802 %)
# Broj igraca na poziciji CB: 114, (7.549668874172186 %)
# Broj igraca na poziciji LCB: 77, (5.099337748344371 %)
# Broj igraca na poziciji LB: 85, (5.629139072847682 %)
# Broj igraca na poziciji LWB: 6, (0.3973509933774834 %)
#
# GOLMANI: 133 (8.80794701986755 %)

# %%
draw(df)

# %% [markdown]
# ## Zadržavanje samo onih kolona koje golmane razlikuju od igrača na ostalim pozicijama

# %%
columns_to_keep = ['Special', 'Skill Moves', 'Crossing', 'Finishing', 'HeadingAccuracy',
                   'ShortPassing', 'Volleys', 'Dribbling', 'Curve', 'FKAccuracy',
                   'LongPassing', 'BallControl', 'Acceleration', 'SprintSpeed',
                   'Agility', 'Balance', 'ShotPower', 'Stamina', 'LongShots', 
                   'Aggression', 'Interceptions', 'Positioning', 'Vision', 'Penalties',
                   'Composure', 'Marking', 'StandingTackle', 'SlidingTackle',
                  'GKDiving', 'GKHandling', 'GKKicking', 'GKPositioning', 'GKReflexes']

# %%
kmeans = KMeans(n_clusters=5, random_state=0)
kmeans.fit(df[columns_to_keep])
# Out:
# KMeans(n_clusters=5, random_state=0)

# %%
print_percentige_of_five_clusters(df)
# Out:
# Broj igraca u klasteru 0: 3070, (16.861646619432086 %)
#
# NAPAD: 1332 (43.387622149837135 %)
# Broj igraca na poziciji RF: 14, (0.4560260586319218 %)
# Broj igraca na poziciji LF: 13, (0.4234527687296417 %)
# Broj igraca na poziciji RW: 191, (6.221498371335505 %)
# Broj igraca na poziciji LW: 194, (6.319218241042346 %)
# Broj igraca na poziciji ST: 666, (21.693811074918568 %)
# Broj igraca na poziciji CF: 36, (1.1726384364820848 %)
# Broj igraca na poziciji RS: 107, (3.4853420195439737 %)
# Broj igraca na poziciji LS: 111, (3.6156351791530943 %)
#
# VEZNI RED: 1732 (56.41693811074918 %)
# Broj igraca na poziciji RDM: 9, (0.2931596091205212 %)
# Broj igraca na poziciji CDM: 3, (0.09771986970684039 %)
# Broj igraca na poziciji LDM: 12, (0.39087947882736157 %)
# Broj igraca na poziciji RM: 493, (16.058631921824105 %)
# Broj igraca na poziciji RCM: 44, (1.4332247557003257 %)
# Broj igraca na poziciji CM: 83, (2.7035830618892507 %)
# Broj igraca na poziciji LCM: 65, (2.1172638436482085 %)
# Broj igraca na poziciji LM: 493, (16.058631921824105 %)
# Broj igraca na poziciji RAM: 17, (0.5537459283387622 %)
# Broj igraca na poziciji CAM: 494, (16.091205211726383 %)
# Broj igraca na poziciji LAM: 19, (0.6188925081433224 %)
#
# ODBRANA: 6 (0.19543973941368079 %)
# Broj igraca na poziciji RWB: 1, (0.03257328990228013 %)
# Broj igraca na poziciji RB: 0, (0.0 %)
# Broj igraca na poziciji RCB: 1, (0.03257328990228013 %)
# Broj igraca na poziciji CB: 0, (0.0 %)
# Broj igraca na poziciji LCB: 0, (0.0 %)
# Broj igraca na poziciji LB: 3, (0.09771986970684039 %)
# Broj igraca na poziciji LWB: 1, (0.03257328990228013 %)
#
# GOLMANI: 0 (0.0 %)
#
# Broj igraca u klasteru 1: 2026, (11.127588290218048 %)
#
# NAPAD: 1 (0.04935834155972359 %)
# Broj igraca na poziciji RF: 0, (0.0 %)
# Broj igraca na poziciji LF: 0, (0.0 %)
# Broj igraca na poziciji RW: 0, (0.0 %)
# Broj igraca na poziciji LW: 0, (0.0 %)
# Broj igraca na poziciji ST: 1, (0.04935834155972359 %)
# Broj igraca na poziciji CF: 0, (0.0 %)
# Broj igraca na poziciji RS: 0, (0.0 %)
# Broj igraca na poziciji LS: 0, (0.0 %)
#
# VEZNI RED: 0 (0.0 %)
# Broj igraca na poziciji RDM: 0, (0.0 %)
# Broj igraca na poziciji CDM: 0, (0.0 %)
# Broj igraca na poziciji LDM: 0, (0.0 %)
# Broj igraca na poziciji RM: 0, (0.0 %)
# Broj igraca na poziciji RCM: 0, (0.0 %)
# Broj igraca na poziciji CM: 0, (0.0 %)
# Broj igraca na poziciji LCM: 0, (0.0 %)
# Broj igraca na poziciji LM: 0, (0.0 %)
# Broj igraca na poziciji RAM: 0, (0.0 %)
# Broj igraca na poziciji CAM: 0, (0.0 %)
# Broj igraca na poziciji LAM: 0, (0.0 %)
#
# ODBRANA: 0 (0.0 %)
# Broj igraca na poziciji RWB: 0, (0.0 %)
# Broj igraca na poziciji RB: 0, (0.0 %)
# Broj igraca na poziciji RCB: 0, (0.0 %)
# Broj igraca na poziciji CB: 0, (0.0 %)
# Broj igraca na poziciji LCB: 0, (0.0 %)
# Broj igraca na poziciji LB: 0, (0.0 %)
# Broj igraca na poziciji LWB: 0, (0.0 %)
#
# GOLMANI: 2025 (99.95064165844028 %)
#
# Broj igraca u klasteru 2: 4726, (25.957049486461255 %)
#
# NAPAD: 12 (0.25391451544646637 %)
# Broj igraca na poziciji RF: 0, (0.0 %)
# Broj igraca na poziciji LF: 0, (0.0 %)
# Broj igraca na poziciji RW: 1, (0.021159542953872196 %)
# Broj igraca na poziciji LW: 1, (0.021159542953872196 %)
# Broj igraca na poziciji ST: 10, (0.21159542953872196 %)
# Broj igraca na poziciji CF: 0, (0.0 %)
# Broj igraca na poziciji RS: 0, (0.0 %)
# Broj igraca na poziciji LS: 0, (0.0 %)
#
# VEZNI RED: 861 (18.21836648328396 %)
# Broj igraca na poziciji RDM: 37, (0.7829030892932712 %)
# Broj igraca na poziciji CDM: 353, (7.469318662716885 %)
# Broj igraca na poziciji LDM: 36, (0.761743546339399 %)
# Broj igraca na poziciji RM: 29, (0.6136267456622937 %)
# Broj igraca na poziciji RCM: 31, (0.655945831570038 %)
# Broj igraca na poziciji CM: 306, (6.474820143884892 %)
# Broj igraca na poziciji LCM: 30, (0.6347862886161659 %)
# Broj igraca na poziciji LM: 30, (0.6347862886161659 %)
# Broj igraca na poziciji RAM: 0, (0.0 %)
# Broj igraca na poziciji CAM: 9, (0.19043588658484975 %)
# Broj igraca na poziciji LAM: 0, (0.0 %)
#
# ODBRANA: 3853 (81.52771900126957 %)
# Broj igraca na poziciji RWB: 37, (0.7829030892932712 %)
# Broj igraca na poziciji RB: 580, (12.272534913245874 %)
# Broj igraca na poziciji RCB: 542, (11.46847228099873 %)
# Broj igraca na poziciji CB: 1587, (33.580194667795176 %)
# Broj igraca na poziciji LCB: 519, (10.98180279305967 %)
# Broj igraca na poziciji LB: 561, (11.870503597122301 %)
# Broj igraca na poziciji LWB: 27, (0.5713076597545493 %)
#
# GOLMANI: 0 (0.0 %)
#
# Broj igraca u klasteru 3: 4995, (27.434503213049926 %)
#
# NAPAD: 78 (1.5615615615615615 %)
# Broj igraca na poziciji RF: 1, (0.02002002002002002 %)
# Broj igraca na poziciji LF: 1, (0.02002002002002002 %)
# Broj igraca na poziciji RW: 23, (0.4604604604604604 %)
# Broj igraca na poziciji LW: 26, (0.5205205205205206 %)
# Broj igraca na poziciji ST: 22, (0.44044044044044045 %)
# Broj igraca na poziciji CF: 0, (0.0 %)
# Broj igraca na poziciji RS: 4, (0.08008008008008008 %)
# Broj igraca na poziciji LS: 1, (0.02002002002002002 %)
#
# VEZNI RED: 2925 (58.55855855855856 %)
# Broj igraca na poziciji RDM: 199, (3.983983983983984 %)
# Broj igraca na poziciji CDM: 591, (11.831831831831833 %)
# Broj igraca na poziciji LDM: 193, (3.863863863863864 %)
# Broj igraca na poziciji RM: 182, (3.6436436436436437 %)
# Broj igraca na poziciji RCM: 303, (6.066066066066067 %)
# Broj igraca na poziciji CM: 825, (16.516516516516518 %)
# Broj igraca na poziciji LCM: 285, (5.7057057057057055 %)
# Broj igraca na poziciji LM: 185, (3.7037037037037033 %)
# Broj igraca na poziciji RAM: 3, (0.06006006006006006 %)
# Broj igraca na poziciji CAM: 159, (3.183183183183183 %)
# Broj igraca na poziciji LAM: 0, (0.0 %)
#
# ODBRANA: 1992 (39.87987987987988 %)
# Broj igraca na poziciji RWB: 47, (0.9409409409409409 %)
# Broj igraca na poziciji RB: 708, (14.174174174174173 %)
# Broj igraca na poziciji RCB: 119, (2.3823823823823824 %)
# Broj igraca na poziciji CB: 188, (3.7637637637637638 %)
# Broj igraca na poziciji LCB: 128, (2.5625625625625625 %)
# Broj igraca na poziciji LB: 754, (15.095095095095095 %)
# Broj igraca na poziciji LWB: 48, (0.960960960960961 %)
#
# GOLMANI: 0 (0.0 %)
#
# Broj igraca u klasteru 4: 3390, (18.619212390838687 %)
#
# NAPAD: 2055 (60.61946902654868 %)
# Broj igraca na poziciji RF: 1, (0.029498525073746312 %)
# Broj igraca na poziciji LF: 1, (0.029498525073746312 %)
# Broj igraca na poziciji RW: 155, (4.572271386430678 %)
# Broj igraca na poziciji LW: 160, (4.71976401179941 %)
# Broj igraca na poziciji ST: 1513, (44.63126843657817 %)
# Broj igraca na poziciji CF: 38, (1.12094395280236 %)
# Broj igraca na poziciji RS: 92, (2.713864306784661 %)
# Broj igraca na poziciji LS: 95, (2.8023598820058995 %)
#
# VEZNI RED: 1320 (38.93805309734513 %)
# Broj igraca na poziciji RDM: 3, (0.08849557522123894 %)
# Broj igraca na poziciji CDM: 1, (0.029498525073746312 %)
# Broj igraca na poziciji LDM: 2, (0.058997050147492625 %)
# Broj igraca na poziciji RM: 420, (12.389380530973451 %)
# Broj igraca na poziciji RCM: 13, (0.38348082595870203 %)
# Broj igraca na poziciji CM: 180, (5.3097345132743365 %)
# Broj igraca na poziciji LCM: 15, (0.4424778761061947 %)
# Broj igraca na poziciji LM: 387, (11.415929203539823 %)
# Broj igraca na poziciji RAM: 1, (0.029498525073746312 %)
# Broj igraca na poziciji CAM: 296, (8.731563421828909 %)
# Broj igraca na poziciji LAM: 2, (0.058997050147492625 %)
#
# ODBRANA: 15 (0.4424778761061947 %)
# Broj igraca na poziciji RWB: 2, (0.058997050147492625 %)
# Broj igraca na poziciji RB: 3, (0.08849557522123894 %)
# Broj igraca na poziciji RCB: 0, (0.0 %)
# Broj igraca na poziciji CB: 3, (0.08849557522123894 %)
# Broj igraca na poziciji LCB: 1, (0.029498525073746312 %)
# Broj igraca na poziciji LB: 4, (0.11799410029498525 %)
# Broj igraca na poziciji LWB: 2, (0.058997050147492625 %)
#
# GOLMANI: 0 (0.0 %)

# %%
draw(df)

# %% [markdown]
# ## Zadržavanje samo onih kolona koje golmane čine "inferiornijim" u odnosu na igrače na ostalim pozicijama

# %%
columns_to_keep = ['Special', 'Skill Moves', 'Crossing', 'Finishing', 'HeadingAccuracy',
                   'ShortPassing', 'Volleys', 'Dribbling', 'Curve', 'FKAccuracy',
                   'LongPassing', 'BallControl', 'Acceleration', 'SprintSpeed',
                   'Agility', 'Balance', 'ShotPower', 'Stamina', 'LongShots', 
                   'Aggression', 'Interceptions', 'Positioning', 'Vision', 'Penalties',
                   'Composure', 'Marking', 'StandingTackle', 'SlidingTackle']

# %%
kmeans = KMeans(n_clusters=5, random_state=0)
kmeans.fit(df[columns_to_keep])
# Out:
# KMeans(n_clusters=5, random_state=0)

# %%
print_percentige_of_five_clusters(df)
# Out:
# Broj igraca u klasteru 0: 3394, (18.64118196298127 %)
#
# NAPAD: 2059 (60.665880966411315 %)
# Broj igraca na poziciji RF: 1, (0.02946375957572186 %)
# Broj igraca na poziciji LF: 1, (0.02946375957572186 %)
# Broj igraca na poziciji RW: 156, (4.596346493812611 %)
# Broj igraca na poziciji LW: 160, (4.714201532115498 %)
# Broj igraca na poziciji ST: 1516, (44.667059516794346 %)
# Broj igraca na poziciji CF: 38, (1.1196228638774306 %)
# Broj igraca na poziciji RS: 92, (2.710665880966411 %)
# Broj igraca na poziciji LS: 95, (2.799057159693577 %)
#
# VEZNI RED: 1320 (38.89216263995286 %)
# Broj igraca na poziciji RDM: 3, (0.0883912787271656 %)
# Broj igraca na poziciji CDM: 1, (0.02946375957572186 %)
# Broj igraca na poziciji LDM: 2, (0.05892751915144372 %)
# Broj igraca na poziciji RM: 420, (12.374779021803182 %)
# Broj igraca na poziciji RCM: 13, (0.3830288744843842 %)
# Broj igraca na poziciji CM: 180, (5.303476723629935 %)
# Broj igraca na poziciji LCM: 14, (0.41249263406010606 %)
# Broj igraca na poziciji LM: 388, (11.431938715380083 %)
# Broj igraca na poziciji RAM: 1, (0.02946375957572186 %)
# Broj igraca na poziciji CAM: 296, (8.721272834413671 %)
# Broj igraca na poziciji LAM: 2, (0.05892751915144372 %)
#
# ODBRANA: 15 (0.44195639363582795 %)
# Broj igraca na poziciji RWB: 2, (0.05892751915144372 %)
# Broj igraca na poziciji RB: 3, (0.0883912787271656 %)
# Broj igraca na poziciji RCB: 0, (0.0 %)
# Broj igraca na poziciji CB: 3, (0.0883912787271656 %)
# Broj igraca na poziciji LCB: 1, (0.02946375957572186 %)
# Broj igraca na poziciji LB: 4, (0.11785503830288745 %)
# Broj igraca na poziciji LWB: 2, (0.05892751915144372 %)
#
# GOLMANI: 0 (0.0 %)
#
# Broj igraca u klasteru 1: 3066, (16.839677047289502 %)
#
# NAPAD: 1328 (43.31376386170906 %)
# Broj igraca na poziciji RF: 14, (0.45662100456621 %)
# Broj igraca na poziciji LF: 13, (0.42400521852576645 %)
# Broj igraca na poziciji RW: 190, (6.196999347684279 %)
# Broj igraca na poziciji LW: 194, (6.327462491846053 %)
# Broj igraca na poziciji ST: 663, (21.62426614481409 %)
# Broj igraca na poziciji CF: 36, (1.1741682974559686 %)
# Broj igraca na poziciji RS: 107, (3.489889106327462 %)
# Broj igraca na poziciji LS: 111, (3.6203522504892365 %)
#
# VEZNI RED: 1732 (56.49054142204827 %)
# Broj igraca na poziciji RDM: 10, (0.32615786040443573 %)
# Broj igraca na poziciji CDM: 3, (0.09784735812133072 %)
# Broj igraca na poziciji LDM: 12, (0.3913894324853229 %)
# Broj igraca na poziciji RM: 493, (16.079582517938682 %)
# Broj igraca na poziciji RCM: 44, (1.4350945857795172 %)
# Broj igraca na poziciji CM: 83, (2.7071102413568164 %)
# Broj igraca na poziciji LCM: 65, (2.1200260926288323 %)
# Broj igraca na poziciji LM: 492, (16.046966731898237 %)
# Broj igraca na poziciji RAM: 17, (0.5544683626875407 %)
# Broj igraca na poziciji CAM: 494, (16.112198303979124 %)
# Broj igraca na poziciji LAM: 19, (0.6196999347684279 %)
#
# ODBRANA: 6 (0.19569471624266144 %)
# Broj igraca na poziciji RWB: 1, (0.03261578604044357 %)
# Broj igraca na poziciji RB: 0, (0.0 %)
# Broj igraca na poziciji RCB: 1, (0.03261578604044357 %)
# Broj igraca na poziciji CB: 0, (0.0 %)
# Broj igraca na poziciji LCB: 0, (0.0 %)
# Broj igraca na poziciji LB: 3, (0.09784735812133072 %)
# Broj igraca na poziciji LWB: 1, (0.03261578604044357 %)
#
# GOLMANI: 0 (0.0 %)
#
# Broj igraca u klasteru 2: 2027, (11.133080683253693 %)
#
# NAPAD: 1 (0.049333991119881605 %)
# Broj igraca na poziciji RF: 0, (0.0 %)
# Broj igraca na poziciji LF: 0, (0.0 %)
# Broj igraca na poziciji RW: 0, (0.0 %)
# Broj igraca na poziciji LW: 0, (0.0 %)
# Broj igraca na poziciji ST: 1, (0.049333991119881605 %)
# Broj igraca na poziciji CF: 0, (0.0 %)
# Broj igraca na poziciji RS: 0, (0.0 %)
# Broj igraca na poziciji LS: 0, (0.0 %)
#
# VEZNI RED: 0 (0.0 %)
# Broj igraca na poziciji RDM: 0, (0.0 %)
# Broj igraca na poziciji CDM: 0, (0.0 %)
# Broj igraca na poziciji LDM: 0, (0.0 %)
# Broj igraca na poziciji RM: 0, (0.0 %)
# Broj igraca na poziciji RCM: 0, (0.0 %)
# Broj igraca na poziciji CM: 0, (0.0 %)
# Broj igraca na poziciji LCM: 0, (0.0 %)
# Broj igraca na poziciji LM: 0, (0.0 %)
# Broj igraca na poziciji RAM: 0, (0.0 %)
# Broj igraca na poziciji CAM: 0, (0.0 %)
# Broj igraca na poziciji LAM: 0, (0.0 %)
#
# ODBRANA: 2 (0.09866798223976321 %)
# Broj igraca na poziciji RWB: 0, (0.0 %)
# Broj igraca na poziciji RB: 1, (0.049333991119881605 %)
# Broj igraca na poziciji RCB: 0, (0.0 %)
# Broj igraca na poziciji CB: 1, (0.049333991119881605 %)
# Broj igraca na poziciji LCB: 0, (0.0 %)
# Broj igraca na poziciji LB: 0, (0.0 %)
# Broj igraca na poziciji LWB: 0, (0.0 %)
#
# GOLMANI: 2024 (99.85199802664036 %)
#
# Broj igraca u klasteru 3: 4724, (25.94606470038996 %)
#
# NAPAD: 12 (0.2540220152413209 %)
# Broj igraca na poziciji RF: 0, (0.0 %)
# Broj igraca na poziciji LF: 0, (0.0 %)
# Broj igraca na poziciji RW: 1, (0.021168501270110076 %)
# Broj igraca na poziciji LW: 1, (0.021168501270110076 %)
# Broj igraca na poziciji ST: 10, (0.21168501270110077 %)
# Broj igraca na poziciji CF: 0, (0.0 %)
# Broj igraca na poziciji RS: 0, (0.0 %)
# Broj igraca na poziciji LS: 0, (0.0 %)
#
# VEZNI RED: 862 (18.247248094834887 %)
# Broj igraca na poziciji RDM: 37, (0.7832345469940728 %)
# Broj igraca na poziciji CDM: 353, (7.472480948348857 %)
# Broj igraca na poziciji LDM: 36, (0.7620660457239627 %)
# Broj igraca na poziciji RM: 29, (0.6138865368331922 %)
# Broj igraca na poziciji RCM: 31, (0.6562235393734124 %)
# Broj igraca na poziciji CM: 306, (6.477561388653684 %)
# Broj igraca na poziciji LCM: 31, (0.6562235393734124 %)
# Broj igraca na poziciji LM: 30, (0.6350550381033023 %)
# Broj igraca na poziciji RAM: 0, (0.0 %)
# Broj igraca na poziciji CAM: 9, (0.1905165114309907 %)
# Broj igraca na poziciji LAM: 0, (0.0 %)
#
# ODBRANA: 3849 (81.47756138865368 %)
# Broj igraca na poziciji RWB: 37, (0.7832345469940728 %)
# Broj igraca na poziciji RB: 578, (12.235393734123624 %)
# Broj igraca na poziciji RCB: 542, (11.47332768839966 %)
# Broj igraca na poziciji CB: 1587, (33.59441151566469 %)
# Broj igraca na poziciji LCB: 519, (10.98645215918713 %)
# Broj igraca na poziciji LB: 559, (11.833192209991534 %)
# Broj igraca na poziciji LWB: 27, (0.5715495342929721 %)
#
# GOLMANI: 1 (0.021168501270110076 %)
#
# Broj igraca u klasteru 4: 4996, (27.43999560608557 %)
#
# NAPAD: 78 (1.5612489991993594 %)
# Broj igraca na poziciji RF: 1, (0.020016012810248198 %)
# Broj igraca na poziciji LF: 1, (0.020016012810248198 %)
# Broj igraca na poziciji RW: 23, (0.4603682946357086 %)
# Broj igraca na poziciji LW: 26, (0.5204163330664532 %)
# Broj igraca na poziciji ST: 22, (0.4403522818254604 %)
# Broj igraca na poziciji CF: 0, (0.0 %)
# Broj igraca na poziciji RS: 4, (0.08006405124099279 %)
# Broj igraca na poziciji LS: 1, (0.020016012810248198 %)
#
# VEZNI RED: 2924 (58.52682145716573 %)
# Broj igraca na poziciji RDM: 198, (3.963170536429143 %)
# Broj igraca na poziciji CDM: 591, (11.829463570856685 %)
# Broj igraca na poziciji LDM: 193, (3.8630904723779023 %)
# Broj igraca na poziciji RM: 182, (3.642914331465172 %)
# Broj igraca na poziciji RCM: 303, (6.064851881505204 %)
# Broj igraca na poziciji CM: 825, (16.513210568454763 %)
# Broj igraca na poziciji LCM: 285, (5.704563650920737 %)
# Broj igraca na poziciji LM: 185, (3.7029623698959164 %)
# Broj igraca na poziciji RAM: 3, (0.06004803843074459 %)
# Broj igraca na poziciji CAM: 159, (3.182546036829464 %)
# Broj igraca na poziciji LAM: 0, (0.0 %)
#
# ODBRANA: 1994 (39.911929543634905 %)
# Broj igraca na poziciji RWB: 47, (0.9407526020816653 %)
# Broj igraca na poziciji RB: 709, (14.191353082465973 %)
# Broj igraca na poziciji RCB: 119, (2.3819055244195355 %)
# Broj igraca na poziciji CB: 187, (3.742994395516413 %)
# Broj igraca na poziciji LCB: 128, (2.5620496397117694 %)
# Broj igraca na poziciji LB: 756, (15.13210568454764 %)
# Broj igraca na poziciji LWB: 48, (0.9607686148919135 %)
#
# GOLMANI: 0 (0.0 %)

# %%
draw(df)

# %% [markdown]
# ## Zadržavanje samo onih kolona koje golmane čine "superiornijim" u odnosu na igrače na ostalim pozicijama

# %%
columns_to_keep = ['GKDiving', 'GKHandling', 'GKKicking', 'GKPositioning', 'GKReflexes']

# %%
kmeans = KMeans(n_clusters=5, random_state=0)
kmeans.fit(df[columns_to_keep])
# Out:
# KMeans(n_clusters=5, random_state=0)

# %%
print_percentige_of_five_clusters(df)
# Out:
# Broj igraca u klasteru 0: 464, (2.5484703685395727 %)
#
# NAPAD: 0 (0.0 %)
# Broj igraca na poziciji RF: 0, (0.0 %)
# Broj igraca na poziciji LF: 0, (0.0 %)
# Broj igraca na poziciji RW: 0, (0.0 %)
# Broj igraca na poziciji LW: 0, (0.0 %)
# Broj igraca na poziciji ST: 0, (0.0 %)
# Broj igraca na poziciji CF: 0, (0.0 %)
# Broj igraca na poziciji RS: 0, (0.0 %)
# Broj igraca na poziciji LS: 0, (0.0 %)
#
# VEZNI RED: 0 (0.0 %)
# Broj igraca na poziciji RDM: 0, (0.0 %)
# Broj igraca na poziciji CDM: 0, (0.0 %)
# Broj igraca na poziciji LDM: 0, (0.0 %)
# Broj igraca na poziciji RM: 0, (0.0 %)
# Broj igraca na poziciji RCM: 0, (0.0 %)
# Broj igraca na poziciji CM: 0, (0.0 %)
# Broj igraca na poziciji LCM: 0, (0.0 %)
# Broj igraca na poziciji LM: 0, (0.0 %)
# Broj igraca na poziciji RAM: 0, (0.0 %)
# Broj igraca na poziciji CAM: 0, (0.0 %)
# Broj igraca na poziciji LAM: 0, (0.0 %)
#
# ODBRANA: 0 (0.0 %)
# Broj igraca na poziciji RWB: 0, (0.0 %)
# Broj igraca na poziciji RB: 0, (0.0 %)
# Broj igraca na poziciji RCB: 0, (0.0 %)
# Broj igraca na poziciji CB: 0, (0.0 %)
# Broj igraca na poziciji LCB: 0, (0.0 %)
# Broj igraca na poziciji LB: 0, (0.0 %)
# Broj igraca na poziciji LWB: 0, (0.0 %)
#
# GOLMANI: 464 (100.0 %)
#
# Broj igraca u klasteru 1: 8194, (45.0046685340803 %)
#
# NAPAD: 1754 (21.405906761044665 %)
# Broj igraca na poziciji RF: 7, (0.0854283622162558 %)
# Broj igraca na poziciji LF: 5, (0.061020258725896996 %)
# Broj igraca na poziciji RW: 197, (2.404198193800342 %)
# Broj igraca na poziciji LW: 209, (2.5506468147424943 %)
# Broj igraca na poziciji ST: 1095, (13.363436660971443 %)
# Broj igraca na poziciji CF: 50, (0.61020258725897 %)
# Broj igraca na poziciji RS: 90, (1.0983646570661458 %)
# Broj igraca na poziciji LS: 101, (1.2326092262631194 %)
#
# VEZNI RED: 3472 (42.372467659262874 %)
# Broj igraca na poziciji RDM: 99, (1.2082011227727607 %)
# Broj igraca na poziciji CDM: 483, (5.8945569929216495 %)
# Broj igraca na poziciji LDM: 116, (1.4156700024408104 %)
# Broj igraca na poziciji RM: 567, (6.91969733951672 %)
# Broj igraca na poziciji RCM: 192, (2.343177935074445 %)
# Broj igraca na poziciji CM: 736, (8.982182084452038 %)
# Broj igraca na poziciji LCM: 190, (2.318769831584086 %)
# Broj igraca na poziciji LM: 557, (6.797656822064925 %)
# Broj igraca na poziciji RAM: 13, (0.15865267268733219 %)
# Broj igraca na poziciji CAM: 509, (6.2118623382963145 %)
# Broj igraca na poziciji LAM: 10, (0.12204051745179399 %)
#
# ODBRANA: 2968 (36.22162557969246 %)
# Broj igraca na poziciji RWB: 45, (0.5491823285330729 %)
# Broj igraca na poziciji RB: 661, (8.066878203563583 %)
# Broj igraca na poziciji RCB: 302, (3.685623627044179 %)
# Broj igraca na poziciji CB: 934, (11.39858432999756 %)
# Broj igraca na poziciji LCB: 314, (3.8320722479863316 %)
# Broj igraca na poziciji LB: 674, (8.225530876250915 %)
# Broj igraca na poziciji LWB: 38, (0.4637539663168172 %)
#
# GOLMANI: 0 (0.0 %)
#
# Broj igraca u klasteru 2: 633, (3.476684791563684 %)
#
# NAPAD: 1 (0.1579778830963665 %)
# Broj igraca na poziciji RF: 0, (0.0 %)
# Broj igraca na poziciji LF: 0, (0.0 %)
# Broj igraca na poziciji RW: 0, (0.0 %)
# Broj igraca na poziciji LW: 0, (0.0 %)
# Broj igraca na poziciji ST: 1, (0.1579778830963665 %)
# Broj igraca na poziciji CF: 0, (0.0 %)
# Broj igraca na poziciji RS: 0, (0.0 %)
# Broj igraca na poziciji LS: 0, (0.0 %)
#
# VEZNI RED: 0 (0.0 %)
# Broj igraca na poziciji RDM: 0, (0.0 %)
# Broj igraca na poziciji CDM: 0, (0.0 %)
# Broj igraca na poziciji LDM: 0, (0.0 %)
# Broj igraca na poziciji RM: 0, (0.0 %)
# Broj igraca na poziciji RCM: 0, (0.0 %)
# Broj igraca na poziciji CM: 0, (0.0 %)
# Broj igraca na poziciji LCM: 0, (0.0 %)
# Broj igraca na poziciji LM: 0, (0.0 %)
# Broj igraca na poziciji RAM: 0, (0.0 %)
# Broj igraca na poziciji CAM: 0, (0.0 %)
# Broj igraca na poziciji LAM: 0, (0.0 %)
#
# ODBRANA: 1 (0.1579778830963665 %)
# Broj igraca na poziciji RWB: 0, (0.0 %)
# Broj igraca na poziciji RB: 0, (0.0 %)
# Broj igraca na poziciji RCB: 0, (0.0 %)
# Broj igraca na poziciji CB: 1, (0.1579778830963665 %)
# Broj igraca na poziciji LCB: 0, (0.0 %)
# Broj igraca na poziciji LB: 0, (0.0 %)
# Broj igraca na poziciji LWB: 0, (0.0 %)
#
# GOLMANI: 631 (99.68404423380727 %)
#
# Broj igraca u klasteru 3: 930, (5.107925523150437 %)
#
# NAPAD: 0 (0.0 %)
# Broj igraca na poziciji RF: 0, (0.0 %)
# Broj igraca na poziciji LF: 0, (0.0 %)
# Broj igraca na poziciji RW: 0, (0.0 %)
# Broj igraca na poziciji LW: 0, (0.0 %)
# Broj igraca na poziciji ST: 0, (0.0 %)
# Broj igraca na poziciji CF: 0, (0.0 %)
# Broj igraca na poziciji RS: 0, (0.0 %)
# Broj igraca na poziciji LS: 0, (0.0 %)
#
# VEZNI RED: 0 (0.0 %)
# Broj igraca na poziciji RDM: 0, (0.0 %)
# Broj igraca na poziciji CDM: 0, (0.0 %)
# Broj igraca na poziciji LDM: 0, (0.0 %)
# Broj igraca na poziciji RM: 0, (0.0 %)
# Broj igraca na poziciji RCM: 0, (0.0 %)
# Broj igraca na poziciji CM: 0, (0.0 %)
# Broj igraca na poziciji LCM: 0, (0.0 %)
# Broj igraca na poziciji LM: 0, (0.0 %)
# Broj igraca na poziciji RAM: 0, (0.0 %)
# Broj igraca na poziciji CAM: 0, (0.0 %)
# Broj igraca na poziciji LAM: 0, (0.0 %)
#
# ODBRANA: 0 (0.0 %)
# Broj igraca na poziciji RWB: 0, (0.0 %)
# Broj igraca na poziciji RB: 0, (0.0 %)
# Broj igraca na poziciji RCB: 0, (0.0 %)
# Broj igraca na poziciji CB: 0, (0.0 %)
# Broj igraca na poziciji LCB: 0, (0.0 %)
# Broj igraca na poziciji LB: 0, (0.0 %)
# Broj igraca na poziciji LWB: 0, (0.0 %)
#
# GOLMANI: 930 (100.0 %)
#
# Broj igraca u klasteru 4: 7986, (43.86225078266601 %)
#
# NAPAD: 1723 (21.57525669922364 %)
# Broj igraca na poziciji RF: 9, (0.11269722013523666 %)
# Broj igraca na poziciji LF: 10, (0.12521913348359628 %)
# Broj igraca na poziciji RW: 173, (2.166291009266216 %)
# Broj igraca na poziciji LW: 172, (2.153769095917856 %)
# Broj igraca na poziciji ST: 1116, (13.974455296769348 %)
# Broj igraca na poziciji CF: 24, (0.30052592036063114 %)
# Broj igraca na poziciji RS: 113, (1.4149762083646382 %)
# Broj igraca na poziciji LS: 106, (1.3273228149261207 %)
#
# VEZNI RED: 3366 (42.14876033057851 %)
# Broj igraca na poziciji RDM: 149, (1.8657650889055848 %)
# Broj igraca na poziciji CDM: 465, (5.822689706987227 %)
# Broj igraca na poziciji LDM: 127, (1.5902829952416728 %)
# Broj igraca na poziciji RM: 557, (6.974705735036313 %)
# Broj igraca na poziciji RCM: 199, (2.4918607563235664 %)
# Broj igraca na poziciji CM: 658, (8.239418983220636 %)
# Broj igraca na poziciji LCM: 205, (2.566992236413724 %)
# Broj igraca na poziciji LM: 538, (6.736789381417481 %)
# Broj igraca na poziciji RAM: 8, (0.10017530678687703 %)
# Broj igraca na poziciji CAM: 449, (5.622339093413474 %)
# Broj igraca na poziciji LAM: 11, (0.13774104683195593 %)
#
# ODBRANA: 2897 (36.275982970197845 %)
# Broj igraca na poziciji RWB: 42, (0.5259203606311045 %)
# Broj igraca na poziciji RB: 630, (7.888805409466566 %)
# Broj igraca na poziciji RCB: 360, (4.507888805409467 %)
# Broj igraca na poziciji CB: 843, (10.555972952667167 %)
# Broj igraca na poziciji LCB: 334, (4.182319058352117 %)
# Broj igraca na poziciji LB: 648, (8.114199849737041 %)
# Broj igraca na poziciji LWB: 40, (0.5008765339343851 %)
#
# GOLMANI: 0 (0.0 %)

# %%
draw(df)

# %% [markdown]
# ## PCA test svih kolona koje golmane razlikuju od igrača na ostalim pozicijama

# %%
columns_to_test = ['Special', 'Skill Moves', 'Crossing', 'Finishing', 'HeadingAccuracy',
                   'ShortPassing', 'Volleys', 'Dribbling', 'Curve', 'FKAccuracy',
                   'LongPassing', 'BallControl', 'Acceleration', 'SprintSpeed',
                   'Agility', 'Balance', 'ShotPower', 'Stamina', 'LongShots', 
                   'Aggression', 'Interceptions', 'Positioning', 'Vision', 'Penalties',
                   'Composure', 'Marking', 'StandingTackle', 'SlidingTackle',
                   'GKDiving', 'GKHandling', 'GKKicking', 'GKPositioning', 'GKReflexes']

# %%
pca_test = PCA(n_components=len(columns_to_test), random_state=0)
pca_test_numpy_1d = pca_test.fit_transform(df[columns_to_test])[0]
pca_test_numpy_1d
pca_series = pd.Series(pca_test_numpy_1d, index=columns_to_test)
pca_series.sort_values(ascending=False)
# Out:
# Crossing           0.463307
# BallControl        0.163714
# FKAccuracy         0.105140
# Acceleration       0.063632
# LongPassing        0.059906
# GKDiving           0.047458
# Dribbling          0.043225
# Balance            0.042461
# HeadingAccuracy    0.035744
# SlidingTackle      0.024934
# SprintSpeed        0.012513
# Aggression         0.004699
# GKPositioning     -0.000559
# GKKicking         -0.004232
# GKReflexes        -0.007763
# Vision            -0.010251
# StandingTackle    -0.015027
# Marking           -0.021361
# Composure         -0.026539
# Volleys           -0.032472
# Penalties         -0.038089
# LongShots         -0.040157
# Finishing         -0.043186
# GKHandling        -0.058245
# Agility           -0.061376
# Positioning       -0.089734
# Curve             -0.102730
# Interceptions     -0.108179
# ShortPassing      -0.111803
# Stamina           -0.115204
# ShotPower         -0.189119
# Skill Moves       -1.177734
# Special           -1.508189
# dtype: float64

# %% [markdown]
# ## Na osnovu PCA testa svih kolona kojima se golmani razlikuju od igrača na ostalim pozicijama, zadržati kolonu po kolonu pri klasterizaciji

# %%
# Crossing

kmeans = KMeans(n_clusters=5, random_state=0)
kmeans.fit(df[['Crossing']])
# Out:
# KMeans(n_clusters=5, random_state=0)

# %%
print_percentige_of_five_clusters(df)
# Out:
# Broj igraca u klasteru 0: 5648, (31.021035865326525 %)
#
# NAPAD: 1073 (18.99787535410765 %)
# Broj igraca na poziciji RF: 8, (0.141643059490085 %)
# Broj igraca na poziciji LF: 7, (0.12393767705382436 %)
# Broj igraca na poziciji RW: 180, (3.186968838526912 %)
# Broj igraca na poziciji LW: 211, (3.7358356940509916 %)
# Broj igraca na poziciji ST: 503, (8.905807365439093 %)
# Broj igraca na poziciji CF: 27, (0.47804532577903686 %)
# Broj igraca na poziciji RS: 67, (1.1862606232294617 %)
# Broj igraca na poziciji LS: 70, (1.2393767705382437 %)
#
# VEZNI RED: 2877 (50.93838526912181 %)
# Broj igraca na poziciji RDM: 107, (1.894475920679887 %)
# Broj igraca na poziciji CDM: 299, (5.293909348441926 %)
# Broj igraca na poziciji LDM: 96, (1.69971671388102 %)
# Broj igraca na poziciji RM: 551, (9.755665722379604 %)
# Broj igraca na poziciji RCM: 192, (3.39943342776204 %)
# Broj igraca na poziciji CM: 489, (8.657932011331445 %)
# Broj igraca na poziciji LCM: 170, (3.009915014164306 %)
# Broj igraca na poziciji LM: 556, (9.844192634560907 %)
# Broj igraca na poziciji RAM: 7, (0.12393767705382436 %)
# Broj igraca na poziciji CAM: 402, (7.11756373937677 %)
# Broj igraca na poziciji LAM: 8, (0.141643059490085 %)
#
# ODBRANA: 1698 (30.06373937677054 %)
# Broj igraca na poziciji RWB: 40, (0.708215297450425 %)
# Broj igraca na poziciji RB: 603, (10.676345609065157 %)
# Broj igraca na poziciji RCB: 109, (1.929886685552408 %)
# Broj igraca na poziciji CB: 182, (3.2223796033994336 %)
# Broj igraca na poziciji LCB: 128, (2.26628895184136 %)
# Broj igraca na poziciji LB: 596, (10.55240793201133 %)
# Broj igraca na poziciji LWB: 40, (0.708215297450425 %)
#
# GOLMANI: 0 (0.0 %)
#
# Broj igraca u klasteru 1: 3074, (16.883616191574667 %)
#
# NAPAD: 971 (31.58750813272609 %)
# Broj igraca na poziciji RF: 0, (0.0 %)
# Broj igraca na poziciji LF: 0, (0.0 %)
# Broj igraca na poziciji RW: 13, (0.4229017566688354 %)
# Broj igraca na poziciji LW: 8, (0.2602472348731295 %)
# Broj igraca na poziciji ST: 840, (27.325959661678596 %)
# Broj igraca na poziciji CF: 12, (0.3903708523096942 %)
# Broj igraca na poziciji RS: 49, (1.594014313597918 %)
# Broj igraca na poziciji LS: 49, (1.594014313597918 %)
#
# VEZNI RED: 500 (16.26545217957059 %)
# Broj igraca na poziciji RDM: 14, (0.4554326610279766 %)
# Broj igraca na poziciji CDM: 165, (5.367599219258295 %)
# Broj igraca na poziciji LDM: 23, (0.7482108002602472 %)
# Broj igraca na poziciji RM: 19, (0.6180871828236825 %)
# Broj igraca na poziciji RCM: 18, (0.5855562784645413 %)
# Broj igraca na poziciji CM: 175, (5.692908262849707 %)
# Broj igraca na poziciji LCM: 16, (0.520494469746259 %)
# Broj igraca na poziciji LM: 15, (0.48796356538711777 %)
# Broj igraca na poziciji RAM: 0, (0.0 %)
# Broj igraca na poziciji CAM: 55, (1.7891997397527653 %)
# Broj igraca na poziciji LAM: 0, (0.0 %)
#
# ODBRANA: 1563 (50.84580351333767 %)
# Broj igraca na poziciji RWB: 4, (0.13012361743656475 %)
# Broj igraca na poziciji RB: 33, (1.073519843851659 %)
# Broj igraca na poziciji RCB: 305, (9.921925829538061 %)
# Broj igraca na poziciji CB: 931, (30.286271958360445 %)
# Broj igraca na poziciji LCB: 255, (8.295380611581002 %)
# Broj igraca na poziciji LB: 33, (1.073519843851659 %)
# Broj igraca na poziciji LWB: 2, (0.06506180871828238 %)
#
# GOLMANI: 40 (1.3012361743656473 %)
#
# Broj igraca u klasteru 2: 2304, (12.654473554127533 %)
#
# NAPAD: 33 (1.4322916666666665 %)
# Broj igraca na poziciji RF: 0, (0.0 %)
# Broj igraca na poziciji LF: 0, (0.0 %)
# Broj igraca na poziciji RW: 0, (0.0 %)
# Broj igraca na poziciji LW: 0, (0.0 %)
# Broj igraca na poziciji ST: 33, (1.4322916666666665 %)
# Broj igraca na poziciji CF: 0, (0.0 %)
# Broj igraca na poziciji RS: 0, (0.0 %)
# Broj igraca na poziciji LS: 0, (0.0 %)
#
# VEZNI RED: 8 (0.3472222222222222 %)
# Broj igraca na poziciji RDM: 0, (0.0 %)
# Broj igraca na poziciji CDM: 3, (0.13020833333333331 %)
# Broj igraca na poziciji LDM: 1, (0.043402777777777776 %)
# Broj igraca na poziciji RM: 0, (0.0 %)
# Broj igraca na poziciji RCM: 0, (0.0 %)
# Broj igraca na poziciji CM: 3, (0.13020833333333331 %)
# Broj igraca na poziciji LCM: 0, (0.0 %)
# Broj igraca na poziciji LM: 0, (0.0 %)
# Broj igraca na poziciji RAM: 0, (0.0 %)
# Broj igraca na poziciji CAM: 1, (0.043402777777777776 %)
# Broj igraca na poziciji LAM: 0, (0.0 %)
#
# ODBRANA: 279 (12.109375 %)
# Broj igraca na poziciji RWB: 0, (0.0 %)
# Broj igraca na poziciji RB: 2, (0.08680555555555555 %)
# Broj igraca na poziciji RCB: 50, (2.170138888888889 %)
# Broj igraca na poziciji CB: 179, (7.769097222222222 %)
# Broj igraca na poziciji LCB: 46, (1.9965277777777777 %)
# Broj igraca na poziciji LB: 2, (0.08680555555555555 %)
# Broj igraca na poziciji LWB: 0, (0.0 %)
#
# GOLMANI: 1984 (86.11111111111111 %)
#
# Broj igraca u klasteru 3: 4364, (23.96880320755753 %)
#
# NAPAD: 1040 (23.831347387717692 %)
# Broj igraca na poziciji RF: 0, (0.0 %)
# Broj igraca na poziciji LF: 1, (0.022914757103574702 %)
# Broj igraca na poziciji RW: 75, (1.7186067827681026 %)
# Broj igraca na poziciji LW: 75, (1.7186067827681026 %)
# Broj igraca na poziciji ST: 741, (16.979835013748854 %)
# Broj igraca na poziciji CF: 26, (0.5957836846929423 %)
# Broj igraca na poziciji RS: 65, (1.4894592117323557 %)
# Broj igraca na poziciji LS: 57, (1.306141154903758 %)
#
# VEZNI RED: 2025 (46.40238313473877 %)
# Broj igraca na poziciji RDM: 97, (2.222731439046746 %)
# Broj igraca na poziciji CDM: 408, (9.349220898258478 %)
# Broj igraca na poziciji LDM: 76, (1.7415215398716772 %)
# Broj igraca na poziciji RM: 231, (5.293308890925756 %)
# Broj igraca na poziciji RCM: 90, (2.0623281393217234 %)
# Broj igraca na poziciji CM: 547, (12.534372135655362 %)
# Broj igraca na poziciji LCM: 104, (2.383134738771769 %)
# Broj igraca na poziciji LM: 206, (4.720439963336388 %)
# Broj igraca na poziciji RAM: 1, (0.022914757103574702 %)
# Broj igraca na poziciji CAM: 264, (6.049495875343721 %)
# Broj igraca na poziciji LAM: 1, (0.022914757103574702 %)
#
# ODBRANA: 1298 (29.743354720439964 %)
# Broj igraca na poziciji RWB: 19, (0.4353803849679193 %)
# Broj igraca na poziciji RB: 236, (5.40788267644363 %)
# Broj igraca na poziciji RCB: 178, (4.078826764436297 %)
# Broj igraca na poziciji CB: 445, (10.197066911090742 %)
# Broj igraca na poziciji LCB: 189, (4.330889092575619 %)
# Broj igraca na poziciji LB: 222, (5.087076076993584 %)
# Broj igraca na poziciji LWB: 9, (0.2062328139321723 %)
#
# GOLMANI: 1 (0.022914757103574702 %)
#
# Broj igraca u klasteru 4: 2817, (15.47207118141374 %)
#
# NAPAD: 361 (12.815051473198439 %)
# Broj igraca na poziciji RF: 8, (0.2839900603478878 %)
# Broj igraca na poziciji LF: 7, (0.24849130280440185 %)
# Broj igraca na poziciji RW: 102, (3.62087326943557 %)
# Broj igraca na poziciji LW: 87, (3.08839190628328 %)
# Broj igraca na poziciji ST: 95, (3.3723819666311683 %)
# Broj igraca na poziciji CF: 9, (0.3194888178913738 %)
# Broj igraca na poziciji RS: 22, (0.7809726659566916 %)
# Broj igraca na poziciji LS: 31, (1.1004614838480653 %)
#
# VEZNI RED: 1428 (50.69222577209798 %)
# Broj igraca na poziciji RDM: 30, (1.0649627263045793 %)
# Broj igraca na poziciji CDM: 73, (2.5914093006744765 %)
# Broj igraca na poziciji LDM: 47, (1.668441604543841 %)
# Broj igraca na poziciji RM: 323, (11.46609868654597 %)
# Broj igraca na poziciji RCM: 91, (3.230386936457224 %)
# Broj igraca na poziciji CM: 180, (6.3897763578274756 %)
# Broj igraca na poziciji LCM: 105, (3.727369542066028 %)
# Broj igraca na poziciji LM: 318, (11.288604898828542 %)
# Broj igraca na poziciji RAM: 13, (0.4614838480653177 %)
# Broj igraca na poziciji CAM: 236, (8.37770678026269 %)
# Broj igraca na poziciji LAM: 12, (0.42598509052183176 %)
#
# ODBRANA: 1028 (36.492722754703586 %)
# Broj igraca na poziciji RWB: 24, (0.8519701810436635 %)
# Broj igraca na poziciji RB: 417, (14.802981895633652 %)
# Broj igraca na poziciji RCB: 20, (0.7099751508697196 %)
# Broj igraca na poziciji CB: 41, (1.455449059282925 %)
# Broj igraca na poziciji LCB: 30, (1.0649627263045793 %)
# Broj igraca na poziciji LB: 469, (16.648917287894925 %)
# Broj igraca na poziciji LWB: 27, (0.9584664536741214 %)
#
# GOLMANI: 0 (0.0 %)

# %%
draw(df)

# %%
# Crossing + BallControl

kmeans = KMeans(n_clusters=5, random_state=0)
kmeans.fit(df[['Crossing', 'BallControl']])
# Out:
# KMeans(n_clusters=5, random_state=0)

# %%
print_percentige_of_five_clusters(df)
# Out:
# Broj igraca u klasteru 0: 2144, (11.775690668424232 %)
#
# NAPAD: 2 (0.09328358208955223 %)
# Broj igraca na poziciji RF: 0, (0.0 %)
# Broj igraca na poziciji LF: 0, (0.0 %)
# Broj igraca na poziciji RW: 0, (0.0 %)
# Broj igraca na poziciji LW: 0, (0.0 %)
# Broj igraca na poziciji ST: 2, (0.09328358208955223 %)
# Broj igraca na poziciji CF: 0, (0.0 %)
# Broj igraca na poziciji RS: 0, (0.0 %)
# Broj igraca na poziciji LS: 0, (0.0 %)
#
# VEZNI RED: 1 (0.046641791044776115 %)
# Broj igraca na poziciji RDM: 0, (0.0 %)
# Broj igraca na poziciji CDM: 0, (0.0 %)
# Broj igraca na poziciji LDM: 0, (0.0 %)
# Broj igraca na poziciji RM: 0, (0.0 %)
# Broj igraca na poziciji RCM: 0, (0.0 %)
# Broj igraca na poziciji CM: 0, (0.0 %)
# Broj igraca na poziciji LCM: 0, (0.0 %)
# Broj igraca na poziciji LM: 0, (0.0 %)
# Broj igraca na poziciji RAM: 0, (0.0 %)
# Broj igraca na poziciji CAM: 1, (0.046641791044776115 %)
# Broj igraca na poziciji LAM: 0, (0.0 %)
#
# ODBRANA: 133 (6.2033582089552235 %)
# Broj igraca na poziciji RWB: 0, (0.0 %)
# Broj igraca na poziciji RB: 1, (0.046641791044776115 %)
# Broj igraca na poziciji RCB: 8, (0.3731343283582089 %)
# Broj igraca na poziciji CB: 114, (5.317164179104478 %)
# Broj igraca na poziciji LCB: 10, (0.46641791044776115 %)
# Broj igraca na poziciji LB: 0, (0.0 %)
# Broj igraca na poziciji LWB: 0, (0.0 %)
#
# GOLMANI: 2008 (93.65671641791045 %)
#
# Broj igraca u klasteru 1: 5881, (32.300763442631954 %)
#
# NAPAD: 1071 (18.211188573371874 %)
# Broj igraca na poziciji RF: 7, (0.11902737629654819 %)
# Broj igraca na poziciji LF: 6, (0.10202346539704132 %)
# Broj igraca na poziciji RW: 170, (2.8906648529161707 %)
# Broj igraca na poziciji LW: 194, (3.298758714504336 %)
# Broj igraca na poziciji ST: 538, (9.148104063934705 %)
# Broj igraca na poziciji CF: 25, (0.42509777248767217 %)
# Broj igraca na poziciji RS: 65, (1.1052542084679475 %)
# Broj igraca na poziciji LS: 66, (1.1222581193674546 %)
#
# VEZNI RED: 2819 (47.93402482570991 %)
# Broj igraca na poziciji RDM: 109, (1.8534262880462509 %)
# Broj igraca na poziciji CDM: 322, (5.475259309641217 %)
# Broj igraca na poziciji LDM: 93, (1.5813637136541405 %)
# Broj igraca na poziciji RM: 560, (9.522190103723856 %)
# Broj igraca na poziciji RCM: 163, (2.7716374766196226 %)
# Broj igraca na poziciji CM: 506, (8.603978915150485 %)
# Broj igraca na poziciji LCM: 163, (2.7716374766196226 %)
# Broj igraca na poziciji LM: 528, (8.978064954939637 %)
# Broj igraca na poziciji RAM: 4, (0.06801564359802754 %)
# Broj igraca na poziciji CAM: 366, (6.22343138921952 %)
# Broj igraca na poziciji LAM: 5, (0.08501955449753444 %)
#
# ODBRANA: 1991 (33.85478660091821 %)
# Broj igraca na poziciji RWB: 48, (0.8161877231763306 %)
# Broj igraca na poziciji RB: 685, (11.647678966162218 %)
# Broj igraca na poziciji RCB: 131, (2.2275123278354023 %)
# Broj igraca na poziciji CB: 244, (4.14895425947968 %)
# Broj igraca na poziciji LCB: 150, (2.550586634926033 %)
# Broj igraca na poziciji LB: 692, (11.766706342458766 %)
# Broj igraca na poziciji LWB: 41, (0.6971603468797823 %)
#
# GOLMANI: 0 (0.0 %)
#
# Broj igraca u klasteru 2: 4127, (22.667106058109518 %)
#
# NAPAD: 1191 (28.858735158710928 %)
# Broj igraca na poziciji RF: 0, (0.0 %)
# Broj igraca na poziciji LF: 0, (0.0 %)
# Broj igraca na poziciji RW: 53, (1.2842258299006541 %)
# Broj igraca na poziciji LW: 51, (1.2357644778289314 %)
# Broj igraca na poziciji ST: 915, (22.171068572813184 %)
# Broj igraca na poziciji CF: 25, (0.605766900896535 %)
# Broj igraca na poziciji RS: 80, (1.9384540828689119 %)
# Broj igraca na poziciji LS: 67, (1.6234552944027136 %)
#
# VEZNI RED: 1692 (40.998303852677495 %)
# Broj igraca na poziciji RDM: 74, (1.7930700266537436 %)
# Broj igraca na poziciji CDM: 428, (10.37072934334868 %)
# Broj igraca na poziciji LDM: 68, (1.6476859704385751 %)
# Broj igraca na poziciji RM: 153, (3.707293433486794 %)
# Broj igraca na poziciji RCM: 75, (1.8173007026896049 %)
# Broj igraca na poziciji CM: 472, (11.436879088926581 %)
# Broj igraca na poziciji LCM: 78, (1.889992730797189 %)
# Broj igraca na poziciji LM: 133, (3.222679912769566 %)
# Broj igraca na poziciji RAM: 1, (0.0242306760358614 %)
# Broj igraca na poziciji CAM: 209, (5.064211291495033 %)
# Broj igraca na poziciji LAM: 1, (0.0242306760358614 %)
#
# ODBRANA: 1244 (30.142960988611584 %)
# Broj igraca na poziciji RWB: 15, (0.36346014053792103 %)
# Broj igraca na poziciji RB: 174, (4.216137630239883 %)
# Broj igraca na poziciji RCB: 202, (4.894596559244003 %)
# Broj igraca na poziciji CB: 482, (11.679185849285195 %)
# Broj igraca na poziciji LCB: 212, (5.136903319602617 %)
# Broj igraca na poziciji LB: 153, (3.707293433486794 %)
# Broj igraca na poziciji LWB: 6, (0.1453840562151684 %)
#
# GOLMANI: 0 (0.0 %)
#
# Broj igraca u klasteru 3: 3629, (19.931894326357995 %)
#
# NAPAD: 621 (17.112152108018737 %)
# Broj igraca na poziciji RF: 9, (0.2480022044640397 %)
# Broj igraca na poziciji LF: 9, (0.2480022044640397 %)
# Broj igraca na poziciji RW: 141, (3.8853678699366214 %)
# Broj igraca na poziciji LW: 131, (3.6098098649765777 %)
# Broj igraca na poziciji ST: 214, (5.896941306144943 %)
# Broj igraca na poziciji CF: 19, (0.5235602094240838 %)
# Broj igraca na poziciji RS: 44, (1.212455221824194 %)
# Broj igraca na poziciji LS: 54, (1.488013226784238 %)
#
# VEZNI RED: 2072 (57.09561862772114 %)
# Broj igraca na poziciji RDM: 60, (1.6533480297602647 %)
# Broj igraca na poziciji CDM: 128, (3.527142463488565 %)
# Broj igraca na poziciji LDM: 74, (2.0391292367043263 %)
# Broj igraca na poziciji RM: 401, (11.049875998897768 %)
# Broj igraca na poziciji RCM: 149, (4.105814273904657 %)
# Broj igraca na poziciji CM: 300, (8.266740148801324 %)
# Broj igraca na poziciji LCM: 148, (4.078258473408653 %)
# Broj igraca na poziciji LM: 427, (11.766326811793883 %)
# Broj igraca na poziciji RAM: 16, (0.4408928079360706 %)
# Broj igraca na poziciji CAM: 354, (9.75475337558556 %)
# Broj igraca na poziciji LAM: 15, (0.4133370074400662 %)
#
# ODBRANA: 936 (25.792229264260126 %)
# Broj igraca na poziciji RWB: 20, (0.5511160099200882 %)
# Broj igraca na poziciji RB: 374, (10.305869385505648 %)
# Broj igraca na poziciji RCB: 27, (0.744006613392119 %)
# Broj igraca na poziciji CB: 32, (0.8817856158721412 %)
# Broj igraca na poziciji LCB: 36, (0.9920088178561588 %)
# Broj igraca na poziciji LB: 418, (11.518324607329843 %)
# Broj igraca na poziciji LWB: 29, (0.7991182143841279 %)
#
# GOLMANI: 0 (0.0 %)
#
# Broj igraca u klasteru 4: 2426, (13.324545504476301 %)
#
# NAPAD: 593 (24.443528441879636 %)
# Broj igraca na poziciji RF: 0, (0.0 %)
# Broj igraca na poziciji LF: 0, (0.0 %)
# Broj igraca na poziciji RW: 6, (0.24732069249793898 %)
# Broj igraca na poziciji LW: 5, (0.2061005770816158 %)
# Broj igraca na poziciji ST: 543, (22.38252267106348 %)
# Broj igraca na poziciji CF: 5, (0.2061005770816158 %)
# Broj igraca na poziciji RS: 14, (0.5770816158285244 %)
# Broj igraca na poziciji LS: 20, (0.8244023083264632 %)
#
# VEZNI RED: 254 (10.469909315746085 %)
# Broj igraca na poziciji RDM: 5, (0.2061005770816158 %)
# Broj igraca na poziciji CDM: 70, (2.8854080791426218 %)
# Broj igraca na poziciji LDM: 8, (0.3297609233305853 %)
# Broj igraca na poziciji RM: 10, (0.4122011541632316 %)
# Broj igraca na poziciji RCM: 4, (0.16488046166529266 %)
# Broj igraca na poziciji CM: 116, (4.781533388293488 %)
# Broj igraca na poziciji LCM: 6, (0.24732069249793898 %)
# Broj igraca na poziciji LM: 7, (0.2885408079142622 %)
# Broj igraca na poziciji RAM: 0, (0.0 %)
# Broj igraca na poziciji CAM: 28, (1.1541632316570487 %)
# Broj igraca na poziciji LAM: 0, (0.0 %)
#
# ODBRANA: 1562 (64.38582028029678 %)
# Broj igraca na poziciji RWB: 4, (0.16488046166529266 %)
# Broj igraca na poziciji RB: 57, (2.3495465787304206 %)
# Broj igraca na poziciji RCB: 294, (12.118713932399011 %)
# Broj igraca na poziciji CB: 906, (37.345424567188786 %)
# Broj igraca na poziciji LCB: 240, (9.892827699917559 %)
# Broj igraca na poziciji LB: 59, (2.431986809563067 %)
# Broj igraca na poziciji LWB: 2, (0.08244023083264633 %)
#
# GOLMANI: 17 (0.7007419620774938 %)

# %%
draw(df)

# %%
# Crossing + BallControl + FKAccuracy

kmeans = KMeans(n_clusters=5, random_state=0)
kmeans.fit(df[['Crossing', 'BallControl', 'FKAccuracy']])
# Out:
# KMeans(n_clusters=5, random_state=0)

# %%
print_percentige_of_five_clusters(df)
# Out:
# Broj igraca u klasteru 0: 2215, (12.165650573955073 %)
#
# NAPAD: 4 (0.1805869074492099 %)
# Broj igraca na poziciji RF: 0, (0.0 %)
# Broj igraca na poziciji LF: 0, (0.0 %)
# Broj igraca na poziciji RW: 0, (0.0 %)
# Broj igraca na poziciji LW: 0, (0.0 %)
# Broj igraca na poziciji ST: 4, (0.1805869074492099 %)
# Broj igraca na poziciji CF: 0, (0.0 %)
# Broj igraca na poziciji RS: 0, (0.0 %)
# Broj igraca na poziciji LS: 0, (0.0 %)
#
# VEZNI RED: 2 (0.09029345372460496 %)
# Broj igraca na poziciji RDM: 0, (0.0 %)
# Broj igraca na poziciji CDM: 1, (0.04514672686230248 %)
# Broj igraca na poziciji LDM: 0, (0.0 %)
# Broj igraca na poziciji RM: 0, (0.0 %)
# Broj igraca na poziciji RCM: 0, (0.0 %)
# Broj igraca na poziciji CM: 0, (0.0 %)
# Broj igraca na poziciji LCM: 0, (0.0 %)
# Broj igraca na poziciji LM: 0, (0.0 %)
# Broj igraca na poziciji RAM: 0, (0.0 %)
# Broj igraca na poziciji CAM: 1, (0.04514672686230248 %)
# Broj igraca na poziciji LAM: 0, (0.0 %)
#
# ODBRANA: 193 (8.713318284424378 %)
# Broj igraca na poziciji RWB: 0, (0.0 %)
# Broj igraca na poziciji RB: 2, (0.09029345372460496 %)
# Broj igraca na poziciji RCB: 17, (0.7674943566591422 %)
# Broj igraca na poziciji CB: 156, (7.042889390519187 %)
# Broj igraca na poziciji LCB: 16, (0.7223476297968396 %)
# Broj igraca na poziciji LB: 1, (0.04514672686230248 %)
# Broj igraca na poziciji LWB: 1, (0.04514672686230248 %)
#
# GOLMANI: 2016 (91.0158013544018 %)
#
# Broj igraca u klasteru 1: 3772, (20.71730653045532 %)
#
# NAPAD: 953 (25.26511134676564 %)
# Broj igraca na poziciji RF: 2, (0.05302226935312832 %)
# Broj igraca na poziciji LF: 2, (0.05302226935312832 %)
# Broj igraca na poziciji RW: 70, (1.855779427359491 %)
# Broj igraca na poziciji LW: 112, (2.9692470837751856 %)
# Broj igraca na poziciji ST: 614, (16.277836691410393 %)
# Broj igraca na poziciji CF: 21, (0.5567338282078473 %)
# Broj igraca na poziciji RS: 77, (2.04135737009544 %)
# Broj igraca na poziciji LS: 55, (1.4581124072110285 %)
#
# VEZNI RED: 2144 (56.83987274655355 %)
# Broj igraca na poziciji RDM: 111, (2.9427359490986214 %)
# Broj igraca na poziciji CDM: 328, (8.695652173913043 %)
# Broj igraca na poziciji LDM: 87, (2.306468716861082 %)
# Broj igraca na poziciji RM: 275, (7.290562036055142 %)
# Broj igraca na poziciji RCM: 132, (3.4994697773064685 %)
# Broj igraca na poziciji CM: 500, (13.255567338282079 %)
# Broj igraca na poziciji LCM: 120, (3.1813361611876987 %)
# Broj igraca na poziciji LM: 247, (6.548250265111347 %)
# Broj igraca na poziciji RAM: 0, (0.0 %)
# Broj igraca na poziciji CAM: 341, (9.040296924708377 %)
# Broj igraca na poziciji LAM: 3, (0.07953340402969247 %)
#
# ODBRANA: 674 (17.868504772004243 %)
# Broj igraca na poziciji RWB: 11, (0.29162248144220576 %)
# Broj igraca na poziciji RB: 114, (3.022269353128314 %)
# Broj igraca na poziciji RCB: 117, (3.1018027571580067 %)
# Broj igraca na poziciji CB: 165, (4.374337221633086 %)
# Broj igraca na poziciji LCB: 85, (2.253446447507953 %)
# Broj igraca na poziciji LB: 167, (4.427359490986214 %)
# Broj igraca na poziciji LWB: 15, (0.39766702014846234 %)
#
# GOLMANI: 1 (0.02651113467656416 %)
#
# Broj igraca u klasteru 2: 4421, (24.281869610589336 %)
#
# NAPAD: 768 (17.37163537661163 %)
# Broj igraca na poziciji RF: 3, (0.06785795068988917 %)
# Broj igraca na poziciji LF: 4, (0.09047726758651889 %)
# Broj igraca na poziciji RW: 132, (2.985749830355123 %)
# Broj igraca na poziciji LW: 122, (2.7595566613888263 %)
# Broj igraca na poziciji ST: 401, (9.07034607554852 %)
# Broj igraca na poziciji CF: 17, (0.38452838724270527 %)
# Broj igraca na poziciji RS: 42, (0.9500113096584483 %)
# Broj igraca na poziciji LS: 47, (1.063107894141597 %)
#
# VEZNI RED: 1559 (35.263515041845736 %)
# Broj igraca na poziciji RDM: 56, (1.2666817462112643 %)
# Broj igraca na poziciji CDM: 195, (4.410766794842796 %)
# Broj igraca na poziciji LDM: 43, (0.9726306265550779 %)
# Broj igraca na poziciji RM: 407, (9.206061976928297 %)
# Broj igraca na poziciji RCM: 74, (1.6738294503505995 %)
# Broj igraca na poziciji CM: 251, (5.67744854105406 %)
# Broj igraca na poziciji LCM: 57, (1.289301063107894 %)
# Broj igraca na poziciji LM: 371, (8.391766568649626 %)
# Broj igraca na poziciji RAM: 3, (0.06785795068988917 %)
# Broj igraca na poziciji CAM: 98, (2.2166930558697127 %)
# Broj igraca na poziciji LAM: 4, (0.09047726758651889 %)
#
# ODBRANA: 2094 (47.36484958154264 %)
# Broj igraca na poziciji RWB: 54, (1.221443112418005 %)
# Broj igraca na poziciji RB: 808, (18.276408052476814 %)
# Broj igraca na poziciji RCB: 113, (2.5559828093191586 %)
# Broj igraca na poziciji CB: 267, (6.039357611400136 %)
# Broj igraca na poziciji LCB: 145, (3.27980095001131 %)
# Broj igraca na poziciji LB: 676, (15.290658222121692 %)
# Broj igraca na poziciji LWB: 31, (0.7011988237955213 %)
#
# GOLMANI: 0 (0.0 %)
#
# Broj igraca u klasteru 3: 3623, (19.89893996814412 %)
#
# NAPAD: 626 (17.27849848192106 %)
# Broj igraca na poziciji RF: 11, (0.3036157880209771 %)
# Broj igraca na poziciji LF: 9, (0.24841291747170852 %)
# Broj igraca na poziciji RW: 135, (3.7261937620756282 %)
# Broj igraca na poziciji LW: 122, (3.367375103505382 %)
# Broj igraca na poziciji ST: 238, (6.569141595362959 %)
# Broj igraca na poziciji CF: 23, (0.6348330113165884 %)
# Broj igraca na poziciji RS: 34, (0.9384487993375654 %)
# Broj igraca na poziciji LS: 54, (1.4904775048302512 %)
#
# VEZNI RED: 2286 (63.096881037813965 %)
# Broj igraca na poziciji RDM: 60, (1.6560861164780567 %)
# Broj igraca na poziciji CDM: 169, (4.664642561413194 %)
# Broj igraca na poziciji LDM: 82, (2.263317692520011 %)
# Broj igraca na poziciji RM: 376, (10.37813966326249 %)
# Broj igraca na poziciji RCM: 157, (4.333425338117582 %)
# Broj igraca na poziciji CM: 361, (9.964118134142975 %)
# Broj igraca na poziciji LCM: 189, (5.2166712669058795 %)
# Broj igraca na poziciji LM: 430, (11.86861716809274 %)
# Broj igraca na poziciji RAM: 17, (0.4692243996687827 %)
# Broj igraca na poziciji CAM: 431, (11.896218603367375 %)
# Broj igraca na poziciji LAM: 14, (0.38642009384487996 %)
#
# ODBRANA: 711 (19.624620480264973 %)
# Broj igraca na poziciji RWB: 12, (0.3312172232956114 %)
# Broj igraca na poziciji RB: 235, (6.486337289539056 %)
# Broj igraca na poziciji RCB: 19, (0.5244272702180514 %)
# Broj igraca na poziciji CB: 34, (0.9384487993375654 %)
# Broj igraca na poziciji LCB: 34, (0.9384487993375654 %)
# Broj igraca na poziciji LB: 349, (9.632900910847365 %)
# Broj igraca na poziciji LWB: 28, (0.7728401876897599 %)
#
# GOLMANI: 0 (0.0 %)
#
# Broj igraca u klasteru 4: 4176, (22.936233316856157 %)
#
# NAPAD: 1127 (26.987547892720304 %)
# Broj igraca na poziciji RF: 0, (0.0 %)
# Broj igraca na poziciji LF: 0, (0.0 %)
# Broj igraca na poziciji RW: 33, (0.7902298850574714 %)
# Broj igraca na poziciji LW: 25, (0.5986590038314177 %)
# Broj igraca na poziciji ST: 955, (22.86877394636015 %)
# Broj igraca na poziciji CF: 13, (0.3113026819923371 %)
# Broj igraca na poziciji RS: 50, (1.1973180076628354 %)
# Broj igraca na poziciji LS: 51, (1.221264367816092 %)
#
# VEZNI RED: 847 (20.282567049808428 %)
# Broj igraca na poziciji RDM: 21, (0.5028735632183908 %)
# Broj igraca na poziciji CDM: 255, (6.10632183908046 %)
# Broj igraca na poziciji LDM: 31, (0.7423371647509579 %)
# Broj igraca na poziciji RM: 66, (1.5804597701149428 %)
# Broj igraca na poziciji RCM: 28, (0.6704980842911877 %)
# Broj igraca na poziciji CM: 282, (6.752873563218391 %)
# Broj igraca na poziciji LCM: 29, (0.6944444444444444 %)
# Broj igraca na poziciji LM: 47, (1.1254789272030652 %)
# Broj igraca na poziciji RAM: 1, (0.023946360153256702 %)
# Broj igraca na poziciji CAM: 87, (2.083333333333333 %)
# Broj igraca na poziciji LAM: 0, (0.0 %)
#
# ODBRANA: 2194 (52.538314176245215 %)
# Broj igraca na poziciji RWB: 10, (0.23946360153256704 %)
# Broj igraca na poziciji RB: 132, (3.1609195402298855 %)
# Broj igraca na poziciji RCB: 396, (9.482758620689655 %)
# Broj igraca na poziciji CB: 1156, (27.68199233716475 %)
# Broj igraca na poziciji LCB: 368, (8.812260536398467 %)
# Broj igraca na poziciji LB: 129, (3.089080459770115 %)
# Broj igraca na poziciji LWB: 3, (0.07183908045977011 %)
#
# GOLMANI: 8 (0.19157088122605362 %)

# %%
draw(df)

# %%
# Crossing + BallControl + FKAccuracy + Acceleration

kmeans = KMeans(n_clusters=5, random_state=0)
kmeans.fit(df[['Crossing', 'BallControl', 'FKAccuracy', 'Acceleration']])
# Out:
# KMeans(n_clusters=5, random_state=0)

# %%
print_percentige_of_five_clusters(df)
# Out:
# Broj igraca u klasteru 0: 3951, (21.700444883835885 %)
#
# NAPAD: 939 (23.766135155656794 %)
# Broj igraca na poziciji RF: 0, (0.0 %)
# Broj igraca na poziciji LF: 0, (0.0 %)
# Broj igraca na poziciji RW: 16, (0.40496076942546194 %)
# Broj igraca na poziciji LW: 14, (0.3543406732472792 %)
# Broj igraca na poziciji ST: 821, (20.779549481144013 %)
# Broj igraca na poziciji CF: 12, (0.30372057706909644 %)
# Broj igraca na poziciji RS: 38, (0.961781827385472 %)
# Broj igraca na poziciji LS: 38, (0.961781827385472 %)
#
# VEZNI RED: 722 (18.273854720323968 %)
# Broj igraca na poziciji RDM: 24, (0.6074411541381929 %)
# Broj igraca na poziciji CDM: 230, (5.8213110604910145 %)
# Broj igraca na poziciji LDM: 30, (0.759301442672741 %)
# Broj igraca na poziciji RM: 42, (1.0630220197418374 %)
# Broj igraca na poziciji RCM: 20, (0.5062009617818274 %)
# Broj igraca na poziciji CM: 259, (6.555302455074664 %)
# Broj igraca na poziciji LCM: 25, (0.6327512022272842 %)
# Broj igraca na poziciji LM: 28, (0.7086813464945584 %)
# Broj igraca na poziciji RAM: 0, (0.0 %)
# Broj igraca na poziciji CAM: 64, (1.6198430777018478 %)
# Broj igraca na poziciji LAM: 0, (0.0 %)
#
# ODBRANA: 2273 (57.52973930650468 %)
# Broj igraca na poziciji RWB: 8, (0.20248038471273097 %)
# Broj igraca na poziciji RB: 119, (3.011895722601873 %)
# Broj igraca na poziciji RCB: 402, (10.174639331814731 %)
# Broj igraca na poziciji CB: 1235, (31.257909390027844 %)
# Broj igraca na poziciji LCB: 382, (9.668438370032902 %)
# Broj igraca na poziciji LB: 123, (3.1131359149582387 %)
# Broj igraca na poziciji LWB: 4, (0.10124019235636549 %)
#
# GOLMANI: 17 (0.4302708175145533 %)
#
# Broj igraca u klasteru 1: 4229, (23.227330147745374 %)
#
# NAPAD: 839 (19.83920548593048 %)
# Broj igraca na poziciji RF: 11, (0.2601087727595176 %)
# Broj igraca na poziciji LF: 9, (0.2128162686214235 %)
# Broj igraca na poziciji RW: 164, (3.8779853393237174 %)
# Broj igraca na poziciji LW: 165, (3.9016315913927646 %)
# Broj igraca na poziciji ST: 341, (8.063371955545046 %)
# Broj igraca na poziciji CF: 28, (0.6620950579333176 %)
# Broj igraca na poziciji RS: 54, (1.276897611728541 %)
# Broj igraca na poziciji LS: 67, (1.5842988886261529 %)
#
# VEZNI RED: 2604 (61.57484038779854 %)
# Broj igraca na poziciji RDM: 68, (1.6079451406952 %)
# Broj igraca na poziciji CDM: 147, (3.475999054149917 %)
# Broj igraca na poziciji LDM: 79, (1.8680539134547174 %)
# Broj igraca na poziciji RM: 499, (11.79947978245448 %)
# Broj igraca na poziciji RCM: 178, (4.209032868290376 %)
# Broj igraca na poziciji CM: 385, (9.103807046583116 %)
# Broj igraca na poziciji LCM: 191, (4.516434145187988 %)
# Broj igraca na poziciji LM: 522, (12.343343580042564 %)
# Broj igraca na poziciji RAM: 17, (0.4019862851738 %)
# Broj igraca na poziciji CAM: 503, (11.89406479073067 %)
# Broj igraca na poziciji LAM: 15, (0.3546937810357058 %)
#
# ODBRANA: 786 (18.585954126270988 %)
# Broj igraca na poziciji RWB: 14, (0.3310475289666588 %)
# Broj igraca na poziciji RB: 262, (6.195318042090329 %)
# Broj igraca na poziciji RCB: 19, (0.4492787893118941 %)
# Broj igraca na poziciji CB: 33, (0.7803263182785528 %)
# Broj igraca na poziciji LCB: 29, (0.6857413100023646 %)
# Broj igraca na poziciji LB: 398, (9.411208323480729 %)
# Broj igraca na poziciji LWB: 31, (0.7330338141404588 %)
#
# GOLMANI: 0 (0.0 %)
#
# Broj igraca u klasteru 2: 2132, (11.709781951996485 %)
#
# NAPAD: 3 (0.14071294559099437 %)
# Broj igraca na poziciji RF: 0, (0.0 %)
# Broj igraca na poziciji LF: 0, (0.0 %)
# Broj igraca na poziciji RW: 0, (0.0 %)
# Broj igraca na poziciji LW: 0, (0.0 %)
# Broj igraca na poziciji ST: 3, (0.14071294559099437 %)
# Broj igraca na poziciji CF: 0, (0.0 %)
# Broj igraca na poziciji RS: 0, (0.0 %)
# Broj igraca na poziciji LS: 0, (0.0 %)
#
# VEZNI RED: 2 (0.09380863039399624 %)
# Broj igraca na poziciji RDM: 0, (0.0 %)
# Broj igraca na poziciji CDM: 1, (0.04690431519699812 %)
# Broj igraca na poziciji LDM: 0, (0.0 %)
# Broj igraca na poziciji RM: 0, (0.0 %)
# Broj igraca na poziciji RCM: 0, (0.0 %)
# Broj igraca na poziciji CM: 0, (0.0 %)
# Broj igraca na poziciji LCM: 0, (0.0 %)
# Broj igraca na poziciji LM: 0, (0.0 %)
# Broj igraca na poziciji RAM: 0, (0.0 %)
# Broj igraca na poziciji CAM: 1, (0.04690431519699812 %)
# Broj igraca na poziciji LAM: 0, (0.0 %)
#
# ODBRANA: 119 (5.581613508442777 %)
# Broj igraca na poziciji RWB: 0, (0.0 %)
# Broj igraca na poziciji RB: 1, (0.04690431519699812 %)
# Broj igraca na poziciji RCB: 15, (0.7035647279549718 %)
# Broj igraca na poziciji CB: 90, (4.221388367729831 %)
# Broj igraca na poziciji LCB: 13, (0.6097560975609756 %)
# Broj igraca na poziciji LB: 0, (0.0 %)
# Broj igraca na poziciji LWB: 0, (0.0 %)
#
# GOLMANI: 2008 (94.18386491557223 %)
#
# Broj igraca u klasteru 3: 4929, (27.072005272697314 %)
#
# NAPAD: 1108 (22.479204706837088 %)
# Broj igraca na poziciji RF: 4, (0.08115236356258876 %)
# Broj igraca na poziciji LF: 4, (0.08115236356258876 %)
# Broj igraca na poziciji RW: 174, (3.5301278149726114 %)
# Broj igraca na poziciji LW: 172, (3.4895516331913163 %)
# Broj igraca na poziciji ST: 586, (11.888821261919254 %)
# Broj igraca na poziciji CF: 24, (0.48691418137553255 %)
# Broj igraca na poziciji RS: 75, (1.5216068167985393 %)
# Broj igraca na poziciji LS: 69, (1.399878271454656 %)
#
# VEZNI RED: 1840 (37.33008723879083 %)
# Broj igraca na poziciji RDM: 42, (0.852099817407182 %)
# Broj igraca na poziciji CDM: 169, (3.4286873605193753 %)
# Broj igraca na poziciji LDM: 46, (0.9332521809697708 %)
# Broj igraca na poziciji RM: 507, (10.286062081558125 %)
# Broj igraca na poziciji RCM: 87, (1.7650639074863057 %)
# Broj igraca na poziciji CM: 266, (5.396632176912153 %)
# Broj igraca na poziciji LCM: 66, (1.3390139987827145 %)
# Broj igraca na poziciji LM: 466, (9.45425035504159 %)
# Broj igraca na poziciji RAM: 4, (0.08115236356258876 %)
# Broj igraca na poziciji CAM: 183, (3.712720632988436 %)
# Broj igraca na poziciji LAM: 4, (0.08115236356258876 %)
#
# ODBRANA: 1981 (40.19070805437208 %)
# Broj igraca na poziciji RWB: 60, (1.2172854534388313 %)
# Broj igraca na poziciji RB: 829, (16.81882734834652 %)
# Broj igraca na poziciji RCB: 91, (1.8462162710488943 %)
# Broj igraca na poziciji CB: 168, (3.408399269628728 %)
# Broj igraca na poziciji LCB: 105, (2.130249543517955 %)
# Broj igraca na poziciji LB: 692, (14.039358896327855 %)
# Broj igraca na poziciji LWB: 36, (0.7303712720632989 %)
#
# GOLMANI: 0 (0.0 %)
#
# Broj igraca u klasteru 4: 2966, (16.290437743724944 %)
#
# NAPAD: 589 (19.8583951449764 %)
# Broj igraca na poziciji RF: 1, (0.033715441672285906 %)
# Broj igraca na poziciji LF: 2, (0.06743088334457181 %)
# Broj igraca na poziciji RW: 16, (0.5394470667565745 %)
# Broj igraca na poziciji LW: 30, (1.0114632501685772 %)
# Broj igraca na poziciji ST: 461, (15.542818610923803 %)
# Broj igraca na poziciji CF: 10, (0.33715441672285906 %)
# Broj igraca na poziciji RS: 36, (1.2137559002022926 %)
# Broj igraca na poziciji LS: 33, (1.1126095751854348 %)
#
# VEZNI RED: 1670 (56.30478759271747 %)
# Broj igraca na poziciji RDM: 114, (3.8435603506405935 %)
# Broj igraca na poziciji CDM: 401, (13.519892110586648 %)
# Broj igraca na poziciji LDM: 88, (2.9669588671611598 %)
# Broj igraca na poziciji RM: 76, (2.562373567093729 %)
# Broj igraca na poziciji RCM: 106, (3.5738368172623063 %)
# Broj igraca na poziciji CM: 484, (16.31827376938638 %)
# Broj igraca na poziciji LCM: 113, (3.8098449089683073 %)
# Broj igraca na poziciji LM: 79, (2.6635198921105867 %)
# Broj igraca na poziciji RAM: 0, (0.0 %)
# Broj igraca na poziciji CAM: 207, (6.979096426163182 %)
# Broj igraca na poziciji LAM: 2, (0.06743088334457181 %)
#
# ODBRANA: 707 (23.836817262306138 %)
# Broj igraca na poziciji RWB: 5, (0.16857720836142953 %)
# Broj igraca na poziciji RB: 80, (2.6972353337828725 %)
# Broj igraca na poziciji RCB: 135, (4.551584625758597 %)
# Broj igraca na poziciji CB: 252, (8.496291301416047 %)
# Broj igraca na poziciji LCB: 119, (4.0121375590020225 %)
# Broj igraca na poziciji LB: 109, (3.6749831422791637 %)
# Broj igraca na poziciji LWB: 7, (0.23600809170600134 %)
#
# GOLMANI: 0 (0.0 %)

# %%
draw(df)

# %%
# Crossing + BallControl + FKAccuracy + Acceleration + LongPassing

kmeans = KMeans(n_clusters=5, random_state=0)
kmeans.fit(df[['Crossing', 'BallControl', 'FKAccuracy', 'Acceleration', 'LongPassing']])
# Out:
# KMeans(n_clusters=5, random_state=0)

# %%
print_percentige_of_five_clusters(df)
# Out:
# Broj igraca u klasteru 0: 4727, (25.962541879496897 %)
#
# NAPAD: 759 (16.056695578591075 %)
# Broj igraca na poziciji RF: 12, (0.2538607996615189 %)
# Broj igraca na poziciji LF: 10, (0.21155066638459913 %)
# Broj igraca na poziciji RW: 151, (3.1944150624074465 %)
# Broj igraca na poziciji LW: 150, (3.1732599957689867 %)
# Broj igraca na poziciji ST: 300, (6.346519991537973 %)
# Broj igraca na poziciji CF: 27, (0.5711867992384176 %)
# Broj igraca na poziciji RS: 46, (0.9731330653691559 %)
# Broj igraca na poziciji LS: 63, (1.3327691982229743 %)
#
# VEZNI RED: 3043 (64.37486778083351 %)
# Broj igraca na poziciji RDM: 109, (2.3059022635921305 %)
# Broj igraca na poziciji CDM: 268, (5.669557859107257 %)
# Broj igraca na poziciji LDM: 117, (2.4751427966998096 %)
# Broj igraca na poziciji RM: 459, (9.710175587053099 %)
# Broj igraca na poziciji RCM: 227, (4.8022001269303995 %)
# Broj igraca na poziciji CM: 537, (11.360270784852974 %)
# Broj igraca na poziciji LCM: 246, (5.204146393061138 %)
# Broj igraca na poziciji LM: 500, (10.577533319229955 %)
# Broj igraca na poziciji RAM: 17, (0.35963613285381846 %)
# Broj igraca na poziciji CAM: 548, (11.592976517876032 %)
# Broj igraca na poziciji LAM: 15, (0.31732599957689867 %)
#
# ODBRANA: 925 (19.568436640575417 %)
# Broj igraca na poziciji RWB: 17, (0.35963613285381846 %)
# Broj igraca na poziciji RB: 292, (6.177279458430294 %)
# Broj igraca na poziciji RCB: 37, (0.7827374656230167 %)
# Broj igraca na poziciji CB: 61, (1.2904590649460546 %)
# Broj igraca na poziciji LCB: 59, (1.2481489316691348 %)
# Broj igraca na poziciji LB: 428, (9.054368521260841 %)
# Broj igraca na poziciji LWB: 31, (0.6558070657922572 %)
#
# GOLMANI: 0 (0.0 %)
#
# Broj igraca u klasteru 1: 3275, (17.98758719173944 %)
#
# NAPAD: 1078 (32.916030534351144 %)
# Broj igraca na poziciji RF: 0, (0.0 %)
# Broj igraca na poziciji LF: 0, (0.0 %)
# Broj igraca na poziciji RW: 26, (0.7938931297709925 %)
# Broj igraca na poziciji LW: 26, (0.7938931297709925 %)
# Broj igraca na poziciji ST: 924, (28.21374045801527 %)
# Broj igraca na poziciji CF: 11, (0.33587786259541985 %)
# Broj igraca na poziciji RS: 49, (1.4961832061068703 %)
# Broj igraca na poziciji LS: 42, (1.282442748091603 %)
#
# VEZNI RED: 314 (9.587786259541984 %)
# Broj igraca na poziciji RDM: 3, (0.0916030534351145 %)
# Broj igraca na poziciji CDM: 71, (2.16793893129771 %)
# Broj igraca na poziciji LDM: 5, (0.15267175572519084 %)
# Broj igraca na poziciji RM: 47, (1.4351145038167938 %)
# Broj igraca na poziciji RCM: 2, (0.06106870229007634 %)
# Broj igraca na poziciji CM: 110, (3.3587786259541987 %)
# Broj igraca na poziciji LCM: 7, (0.2137404580152672 %)
# Broj igraca na poziciji LM: 34, (1.0381679389312977 %)
# Broj igraca na poziciji RAM: 0, (0.0 %)
# Broj igraca na poziciji CAM: 35, (1.0687022900763359 %)
# Broj igraca na poziciji LAM: 0, (0.0 %)
#
# ODBRANA: 1860 (56.79389312977099 %)
# Broj igraca na poziciji RWB: 9, (0.2748091603053435 %)
# Broj igraca na poziciji RB: 148, (4.519083969465649 %)
# Broj igraca na poziciji RCB: 280, (8.549618320610687 %)
# Broj igraca na poziciji CB: 1010, (30.839694656488547 %)
# Broj igraca na poziciji LCB: 260, (7.938931297709924 %)
# Broj igraca na poziciji LB: 149, (4.549618320610687 %)
# Broj igraca na poziciji LWB: 4, (0.12213740458015268 %)
#
# GOLMANI: 23 (0.7022900763358778 %)
#
# Broj igraca u klasteru 2: 2109, (11.583456912176636 %)
#
# NAPAD: 5 (0.2370791844476055 %)
# Broj igraca na poziciji RF: 0, (0.0 %)
# Broj igraca na poziciji LF: 0, (0.0 %)
# Broj igraca na poziciji RW: 0, (0.0 %)
# Broj igraca na poziciji LW: 0, (0.0 %)
# Broj igraca na poziciji ST: 5, (0.2370791844476055 %)
# Broj igraca na poziciji CF: 0, (0.0 %)
# Broj igraca na poziciji RS: 0, (0.0 %)
# Broj igraca na poziciji LS: 0, (0.0 %)
#
# VEZNI RED: 1 (0.0474158368895211 %)
# Broj igraca na poziciji RDM: 0, (0.0 %)
# Broj igraca na poziciji CDM: 0, (0.0 %)
# Broj igraca na poziciji LDM: 0, (0.0 %)
# Broj igraca na poziciji RM: 0, (0.0 %)
# Broj igraca na poziciji RCM: 0, (0.0 %)
# Broj igraca na poziciji CM: 0, (0.0 %)
# Broj igraca na poziciji LCM: 0, (0.0 %)
# Broj igraca na poziciji LM: 0, (0.0 %)
# Broj igraca na poziciji RAM: 0, (0.0 %)
# Broj igraca na poziciji CAM: 1, (0.0474158368895211 %)
# Broj igraca na poziciji LAM: 0, (0.0 %)
#
# ODBRANA: 101 (4.788999525841631 %)
# Broj igraca na poziciji RWB: 0, (0.0 %)
# Broj igraca na poziciji RB: 1, (0.0474158368895211 %)
# Broj igraca na poziciji RCB: 12, (0.5689900426742532 %)
# Broj igraca na poziciji CB: 81, (3.8406827880512093 %)
# Broj igraca na poziciji LCB: 7, (0.33191085822664773 %)
# Broj igraca na poziciji LB: 0, (0.0 %)
# Broj igraca na poziciji LWB: 0, (0.0 %)
#
# GOLMANI: 2002 (94.92650545282125 %)
#
# Broj igraca u klasteru 3: 4596, (25.243038391827323 %)
#
# NAPAD: 1228 (26.718885987815494 %)
# Broj igraca na poziciji RF: 4, (0.08703220191470844 %)
# Broj igraca na poziciji LF: 3, (0.06527415143603134 %)
# Broj igraca na poziciji RW: 185, (4.025239338555266 %)
# Broj igraca na poziciji LW: 196, (4.2645778938207135 %)
# Broj igraca na poziciji ST: 651, (14.1644908616188 %)
# Broj igraca na poziciji CF: 30, (0.6527415143603132 %)
# Broj igraca na poziciji RS: 83, (1.8059181897302001 %)
# Broj igraca na poziciji LS: 76, (1.6536118363794605 %)
#
# VEZNI RED: 1626 (35.37859007832898 %)
# Broj igraca na poziciji RDM: 16, (0.34812880765883375 %)
# Broj igraca na poziciji CDM: 78, (1.6971279373368149 %)
# Broj igraca na poziciji LDM: 28, (0.6092254134029591 %)
# Broj igraca na poziciji RM: 563, (12.249782419495213 %)
# Broj igraca na poziciji RCM: 52, (1.1314186248912097 %)
# Broj igraca na poziciji CM: 135, (2.93733681462141 %)
# Broj igraca na poziciji LCM: 37, (0.8050478677110531 %)
# Broj igraca na poziciji LM: 501, (10.900783289817232 %)
# Broj igraca na poziciji RAM: 4, (0.08703220191470844 %)
# Broj igraca na poziciji CAM: 208, (4.525674499564839 %)
# Broj igraca na poziciji LAM: 4, (0.08703220191470844 %)
#
# ODBRANA: 1742 (37.90252393385553 %)
# Broj igraca na poziciji RWB: 51, (1.1096605744125325 %)
# Broj igraca na poziciji RB: 751, (16.34029590948651 %)
# Broj igraca na poziciji RCB: 58, (1.2619669277632724 %)
# Broj igraca na poziciji CB: 108, (2.3498694516971277 %)
# Broj igraca na poziciji LCB: 68, (1.4795474325500435 %)
# Broj igraca na poziciji LB: 667, (14.512619669277631 %)
# Broj igraca na poziciji LWB: 39, (0.8485639686684074 %)
#
# GOLMANI: 0 (0.0 %)
#
# Broj igraca u klasteru 4: 3500, (19.223375624759708 %)
#
# NAPAD: 408 (11.657142857142858 %)
# Broj igraca na poziciji RF: 0, (0.0 %)
# Broj igraca na poziciji LF: 2, (0.05714285714285715 %)
# Broj igraca na poziciji RW: 8, (0.2285714285714286 %)
# Broj igraca na poziciji LW: 9, (0.2571428571428571 %)
# Broj igraca na poziciji ST: 332, (9.485714285714286 %)
# Broj igraca na poziciji CF: 6, (0.17142857142857143 %)
# Broj igraca na poziciji RS: 25, (0.7142857142857143 %)
# Broj igraca na poziciji LS: 26, (0.7428571428571429 %)
#
# VEZNI RED: 1854 (52.97142857142857 %)
# Broj igraca na poziciji RDM: 120, (3.428571428571429 %)
# Broj igraca na poziciji CDM: 531, (15.171428571428573 %)
# Broj igraca na poziciji LDM: 93, (2.657142857142857 %)
# Broj igraca na poziciji RM: 55, (1.5714285714285716 %)
# Broj igraca na poziciji RCM: 110, (3.1428571428571432 %)
# Broj igraca na poziciji CM: 612, (17.485714285714284 %)
# Broj igraca na poziciji LCM: 105, (3.0 %)
# Broj igraca na poziciji LM: 60, (1.7142857142857144 %)
# Broj igraca na poziciji RAM: 0, (0.0 %)
# Broj igraca na poziciji CAM: 166, (4.742857142857143 %)
# Broj igraca na poziciji LAM: 2, (0.05714285714285715 %)
#
# ODBRANA: 1238 (35.371428571428574 %)
# Broj igraca na poziciji RWB: 10, (0.2857142857142857 %)
# Broj igraca na poziciji RB: 99, (2.8285714285714287 %)
# Broj igraca na poziciji RCB: 275, (7.857142857142857 %)
# Broj igraca na poziciji CB: 518, (14.799999999999999 %)
# Broj igraca na poziciji LCB: 254, (7.257142857142856 %)
# Broj igraca na poziciji LB: 78, (2.2285714285714286 %)
# Broj igraca na poziciji LWB: 4, (0.1142857142857143 %)
#
# GOLMANI: 0 (0.0 %)

# %%
draw(df)

# %%
# Crossing + BallControl + FKAccuracy + Acceleration + LongPassing + GKDiving

kmeans = KMeans(n_clusters=5, random_state=0)
kmeans.fit(df[['Crossing', 'BallControl', 'FKAccuracy', 'Acceleration', 'LongPassing', 'GKDiving']])
# Out:
# KMeans(n_clusters=5, random_state=0)

# %%
print_percentige_of_five_clusters(df)
# Out:
# Broj igraca u klasteru 0: 4764, (26.165760421815786 %)
#
# NAPAD: 766 (16.078925272879932 %)
# Broj igraca na poziciji RF: 12, (0.2518891687657431 %)
# Broj igraca na poziciji LF: 10, (0.20990764063811923 %)
# Broj igraca na poziciji RW: 151, (3.1696053736356005 %)
# Broj igraca na poziciji LW: 152, (3.190596137699412 %)
# Broj igraca na poziciji ST: 303, (6.360201511335013 %)
# Broj igraca na poziciji CF: 28, (0.5877413937867338 %)
# Broj igraca na poziciji RS: 47, (0.9865659109991604 %)
# Broj igraca na poziciji LS: 63, (1.322418136020151 %)
#
# VEZNI RED: 3064 (64.31570109151973 %)
# Broj igraca na poziciji RDM: 109, (2.2879932829554996 %)
# Broj igraca na poziciji CDM: 269, (5.646515533165408 %)
# Broj igraca na poziciji LDM: 117, (2.455919395465995 %)
# Broj igraca na poziciji RM: 463, (9.71872376154492 %)
# Broj igraca na poziciji RCM: 229, (4.806884970612931 %)
# Broj igraca na poziciji CM: 538, (11.293031066330816 %)
# Broj igraca na poziciji LCM: 248, (5.205709487825357 %)
# Broj igraca na poziciji LM: 507, (10.642317380352646 %)
# Broj igraca na poziciji RAM: 17, (0.3568429890848027 %)
# Broj igraca na poziciji CAM: 552, (11.586901763224182 %)
# Broj igraca na poziciji LAM: 15, (0.3148614609571789 %)
#
# ODBRANA: 934 (19.605373635600337 %)
# Broj igraca na poziciji RWB: 18, (0.3778337531486146 %)
# Broj igraca na poziciji RB: 295, (6.192275398824517 %)
# Broj igraca na poziciji RCB: 38, (0.797649034424853 %)
# Broj igraca na poziciji CB: 61, (1.2804366078925273 %)
# Broj igraca na poziciji LCB: 59, (1.2384550797649034 %)
# Broj igraca na poziciji LB: 432, (9.06801007556675 %)
# Broj igraca na poziciji LWB: 31, (0.6507136859781696 %)
#
# GOLMANI: 0 (0.0 %)
#
# Broj igraca u klasteru 1: 2025, (11.122095897182401 %)
#
# NAPAD: 1 (0.04938271604938272 %)
# Broj igraca na poziciji RF: 0, (0.0 %)
# Broj igraca na poziciji LF: 0, (0.0 %)
# Broj igraca na poziciji RW: 0, (0.0 %)
# Broj igraca na poziciji LW: 0, (0.0 %)
# Broj igraca na poziciji ST: 1, (0.04938271604938272 %)
# Broj igraca na poziciji CF: 0, (0.0 %)
# Broj igraca na poziciji RS: 0, (0.0 %)
# Broj igraca na poziciji LS: 0, (0.0 %)
#
# VEZNI RED: 0 (0.0 %)
# Broj igraca na poziciji RDM: 0, (0.0 %)
# Broj igraca na poziciji CDM: 0, (0.0 %)
# Broj igraca na poziciji LDM: 0, (0.0 %)
# Broj igraca na poziciji RM: 0, (0.0 %)
# Broj igraca na poziciji RCM: 0, (0.0 %)
# Broj igraca na poziciji CM: 0, (0.0 %)
# Broj igraca na poziciji LCM: 0, (0.0 %)
# Broj igraca na poziciji LM: 0, (0.0 %)
# Broj igraca na poziciji RAM: 0, (0.0 %)
# Broj igraca na poziciji CAM: 0, (0.0 %)
# Broj igraca na poziciji LAM: 0, (0.0 %)
#
# ODBRANA: 0 (0.0 %)
# Broj igraca na poziciji RWB: 0, (0.0 %)
# Broj igraca na poziciji RB: 0, (0.0 %)
# Broj igraca na poziciji RCB: 0, (0.0 %)
# Broj igraca na poziciji CB: 0, (0.0 %)
# Broj igraca na poziciji LCB: 0, (0.0 %)
# Broj igraca na poziciji LB: 0, (0.0 %)
# Broj igraca na poziciji LWB: 0, (0.0 %)
#
# GOLMANI: 2024 (99.95061728395062 %)
#
# Broj igraca u klasteru 2: 3235, (17.767891470313614 %)
#
# NAPAD: 1035 (31.993817619783616 %)
# Broj igraca na poziciji RF: 0, (0.0 %)
# Broj igraca na poziciji LF: 0, (0.0 %)
# Broj igraca na poziciji RW: 26, (0.80370942812983 %)
# Broj igraca na poziciji LW: 22, (0.6800618238021638 %)
# Broj igraca na poziciji ST: 895, (27.666151468315302 %)
# Broj igraca na poziciji CF: 10, (0.3091190108191654 %)
# Broj igraca na poziciji RS: 42, (1.2982998454404946 %)
# Broj igraca na poziciji LS: 40, (1.2364760432766615 %)
#
# VEZNI RED: 280 (8.65533230293663 %)
# Broj igraca na poziciji RDM: 3, (0.09273570324574962 %)
# Broj igraca na poziciji CDM: 66, (2.0401854714064918 %)
# Broj igraca na poziciji LDM: 5, (0.1545595054095827 %)
# Broj igraca na poziciji RM: 44, (1.3601236476043277 %)
# Broj igraca na poziciji RCM: 2, (0.061823802163833076 %)
# Broj igraca na poziciji CM: 94, (2.9057187017001542 %)
# Broj igraca na poziciji LCM: 6, (0.18547140649149924 %)
# Broj igraca na poziciji LM: 28, (0.865533230293663 %)
# Broj igraca na poziciji RAM: 0, (0.0 %)
# Broj igraca na poziciji CAM: 32, (0.9891808346213292 %)
# Broj igraca na poziciji LAM: 0, (0.0 %)
#
# ODBRANA: 1919 (59.31993817619784 %)
# Broj igraca na poziciji RWB: 9, (0.2782071097372488 %)
# Broj igraca na poziciji RB: 141, (4.358578052550232 %)
# Broj igraca na poziciji RCB: 287, (8.871715610510046 %)
# Broj igraca na poziciji CB: 1079, (33.353941267387945 %)
# Broj igraca na poziciji LCB: 261, (8.068006182380216 %)
# Broj igraca na poziciji LB: 138, (4.265842349304482 %)
# Broj igraca na poziciji LWB: 4, (0.12364760432766615 %)
#
# GOLMANI: 1 (0.030911901081916538 %)
#
# Broj igraca u klasteru 3: 3573, (19.62432031636184 %)
#
# NAPAD: 422 (11.810803246571508 %)
# Broj igraca na poziciji RF: 0, (0.0 %)
# Broj igraca na poziciji LF: 2, (0.055975370836831795 %)
# Broj igraca na poziciji RW: 8, (0.22390148334732718 %)
# Broj igraca na poziciji LW: 10, (0.279876854184159 %)
# Broj igraca na poziciji ST: 341, (9.543800727679821 %)
# Broj igraca na poziciji CF: 7, (0.19591379792891125 %)
# Broj igraca na poziciji RS: 28, (0.783655191715645 %)
# Broj igraca na poziciji LS: 26, (0.7276798208788133 %)
#
# VEZNI RED: 1886 (52.784774699132385 %)
# Broj igraca na poziciji RDM: 120, (3.3585222502099077 %)
# Broj igraca na poziciji CDM: 537, (15.029387069689337 %)
# Broj igraca na poziciji LDM: 94, (2.630842429331094 %)
# Broj igraca na poziciji RM: 55, (1.5393226980128742 %)
# Broj igraca na poziciji RCM: 111, (3.1066330814441647 %)
# Broj igraca na poziciji CM: 631, (17.66022949902043 %)
# Broj igraca na poziciji LCM: 106, (2.966694654352085 %)
# Broj igraca na poziciji LM: 62, (1.7352364959417856 %)
# Broj igraca na poziciji RAM: 0, (0.0 %)
# Broj igraca na poziciji CAM: 168, (4.701931150293871 %)
# Broj igraca na poziciji LAM: 2, (0.055975370836831795 %)
#
# ODBRANA: 1265 (35.404422054296106 %)
# Broj igraca na poziciji RWB: 10, (0.279876854184159 %)
# Broj igraca na poziciji RB: 104, (2.9107192835152533 %)
# Broj igraca na poziciji RCB: 281, (7.864539602574867 %)
# Broj igraca na poziciji CB: 526, (14.721522530086762 %)
# Broj igraca na poziciji LCB: 259, (7.248810523369717 %)
# Broj igraca na poziciji LB: 81, (2.2670025188916876 %)
# Broj igraca na poziciji LWB: 4, (0.11195074167366359 %)
#
# GOLMANI: 0 (0.0 %)
#
# Broj igraca u klasteru 4: 4610, (25.31993189432636 %)
#
# NAPAD: 1254 (27.201735357917574 %)
# Broj igraca na poziciji RF: 4, (0.08676789587852494 %)
# Broj igraca na poziciji LF: 3, (0.0650759219088937 %)
# Broj igraca na poziciji RW: 185, (4.0130151843817785 %)
# Broj igraca na poziciji LW: 197, (4.273318872017354 %)
# Broj igraca na poziciji ST: 672, (14.577006507592191 %)
# Broj igraca na poziciji CF: 29, (0.6290672451193058 %)
# Broj igraca na poziciji RS: 86, (1.8655097613882863 %)
# Broj igraca na poziciji LS: 78, (1.6919739696312366 %)
#
# VEZNI RED: 1608 (34.88069414316703 %)
# Broj igraca na poziciji RDM: 16, (0.3470715835140998 %)
# Broj igraca na poziciji CDM: 76, (1.648590021691974 %)
# Broj igraca na poziciji LDM: 27, (0.5856832971800434 %)
# Broj igraca na poziciji RM: 562, (12.190889370932755 %)
# Broj igraca na poziciji RCM: 49, (1.0629067245119306 %)
# Broj igraca na poziciji CM: 131, (2.841648590021692 %)
# Broj igraca na poziciji LCM: 35, (0.7592190889370932 %)
# Broj igraca na poziciji LM: 498, (10.802603036876356 %)
# Broj igraca na poziciji RAM: 4, (0.08676789587852494 %)
# Broj igraca na poziciji CAM: 206, (4.468546637744035 %)
# Broj igraca na poziciji LAM: 4, (0.08676789587852494 %)
#
# ODBRANA: 1748 (37.9175704989154 %)
# Broj igraca na poziciji RWB: 50, (1.0845986984815619 %)
# Broj igraca na poziciji RB: 751, (16.290672451193057 %)
# Broj igraca na poziciji RCB: 56, (1.2147505422993492 %)
# Broj igraca na poziciji CB: 112, (2.4295010845986984 %)
# Broj igraca na poziciji LCB: 69, (1.4967462039045552 %)
# Broj igraca na poziciji LB: 671, (14.55531453362256 %)
# Broj igraca na poziciji LWB: 39, (0.8459869848156183 %)
#
# GOLMANI: 0 (0.0 %)

# %%
draw(df)

# %% [markdown]
# ## Zašto je napadač ID=193911 svrstan u golmane?

# %%
def find_irq_outliers(values):
    
    outliers = []
    sorted_values = sorted(values)
    min, max = np.percentile(sorted_values, [25, 75])
    irq_difference = max - min
    upper_border = max + 1.5 * irq_difference
    lower_border = min - 1.5 * irq_difference

    for value in sorted_values:
        if value < lower_border or value > upper_border:
            outliers.append(value)
    return outliers

# %%
df_temp = df.loc[df['Position'] == 'ST']

find_irq_outliers(df_temp['GKDiving'])
df_temp.loc[df_temp['GKDiving'] == 0.5842696629213483]
# Out:
#        Unnamed: 0      ID     Name       Age  \
# 16450       16450  193911  S. Paul  0.517241
#
#                                                 Photo Nationality  \
# 16450  https://cdn.sofifa.org/players/4/19/193911.png       India
#
#                                        Flag   Overall  Potential       Club  \
# 16450  https://cdn.sofifa.org/flags/159.png  0.229167   0.191489  AS Monaco
#
#        ...   Marking StandingTackle SlidingTackle  GKDiving GKHandling  \
# 16450  ...  0.098901       0.142857      0.102273   0.58427   0.516484
#
#        GKKicking  GKPositioning  GKReflexes Release Clause cluster_marks
# 16450   0.677778       0.629213    0.634409          1.1M             1
#
# [1 rows x 89 columns]

# %%
find_irq_outliers(df_temp['GKHandling'])
df_temp.loc[df_temp['GKHandling'] == 0.5164835164835165]
# Out:
#        Unnamed: 0      ID     Name       Age  \
# 16450       16450  193911  S. Paul  0.517241
#
#                                                 Photo Nationality  \
# 16450  https://cdn.sofifa.org/players/4/19/193911.png       India
#
#                                        Flag   Overall  Potential       Club  \
# 16450  https://cdn.sofifa.org/flags/159.png  0.229167   0.191489  AS Monaco
#
#        ...   Marking StandingTackle SlidingTackle  GKDiving GKHandling  \
# 16450  ...  0.098901       0.142857      0.102273   0.58427   0.516484
#
#        GKKicking  GKPositioning  GKReflexes Release Clause cluster_marks
# 16450   0.677778       0.629213    0.634409          1.1M             1
#
# [1 rows x 89 columns]

# %%
find_irq_outliers(df_temp['GKKicking'])
df_temp.loc[df_temp['GKKicking'] == 0.6777777777777778]
# Out:
#        Unnamed: 0      ID     Name       Age  \
# 16450       16450  193911  S. Paul  0.517241
#
#                                                 Photo Nationality  \
# 16450  https://cdn.sofifa.org/players/4/19/193911.png       India
#
#                                        Flag   Overall  Potential       Club  \
# 16450  https://cdn.sofifa.org/flags/159.png  0.229167   0.191489  AS Monaco
#
#        ...   Marking StandingTackle SlidingTackle  GKDiving GKHandling  \
# 16450  ...  0.098901       0.142857      0.102273   0.58427   0.516484
#
#        GKKicking  GKPositioning  GKReflexes Release Clause cluster_marks
# 16450   0.677778       0.629213    0.634409          1.1M             1
#
# [1 rows x 89 columns]

# %%
find_irq_outliers(df_temp['GKPositioning'])
df_temp.loc[df_temp['GKPositioning'] == 0.6292134831460674]
# Out:
#        Unnamed: 0      ID     Name       Age  \
# 16450       16450  193911  S. Paul  0.517241
#
#                                                 Photo Nationality  \
# 16450  https://cdn.sofifa.org/players/4/19/193911.png       India
#
#                                        Flag   Overall  Potential       Club  \
# 16450  https://cdn.sofifa.org/flags/159.png  0.229167   0.191489  AS Monaco
#
#        ...   Marking StandingTackle SlidingTackle  GKDiving GKHandling  \
# 16450  ...  0.098901       0.142857      0.102273   0.58427   0.516484
#
#        GKKicking  GKPositioning  GKReflexes Release Clause cluster_marks
# 16450   0.677778       0.629213    0.634409          1.1M             1
#
# [1 rows x 89 columns]

# %%
find_irq_outliers(df_temp['GKReflexes'])
df_temp.loc[df_temp['GKReflexes'] == 0.6344086021505377]
# Out:
#        Unnamed: 0      ID     Name       Age  \
# 16450       16450  193911  S. Paul  0.517241
#
#                                                 Photo Nationality  \
# 16450  https://cdn.sofifa.org/players/4/19/193911.png       India
#
#                                        Flag   Overall  Potential       Club  \
# 16450  https://cdn.sofifa.org/flags/159.png  0.229167   0.191489  AS Monaco
#
#        ...   Marking StandingTackle SlidingTackle  GKDiving GKHandling  \
# 16450  ...  0.098901       0.142857      0.102273   0.58427   0.516484
#
#        GKKicking  GKPositioning  GKReflexes Release Clause cluster_marks
# 16450   0.677778       0.629213    0.634409          1.1M             1
#
# [1 rows x 89 columns]

# %%
find_irq_outliers(df_temp['Special'])
# Out:
# [0.18637770897832823,
#  0.8513931888544892,
#  0.8520123839009288,
#  0.8637770897832817,
#  0.879876160990712,
#  0.8879256965944273,
#  0.9269349845201238,
#  0.958513931888545]

# %%
df_temp.loc[df_temp['Special'] == 0.18637770897832823]
# Out:
#        Unnamed: 0      ID     Name       Age  \
# 16450       16450  193911  S. Paul  0.517241
#
#                                                 Photo Nationality  \
# 16450  https://cdn.sofifa.org/players/4/19/193911.png       India
#
#                                        Flag   Overall  Potential       Club  \
# 16450  https://cdn.sofifa.org/flags/159.png  0.229167   0.191489  AS Monaco
#
#        ...   Marking StandingTackle SlidingTackle  GKDiving GKHandling  \
# 16450  ...  0.098901       0.142857      0.102273   0.58427   0.516484
#
#        GKKicking  GKPositioning  GKReflexes Release Clause cluster_marks
# 16450   0.677778       0.629213    0.634409          1.1M             1
#
# [1 rows x 89 columns]

# %%
df_temp.loc[df_temp['Finishing'] == 0.19354838709677422]
# Out:
#        Unnamed: 0      ID     Name       Age  \
# 16450       16450  193911  S. Paul  0.517241
#
#                                                 Photo Nationality  \
# 16450  https://cdn.sofifa.org/players/4/19/193911.png       India
#
#                                        Flag   Overall  Potential       Club  \
# 16450  https://cdn.sofifa.org/flags/159.png  0.229167   0.191489  AS Monaco
#
#        ...   Marking StandingTackle SlidingTackle  GKDiving GKHandling  \
# 16450  ...  0.098901       0.142857      0.102273   0.58427   0.516484
#
#        GKKicking  GKPositioning  GKReflexes Release Clause cluster_marks
# 16450   0.677778       0.629213    0.634409          1.1M             1
#
# [1 rows x 89 columns]

# %%
find_irq_outliers(df_temp['HeadingAccuracy'])
# Out:
# [0.12222222222222223,
#  0.2888888888888889,
#  0.32222222222222224,
#  0.977777777777778,
#  0.977777777777778,
#  0.988888888888889,
#  1.0]

# %%
df_temp.loc[df_temp['HeadingAccuracy'] == 0.12222222222222223]
# Out:
#        Unnamed: 0      ID     Name       Age  \
# 16450       16450  193911  S. Paul  0.517241
#
#                                                 Photo Nationality  \
# 16450  https://cdn.sofifa.org/players/4/19/193911.png       India
#
#                                        Flag   Overall  Potential       Club  \
# 16450  https://cdn.sofifa.org/flags/159.png  0.229167   0.191489  AS Monaco
#
#        ...   Marking StandingTackle SlidingTackle  GKDiving GKHandling  \
# 16450  ...  0.098901       0.142857      0.102273   0.58427   0.516484
#
#        GKKicking  GKPositioning  GKReflexes Release Clause cluster_marks
# 16450   0.677778       0.629213    0.634409          1.1M             1
#
# [1 rows x 89 columns]

# %%
find_irq_outliers(df_temp['ShortPassing'])
# Out:
# [0.18604651162790695,
#  0.24418604651162792,
#  0.2674418604651163,
#  0.2906976744186046,
#  0.3023255813953488,
#  0.883720930232558,
#  0.883720930232558,
#  0.8953488372093023,
#  0.9069767441860465]

# %%
df_temp.loc[df_temp['ShortPassing'] == 0.18604651162790695]
# Out:
#        Unnamed: 0      ID     Name       Age  \
# 16450       16450  193911  S. Paul  0.517241
#
#                                                 Photo Nationality  \
# 16450  https://cdn.sofifa.org/players/4/19/193911.png       India
#
#                                        Flag   Overall  Potential       Club  \
# 16450  https://cdn.sofifa.org/flags/159.png  0.229167   0.191489  AS Monaco
#
#        ...   Marking StandingTackle SlidingTackle  GKDiving GKHandling  \
# 16450  ...  0.098901       0.142857      0.102273   0.58427   0.516484
#
#        GKKicking  GKPositioning  GKReflexes Release Clause cluster_marks
# 16450   0.677778       0.629213    0.634409          1.1M             1
#
# [1 rows x 89 columns]

# %%
find_irq_outliers(df_temp['Volleys'])
# Out:
# [0.1511627906976744, 0.1744186046511628, 0.18604651162790697]

# %%
df_temp.loc[df_temp['Volleys'] == 0.1511627906976744]
# Out:
#        Unnamed: 0      ID     Name       Age  \
# 16450       16450  193911  S. Paul  0.517241
#
#                                                 Photo Nationality  \
# 16450  https://cdn.sofifa.org/players/4/19/193911.png       India
#
#                                        Flag   Overall  Potential       Club  \
# 16450  https://cdn.sofifa.org/flags/159.png  0.229167   0.191489  AS Monaco
#
#        ...   Marking StandingTackle SlidingTackle  GKDiving GKHandling  \
# 16450  ...  0.098901       0.142857      0.102273   0.58427   0.516484
#
#        GKKicking  GKPositioning  GKReflexes Release Clause cluster_marks
# 16450   0.677778       0.629213    0.634409          1.1M             1
#
# [1 rows x 89 columns]

# %%
find_irq_outliers(df_temp['Dribbling'])
# Out:
# [0.10752688172043011,
#  0.3655913978494624,
#  0.3655913978494624,
#  0.3763440860215054,
#  0.3763440860215054,
#  0.3763440860215054,
#  0.3763440860215054,
#  0.3763440860215054,
#  0.3763440860215054,
#  0.38709677419354843,
#  0.870967741935484,
#  0.870967741935484,
#  0.870967741935484,
#  0.870967741935484,
#  0.870967741935484,
#  0.881720430107527,
#  0.881720430107527,
#  0.881720430107527,
#  0.881720430107527,
#  0.89247311827957,
#  0.89247311827957,
#  0.903225806451613,
#  0.913978494623656]

# %%
df_temp.loc[df_temp['Dribbling'] == 0.10752688172043011]
# Out:
#        Unnamed: 0      ID     Name       Age  \
# 16450       16450  193911  S. Paul  0.517241
#
#                                                 Photo Nationality  \
# 16450  https://cdn.sofifa.org/players/4/19/193911.png       India
#
#                                        Flag   Overall  Potential       Club  \
# 16450  https://cdn.sofifa.org/flags/159.png  0.229167   0.191489  AS Monaco
#
#        ...   Marking StandingTackle SlidingTackle  GKDiving GKHandling  \
# 16450  ...  0.098901       0.142857      0.102273   0.58427   0.516484
#
#        GKKicking  GKPositioning  GKReflexes Release Clause cluster_marks
# 16450   0.677778       0.629213    0.634409          1.1M             1
#
# [1 rows x 89 columns]

# %%
df_temp.loc[df_temp['BallControl'] == 0.08791208791208793]
# Out:
#        Unnamed: 0      ID     Name       Age  \
# 16450       16450  193911  S. Paul  0.517241
#
#                                                 Photo Nationality  \
# 16450  https://cdn.sofifa.org/players/4/19/193911.png       India
#
#                                        Flag   Overall  Potential       Club  \
# 16450  https://cdn.sofifa.org/flags/159.png  0.229167   0.191489  AS Monaco
#
#        ...   Marking StandingTackle SlidingTackle  GKDiving GKHandling  \
# 16450  ...  0.098901       0.142857      0.102273   0.58427   0.516484
#
#        GKKicking  GKPositioning  GKReflexes Release Clause cluster_marks
# 16450   0.677778       0.629213    0.634409          1.1M             1
#
# [1 rows x 89 columns]

# %%
find_irq_outliers(df_temp['ShotPower'])
# Out:
# [0.11827956989247312,
#  0.23655913978494622,
#  0.23655913978494622,
#  0.31182795698924737,
#  0.38709677419354843,
#  0.9677419354838711,
#  1.0]

# %%
df_temp.loc[df_temp['ShotPower'] == 0.11827956989247312]
# Out:
#        Unnamed: 0      ID     Name       Age  \
# 16450       16450  193911  S. Paul  0.517241
#
#                                                 Photo Nationality  \
# 16450  https://cdn.sofifa.org/players/4/19/193911.png       India
#
#                                        Flag   Overall  Potential       Club  \
# 16450  https://cdn.sofifa.org/flags/159.png  0.229167   0.191489  AS Monaco
#
#        ...   Marking StandingTackle SlidingTackle  GKDiving GKHandling  \
# 16450  ...  0.098901       0.142857      0.102273   0.58427   0.516484
#
#        GKKicking  GKPositioning  GKReflexes Release Clause cluster_marks
# 16450   0.677778       0.629213    0.634409          1.1M             1
#
# [1 rows x 89 columns]

# %%
find_irq_outliers(df_temp['LongShots'])
# Out:
# [0.14285714285714288,
#  0.19780219780219782,
#  0.20879120879120883,
#  0.28571428571428575,
#  0.28571428571428575,
#  0.29670329670329676,
#  0.3076923076923077,
#  0.3186813186813187,
#  0.3516483516483517,
#  0.3516483516483517,
#  0.8791208791208792,
#  0.8901098901098902,
#  0.8901098901098902,
#  0.9010989010989012,
#  0.9010989010989012,
#  0.967032967032967,
#  0.9890109890109892]

# %%
df_temp.loc[df_temp['LongShots'] == 0.14285714285714288]
# Out:
#        Unnamed: 0      ID     Name       Age  \
# 16450       16450  193911  S. Paul  0.517241
#
#                                                 Photo Nationality  \
# 16450  https://cdn.sofifa.org/players/4/19/193911.png       India
#
#                                        Flag   Overall  Potential       Club  \
# 16450  https://cdn.sofifa.org/flags/159.png  0.229167   0.191489  AS Monaco
#
#        ...   Marking StandingTackle SlidingTackle  GKDiving GKHandling  \
# 16450  ...  0.098901       0.142857      0.102273   0.58427   0.516484
#
#        GKKicking  GKPositioning  GKReflexes Release Clause cluster_marks
# 16450   0.677778       0.629213    0.634409          1.1M             1
#
# [1 rows x 89 columns]

# %%
find_irq_outliers(df_temp['Interceptions'])
# Out:
# [0.6179775280898877,
#  0.6179775280898877,
#  0.6179775280898877,
#  0.6179775280898877,
#  0.6179775280898877,
#  0.6179775280898877,
#  0.6179775280898877,
#  0.6292134831460674,
#  0.6292134831460674,
#  0.6292134831460674,
#  0.6292134831460674,
#  0.6292134831460674,
#  0.6292134831460674,
#  0.6404494382022472,
#  0.6404494382022472,
#  0.651685393258427,
#  0.651685393258427,
#  0.6629213483146067,
#  0.6629213483146067,
#  0.6741573033707865,
#  0.6741573033707865,
#  0.6741573033707865,
#  0.6853932584269663,
#  0.6966292134831461,
#  0.6966292134831461,
#  0.7078651685393259,
#  0.7078651685393259,
#  0.7191011235955056]

# %%
df_temp.loc[df_temp['Interceptions'] == 0.6179775280898877]
# Out:
#        Unnamed: 0      ID             Name       Age  \
# 3525         3525  158309          Gao Lin  0.551724
# 5197         5197  232318       Waguininho  0.413793
# 5497         5497  198611        N. ?ur?i?  0.551724
# 6349         6349  202175  M. Vilhjálmsson  0.517241
# 9298         9298  191861    Dong Xuesheng  0.448276
# 9608         9608  202169          J. Gatt  0.344828
# 16539       16539  245167  L. Lalruatthara  0.241379
#
#                                                 Photo    Nationality  \
# 3525   https://cdn.sofifa.org/players/4/19/158309.png       China PR
# 5197   https://cdn.sofifa.org/players/4/19/232318.png         Brazil
# 5497   https://cdn.sofifa.org/players/4/19/198611.png         Serbia
# 6349   https://cdn.sofifa.org/players/4/19/202175.png        Iceland
# 9298   https://cdn.sofifa.org/players/4/19/191861.png       China PR
# 9608   https://cdn.sofifa.org/players/4/19/202169.png  United States
# 16539  https://cdn.sofifa.org/players/4/19/245167.png          India
#
#                                        Flag   Overall  Potential  \
# 3525   https://cdn.sofifa.org/flags/155.png  0.541667   0.510638
# 5197    https://cdn.sofifa.org/flags/54.png  0.500000   0.468085
# 5497    https://cdn.sofifa.org/flags/51.png  0.500000   0.468085
# 6349    https://cdn.sofifa.org/flags/24.png  0.479167   0.446809
# 9298   https://cdn.sofifa.org/flags/155.png  0.416667   0.382979
# 9608    https://cdn.sofifa.org/flags/95.png  0.416667   0.382979
# 16539  https://cdn.sofifa.org/flags/159.png  0.229167   0.319149
#
#                                  Club  ...   Marking StandingTackle  \
# 3525   Guangzhou Evergrande Taobao FC  ...  0.428571       0.549451
# 5197          Suwon Samsung Bluewings  ...  0.461538       0.538462
# 5497                      Hammarby IF  ...  0.505495       0.516484
# 6349                     Rosenborg BK  ...  0.604396       0.648352
# 9298           Hebei China Fortune FC  ...  0.395604       0.131868
# 9608                       SCR Altach  ...  0.395604       0.472527
# 16539                       AS Monaco  ...  0.626374       0.648352
#
#       SlidingTackle  GKDiving GKHandling  GKKicking  GKPositioning  \
# 3525       0.545455  0.101124   0.087912   0.066667       0.112360
# 5197       0.488636  0.134831   0.065934   0.111111       0.067416
# 5497       0.465909  0.112360   0.164835   0.088889       0.134831
# 6349       0.579545  0.056180   0.164835   0.144444       0.146067
# 9298       0.170455  0.123596   0.142857   0.088889       0.067416
# 9608       0.443182  0.123596   0.120879   0.133333       0.134831
# 16539      0.613636  0.157303   0.120879   0.111111       0.056180
#
#        GKReflexes Release Clause cluster_marks
# 3525     0.086022          5.4M             0
# 5197     0.129032          2.3M             0
# 5497     0.053763          1.8M             4
# 6349     0.150538          1.2M             3
# 9298     0.096774          1.4M             3
# 9608     0.086022            1M             4
# 16539    0.118280          1.1M             2
#
# [7 rows x 89 columns]

# %%
find_irq_outliers(df_temp['Positioning'])
# Out:
# [0.1075268817204301,
#  0.2580645161290323,
#  0.2580645161290323,
#  0.35483870967741943,
#  0.37634408602150543,
#  0.37634408602150543,
#  0.38709677419354843,
#  0.9569892473118281,
#  0.9569892473118281,
#  0.9677419354838711,
#  0.9677419354838711,
#  0.978494623655914,
#  1.0]

# %%
df_temp.loc[df_temp['Positioning'] == 0.1075268817204301]
# Out:
#        Unnamed: 0      ID     Name       Age  \
# 16450       16450  193911  S. Paul  0.517241
#
#                                                 Photo Nationality  \
# 16450  https://cdn.sofifa.org/players/4/19/193911.png       India
#
#                                        Flag   Overall  Potential       Club  \
# 16450  https://cdn.sofifa.org/flags/159.png  0.229167   0.191489  AS Monaco
#
#        ...   Marking StandingTackle SlidingTackle  GKDiving GKHandling  \
# 16450  ...  0.098901       0.142857      0.102273   0.58427   0.516484
#
#        GKKicking  GKPositioning  GKReflexes Release Clause cluster_marks
# 16450   0.677778       0.629213    0.634409          1.1M             1
#
# [1 rows x 89 columns]

# %% [markdown]
# ## Da li će zamenom outlier parametara median vrednošću odgovarajucih kolona, k-means algoritam prestati napadača ID=193911 da svrstava u golmane?

# %%
# Zamena BallControl vrednosti napadaca ID=193911 median vrednoscu

st = df.loc[df['Position'] == 'ST']
df.loc[df['ID'] == 193911, 'BallControl'] = st['BallControl'].median()

# %%
kmeans= KMeans(n_clusters=5, random_state=0)
kmeans.fit(df[numeric])
# Out:
# KMeans(n_clusters=5, random_state=0)

# %%
print_percentige_of_five_clusters(df)
# Out:
# Broj igraca u klasteru 0: 4626, (25.40781018289669 %)
#
# NAPAD: 10 (0.21616947686986598 %)
# Broj igraca na poziciji RF: 0, (0.0 %)
# Broj igraca na poziciji LF: 0, (0.0 %)
# Broj igraca na poziciji RW: 0, (0.0 %)
# Broj igraca na poziciji LW: 0, (0.0 %)
# Broj igraca na poziciji ST: 10, (0.21616947686986598 %)
# Broj igraca na poziciji CF: 0, (0.0 %)
# Broj igraca na poziciji RS: 0, (0.0 %)
# Broj igraca na poziciji LS: 0, (0.0 %)
#
# VEZNI RED: 809 (17.488110678772156 %)
# Broj igraca na poziciji RDM: 37, (0.799827064418504 %)
# Broj igraca na poziciji CDM: 355, (7.674016428880242 %)
# Broj igraca na poziciji LDM: 37, (0.799827064418504 %)
# Broj igraca na poziciji RM: 27, (0.5836575875486382 %)
# Broj igraca na poziciji RCM: 35, (0.7565931690445309 %)
# Broj igraca na poziciji CM: 255, (5.512321660181582 %)
# Broj igraca na poziciji LCM: 31, (0.6701253782965845 %)
# Broj igraca na poziciji LM: 24, (0.5188067444876783 %)
# Broj igraca na poziciji RAM: 0, (0.0 %)
# Broj igraca na poziciji CAM: 8, (0.17293558149589278 %)
# Broj igraca na poziciji LAM: 0, (0.0 %)
#
# ODBRANA: 3807 (82.29571984435798 %)
# Broj igraca na poziciji RWB: 37, (0.799827064418504 %)
# Broj igraca na poziciji RB: 591, (12.775616083009078 %)
# Broj igraca na poziciji RCB: 517, (11.175961954172072 %)
# Broj igraca na poziciji CB: 1562, (33.765672287073066 %)
# Broj igraca na poziciji LCB: 496, (10.722006052745352 %)
# Broj igraca na poziciji LB: 575, (12.429744920017294 %)
# Broj igraca na poziciji LWB: 29, (0.6268914829226113 %)
#
# GOLMANI: 0 (0.0 %)
#
# Broj igraca u klasteru 1: 3545, (19.47053331136376 %)
#
# NAPAD: 1937 (54.64033850493652 %)
# Broj igraca na poziciji RF: 1, (0.028208744710860365 %)
# Broj igraca na poziciji LF: 1, (0.028208744710860365 %)
# Broj igraca na poziciji RW: 165, (4.65444287729196 %)
# Broj igraca na poziciji LW: 171, (4.823695345557122 %)
# Broj igraca na poziciji ST: 1400, (39.492242595204516 %)
# Broj igraca na poziciji CF: 39, (1.1001410437235544 %)
# Broj igraca na poziciji RS: 78, (2.2002820874471087 %)
# Broj igraca na poziciji LS: 82, (2.31311706629055 %)
#
# VEZNI RED: 1569 (44.25952045133992 %)
# Broj igraca na poziciji RDM: 6, (0.16925246826516221 %)
# Broj igraca na poziciji CDM: 8, (0.22566995768688292 %)
# Broj igraca na poziciji LDM: 6, (0.16925246826516221 %)
# Broj igraca na poziciji RM: 444, (12.524682651622001 %)
# Broj igraca na poziciji RCM: 18, (0.5077574047954866 %)
# Broj igraca na poziciji CM: 300, (8.46262341325811 %)
# Broj igraca na poziciji LCM: 25, (0.7052186177715092 %)
# Broj igraca na poziciji LM: 419, (11.819464033850494 %)
# Broj igraca na poziciji RAM: 1, (0.028208744710860365 %)
# Broj igraca na poziciji CAM: 340, (9.590973201692526 %)
# Broj igraca na poziciji LAM: 2, (0.05641748942172073 %)
#
# ODBRANA: 39 (1.1001410437235544 %)
# Broj igraca na poziciji RWB: 5, (0.14104372355430184 %)
# Broj igraca na poziciji RB: 14, (0.39492242595204513 %)
# Broj igraca na poziciji RCB: 0, (0.0 %)
# Broj igraca na poziciji CB: 3, (0.08462623413258111 %)
# Broj igraca na poziciji LCB: 1, (0.028208744710860365 %)
# Broj igraca na poziciji LB: 13, (0.36671368124118475 %)
# Broj igraca na poziciji LWB: 3, (0.08462623413258111 %)
#
# GOLMANI: 0 (0.0 %)
#
# Broj igraca u klasteru 2: 2026, (11.127588290218048 %)
#
# NAPAD: 1 (0.04935834155972359 %)
# Broj igraca na poziciji RF: 0, (0.0 %)
# Broj igraca na poziciji LF: 0, (0.0 %)
# Broj igraca na poziciji RW: 0, (0.0 %)
# Broj igraca na poziciji LW: 0, (0.0 %)
# Broj igraca na poziciji ST: 1, (0.04935834155972359 %)
# Broj igraca na poziciji CF: 0, (0.0 %)
# Broj igraca na poziciji RS: 0, (0.0 %)
# Broj igraca na poziciji LS: 0, (0.0 %)
#
# VEZNI RED: 0 (0.0 %)
# Broj igraca na poziciji RDM: 0, (0.0 %)
# Broj igraca na poziciji CDM: 0, (0.0 %)
# Broj igraca na poziciji LDM: 0, (0.0 %)
# Broj igraca na poziciji RM: 0, (0.0 %)
# Broj igraca na poziciji RCM: 0, (0.0 %)
# Broj igraca na poziciji CM: 0, (0.0 %)
# Broj igraca na poziciji LCM: 0, (0.0 %)
# Broj igraca na poziciji LM: 0, (0.0 %)
# Broj igraca na poziciji RAM: 0, (0.0 %)
# Broj igraca na poziciji CAM: 0, (0.0 %)
# Broj igraca na poziciji LAM: 0, (0.0 %)
#
# ODBRANA: 0 (0.0 %)
# Broj igraca na poziciji RWB: 0, (0.0 %)
# Broj igraca na poziciji RB: 0, (0.0 %)
# Broj igraca na poziciji RCB: 0, (0.0 %)
# Broj igraca na poziciji CB: 0, (0.0 %)
# Broj igraca na poziciji LCB: 0, (0.0 %)
# Broj igraca na poziciji LB: 0, (0.0 %)
# Broj igraca na poziciji LWB: 0, (0.0 %)
#
# GOLMANI: 2025 (99.95064165844028 %)
#
# Broj igraca u klasteru 3: 3116, (17.114296699071787 %)
#
# NAPAD: 1453 (46.63029525032093 %)
# Broj igraca na poziciji RF: 14, (0.4492939666238768 %)
# Broj igraca na poziciji LF: 13, (0.41720154043645696 %)
# Broj igraca na poziciji RW: 182, (5.840821566110398 %)
# Broj igraca na poziciji LW: 185, (5.937098844672657 %)
# Broj igraca na poziciji ST: 780, (25.03209242618742 %)
# Broj igraca na poziciji CF: 35, (1.123234916559692 %)
# Broj igraca na poziciji RS: 121, (3.8831835686777922 %)
# Broj igraca na poziciji LS: 123, (3.9473684210526314 %)
#
# VEZNI RED: 1658 (53.20924261874198 %)
# Broj igraca na poziciji RDM: 8, (0.25673940949935814 %)
# Broj igraca na poziciji CDM: 2, (0.06418485237483953 %)
# Broj igraca na poziciji LDM: 12, (0.38510911424903727 %)
# Broj igraca na poziciji RM: 477, (15.30808729139923 %)
# Broj igraca na poziciji RCM: 45, (1.4441591784338896 %)
# Broj igraca na poziciji CM: 80, (2.5673940949935816 %)
# Broj igraca na poziciji LCM: 63, (2.0218228498074455 %)
# Broj igraca na poziciji LM: 473, (15.179717586649552 %)
# Broj igraca na poziciji RAM: 18, (0.5776636713735559 %)
# Broj igraca na poziciji CAM: 461, (14.794608472400514 %)
# Broj igraca na poziciji LAM: 19, (0.6097560975609756 %)
#
# ODBRANA: 5 (0.16046213093709885 %)
# Broj igraca na poziciji RWB: 0, (0.0 %)
# Broj igraca na poziciji RB: 0, (0.0 %)
# Broj igraca na poziciji RCB: 1, (0.03209242618741977 %)
# Broj igraca na poziciji CB: 0, (0.0 %)
# Broj igraca na poziciji LCB: 0, (0.0 %)
# Broj igraca na poziciji LB: 3, (0.09627727856225932 %)
# Broj igraca na poziciji LWB: 1, (0.03209242618741977 %)
#
# GOLMANI: 0 (0.0 %)
#
# Broj igraca u klasteru 4: 4894, (26.87977151644972 %)
#
# NAPAD: 77 (1.5733551287290561 %)
# Broj igraca na poziciji RF: 1, (0.02043318348998774 %)
# Broj igraca na poziciji LF: 1, (0.02043318348998774 %)
# Broj igraca na poziciji RW: 23, (0.469963220269718 %)
# Broj igraca na poziciji LW: 25, (0.5108295872496935 %)
# Broj igraca na poziciji ST: 21, (0.4290968532897425 %)
# Broj igraca na poziciji CF: 0, (0.0 %)
# Broj igraca na poziciji RS: 4, (0.08173273395995095 %)
# Broj igraca na poziciji LS: 2, (0.04086636697997548 %)
#
# VEZNI RED: 2802 (57.25378013894564 %)
# Broj igraca na poziciji RDM: 197, (4.025337147527585 %)
# Broj igraca na poziciji CDM: 583, (11.912545974662853 %)
# Broj igraca na poziciji LDM: 188, (3.8414384961176955 %)
# Broj igraca na poziciji RM: 176, (3.5962402942378424 %)
# Broj igraca na poziciji RCM: 293, (5.986922762566408 %)
# Broj igraca na poziciji CM: 759, (15.508786268900696 %)
# Broj igraca na poziciji LCM: 276, (5.639558643236616 %)
# Broj igraca na poziciji LM: 179, (3.657539844707806 %)
# Broj igraca na poziciji RAM: 2, (0.04086636697997548 %)
# Broj igraca na poziciji CAM: 149, (3.0445443400081733 %)
# Broj igraca na poziciji LAM: 0, (0.0 %)
#
# ODBRANA: 2015 (41.1728647323253 %)
# Broj igraca na poziciji RWB: 45, (0.9194932570494483 %)
# Broj igraca na poziciji RB: 686, (14.017163874131588 %)
# Broj igraca na poziciji RCB: 144, (2.942378422558235 %)
# Broj igraca na poziciji CB: 213, (4.352268083367389 %)
# Broj igraca na poziciji LCB: 151, (3.085410706988149 %)
# Broj igraca na poziciji LB: 731, (14.936657131181038 %)
# Broj igraca na poziciji LWB: 45, (0.9194932570494483 %)
#
# GOLMANI: 0 (0.0 %)

# %%
draw(df)

# %%
# Zamena GKDiving vrednosti napadaca ID=193911 median vrednoscu

df.loc[df['ID'] == 193911, 'GKDiving'] = st['GKDiving'].median()

# %%
kmeans= KMeans(n_clusters=5, random_state=0)
kmeans.fit(df[numeric])
# Out:
# KMeans(n_clusters=5, random_state=0)

# %%
print_percentige_of_five_clusters(df)
# Out:
# Broj igraca u klasteru 0: 3544, (19.465040918328118 %)
#
# NAPAD: 1937 (54.65575620767494 %)
# Broj igraca na poziciji RF: 1, (0.02821670428893905 %)
# Broj igraca na poziciji LF: 1, (0.02821670428893905 %)
# Broj igraca na poziciji RW: 165, (4.655756207674944 %)
# Broj igraca na poziciji LW: 171, (4.8250564334085775 %)
# Broj igraca na poziciji ST: 1400, (39.503386004514674 %)
# Broj igraca na poziciji CF: 39, (1.100451467268623 %)
# Broj igraca na poziciji RS: 78, (2.200902934537246 %)
# Broj igraca na poziciji LS: 82, (2.3137697516930023 %)
#
# VEZNI RED: 1568 (44.24379232505643 %)
# Broj igraca na poziciji RDM: 6, (0.16930022573363432 %)
# Broj igraca na poziciji CDM: 8, (0.2257336343115124 %)
# Broj igraca na poziciji LDM: 6, (0.16930022573363432 %)
# Broj igraca na poziciji RM: 444, (12.528216704288939 %)
# Broj igraca na poziciji RCM: 18, (0.5079006772009029 %)
# Broj igraca na poziciji CM: 300, (8.465011286681715 %)
# Broj igraca na poziciji LCM: 25, (0.7054176072234764 %)
# Broj igraca na poziciji LM: 418, (11.794582392776523 %)
# Broj igraca na poziciji RAM: 1, (0.02821670428893905 %)
# Broj igraca na poziciji CAM: 340, (9.593679458239277 %)
# Broj igraca na poziciji LAM: 2, (0.0564334085778781 %)
#
# ODBRANA: 39 (1.100451467268623 %)
# Broj igraca na poziciji RWB: 5, (0.14108352144469527 %)
# Broj igraca na poziciji RB: 14, (0.39503386004514673 %)
# Broj igraca na poziciji RCB: 0, (0.0 %)
# Broj igraca na poziciji CB: 3, (0.08465011286681716 %)
# Broj igraca na poziciji LCB: 1, (0.02821670428893905 %)
# Broj igraca na poziciji LB: 13, (0.36681715575620766 %)
# Broj igraca na poziciji LWB: 3, (0.08465011286681716 %)
#
# GOLMANI: 0 (0.0 %)
#
# Broj igraca u klasteru 1: 2026, (11.127588290218048 %)
#
# NAPAD: 1 (0.04935834155972359 %)
# Broj igraca na poziciji RF: 0, (0.0 %)
# Broj igraca na poziciji LF: 0, (0.0 %)
# Broj igraca na poziciji RW: 0, (0.0 %)
# Broj igraca na poziciji LW: 0, (0.0 %)
# Broj igraca na poziciji ST: 1, (0.04935834155972359 %)
# Broj igraca na poziciji CF: 0, (0.0 %)
# Broj igraca na poziciji RS: 0, (0.0 %)
# Broj igraca na poziciji LS: 0, (0.0 %)
#
# VEZNI RED: 0 (0.0 %)
# Broj igraca na poziciji RDM: 0, (0.0 %)
# Broj igraca na poziciji CDM: 0, (0.0 %)
# Broj igraca na poziciji LDM: 0, (0.0 %)
# Broj igraca na poziciji RM: 0, (0.0 %)
# Broj igraca na poziciji RCM: 0, (0.0 %)
# Broj igraca na poziciji CM: 0, (0.0 %)
# Broj igraca na poziciji LCM: 0, (0.0 %)
# Broj igraca na poziciji LM: 0, (0.0 %)
# Broj igraca na poziciji RAM: 0, (0.0 %)
# Broj igraca na poziciji CAM: 0, (0.0 %)
# Broj igraca na poziciji LAM: 0, (0.0 %)
#
# ODBRANA: 0 (0.0 %)
# Broj igraca na poziciji RWB: 0, (0.0 %)
# Broj igraca na poziciji RB: 0, (0.0 %)
# Broj igraca na poziciji RCB: 0, (0.0 %)
# Broj igraca na poziciji CB: 0, (0.0 %)
# Broj igraca na poziciji LCB: 0, (0.0 %)
# Broj igraca na poziciji LB: 0, (0.0 %)
# Broj igraca na poziciji LWB: 0, (0.0 %)
#
# GOLMANI: 2025 (99.95064165844028 %)
#
# Broj igraca u klasteru 2: 4894, (26.87977151644972 %)
#
# NAPAD: 77 (1.5733551287290561 %)
# Broj igraca na poziciji RF: 1, (0.02043318348998774 %)
# Broj igraca na poziciji LF: 1, (0.02043318348998774 %)
# Broj igraca na poziciji RW: 23, (0.469963220269718 %)
# Broj igraca na poziciji LW: 25, (0.5108295872496935 %)
# Broj igraca na poziciji ST: 21, (0.4290968532897425 %)
# Broj igraca na poziciji CF: 0, (0.0 %)
# Broj igraca na poziciji RS: 4, (0.08173273395995095 %)
# Broj igraca na poziciji LS: 2, (0.04086636697997548 %)
#
# VEZNI RED: 2802 (57.25378013894564 %)
# Broj igraca na poziciji RDM: 197, (4.025337147527585 %)
# Broj igraca na poziciji CDM: 583, (11.912545974662853 %)
# Broj igraca na poziciji LDM: 188, (3.8414384961176955 %)
# Broj igraca na poziciji RM: 176, (3.5962402942378424 %)
# Broj igraca na poziciji RCM: 293, (5.986922762566408 %)
# Broj igraca na poziciji CM: 759, (15.508786268900696 %)
# Broj igraca na poziciji LCM: 276, (5.639558643236616 %)
# Broj igraca na poziciji LM: 179, (3.657539844707806 %)
# Broj igraca na poziciji RAM: 2, (0.04086636697997548 %)
# Broj igraca na poziciji CAM: 149, (3.0445443400081733 %)
# Broj igraca na poziciji LAM: 0, (0.0 %)
#
# ODBRANA: 2015 (41.1728647323253 %)
# Broj igraca na poziciji RWB: 45, (0.9194932570494483 %)
# Broj igraca na poziciji RB: 686, (14.017163874131588 %)
# Broj igraca na poziciji RCB: 144, (2.942378422558235 %)
# Broj igraca na poziciji CB: 213, (4.352268083367389 %)
# Broj igraca na poziciji LCB: 151, (3.085410706988149 %)
# Broj igraca na poziciji LB: 731, (14.936657131181038 %)
# Broj igraca na poziciji LWB: 45, (0.9194932570494483 %)
#
# GOLMANI: 0 (0.0 %)
#
# Broj igraca u klasteru 3: 4626, (25.40781018289669 %)
#
# NAPAD: 10 (0.21616947686986598 %)
# Broj igraca na poziciji RF: 0, (0.0 %)
# Broj igraca na poziciji LF: 0, (0.0 %)
# Broj igraca na poziciji RW: 0, (0.0 %)
# Broj igraca na poziciji LW: 0, (0.0 %)
# Broj igraca na poziciji ST: 10, (0.21616947686986598 %)
# Broj igraca na poziciji CF: 0, (0.0 %)
# Broj igraca na poziciji RS: 0, (0.0 %)
# Broj igraca na poziciji LS: 0, (0.0 %)
#
# VEZNI RED: 809 (17.488110678772156 %)
# Broj igraca na poziciji RDM: 37, (0.799827064418504 %)
# Broj igraca na poziciji CDM: 355, (7.674016428880242 %)
# Broj igraca na poziciji LDM: 37, (0.799827064418504 %)
# Broj igraca na poziciji RM: 27, (0.5836575875486382 %)
# Broj igraca na poziciji RCM: 35, (0.7565931690445309 %)
# Broj igraca na poziciji CM: 255, (5.512321660181582 %)
# Broj igraca na poziciji LCM: 31, (0.6701253782965845 %)
# Broj igraca na poziciji LM: 24, (0.5188067444876783 %)
# Broj igraca na poziciji RAM: 0, (0.0 %)
# Broj igraca na poziciji CAM: 8, (0.17293558149589278 %)
# Broj igraca na poziciji LAM: 0, (0.0 %)
#
# ODBRANA: 3807 (82.29571984435798 %)
# Broj igraca na poziciji RWB: 37, (0.799827064418504 %)
# Broj igraca na poziciji RB: 591, (12.775616083009078 %)
# Broj igraca na poziciji RCB: 517, (11.175961954172072 %)
# Broj igraca na poziciji CB: 1562, (33.765672287073066 %)
# Broj igraca na poziciji LCB: 496, (10.722006052745352 %)
# Broj igraca na poziciji LB: 575, (12.429744920017294 %)
# Broj igraca na poziciji LWB: 29, (0.6268914829226113 %)
#
# GOLMANI: 0 (0.0 %)
#
# Broj igraca u klasteru 4: 3117, (17.119789092107432 %)
#
# NAPAD: 1453 (46.61533525826115 %)
# Broj igraca na poziciji RF: 14, (0.44914982354828364 %)
# Broj igraca na poziciji LF: 13, (0.4170676932948348 %)
# Broj igraca na poziciji RW: 182, (5.838947706127687 %)
# Broj igraca na poziciji LW: 185, (5.935194096888034 %)
# Broj igraca na poziciji ST: 780, (25.02406159769009 %)
# Broj igraca na poziciji CF: 35, (1.122874558870709 %)
# Broj igraca na poziciji RS: 121, (3.881937760667308 %)
# Broj igraca na poziciji LS: 123, (3.946102021174206 %)
#
# VEZNI RED: 1659 (53.22425409047161 %)
# Broj igraca na poziciji RDM: 8, (0.25665704202759065 %)
# Broj igraca na poziciji CDM: 2, (0.06416426050689766 %)
# Broj igraca na poziciji LDM: 12, (0.384985563041386 %)
# Broj igraca na poziciji RM: 477, (15.30317613089509 %)
# Broj igraca na poziciji RCM: 45, (1.4436958614051971 %)
# Broj igraca na poziciji CM: 80, (2.5665704202759065 %)
# Broj igraca na poziciji LCM: 63, (2.021174205967276 %)
# Broj igraca na poziciji LM: 474, (15.206929740134745 %)
# Broj igraca na poziciji RAM: 18, (0.5774783445620789 %)
# Broj igraca na poziciji CAM: 461, (14.789862046839911 %)
# Broj igraca na poziciji LAM: 19, (0.6095604748155278 %)
#
# ODBRANA: 5 (0.16041065126724416 %)
# Broj igraca na poziciji RWB: 0, (0.0 %)
# Broj igraca na poziciji RB: 0, (0.0 %)
# Broj igraca na poziciji RCB: 1, (0.03208213025344883 %)
# Broj igraca na poziciji CB: 0, (0.0 %)
# Broj igraca na poziciji LCB: 0, (0.0 %)
# Broj igraca na poziciji LB: 3, (0.0962463907603465 %)
# Broj igraca na poziciji LWB: 1, (0.03208213025344883 %)
#
# GOLMANI: 0 (0.0 %)

# %%
draw(df)

# %%
# Zamena Dribbling vrednosti napadaca ID=193911 median vrednoscu

df.loc[df['ID'] == 193911, 'Dribbling'] = st['Dribbling'].median()

# %%
kmeans= KMeans(n_clusters=5, random_state=0)
kmeans.fit(df[numeric])
# Out:
# KMeans(n_clusters=5, random_state=0)

# %%
print_percentige_of_five_clusters(df)
# Out:
# Broj igraca u klasteru 0: 4626, (25.40781018289669 %)
#
# NAPAD: 10 (0.21616947686986598 %)
# Broj igraca na poziciji RF: 0, (0.0 %)
# Broj igraca na poziciji LF: 0, (0.0 %)
# Broj igraca na poziciji RW: 0, (0.0 %)
# Broj igraca na poziciji LW: 0, (0.0 %)
# Broj igraca na poziciji ST: 10, (0.21616947686986598 %)
# Broj igraca na poziciji CF: 0, (0.0 %)
# Broj igraca na poziciji RS: 0, (0.0 %)
# Broj igraca na poziciji LS: 0, (0.0 %)
#
# VEZNI RED: 809 (17.488110678772156 %)
# Broj igraca na poziciji RDM: 37, (0.799827064418504 %)
# Broj igraca na poziciji CDM: 355, (7.674016428880242 %)
# Broj igraca na poziciji LDM: 37, (0.799827064418504 %)
# Broj igraca na poziciji RM: 27, (0.5836575875486382 %)
# Broj igraca na poziciji RCM: 35, (0.7565931690445309 %)
# Broj igraca na poziciji CM: 255, (5.512321660181582 %)
# Broj igraca na poziciji LCM: 31, (0.6701253782965845 %)
# Broj igraca na poziciji LM: 24, (0.5188067444876783 %)
# Broj igraca na poziciji RAM: 0, (0.0 %)
# Broj igraca na poziciji CAM: 8, (0.17293558149589278 %)
# Broj igraca na poziciji LAM: 0, (0.0 %)
#
# ODBRANA: 3807 (82.29571984435798 %)
# Broj igraca na poziciji RWB: 37, (0.799827064418504 %)
# Broj igraca na poziciji RB: 591, (12.775616083009078 %)
# Broj igraca na poziciji RCB: 517, (11.175961954172072 %)
# Broj igraca na poziciji CB: 1562, (33.765672287073066 %)
# Broj igraca na poziciji LCB: 496, (10.722006052745352 %)
# Broj igraca na poziciji LB: 575, (12.429744920017294 %)
# Broj igraca na poziciji LWB: 29, (0.6268914829226113 %)
#
# GOLMANI: 0 (0.0 %)
#
# Broj igraca u klasteru 1: 2026, (11.127588290218048 %)
#
# NAPAD: 1 (0.04935834155972359 %)
# Broj igraca na poziciji RF: 0, (0.0 %)
# Broj igraca na poziciji LF: 0, (0.0 %)
# Broj igraca na poziciji RW: 0, (0.0 %)
# Broj igraca na poziciji LW: 0, (0.0 %)
# Broj igraca na poziciji ST: 1, (0.04935834155972359 %)
# Broj igraca na poziciji CF: 0, (0.0 %)
# Broj igraca na poziciji RS: 0, (0.0 %)
# Broj igraca na poziciji LS: 0, (0.0 %)
#
# VEZNI RED: 0 (0.0 %)
# Broj igraca na poziciji RDM: 0, (0.0 %)
# Broj igraca na poziciji CDM: 0, (0.0 %)
# Broj igraca na poziciji LDM: 0, (0.0 %)
# Broj igraca na poziciji RM: 0, (0.0 %)
# Broj igraca na poziciji RCM: 0, (0.0 %)
# Broj igraca na poziciji CM: 0, (0.0 %)
# Broj igraca na poziciji LCM: 0, (0.0 %)
# Broj igraca na poziciji LM: 0, (0.0 %)
# Broj igraca na poziciji RAM: 0, (0.0 %)
# Broj igraca na poziciji CAM: 0, (0.0 %)
# Broj igraca na poziciji LAM: 0, (0.0 %)
#
# ODBRANA: 0 (0.0 %)
# Broj igraca na poziciji RWB: 0, (0.0 %)
# Broj igraca na poziciji RB: 0, (0.0 %)
# Broj igraca na poziciji RCB: 0, (0.0 %)
# Broj igraca na poziciji CB: 0, (0.0 %)
# Broj igraca na poziciji LCB: 0, (0.0 %)
# Broj igraca na poziciji LB: 0, (0.0 %)
# Broj igraca na poziciji LWB: 0, (0.0 %)
#
# GOLMANI: 2025 (99.95064165844028 %)
#
# Broj igraca u klasteru 2: 3545, (19.47053331136376 %)
#
# NAPAD: 1937 (54.64033850493652 %)
# Broj igraca na poziciji RF: 1, (0.028208744710860365 %)
# Broj igraca na poziciji LF: 1, (0.028208744710860365 %)
# Broj igraca na poziciji RW: 165, (4.65444287729196 %)
# Broj igraca na poziciji LW: 171, (4.823695345557122 %)
# Broj igraca na poziciji ST: 1400, (39.492242595204516 %)
# Broj igraca na poziciji CF: 39, (1.1001410437235544 %)
# Broj igraca na poziciji RS: 78, (2.2002820874471087 %)
# Broj igraca na poziciji LS: 82, (2.31311706629055 %)
#
# VEZNI RED: 1569 (44.25952045133992 %)
# Broj igraca na poziciji RDM: 6, (0.16925246826516221 %)
# Broj igraca na poziciji CDM: 8, (0.22566995768688292 %)
# Broj igraca na poziciji LDM: 6, (0.16925246826516221 %)
# Broj igraca na poziciji RM: 444, (12.524682651622001 %)
# Broj igraca na poziciji RCM: 18, (0.5077574047954866 %)
# Broj igraca na poziciji CM: 300, (8.46262341325811 %)
# Broj igraca na poziciji LCM: 25, (0.7052186177715092 %)
# Broj igraca na poziciji LM: 419, (11.819464033850494 %)
# Broj igraca na poziciji RAM: 1, (0.028208744710860365 %)
# Broj igraca na poziciji CAM: 340, (9.590973201692526 %)
# Broj igraca na poziciji LAM: 2, (0.05641748942172073 %)
#
# ODBRANA: 39 (1.1001410437235544 %)
# Broj igraca na poziciji RWB: 5, (0.14104372355430184 %)
# Broj igraca na poziciji RB: 14, (0.39492242595204513 %)
# Broj igraca na poziciji RCB: 0, (0.0 %)
# Broj igraca na poziciji CB: 3, (0.08462623413258111 %)
# Broj igraca na poziciji LCB: 1, (0.028208744710860365 %)
# Broj igraca na poziciji LB: 13, (0.36671368124118475 %)
# Broj igraca na poziciji LWB: 3, (0.08462623413258111 %)
#
# GOLMANI: 0 (0.0 %)
#
# Broj igraca u klasteru 3: 3116, (17.114296699071787 %)
#
# NAPAD: 1453 (46.63029525032093 %)
# Broj igraca na poziciji RF: 14, (0.4492939666238768 %)
# Broj igraca na poziciji LF: 13, (0.41720154043645696 %)
# Broj igraca na poziciji RW: 182, (5.840821566110398 %)
# Broj igraca na poziciji LW: 185, (5.937098844672657 %)
# Broj igraca na poziciji ST: 780, (25.03209242618742 %)
# Broj igraca na poziciji CF: 35, (1.123234916559692 %)
# Broj igraca na poziciji RS: 121, (3.8831835686777922 %)
# Broj igraca na poziciji LS: 123, (3.9473684210526314 %)
#
# VEZNI RED: 1658 (53.20924261874198 %)
# Broj igraca na poziciji RDM: 8, (0.25673940949935814 %)
# Broj igraca na poziciji CDM: 2, (0.06418485237483953 %)
# Broj igraca na poziciji LDM: 12, (0.38510911424903727 %)
# Broj igraca na poziciji RM: 477, (15.30808729139923 %)
# Broj igraca na poziciji RCM: 45, (1.4441591784338896 %)
# Broj igraca na poziciji CM: 80, (2.5673940949935816 %)
# Broj igraca na poziciji LCM: 63, (2.0218228498074455 %)
# Broj igraca na poziciji LM: 473, (15.179717586649552 %)
# Broj igraca na poziciji RAM: 18, (0.5776636713735559 %)
# Broj igraca na poziciji CAM: 461, (14.794608472400514 %)
# Broj igraca na poziciji LAM: 19, (0.6097560975609756 %)
#
# ODBRANA: 5 (0.16046213093709885 %)
# Broj igraca na poziciji RWB: 0, (0.0 %)
# Broj igraca na poziciji RB: 0, (0.0 %)
# Broj igraca na poziciji RCB: 1, (0.03209242618741977 %)
# Broj igraca na poziciji CB: 0, (0.0 %)
# Broj igraca na poziciji LCB: 0, (0.0 %)
# Broj igraca na poziciji LB: 3, (0.09627727856225932 %)
# Broj igraca na poziciji LWB: 1, (0.03209242618741977 %)
#
# GOLMANI: 0 (0.0 %)
#
# Broj igraca u klasteru 4: 4894, (26.87977151644972 %)
#
# NAPAD: 77 (1.5733551287290561 %)
# Broj igraca na poziciji RF: 1, (0.02043318348998774 %)
# Broj igraca na poziciji LF: 1, (0.02043318348998774 %)
# Broj igraca na poziciji RW: 23, (0.469963220269718 %)
# Broj igraca na poziciji LW: 25, (0.5108295872496935 %)
# Broj igraca na poziciji ST: 21, (0.4290968532897425 %)
# Broj igraca na poziciji CF: 0, (0.0 %)
# Broj igraca na poziciji RS: 4, (0.08173273395995095 %)
# Broj igraca na poziciji LS: 2, (0.04086636697997548 %)
#
# VEZNI RED: 2802 (57.25378013894564 %)
# Broj igraca na poziciji RDM: 197, (4.025337147527585 %)
# Broj igraca na poziciji CDM: 583, (11.912545974662853 %)
# Broj igraca na poziciji LDM: 188, (3.8414384961176955 %)
# Broj igraca na poziciji RM: 176, (3.5962402942378424 %)
# Broj igraca na poziciji RCM: 293, (5.986922762566408 %)
# Broj igraca na poziciji CM: 759, (15.508786268900696 %)
# Broj igraca na poziciji LCM: 276, (5.639558643236616 %)
# Broj igraca na poziciji LM: 179, (3.657539844707806 %)
# Broj igraca na poziciji RAM: 2, (0.04086636697997548 %)
# Broj igraca na poziciji CAM: 149, (3.0445443400081733 %)
# Broj igraca na poziciji LAM: 0, (0.0 %)
#
# ODBRANA: 2015 (41.1728647323253 %)
# Broj igraca na poziciji RWB: 45, (0.9194932570494483 %)
# Broj igraca na poziciji RB: 686, (14.017163874131588 %)
# Broj igraca na poziciji RCB: 144, (2.942378422558235 %)
# Broj igraca na poziciji CB: 213, (4.352268083367389 %)
# Broj igraca na poziciji LCB: 151, (3.085410706988149 %)
# Broj igraca na poziciji LB: 731, (14.936657131181038 %)
# Broj igraca na poziciji LWB: 45, (0.9194932570494483 %)
#
# GOLMANI: 0 (0.0 %)

# %%
draw(df)

# %%
# Zamena HeadingAccuracy vrednosti napadaca ID=193911 median vrednoscu

df.loc[df['ID'] == 193911, 'HeadingAccuracy'] = st['HeadingAccuracy'].median()

# %%
kmeans= KMeans(n_clusters=5, random_state=0)
kmeans.fit(df[numeric])
# Out:
# KMeans(n_clusters=5, random_state=0)

# %%
print_percentige_of_five_clusters(df)
# Out:
# Broj igraca u klasteru 0: 4626, (25.40781018289669 %)
#
# NAPAD: 10 (0.21616947686986598 %)
# Broj igraca na poziciji RF: 0, (0.0 %)
# Broj igraca na poziciji LF: 0, (0.0 %)
# Broj igraca na poziciji RW: 0, (0.0 %)
# Broj igraca na poziciji LW: 0, (0.0 %)
# Broj igraca na poziciji ST: 10, (0.21616947686986598 %)
# Broj igraca na poziciji CF: 0, (0.0 %)
# Broj igraca na poziciji RS: 0, (0.0 %)
# Broj igraca na poziciji LS: 0, (0.0 %)
#
# VEZNI RED: 809 (17.488110678772156 %)
# Broj igraca na poziciji RDM: 37, (0.799827064418504 %)
# Broj igraca na poziciji CDM: 355, (7.674016428880242 %)
# Broj igraca na poziciji LDM: 37, (0.799827064418504 %)
# Broj igraca na poziciji RM: 27, (0.5836575875486382 %)
# Broj igraca na poziciji RCM: 35, (0.7565931690445309 %)
# Broj igraca na poziciji CM: 255, (5.512321660181582 %)
# Broj igraca na poziciji LCM: 31, (0.6701253782965845 %)
# Broj igraca na poziciji LM: 24, (0.5188067444876783 %)
# Broj igraca na poziciji RAM: 0, (0.0 %)
# Broj igraca na poziciji CAM: 8, (0.17293558149589278 %)
# Broj igraca na poziciji LAM: 0, (0.0 %)
#
# ODBRANA: 3807 (82.29571984435798 %)
# Broj igraca na poziciji RWB: 37, (0.799827064418504 %)
# Broj igraca na poziciji RB: 591, (12.775616083009078 %)
# Broj igraca na poziciji RCB: 517, (11.175961954172072 %)
# Broj igraca na poziciji CB: 1562, (33.765672287073066 %)
# Broj igraca na poziciji LCB: 496, (10.722006052745352 %)
# Broj igraca na poziciji LB: 575, (12.429744920017294 %)
# Broj igraca na poziciji LWB: 29, (0.6268914829226113 %)
#
# GOLMANI: 0 (0.0 %)
#
# Broj igraca u klasteru 1: 3545, (19.47053331136376 %)
#
# NAPAD: 1937 (54.64033850493652 %)
# Broj igraca na poziciji RF: 1, (0.028208744710860365 %)
# Broj igraca na poziciji LF: 1, (0.028208744710860365 %)
# Broj igraca na poziciji RW: 165, (4.65444287729196 %)
# Broj igraca na poziciji LW: 171, (4.823695345557122 %)
# Broj igraca na poziciji ST: 1400, (39.492242595204516 %)
# Broj igraca na poziciji CF: 39, (1.1001410437235544 %)
# Broj igraca na poziciji RS: 78, (2.2002820874471087 %)
# Broj igraca na poziciji LS: 82, (2.31311706629055 %)
#
# VEZNI RED: 1569 (44.25952045133992 %)
# Broj igraca na poziciji RDM: 6, (0.16925246826516221 %)
# Broj igraca na poziciji CDM: 8, (0.22566995768688292 %)
# Broj igraca na poziciji LDM: 6, (0.16925246826516221 %)
# Broj igraca na poziciji RM: 444, (12.524682651622001 %)
# Broj igraca na poziciji RCM: 18, (0.5077574047954866 %)
# Broj igraca na poziciji CM: 300, (8.46262341325811 %)
# Broj igraca na poziciji LCM: 25, (0.7052186177715092 %)
# Broj igraca na poziciji LM: 419, (11.819464033850494 %)
# Broj igraca na poziciji RAM: 1, (0.028208744710860365 %)
# Broj igraca na poziciji CAM: 340, (9.590973201692526 %)
# Broj igraca na poziciji LAM: 2, (0.05641748942172073 %)
#
# ODBRANA: 39 (1.1001410437235544 %)
# Broj igraca na poziciji RWB: 5, (0.14104372355430184 %)
# Broj igraca na poziciji RB: 14, (0.39492242595204513 %)
# Broj igraca na poziciji RCB: 0, (0.0 %)
# Broj igraca na poziciji CB: 3, (0.08462623413258111 %)
# Broj igraca na poziciji LCB: 1, (0.028208744710860365 %)
# Broj igraca na poziciji LB: 13, (0.36671368124118475 %)
# Broj igraca na poziciji LWB: 3, (0.08462623413258111 %)
#
# GOLMANI: 0 (0.0 %)
#
# Broj igraca u klasteru 2: 2026, (11.127588290218048 %)
#
# NAPAD: 1 (0.04935834155972359 %)
# Broj igraca na poziciji RF: 0, (0.0 %)
# Broj igraca na poziciji LF: 0, (0.0 %)
# Broj igraca na poziciji RW: 0, (0.0 %)
# Broj igraca na poziciji LW: 0, (0.0 %)
# Broj igraca na poziciji ST: 1, (0.04935834155972359 %)
# Broj igraca na poziciji CF: 0, (0.0 %)
# Broj igraca na poziciji RS: 0, (0.0 %)
# Broj igraca na poziciji LS: 0, (0.0 %)
#
# VEZNI RED: 0 (0.0 %)
# Broj igraca na poziciji RDM: 0, (0.0 %)
# Broj igraca na poziciji CDM: 0, (0.0 %)
# Broj igraca na poziciji LDM: 0, (0.0 %)
# Broj igraca na poziciji RM: 0, (0.0 %)
# Broj igraca na poziciji RCM: 0, (0.0 %)
# Broj igraca na poziciji CM: 0, (0.0 %)
# Broj igraca na poziciji LCM: 0, (0.0 %)
# Broj igraca na poziciji LM: 0, (0.0 %)
# Broj igraca na poziciji RAM: 0, (0.0 %)
# Broj igraca na poziciji CAM: 0, (0.0 %)
# Broj igraca na poziciji LAM: 0, (0.0 %)
#
# ODBRANA: 0 (0.0 %)
# Broj igraca na poziciji RWB: 0, (0.0 %)
# Broj igraca na poziciji RB: 0, (0.0 %)
# Broj igraca na poziciji RCB: 0, (0.0 %)
# Broj igraca na poziciji CB: 0, (0.0 %)
# Broj igraca na poziciji LCB: 0, (0.0 %)
# Broj igraca na poziciji LB: 0, (0.0 %)
# Broj igraca na poziciji LWB: 0, (0.0 %)
#
# GOLMANI: 2025 (99.95064165844028 %)
#
# Broj igraca u klasteru 3: 3116, (17.114296699071787 %)
#
# NAPAD: 1453 (46.63029525032093 %)
# Broj igraca na poziciji RF: 14, (0.4492939666238768 %)
# Broj igraca na poziciji LF: 13, (0.41720154043645696 %)
# Broj igraca na poziciji RW: 182, (5.840821566110398 %)
# Broj igraca na poziciji LW: 185, (5.937098844672657 %)
# Broj igraca na poziciji ST: 780, (25.03209242618742 %)
# Broj igraca na poziciji CF: 35, (1.123234916559692 %)
# Broj igraca na poziciji RS: 121, (3.8831835686777922 %)
# Broj igraca na poziciji LS: 123, (3.9473684210526314 %)
#
# VEZNI RED: 1658 (53.20924261874198 %)
# Broj igraca na poziciji RDM: 8, (0.25673940949935814 %)
# Broj igraca na poziciji CDM: 2, (0.06418485237483953 %)
# Broj igraca na poziciji LDM: 12, (0.38510911424903727 %)
# Broj igraca na poziciji RM: 477, (15.30808729139923 %)
# Broj igraca na poziciji RCM: 45, (1.4441591784338896 %)
# Broj igraca na poziciji CM: 80, (2.5673940949935816 %)
# Broj igraca na poziciji LCM: 63, (2.0218228498074455 %)
# Broj igraca na poziciji LM: 473, (15.179717586649552 %)
# Broj igraca na poziciji RAM: 18, (0.5776636713735559 %)
# Broj igraca na poziciji CAM: 461, (14.794608472400514 %)
# Broj igraca na poziciji LAM: 19, (0.6097560975609756 %)
#
# ODBRANA: 5 (0.16046213093709885 %)
# Broj igraca na poziciji RWB: 0, (0.0 %)
# Broj igraca na poziciji RB: 0, (0.0 %)
# Broj igraca na poziciji RCB: 1, (0.03209242618741977 %)
# Broj igraca na poziciji CB: 0, (0.0 %)
# Broj igraca na poziciji LCB: 0, (0.0 %)
# Broj igraca na poziciji LB: 3, (0.09627727856225932 %)
# Broj igraca na poziciji LWB: 1, (0.03209242618741977 %)
#
# GOLMANI: 0 (0.0 %)
#
# Broj igraca u klasteru 4: 4894, (26.87977151644972 %)
#
# NAPAD: 77 (1.5733551287290561 %)
# Broj igraca na poziciji RF: 1, (0.02043318348998774 %)
# Broj igraca na poziciji LF: 1, (0.02043318348998774 %)
# Broj igraca na poziciji RW: 23, (0.469963220269718 %)
# Broj igraca na poziciji LW: 25, (0.5108295872496935 %)
# Broj igraca na poziciji ST: 21, (0.4290968532897425 %)
# Broj igraca na poziciji CF: 0, (0.0 %)
# Broj igraca na poziciji RS: 4, (0.08173273395995095 %)
# Broj igraca na poziciji LS: 2, (0.04086636697997548 %)
#
# VEZNI RED: 2802 (57.25378013894564 %)
# Broj igraca na poziciji RDM: 197, (4.025337147527585 %)
# Broj igraca na poziciji CDM: 583, (11.912545974662853 %)
# Broj igraca na poziciji LDM: 188, (3.8414384961176955 %)
# Broj igraca na poziciji RM: 176, (3.5962402942378424 %)
# Broj igraca na poziciji RCM: 293, (5.986922762566408 %)
# Broj igraca na poziciji CM: 759, (15.508786268900696 %)
# Broj igraca na poziciji LCM: 276, (5.639558643236616 %)
# Broj igraca na poziciji LM: 179, (3.657539844707806 %)
# Broj igraca na poziciji RAM: 2, (0.04086636697997548 %)
# Broj igraca na poziciji CAM: 149, (3.0445443400081733 %)
# Broj igraca na poziciji LAM: 0, (0.0 %)
#
# ODBRANA: 2015 (41.1728647323253 %)
# Broj igraca na poziciji RWB: 45, (0.9194932570494483 %)
# Broj igraca na poziciji RB: 686, (14.017163874131588 %)
# Broj igraca na poziciji RCB: 144, (2.942378422558235 %)
# Broj igraca na poziciji CB: 213, (4.352268083367389 %)
# Broj igraca na poziciji LCB: 151, (3.085410706988149 %)
# Broj igraca na poziciji LB: 731, (14.936657131181038 %)
# Broj igraca na poziciji LWB: 45, (0.9194932570494483 %)
#
# GOLMANI: 0 (0.0 %)

# %%
draw(df)

# %%
# Zamena GKPositioning vrednosti napadaca ID=193911 median vrednoscu

df.loc[df['ID'] == 193911, 'GKPositioning'] = st['GKPositioning'].median()

# %%
kmeans= KMeans(n_clusters=5, random_state=0)
kmeans.fit(df[numeric])
# Out:
# KMeans(n_clusters=5, random_state=0)

# %%
print_percentige_of_five_clusters(df)
# Out:
# Broj igraca u klasteru 0: 3117, (17.119789092107432 %)
#
# NAPAD: 1453 (46.61533525826115 %)
# Broj igraca na poziciji RF: 14, (0.44914982354828364 %)
# Broj igraca na poziciji LF: 13, (0.4170676932948348 %)
# Broj igraca na poziciji RW: 182, (5.838947706127687 %)
# Broj igraca na poziciji LW: 185, (5.935194096888034 %)
# Broj igraca na poziciji ST: 780, (25.02406159769009 %)
# Broj igraca na poziciji CF: 35, (1.122874558870709 %)
# Broj igraca na poziciji RS: 121, (3.881937760667308 %)
# Broj igraca na poziciji LS: 123, (3.946102021174206 %)
#
# VEZNI RED: 1659 (53.22425409047161 %)
# Broj igraca na poziciji RDM: 8, (0.25665704202759065 %)
# Broj igraca na poziciji CDM: 2, (0.06416426050689766 %)
# Broj igraca na poziciji LDM: 12, (0.384985563041386 %)
# Broj igraca na poziciji RM: 477, (15.30317613089509 %)
# Broj igraca na poziciji RCM: 45, (1.4436958614051971 %)
# Broj igraca na poziciji CM: 80, (2.5665704202759065 %)
# Broj igraca na poziciji LCM: 63, (2.021174205967276 %)
# Broj igraca na poziciji LM: 474, (15.206929740134745 %)
# Broj igraca na poziciji RAM: 18, (0.5774783445620789 %)
# Broj igraca na poziciji CAM: 461, (14.789862046839911 %)
# Broj igraca na poziciji LAM: 19, (0.6095604748155278 %)
#
# ODBRANA: 5 (0.16041065126724416 %)
# Broj igraca na poziciji RWB: 0, (0.0 %)
# Broj igraca na poziciji RB: 0, (0.0 %)
# Broj igraca na poziciji RCB: 1, (0.03208213025344883 %)
# Broj igraca na poziciji CB: 0, (0.0 %)
# Broj igraca na poziciji LCB: 0, (0.0 %)
# Broj igraca na poziciji LB: 3, (0.0962463907603465 %)
# Broj igraca na poziciji LWB: 1, (0.03208213025344883 %)
#
# GOLMANI: 0 (0.0 %)
#
# Broj igraca u klasteru 1: 2026, (11.127588290218048 %)
#
# NAPAD: 1 (0.04935834155972359 %)
# Broj igraca na poziciji RF: 0, (0.0 %)
# Broj igraca na poziciji LF: 0, (0.0 %)
# Broj igraca na poziciji RW: 0, (0.0 %)
# Broj igraca na poziciji LW: 0, (0.0 %)
# Broj igraca na poziciji ST: 1, (0.04935834155972359 %)
# Broj igraca na poziciji CF: 0, (0.0 %)
# Broj igraca na poziciji RS: 0, (0.0 %)
# Broj igraca na poziciji LS: 0, (0.0 %)
#
# VEZNI RED: 0 (0.0 %)
# Broj igraca na poziciji RDM: 0, (0.0 %)
# Broj igraca na poziciji CDM: 0, (0.0 %)
# Broj igraca na poziciji LDM: 0, (0.0 %)
# Broj igraca na poziciji RM: 0, (0.0 %)
# Broj igraca na poziciji RCM: 0, (0.0 %)
# Broj igraca na poziciji CM: 0, (0.0 %)
# Broj igraca na poziciji LCM: 0, (0.0 %)
# Broj igraca na poziciji LM: 0, (0.0 %)
# Broj igraca na poziciji RAM: 0, (0.0 %)
# Broj igraca na poziciji CAM: 0, (0.0 %)
# Broj igraca na poziciji LAM: 0, (0.0 %)
#
# ODBRANA: 0 (0.0 %)
# Broj igraca na poziciji RWB: 0, (0.0 %)
# Broj igraca na poziciji RB: 0, (0.0 %)
# Broj igraca na poziciji RCB: 0, (0.0 %)
# Broj igraca na poziciji CB: 0, (0.0 %)
# Broj igraca na poziciji LCB: 0, (0.0 %)
# Broj igraca na poziciji LB: 0, (0.0 %)
# Broj igraca na poziciji LWB: 0, (0.0 %)
#
# GOLMANI: 2025 (99.95064165844028 %)
#
# Broj igraca u klasteru 2: 3544, (19.465040918328118 %)
#
# NAPAD: 1937 (54.65575620767494 %)
# Broj igraca na poziciji RF: 1, (0.02821670428893905 %)
# Broj igraca na poziciji LF: 1, (0.02821670428893905 %)
# Broj igraca na poziciji RW: 165, (4.655756207674944 %)
# Broj igraca na poziciji LW: 171, (4.8250564334085775 %)
# Broj igraca na poziciji ST: 1400, (39.503386004514674 %)
# Broj igraca na poziciji CF: 39, (1.100451467268623 %)
# Broj igraca na poziciji RS: 78, (2.200902934537246 %)
# Broj igraca na poziciji LS: 82, (2.3137697516930023 %)
#
# VEZNI RED: 1568 (44.24379232505643 %)
# Broj igraca na poziciji RDM: 6, (0.16930022573363432 %)
# Broj igraca na poziciji CDM: 8, (0.2257336343115124 %)
# Broj igraca na poziciji LDM: 6, (0.16930022573363432 %)
# Broj igraca na poziciji RM: 444, (12.528216704288939 %)
# Broj igraca na poziciji RCM: 18, (0.5079006772009029 %)
# Broj igraca na poziciji CM: 300, (8.465011286681715 %)
# Broj igraca na poziciji LCM: 25, (0.7054176072234764 %)
# Broj igraca na poziciji LM: 418, (11.794582392776523 %)
# Broj igraca na poziciji RAM: 1, (0.02821670428893905 %)
# Broj igraca na poziciji CAM: 340, (9.593679458239277 %)
# Broj igraca na poziciji LAM: 2, (0.0564334085778781 %)
#
# ODBRANA: 39 (1.100451467268623 %)
# Broj igraca na poziciji RWB: 5, (0.14108352144469527 %)
# Broj igraca na poziciji RB: 14, (0.39503386004514673 %)
# Broj igraca na poziciji RCB: 0, (0.0 %)
# Broj igraca na poziciji CB: 3, (0.08465011286681716 %)
# Broj igraca na poziciji LCB: 1, (0.02821670428893905 %)
# Broj igraca na poziciji LB: 13, (0.36681715575620766 %)
# Broj igraca na poziciji LWB: 3, (0.08465011286681716 %)
#
# GOLMANI: 0 (0.0 %)
#
# Broj igraca u klasteru 3: 4626, (25.40781018289669 %)
#
# NAPAD: 10 (0.21616947686986598 %)
# Broj igraca na poziciji RF: 0, (0.0 %)
# Broj igraca na poziciji LF: 0, (0.0 %)
# Broj igraca na poziciji RW: 0, (0.0 %)
# Broj igraca na poziciji LW: 0, (0.0 %)
# Broj igraca na poziciji ST: 10, (0.21616947686986598 %)
# Broj igraca na poziciji CF: 0, (0.0 %)
# Broj igraca na poziciji RS: 0, (0.0 %)
# Broj igraca na poziciji LS: 0, (0.0 %)
#
# VEZNI RED: 809 (17.488110678772156 %)
# Broj igraca na poziciji RDM: 37, (0.799827064418504 %)
# Broj igraca na poziciji CDM: 355, (7.674016428880242 %)
# Broj igraca na poziciji LDM: 37, (0.799827064418504 %)
# Broj igraca na poziciji RM: 27, (0.5836575875486382 %)
# Broj igraca na poziciji RCM: 35, (0.7565931690445309 %)
# Broj igraca na poziciji CM: 255, (5.512321660181582 %)
# Broj igraca na poziciji LCM: 31, (0.6701253782965845 %)
# Broj igraca na poziciji LM: 24, (0.5188067444876783 %)
# Broj igraca na poziciji RAM: 0, (0.0 %)
# Broj igraca na poziciji CAM: 8, (0.17293558149589278 %)
# Broj igraca na poziciji LAM: 0, (0.0 %)
#
# ODBRANA: 3807 (82.29571984435798 %)
# Broj igraca na poziciji RWB: 37, (0.799827064418504 %)
# Broj igraca na poziciji RB: 591, (12.775616083009078 %)
# Broj igraca na poziciji RCB: 517, (11.175961954172072 %)
# Broj igraca na poziciji CB: 1562, (33.765672287073066 %)
# Broj igraca na poziciji LCB: 496, (10.722006052745352 %)
# Broj igraca na poziciji LB: 575, (12.429744920017294 %)
# Broj igraca na poziciji LWB: 29, (0.6268914829226113 %)
#
# GOLMANI: 0 (0.0 %)
#
# Broj igraca u klasteru 4: 4894, (26.87977151644972 %)
#
# NAPAD: 77 (1.5733551287290561 %)
# Broj igraca na poziciji RF: 1, (0.02043318348998774 %)
# Broj igraca na poziciji LF: 1, (0.02043318348998774 %)
# Broj igraca na poziciji RW: 23, (0.469963220269718 %)
# Broj igraca na poziciji LW: 25, (0.5108295872496935 %)
# Broj igraca na poziciji ST: 21, (0.4290968532897425 %)
# Broj igraca na poziciji CF: 0, (0.0 %)
# Broj igraca na poziciji RS: 4, (0.08173273395995095 %)
# Broj igraca na poziciji LS: 2, (0.04086636697997548 %)
#
# VEZNI RED: 2802 (57.25378013894564 %)
# Broj igraca na poziciji RDM: 197, (4.025337147527585 %)
# Broj igraca na poziciji CDM: 583, (11.912545974662853 %)
# Broj igraca na poziciji LDM: 188, (3.8414384961176955 %)
# Broj igraca na poziciji RM: 176, (3.5962402942378424 %)
# Broj igraca na poziciji RCM: 293, (5.986922762566408 %)
# Broj igraca na poziciji CM: 759, (15.508786268900696 %)
# Broj igraca na poziciji LCM: 276, (5.639558643236616 %)
# Broj igraca na poziciji LM: 179, (3.657539844707806 %)
# Broj igraca na poziciji RAM: 2, (0.04086636697997548 %)
# Broj igraca na poziciji CAM: 149, (3.0445443400081733 %)
# Broj igraca na poziciji LAM: 0, (0.0 %)
#
# ODBRANA: 2015 (41.1728647323253 %)
# Broj igraca na poziciji RWB: 45, (0.9194932570494483 %)
# Broj igraca na poziciji RB: 686, (14.017163874131588 %)
# Broj igraca na poziciji RCB: 144, (2.942378422558235 %)
# Broj igraca na poziciji CB: 213, (4.352268083367389 %)
# Broj igraca na poziciji LCB: 151, (3.085410706988149 %)
# Broj igraca na poziciji LB: 731, (14.936657131181038 %)
# Broj igraca na poziciji LWB: 45, (0.9194932570494483 %)
#
# GOLMANI: 0 (0.0 %)

# %%
draw(df)

# %%
# Zamena GKKicking vrednosti napadaca ID=193911 median vrednoscu

df.loc[df['ID'] == 193911, 'GKKicking'] = st['GKKicking'].median()

# %%
kmeans= KMeans(n_clusters=5, random_state=0)
kmeans.fit(df[numeric])
# Out:
# KMeans(n_clusters=5, random_state=0)

# %%
print_percentige_of_five_clusters(df)
# Out:
# Broj igraca u klasteru 0: 2026, (11.127588290218048 %)
#
# NAPAD: 1 (0.04935834155972359 %)
# Broj igraca na poziciji RF: 0, (0.0 %)
# Broj igraca na poziciji LF: 0, (0.0 %)
# Broj igraca na poziciji RW: 0, (0.0 %)
# Broj igraca na poziciji LW: 0, (0.0 %)
# Broj igraca na poziciji ST: 1, (0.04935834155972359 %)
# Broj igraca na poziciji CF: 0, (0.0 %)
# Broj igraca na poziciji RS: 0, (0.0 %)
# Broj igraca na poziciji LS: 0, (0.0 %)
#
# VEZNI RED: 0 (0.0 %)
# Broj igraca na poziciji RDM: 0, (0.0 %)
# Broj igraca na poziciji CDM: 0, (0.0 %)
# Broj igraca na poziciji LDM: 0, (0.0 %)
# Broj igraca na poziciji RM: 0, (0.0 %)
# Broj igraca na poziciji RCM: 0, (0.0 %)
# Broj igraca na poziciji CM: 0, (0.0 %)
# Broj igraca na poziciji LCM: 0, (0.0 %)
# Broj igraca na poziciji LM: 0, (0.0 %)
# Broj igraca na poziciji RAM: 0, (0.0 %)
# Broj igraca na poziciji CAM: 0, (0.0 %)
# Broj igraca na poziciji LAM: 0, (0.0 %)
#
# ODBRANA: 0 (0.0 %)
# Broj igraca na poziciji RWB: 0, (0.0 %)
# Broj igraca na poziciji RB: 0, (0.0 %)
# Broj igraca na poziciji RCB: 0, (0.0 %)
# Broj igraca na poziciji CB: 0, (0.0 %)
# Broj igraca na poziciji LCB: 0, (0.0 %)
# Broj igraca na poziciji LB: 0, (0.0 %)
# Broj igraca na poziciji LWB: 0, (0.0 %)
#
# GOLMANI: 2025 (99.95064165844028 %)
#
# Broj igraca u klasteru 1: 3117, (17.119789092107432 %)
#
# NAPAD: 1453 (46.61533525826115 %)
# Broj igraca na poziciji RF: 14, (0.44914982354828364 %)
# Broj igraca na poziciji LF: 13, (0.4170676932948348 %)
# Broj igraca na poziciji RW: 182, (5.838947706127687 %)
# Broj igraca na poziciji LW: 185, (5.935194096888034 %)
# Broj igraca na poziciji ST: 780, (25.02406159769009 %)
# Broj igraca na poziciji CF: 35, (1.122874558870709 %)
# Broj igraca na poziciji RS: 121, (3.881937760667308 %)
# Broj igraca na poziciji LS: 123, (3.946102021174206 %)
#
# VEZNI RED: 1659 (53.22425409047161 %)
# Broj igraca na poziciji RDM: 8, (0.25665704202759065 %)
# Broj igraca na poziciji CDM: 2, (0.06416426050689766 %)
# Broj igraca na poziciji LDM: 12, (0.384985563041386 %)
# Broj igraca na poziciji RM: 477, (15.30317613089509 %)
# Broj igraca na poziciji RCM: 45, (1.4436958614051971 %)
# Broj igraca na poziciji CM: 80, (2.5665704202759065 %)
# Broj igraca na poziciji LCM: 63, (2.021174205967276 %)
# Broj igraca na poziciji LM: 474, (15.206929740134745 %)
# Broj igraca na poziciji RAM: 18, (0.5774783445620789 %)
# Broj igraca na poziciji CAM: 461, (14.789862046839911 %)
# Broj igraca na poziciji LAM: 19, (0.6095604748155278 %)
#
# ODBRANA: 5 (0.16041065126724416 %)
# Broj igraca na poziciji RWB: 0, (0.0 %)
# Broj igraca na poziciji RB: 0, (0.0 %)
# Broj igraca na poziciji RCB: 1, (0.03208213025344883 %)
# Broj igraca na poziciji CB: 0, (0.0 %)
# Broj igraca na poziciji LCB: 0, (0.0 %)
# Broj igraca na poziciji LB: 3, (0.0962463907603465 %)
# Broj igraca na poziciji LWB: 1, (0.03208213025344883 %)
#
# GOLMANI: 0 (0.0 %)
#
# Broj igraca u klasteru 2: 4626, (25.40781018289669 %)
#
# NAPAD: 10 (0.21616947686986598 %)
# Broj igraca na poziciji RF: 0, (0.0 %)
# Broj igraca na poziciji LF: 0, (0.0 %)
# Broj igraca na poziciji RW: 0, (0.0 %)
# Broj igraca na poziciji LW: 0, (0.0 %)
# Broj igraca na poziciji ST: 10, (0.21616947686986598 %)
# Broj igraca na poziciji CF: 0, (0.0 %)
# Broj igraca na poziciji RS: 0, (0.0 %)
# Broj igraca na poziciji LS: 0, (0.0 %)
#
# VEZNI RED: 809 (17.488110678772156 %)
# Broj igraca na poziciji RDM: 37, (0.799827064418504 %)
# Broj igraca na poziciji CDM: 355, (7.674016428880242 %)
# Broj igraca na poziciji LDM: 37, (0.799827064418504 %)
# Broj igraca na poziciji RM: 27, (0.5836575875486382 %)
# Broj igraca na poziciji RCM: 35, (0.7565931690445309 %)
# Broj igraca na poziciji CM: 255, (5.512321660181582 %)
# Broj igraca na poziciji LCM: 31, (0.6701253782965845 %)
# Broj igraca na poziciji LM: 24, (0.5188067444876783 %)
# Broj igraca na poziciji RAM: 0, (0.0 %)
# Broj igraca na poziciji CAM: 8, (0.17293558149589278 %)
# Broj igraca na poziciji LAM: 0, (0.0 %)
#
# ODBRANA: 3807 (82.29571984435798 %)
# Broj igraca na poziciji RWB: 37, (0.799827064418504 %)
# Broj igraca na poziciji RB: 591, (12.775616083009078 %)
# Broj igraca na poziciji RCB: 517, (11.175961954172072 %)
# Broj igraca na poziciji CB: 1562, (33.765672287073066 %)
# Broj igraca na poziciji LCB: 496, (10.722006052745352 %)
# Broj igraca na poziciji LB: 575, (12.429744920017294 %)
# Broj igraca na poziciji LWB: 29, (0.6268914829226113 %)
#
# GOLMANI: 0 (0.0 %)
#
# Broj igraca u klasteru 3: 4894, (26.87977151644972 %)
#
# NAPAD: 77 (1.5733551287290561 %)
# Broj igraca na poziciji RF: 1, (0.02043318348998774 %)
# Broj igraca na poziciji LF: 1, (0.02043318348998774 %)
# Broj igraca na poziciji RW: 23, (0.469963220269718 %)
# Broj igraca na poziciji LW: 25, (0.5108295872496935 %)
# Broj igraca na poziciji ST: 21, (0.4290968532897425 %)
# Broj igraca na poziciji CF: 0, (0.0 %)
# Broj igraca na poziciji RS: 4, (0.08173273395995095 %)
# Broj igraca na poziciji LS: 2, (0.04086636697997548 %)
#
# VEZNI RED: 2802 (57.25378013894564 %)
# Broj igraca na poziciji RDM: 197, (4.025337147527585 %)
# Broj igraca na poziciji CDM: 583, (11.912545974662853 %)
# Broj igraca na poziciji LDM: 188, (3.8414384961176955 %)
# Broj igraca na poziciji RM: 176, (3.5962402942378424 %)
# Broj igraca na poziciji RCM: 293, (5.986922762566408 %)
# Broj igraca na poziciji CM: 759, (15.508786268900696 %)
# Broj igraca na poziciji LCM: 276, (5.639558643236616 %)
# Broj igraca na poziciji LM: 179, (3.657539844707806 %)
# Broj igraca na poziciji RAM: 2, (0.04086636697997548 %)
# Broj igraca na poziciji CAM: 149, (3.0445443400081733 %)
# Broj igraca na poziciji LAM: 0, (0.0 %)
#
# ODBRANA: 2015 (41.1728647323253 %)
# Broj igraca na poziciji RWB: 45, (0.9194932570494483 %)
# Broj igraca na poziciji RB: 686, (14.017163874131588 %)
# Broj igraca na poziciji RCB: 144, (2.942378422558235 %)
# Broj igraca na poziciji CB: 213, (4.352268083367389 %)
# Broj igraca na poziciji LCB: 151, (3.085410706988149 %)
# Broj igraca na poziciji LB: 731, (14.936657131181038 %)
# Broj igraca na poziciji LWB: 45, (0.9194932570494483 %)
#
# GOLMANI: 0 (0.0 %)
#
# Broj igraca u klasteru 4: 3544, (19.465040918328118 %)
#
# NAPAD: 1937 (54.65575620767494 %)
# Broj igraca na poziciji RF: 1, (0.02821670428893905 %)
# Broj igraca na poziciji LF: 1, (0.02821670428893905 %)
# Broj igraca na poziciji RW: 165, (4.655756207674944 %)
# Broj igraca na poziciji LW: 171, (4.8250564334085775 %)
# Broj igraca na poziciji ST: 1400, (39.503386004514674 %)
# Broj igraca na poziciji CF: 39, (1.100451467268623 %)
# Broj igraca na poziciji RS: 78, (2.200902934537246 %)
# Broj igraca na poziciji LS: 82, (2.3137697516930023 %)
#
# VEZNI RED: 1568 (44.24379232505643 %)
# Broj igraca na poziciji RDM: 6, (0.16930022573363432 %)
# Broj igraca na poziciji CDM: 8, (0.2257336343115124 %)
# Broj igraca na poziciji LDM: 6, (0.16930022573363432 %)
# Broj igraca na poziciji RM: 444, (12.528216704288939 %)
# Broj igraca na poziciji RCM: 18, (0.5079006772009029 %)
# Broj igraca na poziciji CM: 300, (8.465011286681715 %)
# Broj igraca na poziciji LCM: 25, (0.7054176072234764 %)
# Broj igraca na poziciji LM: 418, (11.794582392776523 %)
# Broj igraca na poziciji RAM: 1, (0.02821670428893905 %)
# Broj igraca na poziciji CAM: 340, (9.593679458239277 %)
# Broj igraca na poziciji LAM: 2, (0.0564334085778781 %)
#
# ODBRANA: 39 (1.100451467268623 %)
# Broj igraca na poziciji RWB: 5, (0.14108352144469527 %)
# Broj igraca na poziciji RB: 14, (0.39503386004514673 %)
# Broj igraca na poziciji RCB: 0, (0.0 %)
# Broj igraca na poziciji CB: 3, (0.08465011286681716 %)
# Broj igraca na poziciji LCB: 1, (0.02821670428893905 %)
# Broj igraca na poziciji LB: 13, (0.36681715575620766 %)
# Broj igraca na poziciji LWB: 3, (0.08465011286681716 %)
#
# GOLMANI: 0 (0.0 %)

# %%
draw(df)

# %%
# Zamena GKReflexes vrednosti napadaca ID=193911 median vrednoscu

df.loc[df['ID'] == 193911, 'GKReflexes'] = st['GKReflexes'].median()

# %%
kmeans= KMeans(n_clusters=5, random_state=0)
kmeans.fit(df[numeric])
# Out:
# KMeans(n_clusters=5, random_state=0)

# %%
print_percentige_of_five_clusters(df)
# Out:
# Broj igraca u klasteru 0: 3117, (17.119789092107432 %)
#
# NAPAD: 1453 (46.61533525826115 %)
# Broj igraca na poziciji RF: 14, (0.44914982354828364 %)
# Broj igraca na poziciji LF: 13, (0.4170676932948348 %)
# Broj igraca na poziciji RW: 182, (5.838947706127687 %)
# Broj igraca na poziciji LW: 185, (5.935194096888034 %)
# Broj igraca na poziciji ST: 780, (25.02406159769009 %)
# Broj igraca na poziciji CF: 35, (1.122874558870709 %)
# Broj igraca na poziciji RS: 121, (3.881937760667308 %)
# Broj igraca na poziciji LS: 123, (3.946102021174206 %)
#
# VEZNI RED: 1659 (53.22425409047161 %)
# Broj igraca na poziciji RDM: 8, (0.25665704202759065 %)
# Broj igraca na poziciji CDM: 2, (0.06416426050689766 %)
# Broj igraca na poziciji LDM: 12, (0.384985563041386 %)
# Broj igraca na poziciji RM: 477, (15.30317613089509 %)
# Broj igraca na poziciji RCM: 45, (1.4436958614051971 %)
# Broj igraca na poziciji CM: 80, (2.5665704202759065 %)
# Broj igraca na poziciji LCM: 63, (2.021174205967276 %)
# Broj igraca na poziciji LM: 474, (15.206929740134745 %)
# Broj igraca na poziciji RAM: 18, (0.5774783445620789 %)
# Broj igraca na poziciji CAM: 461, (14.789862046839911 %)
# Broj igraca na poziciji LAM: 19, (0.6095604748155278 %)
#
# ODBRANA: 5 (0.16041065126724416 %)
# Broj igraca na poziciji RWB: 0, (0.0 %)
# Broj igraca na poziciji RB: 0, (0.0 %)
# Broj igraca na poziciji RCB: 1, (0.03208213025344883 %)
# Broj igraca na poziciji CB: 0, (0.0 %)
# Broj igraca na poziciji LCB: 0, (0.0 %)
# Broj igraca na poziciji LB: 3, (0.0962463907603465 %)
# Broj igraca na poziciji LWB: 1, (0.03208213025344883 %)
#
# GOLMANI: 0 (0.0 %)
#
# Broj igraca u klasteru 1: 2026, (11.127588290218048 %)
#
# NAPAD: 1 (0.04935834155972359 %)
# Broj igraca na poziciji RF: 0, (0.0 %)
# Broj igraca na poziciji LF: 0, (0.0 %)
# Broj igraca na poziciji RW: 0, (0.0 %)
# Broj igraca na poziciji LW: 0, (0.0 %)
# Broj igraca na poziciji ST: 1, (0.04935834155972359 %)
# Broj igraca na poziciji CF: 0, (0.0 %)
# Broj igraca na poziciji RS: 0, (0.0 %)
# Broj igraca na poziciji LS: 0, (0.0 %)
#
# VEZNI RED: 0 (0.0 %)
# Broj igraca na poziciji RDM: 0, (0.0 %)
# Broj igraca na poziciji CDM: 0, (0.0 %)
# Broj igraca na poziciji LDM: 0, (0.0 %)
# Broj igraca na poziciji RM: 0, (0.0 %)
# Broj igraca na poziciji RCM: 0, (0.0 %)
# Broj igraca na poziciji CM: 0, (0.0 %)
# Broj igraca na poziciji LCM: 0, (0.0 %)
# Broj igraca na poziciji LM: 0, (0.0 %)
# Broj igraca na poziciji RAM: 0, (0.0 %)
# Broj igraca na poziciji CAM: 0, (0.0 %)
# Broj igraca na poziciji LAM: 0, (0.0 %)
#
# ODBRANA: 0 (0.0 %)
# Broj igraca na poziciji RWB: 0, (0.0 %)
# Broj igraca na poziciji RB: 0, (0.0 %)
# Broj igraca na poziciji RCB: 0, (0.0 %)
# Broj igraca na poziciji CB: 0, (0.0 %)
# Broj igraca na poziciji LCB: 0, (0.0 %)
# Broj igraca na poziciji LB: 0, (0.0 %)
# Broj igraca na poziciji LWB: 0, (0.0 %)
#
# GOLMANI: 2025 (99.95064165844028 %)
#
# Broj igraca u klasteru 2: 3544, (19.465040918328118 %)
#
# NAPAD: 1937 (54.65575620767494 %)
# Broj igraca na poziciji RF: 1, (0.02821670428893905 %)
# Broj igraca na poziciji LF: 1, (0.02821670428893905 %)
# Broj igraca na poziciji RW: 165, (4.655756207674944 %)
# Broj igraca na poziciji LW: 171, (4.8250564334085775 %)
# Broj igraca na poziciji ST: 1400, (39.503386004514674 %)
# Broj igraca na poziciji CF: 39, (1.100451467268623 %)
# Broj igraca na poziciji RS: 78, (2.200902934537246 %)
# Broj igraca na poziciji LS: 82, (2.3137697516930023 %)
#
# VEZNI RED: 1568 (44.24379232505643 %)
# Broj igraca na poziciji RDM: 6, (0.16930022573363432 %)
# Broj igraca na poziciji CDM: 8, (0.2257336343115124 %)
# Broj igraca na poziciji LDM: 6, (0.16930022573363432 %)
# Broj igraca na poziciji RM: 444, (12.528216704288939 %)
# Broj igraca na poziciji RCM: 18, (0.5079006772009029 %)
# Broj igraca na poziciji CM: 300, (8.465011286681715 %)
# Broj igraca na poziciji LCM: 25, (0.7054176072234764 %)
# Broj igraca na poziciji LM: 418, (11.794582392776523 %)
# Broj igraca na poziciji RAM: 1, (0.02821670428893905 %)
# Broj igraca na poziciji CAM: 340, (9.593679458239277 %)
# Broj igraca na poziciji LAM: 2, (0.0564334085778781 %)
#
# ODBRANA: 39 (1.100451467268623 %)
# Broj igraca na poziciji RWB: 5, (0.14108352144469527 %)
# Broj igraca na poziciji RB: 14, (0.39503386004514673 %)
# Broj igraca na poziciji RCB: 0, (0.0 %)
# Broj igraca na poziciji CB: 3, (0.08465011286681716 %)
# Broj igraca na poziciji LCB: 1, (0.02821670428893905 %)
# Broj igraca na poziciji LB: 13, (0.36681715575620766 %)
# Broj igraca na poziciji LWB: 3, (0.08465011286681716 %)
#
# GOLMANI: 0 (0.0 %)
#
# Broj igraca u klasteru 3: 4626, (25.40781018289669 %)
#
# NAPAD: 10 (0.21616947686986598 %)
# Broj igraca na poziciji RF: 0, (0.0 %)
# Broj igraca na poziciji LF: 0, (0.0 %)
# Broj igraca na poziciji RW: 0, (0.0 %)
# Broj igraca na poziciji LW: 0, (0.0 %)
# Broj igraca na poziciji ST: 10, (0.21616947686986598 %)
# Broj igraca na poziciji CF: 0, (0.0 %)
# Broj igraca na poziciji RS: 0, (0.0 %)
# Broj igraca na poziciji LS: 0, (0.0 %)
#
# VEZNI RED: 809 (17.488110678772156 %)
# Broj igraca na poziciji RDM: 37, (0.799827064418504 %)
# Broj igraca na poziciji CDM: 355, (7.674016428880242 %)
# Broj igraca na poziciji LDM: 37, (0.799827064418504 %)
# Broj igraca na poziciji RM: 27, (0.5836575875486382 %)
# Broj igraca na poziciji RCM: 35, (0.7565931690445309 %)
# Broj igraca na poziciji CM: 255, (5.512321660181582 %)
# Broj igraca na poziciji LCM: 31, (0.6701253782965845 %)
# Broj igraca na poziciji LM: 24, (0.5188067444876783 %)
# Broj igraca na poziciji RAM: 0, (0.0 %)
# Broj igraca na poziciji CAM: 8, (0.17293558149589278 %)
# Broj igraca na poziciji LAM: 0, (0.0 %)
#
# ODBRANA: 3807 (82.29571984435798 %)
# Broj igraca na poziciji RWB: 37, (0.799827064418504 %)
# Broj igraca na poziciji RB: 591, (12.775616083009078 %)
# Broj igraca na poziciji RCB: 517, (11.175961954172072 %)
# Broj igraca na poziciji CB: 1562, (33.765672287073066 %)
# Broj igraca na poziciji LCB: 496, (10.722006052745352 %)
# Broj igraca na poziciji LB: 575, (12.429744920017294 %)
# Broj igraca na poziciji LWB: 29, (0.6268914829226113 %)
#
# GOLMANI: 0 (0.0 %)
#
# Broj igraca u klasteru 4: 4894, (26.87977151644972 %)
#
# NAPAD: 77 (1.5733551287290561 %)
# Broj igraca na poziciji RF: 1, (0.02043318348998774 %)
# Broj igraca na poziciji LF: 1, (0.02043318348998774 %)
# Broj igraca na poziciji RW: 23, (0.469963220269718 %)
# Broj igraca na poziciji LW: 25, (0.5108295872496935 %)
# Broj igraca na poziciji ST: 21, (0.4290968532897425 %)
# Broj igraca na poziciji CF: 0, (0.0 %)
# Broj igraca na poziciji RS: 4, (0.08173273395995095 %)
# Broj igraca na poziciji LS: 2, (0.04086636697997548 %)
#
# VEZNI RED: 2802 (57.25378013894564 %)
# Broj igraca na poziciji RDM: 197, (4.025337147527585 %)
# Broj igraca na poziciji CDM: 583, (11.912545974662853 %)
# Broj igraca na poziciji LDM: 188, (3.8414384961176955 %)
# Broj igraca na poziciji RM: 176, (3.5962402942378424 %)
# Broj igraca na poziciji RCM: 293, (5.986922762566408 %)
# Broj igraca na poziciji CM: 759, (15.508786268900696 %)
# Broj igraca na poziciji LCM: 276, (5.639558643236616 %)
# Broj igraca na poziciji LM: 179, (3.657539844707806 %)
# Broj igraca na poziciji RAM: 2, (0.04086636697997548 %)
# Broj igraca na poziciji CAM: 149, (3.0445443400081733 %)
# Broj igraca na poziciji LAM: 0, (0.0 %)
#
# ODBRANA: 2015 (41.1728647323253 %)
# Broj igraca na poziciji RWB: 45, (0.9194932570494483 %)
# Broj igraca na poziciji RB: 686, (14.017163874131588 %)
# Broj igraca na poziciji RCB: 144, (2.942378422558235 %)
# Broj igraca na poziciji CB: 213, (4.352268083367389 %)
# Broj igraca na poziciji LCB: 151, (3.085410706988149 %)
# Broj igraca na poziciji LB: 731, (14.936657131181038 %)
# Broj igraca na poziciji LWB: 45, (0.9194932570494483 %)
#
# GOLMANI: 0 (0.0 %)

# %%
draw(df)

# %%
# Zamena Volleys vrednosti napadaca ID=193911 median vrednoscu

df.loc[df['ID'] == 193911, 'Volleys'] = st['Volleys'].median()

# %%
kmeans= KMeans(n_clusters=5, random_state=0)
kmeans.fit(df[numeric])
# Out:
# KMeans(n_clusters=5, random_state=0)

# %%
print_percentige_of_five_clusters(df)
# Out:
# Broj igraca u klasteru 0: 3544, (19.465040918328118 %)
#
# NAPAD: 1937 (54.65575620767494 %)
# Broj igraca na poziciji RF: 1, (0.02821670428893905 %)
# Broj igraca na poziciji LF: 1, (0.02821670428893905 %)
# Broj igraca na poziciji RW: 165, (4.655756207674944 %)
# Broj igraca na poziciji LW: 171, (4.8250564334085775 %)
# Broj igraca na poziciji ST: 1400, (39.503386004514674 %)
# Broj igraca na poziciji CF: 39, (1.100451467268623 %)
# Broj igraca na poziciji RS: 78, (2.200902934537246 %)
# Broj igraca na poziciji LS: 82, (2.3137697516930023 %)
#
# VEZNI RED: 1568 (44.24379232505643 %)
# Broj igraca na poziciji RDM: 6, (0.16930022573363432 %)
# Broj igraca na poziciji CDM: 8, (0.2257336343115124 %)
# Broj igraca na poziciji LDM: 6, (0.16930022573363432 %)
# Broj igraca na poziciji RM: 444, (12.528216704288939 %)
# Broj igraca na poziciji RCM: 18, (0.5079006772009029 %)
# Broj igraca na poziciji CM: 300, (8.465011286681715 %)
# Broj igraca na poziciji LCM: 25, (0.7054176072234764 %)
# Broj igraca na poziciji LM: 418, (11.794582392776523 %)
# Broj igraca na poziciji RAM: 1, (0.02821670428893905 %)
# Broj igraca na poziciji CAM: 340, (9.593679458239277 %)
# Broj igraca na poziciji LAM: 2, (0.0564334085778781 %)
#
# ODBRANA: 39 (1.100451467268623 %)
# Broj igraca na poziciji RWB: 5, (0.14108352144469527 %)
# Broj igraca na poziciji RB: 14, (0.39503386004514673 %)
# Broj igraca na poziciji RCB: 0, (0.0 %)
# Broj igraca na poziciji CB: 3, (0.08465011286681716 %)
# Broj igraca na poziciji LCB: 1, (0.02821670428893905 %)
# Broj igraca na poziciji LB: 13, (0.36681715575620766 %)
# Broj igraca na poziciji LWB: 3, (0.08465011286681716 %)
#
# GOLMANI: 0 (0.0 %)
#
# Broj igraca u klasteru 1: 2025, (11.122095897182401 %)
#
# NAPAD: 0 (0.0 %)
# Broj igraca na poziciji RF: 0, (0.0 %)
# Broj igraca na poziciji LF: 0, (0.0 %)
# Broj igraca na poziciji RW: 0, (0.0 %)
# Broj igraca na poziciji LW: 0, (0.0 %)
# Broj igraca na poziciji ST: 0, (0.0 %)
# Broj igraca na poziciji CF: 0, (0.0 %)
# Broj igraca na poziciji RS: 0, (0.0 %)
# Broj igraca na poziciji LS: 0, (0.0 %)
#
# VEZNI RED: 0 (0.0 %)
# Broj igraca na poziciji RDM: 0, (0.0 %)
# Broj igraca na poziciji CDM: 0, (0.0 %)
# Broj igraca na poziciji LDM: 0, (0.0 %)
# Broj igraca na poziciji RM: 0, (0.0 %)
# Broj igraca na poziciji RCM: 0, (0.0 %)
# Broj igraca na poziciji CM: 0, (0.0 %)
# Broj igraca na poziciji LCM: 0, (0.0 %)
# Broj igraca na poziciji LM: 0, (0.0 %)
# Broj igraca na poziciji RAM: 0, (0.0 %)
# Broj igraca na poziciji CAM: 0, (0.0 %)
# Broj igraca na poziciji LAM: 0, (0.0 %)
#
# ODBRANA: 0 (0.0 %)
# Broj igraca na poziciji RWB: 0, (0.0 %)
# Broj igraca na poziciji RB: 0, (0.0 %)
# Broj igraca na poziciji RCB: 0, (0.0 %)
# Broj igraca na poziciji CB: 0, (0.0 %)
# Broj igraca na poziciji LCB: 0, (0.0 %)
# Broj igraca na poziciji LB: 0, (0.0 %)
# Broj igraca na poziciji LWB: 0, (0.0 %)
#
# GOLMANI: 2025 (100.0 %)
#
# Broj igraca u klasteru 2: 4626, (25.40781018289669 %)
#
# NAPAD: 10 (0.21616947686986598 %)
# Broj igraca na poziciji RF: 0, (0.0 %)
# Broj igraca na poziciji LF: 0, (0.0 %)
# Broj igraca na poziciji RW: 0, (0.0 %)
# Broj igraca na poziciji LW: 0, (0.0 %)
# Broj igraca na poziciji ST: 10, (0.21616947686986598 %)
# Broj igraca na poziciji CF: 0, (0.0 %)
# Broj igraca na poziciji RS: 0, (0.0 %)
# Broj igraca na poziciji LS: 0, (0.0 %)
#
# VEZNI RED: 809 (17.488110678772156 %)
# Broj igraca na poziciji RDM: 37, (0.799827064418504 %)
# Broj igraca na poziciji CDM: 355, (7.674016428880242 %)
# Broj igraca na poziciji LDM: 37, (0.799827064418504 %)
# Broj igraca na poziciji RM: 27, (0.5836575875486382 %)
# Broj igraca na poziciji RCM: 35, (0.7565931690445309 %)
# Broj igraca na poziciji CM: 255, (5.512321660181582 %)
# Broj igraca na poziciji LCM: 31, (0.6701253782965845 %)
# Broj igraca na poziciji LM: 24, (0.5188067444876783 %)
# Broj igraca na poziciji RAM: 0, (0.0 %)
# Broj igraca na poziciji CAM: 8, (0.17293558149589278 %)
# Broj igraca na poziciji LAM: 0, (0.0 %)
#
# ODBRANA: 3807 (82.29571984435798 %)
# Broj igraca na poziciji RWB: 37, (0.799827064418504 %)
# Broj igraca na poziciji RB: 591, (12.775616083009078 %)
# Broj igraca na poziciji RCB: 517, (11.175961954172072 %)
# Broj igraca na poziciji CB: 1562, (33.765672287073066 %)
# Broj igraca na poziciji LCB: 496, (10.722006052745352 %)
# Broj igraca na poziciji LB: 575, (12.429744920017294 %)
# Broj igraca na poziciji LWB: 29, (0.6268914829226113 %)
#
# GOLMANI: 0 (0.0 %)
#
# Broj igraca u klasteru 3: 4894, (26.87977151644972 %)
#
# NAPAD: 77 (1.5733551287290561 %)
# Broj igraca na poziciji RF: 1, (0.02043318348998774 %)
# Broj igraca na poziciji LF: 1, (0.02043318348998774 %)
# Broj igraca na poziciji RW: 23, (0.469963220269718 %)
# Broj igraca na poziciji LW: 25, (0.5108295872496935 %)
# Broj igraca na poziciji ST: 21, (0.4290968532897425 %)
# Broj igraca na poziciji CF: 0, (0.0 %)
# Broj igraca na poziciji RS: 4, (0.08173273395995095 %)
# Broj igraca na poziciji LS: 2, (0.04086636697997548 %)
#
# VEZNI RED: 2802 (57.25378013894564 %)
# Broj igraca na poziciji RDM: 197, (4.025337147527585 %)
# Broj igraca na poziciji CDM: 583, (11.912545974662853 %)
# Broj igraca na poziciji LDM: 188, (3.8414384961176955 %)
# Broj igraca na poziciji RM: 176, (3.5962402942378424 %)
# Broj igraca na poziciji RCM: 293, (5.986922762566408 %)
# Broj igraca na poziciji CM: 759, (15.508786268900696 %)
# Broj igraca na poziciji LCM: 276, (5.639558643236616 %)
# Broj igraca na poziciji LM: 179, (3.657539844707806 %)
# Broj igraca na poziciji RAM: 2, (0.04086636697997548 %)
# Broj igraca na poziciji CAM: 149, (3.0445443400081733 %)
# Broj igraca na poziciji LAM: 0, (0.0 %)
#
# ODBRANA: 2015 (41.1728647323253 %)
# Broj igraca na poziciji RWB: 45, (0.9194932570494483 %)
# Broj igraca na poziciji RB: 686, (14.017163874131588 %)
# Broj igraca na poziciji RCB: 144, (2.942378422558235 %)
# Broj igraca na poziciji CB: 213, (4.352268083367389 %)
# Broj igraca na poziciji LCB: 151, (3.085410706988149 %)
# Broj igraca na poziciji LB: 731, (14.936657131181038 %)
# Broj igraca na poziciji LWB: 45, (0.9194932570494483 %)
#
# GOLMANI: 0 (0.0 %)
#
# Broj igraca u klasteru 4: 3118, (17.125281485143077 %)
#
# NAPAD: 1454 (46.63245670301475 %)
# Broj igraca na poziciji RF: 14, (0.4490057729313663 %)
# Broj igraca na poziciji LF: 13, (0.4169339320076972 %)
# Broj igraca na poziciji RW: 182, (5.837075048107762 %)
# Broj igraca na poziciji LW: 185, (5.933290570878769 %)
# Broj igraca na poziciji ST: 781, (25.048107761385502 %)
# Broj igraca na poziciji CF: 35, (1.1225144323284155 %)
# Broj igraca na poziciji RS: 121, (3.8806927517639513 %)
# Broj igraca na poziciji LS: 123, (3.9448364336112896 %)
#
# VEZNI RED: 1659 (53.2071840923669 %)
# Broj igraca na poziciji RDM: 8, (0.2565747273893521 %)
# Broj igraca na poziciji CDM: 2, (0.06414368184733803 %)
# Broj igraca na poziciji LDM: 12, (0.38486209108402825 %)
# Broj igraca na poziciji RM: 477, (15.298268120590123 %)
# Broj igraca na poziciji RCM: 45, (1.443232841565106 %)
# Broj igraca na poziciji CM: 80, (2.5657472738935216 %)
# Broj igraca na poziciji LCM: 63, (2.020525978191148 %)
# Broj igraca na poziciji LM: 474, (15.202052597819115 %)
# Broj igraca na poziciji RAM: 18, (0.5772931366260423 %)
# Broj igraca na poziciji CAM: 461, (14.785118665811417 %)
# Broj igraca na poziciji LAM: 19, (0.6093649775497113 %)
#
# ODBRANA: 5 (0.1603592046183451 %)
# Broj igraca na poziciji RWB: 0, (0.0 %)
# Broj igraca na poziciji RB: 0, (0.0 %)
# Broj igraca na poziciji RCB: 1, (0.032071840923669014 %)
# Broj igraca na poziciji CB: 0, (0.0 %)
# Broj igraca na poziciji LCB: 0, (0.0 %)
# Broj igraca na poziciji LB: 3, (0.09621552277100706 %)
# Broj igraca na poziciji LWB: 1, (0.032071840923669014 %)
#
# GOLMANI: 0 (0.0 %)

# %%
draw(df)

# %%
# Zamena LongShots vrednosti napadaca ID=193911 median vrednoscu

df.loc[df['ID'] == 193911, 'LongShots'] = st['LongShots'].median()

# %%
kmeans= KMeans(n_clusters=5, random_state=0)
kmeans.fit(df[numeric])
# Out:
# KMeans(n_clusters=5, random_state=0)

# %%
print_percentige_of_five_clusters(df)
# Out:
# Broj igraca u klasteru 0: 3544, (19.465040918328118 %)
#
# NAPAD: 1937 (54.65575620767494 %)
# Broj igraca na poziciji RF: 1, (0.02821670428893905 %)
# Broj igraca na poziciji LF: 1, (0.02821670428893905 %)
# Broj igraca na poziciji RW: 165, (4.655756207674944 %)
# Broj igraca na poziciji LW: 171, (4.8250564334085775 %)
# Broj igraca na poziciji ST: 1400, (39.503386004514674 %)
# Broj igraca na poziciji CF: 39, (1.100451467268623 %)
# Broj igraca na poziciji RS: 78, (2.200902934537246 %)
# Broj igraca na poziciji LS: 82, (2.3137697516930023 %)
#
# VEZNI RED: 1568 (44.24379232505643 %)
# Broj igraca na poziciji RDM: 6, (0.16930022573363432 %)
# Broj igraca na poziciji CDM: 8, (0.2257336343115124 %)
# Broj igraca na poziciji LDM: 6, (0.16930022573363432 %)
# Broj igraca na poziciji RM: 444, (12.528216704288939 %)
# Broj igraca na poziciji RCM: 18, (0.5079006772009029 %)
# Broj igraca na poziciji CM: 300, (8.465011286681715 %)
# Broj igraca na poziciji LCM: 25, (0.7054176072234764 %)
# Broj igraca na poziciji LM: 418, (11.794582392776523 %)
# Broj igraca na poziciji RAM: 1, (0.02821670428893905 %)
# Broj igraca na poziciji CAM: 340, (9.593679458239277 %)
# Broj igraca na poziciji LAM: 2, (0.0564334085778781 %)
#
# ODBRANA: 39 (1.100451467268623 %)
# Broj igraca na poziciji RWB: 5, (0.14108352144469527 %)
# Broj igraca na poziciji RB: 14, (0.39503386004514673 %)
# Broj igraca na poziciji RCB: 0, (0.0 %)
# Broj igraca na poziciji CB: 3, (0.08465011286681716 %)
# Broj igraca na poziciji LCB: 1, (0.02821670428893905 %)
# Broj igraca na poziciji LB: 13, (0.36681715575620766 %)
# Broj igraca na poziciji LWB: 3, (0.08465011286681716 %)
#
# GOLMANI: 0 (0.0 %)
#
# Broj igraca u klasteru 1: 2025, (11.122095897182401 %)
#
# NAPAD: 0 (0.0 %)
# Broj igraca na poziciji RF: 0, (0.0 %)
# Broj igraca na poziciji LF: 0, (0.0 %)
# Broj igraca na poziciji RW: 0, (0.0 %)
# Broj igraca na poziciji LW: 0, (0.0 %)
# Broj igraca na poziciji ST: 0, (0.0 %)
# Broj igraca na poziciji CF: 0, (0.0 %)
# Broj igraca na poziciji RS: 0, (0.0 %)
# Broj igraca na poziciji LS: 0, (0.0 %)
#
# VEZNI RED: 0 (0.0 %)
# Broj igraca na poziciji RDM: 0, (0.0 %)
# Broj igraca na poziciji CDM: 0, (0.0 %)
# Broj igraca na poziciji LDM: 0, (0.0 %)
# Broj igraca na poziciji RM: 0, (0.0 %)
# Broj igraca na poziciji RCM: 0, (0.0 %)
# Broj igraca na poziciji CM: 0, (0.0 %)
# Broj igraca na poziciji LCM: 0, (0.0 %)
# Broj igraca na poziciji LM: 0, (0.0 %)
# Broj igraca na poziciji RAM: 0, (0.0 %)
# Broj igraca na poziciji CAM: 0, (0.0 %)
# Broj igraca na poziciji LAM: 0, (0.0 %)
#
# ODBRANA: 0 (0.0 %)
# Broj igraca na poziciji RWB: 0, (0.0 %)
# Broj igraca na poziciji RB: 0, (0.0 %)
# Broj igraca na poziciji RCB: 0, (0.0 %)
# Broj igraca na poziciji CB: 0, (0.0 %)
# Broj igraca na poziciji LCB: 0, (0.0 %)
# Broj igraca na poziciji LB: 0, (0.0 %)
# Broj igraca na poziciji LWB: 0, (0.0 %)
#
# GOLMANI: 2025 (100.0 %)
#
# Broj igraca u klasteru 2: 4626, (25.40781018289669 %)
#
# NAPAD: 10 (0.21616947686986598 %)
# Broj igraca na poziciji RF: 0, (0.0 %)
# Broj igraca na poziciji LF: 0, (0.0 %)
# Broj igraca na poziciji RW: 0, (0.0 %)
# Broj igraca na poziciji LW: 0, (0.0 %)
# Broj igraca na poziciji ST: 10, (0.21616947686986598 %)
# Broj igraca na poziciji CF: 0, (0.0 %)
# Broj igraca na poziciji RS: 0, (0.0 %)
# Broj igraca na poziciji LS: 0, (0.0 %)
#
# VEZNI RED: 809 (17.488110678772156 %)
# Broj igraca na poziciji RDM: 37, (0.799827064418504 %)
# Broj igraca na poziciji CDM: 355, (7.674016428880242 %)
# Broj igraca na poziciji LDM: 37, (0.799827064418504 %)
# Broj igraca na poziciji RM: 27, (0.5836575875486382 %)
# Broj igraca na poziciji RCM: 35, (0.7565931690445309 %)
# Broj igraca na poziciji CM: 255, (5.512321660181582 %)
# Broj igraca na poziciji LCM: 31, (0.6701253782965845 %)
# Broj igraca na poziciji LM: 24, (0.5188067444876783 %)
# Broj igraca na poziciji RAM: 0, (0.0 %)
# Broj igraca na poziciji CAM: 8, (0.17293558149589278 %)
# Broj igraca na poziciji LAM: 0, (0.0 %)
#
# ODBRANA: 3807 (82.29571984435798 %)
# Broj igraca na poziciji RWB: 37, (0.799827064418504 %)
# Broj igraca na poziciji RB: 591, (12.775616083009078 %)
# Broj igraca na poziciji RCB: 517, (11.175961954172072 %)
# Broj igraca na poziciji CB: 1562, (33.765672287073066 %)
# Broj igraca na poziciji LCB: 496, (10.722006052745352 %)
# Broj igraca na poziciji LB: 575, (12.429744920017294 %)
# Broj igraca na poziciji LWB: 29, (0.6268914829226113 %)
#
# GOLMANI: 0 (0.0 %)
#
# Broj igraca u klasteru 3: 4894, (26.87977151644972 %)
#
# NAPAD: 77 (1.5733551287290561 %)
# Broj igraca na poziciji RF: 1, (0.02043318348998774 %)
# Broj igraca na poziciji LF: 1, (0.02043318348998774 %)
# Broj igraca na poziciji RW: 23, (0.469963220269718 %)
# Broj igraca na poziciji LW: 25, (0.5108295872496935 %)
# Broj igraca na poziciji ST: 21, (0.4290968532897425 %)
# Broj igraca na poziciji CF: 0, (0.0 %)
# Broj igraca na poziciji RS: 4, (0.08173273395995095 %)
# Broj igraca na poziciji LS: 2, (0.04086636697997548 %)
#
# VEZNI RED: 2802 (57.25378013894564 %)
# Broj igraca na poziciji RDM: 197, (4.025337147527585 %)
# Broj igraca na poziciji CDM: 583, (11.912545974662853 %)
# Broj igraca na poziciji LDM: 188, (3.8414384961176955 %)
# Broj igraca na poziciji RM: 176, (3.5962402942378424 %)
# Broj igraca na poziciji RCM: 293, (5.986922762566408 %)
# Broj igraca na poziciji CM: 759, (15.508786268900696 %)
# Broj igraca na poziciji LCM: 276, (5.639558643236616 %)
# Broj igraca na poziciji LM: 179, (3.657539844707806 %)
# Broj igraca na poziciji RAM: 2, (0.04086636697997548 %)
# Broj igraca na poziciji CAM: 149, (3.0445443400081733 %)
# Broj igraca na poziciji LAM: 0, (0.0 %)
#
# ODBRANA: 2015 (41.1728647323253 %)
# Broj igraca na poziciji RWB: 45, (0.9194932570494483 %)
# Broj igraca na poziciji RB: 686, (14.017163874131588 %)
# Broj igraca na poziciji RCB: 144, (2.942378422558235 %)
# Broj igraca na poziciji CB: 213, (4.352268083367389 %)
# Broj igraca na poziciji LCB: 151, (3.085410706988149 %)
# Broj igraca na poziciji LB: 731, (14.936657131181038 %)
# Broj igraca na poziciji LWB: 45, (0.9194932570494483 %)
#
# GOLMANI: 0 (0.0 %)
#
# Broj igraca u klasteru 4: 3118, (17.125281485143077 %)
#
# NAPAD: 1454 (46.63245670301475 %)
# Broj igraca na poziciji RF: 14, (0.4490057729313663 %)
# Broj igraca na poziciji LF: 13, (0.4169339320076972 %)
# Broj igraca na poziciji RW: 182, (5.837075048107762 %)
# Broj igraca na poziciji LW: 185, (5.933290570878769 %)
# Broj igraca na poziciji ST: 781, (25.048107761385502 %)
# Broj igraca na poziciji CF: 35, (1.1225144323284155 %)
# Broj igraca na poziciji RS: 121, (3.8806927517639513 %)
# Broj igraca na poziciji LS: 123, (3.9448364336112896 %)
#
# VEZNI RED: 1659 (53.2071840923669 %)
# Broj igraca na poziciji RDM: 8, (0.2565747273893521 %)
# Broj igraca na poziciji CDM: 2, (0.06414368184733803 %)
# Broj igraca na poziciji LDM: 12, (0.38486209108402825 %)
# Broj igraca na poziciji RM: 477, (15.298268120590123 %)
# Broj igraca na poziciji RCM: 45, (1.443232841565106 %)
# Broj igraca na poziciji CM: 80, (2.5657472738935216 %)
# Broj igraca na poziciji LCM: 63, (2.020525978191148 %)
# Broj igraca na poziciji LM: 474, (15.202052597819115 %)
# Broj igraca na poziciji RAM: 18, (0.5772931366260423 %)
# Broj igraca na poziciji CAM: 461, (14.785118665811417 %)
# Broj igraca na poziciji LAM: 19, (0.6093649775497113 %)
#
# ODBRANA: 5 (0.1603592046183451 %)
# Broj igraca na poziciji RWB: 0, (0.0 %)
# Broj igraca na poziciji RB: 0, (0.0 %)
# Broj igraca na poziciji RCB: 1, (0.032071840923669014 %)
# Broj igraca na poziciji CB: 0, (0.0 %)
# Broj igraca na poziciji LCB: 0, (0.0 %)
# Broj igraca na poziciji LB: 3, (0.09621552277100706 %)
# Broj igraca na poziciji LWB: 1, (0.032071840923669014 %)
#
# GOLMANI: 0 (0.0 %)

# %%
draw(df)

# %%
# Zamena Finishing vrednosti napadaca ID=193911 median vrednoscu

df.loc[df['ID'] == 193911, 'Finishing'] = st['Finishing'].median()

# %%
kmeans= KMeans(n_clusters=5, random_state=0)
kmeans.fit(df[numeric])
# Out:
# KMeans(n_clusters=5, random_state=0)

# %%
print_percentige_of_five_clusters(df)
# Out:
# Broj igraca u klasteru 0: 3544, (19.465040918328118 %)
#
# NAPAD: 1937 (54.65575620767494 %)
# Broj igraca na poziciji RF: 1, (0.02821670428893905 %)
# Broj igraca na poziciji LF: 1, (0.02821670428893905 %)
# Broj igraca na poziciji RW: 165, (4.655756207674944 %)
# Broj igraca na poziciji LW: 171, (4.8250564334085775 %)
# Broj igraca na poziciji ST: 1400, (39.503386004514674 %)
# Broj igraca na poziciji CF: 39, (1.100451467268623 %)
# Broj igraca na poziciji RS: 78, (2.200902934537246 %)
# Broj igraca na poziciji LS: 82, (2.3137697516930023 %)
#
# VEZNI RED: 1568 (44.24379232505643 %)
# Broj igraca na poziciji RDM: 6, (0.16930022573363432 %)
# Broj igraca na poziciji CDM: 8, (0.2257336343115124 %)
# Broj igraca na poziciji LDM: 6, (0.16930022573363432 %)
# Broj igraca na poziciji RM: 444, (12.528216704288939 %)
# Broj igraca na poziciji RCM: 18, (0.5079006772009029 %)
# Broj igraca na poziciji CM: 300, (8.465011286681715 %)
# Broj igraca na poziciji LCM: 25, (0.7054176072234764 %)
# Broj igraca na poziciji LM: 418, (11.794582392776523 %)
# Broj igraca na poziciji RAM: 1, (0.02821670428893905 %)
# Broj igraca na poziciji CAM: 340, (9.593679458239277 %)
# Broj igraca na poziciji LAM: 2, (0.0564334085778781 %)
#
# ODBRANA: 39 (1.100451467268623 %)
# Broj igraca na poziciji RWB: 5, (0.14108352144469527 %)
# Broj igraca na poziciji RB: 14, (0.39503386004514673 %)
# Broj igraca na poziciji RCB: 0, (0.0 %)
# Broj igraca na poziciji CB: 3, (0.08465011286681716 %)
# Broj igraca na poziciji LCB: 1, (0.02821670428893905 %)
# Broj igraca na poziciji LB: 13, (0.36681715575620766 %)
# Broj igraca na poziciji LWB: 3, (0.08465011286681716 %)
#
# GOLMANI: 0 (0.0 %)
#
# Broj igraca u klasteru 1: 2025, (11.122095897182401 %)
#
# NAPAD: 0 (0.0 %)
# Broj igraca na poziciji RF: 0, (0.0 %)
# Broj igraca na poziciji LF: 0, (0.0 %)
# Broj igraca na poziciji RW: 0, (0.0 %)
# Broj igraca na poziciji LW: 0, (0.0 %)
# Broj igraca na poziciji ST: 0, (0.0 %)
# Broj igraca na poziciji CF: 0, (0.0 %)
# Broj igraca na poziciji RS: 0, (0.0 %)
# Broj igraca na poziciji LS: 0, (0.0 %)
#
# VEZNI RED: 0 (0.0 %)
# Broj igraca na poziciji RDM: 0, (0.0 %)
# Broj igraca na poziciji CDM: 0, (0.0 %)
# Broj igraca na poziciji LDM: 0, (0.0 %)
# Broj igraca na poziciji RM: 0, (0.0 %)
# Broj igraca na poziciji RCM: 0, (0.0 %)
# Broj igraca na poziciji CM: 0, (0.0 %)
# Broj igraca na poziciji LCM: 0, (0.0 %)
# Broj igraca na poziciji LM: 0, (0.0 %)
# Broj igraca na poziciji RAM: 0, (0.0 %)
# Broj igraca na poziciji CAM: 0, (0.0 %)
# Broj igraca na poziciji LAM: 0, (0.0 %)
#
# ODBRANA: 0 (0.0 %)
# Broj igraca na poziciji RWB: 0, (0.0 %)
# Broj igraca na poziciji RB: 0, (0.0 %)
# Broj igraca na poziciji RCB: 0, (0.0 %)
# Broj igraca na poziciji CB: 0, (0.0 %)
# Broj igraca na poziciji LCB: 0, (0.0 %)
# Broj igraca na poziciji LB: 0, (0.0 %)
# Broj igraca na poziciji LWB: 0, (0.0 %)
#
# GOLMANI: 2025 (100.0 %)
#
# Broj igraca u klasteru 2: 4626, (25.40781018289669 %)
#
# NAPAD: 10 (0.21616947686986598 %)
# Broj igraca na poziciji RF: 0, (0.0 %)
# Broj igraca na poziciji LF: 0, (0.0 %)
# Broj igraca na poziciji RW: 0, (0.0 %)
# Broj igraca na poziciji LW: 0, (0.0 %)
# Broj igraca na poziciji ST: 10, (0.21616947686986598 %)
# Broj igraca na poziciji CF: 0, (0.0 %)
# Broj igraca na poziciji RS: 0, (0.0 %)
# Broj igraca na poziciji LS: 0, (0.0 %)
#
# VEZNI RED: 809 (17.488110678772156 %)
# Broj igraca na poziciji RDM: 37, (0.799827064418504 %)
# Broj igraca na poziciji CDM: 355, (7.674016428880242 %)
# Broj igraca na poziciji LDM: 37, (0.799827064418504 %)
# Broj igraca na poziciji RM: 27, (0.5836575875486382 %)
# Broj igraca na poziciji RCM: 35, (0.7565931690445309 %)
# Broj igraca na poziciji CM: 255, (5.512321660181582 %)
# Broj igraca na poziciji LCM: 31, (0.6701253782965845 %)
# Broj igraca na poziciji LM: 24, (0.5188067444876783 %)
# Broj igraca na poziciji RAM: 0, (0.0 %)
# Broj igraca na poziciji CAM: 8, (0.17293558149589278 %)
# Broj igraca na poziciji LAM: 0, (0.0 %)
#
# ODBRANA: 3807 (82.29571984435798 %)
# Broj igraca na poziciji RWB: 37, (0.799827064418504 %)
# Broj igraca na poziciji RB: 591, (12.775616083009078 %)
# Broj igraca na poziciji RCB: 517, (11.175961954172072 %)
# Broj igraca na poziciji CB: 1562, (33.765672287073066 %)
# Broj igraca na poziciji LCB: 496, (10.722006052745352 %)
# Broj igraca na poziciji LB: 575, (12.429744920017294 %)
# Broj igraca na poziciji LWB: 29, (0.6268914829226113 %)
#
# GOLMANI: 0 (0.0 %)
#
# Broj igraca u klasteru 3: 4894, (26.87977151644972 %)
#
# NAPAD: 77 (1.5733551287290561 %)
# Broj igraca na poziciji RF: 1, (0.02043318348998774 %)
# Broj igraca na poziciji LF: 1, (0.02043318348998774 %)
# Broj igraca na poziciji RW: 23, (0.469963220269718 %)
# Broj igraca na poziciji LW: 25, (0.5108295872496935 %)
# Broj igraca na poziciji ST: 21, (0.4290968532897425 %)
# Broj igraca na poziciji CF: 0, (0.0 %)
# Broj igraca na poziciji RS: 4, (0.08173273395995095 %)
# Broj igraca na poziciji LS: 2, (0.04086636697997548 %)
#
# VEZNI RED: 2802 (57.25378013894564 %)
# Broj igraca na poziciji RDM: 197, (4.025337147527585 %)
# Broj igraca na poziciji CDM: 583, (11.912545974662853 %)
# Broj igraca na poziciji LDM: 188, (3.8414384961176955 %)
# Broj igraca na poziciji RM: 176, (3.5962402942378424 %)
# Broj igraca na poziciji RCM: 293, (5.986922762566408 %)
# Broj igraca na poziciji CM: 759, (15.508786268900696 %)
# Broj igraca na poziciji LCM: 276, (5.639558643236616 %)
# Broj igraca na poziciji LM: 179, (3.657539844707806 %)
# Broj igraca na poziciji RAM: 2, (0.04086636697997548 %)
# Broj igraca na poziciji CAM: 149, (3.0445443400081733 %)
# Broj igraca na poziciji LAM: 0, (0.0 %)
#
# ODBRANA: 2015 (41.1728647323253 %)
# Broj igraca na poziciji RWB: 45, (0.9194932570494483 %)
# Broj igraca na poziciji RB: 686, (14.017163874131588 %)
# Broj igraca na poziciji RCB: 144, (2.942378422558235 %)
# Broj igraca na poziciji CB: 213, (4.352268083367389 %)
# Broj igraca na poziciji LCB: 151, (3.085410706988149 %)
# Broj igraca na poziciji LB: 731, (14.936657131181038 %)
# Broj igraca na poziciji LWB: 45, (0.9194932570494483 %)
#
# GOLMANI: 0 (0.0 %)
#
# Broj igraca u klasteru 4: 3118, (17.125281485143077 %)
#
# NAPAD: 1454 (46.63245670301475 %)
# Broj igraca na poziciji RF: 14, (0.4490057729313663 %)
# Broj igraca na poziciji LF: 13, (0.4169339320076972 %)
# Broj igraca na poziciji RW: 182, (5.837075048107762 %)
# Broj igraca na poziciji LW: 185, (5.933290570878769 %)
# Broj igraca na poziciji ST: 781, (25.048107761385502 %)
# Broj igraca na poziciji CF: 35, (1.1225144323284155 %)
# Broj igraca na poziciji RS: 121, (3.8806927517639513 %)
# Broj igraca na poziciji LS: 123, (3.9448364336112896 %)
#
# VEZNI RED: 1659 (53.2071840923669 %)
# Broj igraca na poziciji RDM: 8, (0.2565747273893521 %)
# Broj igraca na poziciji CDM: 2, (0.06414368184733803 %)
# Broj igraca na poziciji LDM: 12, (0.38486209108402825 %)
# Broj igraca na poziciji RM: 477, (15.298268120590123 %)
# Broj igraca na poziciji RCM: 45, (1.443232841565106 %)
# Broj igraca na poziciji CM: 80, (2.5657472738935216 %)
# Broj igraca na poziciji LCM: 63, (2.020525978191148 %)
# Broj igraca na poziciji LM: 474, (15.202052597819115 %)
# Broj igraca na poziciji RAM: 18, (0.5772931366260423 %)
# Broj igraca na poziciji CAM: 461, (14.785118665811417 %)
# Broj igraca na poziciji LAM: 19, (0.6093649775497113 %)
#
# ODBRANA: 5 (0.1603592046183451 %)
# Broj igraca na poziciji RWB: 0, (0.0 %)
# Broj igraca na poziciji RB: 0, (0.0 %)
# Broj igraca na poziciji RCB: 1, (0.032071840923669014 %)
# Broj igraca na poziciji CB: 0, (0.0 %)
# Broj igraca na poziciji LCB: 0, (0.0 %)
# Broj igraca na poziciji LB: 3, (0.09621552277100706 %)
# Broj igraca na poziciji LWB: 1, (0.032071840923669014 %)
#
# GOLMANI: 0 (0.0 %)

# %%
draw(df)

# %% [markdown]
# ### Nakon zamene parametara: BallControl, GKDiving, Dribbling, HeadingAccuracy, GKPositioning, GKKicking, GKReflexes, Volleys, LongShots, Finishing, median vrednošću njihovih odgovarajućih kolona, k-means algoritam prestaje napadača ID=193911 da svrstava u klaster sa golmanima
