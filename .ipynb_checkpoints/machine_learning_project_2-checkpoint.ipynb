# %%
import pandas as pd
import seaborn as sns
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.cluster import KMeans, AgglomerativeClustering, DBSCAN
import matplotlib.pyplot as plt
from sklearn.metrics import silhouette_score
from kmodes.kprototypes import KPrototypes
from scipy.cluster.hierarchy import linkage, dendrogram

# %matplotlib inline

# %%
df = pd.read_csv('kl.csv', encoding='ISO-8859-1')
df.head()
# Out:
#    Unnamed: 0      ID               Name   Age  \
# 0           0  158023           L. Messi  31.0
# 1           1   20801  Cristiano Ronaldo  33.0
# 2           2  190871          Neymar Jr  26.0
# 3           3  193080             De Gea  27.0
# 4           4  192985       K. De Bruyne  27.0
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png     94.0         94
# 1  https://cdn.sofifa.org/flags/38.png     94.0         94
# 2  https://cdn.sofifa.org/flags/54.png     92.0         93
# 3  https://cdn.sofifa.org/flags/45.png     91.0         93
# 4   https://cdn.sofifa.org/flags/7.png     91.0         92
#
#                   Club  ... Composure Marking StandingTackle  SlidingTackle  \
# 0         FC Barcelona  ...      96.0    33.0           28.0           26.0
# 1             Juventus  ...      95.0    28.0           31.0           23.0
# 2  Paris Saint-Germain  ...      94.0    27.0           24.0           33.0
# 3    Manchester United  ...      68.0    15.0           21.0           13.0
# 4      Manchester City  ...      88.0    68.0           58.0           51.0
#
#   GKDiving  GKHandling  GKKicking  GKPositioning GKReflexes Release Clause
# 0      6.0        11.0       15.0           14.0        8.0        226.5M
# 1      7.0        11.0       15.0           14.0       11.0        127.1M
# 2      9.0         9.0       15.0           15.0       11.0        228.1M
# 3     90.0        85.0       87.0           88.0       94.0        138.6M
# 4     15.0        13.0        5.0           10.0       13.0        196.4M
#
# [5 rows x 89 columns]

# %%
df.shape
# Out:
# (18207, 89)

# %%
df.isnull().mean()
# Out:
# Unnamed: 0        0.000000
# ID                0.000000
# Name              0.000000
# Age               0.000055
# Photo             0.000000
#                     ...
# GKHandling        0.002636
# GKKicking         0.002636
# GKPositioning     0.002636
# GKReflexes        0.002636
# Release Clause    0.085901
# Length: 89, dtype: float64

# %%
sns.heatmap(df.isna(), cmap='viridis', yticklabels=False, cbar=None)
# Out:
# <AxesSubplot:>

# %%
def missing_values_boundry(df, missing_percentige):
    
    columns_with_missing_values_above_border = []
    series = df.isna().mean()
    for index in series.index:
        if series[index] > missing_percentige:
            columns_with_missing_values_above_border.append(index)
    return columns_with_missing_values_above_border
        
missing_values_boundry(df, 0.3)
# Out:
# ['Loaned From']

# %%
df['Loaned From'].isna().mean()
# Out:
# 0.9305761520294392

# %%
df.drop('Loaned From', axis=1, inplace=True)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'Name', 'Age', 'Photo', 'Nationality', 'Flag',
#        'Overall', 'Potential', 'Club', 'Club Logo', 'Value', 'Wage', 'Special',
#        'Preferred Foot', 'International Reputation', 'Weak Foot',
#        'Skill Moves', 'Work Rate', 'Body Type', 'Real Face', 'Position',
#        'Jersey Number', 'Joined', 'Contract Valid Until', 'Height', 'Weight',
#        'LS', 'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW', 'LAM', 'CAM', 'RAM',
#        'LM', 'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM', 'CDM', 'RDM', 'RWB', 'LB',
#        'LCB', 'CB', 'RCB', 'RB', 'Crossing', 'Finishing', 'HeadingAccuracy',
#        'ShortPassing', 'Volleys', 'Dribbling', 'Curve', 'FKAccuracy',
#        'LongPassing', 'BallControl', 'Acceleration', 'SprintSpeed', 'Agility',
#        'Reactions', 'Balance', 'ShotPower', 'Jumping', 'Stamina', 'Strength',
#        'LongShots', 'Aggression', 'Interceptions', 'Positioning', 'Vision',
#        'Penalties', 'Composure', 'Marking', 'StandingTackle', 'SlidingTackle',
#        'GKDiving', 'GKHandling', 'GKKicking', 'GKPositioning', 'GKReflexes',
#        'Release Clause'],
#       dtype='object')

# %%
df['Position'].unique()
# Out:
# array(['RF', 'ST', 'LW', 'GK', 'RCM', 'LF', 'RS', 'RCB', 'LCM', 'CB',
#        'LDM', 'CAM', 'CDM', 'LS', 'LCB', 'RM', 'LAM', 'LM', 'LB', 'RDM',
#        'RW', 'CM', 'RB', 'RAM', 'CF', 'RWB', 'LWB', nan], dtype=object)

# %%
# podela promenljivih na numericke i kategoricke

numeric = []
categorical = []
for column in df.columns:
    if str(df[column].dtype) == 'object':
        categorical.append(column)
    else:
        numeric.append(column)
        
numeric
categorical

len(numeric) + len(categorical)
print('Broj kategorickih promenljivih:', len(categorical))
print('Broj numerickih promenljivih:', len(numeric))
# Out:
# Broj kategorickih promenljivih: 44
# Broj numerickih promenljivih: 44

# %%
# zamena NaN vrednosti zeljenim metodom (mean, mode, median ili random sample imputation-om)

def impute_value(df, variable, method='random sample'):

    if method == 'mean':
        df[variable].fillna(df[variable].mean(), inplace=True)
    elif method == 'mode':
        df[variable].fillna(df[variable].mode()[0], inplace=True)
    elif method == 'median':
        df[variable + '_median'] = df[variable].fillna(df[variable].median())
    else:
        df[variable + '_random_sample'] = df[variable]
        random_sample = df[variable].dropna().sample(df[variable].isna().sum(), random_state=0)
        random_sample.index = df.loc[df[variable].isna()].index
        df.loc[df[variable].isna(), variable] = random_sample

# %%
def find_irq_outliers(values):
    
    outliers = []
    sorted_values = sorted(values)
    min, max = np.percentile(sorted_values, [25, 75])
    irq_difference = max - min
    upper_border = max + 1.5 * irq_difference
    lower_border = min - 1.5 * irq_difference

    for value in sorted_values:
        if value < lower_border or value > upper_border:
#         if upper_border < value < lower_border:
            outliers.append(value)
    return outliers
        
outlier_numeric_columns = []
for numerical_variable in numeric:
    if len(find_irq_outliers(df[numerical_variable])):
        outlier_numeric_columns.append(numerical_variable)

outlier_numeric_columns
# Out:
# ['ID', 'Potential', 'Special']

# %%
for variable in numeric:
    if variable in outlier_numeric_columns:
        impute_value(df, variable, 'median')
        impute_value(df, variable)
        standard_deviation_old_values = df[variable].std()
        standard_deviation_median_values = df[variable + '_median'].std()
        standard_deviation_random_sample = df[variable + '_random_sample'].std()
        if abs(standard_deviation_median_values - standard_deviation_old_values) < abs(standard_deviation_random_sample - standard_deviation_old_values):
            df[variable] = df[variable + '_median']
        else:
            df[variable] = df[variable + '_random_sample']
        df.drop(columns=[variable + '_random_sample', variable + '_median'], inplace=True)

    else:
        impute_value(df, variable, 'mean')

# %%
for categorical_variable in categorical:
    impute_value(df, categorical_variable, 'mode')
sum(df[categorical].isna().sum().values)
# Out:
# 0

# %%
sum(df[numeric].isna().sum().values)
# Out:
# 0

# %%
sns.heatmap(df.isna(), cmap='viridis', yticklabels=False, cbar=None)
# Out:
# <AxesSubplot:>

# %%
# Funkcija koja vrsi skaliranje promenljivih zeljenom metodom

def feature_scaling(df, features, method):
    
    for feature in features:
        scaled_feature = method.fit_transform(df[[feature]])
        df[feature] = scaled_feature
        
feature_scaling(df, numeric, MinMaxScaler())

df[numeric].head()
# Out:
#    Unnamed: 0        ID       Age   Overall  Potential   Special  \
# 0    0.000000  0.640732  0.517241  1.000000   0.978723  0.910836
# 1    0.000055  0.084285  0.586207  1.000000   0.978723  0.926935
# 2    0.000110  0.773933  0.344828  0.958333   0.957447  0.874303
# 3    0.000165  0.782891  0.379310  0.937500   0.957447  0.458204
# 4    0.000220  0.782506  0.379310  0.937500   0.936170  0.959752
#
#    International Reputation  Weak Foot  Skill Moves  Jersey Number  ...  \
# 0                      1.00       0.75         0.75       0.091837  ...
# 1                      1.00       0.75         1.00       0.061224  ...
# 2                      1.00       1.00         1.00       0.091837  ...
# 3                      0.75       0.50         0.00       0.000000  ...
# 4                      0.75       1.00         0.75       0.061224  ...
#
#    Penalties  Composure   Marking  StandingTackle  SlidingTackle  GKDiving  \
# 0   0.804598   1.000000  0.329670        0.285714       0.261364  0.056180
# 1   0.919540   0.989247  0.274725        0.318681       0.227273  0.067416
# 2   0.873563   0.978495  0.263736        0.241758       0.340909  0.089888
# 3   0.402299   0.698925  0.131868        0.208791       0.113636  1.000000
# 4   0.850575   0.913978  0.714286        0.615385       0.545455  0.157303
#
#    GKHandling  GKKicking  GKPositioning  GKReflexes
# 0    0.109890   0.155556       0.146067    0.075269
# 1    0.109890   0.155556       0.146067    0.107527
# 2    0.087912   0.155556       0.157303    0.107527
# 3    0.923077   0.955556       0.977528    1.000000
# 4    0.131868   0.044444       0.101124    0.129032
#
# [5 rows x 44 columns]

# %%
def show_position_percentige_per_cluster(df, cluster_number, original_dataset_length):
    
    number_of_players_in_cluster = len(df)
    print(f'Broj igraca u klasteru {cluster_number}: {number_of_players_in_cluster}, ({(number_of_players_in_cluster / original_dataset_length) * 100} %)' )
    print()

    # Napad
    
    df_num_of_attackers = len(df.loc[(df['Position'] == 'RF') | (df['Position'] == 'LF') | (df['Position'] == 'RW') | (df['Position'] == 'LW') | (df['Position'] == 'ST') | (df['Position'] =='CF') |  (df['Position'] == 'RS') | (df['Position'] == 'LS')])
    df_num_of_attackers_percentige = (df_num_of_attackers / number_of_players_in_cluster) * 100

    print(f'NAPAD: {df_num_of_attackers} ({df_num_of_attackers_percentige} %)')
    rf_number = len(df.loc[df['Position'] == 'RF'])
    rf_percentige = (rf_number / number_of_players_in_cluster) * 100
    print('Broj igraca na poziciji RF:', f'{rf_number}, ({rf_percentige} %)')
    lf_number = len(df.loc[df['Position'] == 'LF'])
    lf_percentige = (lf_number / number_of_players_in_cluster) * 100
    print('Broj igraca na poziciji LF:', f'{lf_number}, ({lf_percentige} %)')
    rw_number = len(df.loc[df['Position'] == 'RW'])
    rw_percentige = (rw_number / number_of_players_in_cluster) * 100
    print('Broj igraca na poziciji RW:', f'{rw_number}, ({rw_percentige} %)')
    lw_number = len(df.loc[df['Position'] == 'LW'])
    lw_percentige = (lw_number / number_of_players_in_cluster) * 100
    print('Broj igraca na poziciji LW:', f'{lw_number}, ({lw_percentige} %)')
    st_number = len(df.loc[df['Position'] == 'ST'])
    st_percentige = (st_number / number_of_players_in_cluster ) * 100
    print('Broj igraca na poziciji ST:', f'{st_number}, ({st_percentige} %)')
    cf_number = len(df.loc[df['Position'] == 'CF'])
    cf_percentige = (cf_number / number_of_players_in_cluster) * 100
    print('Broj igraca na poziciji CF:', f'{cf_number}, ({cf_percentige} %)')
    rs_number = len(df.loc[df['Position'] == 'RS'])
    rs_percentige = (rs_number / number_of_players_in_cluster) * 100
    print('Broj igraca na poziciji RS:', f'{rs_number}, ({rs_percentige} %)')
    ls_number = len(df.loc[df['Position'] == 'LS'])
    ls_percentige = (ls_number / number_of_players_in_cluster) * 100
    print('Broj igraca na poziciji LS:', f'{ls_number}, ({ls_percentige} %)')
    print()

    # Vezni red

    df_num_of_mid = len(df.loc[(df['Position'] == 'RDM') | (df['Position'] == 'CDM') | (df['Position'] == 'LDM') | (df['Position'] == 'RM') | (df['Position'] == 'RCM') | (df['Position'] == 'CM') | (df['Position'] == 'LCM') | (df['Position'] == 'LM') | (df['Position'] == 'RAM') | (df['Position'] == 'CAM') | (df['Position'] =='LAM')])
    df_num_of_mid_percentige = (df_num_of_mid / number_of_players_in_cluster) * 100

    print(f'VEZNI RED: {df_num_of_mid} ({df_num_of_mid_percentige} %)')
    rdm_number = len(df.loc[df['Position'] == 'RDM'])
    rdm_percentige = (rdm_number / number_of_players_in_cluster) * 100
    print('Broj igraca na poziciji RDM:', f'{rdm_number}, ({rdm_percentige} %)')
    cdm_number = len(df.loc[df['Position'] == 'CDM'])
    cdm_percentige = (cdm_number / number_of_players_in_cluster) * 100
    print('Broj igraca na poziciji CDM:', f'{cdm_number}, ({cdm_percentige} %)')
    ldm_number = len(df.loc[df['Position'] == 'LDM'])
    ldm_percentige = (ldm_number / number_of_players_in_cluster) * 100
    print('Broj igraca na poziciji LDM:', f'{ldm_number}, ({ldm_percentige} %)')
    rm_number = len(df.loc[df['Position'] == 'RM'])
    rm_percentige = (rm_number / number_of_players_in_cluster) * 100
    print('Broj igraca na poziciji RM:', f'{rm_number}, ({rm_percentige} %)')
    rcm_number = len(df.loc[df['Position'] == 'RCM'])
    rcm_percentige = (rcm_number / number_of_players_in_cluster) * 100
    print('Broj igraca na poziciji RCM:', f'{rcm_number}, ({rcm_percentige} %)')
    cm_number = len(df.loc[df['Position'] == 'CM'])
    cm_percentige = (cm_number / number_of_players_in_cluster) * 100
    print('Broj igraca na poziciji CM:', f'{cm_number}, ({cm_percentige} %)')
    lcm_number = len(df.loc[df['Position'] == 'LCM'])
    lcm_percentige = (lcm_number / number_of_players_in_cluster) * 100
    print('Broj igraca na poziciji LCM:', f'{lcm_number}, ({lcm_percentige} %)')
    lm_number = len(df.loc[df['Position'] == 'LM'])
    lm_percentige = (lm_number / number_of_players_in_cluster) * 100
    print('Broj igraca na poziciji LM:', f'{lm_number}, ({lm_percentige} %)')
    ram_number = len(df.loc[df['Position'] == 'RAM'])
    ram_percentige = (ram_number / number_of_players_in_cluster) * 100
    print('Broj igraca na poziciji RAM:', f'{ram_number}, ({ram_percentige} %)')
    cam_number = len(df.loc[df['Position'] == 'CAM'])
    cam_percentige = (cam_number / number_of_players_in_cluster) * 100
    print('Broj igraca na poziciji CAM:', f'{cam_number}, ({cam_percentige} %)')
    lam_number = len(df.loc[df['Position'] == 'LAM'])
    lam_percentige = (lam_number / number_of_players_in_cluster) * 100
    print('Broj igraca na poziciji LAM:', f'{lam_number}, ({lam_percentige} %)')
    print()

    # Odbrana

    df_num_of_dif = len(df.loc[(df['Position'] == 'RWB') | (df['Position'] == 'RB') | (df['Position'] == 'RCB') | (df['Position'] == 'CB') | (df['Position'] == 'LCB') | (df['Position'] == 'LB') | (df['Position'] == 'LWB')])
    df_num_of_dif_percentige = (df_num_of_dif / number_of_players_in_cluster) * 100

    print(f'ODBRANA: {df_num_of_dif} ({df_num_of_dif_percentige} %)')
    rwb_number = len(df.loc[df['Position'] == 'RWB'])
    rwb_percentige = (rwb_number / number_of_players_in_cluster) * 100
    print('Broj igraca na poziciji RWB:', f'{rwb_number}, ({rwb_percentige} %)')
    rb_number = len(df.loc[df['Position'] == 'RB'])
    rb_percentige = (rb_number / number_of_players_in_cluster) * 100
    print('Broj igraca na poziciji RB:', f'{rb_number}, ({rb_percentige} %)')
    rcb_number = len(df.loc[df['Position'] == 'RCB'])
    rcb_percentige = (rcb_number / number_of_players_in_cluster) * 100
    print('Broj igraca na poziciji RCB:', f'{rcb_number}, ({rcb_percentige} %)')
    cb_number = len(df.loc[df['Position'] == 'CB'])
    cb_percentige = (cb_number / number_of_players_in_cluster) * 100
    print('Broj igraca na poziciji CB:', f'{cb_number}, ({cb_percentige} %)')
    lcb_number = len(df.loc[df['Position'] == 'LCB'])
    lcb_percentige = (lcb_number / number_of_players_in_cluster) * 100
    print('Broj igraca na poziciji LCB:', f'{lcb_number}, ({lcb_percentige} %)')
    lb_number = len(df.loc[df['Position'] == 'LB'])
    lb_percentige = (lb_number / number_of_players_in_cluster) * 100
    print('Broj igraca na poziciji LB:', f'{lb_number}, ({lb_percentige} %)')
    lwb_number = len(df.loc[df['Position'] == 'LWB'])
    lwb_percentige = (lwb_number / number_of_players_in_cluster) * 100
    print('Broj igraca na poziciji LWB:', f'{lwb_number}, ({lwb_percentige} %)')
    print()

    # Golmani

    df_num_of_gk = len(df.loc[df['Position'] == 'GK'])
    df_num_of_gk_percentige = (df_num_of_gk / number_of_players_in_cluster) * 100
    
    print(f'GOLMANI: {df_num_of_gk} ({df_num_of_gk_percentige} %)')
    print()

# %%
from collections import Counter

sse = []
silhouette = []
for k in range(2, 11):
    kmeans = KMeans(n_clusters=k, random_state=0)
    kmeans.fit(df[numeric])
    sse.append(kmeans.inertia_)
    silhouette.append(silhouette_score(df[numeric], kmeans.labels_))

# %%
plt.plot(range(2, 11), sse)
plt.title('Elbow method')
plt.xlabel('K')
plt.ylabel('SSE')
# Out:
# Text(0, 0.5, 'SSE')

# %%
kmeans = KMeans(n_clusters=4, random_state=0)
kmeans.fit(df[numeric])
kmeans.labels_

count = Counter(kmeans.labels_)
number_and_percentige_per_cluster = {}

for value, times in count.most_common():
    number_and_percentige_per_cluster[value] = [times, (times / len(df)) * 100]
    
number_and_percentige_per_cluster
# Out:
# {3: [5891, 32.35568737298841],
#  1: [5537, 30.411380238369855],
#  0: [4753, 26.105344098423682],
#  2: [2026, 11.127588290218048]}

# %%
df['Position'].unique()
# Out:
# array(['RF', 'ST', 'LW', 'GK', 'RCM', 'LF', 'RS', 'RCB', 'LCM', 'CB',
#        'LDM', 'CAM', 'CDM', 'LS', 'LCB', 'RM', 'LAM', 'LM', 'LB', 'RDM',
#        'RW', 'CM', 'RB', 'RAM', 'CF', 'RWB', 'LWB'], dtype=object)

# %% [markdown]
# **Golman** - GK
#
# **Odbrana** - RWB, RB, RCB, CB, LCB, LB, LWB
#
# **Vezni red** - RDM, CDM, LDM, RM, RCM, CM, LCM, LM, RAM, CAM, LAM
#
# **Napad** - RF, CF, LF, RS, ST, LS, LW, RW

# %%
df['cluster_marks'] = kmeans.labels_

df_cluster_0 = df.loc[df['cluster_marks'] == 0]
df_cluster_1 = df.loc[df['cluster_marks'] == 1]
df_cluster_2 = df.loc[df['cluster_marks'] == 2]
df_cluster_3 = df.loc[df['cluster_marks'] == 3]
# df_cluster_4 = df.loc[df['cluster_marks'] == 4]
# df_cluster_5 = df.loc[df['cluster_marks'] == 5]
# df_cluster_6 = df.loc[df['cluster_marks'] == 6]
# df_cluster_7 = df.loc[df['cluster_marks'] == 7]

show_position_percentige_per_cluster(df_cluster_0, 0, len(df))
show_position_percentige_per_cluster(df_cluster_1, 1, len(df))
show_position_percentige_per_cluster(df_cluster_2, 2, len(df))
show_position_percentige_per_cluster(df_cluster_3, 3, len(df))
# show_position_percentige_per_cluster(df_cluster_4, 4, len(df))
# show_position_percentige_per_cluster(df_cluster_5, 5, len(df))
# show_position_percentige_per_cluster(df_cluster_6, 6, len(df))
# show_position_percentige_per_cluster(df_cluster_7, 7, len(df))
# Out:
# Broj igraca u klasteru 0: 4753, (26.105344098423682 %)
#
# NAPAD: 2542 (53.482011361245526 %)
# Broj igraca na poziciji RF: 5, (0.1051967178624027 %)
# Broj igraca na poziciji LF: 7, (0.14727540500736377 %)
# Broj igraca na poziciji RW: 248, (5.217757205975174 %)
# Broj igraca na poziciji LW: 260, (5.47022932884494 %)
# Broj igraca na poziciji ST: 1716, (36.103513570376606 %)
# Broj igraca na poziciji CF: 50, (1.0519671786240268 %)
# Broj igraca na poziciji RS: 128, (2.6930359772775088 %)
# Broj igraca na poziciji LS: 128, (2.6930359772775088 %)
#
# VEZNI RED: 2173 (45.71849358300021 %)
# Broj igraca na poziciji RDM: 11, (0.23143277929728595 %)
# Broj igraca na poziciji CDM: 7, (0.14727540500736377 %)
# Broj igraca na poziciji LDM: 10, (0.2103934357248054 %)
# Broj igraca na poziciji RM: 624, (13.128550389227856 %)
# Broj igraca na poziciji RCM: 34, (0.7153376814643384 %)
# Broj igraca na poziciji CM: 305, (6.416999789606565 %)
# Broj igraca na poziciji LCM: 40, (0.8415737428992216 %)
# Broj igraca na poziciji LM: 621, (13.065432358510416 %)
# Broj igraca na poziciji RAM: 2, (0.042078687144961074 %)
# Broj igraca na poziciji CAM: 511, (10.751104565537556 %)
# Broj igraca na poziciji LAM: 8, (0.1683147485798443 %)
#
# ODBRANA: 38 (0.7994950557542605 %)
# Broj igraca na poziciji RWB: 5, (0.1051967178624027 %)
# Broj igraca na poziciji RB: 10, (0.2103934357248054 %)
# Broj igraca na poziciji RCB: 1, (0.021039343572480537 %)
# Broj igraca na poziciji CB: 3, (0.06311803071744161 %)
# Broj igraca na poziciji LCB: 1, (0.021039343572480537 %)
# Broj igraca na poziciji LB: 14, (0.29455081001472755 %)
# Broj igraca na poziciji LWB: 4, (0.08415737428992215 %)
#
# GOLMANI: 0 (0.0 %)
#
# Broj igraca u klasteru 1: 5537, (30.411380238369855 %)
#
# NAPAD: 862 (15.567997110348564 %)
# Broj igraca na poziciji RF: 11, (0.19866353621094454 %)
# Broj igraca na poziciji LF: 8, (0.14448257178977786 %)
# Broj igraca na poziciji RW: 119, (2.1491782553729455 %)
# Broj igraca na poziciji LW: 117, (2.113057612425501 %)
# Broj igraca na poziciji ST: 429, (7.747877912226837 %)
# Broj igraca na poziciji CF: 24, (0.4334477153693336 %)
# Broj igraca na poziciji RS: 75, (1.3545241105291674 %)
# Broj igraca na poziciji LS: 79, (1.4267653964240563 %)
#
# VEZNI RED: 3255 (58.78634639696586 %)
# Broj igraca na poziciji RDM: 169, (3.052194329059057 %)
# Broj igraca na poziciji CDM: 417, (7.531154054542171 %)
# Broj igraca na poziciji LDM: 151, (2.727108542532057 %)
# Broj igraca na poziciji RM: 443, (8.000722412858948 %)
# Broj igraca na poziciji RCM: 281, (5.074950334115947 %)
# Broj igraca na poziciji CM: 640, (11.558605743182229 %)
# Broj igraca na poziciji LCM: 281, (5.074950334115947 %)
# Broj igraca na poziciji LM: 424, (7.657576304858226 %)
# Broj igraca na poziciji RAM: 18, (0.32508578652700015 %)
# Broj igraca na poziciji CAM: 418, (7.549214376015893 %)
# Broj igraca na poziciji LAM: 13, (0.23478417915838903 %)
#
# ODBRANA: 1420 (25.64565649268557 %)
# Broj igraca na poziciji RWB: 35, (0.6321112515802781 %)
# Broj igraca na poziciji RB: 499, (9.012100415387394 %)
# Broj igraca na poziciji RCB: 91, (1.643489254108723 %)
# Broj igraca na poziciji CB: 136, (2.456203720426224 %)
# Broj igraca na poziciji LCB: 97, (1.7518511829510566 %)
# Broj igraca na poziciji LB: 525, (9.481668773704172 %)
# Broj igraca na poziciji LWB: 37, (0.6682318945277226 %)
#
# GOLMANI: 0 (0.0 %)
#
# Broj igraca u klasteru 2: 2026, (11.127588290218048 %)
#
# NAPAD: 1 (0.04935834155972359 %)
# Broj igraca na poziciji RF: 0, (0.0 %)
# Broj igraca na poziciji LF: 0, (0.0 %)
# Broj igraca na poziciji RW: 0, (0.0 %)
# Broj igraca na poziciji LW: 0, (0.0 %)
# Broj igraca na poziciji ST: 1, (0.04935834155972359 %)
# Broj igraca na poziciji CF: 0, (0.0 %)
# Broj igraca na poziciji RS: 0, (0.0 %)
# Broj igraca na poziciji LS: 0, (0.0 %)
#
# VEZNI RED: 0 (0.0 %)
# Broj igraca na poziciji RDM: 0, (0.0 %)
# Broj igraca na poziciji CDM: 0, (0.0 %)
# Broj igraca na poziciji LDM: 0, (0.0 %)
# Broj igraca na poziciji RM: 0, (0.0 %)
# Broj igraca na poziciji RCM: 0, (0.0 %)
# Broj igraca na poziciji CM: 0, (0.0 %)
# Broj igraca na poziciji LCM: 0, (0.0 %)
# Broj igraca na poziciji LM: 0, (0.0 %)
# Broj igraca na poziciji RAM: 0, (0.0 %)
# Broj igraca na poziciji CAM: 0, (0.0 %)
# Broj igraca na poziciji LAM: 0, (0.0 %)
#
# ODBRANA: 0 (0.0 %)
# Broj igraca na poziciji RWB: 0, (0.0 %)
# Broj igraca na poziciji RB: 0, (0.0 %)
# Broj igraca na poziciji RCB: 0, (0.0 %)
# Broj igraca na poziciji CB: 0, (0.0 %)
# Broj igraca na poziciji LCB: 0, (0.0 %)
# Broj igraca na poziciji LB: 0, (0.0 %)
# Broj igraca na poziciji LWB: 0, (0.0 %)
#
# GOLMANI: 2025 (99.95064165844028 %)
#
# Broj igraca u klasteru 3: 5891, (32.35568737298841 %)
#
# NAPAD: 73 (1.2391784077406214 %)
# Broj igraca na poziciji RF: 0, (0.0 %)
# Broj igraca na poziciji LF: 0, (0.0 %)
# Broj igraca na poziciji RW: 3, (0.05092514004413513 %)
# Broj igraca na poziciji LW: 4, (0.0679001867255135 %)
# Broj igraca na poziciji ST: 66, (1.1203530809709725 %)
# Broj igraca na poziciji CF: 0, (0.0 %)
# Broj igraca na poziciji RS: 0, (0.0 %)
# Broj igraca na poziciji LS: 0, (0.0 %)
#
# VEZNI RED: 1410 (23.93481582074351 %)
# Broj igraca na poziciji RDM: 68, (1.1543031743337295 %)
# Broj igraca na poziciji CDM: 524, (8.894924461042269 %)
# Broj igraca na poziciji LDM: 82, (1.3919538278730266 %)
# Broj igraca na poziciji RM: 57, (0.9675776608385672 %)
# Broj igraca na poziciji RCM: 76, (1.2901035477847564 %)
# Broj igraca na poziciji CM: 449, (7.62179595993889 %)
# Broj igraca na poziciji LCM: 74, (1.2561534544219997 %)
# Broj igraca na poziciji LM: 50, (0.8487523340689187 %)
# Broj igraca na poziciji RAM: 1, (0.016975046681378374 %)
# Broj igraca na poziciji CAM: 29, (0.49227635375997286 %)
# Broj igraca na poziciji LAM: 0, (0.0 %)
#
# ODBRANA: 4408 (74.82600577151587 %)
# Broj igraca na poziciji RWB: 47, (0.7978271940247836 %)
# Broj igraca na poziciji RB: 782, (13.274486504837887 %)
# Broj igraca na poziciji RCB: 570, (9.675776608385673 %)
# Broj igraca na poziciji CB: 1639, (27.822101510779156 %)
# Broj igraca na poziciji LCB: 550, (9.336275674758106 %)
# Broj igraca na poziciji LB: 783, (13.291461551519268 %)
# Broj igraca na poziciji LWB: 37, (0.6280767272109998 %)
#
# GOLMANI: 0 (0.0 %)

# %%
player = df_cluster_2.loc[df_cluster_2['Position'] == 'ST']
player
# Out:
#        Unnamed: 0        ID     Name       Age  \
# 16450    0.903548  0.786261  S. Paul  0.517241
#
#                                                 Photo Nationality  \
# 16450  https://cdn.sofifa.org/players/4/19/193911.png       India
#
#                                        Flag   Overall  Potential       Club  \
# 16450  https://cdn.sofifa.org/flags/159.png  0.229167   0.191489  AS Monaco
#
#        ...   Marking StandingTackle SlidingTackle  GKDiving GKHandling  \
# 16450  ...  0.098901       0.142857      0.102273   0.58427   0.516484
#
#        GKKicking  GKPositioning  GKReflexes Release Clause cluster_marks
# 16450   0.677778       0.629213    0.634409          1.1M             2
#
# [1 rows x 89 columns]

# %%
plt.plot(range(2, 11), silhouette)
plt.title('Silhouette test')
plt.xlabel('K')
plt.ylabel('Silhouette score')
# Out:
# Text(0, 0.5, 'Silhouette score')

# %%
kmeans = KMeans(n_clusters=2, random_state=0)
kmeans.fit(df[numeric])
kmeans.labels_

count = Counter(kmeans.labels_)
number_and_percentige_per_cluster = {}

for value, times in count.most_common():
    number_and_percentige_per_cluster[value] = [times, (times / len(df)) * 100]

number_and_percentige_per_cluster
# Out:
# {0: [16180, 88.8669193167463], 1: [2027, 11.133080683253693]}

# %%
df['cluster_marks'] = kmeans.labels_

df_cluster_0 = df.loc[df['cluster_marks'] == 0]
df_cluster_1 = df.loc[df['cluster_marks'] == 1]

show_position_percentige_per_cluster(df_cluster_0, 0, len(df))
show_position_percentige_per_cluster(df_cluster_1, 1, len(df))
# Out:
# Broj igraca u klasteru 0: 16180, (88.8669193167463 %)
#
# NAPAD: 3477 (21.489493201483313 %)
# Broj igraca na poziciji RF: 16, (0.0988875154511743 %)
# Broj igraca na poziciji LF: 15, (0.0927070457354759 %)
# Broj igraca na poziciji RW: 370, (2.2867737948084055 %)
# Broj igraca na poziciji LW: 381, (2.3547589616810876 %)
# Broj igraca na poziciji ST: 2211, (13.665018541409147 %)
# Broj igraca na poziciji CF: 74, (0.4573547589616811 %)
# Broj igraca na poziciji RS: 203, (1.254635352286774 %)
# Broj igraca na poziciji LS: 207, (1.2793572311495673 %)
#
# VEZNI RED: 6838 (42.26205191594561 %)
# Broj igraca na poziciji RDM: 248, (1.5327564894932013 %)
# Broj igraca na poziciji CDM: 948, (5.859085290482077 %)
# Broj igraca na poziciji LDM: 243, (1.5018541409147095 %)
# Broj igraca na poziciji RM: 1124, (6.946847960444994 %)
# Broj igraca na poziciji RCM: 391, (2.4165636588380717 %)
# Broj igraca na poziciji CM: 1394, (8.615574783683561 %)
# Broj igraca na poziciji LCM: 395, (2.4412855377008653 %)
# Broj igraca na poziciji LM: 1095, (6.767614338689741 %)
# Broj igraca na poziciji RAM: 21, (0.12978986402966625 %)
# Broj igraca na poziciji CAM: 958, (5.920889987639061 %)
# Broj igraca na poziciji LAM: 21, (0.12978986402966625 %)
#
# ODBRANA: 5865 (36.248454882571075 %)
# Broj igraca na poziciji RWB: 87, (0.5377008652657602 %)
# Broj igraca na poziciji RB: 1291, (7.978986402966626 %)
# Broj igraca na poziciji RCB: 662, (4.091470951792337 %)
# Broj igraca na poziciji CB: 1777, (10.982694684796044 %)
# Broj igraca na poziciji LCB: 648, (4.004944375772559 %)
# Broj igraca na poziciji LB: 1322, (8.170580964153276 %)
# Broj igraca na poziciji LWB: 78, (0.4820766378244747 %)
#
# GOLMANI: 0 (0.0 %)
#
# Broj igraca u klasteru 1: 2027, (11.133080683253693 %)
#
# NAPAD: 1 (0.049333991119881605 %)
# Broj igraca na poziciji RF: 0, (0.0 %)
# Broj igraca na poziciji LF: 0, (0.0 %)
# Broj igraca na poziciji RW: 0, (0.0 %)
# Broj igraca na poziciji LW: 0, (0.0 %)
# Broj igraca na poziciji ST: 1, (0.049333991119881605 %)
# Broj igraca na poziciji CF: 0, (0.0 %)
# Broj igraca na poziciji RS: 0, (0.0 %)
# Broj igraca na poziciji LS: 0, (0.0 %)
#
# VEZNI RED: 0 (0.0 %)
# Broj igraca na poziciji RDM: 0, (0.0 %)
# Broj igraca na poziciji CDM: 0, (0.0 %)
# Broj igraca na poziciji LDM: 0, (0.0 %)
# Broj igraca na poziciji RM: 0, (0.0 %)
# Broj igraca na poziciji RCM: 0, (0.0 %)
# Broj igraca na poziciji CM: 0, (0.0 %)
# Broj igraca na poziciji LCM: 0, (0.0 %)
# Broj igraca na poziciji LM: 0, (0.0 %)
# Broj igraca na poziciji RAM: 0, (0.0 %)
# Broj igraca na poziciji CAM: 0, (0.0 %)
# Broj igraca na poziciji LAM: 0, (0.0 %)
#
# ODBRANA: 1 (0.049333991119881605 %)
# Broj igraca na poziciji RWB: 0, (0.0 %)
# Broj igraca na poziciji RB: 0, (0.0 %)
# Broj igraca na poziciji RCB: 0, (0.0 %)
# Broj igraca na poziciji CB: 1, (0.049333991119881605 %)
# Broj igraca na poziciji LCB: 0, (0.0 %)
# Broj igraca na poziciji LB: 0, (0.0 %)
# Broj igraca na poziciji LWB: 0, (0.0 %)
#
# GOLMANI: 2025 (99.90133201776024 %)

# %%
player = df_cluster_1.loc[df_cluster_1['Position'] == 'ST']
player
# Out:
#        Unnamed: 0        ID     Name       Age  \
# 16450    0.903548  0.786261  S. Paul  0.517241
#
#                                                 Photo Nationality  \
# 16450  https://cdn.sofifa.org/players/4/19/193911.png       India
#
#                                        Flag   Overall  Potential       Club  \
# 16450  https://cdn.sofifa.org/flags/159.png  0.229167   0.191489  AS Monaco
#
#        ...   Marking StandingTackle SlidingTackle  GKDiving GKHandling  \
# 16450  ...  0.098901       0.142857      0.102273   0.58427   0.516484
#
#        GKKicking  GKPositioning  GKReflexes Release Clause cluster_marks
# 16450   0.677778       0.629213    0.634409          1.1M             1
#
# [1 rows x 89 columns]

# %%
player = df_cluster_1.loc[df_cluster_1['Position'] == 'CB']
player
# Out:
#        Unnamed: 0        ID        Name       Age  \
# 17657    0.969845  0.046285  J. McCombe  0.655172
#
#                                                Photo Nationality  \
# 17657  https://cdn.sofifa.org/players/4/19/11430.png     England
#
#                                       Flag   Overall  Potential          Club  \
# 17657  https://cdn.sofifa.org/flags/14.png  0.145833   0.106383  Lincoln City
#
#        ...   Marking StandingTackle SlidingTackle  GKDiving GKHandling  \
# 17657  ...  0.527473       0.538462      0.568182   0.05618   0.142857
#
#        GKKicking  GKPositioning  GKReflexes Release Clause cluster_marks
# 17657   0.122222        0.11236    0.139785           18K             1
#
# [1 rows x 89 columns]

# %%
# Koristiti domensko znanje prilikom odabira k

# Generalno, postoje 4 razlicite pozicije (golman, odbrana, vezni red i napad), tako da prvo pokusati za k=4

kmeans = KMeans(n_clusters=4, random_state=0)
kmeans.fit(df[numeric])
kmeans.labels_

count = Counter(kmeans.labels_)
number_and_percentige_per_cluster = {}

for value, times in count.most_common():
    number_and_percentige_per_cluster[value] = [(times, times / len(df)) * 100]
    
number_and_percentige_per_cluster
# Out:
# {3: [(5891,
#    0.3235568737298841,
#    5891,
#    0.3235568737298841,
#    5891,
#    0.3235568737298841,
#    5891,
#    0.3235568737298841,
#    5891,
#    0.3235568737298841,
#    5891,
#    0.3235568737298841,
#    5891,
#    0.3235568737298841,
#    5891,
#    0.3235568737298841,
#    5891,
#    0.3235568737298841,
#    5891,
#    0.3235568737298841,
#    5891,
#    0.3235568737298841,
#    5891,
#    0.3235568737298841,
#    5891,
#    0.3235568737298841,
#    5891,
#    0.3235568737298841,
#    5891,
#    0.3235568737298841,
#    5891,
#    0.3235568737298841,
#    5891,
#    0.3235568737298841,
#    5891,
#    0.3235568737298841,
#    5891,
#    0.3235568737298841,
#    5891,
#    0.3235568737298841,
#    5891,
#    0.3235568737298841,
#    5891,
#    0.3235568737298841,
#    5891,
#    0.3235568737298841,
#    5891,
#    0.3235568737298841,
#    5891,
#    0.3235568737298841,
#    5891,
#    0.3235568737298841,
#    5891,
#    0.3235568737298841,
#    5891,
#    0.3235568737298841,
#    5891,
#    0.3235568737298841,
#    5891,
#    0.3235568737298841,
#    5891,
#    0.3235568737298841,
#    5891,
#    0.3235568737298841,
#    5891,
#    0.3235568737298841,
#    5891,
#    0.3235568737298841,
#    5891,
#    0.3235568737298841,
#    5891,
#    0.3235568737298841,
#    5891,
#    0.3235568737298841,
#    5891,
#    0.3235568737298841,
#    5891,
#    0.3235568737298841,
#    5891,
#    0.3235568737298841,
#    5891,
#    0.3235568737298841,
#    5891,
#    0.3235568737298841,
#    5891,
#    0.3235568737298841,
#    5891,
#    0.3235568737298841,
#    5891,
#    0.3235568737298841,
#    5891,
#    0.3235568737298841,
#    5891,
#    0.3235568737298841,
#    5891,
#    0.3235568737298841,
#    5891,
#    0.3235568737298841,
#    5891,
#    0.3235568737298841,
#    5891,
#    0.3235568737298841,
#    5891,
#    0.3235568737298841,
#    5891,
#    0.3235568737298841,
#    5891,
#    0.3235568737298841,
#    5891,
#    0.3235568737298841,
#    5891,
#    0.3235568737298841,
#    5891,
#    0.3235568737298841,
#    5891,
#    0.3235568737298841,
#    5891,
#    0.3235568737298841,
#    5891,
#    0.3235568737298841,
#    5891,
#    0.3235568737298841,
#    5891,
#    0.3235568737298841,
#    5891,
#    0.3235568737298841,
#    5891,
#    0.3235568737298841,
#    5891,
#    0.3235568737298841,
#    5891,
#    0.3235568737298841,
#    5891,
#    0.3235568737298841,
#    5891,
#    0.3235568737298841,
#    5891,
#    0.3235568737298841,
#    5891,
#    0.3235568737298841,
#    5891,
#    0.3235568737298841,
#    5891,
#    0.3235568737298841,
#    5891,
#    0.3235568737298841,
#    5891,
#    0.3235568737298841,
#    5891,
#    0.3235568737298841,
#    5891,
#    0.3235568737298841,
#    5891,
#    0.3235568737298841,
#    5891,
#    0.3235568737298841,
#    5891,
#    0.3235568737298841,
#    5891,
#    0.3235568737298841,
#    5891,
#    0.3235568737298841,
#    5891,
#    0.3235568737298841,
#    5891,
#    0.3235568737298841,
#    5891,
#    0.3235568737298841,
#    5891,
#    0.3235568737298841,
#    5891,
#    0.3235568737298841,
#    5891,
#    0.3235568737298841,
#    5891,
#    0.3235568737298841,
#    5891,
#    0.3235568737298841,
#    5891,
#    0.3235568737298841,
#    5891,
#    0.3235568737298841,
#    5891,
#    0.3235568737298841,
#    5891,
#    0.3235568737298841,
#    5891,
#    0.3235568737298841,
#    5891,
#    0.3235568737298841,
#    5891,
#    0.3235568737298841,
#    5891,
#    0.3235568737298841,
#    5891,
#    0.3235568737298841,
#    5891,
#    0.3235568737298841,
#    5891,
#    0.3235568737298841)],
#  1: [(5537,
#    0.30411380238369856,
#    5537,
#    0.30411380238369856,
#    5537,
#    0.30411380238369856,
#    5537,
#    0.30411380238369856,
#    5537,
#    0.30411380238369856,
#    5537,
#    0.30411380238369856,
#    5537,
#    0.30411380238369856,
#    5537,
#    0.30411380238369856,
#    5537,
#    0.30411380238369856,
#    5537,
#    0.30411380238369856,
#    5537,
#    0.30411380238369856,
#    5537,
#    0.30411380238369856,
#    5537,
#    0.30411380238369856,
#    5537,
#    0.30411380238369856,
#    5537,
#    0.30411380238369856,
#    5537,
#    0.30411380238369856,
#    5537,
#    0.30411380238369856,
#    5537,
#    0.30411380238369856,
#    5537,
#    0.30411380238369856,
#    5537,
#    0.30411380238369856,
#    5537,
#    0.30411380238369856,
#    5537,
#    0.30411380238369856,
#    5537,
#    0.30411380238369856,
#    5537,
#    0.30411380238369856,
#    5537,
#    0.30411380238369856,
#    5537,
#    0.30411380238369856,
#    5537,
#    0.30411380238369856,
#    5537,
#    0.30411380238369856,
#    5537,
#    0.30411380238369856,
#    5537,
#    0.30411380238369856,
#    5537,
#    0.30411380238369856,
#    5537,
#    0.30411380238369856,
#    5537,
#    0.30411380238369856,
#    5537,
#    0.30411380238369856,
#    5537,
#    0.30411380238369856,
#    5537,
#    0.30411380238369856,
#    5537,
#    0.30411380238369856,
#    5537,
#    0.30411380238369856,
#    5537,
#    0.30411380238369856,
#    5537,
#    0.30411380238369856,
#    5537,
#    0.30411380238369856,
#    5537,
#    0.30411380238369856,
#    5537,
#    0.30411380238369856,
#    5537,
#    0.30411380238369856,
#    5537,
#    0.30411380238369856,
#    5537,
#    0.30411380238369856,
#    5537,
#    0.30411380238369856,
#    5537,
#    0.30411380238369856,
#    5537,
#    0.30411380238369856,
#    5537,
#    0.30411380238369856,
#    5537,
#    0.30411380238369856,
#    5537,
#    0.30411380238369856,
#    5537,
#    0.30411380238369856,
#    5537,
#    0.30411380238369856,
#    5537,
#    0.30411380238369856,
#    5537,
#    0.30411380238369856,
#    5537,
#    0.30411380238369856,
#    5537,
#    0.30411380238369856,
#    5537,
#    0.30411380238369856,
#    5537,
#    0.30411380238369856,
#    5537,
#    0.30411380238369856,
#    5537,
#    0.30411380238369856,
#    5537,
#    0.30411380238369856,
#    5537,
#    0.30411380238369856,
#    5537,
#    0.30411380238369856,
#    5537,
#    0.30411380238369856,
#    5537,
#    0.30411380238369856,
#    5537,
#    0.30411380238369856,
#    5537,
#    0.30411380238369856,
#    5537,
#    0.30411380238369856,
#    5537,
#    0.30411380238369856,
#    5537,
#    0.30411380238369856,
#    5537,
#    0.30411380238369856,
#    5537,
#    0.30411380238369856,
#    5537,
#    0.30411380238369856,
#    5537,
#    0.30411380238369856,
#    5537,
#    0.30411380238369856,
#    5537,
#    0.30411380238369856,
#    5537,
#    0.30411380238369856,
#    5537,
#    0.30411380238369856,
#    5537,
#    0.30411380238369856,
#    5537,
#    0.30411380238369856,
#    5537,
#    0.30411380238369856,
#    5537,
#    0.30411380238369856,
#    5537,
#    0.30411380238369856,
#    5537,
#    0.30411380238369856,
#    5537,
#    0.30411380238369856,
#    5537,
#    0.30411380238369856,
#    5537,
#    0.30411380238369856,
#    5537,
#    0.30411380238369856,
#    5537,
#    0.30411380238369856,
#    5537,
#    0.30411380238369856,
#    5537,
#    0.30411380238369856,
#    5537,
#    0.30411380238369856,
#    5537,
#    0.30411380238369856,
#    5537,
#    0.30411380238369856,
#    5537,
#    0.30411380238369856,
#    5537,
#    0.30411380238369856,
#    5537,
#    0.30411380238369856,
#    5537,
#    0.30411380238369856)],
#  0: [(4753,
#    0.26105344098423683,
#    4753,
#    0.26105344098423683,
#    4753,
#    0.26105344098423683,
#    4753,
#    0.26105344098423683,
#    4753,
#    0.26105344098423683,
#    4753,
#    0.26105344098423683,
#    4753,
#    0.26105344098423683,
#    4753,
#    0.26105344098423683,
#    4753,
#    0.26105344098423683,
#    4753,
#    0.26105344098423683,
#    4753,
#    0.26105344098423683,
#    4753,
#    0.26105344098423683,
#    4753,
#    0.26105344098423683,
#    4753,
#    0.26105344098423683,
#    4753,
#    0.26105344098423683,
#    4753,
#    0.26105344098423683,
#    4753,
#    0.26105344098423683,
#    4753,
#    0.26105344098423683,
#    4753,
#    0.26105344098423683,
#    4753,
#    0.26105344098423683,
#    4753,
#    0.26105344098423683,
#    4753,
#    0.26105344098423683,
#    4753,
#    0.26105344098423683,
#    4753,
#    0.26105344098423683,
#    4753,
#    0.26105344098423683,
#    4753,
#    0.26105344098423683,
#    4753,
#    0.26105344098423683,
#    4753,
#    0.26105344098423683,
#    4753,
#    0.26105344098423683,
#    4753,
#    0.26105344098423683,
#    4753,
#    0.26105344098423683,
#    4753,
#    0.26105344098423683,
#    4753,
#    0.26105344098423683,
#    4753,
#    0.26105344098423683,
#    4753,
#    0.26105344098423683,
#    4753,
#    0.26105344098423683,
#    4753,
#    0.26105344098423683,
#    4753,
#    0.26105344098423683,
#    4753,
#    0.26105344098423683,
#    4753,
#    0.26105344098423683,
#    4753,
#    0.26105344098423683,
#    4753,
#    0.26105344098423683,
#    4753,
#    0.26105344098423683,
#    4753,
#    0.26105344098423683,
#    4753,
#    0.26105344098423683,
#    4753,
#    0.26105344098423683,
#    4753,
#    0.26105344098423683,
#    4753,
#    0.26105344098423683,
#    4753,
#    0.26105344098423683,
#    4753,
#    0.26105344098423683,
#    4753,
#    0.26105344098423683,
#    4753,
#    0.26105344098423683,
#    4753,
#    0.26105344098423683,
#    4753,
#    0.26105344098423683,
#    4753,
#    0.26105344098423683,
#    4753,
#    0.26105344098423683,
#    4753,
#    0.26105344098423683,
#    4753,
#    0.26105344098423683,
#    4753,
#    0.26105344098423683,
#    4753,
#    0.26105344098423683,
#    4753,
#    0.26105344098423683,
#    4753,
#    0.26105344098423683,
#    4753,
#    0.26105344098423683,
#    4753,
#    0.26105344098423683,
#    4753,
#    0.26105344098423683,
#    4753,
#    0.26105344098423683,
#    4753,
#    0.26105344098423683,
#    4753,
#    0.26105344098423683,
#    4753,
#    0.26105344098423683,
#    4753,
#    0.26105344098423683,
#    4753,
#    0.26105344098423683,
#    4753,
#    0.26105344098423683,
#    4753,
#    0.26105344098423683,
#    4753,
#    0.26105344098423683,
#    4753,
#    0.26105344098423683,
#    4753,
#    0.26105344098423683,
#    4753,
#    0.26105344098423683,
#    4753,
#    0.26105344098423683,
#    4753,
#    0.26105344098423683,
#    4753,
#    0.26105344098423683,
#    4753,
#    0.26105344098423683,
#    4753,
#    0.26105344098423683,
#    4753,
#    0.26105344098423683,
#    4753,
#    0.26105344098423683,
#    4753,
#    0.26105344098423683,
#    4753,
#    0.26105344098423683,
#    4753,
#    0.26105344098423683,
#    4753,
#    0.26105344098423683,
#    4753,
#    0.26105344098423683,
#    4753,
#    0.26105344098423683,
#    4753,
#    0.26105344098423683,
#    4753,
#    0.26105344098423683,
#    4753,
#    0.26105344098423683,
#    4753,
#    0.26105344098423683,
#    4753,
#    0.26105344098423683,
#    4753,
#    0.26105344098423683,
#    4753,
#    0.26105344098423683,
#    4753,
#    0.26105344098423683,
#    4753,
#    0.26105344098423683,
#    4753,
#    0.26105344098423683)],
#  2: [(2026,
#    0.11127588290218048,
#    2026,
#    0.11127588290218048,
#    2026,
#    0.11127588290218048,
#    2026,
#    0.11127588290218048,
#    2026,
#    0.11127588290218048,
#    2026,
#    0.11127588290218048,
#    2026,
#    0.11127588290218048,
#    2026,
#    0.11127588290218048,
#    2026,
#    0.11127588290218048,
#    2026,
#    0.11127588290218048,
#    2026,
#    0.11127588290218048,
#    2026,
#    0.11127588290218048,
#    2026,
#    0.11127588290218048,
#    2026,
#    0.11127588290218048,
#    2026,
#    0.11127588290218048,
#    2026,
#    0.11127588290218048,
#    2026,
#    0.11127588290218048,
#    2026,
#    0.11127588290218048,
#    2026,
#    0.11127588290218048,
#    2026,
#    0.11127588290218048,
#    2026,
#    0.11127588290218048,
#    2026,
#    0.11127588290218048,
#    2026,
#    0.11127588290218048,
#    2026,
#    0.11127588290218048,
#    2026,
#    0.11127588290218048,
#    2026,
#    0.11127588290218048,
#    2026,
#    0.11127588290218048,
#    2026,
#    0.11127588290218048,
#    2026,
#    0.11127588290218048,
#    2026,
#    0.11127588290218048,
#    2026,
#    0.11127588290218048,
#    2026,
#    0.11127588290218048,
#    2026,
#    0.11127588290218048,
#    2026,
#    0.11127588290218048,
#    2026,
#    0.11127588290218048,
#    2026,
#    0.11127588290218048,
#    2026,
#    0.11127588290218048,
#    2026,
#    0.11127588290218048,
#    2026,
#    0.11127588290218048,
#    2026,
#    0.11127588290218048,
#    2026,
#    0.11127588290218048,
#    2026,
#    0.11127588290218048,
#    2026,
#    0.11127588290218048,
#    2026,
#    0.11127588290218048,
#    2026,
#    0.11127588290218048,
#    2026,
#    0.11127588290218048,
#    2026,
#    0.11127588290218048,
#    2026,
#    0.11127588290218048,
#    2026,
#    0.11127588290218048,
#    2026,
#    0.11127588290218048,
#    2026,
#    0.11127588290218048,
#    2026,
#    0.11127588290218048,
#    2026,
#    0.11127588290218048,
#    2026,
#    0.11127588290218048,
#    2026,
#    0.11127588290218048,
#    2026,
#    0.11127588290218048,
#    2026,
#    0.11127588290218048,
#    2026,
#    0.11127588290218048,
#    2026,
#    0.11127588290218048,
#    2026,
#    0.11127588290218048,
#    2026,
#    0.11127588290218048,
#    2026,
#    0.11127588290218048,
#    2026,
#    0.11127588290218048,
#    2026,
#    0.11127588290218048,
#    2026,
#    0.11127588290218048,
#    2026,
#    0.11127588290218048,
#    2026,
#    0.11127588290218048,
#    2026,
#    0.11127588290218048,
#    2026,
#    0.11127588290218048,
#    2026,
#    0.11127588290218048,
#    2026,
#    0.11127588290218048,
#    2026,
#    0.11127588290218048,
#    2026,
#    0.11127588290218048,
#    2026,
#    0.11127588290218048,
#    2026,
#    0.11127588290218048,
#    2026,
#    0.11127588290218048,
#    2026,
#    0.11127588290218048,
#    2026,
#    0.11127588290218048,
#    2026,
#    0.11127588290218048,
#    2026,
#    0.11127588290218048,
#    2026,
#    0.11127588290218048,
#    2026,
#    0.11127588290218048,
#    2026,
#    0.11127588290218048,
#    2026,
#    0.11127588290218048,
#    2026,
#    0.11127588290218048,
#    2026,
#    0.11127588290218048,
#    2026,
#    0.11127588290218048,
#    2026,
#    0.11127588290218048,
#    2026,
#    0.11127588290218048,
#    2026,
#    0.11127588290218048,
#    2026,
#    0.11127588290218048,
#    2026,
#    0.11127588290218048,
#    2026,
#    0.11127588290218048,
#    2026,
#    0.11127588290218048,
#    2026,
#    0.11127588290218048,
#    2026,
#    0.11127588290218048,
#    2026,
#    0.11127588290218048,
#    2026,
#    0.11127588290218048,
#    2026,
#    0.11127588290218048,
#    2026,
#    0.11127588290218048)]}

# %%
df['cluster_marks'] = kmeans.labels_

df_cluster_0 = df.loc[df['cluster_marks'] == 0]
df_cluster_1 = df.loc[df['cluster_marks'] == 1]
df_cluster_2 = df.loc[df['cluster_marks'] == 2]
df_cluster_3 = df.loc[df['cluster_marks'] == 3]

show_position_percentige_per_cluster(df_cluster_0, 0, len(df))
show_position_percentige_per_cluster(df_cluster_1, 1, len(df))
show_position_percentige_per_cluster(df_cluster_2, 2, len(df))
show_position_percentige_per_cluster(df_cluster_3, 3, len(df))
# Out:
# Broj igraca u klasteru 0: 4753, (26.105344098423682 %)
#
# NAPAD: 2542 (53.482011361245526 %)
# Broj igraca na poziciji RF: 5, (0.1051967178624027 %)
# Broj igraca na poziciji LF: 7, (0.14727540500736377 %)
# Broj igraca na poziciji RW: 248, (5.217757205975174 %)
# Broj igraca na poziciji LW: 260, (5.47022932884494 %)
# Broj igraca na poziciji ST: 1716, (36.103513570376606 %)
# Broj igraca na poziciji CF: 50, (1.0519671786240268 %)
# Broj igraca na poziciji RS: 128, (2.6930359772775088 %)
# Broj igraca na poziciji LS: 128, (2.6930359772775088 %)
#
# VEZNI RED: 2173 (45.71849358300021 %)
# Broj igraca na poziciji RDM: 11, (0.23143277929728595 %)
# Broj igraca na poziciji CDM: 7, (0.14727540500736377 %)
# Broj igraca na poziciji LDM: 10, (0.2103934357248054 %)
# Broj igraca na poziciji RM: 624, (13.128550389227856 %)
# Broj igraca na poziciji RCM: 34, (0.7153376814643384 %)
# Broj igraca na poziciji CM: 305, (6.416999789606565 %)
# Broj igraca na poziciji LCM: 40, (0.8415737428992216 %)
# Broj igraca na poziciji LM: 621, (13.065432358510416 %)
# Broj igraca na poziciji RAM: 2, (0.042078687144961074 %)
# Broj igraca na poziciji CAM: 511, (10.751104565537556 %)
# Broj igraca na poziciji LAM: 8, (0.1683147485798443 %)
#
# ODBRANA: 38 (0.7994950557542605 %)
# Broj igraca na poziciji RWB: 5, (0.1051967178624027 %)
# Broj igraca na poziciji RB: 10, (0.2103934357248054 %)
# Broj igraca na poziciji RCB: 1, (0.021039343572480537 %)
# Broj igraca na poziciji CB: 3, (0.06311803071744161 %)
# Broj igraca na poziciji LCB: 1, (0.021039343572480537 %)
# Broj igraca na poziciji LB: 14, (0.29455081001472755 %)
# Broj igraca na poziciji LWB: 4, (0.08415737428992215 %)
#
# GOLMANI: 0 (0.0 %)
#
# Broj igraca u klasteru 1: 5537, (30.411380238369855 %)
#
# NAPAD: 862 (15.567997110348564 %)
# Broj igraca na poziciji RF: 11, (0.19866353621094454 %)
# Broj igraca na poziciji LF: 8, (0.14448257178977786 %)
# Broj igraca na poziciji RW: 119, (2.1491782553729455 %)
# Broj igraca na poziciji LW: 117, (2.113057612425501 %)
# Broj igraca na poziciji ST: 429, (7.747877912226837 %)
# Broj igraca na poziciji CF: 24, (0.4334477153693336 %)
# Broj igraca na poziciji RS: 75, (1.3545241105291674 %)
# Broj igraca na poziciji LS: 79, (1.4267653964240563 %)
#
# VEZNI RED: 3255 (58.78634639696586 %)
# Broj igraca na poziciji RDM: 169, (3.052194329059057 %)
# Broj igraca na poziciji CDM: 417, (7.531154054542171 %)
# Broj igraca na poziciji LDM: 151, (2.727108542532057 %)
# Broj igraca na poziciji RM: 443, (8.000722412858948 %)
# Broj igraca na poziciji RCM: 281, (5.074950334115947 %)
# Broj igraca na poziciji CM: 640, (11.558605743182229 %)
# Broj igraca na poziciji LCM: 281, (5.074950334115947 %)
# Broj igraca na poziciji LM: 424, (7.657576304858226 %)
# Broj igraca na poziciji RAM: 18, (0.32508578652700015 %)
# Broj igraca na poziciji CAM: 418, (7.549214376015893 %)
# Broj igraca na poziciji LAM: 13, (0.23478417915838903 %)
#
# ODBRANA: 1420 (25.64565649268557 %)
# Broj igraca na poziciji RWB: 35, (0.6321112515802781 %)
# Broj igraca na poziciji RB: 499, (9.012100415387394 %)
# Broj igraca na poziciji RCB: 91, (1.643489254108723 %)
# Broj igraca na poziciji CB: 136, (2.456203720426224 %)
# Broj igraca na poziciji LCB: 97, (1.7518511829510566 %)
# Broj igraca na poziciji LB: 525, (9.481668773704172 %)
# Broj igraca na poziciji LWB: 37, (0.6682318945277226 %)
#
# GOLMANI: 0 (0.0 %)
#
# Broj igraca u klasteru 2: 2026, (11.127588290218048 %)
#
# NAPAD: 1 (0.04935834155972359 %)
# Broj igraca na poziciji RF: 0, (0.0 %)
# Broj igraca na poziciji LF: 0, (0.0 %)
# Broj igraca na poziciji RW: 0, (0.0 %)
# Broj igraca na poziciji LW: 0, (0.0 %)
# Broj igraca na poziciji ST: 1, (0.04935834155972359 %)
# Broj igraca na poziciji CF: 0, (0.0 %)
# Broj igraca na poziciji RS: 0, (0.0 %)
# Broj igraca na poziciji LS: 0, (0.0 %)
#
# VEZNI RED: 0 (0.0 %)
# Broj igraca na poziciji RDM: 0, (0.0 %)
# Broj igraca na poziciji CDM: 0, (0.0 %)
# Broj igraca na poziciji LDM: 0, (0.0 %)
# Broj igraca na poziciji RM: 0, (0.0 %)
# Broj igraca na poziciji RCM: 0, (0.0 %)
# Broj igraca na poziciji CM: 0, (0.0 %)
# Broj igraca na poziciji LCM: 0, (0.0 %)
# Broj igraca na poziciji LM: 0, (0.0 %)
# Broj igraca na poziciji RAM: 0, (0.0 %)
# Broj igraca na poziciji CAM: 0, (0.0 %)
# Broj igraca na poziciji LAM: 0, (0.0 %)
#
# ODBRANA: 0 (0.0 %)
# Broj igraca na poziciji RWB: 0, (0.0 %)
# Broj igraca na poziciji RB: 0, (0.0 %)
# Broj igraca na poziciji RCB: 0, (0.0 %)
# Broj igraca na poziciji CB: 0, (0.0 %)
# Broj igraca na poziciji LCB: 0, (0.0 %)
# Broj igraca na poziciji LB: 0, (0.0 %)
# Broj igraca na poziciji LWB: 0, (0.0 %)
#
# GOLMANI: 2025 (99.95064165844028 %)
#
# Broj igraca u klasteru 3: 5891, (32.35568737298841 %)
#
# NAPAD: 73 (1.2391784077406214 %)
# Broj igraca na poziciji RF: 0, (0.0 %)
# Broj igraca na poziciji LF: 0, (0.0 %)
# Broj igraca na poziciji RW: 3, (0.05092514004413513 %)
# Broj igraca na poziciji LW: 4, (0.0679001867255135 %)
# Broj igraca na poziciji ST: 66, (1.1203530809709725 %)
# Broj igraca na poziciji CF: 0, (0.0 %)
# Broj igraca na poziciji RS: 0, (0.0 %)
# Broj igraca na poziciji LS: 0, (0.0 %)
#
# VEZNI RED: 1410 (23.93481582074351 %)
# Broj igraca na poziciji RDM: 68, (1.1543031743337295 %)
# Broj igraca na poziciji CDM: 524, (8.894924461042269 %)
# Broj igraca na poziciji LDM: 82, (1.3919538278730266 %)
# Broj igraca na poziciji RM: 57, (0.9675776608385672 %)
# Broj igraca na poziciji RCM: 76, (1.2901035477847564 %)
# Broj igraca na poziciji CM: 449, (7.62179595993889 %)
# Broj igraca na poziciji LCM: 74, (1.2561534544219997 %)
# Broj igraca na poziciji LM: 50, (0.8487523340689187 %)
# Broj igraca na poziciji RAM: 1, (0.016975046681378374 %)
# Broj igraca na poziciji CAM: 29, (0.49227635375997286 %)
# Broj igraca na poziciji LAM: 0, (0.0 %)
#
# ODBRANA: 4408 (74.82600577151587 %)
# Broj igraca na poziciji RWB: 47, (0.7978271940247836 %)
# Broj igraca na poziciji RB: 782, (13.274486504837887 %)
# Broj igraca na poziciji RCB: 570, (9.675776608385673 %)
# Broj igraca na poziciji CB: 1639, (27.822101510779156 %)
# Broj igraca na poziciji LCB: 550, (9.336275674758106 %)
# Broj igraca na poziciji LB: 783, (13.291461551519268 %)
# Broj igraca na poziciji LWB: 37, (0.6280767272109998 %)
#
# GOLMANI: 0 (0.0 %)

# %%
# Dalje, ukoliko znamo da se svaka pozicija (odbrana, vezni red i napad) moze podeliti na...
# ... podpozicije, dolazimo na 27 razlicitih podpozicija
# Pokusati za k=27

kmeans = KMeans(n_clusters=27, random_state=0)
kmeans.fit(df[numeric])
kmeans.labels_

count = Counter(kmeans.labels_)
number_and_percentige_per_cluster = {}

for value, times in count.most_common():
    d[value] = [times, (times / len(df)) * 100]
number_and_percentige_per_cluster
# Out:
# {11: [1048, 5.756027901356621],
#  24: [1000, 5.49239303564563],
#  23: [935, 5.135387488328664],
#  2: [903, 4.959630911188005],
#  6: [901, 4.9486461251167135],
#  3: [880, 4.833305871368155],
#  8: [865, 4.750919975833471],
#  15: [858, 4.712473224583951],
#  0: [824, 4.525731861372],
#  12: [709, 3.8941066622727525],
#  19: [706, 3.8776294831658156],
#  21: [698, 3.8336903388806505],
#  18: [673, 3.6963805129895095],
#  7: [670, 3.6799033338825726],
#  26: [667, 3.6634261547756357],
#  4: [624, 3.4272532542428733],
#  20: [614, 3.3723293238864174],
#  13: [532, 2.9219530949634756],
#  10: [527, 2.8944911297852474],
#  22: [526, 2.8889987367496017],
#  1: [484, 2.6583182292524854],
#  25: [480, 2.636348657109903],
#  9: [462, 2.5374855824682814],
#  17: [458, 2.515516010325699],
#  16: [402, 2.2079420003295436],
#  5: [401, 2.202449607293898],
#  14: [360, 1.9772614928324272]}

# %%
df['cluster_marks'] = kmeans.labels_

df_cluster_0 = df.loc[df['cluster_marks'] == 0]
df_cluster_1 = df.loc[df['cluster_marks'] == 1]
df_cluster_2 = df.loc[df['cluster_marks'] == 2]
df_cluster_3 = df.loc[df['cluster_marks'] == 3]
df_cluster_4 = df.loc[df['cluster_marks'] == 4]
df_cluster_5 = df.loc[df['cluster_marks'] == 5]
df_cluster_6 = df.loc[df['cluster_marks'] == 6]
df_cluster_7 = df.loc[df['cluster_marks'] == 7]
df_cluster_8 = df.loc[df['cluster_marks'] == 8]
df_cluster_9 = df.loc[df['cluster_marks'] == 9]
df_cluster_10 = df.loc[df['cluster_marks'] == 10]
df_cluster_11 = df.loc[df['cluster_marks'] == 11]
df_cluster_12 = df.loc[df['cluster_marks'] == 12]
df_cluster_13 = df.loc[df['cluster_marks'] == 13]
df_cluster_14 = df.loc[df['cluster_marks'] == 14]
df_cluster_15 = df.loc[df['cluster_marks'] == 15]
df_cluster_16 = df.loc[df['cluster_marks'] == 16]
df_cluster_17 = df.loc[df['cluster_marks'] == 17]
df_cluster_18 = df.loc[df['cluster_marks'] == 18]
df_cluster_19 = df.loc[df['cluster_marks'] == 19]
df_cluster_20 = df.loc[df['cluster_marks'] == 20]
df_cluster_21 = df.loc[df['cluster_marks'] == 21]
df_cluster_22 = df.loc[df['cluster_marks'] == 22]
df_cluster_23 = df.loc[df['cluster_marks'] == 23]
df_cluster_24 = df.loc[df['cluster_marks'] == 24]
df_cluster_25 = df.loc[df['cluster_marks'] == 25]
df_cluster_26 = df.loc[df['cluster_marks'] == 26]

show_position_percentige_per_cluster(df_cluster_0, 0, len(df))
show_position_percentige_per_cluster(df_cluster_1, 1, len(df))
show_position_percentige_per_cluster(df_cluster_2, 2, len(df))
show_position_percentige_per_cluster(df_cluster_3, 3, len(df))
show_position_percentige_per_cluster(df_cluster_4, 4, len(df))
show_position_percentige_per_cluster(df_cluster_5, 5, len(df))
show_position_percentige_per_cluster(df_cluster_6, 6, len(df))
show_position_percentige_per_cluster(df_cluster_7, 7, len(df))
show_position_percentige_per_cluster(df_cluster_8, 8, len(df))
show_position_percentige_per_cluster(df_cluster_9, 9, len(df))
show_position_percentige_per_cluster(df_cluster_10, 10, len(df))
show_position_percentige_per_cluster(df_cluster_11, 11, len(df))
show_position_percentige_per_cluster(df_cluster_12, 12, len(df))
show_position_percentige_per_cluster(df_cluster_13, 13, len(df))
show_position_percentige_per_cluster(df_cluster_14, 14, len(df))
show_position_percentige_per_cluster(df_cluster_15, 15, len(df))
show_position_percentige_per_cluster(df_cluster_16, 16, len(df))
show_position_percentige_per_cluster(df_cluster_17, 17, len(df))
show_position_percentige_per_cluster(df_cluster_18, 18, len(df))
show_position_percentige_per_cluster(df_cluster_19, 19, len(df))
show_position_percentige_per_cluster(df_cluster_20, 20, len(df))
show_position_percentige_per_cluster(df_cluster_21, 12, len(df))
show_position_percentige_per_cluster(df_cluster_22, 22, len(df))
show_position_percentige_per_cluster(df_cluster_23, 23, len(df))
show_position_percentige_per_cluster(df_cluster_24, 24, len(df))
show_position_percentige_per_cluster(df_cluster_24, 25, len(df))
show_position_percentige_per_cluster(df_cluster_26, 26, len(df))
# Out:
# Broj igraca u klasteru 0: 824, (4.525731861372 %)
#
# NAPAD: 1 (0.12135922330097086 %)
# Broj igraca na poziciji RF: 0, (0.0 %)
# Broj igraca na poziciji LF: 0, (0.0 %)
# Broj igraca na poziciji RW: 0, (0.0 %)
# Broj igraca na poziciji LW: 0, (0.0 %)
# Broj igraca na poziciji ST: 1, (0.12135922330097086 %)
# Broj igraca na poziciji CF: 0, (0.0 %)
# Broj igraca na poziciji RS: 0, (0.0 %)
# Broj igraca na poziciji LS: 0, (0.0 %)
#
# VEZNI RED: 0 (0.0 %)
# Broj igraca na poziciji RDM: 0, (0.0 %)
# Broj igraca na poziciji CDM: 0, (0.0 %)
# Broj igraca na poziciji LDM: 0, (0.0 %)
# Broj igraca na poziciji RM: 0, (0.0 %)
# Broj igraca na poziciji RCM: 0, (0.0 %)
# Broj igraca na poziciji CM: 0, (0.0 %)
# Broj igraca na poziciji LCM: 0, (0.0 %)
# Broj igraca na poziciji LM: 0, (0.0 %)
# Broj igraca na poziciji RAM: 0, (0.0 %)
# Broj igraca na poziciji CAM: 0, (0.0 %)
# Broj igraca na poziciji LAM: 0, (0.0 %)
#
# ODBRANA: 0 (0.0 %)
# Broj igraca na poziciji RWB: 0, (0.0 %)
# Broj igraca na poziciji RB: 0, (0.0 %)
# Broj igraca na poziciji RCB: 0, (0.0 %)
# Broj igraca na poziciji CB: 0, (0.0 %)
# Broj igraca na poziciji LCB: 0, (0.0 %)
# Broj igraca na poziciji LB: 0, (0.0 %)
# Broj igraca na poziciji LWB: 0, (0.0 %)
#
# GOLMANI: 823 (99.87864077669903 %)
#
# Broj igraca u klasteru 1: 484, (2.6583182292524854 %)
#
# NAPAD: 0 (0.0 %)
# Broj igraca na poziciji RF: 0, (0.0 %)
# Broj igraca na poziciji LF: 0, (0.0 %)
# Broj igraca na poziciji RW: 0, (0.0 %)
# Broj igraca na poziciji LW: 0, (0.0 %)
# Broj igraca na poziciji ST: 0, (0.0 %)
# Broj igraca na poziciji CF: 0, (0.0 %)
# Broj igraca na poziciji RS: 0, (0.0 %)
# Broj igraca na poziciji LS: 0, (0.0 %)
#
# VEZNI RED: 109 (22.520661157024794 %)
# Broj igraca na poziciji RDM: 25, (5.1652892561983474 %)
# Broj igraca na poziciji CDM: 50, (10.330578512396695 %)
# Broj igraca na poziciji LDM: 19, (3.925619834710744 %)
# Broj igraca na poziciji RM: 0, (0.0 %)
# Broj igraca na poziciji RCM: 3, (0.6198347107438017 %)
# Broj igraca na poziciji CM: 2, (0.4132231404958678 %)
# Broj igraca na poziciji LCM: 9, (1.859504132231405 %)
# Broj igraca na poziciji LM: 1, (0.2066115702479339 %)
# Broj igraca na poziciji RAM: 0, (0.0 %)
# Broj igraca na poziciji CAM: 0, (0.0 %)
# Broj igraca na poziciji LAM: 0, (0.0 %)
#
# ODBRANA: 375 (77.47933884297521 %)
# Broj igraca na poziciji RWB: 2, (0.4132231404958678 %)
# Broj igraca na poziciji RB: 12, (2.479338842975207 %)
# Broj igraca na poziciji RCB: 107, (22.107438016528928 %)
# Broj igraca na poziciji CB: 138, (28.512396694214875 %)
# Broj igraca na poziciji LCB: 100, (20.66115702479339 %)
# Broj igraca na poziciji LB: 16, (3.3057851239669422 %)
# Broj igraca na poziciji LWB: 0, (0.0 %)
#
# GOLMANI: 0 (0.0 %)
#
# Broj igraca u klasteru 2: 903, (4.959630911188005 %)
#
# NAPAD: 1 (0.11074197120708748 %)
# Broj igraca na poziciji RF: 0, (0.0 %)
# Broj igraca na poziciji LF: 0, (0.0 %)
# Broj igraca na poziciji RW: 0, (0.0 %)
# Broj igraca na poziciji LW: 0, (0.0 %)
# Broj igraca na poziciji ST: 1, (0.11074197120708748 %)
# Broj igraca na poziciji CF: 0, (0.0 %)
# Broj igraca na poziciji RS: 0, (0.0 %)
# Broj igraca na poziciji LS: 0, (0.0 %)
#
# VEZNI RED: 163 (18.05094130675526 %)
# Broj igraca na poziciji RDM: 10, (1.1074197120708749 %)
# Broj igraca na poziciji CDM: 94, (10.409745293466225 %)
# Broj igraca na poziciji LDM: 8, (0.8859357696566998 %)
# Broj igraca na poziciji RM: 10, (1.1074197120708749 %)
# Broj igraca na poziciji RCM: 7, (0.7751937984496124 %)
# Broj igraca na poziciji CM: 19, (2.104097452934662 %)
# Broj igraca na poziciji LCM: 7, (0.7751937984496124 %)
# Broj igraca na poziciji LM: 8, (0.8859357696566998 %)
# Broj igraca na poziciji RAM: 0, (0.0 %)
# Broj igraca na poziciji CAM: 0, (0.0 %)
# Broj igraca na poziciji LAM: 0, (0.0 %)
#
# ODBRANA: 739 (81.83831672203765 %)
# Broj igraca na poziciji RWB: 14, (1.550387596899225 %)
# Broj igraca na poziciji RB: 267, (29.568106312292358 %)
# Broj igraca na poziciji RCB: 38, (4.208194905869324 %)
# Broj igraca na poziciji CB: 135, (14.950166112956811 %)
# Broj igraca na poziciji LCB: 30, (3.322259136212625 %)
# Broj igraca na poziciji LB: 241, (26.688815060908084 %)
# Broj igraca na poziciji LWB: 14, (1.550387596899225 %)
#
# GOLMANI: 0 (0.0 %)
#
# Broj igraca u klasteru 3: 880, (4.833305871368155 %)
#
# NAPAD: 268 (30.454545454545457 %)
# Broj igraca na poziciji RF: 1, (0.11363636363636363 %)
# Broj igraca na poziciji LF: 3, (0.3409090909090909 %)
# Broj igraca na poziciji RW: 89, (10.113636363636363 %)
# Broj igraca na poziciji LW: 98, (11.136363636363637 %)
# Broj igraca na poziciji ST: 54, (6.136363636363637 %)
# Broj igraca na poziciji CF: 9, (1.0227272727272727 %)
# Broj igraca na poziciji RS: 9, (1.0227272727272727 %)
# Broj igraca na poziciji LS: 5, (0.5681818181818182 %)
#
# VEZNI RED: 612 (69.54545454545455 %)
# Broj igraca na poziciji RDM: 2, (0.22727272727272727 %)
# Broj igraca na poziciji CDM: 0, (0.0 %)
# Broj igraca na poziciji LDM: 2, (0.22727272727272727 %)
# Broj igraca na poziciji RM: 218, (24.772727272727273 %)
# Broj igraca na poziciji RCM: 4, (0.45454545454545453 %)
# Broj igraca na poziciji CM: 15, (1.7045454545454544 %)
# Broj igraca na poziciji LCM: 8, (0.9090909090909091 %)
# Broj igraca na poziciji LM: 201, (22.840909090909093 %)
# Broj igraca na poziciji RAM: 2, (0.22727272727272727 %)
# Broj igraca na poziciji CAM: 159, (18.06818181818182 %)
# Broj igraca na poziciji LAM: 1, (0.11363636363636363 %)
#
# ODBRANA: 0 (0.0 %)
# Broj igraca na poziciji RWB: 0, (0.0 %)
# Broj igraca na poziciji RB: 0, (0.0 %)
# Broj igraca na poziciji RCB: 0, (0.0 %)
# Broj igraca na poziciji CB: 0, (0.0 %)
# Broj igraca na poziciji LCB: 0, (0.0 %)
# Broj igraca na poziciji LB: 0, (0.0 %)
# Broj igraca na poziciji LWB: 0, (0.0 %)
#
# GOLMANI: 0 (0.0 %)
#
# Broj igraca u klasteru 4: 624, (3.4272532542428733 %)
#
# NAPAD: 0 (0.0 %)
# Broj igraca na poziciji RF: 0, (0.0 %)
# Broj igraca na poziciji LF: 0, (0.0 %)
# Broj igraca na poziciji RW: 0, (0.0 %)
# Broj igraca na poziciji LW: 0, (0.0 %)
# Broj igraca na poziciji ST: 0, (0.0 %)
# Broj igraca na poziciji CF: 0, (0.0 %)
# Broj igraca na poziciji RS: 0, (0.0 %)
# Broj igraca na poziciji LS: 0, (0.0 %)
#
# VEZNI RED: 29 (4.647435897435898 %)
# Broj igraca na poziciji RDM: 4, (0.641025641025641 %)
# Broj igraca na poziciji CDM: 16, (2.564102564102564 %)
# Broj igraca na poziciji LDM: 5, (0.8012820512820512 %)
# Broj igraca na poziciji RM: 0, (0.0 %)
# Broj igraca na poziciji RCM: 1, (0.16025641025641024 %)
# Broj igraca na poziciji CM: 1, (0.16025641025641024 %)
# Broj igraca na poziciji LCM: 2, (0.3205128205128205 %)
# Broj igraca na poziciji LM: 0, (0.0 %)
# Broj igraca na poziciji RAM: 0, (0.0 %)
# Broj igraca na poziciji CAM: 0, (0.0 %)
# Broj igraca na poziciji LAM: 0, (0.0 %)
#
# ODBRANA: 595 (95.3525641025641 %)
# Broj igraca na poziciji RWB: 0, (0.0 %)
# Broj igraca na poziciji RB: 19, (3.0448717948717947 %)
# Broj igraca na poziciji RCB: 158, (25.320512820512818 %)
# Broj igraca na poziciji CB: 254, (40.705128205128204 %)
# Broj igraca na poziciji LCB: 152, (24.358974358974358 %)
# Broj igraca na poziciji LB: 12, (1.9230769230769231 %)
# Broj igraca na poziciji LWB: 0, (0.0 %)
#
# GOLMANI: 0 (0.0 %)
#
# Broj igraca u klasteru 5: 401, (2.202449607293898 %)
#
# NAPAD: 389 (97.0074812967581 %)
# Broj igraca na poziciji RF: 0, (0.0 %)
# Broj igraca na poziciji LF: 0, (0.0 %)
# Broj igraca na poziciji RW: 3, (0.7481296758104738 %)
# Broj igraca na poziciji LW: 2, (0.4987531172069825 %)
# Broj igraca na poziciji ST: 323, (80.54862842892769 %)
# Broj igraca na poziciji CF: 3, (0.7481296758104738 %)
# Broj igraca na poziciji RS: 27, (6.733167082294264 %)
# Broj igraca na poziciji LS: 31, (7.73067331670823 %)
#
# VEZNI RED: 12 (2.9925187032418954 %)
# Broj igraca na poziciji RDM: 0, (0.0 %)
# Broj igraca na poziciji CDM: 0, (0.0 %)
# Broj igraca na poziciji LDM: 0, (0.0 %)
# Broj igraca na poziciji RM: 3, (0.7481296758104738 %)
# Broj igraca na poziciji RCM: 2, (0.4987531172069825 %)
# Broj igraca na poziciji CM: 0, (0.0 %)
# Broj igraca na poziciji LCM: 0, (0.0 %)
# Broj igraca na poziciji LM: 4, (0.997506234413965 %)
# Broj igraca na poziciji RAM: 0, (0.0 %)
# Broj igraca na poziciji CAM: 3, (0.7481296758104738 %)
# Broj igraca na poziciji LAM: 0, (0.0 %)
#
# ODBRANA: 0 (0.0 %)
# Broj igraca na poziciji RWB: 0, (0.0 %)
# Broj igraca na poziciji RB: 0, (0.0 %)
# Broj igraca na poziciji RCB: 0, (0.0 %)
# Broj igraca na poziciji CB: 0, (0.0 %)
# Broj igraca na poziciji LCB: 0, (0.0 %)
# Broj igraca na poziciji LB: 0, (0.0 %)
# Broj igraca na poziciji LWB: 0, (0.0 %)
#
# GOLMANI: 0 (0.0 %)
#
# Broj igraca u klasteru 6: 901, (4.9486461251167135 %)
#
# NAPAD: 256 (28.412874583795784 %)
# Broj igraca na poziciji RF: 3, (0.3329633740288568 %)
# Broj igraca na poziciji LF: 3, (0.3329633740288568 %)
# Broj igraca na poziciji RW: 82, (9.100998890122087 %)
# Broj igraca na poziciji LW: 82, (9.100998890122087 %)
# Broj igraca na poziciji ST: 48, (5.3274139844617086 %)
# Broj igraca na poziciji CF: 11, (1.2208657047724751 %)
# Broj igraca na poziciji RS: 14, (1.553829078801332 %)
# Broj igraca na poziciji LS: 13, (1.4428412874583796 %)
#
# VEZNI RED: 643 (71.36514983351832 %)
# Broj igraca na poziciji RDM: 4, (0.4439511653718091 %)
# Broj igraca na poziciji CDM: 0, (0.0 %)
# Broj igraca na poziciji LDM: 1, (0.11098779134295228 %)
# Broj igraca na poziciji RM: 186, (20.643729189789124 %)
# Broj igraca na poziciji RCM: 9, (0.9988901220865706 %)
# Broj igraca na poziciji CM: 8, (0.8879023307436182 %)
# Broj igraca na poziciji LCM: 21, (2.3307436182019976 %)
# Broj igraca na poziciji LM: 208, (23.085460599334073 %)
# Broj igraca na poziciji RAM: 13, (1.4428412874583796 %)
# Broj igraca na poziciji CAM: 180, (19.97780244173141 %)
# Broj igraca na poziciji LAM: 13, (1.4428412874583796 %)
#
# ODBRANA: 2 (0.22197558268590456 %)
# Broj igraca na poziciji RWB: 0, (0.0 %)
# Broj igraca na poziciji RB: 0, (0.0 %)
# Broj igraca na poziciji RCB: 0, (0.0 %)
# Broj igraca na poziciji CB: 0, (0.0 %)
# Broj igraca na poziciji LCB: 0, (0.0 %)
# Broj igraca na poziciji LB: 1, (0.11098779134295228 %)
# Broj igraca na poziciji LWB: 1, (0.11098779134295228 %)
#
# GOLMANI: 0 (0.0 %)
#
# Broj igraca u klasteru 7: 670, (3.6799033338825726 %)
#
# NAPAD: 0 (0.0 %)
# Broj igraca na poziciji RF: 0, (0.0 %)
# Broj igraca na poziciji LF: 0, (0.0 %)
# Broj igraca na poziciji RW: 0, (0.0 %)
# Broj igraca na poziciji LW: 0, (0.0 %)
# Broj igraca na poziciji ST: 0, (0.0 %)
# Broj igraca na poziciji CF: 0, (0.0 %)
# Broj igraca na poziciji RS: 0, (0.0 %)
# Broj igraca na poziciji LS: 0, (0.0 %)
#
# VEZNI RED: 0 (0.0 %)
# Broj igraca na poziciji RDM: 0, (0.0 %)
# Broj igraca na poziciji CDM: 0, (0.0 %)
# Broj igraca na poziciji LDM: 0, (0.0 %)
# Broj igraca na poziciji RM: 0, (0.0 %)
# Broj igraca na poziciji RCM: 0, (0.0 %)
# Broj igraca na poziciji CM: 0, (0.0 %)
# Broj igraca na poziciji LCM: 0, (0.0 %)
# Broj igraca na poziciji LM: 0, (0.0 %)
# Broj igraca na poziciji RAM: 0, (0.0 %)
# Broj igraca na poziciji CAM: 0, (0.0 %)
# Broj igraca na poziciji LAM: 0, (0.0 %)
#
# ODBRANA: 0 (0.0 %)
# Broj igraca na poziciji RWB: 0, (0.0 %)
# Broj igraca na poziciji RB: 0, (0.0 %)
# Broj igraca na poziciji RCB: 0, (0.0 %)
# Broj igraca na poziciji CB: 0, (0.0 %)
# Broj igraca na poziciji LCB: 0, (0.0 %)
# Broj igraca na poziciji LB: 0, (0.0 %)
# Broj igraca na poziciji LWB: 0, (0.0 %)
#
# GOLMANI: 670 (100.0 %)
#
# Broj igraca u klasteru 8: 865, (4.750919975833471 %)
#
# NAPAD: 7 (0.8092485549132947 %)
# Broj igraca na poziciji RF: 0, (0.0 %)
# Broj igraca na poziciji LF: 0, (0.0 %)
# Broj igraca na poziciji RW: 4, (0.46242774566473993 %)
# Broj igraca na poziciji LW: 2, (0.23121387283236997 %)
# Broj igraca na poziciji ST: 0, (0.0 %)
# Broj igraca na poziciji CF: 0, (0.0 %)
# Broj igraca na poziciji RS: 1, (0.11560693641618498 %)
# Broj igraca na poziciji LS: 0, (0.0 %)
#
# VEZNI RED: 252 (29.132947976878615 %)
# Broj igraca na poziciji RDM: 17, (1.9653179190751446 %)
# Broj igraca na poziciji CDM: 93, (10.751445086705203 %)
# Broj igraca na poziciji LDM: 18, (2.0809248554913293 %)
# Broj igraca na poziciji RM: 23, (2.6589595375722546 %)
# Broj igraca na poziciji RCM: 25, (2.8901734104046244 %)
# Broj igraca na poziciji CM: 44, (5.086705202312139 %)
# Broj igraca na poziciji LCM: 18, (2.0809248554913293 %)
# Broj igraca na poziciji LM: 11, (1.2716763005780347 %)
# Broj igraca na poziciji RAM: 1, (0.11560693641618498 %)
# Broj igraca na poziciji CAM: 2, (0.23121387283236997 %)
# Broj igraca na poziciji LAM: 0, (0.0 %)
#
# ODBRANA: 606 (70.05780346820809 %)
# Broj igraca na poziciji RWB: 12, (1.3872832369942196 %)
# Broj igraca na poziciji RB: 285, (32.947976878612714 %)
# Broj igraca na poziciji RCB: 14, (1.6184971098265895 %)
# Broj igraca na poziciji CB: 22, (2.5433526011560694 %)
# Broj igraca na poziciji LCB: 13, (1.5028901734104045 %)
# Broj igraca na poziciji LB: 249, (28.78612716763006 %)
# Broj igraca na poziciji LWB: 11, (1.2716763005780347 %)
#
# GOLMANI: 0 (0.0 %)
#
# Broj igraca u klasteru 9: 462, (2.5374855824682814 %)
#
# NAPAD: 1 (0.21645021645021645 %)
# Broj igraca na poziciji RF: 0, (0.0 %)
# Broj igraca na poziciji LF: 0, (0.0 %)
# Broj igraca na poziciji RW: 0, (0.0 %)
# Broj igraca na poziciji LW: 0, (0.0 %)
# Broj igraca na poziciji ST: 1, (0.21645021645021645 %)
# Broj igraca na poziciji CF: 0, (0.0 %)
# Broj igraca na poziciji RS: 0, (0.0 %)
# Broj igraca na poziciji LS: 0, (0.0 %)
#
# VEZNI RED: 34 (7.35930735930736 %)
# Broj igraca na poziciji RDM: 4, (0.8658008658008658 %)
# Broj igraca na poziciji CDM: 23, (4.978354978354979 %)
# Broj igraca na poziciji LDM: 2, (0.4329004329004329 %)
# Broj igraca na poziciji RM: 0, (0.0 %)
# Broj igraca na poziciji RCM: 3, (0.6493506493506493 %)
# Broj igraca na poziciji CM: 1, (0.21645021645021645 %)
# Broj igraca na poziciji LCM: 1, (0.21645021645021645 %)
# Broj igraca na poziciji LM: 0, (0.0 %)
# Broj igraca na poziciji RAM: 0, (0.0 %)
# Broj igraca na poziciji CAM: 0, (0.0 %)
# Broj igraca na poziciji LAM: 0, (0.0 %)
#
# ODBRANA: 427 (92.42424242424242 %)
# Broj igraca na poziciji RWB: 0, (0.0 %)
# Broj igraca na poziciji RB: 4, (0.8658008658008658 %)
# Broj igraca na poziciji RCB: 112, (24.242424242424242 %)
# Broj igraca na poziciji CB: 205, (44.37229437229438 %)
# Broj igraca na poziciji LCB: 103, (22.294372294372295 %)
# Broj igraca na poziciji LB: 3, (0.6493506493506493 %)
# Broj igraca na poziciji LWB: 0, (0.0 %)
#
# GOLMANI: 0 (0.0 %)
#
# Broj igraca u klasteru 10: 527, (2.8944911297852474 %)
#
# NAPAD: 466 (88.42504743833017 %)
# Broj igraca na poziciji RF: 0, (0.0 %)
# Broj igraca na poziciji LF: 1, (0.18975332068311196 %)
# Broj igraca na poziciji RW: 10, (1.8975332068311195 %)
# Broj igraca na poziciji LW: 6, (1.1385199240986716 %)
# Broj igraca na poziciji ST: 333, (63.18785578747628 %)
# Broj igraca na poziciji CF: 4, (0.7590132827324478 %)
# Broj igraca na poziciji RS: 56, (10.62618595825427 %)
# Broj igraca na poziciji LS: 56, (10.62618595825427 %)
#
# VEZNI RED: 61 (11.57495256166983 %)
# Broj igraca na poziciji RDM: 0, (0.0 %)
# Broj igraca na poziciji CDM: 0, (0.0 %)
# Broj igraca na poziciji LDM: 0, (0.0 %)
# Broj igraca na poziciji RM: 18, (3.415559772296015 %)
# Broj igraca na poziciji RCM: 0, (0.0 %)
# Broj igraca na poziciji CM: 0, (0.0 %)
# Broj igraca na poziciji LCM: 0, (0.0 %)
# Broj igraca na poziciji LM: 20, (3.795066413662239 %)
# Broj igraca na poziciji RAM: 0, (0.0 %)
# Broj igraca na poziciji CAM: 22, (4.174573055028463 %)
# Broj igraca na poziciji LAM: 1, (0.18975332068311196 %)
#
# ODBRANA: 0 (0.0 %)
# Broj igraca na poziciji RWB: 0, (0.0 %)
# Broj igraca na poziciji RB: 0, (0.0 %)
# Broj igraca na poziciji RCB: 0, (0.0 %)
# Broj igraca na poziciji CB: 0, (0.0 %)
# Broj igraca na poziciji LCB: 0, (0.0 %)
# Broj igraca na poziciji LB: 0, (0.0 %)
# Broj igraca na poziciji LWB: 0, (0.0 %)
#
# GOLMANI: 0 (0.0 %)
#
# Broj igraca u klasteru 11: 1048, (5.756027901356621 %)
#
# NAPAD: 85 (8.110687022900763 %)
# Broj igraca na poziciji RF: 0, (0.0 %)
# Broj igraca na poziciji LF: 0, (0.0 %)
# Broj igraca na poziciji RW: 11, (1.049618320610687 %)
# Broj igraca na poziciji LW: 9, (0.8587786259541985 %)
# Broj igraca na poziciji ST: 58, (5.534351145038168 %)
# Broj igraca na poziciji CF: 4, (0.38167938931297707 %)
# Broj igraca na poziciji RS: 2, (0.19083969465648853 %)
# Broj igraca na poziciji LS: 1, (0.09541984732824427 %)
#
# VEZNI RED: 784 (74.80916030534351 %)
# Broj igraca na poziciji RDM: 9, (0.8587786259541985 %)
# Broj igraca na poziciji CDM: 115, (10.973282442748092 %)
# Broj igraca na poziciji LDM: 16, (1.5267175572519083 %)
# Broj igraca na poziciji RM: 58, (5.534351145038168 %)
# Broj igraca na poziciji RCM: 31, (2.9580152671755724 %)
# Broj igraca na poziciji CM: 385, (36.73664122137404 %)
# Broj igraca na poziciji LCM: 33, (3.1488549618320607 %)
# Broj igraca na poziciji LM: 62, (5.916030534351145 %)
# Broj igraca na poziciji RAM: 0, (0.0 %)
# Broj igraca na poziciji CAM: 75, (7.15648854961832 %)
# Broj igraca na poziciji LAM: 0, (0.0 %)
#
# ODBRANA: 179 (17.080152671755723 %)
# Broj igraca na poziciji RWB: 13, (1.2404580152671756 %)
# Broj igraca na poziciji RB: 62, (5.916030534351145 %)
# Broj igraca na poziciji RCB: 2, (0.19083969465648853 %)
# Broj igraca na poziciji CB: 16, (1.5267175572519083 %)
# Broj igraca na poziciji LCB: 4, (0.38167938931297707 %)
# Broj igraca na poziciji LB: 75, (7.15648854961832 %)
# Broj igraca na poziciji LWB: 7, (0.6679389312977099 %)
#
# GOLMANI: 0 (0.0 %)
#
# Broj igraca u klasteru 12: 709, (3.8941066622727525 %)
# NAPAD: 0 (0.0 %)
# Broj igraca na poziciji RF: 0, (0.0 %)
# Broj igraca na poziciji LF: 0, (0.0 %)
# Broj igraca na poziciji RW: 0, (0.0 %)
# Broj igraca na poziciji LW: 0, (0.0 %)
# Broj igraca na poziciji ST: 0, (0.0 %)
# Broj igraca na poziciji CF: 0, (0.0 %)
# Broj igraca na poziciji RS: 0, (0.0 %)
# Broj igraca na poziciji LS: 0, (0.0 %)
#
# VEZNI RED: 8 (1.1283497884344147 %)
# Broj igraca na poziciji RDM: 0, (0.0 %)
# Broj igraca na poziciji CDM: 5, (0.7052186177715092 %)
# Broj igraca na poziciji LDM: 0, (0.0 %)
# Broj igraca na poziciji RM: 0, (0.0 %)
# Broj igraca na poziciji RCM: 0, (0.0 %)
# Broj igraca na poziciji CM: 2, (0.2820874471086037 %)
# Broj igraca na poziciji LCM: 0, (0.0 %)
# Broj igraca na poziciji LM: 0, (0.0 %)
# Broj igraca na poziciji RAM: 0, (0.0 %)
# Broj igraca na poziciji CAM: 1, (0.14104372355430184 %)
# Broj igraca na poziciji LAM: 0, (0.0 %)
#
# ODBRANA: 701 (98.8716502115656 %)
# Broj igraca na poziciji RWB: 1, (0.14104372355430184 %)
# Broj igraca na poziciji RB: 8, (1.1283497884344147 %)
# Broj igraca na poziciji RCB: 133, (18.758815232722146 %)
# Broj igraca na poziciji CB: 410, (57.82792665726375 %)
# Broj igraca na poziciji LCB: 135, (19.040902679830747 %)
# Broj igraca na poziciji LB: 13, (1.8335684062059237 %)
# Broj igraca na poziciji LWB: 1, (0.14104372355430184 %)
#
# GOLMANI: 0 (0.0 %)
#
# Broj igraca u klasteru 13: 532, (2.9219530949634756 %)
#
# NAPAD: 0 (0.0 %)
# Broj igraca na poziciji RF: 0, (0.0 %)
# Broj igraca na poziciji LF: 0, (0.0 %)
# Broj igraca na poziciji RW: 0, (0.0 %)
# Broj igraca na poziciji LW: 0, (0.0 %)
# Broj igraca na poziciji ST: 0, (0.0 %)
# Broj igraca na poziciji CF: 0, (0.0 %)
# Broj igraca na poziciji RS: 0, (0.0 %)
# Broj igraca na poziciji LS: 0, (0.0 %)
#
# VEZNI RED: 0 (0.0 %)
# Broj igraca na poziciji RDM: 0, (0.0 %)
# Broj igraca na poziciji CDM: 0, (0.0 %)
# Broj igraca na poziciji LDM: 0, (0.0 %)
# Broj igraca na poziciji RM: 0, (0.0 %)
# Broj igraca na poziciji RCM: 0, (0.0 %)
# Broj igraca na poziciji CM: 0, (0.0 %)
# Broj igraca na poziciji LCM: 0, (0.0 %)
# Broj igraca na poziciji LM: 0, (0.0 %)
# Broj igraca na poziciji RAM: 0, (0.0 %)
# Broj igraca na poziciji CAM: 0, (0.0 %)
# Broj igraca na poziciji LAM: 0, (0.0 %)
#
# ODBRANA: 0 (0.0 %)
# Broj igraca na poziciji RWB: 0, (0.0 %)
# Broj igraca na poziciji RB: 0, (0.0 %)
# Broj igraca na poziciji RCB: 0, (0.0 %)
# Broj igraca na poziciji CB: 0, (0.0 %)
# Broj igraca na poziciji LCB: 0, (0.0 %)
# Broj igraca na poziciji LB: 0, (0.0 %)
# Broj igraca na poziciji LWB: 0, (0.0 %)
#
# GOLMANI: 532 (100.0 %)
#
# Broj igraca u klasteru 14: 360, (1.9772614928324272 %)
#
# NAPAD: 149 (41.388888888888886 %)
# Broj igraca na poziciji RF: 4, (1.1111111111111112 %)
# Broj igraca na poziciji LF: 5, (1.3888888888888888 %)
# Broj igraca na poziciji RW: 32, (8.88888888888889 %)
# Broj igraca na poziciji LW: 26, (7.222222222222221 %)
# Broj igraca na poziciji ST: 48, (13.333333333333334 %)
# Broj igraca na poziciji CF: 9, (2.5 %)
# Broj igraca na poziciji RS: 9, (2.5 %)
# Broj igraca na poziciji LS: 16, (4.444444444444445 %)
#
# VEZNI RED: 211 (58.611111111111114 %)
# Broj igraca na poziciji RDM: 0, (0.0 %)
# Broj igraca na poziciji CDM: 0, (0.0 %)
# Broj igraca na poziciji LDM: 3, (0.8333333333333334 %)
# Broj igraca na poziciji RM: 63, (17.5 %)
# Broj igraca na poziciji RCM: 7, (1.9444444444444444 %)
# Broj igraca na poziciji CM: 6, (1.6666666666666667 %)
# Broj igraca na poziciji LCM: 10, (2.7777777777777777 %)
# Broj igraca na poziciji LM: 56, (15.555555555555555 %)
# Broj igraca na poziciji RAM: 1, (0.2777777777777778 %)
# Broj igraca na poziciji CAM: 63, (17.5 %)
# Broj igraca na poziciji LAM: 2, (0.5555555555555556 %)
#
# ODBRANA: 0 (0.0 %)
# Broj igraca na poziciji RWB: 0, (0.0 %)
# Broj igraca na poziciji RB: 0, (0.0 %)
# Broj igraca na poziciji RCB: 0, (0.0 %)
# Broj igraca na poziciji CB: 0, (0.0 %)
# Broj igraca na poziciji LCB: 0, (0.0 %)
# Broj igraca na poziciji LB: 0, (0.0 %)
# Broj igraca na poziciji LWB: 0, (0.0 %)
#
# GOLMANI: 0 (0.0 %)
#
# Broj igraca u klasteru 15: 858, (4.712473224583951 %)
#
# NAPAD: 19 (2.2144522144522143 %)
# Broj igraca na poziciji RF: 0, (0.0 %)
# Broj igraca na poziciji LF: 0, (0.0 %)
# Broj igraca na poziciji RW: 0, (0.0 %)
# Broj igraca na poziciji LW: 2, (0.2331002331002331 %)
# Broj igraca na poziciji ST: 17, (1.9813519813519813 %)
# Broj igraca na poziciji CF: 0, (0.0 %)
# Broj igraca na poziciji RS: 0, (0.0 %)
# Broj igraca na poziciji LS: 0, (0.0 %)
#
# VEZNI RED: 432 (50.349650349650354 %)
# Broj igraca na poziciji RDM: 37, (4.312354312354312 %)
# Broj igraca na poziciji CDM: 149, (17.365967365967368 %)
# Broj igraca na poziciji LDM: 30, (3.4965034965034967 %)
# Broj igraca na poziciji RM: 12, (1.3986013986013985 %)
# Broj igraca na poziciji RCM: 47, (5.477855477855478 %)
# Broj igraca na poziciji CM: 103, (12.004662004662006 %)
# Broj igraca na poziciji LCM: 36, (4.195804195804196 %)
# Broj igraca na poziciji LM: 10, (1.1655011655011656 %)
# Broj igraca na poziciji RAM: 0, (0.0 %)
# Broj igraca na poziciji CAM: 8, (0.9324009324009324 %)
# Broj igraca na poziciji LAM: 0, (0.0 %)
#
# ODBRANA: 407 (47.43589743589743 %)
# Broj igraca na poziciji RWB: 5, (0.5827505827505828 %)
# Broj igraca na poziciji RB: 108, (12.587412587412588 %)
# Broj igraca na poziciji RCB: 36, (4.195804195804196 %)
# Broj igraca na poziciji CB: 88, (10.256410256410255 %)
# Broj igraca na poziciji LCB: 42, (4.895104895104895 %)
# Broj igraca na poziciji LB: 121, (14.102564102564102 %)
# Broj igraca na poziciji LWB: 7, (0.8158508158508158 %)
#
# GOLMANI: 0 (0.0 %)
#
# Broj igraca u klasteru 16: 402, (2.2079420003295436 %)
#
# NAPAD: 4 (0.9950248756218906 %)
# Broj igraca na poziciji RF: 0, (0.0 %)
# Broj igraca na poziciji LF: 0, (0.0 %)
# Broj igraca na poziciji RW: 1, (0.24875621890547264 %)
# Broj igraca na poziciji LW: 0, (0.0 %)
# Broj igraca na poziciji ST: 3, (0.7462686567164178 %)
# Broj igraca na poziciji CF: 0, (0.0 %)
# Broj igraca na poziciji RS: 0, (0.0 %)
# Broj igraca na poziciji LS: 0, (0.0 %)
#
# VEZNI RED: 313 (77.86069651741293 %)
# Broj igraca na poziciji RDM: 31, (7.711442786069651 %)
# Broj igraca na poziciji CDM: 84, (20.8955223880597 %)
# Broj igraca na poziciji LDM: 32, (7.960199004975125 %)
# Broj igraca na poziciji RM: 6, (1.4925373134328357 %)
# Broj igraca na poziciji RCM: 41, (10.199004975124378 %)
# Broj igraca na poziciji CM: 60, (14.925373134328357 %)
# Broj igraca na poziciji LCM: 35, (8.706467661691542 %)
# Broj igraca na poziciji LM: 4, (0.9950248756218906 %)
# Broj igraca na poziciji RAM: 0, (0.0 %)
# Broj igraca na poziciji CAM: 20, (4.975124378109453 %)
# Broj igraca na poziciji LAM: 0, (0.0 %)
#
# ODBRANA: 85 (21.144278606965177 %)
# Broj igraca na poziciji RWB: 0, (0.0 %)
# Broj igraca na poziciji RB: 18, (4.477611940298507 %)
# Broj igraca na poziciji RCB: 8, (1.9900497512437811 %)
# Broj igraca na poziciji CB: 22, (5.472636815920398 %)
# Broj igraca na poziciji LCB: 17, (4.228855721393035 %)
# Broj igraca na poziciji LB: 20, (4.975124378109453 %)
# Broj igraca na poziciji LWB: 0, (0.0 %)
#
# GOLMANI: 0 (0.0 %)
#
# Broj igraca u klasteru 17: 458, (2.515516010325699 %)
#
# NAPAD: 4 (0.8733624454148471 %)
# Broj igraca na poziciji RF: 0, (0.0 %)
# Broj igraca na poziciji LF: 0, (0.0 %)
# Broj igraca na poziciji RW: 2, (0.43668122270742354 %)
# Broj igraca na poziciji LW: 0, (0.0 %)
# Broj igraca na poziciji ST: 2, (0.43668122270742354 %)
# Broj igraca na poziciji CF: 0, (0.0 %)
# Broj igraca na poziciji RS: 0, (0.0 %)
# Broj igraca na poziciji LS: 0, (0.0 %)
#
# VEZNI RED: 309 (67.46724890829694 %)
# Broj igraca na poziciji RDM: 24, (5.240174672489083 %)
# Broj igraca na poziciji CDM: 49, (10.698689956331878 %)
# Broj igraca na poziciji LDM: 24, (5.240174672489083 %)
# Broj igraca na poziciji RM: 14, (3.056768558951965 %)
# Broj igraca na poziciji RCM: 47, (10.262008733624455 %)
# Broj igraca na poziciji CM: 76, (16.593886462882097 %)
# Broj igraca na poziciji LCM: 40, (8.73362445414847 %)
# Broj igraca na poziciji LM: 18, (3.9301310043668125 %)
# Broj igraca na poziciji RAM: 1, (0.21834061135371177 %)
# Broj igraca na poziciji CAM: 16, (3.4934497816593884 %)
# Broj igraca na poziciji LAM: 0, (0.0 %)
#
# ODBRANA: 145 (31.65938864628821 %)
# Broj igraca na poziciji RWB: 3, (0.6550218340611353 %)
# Broj igraca na poziciji RB: 55, (12.008733624454148 %)
# Broj igraca na poziciji RCB: 3, (0.6550218340611353 %)
# Broj igraca na poziciji CB: 6, (1.3100436681222707 %)
# Broj igraca na poziciji LCB: 9, (1.9650655021834063 %)
# Broj igraca na poziciji LB: 64, (13.973799126637553 %)
# Broj igraca na poziciji LWB: 5, (1.0917030567685588 %)
#
# GOLMANI: 0 (0.0 %)
#
# Broj igraca u klasteru 18: 673, (3.6963805129895095 %)
#
# NAPAD: 153 (22.73402674591382 %)
# Broj igraca na poziciji RF: 0, (0.0 %)
# Broj igraca na poziciji LF: 0, (0.0 %)
# Broj igraca na poziciji RW: 58, (8.618127786032689 %)
# Broj igraca na poziciji LW: 46, (6.8350668647845465 %)
# Broj igraca na poziciji ST: 38, (5.646359583952452 %)
# Broj igraca na poziciji CF: 9, (1.337295690936107 %)
# Broj igraca na poziciji RS: 0, (0.0 %)
# Broj igraca na poziciji LS: 2, (0.2971768202080238 %)
#
# VEZNI RED: 516 (76.67161961367015 %)
# Broj igraca na poziciji RDM: 0, (0.0 %)
# Broj igraca na poziciji CDM: 0, (0.0 %)
# Broj igraca na poziciji LDM: 1, (0.1485884101040119 %)
# Broj igraca na poziciji RM: 138, (20.50520059435364 %)
# Broj igraca na poziciji RCM: 6, (0.8915304606240713 %)
# Broj igraca na poziciji CM: 74, (10.99554234769688 %)
# Broj igraca na poziciji LCM: 5, (0.7429420505200593 %)
# Broj igraca na poziciji LM: 155, (23.031203566121842 %)
# Broj igraca na poziciji RAM: 0, (0.0 %)
# Broj igraca na poziciji CAM: 137, (20.356612184249627 %)
# Broj igraca na poziciji LAM: 0, (0.0 %)
#
# ODBRANA: 4 (0.5943536404160475 %)
# Broj igraca na poziciji RWB: 1, (0.1485884101040119 %)
# Broj igraca na poziciji RB: 0, (0.0 %)
# Broj igraca na poziciji RCB: 0, (0.0 %)
# Broj igraca na poziciji CB: 0, (0.0 %)
# Broj igraca na poziciji LCB: 0, (0.0 %)
# Broj igraca na poziciji LB: 2, (0.2971768202080238 %)
# Broj igraca na poziciji LWB: 1, (0.1485884101040119 %)
#
# GOLMANI: 0 (0.0 %)
#
# Broj igraca u klasteru 19: 706, (3.8776294831658156 %)
#
# NAPAD: 512 (72.52124645892351 %)
# Broj igraca na poziciji RF: 4, (0.56657223796034 %)
# Broj igraca na poziciji LF: 1, (0.141643059490085 %)
# Broj igraca na poziciji RW: 26, (3.6827195467422094 %)
# Broj igraca na poziciji LW: 27, (3.824362606232295 %)
# Broj igraca na poziciji ST: 367, (51.98300283286119 %)
# Broj igraca na poziciji CF: 6, (0.84985835694051 %)
# Broj igraca na poziciji RS: 40, (5.6657223796034 %)
# Broj igraca na poziciji LS: 41, (5.807365439093484 %)
#
# VEZNI RED: 193 (27.3371104815864 %)
# Broj igraca na poziciji RDM: 1, (0.141643059490085 %)
# Broj igraca na poziciji CDM: 0, (0.0 %)
# Broj igraca na poziciji LDM: 0, (0.0 %)
# Broj igraca na poziciji RM: 79, (11.189801699716714 %)
# Broj igraca na poziciji RCM: 2, (0.28328611898017 %)
# Broj igraca na poziciji CM: 0, (0.0 %)
# Broj igraca na poziciji LCM: 4, (0.56657223796034 %)
# Broj igraca na poziciji LM: 75, (10.623229461756374 %)
# Broj igraca na poziciji RAM: 0, (0.0 %)
# Broj igraca na poziciji CAM: 30, (4.2492917847025495 %)
# Broj igraca na poziciji LAM: 2, (0.28328611898017 %)
#
# ODBRANA: 1 (0.141643059490085 %)
# Broj igraca na poziciji RWB: 0, (0.0 %)
# Broj igraca na poziciji RB: 0, (0.0 %)
# Broj igraca na poziciji RCB: 1, (0.141643059490085 %)
# Broj igraca na poziciji CB: 0, (0.0 %)
# Broj igraca na poziciji LCB: 0, (0.0 %)
# Broj igraca na poziciji LB: 0, (0.0 %)
# Broj igraca na poziciji LWB: 0, (0.0 %)
#
# GOLMANI: 0 (0.0 %)
#
# Broj igraca u klasteru 20: 614, (3.3723293238864174 %)
#
# NAPAD: 48 (7.81758957654723 %)
# Broj igraca na poziciji RF: 4, (0.6514657980456027 %)
# Broj igraca na poziciji LF: 1, (0.16286644951140067 %)
# Broj igraca na poziciji RW: 8, (1.3029315960912053 %)
# Broj igraca na poziciji LW: 15, (2.44299674267101 %)
# Broj igraca na poziciji ST: 11, (1.7915309446254073 %)
# Broj igraca na poziciji CF: 3, (0.4885993485342019 %)
# Broj igraca na poziciji RS: 4, (0.6514657980456027 %)
# Broj igraca na poziciji LS: 2, (0.32573289902280134 %)
#
# VEZNI RED: 518 (84.36482084690554 %)
# Broj igraca na poziciji RDM: 20, (3.257328990228013 %)
# Broj igraca na poziciji CDM: 24, (3.908794788273615 %)
# Broj igraca na poziciji LDM: 25, (4.071661237785016 %)
# Broj igraca na poziciji RM: 72, (11.726384364820847 %)
# Broj igraca na poziciji RCM: 51, (8.306188925081432 %)
# Broj igraca na poziciji CM: 121, (19.706840390879478 %)
# Broj igraca na poziciji LCM: 55, (8.957654723127035 %)
# Broj igraca na poziciji LM: 54, (8.794788273615636 %)
# Broj igraca na poziciji RAM: 3, (0.4885993485342019 %)
# Broj igraca na poziciji CAM: 93, (15.146579804560261 %)
# Broj igraca na poziciji LAM: 0, (0.0 %)
#
# ODBRANA: 48 (7.81758957654723 %)
# Broj igraca na poziciji RWB: 1, (0.16286644951140067 %)
# Broj igraca na poziciji RB: 14, (2.2801302931596092 %)
# Broj igraca na poziciji RCB: 0, (0.0 %)
# Broj igraca na poziciji CB: 0, (0.0 %)
# Broj igraca na poziciji LCB: 1, (0.16286644951140067 %)
# Broj igraca na poziciji LB: 30, (4.88599348534202 %)
# Broj igraca na poziciji LWB: 2, (0.32573289902280134 %)
#
# GOLMANI: 0 (0.0 %)
#
# Broj igraca u klasteru 12: 698, (3.8336903388806505 %)
#
# NAPAD: 5 (0.7163323782234957 %)
# Broj igraca na poziciji RF: 0, (0.0 %)
# Broj igraca na poziciji LF: 0, (0.0 %)
# Broj igraca na poziciji RW: 0, (0.0 %)
# Broj igraca na poziciji LW: 1, (0.14326647564469913 %)
# Broj igraca na poziciji ST: 4, (0.5730659025787965 %)
# Broj igraca na poziciji CF: 0, (0.0 %)
# Broj igraca na poziciji RS: 0, (0.0 %)
# Broj igraca na poziciji LS: 0, (0.0 %)
#
# VEZNI RED: 293 (41.977077363896846 %)
# Broj igraca na poziciji RDM: 3, (0.42979942693409745 %)
# Broj igraca na poziciji CDM: 88, (12.607449856733524 %)
# Broj igraca na poziciji LDM: 6, (0.8595988538681949 %)
# Broj igraca na poziciji RM: 19, (2.722063037249284 %)
# Broj igraca na poziciji RCM: 3, (0.42979942693409745 %)
# Broj igraca na poziciji CM: 140, (20.057306590257877 %)
# Broj igraca na poziciji LCM: 5, (0.7163323782234957 %)
# Broj igraca na poziciji LM: 19, (2.722063037249284 %)
# Broj igraca na poziciji RAM: 0, (0.0 %)
# Broj igraca na poziciji CAM: 10, (1.4326647564469914 %)
# Broj igraca na poziciji LAM: 0, (0.0 %)
#
# ODBRANA: 400 (57.306590257879655 %)
# Broj igraca na poziciji RWB: 15, (2.148997134670487 %)
# Broj igraca na poziciji RB: 155, (22.206303724928368 %)
# Broj igraca na poziciji RCB: 2, (0.28653295128939826 %)
# Broj igraca na poziciji CB: 39, (5.587392550143266 %)
# Broj igraca na poziciji LCB: 3, (0.42979942693409745 %)
# Broj igraca na poziciji LB: 180, (25.787965616045845 %)
# Broj igraca na poziciji LWB: 6, (0.8595988538681949 %)
#
# GOLMANI: 0 (0.0 %)
#
# Broj igraca u klasteru 22: 526, (2.8889987367496017 %)
#
# NAPAD: 1 (0.19011406844106463 %)
# Broj igraca na poziciji RF: 0, (0.0 %)
# Broj igraca na poziciji LF: 0, (0.0 %)
# Broj igraca na poziciji RW: 0, (0.0 %)
# Broj igraca na poziciji LW: 0, (0.0 %)
# Broj igraca na poziciji ST: 1, (0.19011406844106463 %)
# Broj igraca na poziciji CF: 0, (0.0 %)
# Broj igraca na poziciji RS: 0, (0.0 %)
# Broj igraca na poziciji LS: 0, (0.0 %)
#
# VEZNI RED: 5 (0.9505703422053232 %)
# Broj igraca na poziciji RDM: 0, (0.0 %)
# Broj igraca na poziciji CDM: 4, (0.7604562737642585 %)
# Broj igraca na poziciji LDM: 1, (0.19011406844106463 %)
# Broj igraca na poziciji RM: 0, (0.0 %)
# Broj igraca na poziciji RCM: 0, (0.0 %)
# Broj igraca na poziciji CM: 0, (0.0 %)
# Broj igraca na poziciji LCM: 0, (0.0 %)
# Broj igraca na poziciji LM: 0, (0.0 %)
# Broj igraca na poziciji RAM: 0, (0.0 %)
# Broj igraca na poziciji CAM: 0, (0.0 %)
# Broj igraca na poziciji LAM: 0, (0.0 %)
#
# ODBRANA: 520 (98.85931558935361 %)
# Broj igraca na poziciji RWB: 0, (0.0 %)
# Broj igraca na poziciji RB: 17, (3.2319391634980987 %)
# Broj igraca na poziciji RCB: 31, (5.893536121673003 %)
# Broj igraca na poziciji CB: 429, (81.55893536121674 %)
# Broj igraca na poziciji LCB: 25, (4.752851711026616 %)
# Broj igraca na poziciji LB: 17, (3.2319391634980987 %)
# Broj igraca na poziciji LWB: 1, (0.19011406844106463 %)
#
# GOLMANI: 0 (0.0 %)
#
# Broj igraca u klasteru 23: 935, (5.135387488328664 %)
#
# NAPAD: 3 (0.32085561497326204 %)
# Broj igraca na poziciji RF: 0, (0.0 %)
# Broj igraca na poziciji LF: 0, (0.0 %)
# Broj igraca na poziciji RW: 0, (0.0 %)
# Broj igraca na poziciji LW: 2, (0.21390374331550802 %)
# Broj igraca na poziciji ST: 1, (0.10695187165775401 %)
# Broj igraca na poziciji CF: 0, (0.0 %)
# Broj igraca na poziciji RS: 0, (0.0 %)
# Broj igraca na poziciji LS: 0, (0.0 %)
#
# VEZNI RED: 425 (45.45454545454545 %)
# Broj igraca na poziciji RDM: 41, (4.385026737967915 %)
# Broj igraca na poziciji CDM: 114, (12.192513368983956 %)
# Broj igraca na poziciji LDM: 30, (3.2085561497326207 %)
# Broj igraca na poziciji RM: 22, (2.3529411764705883 %)
# Broj igraca na poziciji RCM: 47, (5.026737967914439 %)
# Broj igraca na poziciji CM: 87, (9.304812834224599 %)
# Broj igraca na poziciji LCM: 46, (4.919786096256685 %)
# Broj igraca na poziciji LM: 30, (3.2085561497326207 %)
# Broj igraca na poziciji RAM: 0, (0.0 %)
# Broj igraca na poziciji CAM: 8, (0.8556149732620321 %)
# Broj igraca na poziciji LAM: 0, (0.0 %)
#
# ODBRANA: 507 (54.224598930481285 %)
# Broj igraca na poziciji RWB: 13, (1.3903743315508021 %)
# Broj igraca na poziciji RB: 226, (24.171122994652407 %)
# Broj igraca na poziciji RCB: 14, (1.4973262032085561 %)
# Broj igraca na poziciji CB: 13, (1.3903743315508021 %)
# Broj igraca na poziciji LCB: 13, (1.3903743315508021 %)
# Broj igraca na poziciji LB: 213, (22.780748663101605 %)
# Broj igraca na poziciji LWB: 15, (1.6042780748663104 %)
#
# GOLMANI: 0 (0.0 %)
#
# Broj igraca u klasteru 24: 1000, (5.49239303564563 %)
#
# NAPAD: 80 (8.0 %)
# Broj igraca na poziciji RF: 0, (0.0 %)
# Broj igraca na poziciji LF: 1, (0.1 %)
# Broj igraca na poziciji RW: 21, (2.1 %)
# Broj igraca na poziciji LW: 33, (3.3000000000000003 %)
# Broj igraca na poziciji ST: 20, (2.0 %)
# Broj igraca na poziciji CF: 0, (0.0 %)
# Broj igraca na poziciji RS: 3, (0.3 %)
# Broj igraca na poziciji LS: 2, (0.2 %)
#
# VEZNI RED: 795 (79.5 %)
# Broj igraca na poziciji RDM: 15, (1.5 %)
# Broj igraca na poziciji CDM: 40, (4.0 %)
# Broj igraca na poziciji LDM: 20, (2.0 %)
# Broj igraca na poziciji RM: 124, (12.4 %)
# Broj igraca na poziciji RCM: 54, (5.4 %)
# Broj igraca na poziciji CM: 250, (25.0 %)
# Broj igraca na poziciji LCM: 59, (5.8999999999999995 %)
# Broj igraca na poziciji LM: 118, (11.799999999999999 %)
# Broj igraca na poziciji RAM: 0, (0.0 %)
# Broj igraca na poziciji CAM: 113, (11.3 %)
# Broj igraca na poziciji LAM: 2, (0.2 %)
#
# ODBRANA: 125 (12.5 %)
# Broj igraca na poziciji RWB: 7, (0.7000000000000001 %)
# Broj igraca na poziciji RB: 41, (4.1000000000000005 %)
# Broj igraca na poziciji RCB: 3, (0.3 %)
# Broj igraca na poziciji CB: 1, (0.1 %)
# Broj igraca na poziciji LCB: 1, (0.1 %)
# Broj igraca na poziciji LB: 65, (6.5 %)
# Broj igraca na poziciji LWB: 7, (0.7000000000000001 %)
#
# GOLMANI: 0 (0.0 %)
#
# Broj igraca u klasteru 25: 1000, (5.49239303564563 %)
#
# NAPAD: 80 (8.0 %)
# Broj igraca na poziciji RF: 0, (0.0 %)
# Broj igraca na poziciji LF: 1, (0.1 %)
# Broj igraca na poziciji RW: 21, (2.1 %)
# Broj igraca na poziciji LW: 33, (3.3000000000000003 %)
# Broj igraca na poziciji ST: 20, (2.0 %)
# Broj igraca na poziciji CF: 0, (0.0 %)
# Broj igraca na poziciji RS: 3, (0.3 %)
# Broj igraca na poziciji LS: 2, (0.2 %)
#
# VEZNI RED: 795 (79.5 %)
# Broj igraca na poziciji RDM: 15, (1.5 %)
# Broj igraca na poziciji CDM: 40, (4.0 %)
# Broj igraca na poziciji LDM: 20, (2.0 %)
# Broj igraca na poziciji RM: 124, (12.4 %)
# Broj igraca na poziciji RCM: 54, (5.4 %)
# Broj igraca na poziciji CM: 250, (25.0 %)
# Broj igraca na poziciji LCM: 59, (5.8999999999999995 %)
# Broj igraca na poziciji LM: 118, (11.799999999999999 %)
# Broj igraca na poziciji RAM: 0, (0.0 %)
# Broj igraca na poziciji CAM: 113, (11.3 %)
# Broj igraca na poziciji LAM: 2, (0.2 %)
#
# ODBRANA: 125 (12.5 %)
# Broj igraca na poziciji RWB: 7, (0.7000000000000001 %)
# Broj igraca na poziciji RB: 41, (4.1000000000000005 %)
# Broj igraca na poziciji RCB: 3, (0.3 %)
# Broj igraca na poziciji CB: 1, (0.1 %)
# Broj igraca na poziciji LCB: 1, (0.1 %)
# Broj igraca na poziciji LB: 65, (6.5 %)
# Broj igraca na poziciji LWB: 7, (0.7000000000000001 %)
#
# GOLMANI: 0 (0.0 %)
#
# Broj igraca u klasteru 26: 667, (3.6634261547756357 %)
#
# NAPAD: 567 (85.00749625187406 %)
# Broj igraca na poziciji RF: 0, (0.0 %)
# Broj igraca na poziciji LF: 0, (0.0 %)
# Broj igraca na poziciji RW: 15, (2.2488755622188905 %)
# Broj igraca na poziciji LW: 22, (3.2983508245877062 %)
# Broj igraca na poziciji ST: 453, (67.9160419790105 %)
# Broj igraca na poziciji CF: 11, (1.6491754122938531 %)
# Broj igraca na poziciji RS: 33, (4.94752623688156 %)
# Broj igraca na poziciji LS: 33, (4.94752623688156 %)
#
# VEZNI RED: 100 (14.992503748125937 %)
# Broj igraca na poziciji RDM: 1, (0.14992503748125938 %)
# Broj igraca na poziciji CDM: 0, (0.0 %)
# Broj igraca na poziciji LDM: 0, (0.0 %)
# Broj igraca na poziciji RM: 47, (7.04647676161919 %)
# Broj igraca na poziciji RCM: 1, (0.14992503748125938 %)
# Broj igraca na poziciji CM: 0, (0.0 %)
# Broj igraca na poziciji LCM: 1, (0.14992503748125938 %)
# Broj igraca na poziciji LM: 37, (5.547226386806597 %)
# Broj igraca na poziciji RAM: 0, (0.0 %)
# Broj igraca na poziciji CAM: 13, (1.9490254872563717 %)
# Broj igraca na poziciji LAM: 0, (0.0 %)
#
# ODBRANA: 0 (0.0 %)
# Broj igraca na poziciji RWB: 0, (0.0 %)
# Broj igraca na poziciji RB: 0, (0.0 %)
# Broj igraca na poziciji RCB: 0, (0.0 %)
# Broj igraca na poziciji CB: 0, (0.0 %)
# Broj igraca na poziciji LCB: 0, (0.0 %)
# Broj igraca na poziciji LB: 0, (0.0 %)
# Broj igraca na poziciji LWB: 0, (0.0 %)
#
# GOLMANI: 0 (0.0 %)

# %%
# KPrototypes

categorical_features_index = []
for index, feature in enumerate(df.columns.values):
    if str(df[feature].dtype) == 'object':
        categorical_features_index.append(index)

sse = []

for k in range(2, 11):
    kprototypes = KPrototypes(n_clusters=k, random_state=0, n_jobs=-1)
    kprototypes.fit(df, categorical=categorical_features_index)
    sse.append(kprototypes.cost_)

# %%
plt.plot(range(2, 11), sse)
plt.xlabel('K')
plt.ylabel('Cost')
# Out:
# Text(0, 0.5, 'Cost')

# %%
kprototypes = KPrototypes(n_clusters=8, random_state=0)
kprototypes.fit(df, categorical=categorical_features_index)
# Out:
# KPrototypes(gamma=1.0956456863112687, random_state=0)

# %%
df['cluster_marks'] = kmeans.labels_

df_cluster_0 = df.loc[df['cluster_marks'] == 0]
df_cluster_1 = df.loc[df['cluster_marks'] == 1]
df_cluster_2 = df.loc[df['cluster_marks'] == 2]
df_cluster_3 = df.loc[df['cluster_marks'] == 3]
df_cluster_4 = df.loc[df['cluster_marks'] == 4]
df_cluster_5 = df.loc[df['cluster_marks'] == 5]
df_cluster_6 = df.loc[df['cluster_marks'] == 6]
df_cluster_7 = df.loc[df['cluster_marks'] == 7]

show_position_percentige_per_cluster(df_cluster_0, 0, len(df))
show_position_percentige_per_cluster(df_cluster_1, 1, len(df))
show_position_percentige_per_cluster(df_cluster_2, 2, len(df))
show_position_percentige_per_cluster(df_cluster_3, 3, len(df))
show_position_percentige_per_cluster(df_cluster_4, 4, len(df))
show_position_percentige_per_cluster(df_cluster_5, 5, len(df))
show_position_percentige_per_cluster(df_cluster_6, 6, len(df))
show_position_percentige_per_cluster(df_cluster_7, 7, len(df))
# Out:
# Broj igraca u klasteru 0: 824, (4.525731861372 %)
#
# NAPAD: 1 (0.12135922330097086 %)
# Broj igraca na poziciji RF: 0, (0.0 %)
# Broj igraca na poziciji LF: 0, (0.0 %)
# Broj igraca na poziciji RW: 0, (0.0 %)
# Broj igraca na poziciji LW: 0, (0.0 %)
# Broj igraca na poziciji ST: 1, (0.12135922330097086 %)
# Broj igraca na poziciji CF: 0, (0.0 %)
# Broj igraca na poziciji RS: 0, (0.0 %)
# Broj igraca na poziciji LS: 0, (0.0 %)
#
# VEZNI RED: 0 (0.0 %)
# Broj igraca na poziciji RDM: 0, (0.0 %)
# Broj igraca na poziciji CDM: 0, (0.0 %)
# Broj igraca na poziciji LDM: 0, (0.0 %)
# Broj igraca na poziciji RM: 0, (0.0 %)
# Broj igraca na poziciji RCM: 0, (0.0 %)
# Broj igraca na poziciji CM: 0, (0.0 %)
# Broj igraca na poziciji LCM: 0, (0.0 %)
# Broj igraca na poziciji LM: 0, (0.0 %)
# Broj igraca na poziciji RAM: 0, (0.0 %)
# Broj igraca na poziciji CAM: 0, (0.0 %)
# Broj igraca na poziciji LAM: 0, (0.0 %)
#
# ODBRANA: 0 (0.0 %)
# Broj igraca na poziciji RWB: 0, (0.0 %)
# Broj igraca na poziciji RB: 0, (0.0 %)
# Broj igraca na poziciji RCB: 0, (0.0 %)
# Broj igraca na poziciji CB: 0, (0.0 %)
# Broj igraca na poziciji LCB: 0, (0.0 %)
# Broj igraca na poziciji LB: 0, (0.0 %)
# Broj igraca na poziciji LWB: 0, (0.0 %)
#
# GOLMANI: 823 (99.87864077669903 %)
#
# Broj igraca u klasteru 1: 484, (2.6583182292524854 %)
#
# NAPAD: 0 (0.0 %)
# Broj igraca na poziciji RF: 0, (0.0 %)
# Broj igraca na poziciji LF: 0, (0.0 %)
# Broj igraca na poziciji RW: 0, (0.0 %)
# Broj igraca na poziciji LW: 0, (0.0 %)
# Broj igraca na poziciji ST: 0, (0.0 %)
# Broj igraca na poziciji CF: 0, (0.0 %)
# Broj igraca na poziciji RS: 0, (0.0 %)
# Broj igraca na poziciji LS: 0, (0.0 %)
#
# VEZNI RED: 109 (22.520661157024794 %)
# Broj igraca na poziciji RDM: 25, (5.1652892561983474 %)
# Broj igraca na poziciji CDM: 50, (10.330578512396695 %)
# Broj igraca na poziciji LDM: 19, (3.925619834710744 %)
# Broj igraca na poziciji RM: 0, (0.0 %)
# Broj igraca na poziciji RCM: 3, (0.6198347107438017 %)
# Broj igraca na poziciji CM: 2, (0.4132231404958678 %)
# Broj igraca na poziciji LCM: 9, (1.859504132231405 %)
# Broj igraca na poziciji LM: 1, (0.2066115702479339 %)
# Broj igraca na poziciji RAM: 0, (0.0 %)
# Broj igraca na poziciji CAM: 0, (0.0 %)
# Broj igraca na poziciji LAM: 0, (0.0 %)
#
# ODBRANA: 375 (77.47933884297521 %)
# Broj igraca na poziciji RWB: 2, (0.4132231404958678 %)
# Broj igraca na poziciji RB: 12, (2.479338842975207 %)
# Broj igraca na poziciji RCB: 107, (22.107438016528928 %)
# Broj igraca na poziciji CB: 138, (28.512396694214875 %)
# Broj igraca na poziciji LCB: 100, (20.66115702479339 %)
# Broj igraca na poziciji LB: 16, (3.3057851239669422 %)
# Broj igraca na poziciji LWB: 0, (0.0 %)
#
# GOLMANI: 0 (0.0 %)
#
# Broj igraca u klasteru 2: 903, (4.959630911188005 %)
#
# NAPAD: 1 (0.11074197120708748 %)
# Broj igraca na poziciji RF: 0, (0.0 %)
# Broj igraca na poziciji LF: 0, (0.0 %)
# Broj igraca na poziciji RW: 0, (0.0 %)
# Broj igraca na poziciji LW: 0, (0.0 %)
# Broj igraca na poziciji ST: 1, (0.11074197120708748 %)
# Broj igraca na poziciji CF: 0, (0.0 %)
# Broj igraca na poziciji RS: 0, (0.0 %)
# Broj igraca na poziciji LS: 0, (0.0 %)
#
# VEZNI RED: 163 (18.05094130675526 %)
# Broj igraca na poziciji RDM: 10, (1.1074197120708749 %)
# Broj igraca na poziciji CDM: 94, (10.409745293466225 %)
# Broj igraca na poziciji LDM: 8, (0.8859357696566998 %)
# Broj igraca na poziciji RM: 10, (1.1074197120708749 %)
# Broj igraca na poziciji RCM: 7, (0.7751937984496124 %)
# Broj igraca na poziciji CM: 19, (2.104097452934662 %)
# Broj igraca na poziciji LCM: 7, (0.7751937984496124 %)
# Broj igraca na poziciji LM: 8, (0.8859357696566998 %)
# Broj igraca na poziciji RAM: 0, (0.0 %)
# Broj igraca na poziciji CAM: 0, (0.0 %)
# Broj igraca na poziciji LAM: 0, (0.0 %)
#
# ODBRANA: 739 (81.83831672203765 %)
# Broj igraca na poziciji RWB: 14, (1.550387596899225 %)
# Broj igraca na poziciji RB: 267, (29.568106312292358 %)
# Broj igraca na poziciji RCB: 38, (4.208194905869324 %)
# Broj igraca na poziciji CB: 135, (14.950166112956811 %)
# Broj igraca na poziciji LCB: 30, (3.322259136212625 %)
# Broj igraca na poziciji LB: 241, (26.688815060908084 %)
# Broj igraca na poziciji LWB: 14, (1.550387596899225 %)
#
# GOLMANI: 0 (0.0 %)
#
# Broj igraca u klasteru 3: 880, (4.833305871368155 %)
#
# NAPAD: 268 (30.454545454545457 %)
# Broj igraca na poziciji RF: 1, (0.11363636363636363 %)
# Broj igraca na poziciji LF: 3, (0.3409090909090909 %)
# Broj igraca na poziciji RW: 89, (10.113636363636363 %)
# Broj igraca na poziciji LW: 98, (11.136363636363637 %)
# Broj igraca na poziciji ST: 54, (6.136363636363637 %)
# Broj igraca na poziciji CF: 9, (1.0227272727272727 %)
# Broj igraca na poziciji RS: 9, (1.0227272727272727 %)
# Broj igraca na poziciji LS: 5, (0.5681818181818182 %)
#
# VEZNI RED: 612 (69.54545454545455 %)
# Broj igraca na poziciji RDM: 2, (0.22727272727272727 %)
# Broj igraca na poziciji CDM: 0, (0.0 %)
# Broj igraca na poziciji LDM: 2, (0.22727272727272727 %)
# Broj igraca na poziciji RM: 218, (24.772727272727273 %)
# Broj igraca na poziciji RCM: 4, (0.45454545454545453 %)
# Broj igraca na poziciji CM: 15, (1.7045454545454544 %)
# Broj igraca na poziciji LCM: 8, (0.9090909090909091 %)
# Broj igraca na poziciji LM: 201, (22.840909090909093 %)
# Broj igraca na poziciji RAM: 2, (0.22727272727272727 %)
# Broj igraca na poziciji CAM: 159, (18.06818181818182 %)
# Broj igraca na poziciji LAM: 1, (0.11363636363636363 %)
#
# ODBRANA: 0 (0.0 %)
# Broj igraca na poziciji RWB: 0, (0.0 %)
# Broj igraca na poziciji RB: 0, (0.0 %)
# Broj igraca na poziciji RCB: 0, (0.0 %)
# Broj igraca na poziciji CB: 0, (0.0 %)
# Broj igraca na poziciji LCB: 0, (0.0 %)
# Broj igraca na poziciji LB: 0, (0.0 %)
# Broj igraca na poziciji LWB: 0, (0.0 %)
#
# GOLMANI: 0 (0.0 %)
#
# Broj igraca u klasteru 4: 624, (3.4272532542428733 %)
#
# NAPAD: 0 (0.0 %)
# Broj igraca na poziciji RF: 0, (0.0 %)
# Broj igraca na poziciji LF: 0, (0.0 %)
# Broj igraca na poziciji RW: 0, (0.0 %)
# Broj igraca na poziciji LW: 0, (0.0 %)
# Broj igraca na poziciji ST: 0, (0.0 %)
# Broj igraca na poziciji CF: 0, (0.0 %)
# Broj igraca na poziciji RS: 0, (0.0 %)
# Broj igraca na poziciji LS: 0, (0.0 %)
#
# VEZNI RED: 29 (4.647435897435898 %)
# Broj igraca na poziciji RDM: 4, (0.641025641025641 %)
# Broj igraca na poziciji CDM: 16, (2.564102564102564 %)
# Broj igraca na poziciji LDM: 5, (0.8012820512820512 %)
# Broj igraca na poziciji RM: 0, (0.0 %)
# Broj igraca na poziciji RCM: 1, (0.16025641025641024 %)
# Broj igraca na poziciji CM: 1, (0.16025641025641024 %)
# Broj igraca na poziciji LCM: 2, (0.3205128205128205 %)
# Broj igraca na poziciji LM: 0, (0.0 %)
# Broj igraca na poziciji RAM: 0, (0.0 %)
# Broj igraca na poziciji CAM: 0, (0.0 %)
# Broj igraca na poziciji LAM: 0, (0.0 %)
#
# ODBRANA: 595 (95.3525641025641 %)
# Broj igraca na poziciji RWB: 0, (0.0 %)
# Broj igraca na poziciji RB: 19, (3.0448717948717947 %)
# Broj igraca na poziciji RCB: 158, (25.320512820512818 %)
# Broj igraca na poziciji CB: 254, (40.705128205128204 %)
# Broj igraca na poziciji LCB: 152, (24.358974358974358 %)
# Broj igraca na poziciji LB: 12, (1.9230769230769231 %)
# Broj igraca na poziciji LWB: 0, (0.0 %)
#
# GOLMANI: 0 (0.0 %)
#
# Broj igraca u klasteru 5: 401, (2.202449607293898 %)
#
# NAPAD: 389 (97.0074812967581 %)
# Broj igraca na poziciji RF: 0, (0.0 %)
# Broj igraca na poziciji LF: 0, (0.0 %)
# Broj igraca na poziciji RW: 3, (0.7481296758104738 %)
# Broj igraca na poziciji LW: 2, (0.4987531172069825 %)
# Broj igraca na poziciji ST: 323, (80.54862842892769 %)
# Broj igraca na poziciji CF: 3, (0.7481296758104738 %)
# Broj igraca na poziciji RS: 27, (6.733167082294264 %)
# Broj igraca na poziciji LS: 31, (7.73067331670823 %)
#
# VEZNI RED: 12 (2.9925187032418954 %)
# Broj igraca na poziciji RDM: 0, (0.0 %)
# Broj igraca na poziciji CDM: 0, (0.0 %)
# Broj igraca na poziciji LDM: 0, (0.0 %)
# Broj igraca na poziciji RM: 3, (0.7481296758104738 %)
# Broj igraca na poziciji RCM: 2, (0.4987531172069825 %)
# Broj igraca na poziciji CM: 0, (0.0 %)
# Broj igraca na poziciji LCM: 0, (0.0 %)
# Broj igraca na poziciji LM: 4, (0.997506234413965 %)
# Broj igraca na poziciji RAM: 0, (0.0 %)
# Broj igraca na poziciji CAM: 3, (0.7481296758104738 %)
# Broj igraca na poziciji LAM: 0, (0.0 %)
#
# ODBRANA: 0 (0.0 %)
# Broj igraca na poziciji RWB: 0, (0.0 %)
# Broj igraca na poziciji RB: 0, (0.0 %)
# Broj igraca na poziciji RCB: 0, (0.0 %)
# Broj igraca na poziciji CB: 0, (0.0 %)
# Broj igraca na poziciji LCB: 0, (0.0 %)
# Broj igraca na poziciji LB: 0, (0.0 %)
# Broj igraca na poziciji LWB: 0, (0.0 %)
#
# GOLMANI: 0 (0.0 %)
#
# Broj igraca u klasteru 6: 901, (4.9486461251167135 %)
#
# NAPAD: 256 (28.412874583795784 %)
# Broj igraca na poziciji RF: 3, (0.3329633740288568 %)
# Broj igraca na poziciji LF: 3, (0.3329633740288568 %)
# Broj igraca na poziciji RW: 82, (9.100998890122087 %)
# Broj igraca na poziciji LW: 82, (9.100998890122087 %)
# Broj igraca na poziciji ST: 48, (5.3274139844617086 %)
# Broj igraca na poziciji CF: 11, (1.2208657047724751 %)
# Broj igraca na poziciji RS: 14, (1.553829078801332 %)
# Broj igraca na poziciji LS: 13, (1.4428412874583796 %)
#
# VEZNI RED: 643 (71.36514983351832 %)
# Broj igraca na poziciji RDM: 4, (0.4439511653718091 %)
# Broj igraca na poziciji CDM: 0, (0.0 %)
# Broj igraca na poziciji LDM: 1, (0.11098779134295228 %)
# Broj igraca na poziciji RM: 186, (20.643729189789124 %)
# Broj igraca na poziciji RCM: 9, (0.9988901220865706 %)
# Broj igraca na poziciji CM: 8, (0.8879023307436182 %)
# Broj igraca na poziciji LCM: 21, (2.3307436182019976 %)
# Broj igraca na poziciji LM: 208, (23.085460599334073 %)
# Broj igraca na poziciji RAM: 13, (1.4428412874583796 %)
# Broj igraca na poziciji CAM: 180, (19.97780244173141 %)
# Broj igraca na poziciji LAM: 13, (1.4428412874583796 %)
#
# ODBRANA: 2 (0.22197558268590456 %)
# Broj igraca na poziciji RWB: 0, (0.0 %)
# Broj igraca na poziciji RB: 0, (0.0 %)
# Broj igraca na poziciji RCB: 0, (0.0 %)
# Broj igraca na poziciji CB: 0, (0.0 %)
# Broj igraca na poziciji LCB: 0, (0.0 %)
# Broj igraca na poziciji LB: 1, (0.11098779134295228 %)
# Broj igraca na poziciji LWB: 1, (0.11098779134295228 %)
#
# GOLMANI: 0 (0.0 %)
#
# Broj igraca u klasteru 7: 670, (3.6799033338825726 %)
#
# NAPAD: 0 (0.0 %)
# Broj igraca na poziciji RF: 0, (0.0 %)
# Broj igraca na poziciji LF: 0, (0.0 %)
# Broj igraca na poziciji RW: 0, (0.0 %)
# Broj igraca na poziciji LW: 0, (0.0 %)
# Broj igraca na poziciji ST: 0, (0.0 %)
# Broj igraca na poziciji CF: 0, (0.0 %)
# Broj igraca na poziciji RS: 0, (0.0 %)
# Broj igraca na poziciji LS: 0, (0.0 %)
#
# VEZNI RED: 0 (0.0 %)
# Broj igraca na poziciji RDM: 0, (0.0 %)
# Broj igraca na poziciji CDM: 0, (0.0 %)
# Broj igraca na poziciji LDM: 0, (0.0 %)
# Broj igraca na poziciji RM: 0, (0.0 %)
# Broj igraca na poziciji RCM: 0, (0.0 %)
# Broj igraca na poziciji CM: 0, (0.0 %)
# Broj igraca na poziciji LCM: 0, (0.0 %)
# Broj igraca na poziciji LM: 0, (0.0 %)
# Broj igraca na poziciji RAM: 0, (0.0 %)
# Broj igraca na poziciji CAM: 0, (0.0 %)
# Broj igraca na poziciji LAM: 0, (0.0 %)
#
# ODBRANA: 0 (0.0 %)
# Broj igraca na poziciji RWB: 0, (0.0 %)
# Broj igraca na poziciji RB: 0, (0.0 %)
# Broj igraca na poziciji RCB: 0, (0.0 %)
# Broj igraca na poziciji CB: 0, (0.0 %)
# Broj igraca na poziciji LCB: 0, (0.0 %)
# Broj igraca na poziciji LB: 0, (0.0 %)
# Broj igraca na poziciji LWB: 0, (0.0 %)
#
# GOLMANI: 670 (100.0 %)

# %%
# Koristiti domensko znanje prilikom odabira k

# Generalno, postoje 4 razlicite pozicije (golman, odbrana, vezni red i napad), tako da prvo pokusati za k=4

kprototypes = KPrototypes(n_clusters=4, random_state=0)
kprototypes.fit(df, categorical=categorical_features_index)

count = Counter(kprototypes.labels_)
number_and_percentige_per_cluster = {}

for value, times in count.most_common():
    number_and_percentige_per_cluster[value] = [times, (times / len(df)) * 100]

number_and_percentige_per_cluster
# Out:
# {0: [5687, 31.2352391937167],
#  1: [4310, 23.67221398363267],
#  2: [4156, 22.826385456143242],
#  3: [4054, 22.266161366507387]}

# %%
df['cluster_marks'] = kprototypes.labels_

df_cluster_0 = df.loc[df['cluster_marks'] == 0]
df_cluster_1 = df.loc[df['cluster_marks'] == 1]
df_cluster_2 = df.loc[df['cluster_marks'] == 2]
df_cluster_3 = df.loc[df['cluster_marks'] == 3]

show_position_percentige_per_cluster(df_cluster_0, 0, len(df))
show_position_percentige_per_cluster(df_cluster_1, 1, len(df))
show_position_percentige_per_cluster(df_cluster_2, 2, len(df))
show_position_percentige_per_cluster(df_cluster_3, 3, len(df))
# Out:
# Broj igraca u klasteru 0: 5687, (31.2352391937167 %)
#
# NAPAD: 915 (16.089326534200808 %)
# Broj igraca na poziciji RF: 4, (0.0703358537014243 %)
# Broj igraca na poziciji LF: 6, (0.10550378055213644 %)
# Broj igraca na poziciji RW: 174, (3.059609636011957 %)
# Broj igraca na poziciji LW: 182, (3.2002813434148054 %)
# Broj igraca na poziciji ST: 427, (7.508352382627044 %)
# Broj igraca na poziciji CF: 23, (0.4044311587831897 %)
# Broj igraca na poziciji RS: 50, (0.8791981712678038 %)
# Broj igraca na poziciji LS: 49, (0.8616142078424477 %)
#
# VEZNI RED: 1568 (27.571654650958326 %)
# Broj igraca na poziciji RDM: 45, (0.7912783541410234 %)
# Broj igraca na poziciji CDM: 160, (2.813434148056972 %)
# Broj igraca na poziciji LDM: 35, (0.6154387198874627 %)
# Broj igraca na poziciji RM: 417, (7.3325127483734835 %)
# Broj igraca na poziciji RCM: 26, (0.45718304905925794 %)
# Broj igraca na poziciji CM: 45, (0.7912783541410234 %)
# Broj igraca na poziciji LCM: 47, (0.8264462809917356 %)
# Broj igraca na poziciji LM: 422, (7.420432565500263 %)
# Broj igraca na poziciji RAM: 15, (0.2637594513803411 %)
# Broj igraca na poziciji CAM: 342, (6.013715491471778 %)
# Broj igraca na poziciji LAM: 14, (0.24617548795498506 %)
#
# ODBRANA: 1711 (30.086161420784247 %)
# Broj igraca na poziciji RWB: 16, (0.2813434148056972 %)
# Broj igraca na poziciji RB: 298, (5.240021100756111 %)
# Broj igraca na poziciji RCB: 303, (5.327940917882891 %)
# Broj igraca na poziciji CB: 527, (9.266748725162651 %)
# Broj igraca na poziciji LCB: 282, (4.958677685950414 %)
# Broj igraca na poziciji LB: 270, (4.74767012484614 %)
# Broj igraca na poziciji LWB: 15, (0.2637594513803411 %)
#
# GOLMANI: 1493 (26.252857394056623 %)
#
# Broj igraca u klasteru 1: 4310, (23.67221398363267 %)
#
# NAPAD: 1115 (25.870069605568446 %)
# Broj igraca na poziciji RF: 0, (0.0 %)
# Broj igraca na poziciji LF: 1, (0.02320185614849188 %)
# Broj igraca na poziciji RW: 44, (1.0208816705336428 %)
# Broj igraca na poziciji LW: 66, (1.531322505800464 %)
# Broj igraca na poziciji ST: 907, (21.044083526682133 %)
# Broj igraca na poziciji CF: 16, (0.37122969837587005 %)
# Broj igraca na poziciji RS: 41, (0.9512761020881672 %)
# Broj igraca na poziciji LS: 40, (0.9280742459396751 %)
#
# VEZNI RED: 1642 (38.09744779582366 %)
# Broj igraca na poziciji RDM: 62, (1.4385150812064964 %)
# Broj igraca na poziciji CDM: 247, (5.730858468677495 %)
# Broj igraca na poziciji LDM: 57, (1.322505800464037 %)
# Broj igraca na poziciji RM: 224, (5.197215777262181 %)
# Broj igraca na poziciji RCM: 105, (2.436194895591647 %)
# Broj igraca na poziciji CM: 477, (11.067285382830626 %)
# Broj igraca na poziciji LCM: 111, (2.575406032482599 %)
# Broj igraca na poziciji LM: 208, (4.825986078886311 %)
# Broj igraca na poziciji RAM: 0, (0.0 %)
# Broj igraca na poziciji CAM: 149, (3.4570765661252905 %)
# Broj igraca na poziciji LAM: 2, (0.04640371229698376 %)
#
# ODBRANA: 1553 (36.03248259860789 %)
# Broj igraca na poziciji RWB: 35, (0.8120649651972157 %)
# Broj igraca na poziciji RB: 439, (10.185614849187935 %)
# Broj igraca na poziciji RCB: 50, (1.160092807424594 %)
# Broj igraca na poziciji CB: 482, (11.183294663573086 %)
# Broj igraca na poziciji LCB: 42, (0.974477958236659 %)
# Broj igraca na poziciji LB: 476, (11.044083526682135 %)
# Broj igraca na poziciji LWB: 29, (0.6728538283062645 %)
#
# GOLMANI: 0 (0.0 %)
#
# Broj igraca u klasteru 2: 4156, (22.826385456143242 %)
#
# NAPAD: 566 (13.618864292589027 %)
# Broj igraca na poziciji RF: 0, (0.0 %)
# Broj igraca na poziciji LF: 1, (0.024061597690086624 %)
# Broj igraca na poziciji RW: 25, (0.6015399422521656 %)
# Broj igraca na poziciji LW: 19, (0.4571703561116458 %)
# Broj igraca na poziciji ST: 397, (9.552454282964389 %)
# Broj igraca na poziciji CF: 8, (0.192492781520693 %)
# Broj igraca na poziciji RS: 59, (1.4196342637151107 %)
# Broj igraca na poziciji LS: 57, (1.3715110683349374 %)
#
# VEZNI RED: 1145 (27.550529355149184 %)
# Broj igraca na poziciji RDM: 30, (0.7218479307025986 %)
# Broj igraca na poziciji CDM: 236, (5.678537054860443 %)
# Broj igraca na poziciji LDM: 36, (0.8662175168431183 %)
# Broj igraca na poziciji RM: 100, (2.4061597690086622 %)
# Broj igraca na poziciji RCM: 59, (1.4196342637151107 %)
# Broj igraca na poziciji CM: 432, (10.39461020211742 %)
# Broj igraca na poziciji LCM: 52, (1.2512030798845042 %)
# Broj igraca na poziciji LM: 94, (2.2617901828681424 %)
# Broj igraca na poziciji RAM: 1, (0.024061597690086624 %)
# Broj igraca na poziciji CAM: 104, (2.5024061597690084 %)
# Broj igraca na poziciji LAM: 1, (0.024061597690086624 %)
#
# ODBRANA: 1913 (46.02983638113571 %)
# Broj igraca na poziciji RWB: 26, (0.6256015399422521 %)
# Broj igraca na poziciji RB: 359, (8.638113570741098 %)
# Broj igraca na poziciji RCB: 261, (6.280076997112609 %)
# Broj igraca na poziciji CB: 653, (15.712223291626565 %)
# Broj igraca na poziciji LCB: 255, (6.135707410972088 %)
# Broj igraca na poziciji LB: 340, (8.180943214629451 %)
# Broj igraca na poziciji LWB: 19, (0.4571703561116458 %)
#
# GOLMANI: 532 (12.800769971126083 %)
#
# Broj igraca u klasteru 3: 4054, (22.266161366507387 %)
#
# NAPAD: 882 (21.756290083867786 %)
# Broj igraca na poziciji RF: 12, (0.2960039467192896 %)
# Broj igraca na poziciji LF: 7, (0.1726689689195856 %)
# Broj igraca na poziciji RW: 127, (3.1327084361124817 %)
# Broj igraca na poziciji LW: 114, (2.8120374938332513 %)
# Broj igraca na poziciji ST: 481, (11.864824864331524 %)
# Broj igraca na poziciji CF: 27, (0.6660088801184015 %)
# Broj igraca na poziciji RS: 53, (1.3073507646768623 %)
# Broj igraca na poziciji LS: 61, (1.5046867291563888 %)
#
# VEZNI RED: 2483 (61.248149975333 %)
# Broj igraca na poziciji RDM: 111, (2.7380365071534287 %)
# Broj igraca na poziciji CDM: 305, (7.523433645781943 %)
# Broj igraca na poziciji LDM: 115, (2.836704489393192 %)
# Broj igraca na poziciji RM: 383, (9.447459299457327 %)
# Broj igraca na poziciji RCM: 201, (4.958066107548101 %)
# Broj igraca na poziciji CM: 440, (10.85347804637395 %)
# Broj igraca na poziciji LCM: 185, (4.563394178589048 %)
# Broj igraca na poziciji LM: 371, (9.151455352738036 %)
# Broj igraca na poziciji RAM: 5, (0.123334977799704 %)
# Broj igraca na poziciji CAM: 363, (8.95411938825851 %)
# Broj igraca na poziciji LAM: 4, (0.09866798223976321 %)
#
# ODBRANA: 689 (16.99555994079921 %)
# Broj igraca na poziciji RWB: 10, (0.246669955599408 %)
# Broj igraca na poziciji RB: 195, (4.8100641341884565 %)
# Broj igraca na poziciji RCB: 48, (1.1840157868771584 %)
# Broj igraca na poziciji CB: 116, (2.8613714849531324 %)
# Broj igraca na poziciji LCB: 69, (1.7020226936359153 %)
# Broj igraca na poziciji LB: 236, (5.821410952146029 %)
# Broj igraca na poziciji LWB: 15, (0.370004933399112 %)
#
# GOLMANI: 0 (0.0 %)

# %%
kprototypes = KPrototypes(n_clusters=27, random_state=0)
kprototypes.fit(df, categorical=categorical_features_index)

count = Counter(kprototypes.labels_)
number_and_percentige_per_cluster = {}

for value, times in count.most_common():
    number_and_percentige_per_cluster[value] = [times, (times / len(df)) * 100]
    
number_and_percentige_per_cluster
# Out:
# {19: [1003, 5.508870214752568],
#  10: [915, 5.0255396276157525],
#  9: [903, 4.959630911188005],
#  22: [866, 4.756412368869116],
#  24: [839, 4.608117756906684],
#  14: [832, 4.569671005657165],
#  23: [811, 4.454330751908606],
#  13: [778, 4.273081781732301],
#  16: [745, 4.091832811555995],
#  17: [744, 4.086340418520349],
#  4: [698, 3.8336903388806505],
#  21: [685, 3.762289229417257],
#  11: [685, 3.762289229417257],
#  26: [679, 3.7293348712033834],
#  3: [672, 3.690888119953864],
#  5: [645, 3.5425935079914317],
#  25: [591, 3.2460042840665677],
#  7: [575, 3.158125995496238],
#  6: [574, 3.1526336024605923],
#  8: [562, 3.0867248860328442],
#  15: [532, 2.9219530949634756],
#  12: [529, 2.9054759158565386],
#  20: [509, 2.7956280551436263],
#  18: [506, 2.779150876036689],
#  0: [476, 2.6143790849673203],
#  1: [447, 2.455099686933597],
#  2: [406, 2.229911572472126]}

# %%
df['cluster_marks'] = kprototypes.labels_

df_cluster_0 = df.loc[df['cluster_marks'] == 0]
df_cluster_1 = df.loc[df['cluster_marks'] == 1]
df_cluster_2 = df.loc[df['cluster_marks'] == 2]
df_cluster_3 = df.loc[df['cluster_marks'] == 3]
df_cluster_4 = df.loc[df['cluster_marks'] == 4]
df_cluster_5 = df.loc[df['cluster_marks'] == 5]
df_cluster_6 = df.loc[df['cluster_marks'] == 6]
df_cluster_7 = df.loc[df['cluster_marks'] == 7]
df_cluster_8 = df.loc[df['cluster_marks'] == 8]
df_cluster_9 = df.loc[df['cluster_marks'] == 9]
df_cluster_10 = df.loc[df['cluster_marks'] == 10]
df_cluster_11 = df.loc[df['cluster_marks'] == 11]
df_cluster_12 = df.loc[df['cluster_marks'] == 12]
df_cluster_13 = df.loc[df['cluster_marks'] == 13]
df_cluster_14 = df.loc[df['cluster_marks'] == 14]
df_cluster_15 = df.loc[df['cluster_marks'] == 15]
df_cluster_16 = df.loc[df['cluster_marks'] == 16]
df_cluster_17 = df.loc[df['cluster_marks'] == 17]
df_cluster_18 = df.loc[df['cluster_marks'] == 18]
df_cluster_19 = df.loc[df['cluster_marks'] == 19]
df_cluster_20 = df.loc[df['cluster_marks'] == 20]
df_cluster_21 = df.loc[df['cluster_marks'] == 21]
df_cluster_22 = df.loc[df['cluster_marks'] == 22]
df_cluster_23 = df.loc[df['cluster_marks'] == 23]
df_cluster_24 = df.loc[df['cluster_marks'] == 24]
df_cluster_25 = df.loc[df['cluster_marks'] == 25]
df_cluster_26 = df.loc[df['cluster_marks'] == 26]

show_position_percentige_per_cluster(df_cluster_0, 0, len(df))
show_position_percentige_per_cluster(df_cluster_1, 1, len(df))
show_position_percentige_per_cluster(df_cluster_2, 2, len(df))
show_position_percentige_per_cluster(df_cluster_3, 3, len(df))
show_position_percentige_per_cluster(df_cluster_4, 4, len(df))
show_position_percentige_per_cluster(df_cluster_5, 5, len(df))
show_position_percentige_per_cluster(df_cluster_6, 6, len(df))
show_position_percentige_per_cluster(df_cluster_7, 7, len(df))
show_position_percentige_per_cluster(df_cluster_8, 8, len(df))
show_position_percentige_per_cluster(df_cluster_9, 9, len(df))
show_position_percentige_per_cluster(df_cluster_10, 10, len(df))
show_position_percentige_per_cluster(df_cluster_11, 11, len(df))
show_position_percentige_per_cluster(df_cluster_12, 12, len(df))
show_position_percentige_per_cluster(df_cluster_13, 13, len(df))
show_position_percentige_per_cluster(df_cluster_14, 14, len(df))
show_position_percentige_per_cluster(df_cluster_15, 15, len(df))
show_position_percentige_per_cluster(df_cluster_16, 16, len(df))
show_position_percentige_per_cluster(df_cluster_17, 17, len(df))
show_position_percentige_per_cluster(df_cluster_18, 18, len(df))
show_position_percentige_per_cluster(df_cluster_19, 19, len(df))
show_position_percentige_per_cluster(df_cluster_20, 20, len(df))
show_position_percentige_per_cluster(df_cluster_21, 12, len(df))
show_position_percentige_per_cluster(df_cluster_22, 22, len(df))
show_position_percentige_per_cluster(df_cluster_23, 23, len(df))
show_position_percentige_per_cluster(df_cluster_24, 24, len(df))
show_position_percentige_per_cluster(df_cluster_24, 25, len(df))
show_position_percentige_per_cluster(df_cluster_26, 26, len(df))
# Out:
# Broj igraca u klasteru 0: 476, (2.6143790849673203 %)
#
# NAPAD: 0 (0.0 %)
# Broj igraca na poziciji RF: 0, (0.0 %)
# Broj igraca na poziciji LF: 0, (0.0 %)
# Broj igraca na poziciji RW: 0, (0.0 %)
# Broj igraca na poziciji LW: 0, (0.0 %)
# Broj igraca na poziciji ST: 0, (0.0 %)
# Broj igraca na poziciji CF: 0, (0.0 %)
# Broj igraca na poziciji RS: 0, (0.0 %)
# Broj igraca na poziciji LS: 0, (0.0 %)
#
# VEZNI RED: 27 (5.6722689075630255 %)
# Broj igraca na poziciji RDM: 2, (0.42016806722689076 %)
# Broj igraca na poziciji CDM: 20, (4.201680672268908 %)
# Broj igraca na poziciji LDM: 0, (0.0 %)
# Broj igraca na poziciji RM: 0, (0.0 %)
# Broj igraca na poziciji RCM: 2, (0.42016806722689076 %)
# Broj igraca na poziciji CM: 2, (0.42016806722689076 %)
# Broj igraca na poziciji LCM: 1, (0.21008403361344538 %)
# Broj igraca na poziciji LM: 0, (0.0 %)
# Broj igraca na poziciji RAM: 0, (0.0 %)
# Broj igraca na poziciji CAM: 0, (0.0 %)
# Broj igraca na poziciji LAM: 0, (0.0 %)
#
# ODBRANA: 449 (94.32773109243698 %)
# Broj igraca na poziciji RWB: 0, (0.0 %)
# Broj igraca na poziciji RB: 3, (0.6302521008403361 %)
# Broj igraca na poziciji RCB: 99, (20.798319327731093 %)
# Broj igraca na poziciji CB: 237, (49.78991596638656 %)
# Broj igraca na poziciji LCB: 103, (21.638655462184875 %)
# Broj igraca na poziciji LB: 7, (1.4705882352941175 %)
# Broj igraca na poziciji LWB: 0, (0.0 %)
#
# GOLMANI: 0 (0.0 %)
#
# Broj igraca u klasteru 1: 447, (2.455099686933597 %)
#
# NAPAD: 0 (0.0 %)
# Broj igraca na poziciji RF: 0, (0.0 %)
# Broj igraca na poziciji LF: 0, (0.0 %)
# Broj igraca na poziciji RW: 0, (0.0 %)
# Broj igraca na poziciji LW: 0, (0.0 %)
# Broj igraca na poziciji ST: 0, (0.0 %)
# Broj igraca na poziciji CF: 0, (0.0 %)
# Broj igraca na poziciji RS: 0, (0.0 %)
# Broj igraca na poziciji LS: 0, (0.0 %)
#
# VEZNI RED: 81 (18.120805369127517 %)
# Broj igraca na poziciji RDM: 19, (4.250559284116331 %)
# Broj igraca na poziciji CDM: 38, (8.501118568232663 %)
# Broj igraca na poziciji LDM: 13, (2.9082774049217 %)
# Broj igraca na poziciji RM: 0, (0.0 %)
# Broj igraca na poziciji RCM: 3, (0.6711409395973155 %)
# Broj igraca na poziciji CM: 2, (0.44742729306487694 %)
# Broj igraca na poziciji LCM: 6, (1.342281879194631 %)
# Broj igraca na poziciji LM: 0, (0.0 %)
# Broj igraca na poziciji RAM: 0, (0.0 %)
# Broj igraca na poziciji CAM: 0, (0.0 %)
# Broj igraca na poziciji LAM: 0, (0.0 %)
#
# ODBRANA: 366 (81.87919463087249 %)
# Broj igraca na poziciji RWB: 2, (0.44742729306487694 %)
# Broj igraca na poziciji RB: 11, (2.460850111856823 %)
# Broj igraca na poziciji RCB: 85, (19.015659955257274 %)
# Broj igraca na poziciji CB: 156, (34.899328859060404 %)
# Broj igraca na poziciji LCB: 91, (20.3579418344519 %)
# Broj igraca na poziciji LB: 19, (4.250559284116331 %)
# Broj igraca na poziciji LWB: 2, (0.44742729306487694 %)
#
# GOLMANI: 0 (0.0 %)
#
# Broj igraca u klasteru 2: 406, (2.229911572472126 %)
#
# NAPAD: 0 (0.0 %)
# Broj igraca na poziciji RF: 0, (0.0 %)
# Broj igraca na poziciji LF: 0, (0.0 %)
# Broj igraca na poziciji RW: 0, (0.0 %)
# Broj igraca na poziciji LW: 0, (0.0 %)
# Broj igraca na poziciji ST: 0, (0.0 %)
# Broj igraca na poziciji CF: 0, (0.0 %)
# Broj igraca na poziciji RS: 0, (0.0 %)
# Broj igraca na poziciji LS: 0, (0.0 %)
#
# VEZNI RED: 66 (16.25615763546798 %)
# Broj igraca na poziciji RDM: 9, (2.2167487684729066 %)
# Broj igraca na poziciji CDM: 36, (8.866995073891626 %)
# Broj igraca na poziciji LDM: 10, (2.4630541871921183 %)
# Broj igraca na poziciji RM: 0, (0.0 %)
# Broj igraca na poziciji RCM: 1, (0.24630541871921183 %)
# Broj igraca na poziciji CM: 3, (0.7389162561576355 %)
# Broj igraca na poziciji LCM: 6, (1.477832512315271 %)
# Broj igraca na poziciji LM: 1, (0.24630541871921183 %)
# Broj igraca na poziciji RAM: 0, (0.0 %)
# Broj igraca na poziciji CAM: 0, (0.0 %)
# Broj igraca na poziciji LAM: 0, (0.0 %)
#
# ODBRANA: 340 (83.74384236453201 %)
# Broj igraca na poziciji RWB: 3, (0.7389162561576355 %)
# Broj igraca na poziciji RB: 27, (6.65024630541872 %)
# Broj igraca na poziciji RCB: 112, (27.586206896551722 %)
# Broj igraca na poziciji CB: 95, (23.39901477832512 %)
# Broj igraca na poziciji LCB: 79, (19.458128078817737 %)
# Broj igraca na poziciji LB: 24, (5.911330049261084 %)
# Broj igraca na poziciji LWB: 0, (0.0 %)
#
# GOLMANI: 0 (0.0 %)
#
# Broj igraca u klasteru 3: 672, (3.690888119953864 %)
#
# NAPAD: 10 (1.488095238095238 %)
# Broj igraca na poziciji RF: 0, (0.0 %)
# Broj igraca na poziciji LF: 0, (0.0 %)
# Broj igraca na poziciji RW: 5, (0.744047619047619 %)
# Broj igraca na poziciji LW: 3, (0.4464285714285714 %)
# Broj igraca na poziciji ST: 2, (0.2976190476190476 %)
# Broj igraca na poziciji CF: 0, (0.0 %)
# Broj igraca na poziciji RS: 0, (0.0 %)
# Broj igraca na poziciji LS: 0, (0.0 %)
#
# VEZNI RED: 281 (41.81547619047619 %)
# Broj igraca na poziciji RDM: 13, (1.9345238095238095 %)
# Broj igraca na poziciji CDM: 79, (11.755952380952381 %)
# Broj igraca na poziciji LDM: 12, (1.7857142857142856 %)
# Broj igraca na poziciji RM: 21, (3.125 %)
# Broj igraca na poziciji RCM: 22, (3.273809523809524 %)
# Broj igraca na poziciji CM: 85, (12.648809523809524 %)
# Broj igraca na poziciji LCM: 22, (3.273809523809524 %)
# Broj igraca na poziciji LM: 14, (2.083333333333333 %)
# Broj igraca na poziciji RAM: 0, (0.0 %)
# Broj igraca na poziciji CAM: 13, (1.9345238095238095 %)
# Broj igraca na poziciji LAM: 0, (0.0 %)
#
# ODBRANA: 381 (56.69642857142857 %)
# Broj igraca na poziciji RWB: 9, (1.3392857142857142 %)
# Broj igraca na poziciji RB: 140, (20.833333333333336 %)
# Broj igraca na poziciji RCB: 12, (1.7857142857142856 %)
# Broj igraca na poziciji CB: 16, (2.380952380952381 %)
# Broj igraca na poziciji LCB: 8, (1.1904761904761905 %)
# Broj igraca na poziciji LB: 187, (27.827380952380953 %)
# Broj igraca na poziciji LWB: 9, (1.3392857142857142 %)
#
# GOLMANI: 0 (0.0 %)
#
# Broj igraca u klasteru 4: 698, (3.8336903388806505 %)
#
# NAPAD: 541 (77.50716332378224 %)
# Broj igraca na poziciji RF: 0, (0.0 %)
# Broj igraca na poziciji LF: 0, (0.0 %)
# Broj igraca na poziciji RW: 22, (3.151862464183381 %)
# Broj igraca na poziciji LW: 31, (4.441260744985674 %)
# Broj igraca na poziciji ST: 411, (58.88252148997135 %)
# Broj igraca na poziciji CF: 11, (1.5759312320916905 %)
# Broj igraca na poziciji RS: 32, (4.584527220630372 %)
# Broj igraca na poziciji LS: 34, (4.871060171919771 %)
#
# VEZNI RED: 157 (22.492836676217763 %)
# Broj igraca na poziciji RDM: 0, (0.0 %)
# Broj igraca na poziciji CDM: 0, (0.0 %)
# Broj igraca na poziciji LDM: 0, (0.0 %)
# Broj igraca na poziciji RM: 68, (9.742120343839542 %)
# Broj igraca na poziciji RCM: 2, (0.28653295128939826 %)
# Broj igraca na poziciji CM: 2, (0.28653295128939826 %)
# Broj igraca na poziciji LCM: 0, (0.0 %)
# Broj igraca na poziciji LM: 57, (8.166189111747851 %)
# Broj igraca na poziciji RAM: 1, (0.14326647564469913 %)
# Broj igraca na poziciji CAM: 27, (3.8681948424068766 %)
# Broj igraca na poziciji LAM: 0, (0.0 %)
#
# ODBRANA: 0 (0.0 %)
# Broj igraca na poziciji RWB: 0, (0.0 %)
# Broj igraca na poziciji RB: 0, (0.0 %)
# Broj igraca na poziciji RCB: 0, (0.0 %)
# Broj igraca na poziciji CB: 0, (0.0 %)
# Broj igraca na poziciji LCB: 0, (0.0 %)
# Broj igraca na poziciji LB: 0, (0.0 %)
# Broj igraca na poziciji LWB: 0, (0.0 %)
#
# GOLMANI: 0 (0.0 %)
#
# Broj igraca u klasteru 5: 645, (3.5425935079914317 %)
#
# NAPAD: 31 (4.8062015503875966 %)
# Broj igraca na poziciji RF: 0, (0.0 %)
# Broj igraca na poziciji LF: 0, (0.0 %)
# Broj igraca na poziciji RW: 9, (1.3953488372093024 %)
# Broj igraca na poziciji LW: 12, (1.8604651162790697 %)
# Broj igraca na poziciji ST: 8, (1.2403100775193798 %)
# Broj igraca na poziciji CF: 0, (0.0 %)
# Broj igraca na poziciji RS: 2, (0.31007751937984496 %)
# Broj igraca na poziciji LS: 0, (0.0 %)
#
# VEZNI RED: 390 (60.46511627906976 %)
# Broj igraca na poziciji RDM: 19, (2.945736434108527 %)
# Broj igraca na poziciji CDM: 64, (9.922480620155039 %)
# Broj igraca na poziciji LDM: 17, (2.635658914728682 %)
# Broj igraca na poziciji RM: 34, (5.271317829457364 %)
# Broj igraca na poziciji RCM: 41, (6.3565891472868215 %)
# Broj igraca na poziciji CM: 94, (14.573643410852712 %)
# Broj igraca na poziciji LCM: 46, (7.131782945736434 %)
# Broj igraca na poziciji LM: 43, (6.666666666666667 %)
# Broj igraca na poziciji RAM: 0, (0.0 %)
# Broj igraca na poziciji CAM: 32, (4.961240310077519 %)
# Broj igraca na poziciji LAM: 0, (0.0 %)
#
# ODBRANA: 224 (34.72868217054263 %)
# Broj igraca na poziciji RWB: 6, (0.9302325581395349 %)
# Broj igraca na poziciji RB: 72, (11.162790697674419 %)
# Broj igraca na poziciji RCB: 9, (1.3953488372093024 %)
# Broj igraca na poziciji CB: 7, (1.0852713178294573 %)
# Broj igraca na poziciji LCB: 8, (1.2403100775193798 %)
# Broj igraca na poziciji LB: 117, (18.13953488372093 %)
# Broj igraca na poziciji LWB: 5, (0.7751937984496124 %)
#
# GOLMANI: 0 (0.0 %)
#
# Broj igraca u klasteru 6: 574, (3.1526336024605923 %)
#
# NAPAD: 2 (0.34843205574912894 %)
# Broj igraca na poziciji RF: 0, (0.0 %)
# Broj igraca na poziciji LF: 0, (0.0 %)
# Broj igraca na poziciji RW: 0, (0.0 %)
# Broj igraca na poziciji LW: 0, (0.0 %)
# Broj igraca na poziciji ST: 2, (0.34843205574912894 %)
# Broj igraca na poziciji CF: 0, (0.0 %)
# Broj igraca na poziciji RS: 0, (0.0 %)
# Broj igraca na poziciji LS: 0, (0.0 %)
#
# VEZNI RED: 102 (17.770034843205575 %)
# Broj igraca na poziciji RDM: 8, (1.3937282229965158 %)
# Broj igraca na poziciji CDM: 54, (9.40766550522648 %)
# Broj igraca na poziciji LDM: 4, (0.6968641114982579 %)
# Broj igraca na poziciji RM: 9, (1.5679442508710801 %)
# Broj igraca na poziciji RCM: 2, (0.34843205574912894 %)
# Broj igraca na poziciji CM: 14, (2.4390243902439024 %)
# Broj igraca na poziciji LCM: 2, (0.34843205574912894 %)
# Broj igraca na poziciji LM: 8, (1.3937282229965158 %)
# Broj igraca na poziciji RAM: 0, (0.0 %)
# Broj igraca na poziciji CAM: 1, (0.17421602787456447 %)
# Broj igraca na poziciji LAM: 0, (0.0 %)
#
# ODBRANA: 470 (81.8815331010453 %)
# Broj igraca na poziciji RWB: 9, (1.5679442508710801 %)
# Broj igraca na poziciji RB: 186, (32.40418118466899 %)
# Broj igraca na poziciji RCB: 30, (5.2264808362369335 %)
# Broj igraca na poziciji CB: 58, (10.104529616724738 %)
# Broj igraca na poziciji LCB: 33, (5.7491289198606275 %)
# Broj igraca na poziciji LB: 149, (25.958188153310104 %)
# Broj igraca na poziciji LWB: 5, (0.8710801393728222 %)
#
# GOLMANI: 0 (0.0 %)
#
# Broj igraca u klasteru 7: 575, (3.158125995496238 %)
#
# NAPAD: 21 (3.6521739130434785 %)
# Broj igraca na poziciji RF: 0, (0.0 %)
# Broj igraca na poziciji LF: 0, (0.0 %)
# Broj igraca na poziciji RW: 7, (1.2173913043478262 %)
# Broj igraca na poziciji LW: 5, (0.8695652173913043 %)
# Broj igraca na poziciji ST: 6, (1.0434782608695654 %)
# Broj igraca na poziciji CF: 1, (0.17391304347826086 %)
# Broj igraca na poziciji RS: 1, (0.17391304347826086 %)
# Broj igraca na poziciji LS: 1, (0.17391304347826086 %)
#
# VEZNI RED: 254 (44.173913043478265 %)
# Broj igraca na poziciji RDM: 13, (2.2608695652173916 %)
# Broj igraca na poziciji CDM: 45, (7.82608695652174 %)
# Broj igraca na poziciji LDM: 13, (2.2608695652173916 %)
# Broj igraca na poziciji RM: 23, (4.0 %)
# Broj igraca na poziciji RCM: 24, (4.173913043478262 %)
# Broj igraca na poziciji CM: 69, (12.0 %)
# Broj igraca na poziciji LCM: 18, (3.130434782608696 %)
# Broj igraca na poziciji LM: 22, (3.826086956521739 %)
# Broj igraca na poziciji RAM: 0, (0.0 %)
# Broj igraca na poziciji CAM: 27, (4.695652173913043 %)
# Broj igraca na poziciji LAM: 0, (0.0 %)
#
# ODBRANA: 300 (52.17391304347826 %)
# Broj igraca na poziciji RWB: 5, (0.8695652173913043 %)
# Broj igraca na poziciji RB: 162, (28.17391304347826 %)
# Broj igraca na poziciji RCB: 8, (1.391304347826087 %)
# Broj igraca na poziciji CB: 12, (2.086956521739131 %)
# Broj igraca na poziciji LCB: 7, (1.2173913043478262 %)
# Broj igraca na poziciji LB: 103, (17.91304347826087 %)
# Broj igraca na poziciji LWB: 3, (0.5217391304347827 %)
#
# GOLMANI: 0 (0.0 %)
#
# Broj igraca u klasteru 8: 562, (3.0867248860328442 %)
#
# NAPAD: 1 (0.1779359430604982 %)
# Broj igraca na poziciji RF: 0, (0.0 %)
# Broj igraca na poziciji LF: 0, (0.0 %)
# Broj igraca na poziciji RW: 0, (0.0 %)
# Broj igraca na poziciji LW: 0, (0.0 %)
# Broj igraca na poziciji ST: 1, (0.1779359430604982 %)
# Broj igraca na poziciji CF: 0, (0.0 %)
# Broj igraca na poziciji RS: 0, (0.0 %)
# Broj igraca na poziciji LS: 0, (0.0 %)
#
# VEZNI RED: 54 (9.608540925266903 %)
# Broj igraca na poziciji RDM: 2, (0.3558718861209964 %)
# Broj igraca na poziciji CDM: 32, (5.6939501779359425 %)
# Broj igraca na poziciji LDM: 6, (1.0676156583629894 %)
# Broj igraca na poziciji RM: 1, (0.1779359430604982 %)
# Broj igraca na poziciji RCM: 5, (0.8896797153024912 %)
# Broj igraca na poziciji CM: 5, (0.8896797153024912 %)
# Broj igraca na poziciji LCM: 3, (0.5338078291814947 %)
# Broj igraca na poziciji LM: 0, (0.0 %)
# Broj igraca na poziciji RAM: 0, (0.0 %)
# Broj igraca na poziciji CAM: 0, (0.0 %)
# Broj igraca na poziciji LAM: 0, (0.0 %)
#
# ODBRANA: 507 (90.2135231316726 %)
# Broj igraca na poziciji RWB: 2, (0.3558718861209964 %)
# Broj igraca na poziciji RB: 68, (12.099644128113878 %)
# Broj igraca na poziciji RCB: 75, (13.345195729537366 %)
# Broj igraca na poziciji CB: 216, (38.43416370106761 %)
# Broj igraca na poziciji LCB: 76, (13.523131672597867 %)
# Broj igraca na poziciji LB: 64, (11.387900355871885 %)
# Broj igraca na poziciji LWB: 6, (1.0676156583629894 %)
#
# GOLMANI: 0 (0.0 %)
#
# Broj igraca u klasteru 9: 903, (4.959630911188005 %)
#
# NAPAD: 1 (0.11074197120708748 %)
# Broj igraca na poziciji RF: 0, (0.0 %)
# Broj igraca na poziciji LF: 0, (0.0 %)
# Broj igraca na poziciji RW: 0, (0.0 %)
# Broj igraca na poziciji LW: 0, (0.0 %)
# Broj igraca na poziciji ST: 1, (0.11074197120708748 %)
# Broj igraca na poziciji CF: 0, (0.0 %)
# Broj igraca na poziciji RS: 0, (0.0 %)
# Broj igraca na poziciji LS: 0, (0.0 %)
#
# VEZNI RED: 0 (0.0 %)
# Broj igraca na poziciji RDM: 0, (0.0 %)
# Broj igraca na poziciji CDM: 0, (0.0 %)
# Broj igraca na poziciji LDM: 0, (0.0 %)
# Broj igraca na poziciji RM: 0, (0.0 %)
# Broj igraca na poziciji RCM: 0, (0.0 %)
# Broj igraca na poziciji CM: 0, (0.0 %)
# Broj igraca na poziciji LCM: 0, (0.0 %)
# Broj igraca na poziciji LM: 0, (0.0 %)
# Broj igraca na poziciji RAM: 0, (0.0 %)
# Broj igraca na poziciji CAM: 0, (0.0 %)
# Broj igraca na poziciji LAM: 0, (0.0 %)
#
# ODBRANA: 0 (0.0 %)
# Broj igraca na poziciji RWB: 0, (0.0 %)
# Broj igraca na poziciji RB: 0, (0.0 %)
# Broj igraca na poziciji RCB: 0, (0.0 %)
# Broj igraca na poziciji CB: 0, (0.0 %)
# Broj igraca na poziciji LCB: 0, (0.0 %)
# Broj igraca na poziciji LB: 0, (0.0 %)
# Broj igraca na poziciji LWB: 0, (0.0 %)
#
# GOLMANI: 902 (99.88925802879291 %)
#
# Broj igraca u klasteru 10: 915, (5.0255396276157525 %)
#
# NAPAD: 833 (91.03825136612022 %)
# Broj igraca na poziciji RF: 0, (0.0 %)
# Broj igraca na poziciji LF: 0, (0.0 %)
# Broj igraca na poziciji RW: 19, (2.0765027322404372 %)
# Broj igraca na poziciji LW: 21, (2.2950819672131146 %)
# Broj igraca na poziciji ST: 731, (79.89071038251366 %)
# Broj igraca na poziciji CF: 11, (1.2021857923497268 %)
# Broj igraca na poziciji RS: 28, (3.060109289617486 %)
# Broj igraca na poziciji LS: 23, (2.5136612021857925 %)
#
# VEZNI RED: 82 (8.961748633879782 %)
# Broj igraca na poziciji RDM: 0, (0.0 %)
# Broj igraca na poziciji CDM: 0, (0.0 %)
# Broj igraca na poziciji LDM: 0, (0.0 %)
# Broj igraca na poziciji RM: 44, (4.808743169398907 %)
# Broj igraca na poziciji RCM: 1, (0.1092896174863388 %)
# Broj igraca na poziciji CM: 2, (0.2185792349726776 %)
# Broj igraca na poziciji LCM: 1, (0.1092896174863388 %)
# Broj igraca na poziciji LM: 21, (2.2950819672131146 %)
# Broj igraca na poziciji RAM: 0, (0.0 %)
# Broj igraca na poziciji CAM: 13, (1.4207650273224044 %)
# Broj igraca na poziciji LAM: 0, (0.0 %)
#
# ODBRANA: 0 (0.0 %)
# Broj igraca na poziciji RWB: 0, (0.0 %)
# Broj igraca na poziciji RB: 0, (0.0 %)
# Broj igraca na poziciji RCB: 0, (0.0 %)
# Broj igraca na poziciji CB: 0, (0.0 %)
# Broj igraca na poziciji LCB: 0, (0.0 %)
# Broj igraca na poziciji LB: 0, (0.0 %)
# Broj igraca na poziciji LWB: 0, (0.0 %)
#
# GOLMANI: 0 (0.0 %)
#
# Broj igraca u klasteru 11: 685, (3.762289229417257 %)
#
# NAPAD: 0 (0.0 %)
# Broj igraca na poziciji RF: 0, (0.0 %)
# Broj igraca na poziciji LF: 0, (0.0 %)
# Broj igraca na poziciji RW: 0, (0.0 %)
# Broj igraca na poziciji LW: 0, (0.0 %)
# Broj igraca na poziciji ST: 0, (0.0 %)
# Broj igraca na poziciji CF: 0, (0.0 %)
# Broj igraca na poziciji RS: 0, (0.0 %)
# Broj igraca na poziciji LS: 0, (0.0 %)
#
# VEZNI RED: 11 (1.6058394160583942 %)
# Broj igraca na poziciji RDM: 0, (0.0 %)
# Broj igraca na poziciji CDM: 7, (1.0218978102189782 %)
# Broj igraca na poziciji LDM: 1, (0.145985401459854 %)
# Broj igraca na poziciji RM: 0, (0.0 %)
# Broj igraca na poziciji RCM: 0, (0.0 %)
# Broj igraca na poziciji CM: 2, (0.291970802919708 %)
# Broj igraca na poziciji LCM: 0, (0.0 %)
# Broj igraca na poziciji LM: 0, (0.0 %)
# Broj igraca na poziciji RAM: 0, (0.0 %)
# Broj igraca na poziciji CAM: 1, (0.145985401459854 %)
# Broj igraca na poziciji LAM: 0, (0.0 %)
#
# ODBRANA: 674 (98.3941605839416 %)
# Broj igraca na poziciji RWB: 1, (0.145985401459854 %)
# Broj igraca na poziciji RB: 7, (1.0218978102189782 %)
# Broj igraca na poziciji RCB: 140, (20.437956204379564 %)
# Broj igraca na poziciji CB: 381, (55.620437956204384 %)
# Broj igraca na poziciji LCB: 133, (19.416058394160586 %)
# Broj igraca na poziciji LB: 11, (1.6058394160583942 %)
# Broj igraca na poziciji LWB: 1, (0.145985401459854 %)
#
# GOLMANI: 0 (0.0 %)
#
# Broj igraca u klasteru 12: 529, (2.9054759158565386 %)
#
# NAPAD: 464 (87.71266540642722 %)
# Broj igraca na poziciji RF: 0, (0.0 %)
# Broj igraca na poziciji LF: 1, (0.1890359168241966 %)
# Broj igraca na poziciji RW: 11, (2.0793950850661624 %)
# Broj igraca na poziciji LW: 8, (1.5122873345935728 %)
# Broj igraca na poziciji ST: 329, (62.19281663516069 %)
# Broj igraca na poziciji CF: 5, (0.945179584120983 %)
# Broj igraca na poziciji RS: 55, (10.396975425330812 %)
# Broj igraca na poziciji LS: 55, (10.396975425330812 %)
#
# VEZNI RED: 65 (12.287334593572778 %)
# Broj igraca na poziciji RDM: 0, (0.0 %)
# Broj igraca na poziciji CDM: 0, (0.0 %)
# Broj igraca na poziciji LDM: 0, (0.0 %)
# Broj igraca na poziciji RM: 18, (3.402646502835539 %)
# Broj igraca na poziciji RCM: 0, (0.0 %)
# Broj igraca na poziciji CM: 0, (0.0 %)
# Broj igraca na poziciji LCM: 0, (0.0 %)
# Broj igraca na poziciji LM: 23, (4.3478260869565215 %)
# Broj igraca na poziciji RAM: 0, (0.0 %)
# Broj igraca na poziciji CAM: 23, (4.3478260869565215 %)
# Broj igraca na poziciji LAM: 1, (0.1890359168241966 %)
#
# ODBRANA: 0 (0.0 %)
# Broj igraca na poziciji RWB: 0, (0.0 %)
# Broj igraca na poziciji RB: 0, (0.0 %)
# Broj igraca na poziciji RCB: 0, (0.0 %)
# Broj igraca na poziciji CB: 0, (0.0 %)
# Broj igraca na poziciji LCB: 0, (0.0 %)
# Broj igraca na poziciji LB: 0, (0.0 %)
# Broj igraca na poziciji LWB: 0, (0.0 %)
#
# GOLMANI: 0 (0.0 %)
#
# Broj igraca u klasteru 13: 778, (4.273081781732301 %)
#
# NAPAD: 59 (7.583547557840617 %)
# Broj igraca na poziciji RF: 0, (0.0 %)
# Broj igraca na poziciji LF: 1, (0.12853470437017994 %)
# Broj igraca na poziciji RW: 11, (1.4138817480719794 %)
# Broj igraca na poziciji LW: 20, (2.570694087403599 %)
# Broj igraca na poziciji ST: 24, (3.0848329048843186 %)
# Broj igraca na poziciji CF: 0, (0.0 %)
# Broj igraca na poziciji RS: 0, (0.0 %)
# Broj igraca na poziciji LS: 3, (0.3856041131105398 %)
#
# VEZNI RED: 571 (73.39331619537275 %)
# Broj igraca na poziciji RDM: 19, (2.442159383033419 %)
# Broj igraca na poziciji CDM: 43, (5.526992287917738 %)
# Broj igraca na poziciji LDM: 18, (2.313624678663239 %)
# Broj igraca na poziciji RM: 79, (10.154241645244216 %)
# Broj igraca na poziciji RCM: 37, (4.755784061696658 %)
# Broj igraca na poziciji CM: 188, (24.164524421593832 %)
# Broj igraca na poziciji LCM: 32, (4.113110539845758 %)
# Broj igraca na poziciji LM: 86, (11.053984575835475 %)
# Broj igraca na poziciji RAM: 0, (0.0 %)
# Broj igraca na poziciji CAM: 69, (8.868894601542417 %)
# Broj igraca na poziciji LAM: 0, (0.0 %)
#
# ODBRANA: 148 (19.02313624678663 %)
# Broj igraca na poziciji RWB: 5, (0.6426735218508998 %)
# Broj igraca na poziciji RB: 60, (7.712082262210797 %)
# Broj igraca na poziciji RCB: 3, (0.3856041131105398 %)
# Broj igraca na poziciji CB: 4, (0.5141388174807198 %)
# Broj igraca na poziciji LCB: 1, (0.12853470437017994 %)
# Broj igraca na poziciji LB: 67, (8.611825192802057 %)
# Broj igraca na poziciji LWB: 8, (1.0282776349614395 %)
#
# GOLMANI: 0 (0.0 %)
#
# Broj igraca u klasteru 14: 832, (4.569671005657165 %)
#
# NAPAD: 44 (5.288461538461538 %)
# Broj igraca na poziciji RF: 2, (0.2403846153846154 %)
# Broj igraca na poziciji LF: 1, (0.1201923076923077 %)
# Broj igraca na poziciji RW: 10, (1.201923076923077 %)
# Broj igraca na poziciji LW: 7, (0.8413461538461539 %)
# Broj igraca na poziciji ST: 15, (1.8028846153846152 %)
# Broj igraca na poziciji CF: 2, (0.2403846153846154 %)
# Broj igraca na poziciji RS: 6, (0.7211538461538461 %)
# Broj igraca na poziciji LS: 1, (0.1201923076923077 %)
#
# VEZNI RED: 641 (77.04326923076923 %)
# Broj igraca na poziciji RDM: 44, (5.288461538461538 %)
# Broj igraca na poziciji CDM: 135, (16.22596153846154 %)
# Broj igraca na poziciji LDM: 45, (5.408653846153847 %)
# Broj igraca na poziciji RM: 53, (6.3701923076923075 %)
# Broj igraca na poziciji RCM: 71, (8.533653846153847 %)
# Broj igraca na poziciji CM: 116, (13.942307692307693 %)
# Broj igraca na poziciji LCM: 72, (8.653846153846153 %)
# Broj igraca na poziciji LM: 38, (4.567307692307692 %)
# Broj igraca na poziciji RAM: 1, (0.1201923076923077 %)
# Broj igraca na poziciji CAM: 66, (7.9326923076923075 %)
# Broj igraca na poziciji LAM: 0, (0.0 %)
#
# ODBRANA: 147 (17.668269230769234 %)
# Broj igraca na poziciji RWB: 1, (0.1201923076923077 %)
# Broj igraca na poziciji RB: 37, (4.447115384615385 %)
# Broj igraca na poziciji RCB: 13, (1.5625 %)
# Broj igraca na poziciji CB: 28, (3.3653846153846154 %)
# Broj igraca na poziciji LCB: 18, (2.1634615384615383 %)
# Broj igraca na poziciji LB: 47, (5.649038461538462 %)
# Broj igraca na poziciji LWB: 3, (0.3605769230769231 %)
#
# GOLMANI: 0 (0.0 %)
#
# Broj igraca u klasteru 15: 532, (2.9219530949634756 %)
#
# NAPAD: 0 (0.0 %)
# Broj igraca na poziciji RF: 0, (0.0 %)
# Broj igraca na poziciji LF: 0, (0.0 %)
# Broj igraca na poziciji RW: 0, (0.0 %)
# Broj igraca na poziciji LW: 0, (0.0 %)
# Broj igraca na poziciji ST: 0, (0.0 %)
# Broj igraca na poziciji CF: 0, (0.0 %)
# Broj igraca na poziciji RS: 0, (0.0 %)
# Broj igraca na poziciji LS: 0, (0.0 %)
#
# VEZNI RED: 0 (0.0 %)
# Broj igraca na poziciji RDM: 0, (0.0 %)
# Broj igraca na poziciji CDM: 0, (0.0 %)
# Broj igraca na poziciji LDM: 0, (0.0 %)
# Broj igraca na poziciji RM: 0, (0.0 %)
# Broj igraca na poziciji RCM: 0, (0.0 %)
# Broj igraca na poziciji CM: 0, (0.0 %)
# Broj igraca na poziciji LCM: 0, (0.0 %)
# Broj igraca na poziciji LM: 0, (0.0 %)
# Broj igraca na poziciji RAM: 0, (0.0 %)
# Broj igraca na poziciji CAM: 0, (0.0 %)
# Broj igraca na poziciji LAM: 0, (0.0 %)
#
# ODBRANA: 0 (0.0 %)
# Broj igraca na poziciji RWB: 0, (0.0 %)
# Broj igraca na poziciji RB: 0, (0.0 %)
# Broj igraca na poziciji RCB: 0, (0.0 %)
# Broj igraca na poziciji CB: 0, (0.0 %)
# Broj igraca na poziciji LCB: 0, (0.0 %)
# Broj igraca na poziciji LB: 0, (0.0 %)
# Broj igraca na poziciji LWB: 0, (0.0 %)
#
# GOLMANI: 532 (100.0 %)
#
# Broj igraca u klasteru 16: 745, (4.091832811555995 %)
#
# NAPAD: 5 (0.6711409395973155 %)
# Broj igraca na poziciji RF: 0, (0.0 %)
# Broj igraca na poziciji LF: 0, (0.0 %)
# Broj igraca na poziciji RW: 1, (0.1342281879194631 %)
# Broj igraca na poziciji LW: 0, (0.0 %)
# Broj igraca na poziciji ST: 4, (0.5369127516778524 %)
# Broj igraca na poziciji CF: 0, (0.0 %)
# Broj igraca na poziciji RS: 0, (0.0 %)
# Broj igraca na poziciji LS: 0, (0.0 %)
#
# VEZNI RED: 94 (12.61744966442953 %)
# Broj igraca na poziciji RDM: 1, (0.1342281879194631 %)
# Broj igraca na poziciji CDM: 34, (4.563758389261745 %)
# Broj igraca na poziciji LDM: 2, (0.2684563758389262 %)
# Broj igraca na poziciji RM: 7, (0.9395973154362416 %)
# Broj igraca na poziciji RCM: 0, (0.0 %)
# Broj igraca na poziciji CM: 43, (5.771812080536913 %)
# Broj igraca na poziciji LCM: 1, (0.1342281879194631 %)
# Broj igraca na poziciji LM: 4, (0.5369127516778524 %)
# Broj igraca na poziciji RAM: 0, (0.0 %)
# Broj igraca na poziciji CAM: 2, (0.2684563758389262 %)
# Broj igraca na poziciji LAM: 0, (0.0 %)
#
# ODBRANA: 646 (86.71140939597315 %)
# Broj igraca na poziciji RWB: 3, (0.4026845637583893 %)
# Broj igraca na poziciji RB: 81, (10.87248322147651 %)
# Broj igraca na poziciji RCB: 30, (4.026845637583892 %)
# Broj igraca na poziciji CB: 422, (56.644295302013425 %)
# Broj igraca na poziciji LCB: 24, (3.2214765100671143 %)
# Broj igraca na poziciji LB: 84, (11.275167785234899 %)
# Broj igraca na poziciji LWB: 2, (0.2684563758389262 %)
#
# GOLMANI: 0 (0.0 %)
#
# Broj igraca u klasteru 17: 744, (4.086340418520349 %)
#
# NAPAD: 21 (2.82258064516129 %)
# Broj igraca na poziciji RF: 0, (0.0 %)
# Broj igraca na poziciji LF: 0, (0.0 %)
# Broj igraca na poziciji RW: 4, (0.5376344086021506 %)
# Broj igraca na poziciji LW: 5, (0.6720430107526881 %)
# Broj igraca na poziciji ST: 6, (0.8064516129032258 %)
# Broj igraca na poziciji CF: 3, (0.4032258064516129 %)
# Broj igraca na poziciji RS: 2, (0.2688172043010753 %)
# Broj igraca na poziciji LS: 1, (0.13440860215053765 %)
#
# VEZNI RED: 551 (74.05913978494624 %)
# Broj igraca na poziciji RDM: 7, (0.9408602150537635 %)
# Broj igraca na poziciji CDM: 95, (12.768817204301076 %)
# Broj igraca na poziciji LDM: 14, (1.881720430107527 %)
# Broj igraca na poziciji RM: 40, (5.376344086021505 %)
# Broj igraca na poziciji RCM: 18, (2.4193548387096775 %)
# Broj igraca na poziciji CM: 282, (37.903225806451616 %)
# Broj igraca na poziciji LCM: 16, (2.1505376344086025 %)
# Broj igraca na poziciji LM: 39, (5.241935483870968 %)
# Broj igraca na poziciji RAM: 1, (0.13440860215053765 %)
# Broj igraca na poziciji CAM: 39, (5.241935483870968 %)
# Broj igraca na poziciji LAM: 0, (0.0 %)
#
# ODBRANA: 172 (23.118279569892472 %)
# Broj igraca na poziciji RWB: 10, (1.3440860215053763 %)
# Broj igraca na poziciji RB: 58, (7.795698924731183 %)
# Broj igraca na poziciji RCB: 3, (0.4032258064516129 %)
# Broj igraca na poziciji CB: 19, (2.553763440860215 %)
# Broj igraca na poziciji LCB: 8, (1.0752688172043012 %)
# Broj igraca na poziciji LB: 69, (9.274193548387096 %)
# Broj igraca na poziciji LWB: 5, (0.6720430107526881 %)
#
# GOLMANI: 0 (0.0 %)
#
# Broj igraca u klasteru 18: 506, (2.779150876036689 %)
#
# NAPAD: 9 (1.7786561264822136 %)
# Broj igraca na poziciji RF: 0, (0.0 %)
# Broj igraca na poziciji LF: 0, (0.0 %)
# Broj igraca na poziciji RW: 0, (0.0 %)
# Broj igraca na poziciji LW: 1, (0.1976284584980237 %)
# Broj igraca na poziciji ST: 7, (1.383399209486166 %)
# Broj igraca na poziciji CF: 0, (0.0 %)
# Broj igraca na poziciji RS: 0, (0.0 %)
# Broj igraca na poziciji LS: 1, (0.1976284584980237 %)
#
# VEZNI RED: 205 (40.51383399209486 %)
# Broj igraca na poziciji RDM: 3, (0.592885375494071 %)
# Broj igraca na poziciji CDM: 59, (11.6600790513834 %)
# Broj igraca na poziciji LDM: 4, (0.7905138339920948 %)
# Broj igraca na poziciji RM: 14, (2.766798418972332 %)
# Broj igraca na poziciji RCM: 3, (0.592885375494071 %)
# Broj igraca na poziciji CM: 93, (18.379446640316203 %)
# Broj igraca na poziciji LCM: 4, (0.7905138339920948 %)
# Broj igraca na poziciji LM: 17, (3.3596837944664033 %)
# Broj igraca na poziciji RAM: 0, (0.0 %)
# Broj igraca na poziciji CAM: 8, (1.5810276679841897 %)
# Broj igraca na poziciji LAM: 0, (0.0 %)
#
# ODBRANA: 292 (57.70750988142292 %)
# Broj igraca na poziciji RWB: 12, (2.371541501976284 %)
# Broj igraca na poziciji RB: 95, (18.774703557312254 %)
# Broj igraca na poziciji RCB: 4, (0.7905138339920948 %)
# Broj igraca na poziciji CB: 41, (8.102766798418973 %)
# Broj igraca na poziciji LCB: 7, (1.383399209486166 %)
# Broj igraca na poziciji LB: 126, (24.90118577075099 %)
# Broj igraca na poziciji LWB: 7, (1.383399209486166 %)
#
# GOLMANI: 0 (0.0 %)
#
# Broj igraca u klasteru 19: 1003, (5.508870214752568 %)
#
# NAPAD: 166 (16.550348953140578 %)
# Broj igraca na poziciji RF: 5, (0.4985044865403789 %)
# Broj igraca na poziciji LF: 5, (0.4985044865403789 %)
# Broj igraca na poziciji RW: 33, (3.290129611166501 %)
# Broj igraca na poziciji LW: 34, (3.389830508474576 %)
# Broj igraca na poziciji ST: 53, (5.284147557328016 %)
# Broj igraca na poziciji CF: 9, (0.897308075772682 %)
# Broj igraca na poziciji RS: 10, (0.9970089730807578 %)
# Broj igraca na poziciji LS: 17, (1.694915254237288 %)
#
# VEZNI RED: 691 (68.89332003988035 %)
# Broj igraca na poziciji RDM: 27, (2.6919242273180455 %)
# Broj igraca na poziciji CDM: 30, (2.991026919242273 %)
# Broj igraca na poziciji LDM: 33, (3.290129611166501 %)
# Broj igraca na poziciji RM: 107, (10.667996011964108 %)
# Broj igraca na poziciji RCM: 74, (7.377866400797608 %)
# Broj igraca na poziciji CM: 143, (14.257228315054835 %)
# Broj igraca na poziciji LCM: 66, (6.580259222333002 %)
# Broj igraca na poziciji LM: 93, (9.272183449651047 %)
# Broj igraca na poziciji RAM: 4, (0.3988035892323031 %)
# Broj igraca na poziciji CAM: 112, (11.166500498504487 %)
# Broj igraca na poziciji LAM: 2, (0.19940179461615154 %)
#
# ODBRANA: 146 (14.556331006979061 %)
# Broj igraca na poziciji RWB: 3, (0.29910269192422734 %)
# Broj igraca na poziciji RB: 55, (5.483549351944168 %)
# Broj igraca na poziciji RCB: 1, (0.09970089730807577 %)
# Broj igraca na poziciji CB: 5, (0.4985044865403789 %)
# Broj igraca na poziciji LCB: 7, (0.6979062811565304 %)
# Broj igraca na poziciji LB: 70, (6.979062811565304 %)
# Broj igraca na poziciji LWB: 5, (0.4985044865403789 %)
#
# GOLMANI: 0 (0.0 %)
#
# Broj igraca u klasteru 20: 509, (2.7956280551436263 %)
#
# NAPAD: 6 (1.1787819253438114 %)
# Broj igraca na poziciji RF: 0, (0.0 %)
# Broj igraca na poziciji LF: 0, (0.0 %)
# Broj igraca na poziciji RW: 3, (0.5893909626719057 %)
# Broj igraca na poziciji LW: 1, (0.19646365422396855 %)
# Broj igraca na poziciji ST: 2, (0.3929273084479371 %)
# Broj igraca na poziciji CF: 0, (0.0 %)
# Broj igraca na poziciji RS: 0, (0.0 %)
# Broj igraca na poziciji LS: 0, (0.0 %)
#
# VEZNI RED: 243 (47.74066797642436 %)
# Broj igraca na poziciji RDM: 20, (3.9292730844793713 %)
# Broj igraca na poziciji CDM: 47, (9.233791748526523 %)
# Broj igraca na poziciji LDM: 15, (2.9469548133595285 %)
# Broj igraca na poziciji RM: 20, (3.9292730844793713 %)
# Broj igraca na poziciji RCM: 21, (4.12573673870334 %)
# Broj igraca na poziciji CM: 57, (11.19842829076621 %)
# Broj igraca na poziciji LCM: 28, (5.50098231827112 %)
# Broj igraca na poziciji LM: 18, (3.536345776031434 %)
# Broj igraca na poziciji RAM: 0, (0.0 %)
# Broj igraca na poziciji CAM: 15, (2.9469548133595285 %)
# Broj igraca na poziciji LAM: 2, (0.3929273084479371 %)
#
# ODBRANA: 260 (51.080550098231825 %)
# Broj igraca na poziciji RWB: 8, (1.5717092337917484 %)
# Broj igraca na poziciji RB: 138, (27.111984282907663 %)
# Broj igraca na poziciji RCB: 6, (1.1787819253438114 %)
# Broj igraca na poziciji CB: 4, (0.7858546168958742 %)
# Broj igraca na poziciji LCB: 6, (1.1787819253438114 %)
# Broj igraca na poziciji LB: 88, (17.288801571709232 %)
# Broj igraca na poziciji LWB: 10, (1.9646365422396856 %)
#
# GOLMANI: 0 (0.0 %)
#
# Broj igraca u klasteru 12: 685, (3.762289229417257 %)
#
# NAPAD: 486 (70.94890510948905 %)
# Broj igraca na poziciji RF: 4, (0.583941605839416 %)
# Broj igraca na poziciji LF: 1, (0.145985401459854 %)
# Broj igraca na poziciji RW: 25, (3.64963503649635 %)
# Broj igraca na poziciji LW: 24, (3.5036496350364965 %)
# Broj igraca na poziciji ST: 354, (51.67883211678832 %)
# Broj igraca na poziciji CF: 6, (0.8759124087591241 %)
# Broj igraca na poziciji RS: 34, (4.963503649635037 %)
# Broj igraca na poziciji LS: 38, (5.547445255474453 %)
#
# VEZNI RED: 197 (28.759124087591243 %)
# Broj igraca na poziciji RDM: 2, (0.291970802919708 %)
# Broj igraca na poziciji CDM: 0, (0.0 %)
# Broj igraca na poziciji LDM: 0, (0.0 %)
# Broj igraca na poziciji RM: 74, (10.802919708029197 %)
# Broj igraca na poziciji RCM: 3, (0.43795620437956206 %)
# Broj igraca na poziciji CM: 2, (0.291970802919708 %)
# Broj igraca na poziciji LCM: 5, (0.7299270072992701 %)
# Broj igraca na poziciji LM: 69, (10.072992700729927 %)
# Broj igraca na poziciji RAM: 0, (0.0 %)
# Broj igraca na poziciji CAM: 40, (5.839416058394161 %)
# Broj igraca na poziciji LAM: 2, (0.291970802919708 %)
#
# ODBRANA: 2 (0.291970802919708 %)
# Broj igraca na poziciji RWB: 1, (0.145985401459854 %)
# Broj igraca na poziciji RB: 0, (0.0 %)
# Broj igraca na poziciji RCB: 1, (0.145985401459854 %)
# Broj igraca na poziciji CB: 0, (0.0 %)
# Broj igraca na poziciji LCB: 0, (0.0 %)
# Broj igraca na poziciji LB: 0, (0.0 %)
# Broj igraca na poziciji LWB: 0, (0.0 %)
#
# GOLMANI: 0 (0.0 %)
#
# Broj igraca u klasteru 22: 866, (4.756412368869116 %)
#
# NAPAD: 250 (28.868360277136258 %)
# Broj igraca na poziciji RF: 3, (0.3464203233256351 %)
# Broj igraca na poziciji LF: 3, (0.3464203233256351 %)
# Broj igraca na poziciji RW: 81, (9.353348729792147 %)
# Broj igraca na poziciji LW: 73, (8.429561200923787 %)
# Broj igraca na poziciji ST: 54, (6.235565819861432 %)
# Broj igraca na poziciji CF: 8, (0.9237875288683602 %)
# Broj igraca na poziciji RS: 16, (1.8475750577367205 %)
# Broj igraca na poziciji LS: 12, (1.3856812933025404 %)
#
# VEZNI RED: 614 (70.90069284064666 %)
# Broj igraca na poziciji RDM: 4, (0.4618937644341801 %)
# Broj igraca na poziciji CDM: 0, (0.0 %)
# Broj igraca na poziciji LDM: 1, (0.11547344110854503 %)
# Broj igraca na poziciji RM: 165, (19.053117782909933 %)
# Broj igraca na poziciji RCM: 8, (0.9237875288683602 %)
# Broj igraca na poziciji CM: 11, (1.2702078521939952 %)
# Broj igraca na poziciji LCM: 20, (2.3094688221709005 %)
# Broj igraca na poziciji LM: 213, (24.59584295612009 %)
# Broj igraca na poziciji RAM: 13, (1.5011547344110854 %)
# Broj igraca na poziciji CAM: 166, (19.168591224018474 %)
# Broj igraca na poziciji LAM: 13, (1.5011547344110854 %)
#
# ODBRANA: 2 (0.23094688221709006 %)
# Broj igraca na poziciji RWB: 0, (0.0 %)
# Broj igraca na poziciji RB: 0, (0.0 %)
# Broj igraca na poziciji RCB: 0, (0.0 %)
# Broj igraca na poziciji CB: 0, (0.0 %)
# Broj igraca na poziciji LCB: 0, (0.0 %)
# Broj igraca na poziciji LB: 1, (0.11547344110854503 %)
# Broj igraca na poziciji LWB: 1, (0.11547344110854503 %)
#
# GOLMANI: 0 (0.0 %)
#
# Broj igraca u klasteru 23: 811, (4.454330751908606 %)
#
# NAPAD: 84 (10.35758323057953 %)
# Broj igraca na poziciji RF: 1, (0.12330456226880394 %)
# Broj igraca na poziciji LF: 0, (0.0 %)
# Broj igraca na poziciji RW: 1, (0.12330456226880394 %)
# Broj igraca na poziciji LW: 3, (0.36991368680641185 %)
# Broj igraca na poziciji ST: 74, (9.124537607891492 %)
# Broj igraca na poziciji CF: 0, (0.0 %)
# Broj igraca na poziciji RS: 3, (0.36991368680641185 %)
# Broj igraca na poziciji LS: 2, (0.2466091245376079 %)
#
# VEZNI RED: 395 (48.70530209617756 %)
# Broj igraca na poziciji RDM: 32, (3.945745992601726 %)
# Broj igraca na poziciji CDM: 128, (15.782983970406905 %)
# Broj igraca na poziciji LDM: 33, (4.069050554870531 %)
# Broj igraca na poziciji RM: 11, (1.3563501849568433 %)
# Broj igraca na poziciji RCM: 40, (4.932182490752158 %)
# Broj igraca na poziciji CM: 91, (11.22071516646116 %)
# Broj igraca na poziciji LCM: 31, (3.822441430332922 %)
# Broj igraca na poziciji LM: 13, (1.6029593094944512 %)
# Broj igraca na poziciji RAM: 0, (0.0 %)
# Broj igraca na poziciji CAM: 16, (1.972872996300863 %)
# Broj igraca na poziciji LAM: 0, (0.0 %)
#
# ODBRANA: 332 (40.93711467324291 %)
# Broj igraca na poziciji RWB: 6, (0.7398273736128237 %)
# Broj igraca na poziciji RB: 89, (10.974106041923552 %)
# Broj igraca na poziciji RCB: 31, (3.822441430332922 %)
# Broj igraca na poziciji CB: 76, (9.3711467324291 %)
# Broj igraca na poziciji LCB: 39, (4.808877928483354 %)
# Broj igraca na poziciji LB: 86, (10.60419235511714 %)
# Broj igraca na poziciji LWB: 5, (0.6165228113440198 %)
#
# GOLMANI: 0 (0.0 %)
#
# Broj igraca u klasteru 24: 839, (4.608117756906684 %)
#
# NAPAD: 292 (34.80333730631705 %)
# Broj igraca na poziciji RF: 1, (0.11918951132300357 %)
# Broj igraca na poziciji LF: 3, (0.3575685339690107 %)
# Broj igraca na poziciji RW: 72, (8.581644815256258 %)
# Broj igraca na poziciji LW: 89, (10.607866507747318 %)
# Broj igraca na poziciji ST: 89, (10.607866507747318 %)
# Broj igraca na poziciji CF: 9, (1.0727056019070322 %)
# Broj igraca na poziciji RS: 13, (1.5494636471990464 %)
# Broj igraca na poziciji LS: 16, (1.907032181168057 %)
#
# VEZNI RED: 546 (65.07747318235995 %)
# Broj igraca na poziciji RDM: 2, (0.23837902264600713 %)
# Broj igraca na poziciji CDM: 0, (0.0 %)
# Broj igraca na poziciji LDM: 2, (0.23837902264600713 %)
# Broj igraca na poziciji RM: 198, (23.59952324195471 %)
# Broj igraca na poziciji RCM: 6, (0.7151370679380215 %)
# Broj igraca na poziciji CM: 11, (1.3110846245530394 %)
# Broj igraca na poziciji LCM: 9, (1.0727056019070322 %)
# Broj igraca na poziciji LM: 159, (18.951132300357568 %)
# Broj igraca na poziciji RAM: 1, (0.11918951132300357 %)
# Broj igraca na poziciji CAM: 157, (18.71275327771156 %)
# Broj igraca na poziciji LAM: 1, (0.11918951132300357 %)
#
# ODBRANA: 1 (0.11918951132300357 %)
# Broj igraca na poziciji RWB: 1, (0.11918951132300357 %)
# Broj igraca na poziciji RB: 0, (0.0 %)
# Broj igraca na poziciji RCB: 0, (0.0 %)
# Broj igraca na poziciji CB: 0, (0.0 %)
# Broj igraca na poziciji LCB: 0, (0.0 %)
# Broj igraca na poziciji LB: 0, (0.0 %)
# Broj igraca na poziciji LWB: 0, (0.0 %)
#
# GOLMANI: 0 (0.0 %)
#
# Broj igraca u klasteru 25: 839, (4.608117756906684 %)
#
# NAPAD: 292 (34.80333730631705 %)
# Broj igraca na poziciji RF: 1, (0.11918951132300357 %)
# Broj igraca na poziciji LF: 3, (0.3575685339690107 %)
# Broj igraca na poziciji RW: 72, (8.581644815256258 %)
# Broj igraca na poziciji LW: 89, (10.607866507747318 %)
# Broj igraca na poziciji ST: 89, (10.607866507747318 %)
# Broj igraca na poziciji CF: 9, (1.0727056019070322 %)
# Broj igraca na poziciji RS: 13, (1.5494636471990464 %)
# Broj igraca na poziciji LS: 16, (1.907032181168057 %)
#
# VEZNI RED: 546 (65.07747318235995 %)
# Broj igraca na poziciji RDM: 2, (0.23837902264600713 %)
# Broj igraca na poziciji CDM: 0, (0.0 %)
# Broj igraca na poziciji LDM: 2, (0.23837902264600713 %)
# Broj igraca na poziciji RM: 198, (23.59952324195471 %)
# Broj igraca na poziciji RCM: 6, (0.7151370679380215 %)
# Broj igraca na poziciji CM: 11, (1.3110846245530394 %)
# Broj igraca na poziciji LCM: 9, (1.0727056019070322 %)
# Broj igraca na poziciji LM: 159, (18.951132300357568 %)
# Broj igraca na poziciji RAM: 1, (0.11918951132300357 %)
# Broj igraca na poziciji CAM: 157, (18.71275327771156 %)
# Broj igraca na poziciji LAM: 1, (0.11918951132300357 %)
#
# ODBRANA: 1 (0.11918951132300357 %)
# Broj igraca na poziciji RWB: 1, (0.11918951132300357 %)
# Broj igraca na poziciji RB: 0, (0.0 %)
# Broj igraca na poziciji RCB: 0, (0.0 %)
# Broj igraca na poziciji CB: 0, (0.0 %)
# Broj igraca na poziciji LCB: 0, (0.0 %)
# Broj igraca na poziciji LB: 0, (0.0 %)
# Broj igraca na poziciji LWB: 0, (0.0 %)
#
# GOLMANI: 0 (0.0 %)
#
# Broj igraca u klasteru 26: 679, (3.7293348712033834 %)
#
# NAPAD: 152 (22.385861561119295 %)
# Broj igraca na poziciji RF: 0, (0.0 %)
# Broj igraca na poziciji LF: 0, (0.0 %)
# Broj igraca na poziciji RW: 56, (8.24742268041237 %)
# Broj igraca na poziciji LW: 44, (6.480117820324007 %)
# Broj igraca na poziciji ST: 39, (5.743740795287187 %)
# Broj igraca na poziciji CF: 9, (1.3254786450662739 %)
# Broj igraca na poziciji RS: 1, (0.14727540500736377 %)
# Broj igraca na poziciji LS: 3, (0.4418262150220913 %)
#
# VEZNI RED: 520 (76.58321060382917 %)
# Broj igraca na poziciji RDM: 2, (0.29455081001472755 %)
# Broj igraca na poziciji CDM: 2, (0.29455081001472755 %)
# Broj igraca na poziciji LDM: 0, (0.0 %)
# Broj igraca na poziciji RM: 138, (20.3240058910162 %)
# Broj igraca na poziciji RCM: 7, (1.0309278350515463 %)
# Broj igraca na poziciji CM: 77, (11.34020618556701 %)
# Broj igraca na poziciji LCM: 6, (0.8836524300441826 %)
# Broj igraca na poziciji LM: 157, (23.12223858615611 %)
# Broj igraca na poziciji RAM: 0, (0.0 %)
# Broj igraca na poziciji CAM: 131, (19.293078055964656 %)
# Broj igraca na poziciji LAM: 0, (0.0 %)
#
# ODBRANA: 7 (1.0309278350515463 %)
# Broj igraca na poziciji RWB: 0, (0.0 %)
# Broj igraca na poziciji RB: 2, (0.29455081001472755 %)
# Broj igraca na poziciji RCB: 0, (0.0 %)
# Broj igraca na poziciji CB: 1, (0.14727540500736377 %)
# Broj igraca na poziciji LCB: 0, (0.0 %)
# Broj igraca na poziciji LB: 3, (0.4418262150220913 %)
# Broj igraca na poziciji LWB: 1, (0.14727540500736377 %)
#
# GOLMANI: 0 (0.0 %)

# %%
# Agglomerative

distance_matrix = linkage(df[numeric], 'ward')
dendrogram(distance_matrix, truncate_mode='lastp', p=12, leaf_font_size=15, show_contracted=True)
plt.axhline(y=120, linestyle='-.', color='red')
plt.axhline(y=70, linestyle='-.', color='red')
plt.title('Dendrogram')
plt.xlabel('Clusters')
plt.ylabel('Distance between clusters')
# Out:
# Text(0, 0.5, 'Distance between clusters')

# %%
agglomerative = AgglomerativeClustering(n_clusters=2, affinity='euclidean', linkage='ward')
agglomerative.fit(df[numeric])
clusters = agglomerative.labels_

# %%
# za podelu na 2 klastera

count = Counter(agglomerative.labels_)
number_and_percentige_per_cluster = {}

for value, times in count.most_common():
    number_and_percentige_per_cluster[value] = [times, (times / len(df)) * 100]
    
number_and_percentige_per_cluster
# Out:
# {0: [16181, 88.87241170978196], 1: [2026, 11.127588290218048]}

# %%
df['cluster_marks'] = agglomerative.labels_

df_cluster_0 = df.loc[df['cluster_marks'] == 0]
df_cluster_1 = df.loc[df['cluster_marks'] == 1]

show_position_percentige_per_cluster(df_cluster_0, 0, len(df))
show_position_percentige_per_cluster(df_cluster_1, 1, len(df))
# Out:
# Broj igraca u klasteru 0: 16181, (0.8887241170978195)
#
# NAPAD: 3477 (0.21488165131944872)
# Broj igraca na poziciji RF: 16
# Broj igraca na poziciji LF: 15
# Broj igraca na poziciji RW: 370
# Broj igraca na poziciji LW: 381
# Broj igraca na poziciji ST: 2211
# Broj igraca na poziciji CF: 74
# Broj igraca na poziciji RS: 203
# Broj igraca na poziciji LS: 207
#
# VEZNI RED: 6838 (0.42259440084049193)
# Broj igraca na poziciji RDM: 248
# Broj igraca na poziciji CDM: 948
# Broj igraca na poziciji LDM: 243
# Broj igraca na poziciji RM: 1124
# Broj igraca na poziciji RCM: 391
# Broj igraca na poziciji CM: 1394
# Broj igraca na poziciji LCM: 395
# Broj igraca na poziciji LM: 1095
# Broj igraca na poziciji RAM: 21
# Broj igraca na poziciji CAM: 958
# Broj igraca na poziciji LAM: 21
#
# ODBRANA: 5866 (0.3625239478400593)
# Broj igraca na poziciji RWB 87
# Broj igraca na poziciji RB 1291
# Broj igraca na poziciji RCB 662
# Broj igraca na poziciji CB 1778
# Broj igraca na poziciji LCB 648
# Broj igraca na poziciji LB 1322
# Broj igraca na poziciji LWB 78
#
# GOLMANI: 0 (0.0)
#
# Broj igraca u klasteru 1: 2026, (0.11127588290218048)
#
# NAPAD: 1 (0.0004935834155972359)
# Broj igraca na poziciji RF: 0
# Broj igraca na poziciji LF: 0
# Broj igraca na poziciji RW: 0
# Broj igraca na poziciji LW: 0
# Broj igraca na poziciji ST: 1
# Broj igraca na poziciji CF: 0
# Broj igraca na poziciji RS: 0
# Broj igraca na poziciji LS: 0
#
# VEZNI RED: 0 (0.0)
# Broj igraca na poziciji RDM: 0
# Broj igraca na poziciji CDM: 0
# Broj igraca na poziciji LDM: 0
# Broj igraca na poziciji RM: 0
# Broj igraca na poziciji RCM: 0
# Broj igraca na poziciji CM: 0
# Broj igraca na poziciji LCM: 0
# Broj igraca na poziciji LM: 0
# Broj igraca na poziciji RAM: 0
# Broj igraca na poziciji CAM: 0
# Broj igraca na poziciji LAM: 0
#
# ODBRANA: 0 (0.0)
# Broj igraca na poziciji RWB 0
# Broj igraca na poziciji RB 0
# Broj igraca na poziciji RCB 0
# Broj igraca na poziciji CB 0
# Broj igraca na poziciji LCB 0
# Broj igraca na poziciji LB 0
# Broj igraca na poziciji LWB 0
#
# GOLMANI: 2025 (0.9995064165844028)

# %%
# Za podelu na 3 klastera

agglomerative = AgglomerativeClustering(n_clusters=3, affinity='euclidean', linkage='ward')
agglomerative.fit(df[numeric])
clusters = agglomerative.labels_

count = Counter(clusters)
number_and_percentige_per_cluster = {}

for value, times in count.most_common():
    number_and_percentige_per_cluster[value] = [times, (times / len(df)) * 100]
    
number_and_percentige_per_cluster
# Out:
# {0: 10388, 2: 5793, 1: 2026}

# %%
df['cluster_marks'] = agglomerative.labels_

df_cluster_0 = df.loc[df['cluster_marks'] == 0]
df_cluster_1 = df.loc[df['cluster_marks'] == 1]
df_cluster_2 = df.loc[df['cluster_marks'] == 2]

show_position_percentige_per_cluster(df_cluster_0, 0, len(df))
show_position_percentige_per_cluster(df_cluster_1, 1, len(df))
show_position_percentige_per_cluster(df_cluster_2, 1, len(df))
# Out:
# Broj igraca u klasteru 0: 10388, (0.5705497885428681)
#
# NAPAD: 1603 (0.15431266846361186)
# Broj igraca na poziciji RF: 0
# Broj igraca na poziciji LF: 2
# Broj igraca na poziciji RW: 164
# Broj igraca na poziciji LW: 167
# Broj igraca na poziciji ST: 1137
# Broj igraca na poziciji CF: 35
# Broj igraca na poziciji RS: 53
# Broj igraca na poziciji LS: 45
#
# VEZNI RED: 3695 (0.3556988833269157)
# Broj igraca na poziciji RDM: 134
# Broj igraca na poziciji CDM: 727
# Broj igraca na poziciji LDM: 149
# Broj igraca na poziciji RM: 523
# Broj igraca na poziciji RCM: 180
# Broj igraca na poziciji CM: 944
# Broj igraca na poziciji LCM: 173
# Broj igraca na poziciji LM: 476
# Broj igraca na poziciji RAM: 2
# Broj igraca na poziciji CAM: 387
# Broj igraca na poziciji LAM: 0
#
# ODBRANA: 5090 (0.48998844820947246)
# Broj igraca na poziciji RWB 67
# Broj igraca na poziciji RB 998
# Broj igraca na poziciji RCB 626
# Broj igraca na poziciji CB 1741
# Broj igraca na poziciji LCB 604
# Broj igraca na poziciji LB 1002
# Broj igraca na poziciji LWB 52
#
# GOLMANI: 0 (0.0)
#
# Broj igraca u klasteru 1: 2026, (0.11127588290218048)
#
# NAPAD: 1 (0.0004935834155972359)
# Broj igraca na poziciji RF: 0
# Broj igraca na poziciji LF: 0
# Broj igraca na poziciji RW: 0
# Broj igraca na poziciji LW: 0
# Broj igraca na poziciji ST: 1
# Broj igraca na poziciji CF: 0
# Broj igraca na poziciji RS: 0
# Broj igraca na poziciji LS: 0
#
# VEZNI RED: 0 (0.0)
# Broj igraca na poziciji RDM: 0
# Broj igraca na poziciji CDM: 0
# Broj igraca na poziciji LDM: 0
# Broj igraca na poziciji RM: 0
# Broj igraca na poziciji RCM: 0
# Broj igraca na poziciji CM: 0
# Broj igraca na poziciji LCM: 0
# Broj igraca na poziciji LM: 0
# Broj igraca na poziciji RAM: 0
# Broj igraca na poziciji CAM: 0
# Broj igraca na poziciji LAM: 0
#
# ODBRANA: 0 (0.0)
# Broj igraca na poziciji RWB 0
# Broj igraca na poziciji RB 0
# Broj igraca na poziciji RCB 0
# Broj igraca na poziciji CB 0
# Broj igraca na poziciji LCB 0
# Broj igraca na poziciji LB 0
# Broj igraca na poziciji LWB 0
#
# GOLMANI: 2025 (0.9995064165844028)
#
# Broj igraca u klasteru 1: 5793, (0.31817432855495137)
#
# NAPAD: 1874 (0.32349387191437945)
# Broj igraca na poziciji RF: 16
# Broj igraca na poziciji LF: 13
# Broj igraca na poziciji RW: 206
# Broj igraca na poziciji LW: 214
# Broj igraca na poziciji ST: 1074
# Broj igraca na poziciji CF: 39
# Broj igraca na poziciji RS: 150
# Broj igraca na poziciji LS: 162
#
# VEZNI RED: 3143 (0.5425513550837218)
# Broj igraca na poziciji RDM: 114
# Broj igraca na poziciji CDM: 221
# Broj igraca na poziciji LDM: 94
# Broj igraca na poziciji RM: 601
# Broj igraca na poziciji RCM: 211
# Broj igraca na poziciji CM: 450
# Broj igraca na poziciji LCM: 222
# Broj igraca na poziciji LM: 619
# Broj igraca na poziciji RAM: 19
# Broj igraca na poziciji CAM: 571
# Broj igraca na poziciji LAM: 21
#
# ODBRANA: 776 (0.13395477300189884)
# Broj igraca na poziciji RWB 20
# Broj igraca na poziciji RB 293
# Broj igraca na poziciji RCB 36
# Broj igraca na poziciji CB 37
# Broj igraca na poziciji LCB 44
# Broj igraca na poziciji LB 320
# Broj igraca na poziciji LWB 26
#
# GOLMANI: 0 (0.0)

# %%
# DBSCAN

dbscan = DBSCAN()
dbscan.fit(df[numeric])
dbscan.labels_

count = Counter(dbscan.labels_)
number_and_percentige_per_cluster = {}

for value, times in count.most_common():
    number_and_percentige_per_cluster[value] = [times, (times / len(df)) * 100]

number_and_percentige_per_cluster
# Out:
# {1: 10979,
#  -1: 5632,
#  0: 1546,
#  3: 7,
#  2: 5,
#  8: 5,
#  5: 5,
#  9: 4,
#  6: 4,
#  10: 4,
#  11: 4,
#  4: 3,
#  7: 3,
#  12: 3,
#  13: 3}

# %%
df['cluster_marks'] = dbscan.labels_

df_cluster_minus_1 = df.loc[df['cluster_marks'] == -1]
df_cluster_0 = df.loc[df['cluster_marks'] == 0]
df_cluster_1 = df.loc[df['cluster_marks'] == 1]
df_cluster_2 = df.loc[df['cluster_marks'] == 2]
df_cluster_3 = df.loc[df['cluster_marks'] == 3]
df_cluster_4 = df.loc[df['cluster_marks'] == 4]
df_cluster_5 = df.loc[df['cluster_marks'] == 5]
df_cluster_6 = df.loc[df['cluster_marks'] == 6]
df_cluster_7 = df.loc[df['cluster_marks'] == 7]
df_cluster_8 = df.loc[df['cluster_marks'] == 8]
df_cluster_9 = df.loc[df['cluster_marks'] == 9]
df_cluster_10 = df.loc[df['cluster_marks'] == 10]
df_cluster_11 = df.loc[df['cluster_marks'] == 11]
df_cluster_12 = df.loc[df['cluster_marks'] == 12]
df_cluster_13 = df.loc[df['cluster_marks'] == 13]

show_position_percentige_per_cluster(df_cluster_minus_1, -1, len(df))
show_position_percentige_per_cluster(df_cluster_0, 0, len(df))
show_position_percentige_per_cluster(df_cluster_1, 1, len(df))
show_position_percentige_per_cluster(df_cluster_2, 2, len(df))
show_position_percentige_per_cluster(df_cluster_3, 3, len(df))
show_position_percentige_per_cluster(df_cluster_4, 4, len(df))
show_position_percentige_per_cluster(df_cluster_5, 5, len(df))
show_position_percentige_per_cluster(df_cluster_6, 6, len(df))
show_position_percentige_per_cluster(df_cluster_7, 7, len(df))
show_position_percentige_per_cluster(df_cluster_8, 8, len(df))
show_position_percentige_per_cluster(df_cluster_9, 9, len(df))
show_position_percentige_per_cluster(df_cluster_10, 10, len(df))
show_position_percentige_per_cluster(df_cluster_11, 11, len(df))
show_position_percentige_per_cluster(df_cluster_12, 12, len(df))
show_position_percentige_per_cluster(df_cluster_13, 13, len(df))
# Out:
# Broj igraca u klasteru -1: 5632, (0.30933157576756193)
#
# NAPAD: 1338 (0.23757102272727273)
# Broj igraca na poziciji RF: 8
# Broj igraca na poziciji LF: 9
# Broj igraca na poziciji RW: 155
# Broj igraca na poziciji LW: 149
# Broj igraca na poziciji ST: 803
# Broj igraca na poziciji CF: 31
# Broj igraca na poziciji RS: 90
# Broj igraca na poziciji LS: 93
#
# VEZNI RED: 2062 (0.3661221590909091)
# Broj igraca na poziciji RDM: 63
# Broj igraca na poziciji CDM: 250
# Broj igraca na poziciji LDM: 77
# Broj igraca na poziciji RM: 399
# Broj igraca na poziciji RCM: 97
# Broj igraca na poziciji CM: 286
# Broj igraca na poziciji LCM: 99
# Broj igraca na poziciji LM: 403
# Broj igraca na poziciji RAM: 15
# Broj igraca na poziciji CAM: 359
# Broj igraca na poziciji LAM: 14
#
# ODBRANA: 1761 (0.3126775568181818)
# Broj igraca na poziciji RWB 18
# Broj igraca na poziciji RB 304
# Broj igraca na poziciji RCB 267
# Broj igraca na poziciji CB 569
# Broj igraca na poziciji LCB 268
# Broj igraca na poziciji LB 315
# Broj igraca na poziciji LWB 20
#
# GOLMANI: 471 (0.08362926136363637)
#
# Broj igraca u klasteru 0: 1546, (0.08491239633108146)
#
# NAPAD: 0 (0.0)
# Broj igraca na poziciji RF: 0
# Broj igraca na poziciji LF: 0
# Broj igraca na poziciji RW: 0
# Broj igraca na poziciji LW: 0
# Broj igraca na poziciji ST: 0
# Broj igraca na poziciji CF: 0
# Broj igraca na poziciji RS: 0
# Broj igraca na poziciji LS: 0
#
# VEZNI RED: 0 (0.0)
# Broj igraca na poziciji RDM: 0
# Broj igraca na poziciji CDM: 0
# Broj igraca na poziciji LDM: 0
# Broj igraca na poziciji RM: 0
# Broj igraca na poziciji RCM: 0
# Broj igraca na poziciji CM: 0
# Broj igraca na poziciji LCM: 0
# Broj igraca na poziciji LM: 0
# Broj igraca na poziciji RAM: 0
# Broj igraca na poziciji CAM: 0
# Broj igraca na poziciji LAM: 0
#
# ODBRANA: 0 (0.0)
# Broj igraca na poziciji RWB 0
# Broj igraca na poziciji RB 0
# Broj igraca na poziciji RCB 0
# Broj igraca na poziciji CB 0
# Broj igraca na poziciji LCB 0
# Broj igraca na poziciji LB 0
# Broj igraca na poziciji LWB 0
#
# GOLMANI: 1546 (1.0)
#
# Broj igraca u klasteru 1: 10979, (0.6030098313835338)
#
# NAPAD: 2134 (0.19437107204663448)
# Broj igraca na poziciji RF: 8
# Broj igraca na poziciji LF: 6
# Broj igraca na poziciji RW: 213
# Broj igraca na poziciji LW: 232
# Broj igraca na poziciji ST: 1408
# Broj igraca na poziciji CF: 43
# Broj igraca na poziciji RS: 111
# Broj igraca na poziciji LS: 113
#
# VEZNI RED: 4769 (0.43437471536569816)
# Broj igraca na poziciji RDM: 185
# Broj igraca na poziciji CDM: 698
# Broj igraca na poziciji LDM: 166
# Broj igraca na poziciji RM: 723
# Broj igraca na poziciji RCM: 294
# Broj igraca na poziciji CM: 1107
# Broj igraca na poziciji LCM: 296
# Broj igraca na poziciji LM: 689
# Broj igraca na poziciji RAM: 6
# Broj igraca na poziciji CAM: 598
# Broj igraca na poziciji LAM: 7
#
# ODBRANA: 4076 (0.3712542125876674)
# Broj igraca na poziciji RWB 69
# Broj igraca na poziciji RB 985
# Broj igraca na poziciji RCB 389
# Broj igraca na poziciji CB 1196
# Broj igraca na poziciji LCB 373
# Broj igraca na poziciji LB 1006
# Broj igraca na poziciji LWB 58
#
# GOLMANI: 0 (0.0)
#
# Broj igraca u klasteru 2: 5, (0.00027461965178228156)
#
# NAPAD: 2 (0.4)
# Broj igraca na poziciji RF: 0
# Broj igraca na poziciji LF: 0
# Broj igraca na poziciji RW: 0
# Broj igraca na poziciji LW: 0
# Broj igraca na poziciji ST: 1
# Broj igraca na poziciji CF: 0
# Broj igraca na poziciji RS: 0
# Broj igraca na poziciji LS: 1
#
# VEZNI RED: 3 (0.6)
# Broj igraca na poziciji RDM: 0
# Broj igraca na poziciji CDM: 0
# Broj igraca na poziciji LDM: 0
# Broj igraca na poziciji RM: 1
# Broj igraca na poziciji RCM: 0
# Broj igraca na poziciji CM: 0
# Broj igraca na poziciji LCM: 0
# Broj igraca na poziciji LM: 2
# Broj igraca na poziciji RAM: 0
# Broj igraca na poziciji CAM: 0
# Broj igraca na poziciji LAM: 0
#
# ODBRANA: 0 (0.0)
# Broj igraca na poziciji RWB 0
# Broj igraca na poziciji RB 0
# Broj igraca na poziciji RCB 0
# Broj igraca na poziciji CB 0
# Broj igraca na poziciji LCB 0
# Broj igraca na poziciji LB 0
# Broj igraca na poziciji LWB 0
#
# GOLMANI: 0 (0.0)
#
# Broj igraca u klasteru 3: 7, (0.00038446751249519417)
#
# NAPAD: 0 (0.0)
# Broj igraca na poziciji RF: 0
# Broj igraca na poziciji LF: 0
# Broj igraca na poziciji RW: 0
# Broj igraca na poziciji LW: 0
# Broj igraca na poziciji ST: 0
# Broj igraca na poziciji CF: 0
# Broj igraca na poziciji RS: 0
# Broj igraca na poziciji LS: 0
#
# VEZNI RED: 0 (0.0)
# Broj igraca na poziciji RDM: 0
# Broj igraca na poziciji CDM: 0
# Broj igraca na poziciji LDM: 0
# Broj igraca na poziciji RM: 0
# Broj igraca na poziciji RCM: 0
# Broj igraca na poziciji CM: 0
# Broj igraca na poziciji LCM: 0
# Broj igraca na poziciji LM: 0
# Broj igraca na poziciji RAM: 0
# Broj igraca na poziciji CAM: 0
# Broj igraca na poziciji LAM: 0
#
# ODBRANA: 7 (1.0)
# Broj igraca na poziciji RWB 0
# Broj igraca na poziciji RB 0
# Broj igraca na poziciji RCB 1
# Broj igraca na poziciji CB 6
# Broj igraca na poziciji LCB 0
# Broj igraca na poziciji LB 0
# Broj igraca na poziciji LWB 0
#
# GOLMANI: 0 (0.0)
#
# Broj igraca u klasteru 4: 3, (0.00016477179106936892)
#
# NAPAD: 1 (0.3333333333333333)
# Broj igraca na poziciji RF: 0
# Broj igraca na poziciji LF: 0
# Broj igraca na poziciji RW: 1
# Broj igraca na poziciji LW: 0
# Broj igraca na poziciji ST: 0
# Broj igraca na poziciji CF: 0
# Broj igraca na poziciji RS: 0
# Broj igraca na poziciji LS: 0
#
# VEZNI RED: 2 (0.6666666666666666)
# Broj igraca na poziciji RDM: 0
# Broj igraca na poziciji CDM: 0
# Broj igraca na poziciji LDM: 0
# Broj igraca na poziciji RM: 1
# Broj igraca na poziciji RCM: 0
# Broj igraca na poziciji CM: 0
# Broj igraca na poziciji LCM: 0
# Broj igraca na poziciji LM: 1
# Broj igraca na poziciji RAM: 0
# Broj igraca na poziciji CAM: 0
# Broj igraca na poziciji LAM: 0
#
# ODBRANA: 0 (0.0)
# Broj igraca na poziciji RWB 0
# Broj igraca na poziciji RB 0
# Broj igraca na poziciji RCB 0
# Broj igraca na poziciji CB 0
# Broj igraca na poziciji LCB 0
# Broj igraca na poziciji LB 0
# Broj igraca na poziciji LWB 0
#
# GOLMANI: 0 (0.0)
#
# Broj igraca u klasteru 5: 5, (0.00027461965178228156)
#
# NAPAD: 0 (0.0)
# Broj igraca na poziciji RF: 0
# Broj igraca na poziciji LF: 0
# Broj igraca na poziciji RW: 0
# Broj igraca na poziciji LW: 0
# Broj igraca na poziciji ST: 0
# Broj igraca na poziciji CF: 0
# Broj igraca na poziciji RS: 0
# Broj igraca na poziciji LS: 0
#
# VEZNI RED: 0 (0.0)
# Broj igraca na poziciji RDM: 0
# Broj igraca na poziciji CDM: 0
# Broj igraca na poziciji LDM: 0
# Broj igraca na poziciji RM: 0
# Broj igraca na poziciji RCM: 0
# Broj igraca na poziciji CM: 0
# Broj igraca na poziciji LCM: 0
# Broj igraca na poziciji LM: 0
# Broj igraca na poziciji RAM: 0
# Broj igraca na poziciji CAM: 0
# Broj igraca na poziciji LAM: 0
#
# ODBRANA: 5 (1.0)
# Broj igraca na poziciji RWB 0
# Broj igraca na poziciji RB 0
# Broj igraca na poziciji RCB 1
# Broj igraca na poziciji CB 2
# Broj igraca na poziciji LCB 2
# Broj igraca na poziciji LB 0
# Broj igraca na poziciji LWB 0
#
# GOLMANI: 0 (0.0)
#
# Broj igraca u klasteru 6: 4, (0.00021969572142582522)
#
# NAPAD: 0 (0.0)
# Broj igraca na poziciji RF: 0
# Broj igraca na poziciji LF: 0
# Broj igraca na poziciji RW: 0
# Broj igraca na poziciji LW: 0
# Broj igraca na poziciji ST: 0
# Broj igraca na poziciji CF: 0
# Broj igraca na poziciji RS: 0
# Broj igraca na poziciji LS: 0
#
# VEZNI RED: 0 (0.0)
# Broj igraca na poziciji RDM: 0
# Broj igraca na poziciji CDM: 0
# Broj igraca na poziciji LDM: 0
# Broj igraca na poziciji RM: 0
# Broj igraca na poziciji RCM: 0
# Broj igraca na poziciji CM: 0
# Broj igraca na poziciji LCM: 0
# Broj igraca na poziciji LM: 0
# Broj igraca na poziciji RAM: 0
# Broj igraca na poziciji CAM: 0
# Broj igraca na poziciji LAM: 0
#
# ODBRANA: 4 (1.0)
# Broj igraca na poziciji RWB 0
# Broj igraca na poziciji RB 0
# Broj igraca na poziciji RCB 1
# Broj igraca na poziciji CB 1
# Broj igraca na poziciji LCB 2
# Broj igraca na poziciji LB 0
# Broj igraca na poziciji LWB 0
#
# GOLMANI: 0 (0.0)
#
# Broj igraca u klasteru 7: 3, (0.00016477179106936892)
#
# NAPAD: 0 (0.0)
# Broj igraca na poziciji RF: 0
# Broj igraca na poziciji LF: 0
# Broj igraca na poziciji RW: 0
# Broj igraca na poziciji LW: 0
# Broj igraca na poziciji ST: 0
# Broj igraca na poziciji CF: 0
# Broj igraca na poziciji RS: 0
# Broj igraca na poziciji LS: 0
#
# VEZNI RED: 0 (0.0)
# Broj igraca na poziciji RDM: 0
# Broj igraca na poziciji CDM: 0
# Broj igraca na poziciji LDM: 0
# Broj igraca na poziciji RM: 0
# Broj igraca na poziciji RCM: 0
# Broj igraca na poziciji CM: 0
# Broj igraca na poziciji LCM: 0
# Broj igraca na poziciji LM: 0
# Broj igraca na poziciji RAM: 0
# Broj igraca na poziciji CAM: 0
# Broj igraca na poziciji LAM: 0
#
# ODBRANA: 3 (1.0)
# Broj igraca na poziciji RWB 0
# Broj igraca na poziciji RB 0
# Broj igraca na poziciji RCB 1
# Broj igraca na poziciji CB 1
# Broj igraca na poziciji LCB 1
# Broj igraca na poziciji LB 0
# Broj igraca na poziciji LWB 0
#
# GOLMANI: 0 (0.0)
#
# Broj igraca u klasteru 8: 5, (0.00027461965178228156)
#
# NAPAD: 0 (0.0)
# Broj igraca na poziciji RF: 0
# Broj igraca na poziciji LF: 0
# Broj igraca na poziciji RW: 0
# Broj igraca na poziciji LW: 0
# Broj igraca na poziciji ST: 0
# Broj igraca na poziciji CF: 0
# Broj igraca na poziciji RS: 0
# Broj igraca na poziciji LS: 0
#
# VEZNI RED: 0 (0.0)
# Broj igraca na poziciji RDM: 0
# Broj igraca na poziciji CDM: 0
# Broj igraca na poziciji LDM: 0
# Broj igraca na poziciji RM: 0
# Broj igraca na poziciji RCM: 0
# Broj igraca na poziciji CM: 0
# Broj igraca na poziciji LCM: 0
# Broj igraca na poziciji LM: 0
# Broj igraca na poziciji RAM: 0
# Broj igraca na poziciji CAM: 0
# Broj igraca na poziciji LAM: 0
#
# ODBRANA: 0 (0.0)
# Broj igraca na poziciji RWB 0
# Broj igraca na poziciji RB 0
# Broj igraca na poziciji RCB 0
# Broj igraca na poziciji CB 0
# Broj igraca na poziciji LCB 0
# Broj igraca na poziciji LB 0
# Broj igraca na poziciji LWB 0
#
# GOLMANI: 5 (1.0)
#
# Broj igraca u klasteru 9: 4, (0.00021969572142582522)
#
# NAPAD: 0 (0.0)
# Broj igraca na poziciji RF: 0
# Broj igraca na poziciji LF: 0
# Broj igraca na poziciji RW: 0
# Broj igraca na poziciji LW: 0
# Broj igraca na poziciji ST: 0
# Broj igraca na poziciji CF: 0
# Broj igraca na poziciji RS: 0
# Broj igraca na poziciji LS: 0
#
# VEZNI RED: 0 (0.0)
# Broj igraca na poziciji RDM: 0
# Broj igraca na poziciji CDM: 0
# Broj igraca na poziciji LDM: 0
# Broj igraca na poziciji RM: 0
# Broj igraca na poziciji RCM: 0
# Broj igraca na poziciji CM: 0
# Broj igraca na poziciji LCM: 0
# Broj igraca na poziciji LM: 0
# Broj igraca na poziciji RAM: 0
# Broj igraca na poziciji CAM: 0
# Broj igraca na poziciji LAM: 0
#
# ODBRANA: 4 (1.0)
# Broj igraca na poziciji RWB 0
# Broj igraca na poziciji RB 0
# Broj igraca na poziciji RCB 2
# Broj igraca na poziciji CB 1
# Broj igraca na poziciji LCB 1
# Broj igraca na poziciji LB 0
# Broj igraca na poziciji LWB 0
#
# GOLMANI: 0 (0.0)
#
# Broj igraca u klasteru 10: 4, (0.00021969572142582522)
#
# NAPAD: 0 (0.0)
# Broj igraca na poziciji RF: 0
# Broj igraca na poziciji LF: 0
# Broj igraca na poziciji RW: 0
# Broj igraca na poziciji LW: 0
# Broj igraca na poziciji ST: 0
# Broj igraca na poziciji CF: 0
# Broj igraca na poziciji RS: 0
# Broj igraca na poziciji LS: 0
#
# VEZNI RED: 1 (0.25)
# Broj igraca na poziciji RDM: 0
# Broj igraca na poziciji CDM: 0
# Broj igraca na poziciji LDM: 0
# Broj igraca na poziciji RM: 0
# Broj igraca na poziciji RCM: 0
# Broj igraca na poziciji CM: 1
# Broj igraca na poziciji LCM: 0
# Broj igraca na poziciji LM: 0
# Broj igraca na poziciji RAM: 0
# Broj igraca na poziciji CAM: 0
# Broj igraca na poziciji LAM: 0
#
# ODBRANA: 3 (0.75)
# Broj igraca na poziciji RWB 0
# Broj igraca na poziciji RB 2
# Broj igraca na poziciji RCB 0
# Broj igraca na poziciji CB 0
# Broj igraca na poziciji LCB 0
# Broj igraca na poziciji LB 1
# Broj igraca na poziciji LWB 0
#
# GOLMANI: 0 (0.0)
#
# Broj igraca u klasteru 11: 4, (0.00021969572142582522)
#
# NAPAD: 3 (0.75)
# Broj igraca na poziciji RF: 0
# Broj igraca na poziciji LF: 0
# Broj igraca na poziciji RW: 1
# Broj igraca na poziciji LW: 0
# Broj igraca na poziciji ST: 0
# Broj igraca na poziciji CF: 0
# Broj igraca na poziciji RS: 2
# Broj igraca na poziciji LS: 0
#
# VEZNI RED: 1 (0.25)
# Broj igraca na poziciji RDM: 0
# Broj igraca na poziciji CDM: 0
# Broj igraca na poziciji LDM: 0
# Broj igraca na poziciji RM: 0
# Broj igraca na poziciji RCM: 0
# Broj igraca na poziciji CM: 0
# Broj igraca na poziciji LCM: 0
# Broj igraca na poziciji LM: 0
# Broj igraca na poziciji RAM: 0
# Broj igraca na poziciji CAM: 1
# Broj igraca na poziciji LAM: 0
#
# ODBRANA: 0 (0.0)
# Broj igraca na poziciji RWB 0
# Broj igraca na poziciji RB 0
# Broj igraca na poziciji RCB 0
# Broj igraca na poziciji CB 0
# Broj igraca na poziciji LCB 0
# Broj igraca na poziciji LB 0
# Broj igraca na poziciji LWB 0
#
# GOLMANI: 0 (0.0)
#
# Broj igraca u klasteru 12: 3, (0.00016477179106936892)
#
# NAPAD: 0 (0.0)
# Broj igraca na poziciji RF: 0
# Broj igraca na poziciji LF: 0
# Broj igraca na poziciji RW: 0
# Broj igraca na poziciji LW: 0
# Broj igraca na poziciji ST: 0
# Broj igraca na poziciji CF: 0
# Broj igraca na poziciji RS: 0
# Broj igraca na poziciji LS: 0
#
# VEZNI RED: 0 (0.0)
# Broj igraca na poziciji RDM: 0
# Broj igraca na poziciji CDM: 0
# Broj igraca na poziciji LDM: 0
# Broj igraca na poziciji RM: 0
# Broj igraca na poziciji RCM: 0
# Broj igraca na poziciji CM: 0
# Broj igraca na poziciji LCM: 0
# Broj igraca na poziciji LM: 0
# Broj igraca na poziciji RAM: 0
# Broj igraca na poziciji CAM: 0
# Broj igraca na poziciji LAM: 0
#
# ODBRANA: 0 (0.0)
# Broj igraca na poziciji RWB 0
# Broj igraca na poziciji RB 0
# Broj igraca na poziciji RCB 0
# Broj igraca na poziciji CB 0
# Broj igraca na poziciji LCB 0
# Broj igraca na poziciji LB 0
# Broj igraca na poziciji LWB 0
#
# GOLMANI: 3 (1.0)
#
# Broj igraca u klasteru 13: 3, (0.00016477179106936892)
#
# NAPAD: 0 (0.0)
# Broj igraca na poziciji RF: 0
# Broj igraca na poziciji LF: 0
# Broj igraca na poziciji RW: 0
# Broj igraca na poziciji LW: 0
# Broj igraca na poziciji ST: 0
# Broj igraca na poziciji CF: 0
# Broj igraca na poziciji RS: 0
# Broj igraca na poziciji LS: 0
#
# VEZNI RED: 0 (0.0)
# Broj igraca na poziciji RDM: 0
# Broj igraca na poziciji CDM: 0
# Broj igraca na poziciji LDM: 0
# Broj igraca na poziciji RM: 0
# Broj igraca na poziciji RCM: 0
# Broj igraca na poziciji CM: 0
# Broj igraca na poziciji LCM: 0
# Broj igraca na poziciji LM: 0
# Broj igraca na poziciji RAM: 0
# Broj igraca na poziciji CAM: 0
# Broj igraca na poziciji LAM: 0
#
# ODBRANA: 3 (1.0)
# Broj igraca na poziciji RWB 0
# Broj igraca na poziciji RB 0
# Broj igraca na poziciji RCB 0
# Broj igraca na poziciji CB 2
# Broj igraca na poziciji LCB 1
# Broj igraca na poziciji LB 0
# Broj igraca na poziciji LWB 0
#
# GOLMANI: 0 (0.0)

# %%
dbscan = DBSCAN(min_samples=6)
dbscan.fit(df[numeric])
dbscan.labels_

count = Counter(dbscan.labels_)
number_and_percentige_per_cluster = {}

for value, times in count.most_common():
    number_and_percentige_per_cluster[value] = [times, (times / len(df)) * 100]
    
number_and_percentige_per_cluster
# Out:
# {2: 10810, -1: 5852, 0: 1526, 1: 6, 3: 5, 4: 4, 5: 4}

# %%
df['cluster_marks'] = dbscan.labels_

df_cluster_minus_1 = df.loc[df['cluster_marks'] == -1]
df_cluster_0 = df.loc[df['cluster_marks'] == 0]
df_cluster_1 = df.loc[df['cluster_marks'] == 1]
df_cluster_2 = df.loc[df['cluster_marks'] == 2]
df_cluster_3 = df.loc[df['cluster_marks'] == 3]
df_cluster_4 = df.loc[df['cluster_marks'] == 4]
df_cluster_5 = df.loc[df['cluster_marks'] == 5]

show_position_percentige_per_cluster(df_cluster_minus_1, -1, len(df))
show_position_percentige_per_cluster(df_cluster_0, 0, len(df))
show_position_percentige_per_cluster(df_cluster_1, 1, len(df))
show_position_percentige_per_cluster(df_cluster_2, 2, len(df))
show_position_percentige_per_cluster(df_cluster_3, 3, len(df))
show_position_percentige_per_cluster(df_cluster_4, 4, len(df))
show_position_percentige_per_cluster(df_cluster_5, 5, len(df))
# Out:
# Broj igraca u klasteru -1: 5852, (0.32141484044598234)
#
# NAPAD: 1391 (0.2376965140123035)
# Broj igraca na poziciji RF: 8
# Broj igraca na poziciji LF: 9
# Broj igraca na poziciji RW: 165
# Broj igraca na poziciji LW: 160
# Broj igraca na poziciji ST: 821
# Broj igraca na poziciji CF: 34
# Broj igraca na poziciji RS: 95
# Broj igraca na poziciji LS: 99
#
# VEZNI RED: 2130 (0.3639781271360219)
# Broj igraca na poziciji RDM: 65
# Broj igraca na poziciji CDM: 259
# Broj igraca na poziciji LDM: 78
# Broj igraca na poziciji RM: 414
# Broj igraca na poziciji RCM: 101
# Broj igraca na poziciji CM: 289
# Broj igraca na poziciji LCM: 100
# Broj igraca na poziciji LM: 423
# Broj igraca na poziciji RAM: 16
# Broj igraca na poziciji CAM: 369
# Broj igraca na poziciji LAM: 16
#
# ODBRANA: 1837 (0.31390977443609025)
# Broj igraca na poziciji RWB 19
# Broj igraca na poziciji RB 316
# Broj igraca na poziciji RCB 282
# Broj igraca na poziciji CB 590
# Broj igraca na poziciji LCB 285
# Broj igraca na poziciji LB 325
# Broj igraca na poziciji LWB 20
#
# GOLMANI: 494 (0.08441558441558442)
#
# Broj igraca u klasteru 0: 1526, (0.08381391772395233)
#
# NAPAD: 0 (0.0)
# Broj igraca na poziciji RF: 0
# Broj igraca na poziciji LF: 0
# Broj igraca na poziciji RW: 0
# Broj igraca na poziciji LW: 0
# Broj igraca na poziciji ST: 0
# Broj igraca na poziciji CF: 0
# Broj igraca na poziciji RS: 0
# Broj igraca na poziciji LS: 0
#
# VEZNI RED: 0 (0.0)
# Broj igraca na poziciji RDM: 0
# Broj igraca na poziciji CDM: 0
# Broj igraca na poziciji LDM: 0
# Broj igraca na poziciji RM: 0
# Broj igraca na poziciji RCM: 0
# Broj igraca na poziciji CM: 0
# Broj igraca na poziciji LCM: 0
# Broj igraca na poziciji LM: 0
# Broj igraca na poziciji RAM: 0
# Broj igraca na poziciji CAM: 0
# Broj igraca na poziciji LAM: 0
#
# ODBRANA: 0 (0.0)
# Broj igraca na poziciji RWB 0
# Broj igraca na poziciji RB 0
# Broj igraca na poziciji RCB 0
# Broj igraca na poziciji CB 0
# Broj igraca na poziciji LCB 0
# Broj igraca na poziciji LB 0
# Broj igraca na poziciji LWB 0
#
# GOLMANI: 1526 (1.0)
#
# Broj igraca u klasteru 1: 6, (0.00032954358213873783)
#
# NAPAD: 0 (0.0)
# Broj igraca na poziciji RF: 0
# Broj igraca na poziciji LF: 0
# Broj igraca na poziciji RW: 0
# Broj igraca na poziciji LW: 0
# Broj igraca na poziciji ST: 0
# Broj igraca na poziciji CF: 0
# Broj igraca na poziciji RS: 0
# Broj igraca na poziciji LS: 0
#
# VEZNI RED: 0 (0.0)
# Broj igraca na poziciji RDM: 0
# Broj igraca na poziciji CDM: 0
# Broj igraca na poziciji LDM: 0
# Broj igraca na poziciji RM: 0
# Broj igraca na poziciji RCM: 0
# Broj igraca na poziciji CM: 0
# Broj igraca na poziciji LCM: 0
# Broj igraca na poziciji LM: 0
# Broj igraca na poziciji RAM: 0
# Broj igraca na poziciji CAM: 0
# Broj igraca na poziciji LAM: 0
#
# ODBRANA: 6 (1.0)
# Broj igraca na poziciji RWB 0
# Broj igraca na poziciji RB 0
# Broj igraca na poziciji RCB 0
# Broj igraca na poziciji CB 6
# Broj igraca na poziciji LCB 0
# Broj igraca na poziciji LB 0
# Broj igraca na poziciji LWB 0
#
# GOLMANI: 0 (0.0)
#
# Broj igraca u klasteru 2: 10810, (0.5937276871532927)
#
# NAPAD: 2080 (0.19241443108233117)
# Broj igraca na poziciji RF: 8
# Broj igraca na poziciji LF: 6
# Broj igraca na poziciji RW: 204
# Broj igraca na poziciji LW: 221
# Broj igraca na poziciji ST: 1387
# Broj igraca na poziciji CF: 40
# Broj igraca na poziciji RS: 106
# Broj igraca na poziciji LS: 108
#
# VEZNI RED: 4707 (0.4354301572617946)
# Broj igraca na poziciji RDM: 183
# Broj igraca na poziciji CDM: 689
# Broj igraca na poziciji LDM: 165
# Broj igraca na poziciji RM: 710
# Broj igraca na poziciji RCM: 290
# Broj igraca na poziciji CM: 1105
# Broj igraca na poziciji LCM: 295
# Broj igraca na poziciji LM: 672
# Broj igraca na poziciji RAM: 5
# Broj igraca na poziciji CAM: 588
# Broj igraca na poziciji LAM: 5
#
# ODBRANA: 4023 (0.3721554116558742)
# Broj igraca na poziciji RWB 68
# Broj igraca na poziciji RB 975
# Broj igraca na poziciji RCB 380
# Broj igraca na poziciji CB 1182
# Broj igraca na poziciji LCB 363
# Broj igraca na poziciji LB 997
# Broj igraca na poziciji LWB 58
#
# GOLMANI: 0 (0.0)
#
# Broj igraca u klasteru 3: 5, (0.00027461965178228156)
#
# NAPAD: 0 (0.0)
# Broj igraca na poziciji RF: 0
# Broj igraca na poziciji LF: 0
# Broj igraca na poziciji RW: 0
# Broj igraca na poziciji LW: 0
# Broj igraca na poziciji ST: 0
# Broj igraca na poziciji CF: 0
# Broj igraca na poziciji RS: 0
# Broj igraca na poziciji LS: 0
#
# VEZNI RED: 0 (0.0)
# Broj igraca na poziciji RDM: 0
# Broj igraca na poziciji CDM: 0
# Broj igraca na poziciji LDM: 0
# Broj igraca na poziciji RM: 0
# Broj igraca na poziciji RCM: 0
# Broj igraca na poziciji CM: 0
# Broj igraca na poziciji LCM: 0
# Broj igraca na poziciji LM: 0
# Broj igraca na poziciji RAM: 0
# Broj igraca na poziciji CAM: 0
# Broj igraca na poziciji LAM: 0
#
# ODBRANA: 0 (0.0)
# Broj igraca na poziciji RWB 0
# Broj igraca na poziciji RB 0
# Broj igraca na poziciji RCB 0
# Broj igraca na poziciji CB 0
# Broj igraca na poziciji LCB 0
# Broj igraca na poziciji LB 0
# Broj igraca na poziciji LWB 0
#
# GOLMANI: 5 (1.0)
#
# Broj igraca u klasteru 4: 4, (0.00021969572142582522)
#
# NAPAD: 3 (0.75)
# Broj igraca na poziciji RF: 0
# Broj igraca na poziciji LF: 0
# Broj igraca na poziciji RW: 1
# Broj igraca na poziciji LW: 0
# Broj igraca na poziciji ST: 0
# Broj igraca na poziciji CF: 0
# Broj igraca na poziciji RS: 2
# Broj igraca na poziciji LS: 0
#
# VEZNI RED: 1 (0.25)
# Broj igraca na poziciji RDM: 0
# Broj igraca na poziciji CDM: 0
# Broj igraca na poziciji LDM: 0
# Broj igraca na poziciji RM: 0
# Broj igraca na poziciji RCM: 0
# Broj igraca na poziciji CM: 0
# Broj igraca na poziciji LCM: 0
# Broj igraca na poziciji LM: 0
# Broj igraca na poziciji RAM: 0
# Broj igraca na poziciji CAM: 1
# Broj igraca na poziciji LAM: 0
#
# ODBRANA: 0 (0.0)
# Broj igraca na poziciji RWB 0
# Broj igraca na poziciji RB 0
# Broj igraca na poziciji RCB 0
# Broj igraca na poziciji CB 0
# Broj igraca na poziciji LCB 0
# Broj igraca na poziciji LB 0
# Broj igraca na poziciji LWB 0
#
# GOLMANI: 0 (0.0)
#
# Broj igraca u klasteru 5: 4, (0.00021969572142582522)
#
# NAPAD: 4 (1.0)
# Broj igraca na poziciji RF: 0
# Broj igraca na poziciji LF: 0
# Broj igraca na poziciji RW: 0
# Broj igraca na poziciji LW: 0
# Broj igraca na poziciji ST: 4
# Broj igraca na poziciji CF: 0
# Broj igraca na poziciji RS: 0
# Broj igraca na poziciji LS: 0
#
# VEZNI RED: 0 (0.0)
# Broj igraca na poziciji RDM: 0
# Broj igraca na poziciji CDM: 0
# Broj igraca na poziciji LDM: 0
# Broj igraca na poziciji RM: 0
# Broj igraca na poziciji RCM: 0
# Broj igraca na poziciji CM: 0
# Broj igraca na poziciji LCM: 0
# Broj igraca na poziciji LM: 0
# Broj igraca na poziciji RAM: 0
# Broj igraca na poziciji CAM: 0
# Broj igraca na poziciji LAM: 0
#
# ODBRANA: 0 (0.0)
# Broj igraca na poziciji RWB 0
# Broj igraca na poziciji RB 0
# Broj igraca na poziciji RCB 0
# Broj igraca na poziciji CB 0
# Broj igraca na poziciji LCB 0
# Broj igraca na poziciji LB 0
# Broj igraca na poziciji LWB 0
#
# GOLMANI: 0 (0.0)

# %%
dbscan = DBSCAN(min_samples=7)
dbscan.fit(df[numeric])
dbscan.labels_

count = Counter(dbscan.labels_)
number_and_percentige_per_cluster = {}

for value, times in count.most_common():
    number_and_percentige_per_cluster[value] = [times, (times / len(df)) * 100]
    
number_and_percentige_per_cluster
# Out:
# {1: 10636, -1: 6049, 0: 1514, 2: 4, 3: 4}

# %%
df['cluster_marks'] = dbscan.labels_

df_cluster_minus_1 = df.loc[df['cluster_marks'] == -1]
df_cluster_0 = df.loc[df['cluster_marks'] == 0]
df_cluster_1 = df.loc[df['cluster_marks'] == 1]
df_cluster_2 = df.loc[df['cluster_marks'] == 2]
df_cluster_3 = df.loc[df['cluster_marks'] == 3]

show_position_percentige_per_cluster(df_cluster_minus_1, -1, len(df))
show_position_percentige_per_cluster(df_cluster_0, 0, len(df))
show_position_percentige_per_cluster(df_cluster_1, 1, len(df))
show_position_percentige_per_cluster(df_cluster_2, 2, len(df))
show_position_percentige_per_cluster(df_cluster_3, 3, len(df))
# Out:
# Broj igraca u klasteru -1: 6049, (0.33223485472620423)
#
# NAPAD: 1441 (0.23822119358571664)
# Broj igraca na poziciji RF: 8
# Broj igraca na poziciji LF: 9
# Broj igraca na poziciji RW: 175
# Broj igraca na poziciji LW: 167
# Broj igraca na poziciji ST: 844
# Broj igraca na poziciji CF: 37
# Broj igraca na poziciji RS: 100
# Broj igraca na poziciji LS: 101
#
# VEZNI RED: 2203 (0.3641924285005786)
# Broj igraca na poziciji RDM: 67
# Broj igraca na poziciji CDM: 266
# Broj igraca na poziciji LDM: 80
# Broj igraca na poziciji RM: 433
# Broj igraca na poziciji RCM: 103
# Broj igraca na poziciji CM: 300
# Broj igraca na poziciji LCM: 103
# Broj igraca na poziciji LM: 437
# Broj igraca na poziciji RAM: 16
# Broj igraca na poziciji CAM: 382
# Broj igraca na poziciji LAM: 16
#
# ODBRANA: 1894 (0.3131096048933708)
# Broj igraca na poziciji RWB 19
# Broj igraca na poziciji RB 321
# Broj igraca na poziciji RCB 292
# Broj igraca na poziciji CB 612
# Broj igraca na poziciji LCB 294
# Broj igraca na poziciji LB 336
# Broj igraca na poziciji LWB 20
#
# GOLMANI: 511 (0.08447677302033393)
#
# Broj igraca u klasteru 0: 1514, (0.08315483055967485)
#
# NAPAD: 0 (0.0)
# Broj igraca na poziciji RF: 0
# Broj igraca na poziciji LF: 0
# Broj igraca na poziciji RW: 0
# Broj igraca na poziciji LW: 0
# Broj igraca na poziciji ST: 0
# Broj igraca na poziciji CF: 0
# Broj igraca na poziciji RS: 0
# Broj igraca na poziciji LS: 0
#
# VEZNI RED: 0 (0.0)
# Broj igraca na poziciji RDM: 0
# Broj igraca na poziciji CDM: 0
# Broj igraca na poziciji LDM: 0
# Broj igraca na poziciji RM: 0
# Broj igraca na poziciji RCM: 0
# Broj igraca na poziciji CM: 0
# Broj igraca na poziciji LCM: 0
# Broj igraca na poziciji LM: 0
# Broj igraca na poziciji RAM: 0
# Broj igraca na poziciji CAM: 0
# Broj igraca na poziciji LAM: 0
#
# ODBRANA: 0 (0.0)
# Broj igraca na poziciji RWB 0
# Broj igraca na poziciji RB 0
# Broj igraca na poziciji RCB 0
# Broj igraca na poziciji CB 0
# Broj igraca na poziciji LCB 0
# Broj igraca na poziciji LB 0
# Broj igraca na poziciji LWB 0
#
# GOLMANI: 1514 (1.0)
#
# Broj igraca u klasteru 1: 10636, (0.5841709232712693)
#
# NAPAD: 2030 (0.19086122602482136)
# Broj igraca na poziciji RF: 8
# Broj igraca na poziciji LF: 6
# Broj igraca na poziciji RW: 194
# Broj igraca na poziciji LW: 214
# Broj igraca na poziciji ST: 1364
# Broj igraca na poziciji CF: 37
# Broj igraca na poziciji RS: 101
# Broj igraca na poziciji LS: 106
#
# VEZNI RED: 4634 (0.4356901090635577)
# Broj igraca na poziciji RDM: 181
# Broj igraca na poziciji CDM: 682
# Broj igraca na poziciji LDM: 163
# Broj igraca na poziciji RM: 691
# Broj igraca na poziciji RCM: 288
# Broj igraca na poziciji CM: 1094
# Broj igraca na poziciji LCM: 292
# Broj igraca na poziciji LM: 658
# Broj igraca na poziciji RAM: 5
# Broj igraca na poziciji CAM: 575
# Broj igraca na poziciji LAM: 5
#
# ODBRANA: 3972 (0.37344866491162093)
# Broj igraca na poziciji RWB 68
# Broj igraca na poziciji RB 970
# Broj igraca na poziciji RCB 370
# Broj igraca na poziciji CB 1166
# Broj igraca na poziciji LCB 354
# Broj igraca na poziciji LB 986
# Broj igraca na poziciji LWB 58
#
# GOLMANI: 0 (0.0)
#
# Broj igraca u klasteru 2: 4, (0.00021969572142582522)
#
# NAPAD: 3 (0.75)
# Broj igraca na poziciji RF: 0
# Broj igraca na poziciji LF: 0
# Broj igraca na poziciji RW: 1
# Broj igraca na poziciji LW: 0
# Broj igraca na poziciji ST: 0
# Broj igraca na poziciji CF: 0
# Broj igraca na poziciji RS: 2
# Broj igraca na poziciji LS: 0
#
# VEZNI RED: 1 (0.25)
# Broj igraca na poziciji RDM: 0
# Broj igraca na poziciji CDM: 0
# Broj igraca na poziciji LDM: 0
# Broj igraca na poziciji RM: 0
# Broj igraca na poziciji RCM: 0
# Broj igraca na poziciji CM: 0
# Broj igraca na poziciji LCM: 0
# Broj igraca na poziciji LM: 0
# Broj igraca na poziciji RAM: 0
# Broj igraca na poziciji CAM: 1
# Broj igraca na poziciji LAM: 0
#
# ODBRANA: 0 (0.0)
# Broj igraca na poziciji RWB 0
# Broj igraca na poziciji RB 0
# Broj igraca na poziciji RCB 0
# Broj igraca na poziciji CB 0
# Broj igraca na poziciji LCB 0
# Broj igraca na poziciji LB 0
# Broj igraca na poziciji LWB 0
#
# GOLMANI: 0 (0.0)
#
# Broj igraca u klasteru 3: 4, (0.00021969572142582522)
#
# NAPAD: 4 (1.0)
# Broj igraca na poziciji RF: 0
# Broj igraca na poziciji LF: 0
# Broj igraca na poziciji RW: 0
# Broj igraca na poziciji LW: 0
# Broj igraca na poziciji ST: 4
# Broj igraca na poziciji CF: 0
# Broj igraca na poziciji RS: 0
# Broj igraca na poziciji LS: 0
#
# VEZNI RED: 0 (0.0)
# Broj igraca na poziciji RDM: 0
# Broj igraca na poziciji CDM: 0
# Broj igraca na poziciji LDM: 0
# Broj igraca na poziciji RM: 0
# Broj igraca na poziciji RCM: 0
# Broj igraca na poziciji CM: 0
# Broj igraca na poziciji LCM: 0
# Broj igraca na poziciji LM: 0
# Broj igraca na poziciji RAM: 0
# Broj igraca na poziciji CAM: 0
# Broj igraca na poziciji LAM: 0
#
# ODBRANA: 0 (0.0)
# Broj igraca na poziciji RWB 0
# Broj igraca na poziciji RB 0
# Broj igraca na poziciji RCB 0
# Broj igraca na poziciji CB 0
# Broj igraca na poziciji LCB 0
# Broj igraca na poziciji LB 0
# Broj igraca na poziciji LWB 0
#
# GOLMANI: 0 (0.0)
